# %% [markdown]
# Hier werden die Portfolio-Methoden angewandt und mithilfe der Performance-Metriken bewertet. Die Ergebnisse werden in CSV-Dateien festgehalten. Das Akquirieren, modifizieren und beschreiben der Daten befindet sich der Übersicht halber im Notebook Datenbasis. Die Daten werden dort als CSV exportiert und hier als Dataframe wieder eingelesen.
#
# Die Korrektheit der implementierten Methoden und Metriken wird in dem separaten Notebook Verifizierung anhand eines kleinen Teilbestandes aufgezeigt, siehe dazu auch beigefügte Excel-Dateien, in denen die Portfolio-Gewichte "per Hand" nachgerechnet und mit den Ergebnissen aus der Python-Implementierung abgeglichen werden.
#
# ACHTUNG: LANGE LAUFZEIT!

# %% [markdown]
# ## Importe

# %%
#Import der notwendigen Bibliotheken, Installation mit pip bereits erfolgt

import yfinance as yf
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import csv
from scipy.optimize import minimize
import math
import random
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import linkage, dendrogram
import riskfolio as rp
from sklearn.covariance import LedoitWolf
from scipy.spatial.distance import squareform
from riskfolio import HCPortfolio as hc
from pandas.tseries.offsets import MonthBegin
from pandas.tseries.offsets import MonthEnd

# %% [markdown]
# ## Einlesen der Daten

# %%
#Bearbeitete JSE-Daten (Gesamtbestand)

df_JSE = pd.read_csv(
    'WhartonFinal_Neu.csv',
    sep=',',
    encoding='utf-8',
    index_col=0,
    decimal = '.',
    low_memory=False,
    parse_dates=['Date'],
    dayfirst=True
)

# %%
df_JSE.info
# Out:
# <bound method DataFrame.info of                  8303  15604   15618  16179  16183  16291   16305  16355  \
# Date
# 2005-06-01  39.000000  62.11   74.50  14.50   8.60   4.42   82.40   9.95
# 2005-06-02  38.800000  62.00   75.00  14.51   8.51   4.40   82.50   9.80
# 2005-06-03  37.903333  60.79   75.64  14.50   8.50   4.37   82.61   9.90
# 2005-06-06  37.006667  60.75   78.49  13.85   8.62   4.38   82.90   9.90
# 2005-06-07  36.110000  60.90   77.90  13.89   8.67   4.43   83.45   9.90
# ...               ...    ...     ...    ...    ...    ...     ...    ...
# 2025-05-26        NaN    NaN  256.98    NaN  12.95    NaN  168.45    NaN
# 2025-05-27        NaN    NaN  255.97    NaN  13.08    NaN  168.48    NaN
# 2025-05-28        NaN    NaN  257.02    NaN  13.10    NaN  173.00    NaN
# 2025-05-29        NaN    NaN  259.83    NaN  13.32    NaN  175.79    NaN
# 2025-05-30        NaN    NaN  255.50    NaN  13.49    NaN  173.32    NaN
#
#             16356   16610  ...  364340  364439  364518  364519  364717  \
# Date                       ...
# 2005-06-01  23.60  296.00  ...     NaN     NaN     NaN     NaN     NaN
# 2005-06-02  23.40  296.00  ...     NaN     NaN     NaN     NaN     NaN
# 2005-06-03  23.40  290.00  ...     NaN     NaN     NaN     NaN     NaN
# 2005-06-06  23.50  287.00  ...     NaN     NaN     NaN     NaN     NaN
# 2005-06-07  23.50  278.00  ...     NaN     NaN     NaN     NaN     NaN
# ...           ...     ...  ...     ...     ...     ...     ...     ...
# 2025-05-26  42.01  748.00  ...   53.35   10.34   10.47   10.08   10.01
# 2025-05-27  42.50  736.81  ...   53.71   10.39   10.49   10.17   10.02
# 2025-05-28  42.07  724.26  ...   53.96   10.40   10.55   10.32   10.05
# 2025-05-29  42.68  719.83  ...   53.69   10.33   10.55   10.25    9.99
# 2025-05-30  44.00  704.72  ...   54.11   10.45   10.58   10.31   10.12
#
#             365459  365648  366651  366185  366905
# Date
# 2005-06-01     NaN     NaN     NaN     NaN     NaN
# 2005-06-02     NaN     NaN     NaN     NaN     NaN
# 2005-06-03     NaN     NaN     NaN     NaN     NaN
# 2005-06-06     NaN     NaN     NaN     NaN     NaN
# 2005-06-07     NaN     NaN     NaN     NaN     NaN
# ...            ...     ...     ...     ...     ...
# 2025-05-26   20.17  101.22    9.69   10.15    9.92
# 2025-05-27   20.22  101.23    9.76   10.15    9.92
# 2025-05-28   20.23  101.28    9.79   10.15    9.92
# 2025-05-29   20.08  101.32    9.82   10.31    9.93
# 2025-05-30   20.35  101.32    9.94   10.32    9.93
#
# [5173 rows x 350 columns]>

# %% [markdown]
# ## Definition der Methoden und Metriken

# %% [markdown]
# #### Equally-Weighted Portfolio

# %%
#Rückgabe gleicher Gewichte anhand der Anzahl der Unternehmen (Input Returns)

def equally_weighted(returns):
    anzahl_assets = returns.shape[1]

    w0 = 1/anzahl_assets
    gewichte = np.full(anzahl_assets, w0)

    return gewichte

# %% [markdown]
# #### Minimum-Variance Portfolio

# %%
#Minimum-Variance Portfolio
#Code adaptiert von https://medium.com/@BorisGerat/mean-variance-and-minimum-variance-portfolio-models-in-python-64a5c6b57b2d

def min_variance_opt(matrix):
    
    #Compute the minimum-variance portfolio weights subject to the constraints of:
    #- No short-selling (weights must be >= 0)
    #- Full investment (sum of weights must equal 1)
    
    number_of_assets = matrix.shape[0]

    # Define the objective function to minimize portfolio variance
    def objective(w):
        portfolio_variance = np.dot(w, matrix @ w)
        return portfolio_variance

    # Constraint: The sum of portfolio weights must be equal to 1
    constraints = [{'type': 'eq', 'fun': lambda w: np.sum(w) - 1}]

    # Bounds: Each weight must be between 0 and 1 (no short-selling)
    bounds = [[0, 1] for _ in range(number_of_assets)]

    # Initial guess: Equal weights for all assets
    w0 = np.ones(number_of_assets) / number_of_assets

    # Solve the optimization problem using Sequential Least Squares Quadratic Programming (SLSQP)
    res = minimize(objective, w0, method='SLSQP', bounds=bounds, constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    
    return res.x  # Return the optimal weights

# %% [markdown]
# #### Maximum Diversification Portfolio

# %%
#Code von https://thequantmba.wordpress.com/2017/06/06/max-diversification-in-python/ adaptiert

def calc_max_diversification_ratio(weights, matrix):
    
    # gewichtete Volatilität
    average_vol = np.dot(np.sqrt(np.diag(matrix)), weights.T)
    
    # portfolio volatilität
    portfolio_variance = np.dot(weights, matrix @ weights)
    portfolio_vol = np.sqrt(portfolio_variance)
    
    #Bestimmung Ratio
    diversification_ratio = average_vol/portfolio_vol
    
    # Negativer Wert für Minimierung (Maximizieren = Minimieren -)
    return -diversification_ratio

# %%
#Code von https://thequantmba.wordpress.com/2017/06/06/max-diversification-in-python/ adaptiert

def max_diversification_portfolio(matrix):
    
    anzahl_assets = matrix.shape[0]
    
    w0 = 1/anzahl_assets
    w = np.full(anzahl_assets, w0)
    
    # Constraint: The sum of portfolio weights must be equal to 1
    constraints = [{'type': 'eq', 'fun': lambda w: np.sum(w) - 1}]
    
    # Bounds: Each weight must be between 0 and 1 (no short-selling)
    bounds = [[0, 1] for _ in range(anzahl_assets)]
    
    res = minimize(calc_max_diversification_ratio, w, bounds=bounds, args=(matrix), method='SLSQP', constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    return res.x

# %% [markdown]
# #### Inverse Volatility Portfolio

# %%
#Code adaptiert von https://www.kaggle.com/code/vijipai/lesson-4-traditional-portfolio-construction-method

def inverse_volatility_portfolio (matrix):
    
    standardabweichungen = np.sqrt(np.diagonal(matrix))
    invertierte_std = 1/standardabweichungen
    summe_invertierte_std = np.sum(invertierte_std)
    
    inverse_volatility_gewichte = invertierte_std / summe_invertierte_std
    
    return inverse_volatility_gewichte

# %% [markdown]
# #### Equal Risk Contribution Portfolio

# %%
#Code adaptiert von https://medium.com/@deepml1818/building-a-python-based-risk-parity-portfolio-for-trading-40441ecdd84d

def calculate_portfolio_volatility(weights, matrix):
    
    portfolio_variance = np.dot(weights, matrix @ weights)
    portfolio_volatility = np.sqrt(portfolio_variance)
    return portfolio_volatility

def calculate_risk_contribution(weights, matrix):
    portfolio_volatility = calculate_portfolio_volatility(weights, matrix)
    marginal_contribution_zaehler = np.dot(matrix, weights)
    risk_contribution = np.multiply(weights, marginal_contribution_zaehler) / portfolio_volatility
    return risk_contribution

def risk_parity_objective(weights, matrix):
    risk_contribution = calculate_risk_contribution(weights, matrix)
    target_risk = np.mean(risk_contribution)
    return np.sum((risk_contribution - target_risk) ** 2)

# %%
def get_risk_parity_weights(matrix):
    
    number_of_assets = matrix.shape[0]
    w0 = 1/number_of_assets
    initial_weights = np.full(number_of_assets, w0)
    
    constraints = ({'type': 'eq', 'fun': lambda initial_weights: np.sum(initial_weights) - 1})
    bounds = [[0, 1] for _ in range(number_of_assets)]
    
    result = minimize(risk_parity_objective, initial_weights, args=(matrix), method='SLSQP', bounds=bounds, constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    
    return result.x

# %% [markdown]
# #### Hierarchical Risk Parity

# %%
#Aus dem Paper von Lopez De Prado (2016)
def getIVP(cov,**kargs): # Compute the inverse-variance portfolio 
    ivp=1./np.diag(cov) 
    ivp/=ivp.sum() 
    return ivp

# %%
#------------------------------------------------------------------------------ 
def getClusterVar(cov,cItems): # Compute variance per cluster 
    cov_=cov.loc[cItems,cItems] # matrix slice 
    w_=getIVP(cov_).reshape(-1,1) 
    cVar=np.dot(np.dot(w_.T,cov_),w_)[0,0] 
    return cVar

# %%
#------------------------------------------------------------------------------ 
def getQuasiDiag(link): # Sort clustered items by distance 
    link=link.astype(int) 
    sortIx=pd.Series([link[-1,0],link[-1,1]]) 
    numItems=link[-1,3] # number of original items 
    while sortIx.max()>=numItems: 
        sortIx.index=range(0,sortIx.shape[0]*2,2) # make space 
        df0=sortIx[sortIx>=numItems] # find clusters
        i=df0.index;j=df0.values-numItems 
        sortIx[i]=link[j,0] # item 1 
        df0=pd.Series(link[j,1],index=i+1) 
        sortIx = pd.concat([sortIx, df0]) # item 2  ####Anpassung wegen neuer Pandas-Version!
        sortIx=sortIx.sort_index() # re-sort 
        sortIx.index=range(sortIx.shape[0]) # re-index 
    return sortIx.tolist()

# %%
#------------------------------------------------------------------------------ 
def getRecBipart(cov,sortIx): # Compute HRP allocation
    w = pd.Series(1,index=sortIx) 
    cItems=[sortIx] # initialize all items in one cluster 
    while len(cItems)>0: 
        #Bi-Section der Cluster
        cItems = [i[j:k] 
                  for i in cItems 
                  for j, k in ((0, len(i)//2), (len(i)//2, len(i))) 
                  if len(i) > 1]
        for i in range(0, len(cItems), 2): # parse in pairs 
            cItems0=cItems[i] # cluster 1 
            cItems1=cItems[i+1] # cluster 2 
            cVar0=getClusterVar(cov,cItems0) 
            cVar1=getClusterVar(cov,cItems1) 
            alpha=1-cVar0/(cVar0+cVar1) 
            w[cItems0]*=alpha # weight 1 
            w[cItems1]*=1-alpha # weight 2 
    return w

# %%
#------------------------------------------------------------------------------ 
def correlDist(corr): 
    # A distance matrix based on correlation, where 0<=d[i,j]<=1 
    # This is a proper distance metric 
    dist=((1-corr)/2.)**.5 # distance matrix 
    
    #Adjustierung zur condensed_distance_matrix
    condensed_distance_matrix = squareform(X=dist, checks=False)
    
    return condensed_distance_matrix

# %%
def hrp_main(corr, cov, returns): 
    
    #3) cluster 
    dist=correlDist(corr) 
    link=sch.linkage(dist,'single') 
    sortIx=getQuasiDiag(link) 
    sortIx=corr.index[sortIx].tolist() # recover labels 
    df0=corr.loc[sortIx,sortIx] # reorder 
    
    #4) Capital allocation 
    hrp=getRecBipart(cov,sortIx) 
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    hrp_sortiert = hrp.reindex(original_reihenfolge)
    
    array = hrp_sortiert.T.values

    return array

# %% [markdown]
# #### Hierarchical Equal Risk Contribution Portfolio

# %%
#Es wird auf die Implementierung der Riskfolio-Lib zurückgegriffen
#Code adaptiert von #Code adaptiert von https://medium.com/@orenji.eirl/hierarchical-equal-risk-contribution-with-python-and-riskfolio-lib-ec45dd0f9899

def herc (returns):

    # Building the portfolio object
    port = hc(returns=returns)

    # Estimate optimal portfolio:

    model='HERC'
    correlation = 'pearson'
    rm = 'MV'
    rf = 0 
    linkage = 'ward' 
    max_k = 10 
    leaf_order = True 

    gewichte = port.optimization(model=model,
                          correlation=correlation,
                          rm=rm,
                          rf=rf,
                          linkage=linkage,
                          max_k=max_k,
                          leaf_order=leaf_order)
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    gewichte_sortiert = gewichte.reindex(original_reihenfolge)
    
    array = gewichte_sortiert.values.flatten()

    return array

# %% [markdown]
# #### Vergleichs-Metriken

# %%
def gesamt_return(gewichte, returns):

    daily_returns = returns @ gewichte
    total = np.prod(1 + daily_returns) - 1
    
    return total

# %%
def portfolio_return (gewichte, returns):
    
    avg_returns = []
    avg_returns = returns.mean()
    
    pf_return = sum([gewicht * rendite for gewicht, rendite in zip(gewichte, avg_returns)])
    
    return pf_return

# %%
def portfolio_variance (gewichte, returns):
    daily_returns = []
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    pf_var = np.var(daily_returns)
    
    return pf_var

# %%
def portfolio_volatility (gewichte, returns):
    variance = portfolio_variance(gewichte, returns)
    volatility = np.sqrt(variance)
    
    return volatility

# %%
def annualized_return(gewichte, returns):
    daily_returns = returns @ gewichte
    annual = (np.prod(1 + daily_returns))**(252/daily_returns.shape[0]) - 1
    
    return annual

# %%
def annualized_portfolio_return(gewichte, returns):
    pf_return = portfolio_return(gewichte, returns)
    
    return pf_return*252

# %%
def annualized_portfolio_volatility(gewichte, returns):
    pf_volatility = portfolio_volatility(gewichte, returns)
    
    return pf_volatility*np.sqrt(252)

# %%
def sharpe_ratio (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sharpe_ratio_one (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.01
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sharpe_ratio_two (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.02
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio_one (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.01
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio_two (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.02
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sortino_ratio (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def sortino_ratio_one (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.01
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def sortino_ratio_two (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.02
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio_one (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.01
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio_two (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.02
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def maximum_drawdown (gewichte, returns):
    daily_returns = returns @ gewichte
    returns_kumuliert = (1 + daily_returns).cumprod()
    hochpunkte = returns_kumuliert.cummax()
    
    drawdowns = (returns_kumuliert - hochpunkte) / hochpunkte
    max_drawdown = drawdowns.min()
    
    #print(drawdowns)
    return max_drawdown

# %%
def calmar_ratio (gewichte, returns):
    pf_return = portfolio_return(gewichte, returns)
    max_drawdown = maximum_drawdown(gewichte, returns)
    
    calmar_ratio = pf_return / (-max_drawdown)
    
    return calmar_ratio

# %%
def value_at_risk_func(gewichte, returns):
    daily_returns = returns @ gewichte
    sorted_daily_returns = daily_returns.sort_values(ascending = True)
    value_at_risk = np.percentile(sorted_daily_returns, 100*0.05)
    return value_at_risk

# %%
#https://github.com/malctaylor15/VaR-and-Expected-Shortfall-Python/blob/master/Expected%20Shortfall%20and%20Value%20at%20Risk.ipynb

def expected_shortfall(gewichte, returns):
    daily_returns = returns @ gewichte
    sorted_daily_returns = daily_returns.sort_values(ascending = True)
    value_at_risk = value_at_risk_func(gewichte, returns)
    
    expected_shortfall = daily_returns[daily_returns <= value_at_risk].mean()
    
    return expected_shortfall

# %% [markdown]
# #### Sammel-Funktionen zum Berechnen und Speichern der Metriken

# %%
def metriken_equally_weighted(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile1 = {"Methode": "Equally-Weighted",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile1[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile1])], ignore_index=True)

# %%
def metriken_minimum_variance(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile2 = {"Methode": "Minimum_Variance",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile2[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile2])], ignore_index=True)

# %%
def metriken_max_diversification(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile3 = {"Methode": "Max-Diversification",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile3[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile3])], ignore_index=True)

# %%
def metriken_inverse_volatility(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile4 = {"Methode": "Inverse-Volatility",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile4[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile4])], ignore_index=True)

# %%
def metriken_risk_parity(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile5 = {"Methode": "Risk-Parity",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile5[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile5])], ignore_index=True)

# %%
def metriken_hrp(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile6 = {"Methode": "HRP",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile6[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile6])], ignore_index=True)

# %%
def metriken_herc(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile7 = {"Methode": "HERC",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile7[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile7])], ignore_index=True)

# %% [markdown]
# ## Erzeugung Ergebnisse S&P500

# %% [markdown]
# ## Ergebnis-Erzeugung JSE

# %%
returns = df_JSE.pct_change()
returns = returns.where(~df_JSE.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                 8303     15604     15618     16179     16183     16291  \
# Date
# 2005-06-02 -0.005128 -0.001771  0.006711  0.000690 -0.010465 -0.004525
# 2005-06-03 -0.023110 -0.019516  0.008533 -0.000689 -0.001175 -0.006818
# 2005-06-06 -0.023657 -0.000658  0.037678 -0.044828  0.014118  0.002288
# 2005-06-07 -0.024230  0.002469 -0.007517  0.002888  0.005800  0.011416
# 2005-06-08 -0.027970 -0.003284 -0.005135  0.006479  0.014994  0.006772
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26       NaN       NaN  0.013928       NaN -0.001542       NaN
# 2025-05-27       NaN       NaN -0.003930       NaN  0.010039       NaN
# 2025-05-28       NaN       NaN  0.004102       NaN  0.001529       NaN
# 2025-05-29       NaN       NaN  0.010933       NaN  0.016794       NaN
# 2025-05-30       NaN       NaN -0.016665       NaN  0.012763       NaN
#
#                16305     16355     16356     16610  ...    364340    364439  \
# Date                                                ...
# 2005-06-02  0.001214 -0.015075 -0.008475  0.000000  ...       NaN       NaN
# 2005-06-03  0.001333  0.010204  0.000000 -0.020270  ...       NaN       NaN
# 2005-06-06  0.003510  0.000000  0.004274 -0.010345  ...       NaN       NaN
# 2005-06-07  0.006634  0.000000  0.000000 -0.031359  ...       NaN       NaN
# 2005-06-08 -0.005392  0.000000  0.000000 -0.027158  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-26  0.007235       NaN -0.020518 -0.023906  ...  0.003574  0.010753
# 2025-05-27  0.000178       NaN  0.011664 -0.014960  ...  0.006748  0.004836
# 2025-05-28  0.026828       NaN -0.010118 -0.017033  ...  0.004655  0.000962
# 2025-05-29  0.016127       NaN  0.014500 -0.006117  ... -0.005004 -0.006731
# 2025-05-30 -0.014051       NaN  0.030928 -0.020991  ...  0.007823  0.011617
#
#               364518    364519    364717    365459    365648    366651  \
# Date
# 2005-06-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26  0.009643  0.018182  0.000000  0.011535  0.000395  0.006231
# 2025-05-27  0.001910  0.008929  0.000999  0.002479  0.000099  0.007224
# 2025-05-28  0.005720  0.014749  0.002994  0.000495  0.000494  0.003074
# 2025-05-29  0.000000 -0.006783 -0.005970 -0.007415  0.000395  0.003064
# 2025-05-30  0.002844  0.005854  0.013013  0.013446  0.000000  0.012220
#
#               366185    366905
# Date
# 2005-06-02       NaN       NaN
# 2005-06-03       NaN       NaN
# 2005-06-06       NaN       NaN
# 2005-06-07       NaN       NaN
# 2005-06-08       NaN       NaN
# ...              ...       ...
# 2025-05-26 -0.000984  0.000000
# 2025-05-27  0.000000  0.000000
# 2025-05-28  0.000000  0.000000
# 2025-05-29  0.015764  0.001008
# 2025-05-30  0.000970  0.000000
#
# [5172 rows x 350 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 1
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    #Inf-Werte in NaN umwandeln
    training_daten = training_daten.replace([np.inf, -np.inf], np.nan)
    #Spalten entfernen, die nachher noch NaN enthalten
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = training_daten.cov()
    corr_matrix = training_daten.corr()
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    JSE_gewichte_equally_weighted = equally_weighted(training_daten)
    JSE_gewichte_min_variance= min_variance_opt(cov_matrix)
    JSE_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    JSE_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    JSE_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    JSE_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    JSE_gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": JSE_gewichte_equally_weighted,
    "Minimum-Variance": JSE_gewichte_min_variance,
    "Maximum-Diversification": JSE_gewichte_max_diversification,
    "Inverse-Volatility": JSE_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": JSE_gewichte_risk_parity,
    "HRP": JSE_gewichte_hrp,
    "HERC": JSE_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
    #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
# Alle Testperioden zusammenführen
portfolio_returns_df_JSE = pd.concat(portfolio_returns_list)
portfolio_returns_df_JSE = portfolio_returns_df_JSE.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3615321147770287e-05
#             Iterations: 203
#             Function evaluations: 18676
#             Gradient evaluations: 203
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.933403368098824
#             Iterations: 59
#             Function evaluations: 5491
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0304397525905373e-08
#             Iterations: 40
#             Function evaluations: 3680
#             Gradient evaluations: 40
# 2005-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9834372168493496e-05
#             Iterations: 215
#             Function evaluations: 20425
#             Gradient evaluations: 215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.638825048320111
#             Iterations: 56
#             Function evaluations: 5377
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.464669064967967e-09
#             Iterations: 62
#             Function evaluations: 5891
#             Gradient evaluations: 62
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9368549284297376e-05
#             Iterations: 233
#             Function evaluations: 23067
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7607881359932005
#             Iterations: 54
#             Function evaluations: 5396
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.84485140414553e-09
#             Iterations: 57
#             Function evaluations: 5643
#             Gradient evaluations: 57
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8981528801815677e-05
#             Iterations: 236
#             Function evaluations: 23129
#             Gradient evaluations: 236
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.705461677475638
#             Iterations: 49
#             Function evaluations: 4846
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.17468104493759e-08
#             Iterations: 46
#             Function evaluations: 4508
#             Gradient evaluations: 46
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.936011036455246e-05
#             Iterations: 248
#             Function evaluations: 25048
#             Gradient evaluations: 248
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7972048378902628
#             Iterations: 79
#             Function evaluations: 7738
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.179470436470115e-08
#             Iterations: 46
#             Function evaluations: 4647
#             Gradient evaluations: 46
# 2005-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9187745400549496e-05
#             Iterations: 228
#             Function evaluations: 22116
#             Gradient evaluations: 228
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8497870512613517
#             Iterations: 58
#             Function evaluations: 5291
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.6227110364230005e-09
#             Iterations: 86
#             Function evaluations: 8344
#             Gradient evaluations: 86
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8124150035108806e-05
#             Iterations: 228
#             Function evaluations: 22117
#             Gradient evaluations: 228
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8608492393563756
#             Iterations: 57
#             Function evaluations: 5587
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.278883445865177e-09
#             Iterations: 84
#             Function evaluations: 8150
#             Gradient evaluations: 84
# 2006-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7582697701821466e-05
#             Iterations: 238
#             Function evaluations: 24038
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.125666411299673
#             Iterations: 57
#             Function evaluations: 5817
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.016074443016164e-09
#             Iterations: 75
#             Function evaluations: 7577
#             Gradient evaluations: 75
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8075356950244162e-05
#             Iterations: 219
#             Function evaluations: 22119
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.119056939023159
#             Iterations: 64
#             Function evaluations: 6119
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.12092244785794e-09
#             Iterations: 69
#             Function evaluations: 6970
#             Gradient evaluations: 69
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.894041319342946e-05
#             Iterations: 207
#             Function evaluations: 21321
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.173159354799049
#             Iterations: 57
#             Function evaluations: 5929
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.660032493613054e-09
#             Iterations: 65
#             Function evaluations: 6697
#             Gradient evaluations: 65
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0744289448173447e-05
#             Iterations: 212
#             Function evaluations: 22261
#             Gradient evaluations: 212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9891148563572303
#             Iterations: 62
#             Function evaluations: 6569
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.3915402297846215e-09
#             Iterations: 60
#             Function evaluations: 6303
#             Gradient evaluations: 60
# 2006-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2784100450600194e-05
#             Iterations: 215
#             Function evaluations: 21930
#             Gradient evaluations: 215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9412359559070227
#             Iterations: 60
#             Function evaluations: 6181
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0492775968037413e-08
#             Iterations: 49
#             Function evaluations: 5000
#             Gradient evaluations: 49
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9669338974922165e-05
#             Iterations: 209
#             Function evaluations: 20900
#             Gradient evaluations: 209
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.069917369583879
#             Iterations: 157
#             Function evaluations: 16171
#             Gradient evaluations: 153
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0551612246507073e-08
#             Iterations: 52
#             Function evaluations: 5203
#             Gradient evaluations: 52
# 2006-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2443049969624329e-05
#             Iterations: 242
#             Function evaluations: 25168
#             Gradient evaluations: 242
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.716754184860825
#             Iterations: 77
#             Function evaluations: 7996
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.926862470662092e-09
#             Iterations: 38
#             Function evaluations: 3955
#             Gradient evaluations: 38
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2160015495073515e-05
#             Iterations: 218
#             Function evaluations: 22236
#             Gradient evaluations: 218
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.664816523403831
#             Iterations: 73
#             Function evaluations: 7524
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.825969026814816e-09
#             Iterations: 45
#             Function evaluations: 4592
#             Gradient evaluations: 45
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.481076141385662e-05
#             Iterations: 211
#             Function evaluations: 21733
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.179745410090601
#             Iterations: 186
#             Function evaluations: 19752
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.237499753391388e-08
#             Iterations: 41
#             Function evaluations: 4224
#             Gradient evaluations: 41
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4817242440299363e-05
#             Iterations: 272
#             Function evaluations: 28288
#             Gradient evaluations: 272
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.174448800549267
#             Iterations: 71
#             Function evaluations: 7458
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2519256563054283e-08
#             Iterations: 40
#             Function evaluations: 4160
#             Gradient evaluations: 40
# 2006-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4479117600721668e-05
#             Iterations: 265
#             Function evaluations: 28355
#             Gradient evaluations: 265
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.136279488412318
#             Iterations: 75
#             Function evaluations: 8106
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1044359815691798e-08
#             Iterations: 37
#             Function evaluations: 3960
#             Gradient evaluations: 37
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4078919316612832e-05
#             Iterations: 236
#             Function evaluations: 26668
#             Gradient evaluations: 236
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.002574094235538
#             Iterations: 73
#             Function evaluations: 8325
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.138263362945413e-08
#             Iterations: 32
#             Function evaluations: 3617
#             Gradient evaluations: 32
# 2007-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3734362347049722e-05
#             Iterations: 247
#             Function evaluations: 28158
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.080869773927967
#             Iterations: 75
#             Function evaluations: 8168
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1952074182536956e-08
#             Iterations: 32
#             Function evaluations: 3649
#             Gradient evaluations: 32
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6653695917188233e-05
#             Iterations: 243
#             Function evaluations: 27216
#             Gradient evaluations: 243
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.799392462910472
#             Iterations: 69
#             Function evaluations: 7686
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3198486824659781e-08
#             Iterations: 43
#             Function evaluations: 4817
#             Gradient evaluations: 43
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6760157608104257e-05
#             Iterations: 245
#             Function evaluations: 26705
#             Gradient evaluations: 245
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9643506120057874
#             Iterations: 65
#             Function evaluations: 7151
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.655477670606818e-08
#             Iterations: 43
#             Function evaluations: 4688
#             Gradient evaluations: 43
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.763676474037628e-05
#             Iterations: 206
#             Function evaluations: 22660
#             Gradient evaluations: 206
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.030243797268325
#             Iterations: 68
#             Function evaluations: 7552
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3965045160323806e-08
#             Iterations: 35
#             Function evaluations: 3852
#             Gradient evaluations: 35
# 2007-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2644203639671148e-05
#             Iterations: 195
#             Function evaluations: 20866
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8106292062312397
#             Iterations: 137
#             Function evaluations: 14852
#             Gradient evaluations: 133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0418046296338997e-08
#             Iterations: 59
#             Function evaluations: 6315
#             Gradient evaluations: 59
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.814951581649187e-05
#             Iterations: 240
#             Function evaluations: 25921
#             Gradient evaluations: 240
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.006581838423652
#             Iterations: 184
#             Function evaluations: 20483
#             Gradient evaluations: 180
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4040842065800533e-08
#             Iterations: 60
#             Function evaluations: 6483
#             Gradient evaluations: 60
# 2007-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9895094129948338e-05
#             Iterations: 237
#             Function evaluations: 25834
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9569802141897923
#             Iterations: 66
#             Function evaluations: 7261
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2680035022906902e-08
#             Iterations: 55
#             Function evaluations: 5995
#             Gradient evaluations: 55
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.337792362563132e-05
#             Iterations: 192
#             Function evaluations: 20928
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.807486762929132
#             Iterations: 138
#             Function evaluations: 15267
#             Gradient evaluations: 134
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1893546163990953e-08
#             Iterations: 54
#             Function evaluations: 5887
#             Gradient evaluations: 54
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3105272598929205e-05
#             Iterations: 207
#             Function evaluations: 23185
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.004269418346111
#             Iterations: 166
#             Function evaluations: 19047
#             Gradient evaluations: 162
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.384597351150247e-09
#             Iterations: 56
#             Function evaluations: 6273
#             Gradient evaluations: 56
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.382252774274513e-05
#             Iterations: 194
#             Function evaluations: 21146
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.0434776196720685
#             Iterations: 62
#             Function evaluations: 6822
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4471865685812507e-08
#             Iterations: 92
#             Function evaluations: 10028
#             Gradient evaluations: 92
# 2007-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.054149437032259e-05
#             Iterations: 202
#             Function evaluations: 22423
#             Gradient evaluations: 202
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9461922425957106
#             Iterations: 59
#             Function evaluations: 6606
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.072775127402733e-08
#             Iterations: 105
#             Function evaluations: 11655
#             Gradient evaluations: 105
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0928816817276644e-05
#             Iterations: 211
#             Function evaluations: 23210
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.285034498379196
#             Iterations: 125
#             Function evaluations: 13863
#             Gradient evaluations: 121
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0767873918191264e-08
#             Iterations: 119
#             Function evaluations: 13090
#             Gradient evaluations: 119
# 2008-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.166356439763493e-05
#             Iterations: 208
#             Function evaluations: 22881
#             Gradient evaluations: 208
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.343059831915097
#             Iterations: 67
#             Function evaluations: 7329
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.271227804654102e-08
#             Iterations: 104
#             Function evaluations: 11441
#             Gradient evaluations: 104
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.161165558403647e-05
#             Iterations: 213
#             Function evaluations: 22791
#             Gradient evaluations: 213
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.342131947719348
#             Iterations: 70
#             Function evaluations: 7132
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.112255688239972e-08
#             Iterations: 138
#             Function evaluations: 14766
#             Gradient evaluations: 138
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1501076090784954e-05
#             Iterations: 219
#             Function evaluations: 22776
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.481980841365111
#             Iterations: 59
#             Function evaluations: 6201
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3387241939987994e-08
#             Iterations: 110
#             Function evaluations: 11441
#             Gradient evaluations: 110
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.4818450830765085e-05
#             Iterations: 232
#             Function evaluations: 24360
#             Gradient evaluations: 232
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.493754758692053
#             Iterations: 139
#             Function evaluations: 14866
#             Gradient evaluations: 135
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1582113743161418e-08
#             Iterations: 133
#             Function evaluations: 13965
#             Gradient evaluations: 133
# 2008-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.372456788022075e-05
#             Iterations: 212
#             Function evaluations: 22048
#             Gradient evaluations: 212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.571707784695147
#             Iterations: 59
#             Function evaluations: 6200
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.233490348553873e-08
#             Iterations: 134
#             Function evaluations: 13937
#             Gradient evaluations: 134
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.403082620131643e-05
#             Iterations: 218
#             Function evaluations: 22018
#             Gradient evaluations: 218
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.385809723543719
#             Iterations: 58
#             Function evaluations: 5919
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3915656855465744e-08
#             Iterations: 134
#             Function evaluations: 13535
#             Gradient evaluations: 134
# 2008-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.617641590705157e-05
#             Iterations: 224
#             Function evaluations: 21952
#             Gradient evaluations: 224
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.097994435919275
#             Iterations: 61
#             Function evaluations: 6039
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5285527448018285e-08
#             Iterations: 144
#             Function evaluations: 14112
#             Gradient evaluations: 144
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2442093250581626e-05
#             Iterations: 214
#             Function evaluations: 20544
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9794202662160187
#             Iterations: 61
#             Function evaluations: 5817
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.540455166886164e-08
#             Iterations: 154
#             Function evaluations: 14784
#             Gradient evaluations: 154
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0335495260028077e-05
#             Iterations: 215
#             Function evaluations: 21070
#             Gradient evaluations: 215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.002879305077291
#             Iterations: 94
#             Function evaluations: 8938
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8233868044612594e-08
#             Iterations: 165
#             Function evaluations: 16170
#             Gradient evaluations: 165
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8818731553314637e-05
#             Iterations: 227
#             Function evaluations: 21566
#             Gradient evaluations: 227
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.025365678676267
#             Iterations: 62
#             Function evaluations: 5951
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1441569144747736e-08
#             Iterations: 145
#             Function evaluations: 13776
#             Gradient evaluations: 145
# 2008-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9900258396541844e-05
#             Iterations: 207
#             Function evaluations: 19665
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.346867935122678
#             Iterations: 75
#             Function evaluations: 6838
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.617631257413583e-08
#             Iterations: 70
#             Function evaluations: 6651
#             Gradient evaluations: 70
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7057408502798892e-05
#             Iterations: 212
#             Function evaluations: 20565
#             Gradient evaluations: 212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.485743470464168
#             Iterations: 73
#             Function evaluations: 6774
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.691352033795173e-08
#             Iterations: 82
#             Function evaluations: 7954
#             Gradient evaluations: 82
# 2009-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.567545989712703e-05
#             Iterations: 225
#             Function evaluations: 21376
#             Gradient evaluations: 225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.537910768271085
#             Iterations: 67
#             Function evaluations: 6349
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7136536005915345e-08
#             Iterations: 71
#             Function evaluations: 6746
#             Gradient evaluations: 71
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5392184484098805e-05
#             Iterations: 215
#             Function evaluations: 20210
#             Gradient evaluations: 215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.358483695218873
#             Iterations: 65
#             Function evaluations: 6182
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.584566180932354e-08
#             Iterations: 84
#             Function evaluations: 7896
#             Gradient evaluations: 84
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.463662476077884e-05
#             Iterations: 223
#             Function evaluations: 20740
#             Gradient evaluations: 223
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.344820715168629
#             Iterations: 64
#             Function evaluations: 6023
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7498217717625694e-08
#             Iterations: 61
#             Function evaluations: 5674
#             Gradient evaluations: 61
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2612482334017115e-05
#             Iterations: 237
#             Function evaluations: 22041
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.4549680401543394
#             Iterations: 63
#             Function evaluations: 5840
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0525866881756939e-08
#             Iterations: 67
#             Function evaluations: 6232
#             Gradient evaluations: 67
# 2009-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2555997583712954e-05
#             Iterations: 225
#             Function evaluations: 20700
#             Gradient evaluations: 225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.250268269342555
#             Iterations: 59
#             Function evaluations: 5492
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.10749259605834e-09
#             Iterations: 57
#             Function evaluations: 5244
#             Gradient evaluations: 57
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.282766301648939e-05
#             Iterations: 198
#             Function evaluations: 18414
#             Gradient evaluations: 198
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.148394848811104
#             Iterations: 57
#             Function evaluations: 5354
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2296769074862923e-08
#             Iterations: 65
#             Function evaluations: 6045
#             Gradient evaluations: 65
# 2009-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5147715821216296e-05
#             Iterations: 186
#             Function evaluations: 16741
#             Gradient evaluations: 186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.861936488975869
#             Iterations: 54
#             Function evaluations: 4912
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.938368550028148e-09
#             Iterations: 65
#             Function evaluations: 5850
#             Gradient evaluations: 65
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.433084369839155e-05
#             Iterations: 210
#             Function evaluations: 18900
#             Gradient evaluations: 210
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7875110186274985
#             Iterations: 55
#             Function evaluations: 5001
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.444161525708757e-09
#             Iterations: 66
#             Function evaluations: 5941
#             Gradient evaluations: 66
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3154169623762278e-05
#             Iterations: 239
#             Function evaluations: 21033
#             Gradient evaluations: 239
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8551093006660526
#             Iterations: 58
#             Function evaluations: 5072
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.340256736400514e-09
#             Iterations: 67
#             Function evaluations: 5897
#             Gradient evaluations: 67
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.127376830704291e-05
#             Iterations: 270
#             Function evaluations: 23760
#             Gradient evaluations: 270
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.065315108170884
#             Iterations: 75
#             Function evaluations: 6332
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.379517310795006e-09
#             Iterations: 67
#             Function evaluations: 5896
#             Gradient evaluations: 67
# 2009-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.706982410135622e-06
#             Iterations: 243
#             Function evaluations: 21627
#             Gradient evaluations: 243
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.231406058306196
#             Iterations: 62
#             Function evaluations: 5222
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0365957371406383e-08
#             Iterations: 64
#             Function evaluations: 5697
#             Gradient evaluations: 64
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.579453002642917e-06
#             Iterations: 261
#             Function evaluations: 23229
#             Gradient evaluations: 261
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.207368475605077
#             Iterations: 63
#             Function evaluations: 5583
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.035474624839056e-08
#             Iterations: 59
#             Function evaluations: 5251
#             Gradient evaluations: 59
# 2010-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.264068467147832e-06
#             Iterations: 254
#             Function evaluations: 23369
#             Gradient evaluations: 254
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.3929979833658495
#             Iterations: 71
#             Function evaluations: 6231
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0423203844939939e-08
#             Iterations: 51
#             Function evaluations: 4693
#             Gradient evaluations: 51
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.510462968236349e-06
#             Iterations: 242
#             Function evaluations: 22506
#             Gradient evaluations: 242
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.512291196259384
#             Iterations: 58
#             Function evaluations: 5460
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.12090547945896e-09
#             Iterations: 55
#             Function evaluations: 5115
#             Gradient evaluations: 55
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.648860808209932e-06
#             Iterations: 241
#             Function evaluations: 22413
#             Gradient evaluations: 241
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.538338994857766
#             Iterations: 68
#             Function evaluations: 6021
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.83770784997814e-09
#             Iterations: 52
#             Function evaluations: 4837
#             Gradient evaluations: 52
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.71610343354687e-06
#             Iterations: 252
#             Function evaluations: 23688
#             Gradient evaluations: 252
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.552480779363335
#             Iterations: 76
#             Function evaluations: 6887
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.743507418643861e-09
#             Iterations: 55
#             Function evaluations: 5171
#             Gradient evaluations: 55
# 2010-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.61666888702685e-06
#             Iterations: 251
#             Function evaluations: 23343
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.573634709445829
#             Iterations: 103
#             Function evaluations: 9611
#             Gradient evaluations: 99
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0469243431189736e-08
#             Iterations: 54
#             Function evaluations: 5022
#             Gradient evaluations: 54
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.470544738190638e-06
#             Iterations: 255
#             Function evaluations: 23461
#             Gradient evaluations: 255
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.723038063303395
#             Iterations: 86
#             Function evaluations: 7666
#             Gradient evaluations: 82
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.150781377076842e-09
#             Iterations: 46
#             Function evaluations: 4232
#             Gradient evaluations: 46
# 2010-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.652519842344293e-06
#             Iterations: 234
#             Function evaluations: 21762
#             Gradient evaluations: 234
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.559143362942628
#             Iterations: 65
#             Function evaluations: 6120
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0572599901181604e-08
#             Iterations: 34
#             Function evaluations: 3162
#             Gradient evaluations: 34
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.622407439416811e-06
#             Iterations: 245
#             Function evaluations: 23030
#             Gradient evaluations: 245
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.589441151113928
#             Iterations: 68
#             Function evaluations: 6472
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.542493068280282e-09
#             Iterations: 35
#             Function evaluations: 3291
#             Gradient evaluations: 35
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.402578796447832e-06
#             Iterations: 251
#             Function evaluations: 23845
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.180718434535384
#             Iterations: 62
#             Function evaluations: 5954
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.588065460347588e-09
#             Iterations: 46
#             Function evaluations: 4370
#             Gradient evaluations: 46
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.04049930110814e-05
#             Iterations: 242
#             Function evaluations: 22748
#             Gradient evaluations: 242
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9722068100232724
#             Iterations: 114
#             Function evaluations: 10814
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.191770678415593e-09
#             Iterations: 46
#             Function evaluations: 4324
#             Gradient evaluations: 46
# 2010-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2030365357188119e-05
#             Iterations: 249
#             Function evaluations: 23406
#             Gradient evaluations: 249
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.04134571582401
#             Iterations: 60
#             Function evaluations: 5608
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.19799626194163e-09
#             Iterations: 45
#             Function evaluations: 4231
#             Gradient evaluations: 45
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.140691372390868e-05
#             Iterations: 219
#             Function evaluations: 21024
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.115473173182892
#             Iterations: 71
#             Function evaluations: 6509
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.7214086644103935e-09
#             Iterations: 57
#             Function evaluations: 5473
#             Gradient evaluations: 57
# 2011-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.122872497777138e-05
#             Iterations: 230
#             Function evaluations: 22080
#             Gradient evaluations: 230
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.0591444203830385
#             Iterations: 93
#             Function evaluations: 8737
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.522896333399197e-09
#             Iterations: 58
#             Function evaluations: 5569
#             Gradient evaluations: 58
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1264217564400241e-05
#             Iterations: 237
#             Function evaluations: 21804
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.785767349649008
#             Iterations: 53
#             Function evaluations: 4927
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.065962919232599e-08
#             Iterations: 45
#             Function evaluations: 4141
#             Gradient evaluations: 45
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0489778385552461e-05
#             Iterations: 218
#             Function evaluations: 20056
#             Gradient evaluations: 218
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8637428532661526
#             Iterations: 58
#             Function evaluations: 5389
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.07954609061829e-08
#             Iterations: 45
#             Function evaluations: 4141
#             Gradient evaluations: 45
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0330067597651214e-05
#             Iterations: 223
#             Function evaluations: 20740
#             Gradient evaluations: 223
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.871221407193236
#             Iterations: 53
#             Function evaluations: 4887
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.009298419739094e-08
#             Iterations: 45
#             Function evaluations: 4186
#             Gradient evaluations: 45
# 2011-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.015899344088031e-05
#             Iterations: 205
#             Function evaluations: 19066
#             Gradient evaluations: 205
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.847472014643524
#             Iterations: 78
#             Function evaluations: 7038
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0310854254461317e-08
#             Iterations: 45
#             Function evaluations: 4186
# ...
#             Iterations: 403
#             Function evaluations: 55614
#             Gradient evaluations: 403
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.515431650410209
#             Iterations: 98
#             Function evaluations: 13113
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4141652509666567e-08
#             Iterations: 57
#             Function evaluations: 7866
#             Gradient evaluations: 57
# 2022-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.887854444628292e-06
#             Iterations: 351
#             Function evaluations: 47386
#             Gradient evaluations: 351
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.774250999566196
#             Iterations: 106
#             Function evaluations: 13990
#             Gradient evaluations: 102
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4780297537772645e-08
#             Iterations: 45
#             Function evaluations: 6076
#             Gradient evaluations: 45
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.6027701769570896e-06
#             Iterations: 410
#             Function evaluations: 56171
#             Gradient evaluations: 410
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5.936359117906111
#             Iterations: 93
#             Function evaluations: 12325
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2408884342672863e-08
#             Iterations: 45
#             Function evaluations: 6165
#             Gradient evaluations: 45
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.7855279864267455e-06
#             Iterations: 385
#             Function evaluations: 53131
#             Gradient evaluations: 385
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.8485010999594484
#             Iterations: 101
#             Function evaluations: 13620
#             Gradient evaluations: 97
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2565922967484445e-08
#             Iterations: 43
#             Function evaluations: 5934
#             Gradient evaluations: 43
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.366818642764368e-06
#             Iterations: 406
#             Function evaluations: 55217
#             Gradient evaluations: 406
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.911700977533131
#             Iterations: 87
#             Function evaluations: 11399
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1436795107773292e-08
#             Iterations: 44
#             Function evaluations: 5984
#             Gradient evaluations: 44
# 2022-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.008913026211143e-06
#             Iterations: 374
#             Function evaluations: 51238
#             Gradient evaluations: 374
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.038403955701399
#             Iterations: 101
#             Function evaluations: 13467
#             Gradient evaluations: 97
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1714947997162082e-08
#             Iterations: 38
#             Function evaluations: 5206
#             Gradient evaluations: 38
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.6027386547119235e-06
#             Iterations: 389
#             Function evaluations: 52127
#             Gradient evaluations: 389
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.807152266495336
#             Iterations: 98
#             Function evaluations: 12771
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2395015320548784e-08
#             Iterations: 40
#             Function evaluations: 5360
#             Gradient evaluations: 40
# 2023-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.518522749010274e-06
#             Iterations: 421
#             Function evaluations: 56835
#             Gradient evaluations: 421
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.515494773359772
#             Iterations: 190
#             Function evaluations: 26086
#             Gradient evaluations: 186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2694398407737835e-08
#             Iterations: 40
#             Function evaluations: 5400
#             Gradient evaluations: 40
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.386554249121958e-06
#             Iterations: 388
#             Function evaluations: 52380
#             Gradient evaluations: 388
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.704534641269519
#             Iterations: 81
#             Function evaluations: 10916
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3706205490085464e-08
#             Iterations: 30
#             Function evaluations: 4050
#             Gradient evaluations: 30
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.278862181367058e-06
#             Iterations: 384
#             Function evaluations: 51456
#             Gradient evaluations: 384
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.5471653743884675
#             Iterations: 83
#             Function evaluations: 11227
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.430333882465319e-08
#             Iterations: 30
#             Function evaluations: 4020
#             Gradient evaluations: 30
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.60863238420794e-06
#             Iterations: 452
#             Function evaluations: 60568
#             Gradient evaluations: 452
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.512692365748312
#             Iterations: 165
#             Function evaluations: 22313
#             Gradient evaluations: 161
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.789631288509734e-09
#             Iterations: 41
#             Function evaluations: 5494
#             Gradient evaluations: 41
# 2023-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.001658563058949e-06
#             Iterations: 405
#             Function evaluations: 55485
#             Gradient evaluations: 405
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.523213224451437
#             Iterations: 88
#             Function evaluations: 12040
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0304550859664532e-08
#             Iterations: 40
#             Function evaluations: 5480
#             Gradient evaluations: 40
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.662705639540186e-06
#             Iterations: 434
#             Function evaluations: 58156
#             Gradient evaluations: 434
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.2415707266548965
#             Iterations: 80
#             Function evaluations: 10697
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.613351853957479e-09
#             Iterations: 41
#             Function evaluations: 5494
#             Gradient evaluations: 41
# 2023-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.760443299977238e-06
#             Iterations: 422
#             Function evaluations: 58236
#             Gradient evaluations: 422
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.320177629058441
#             Iterations: 85
#             Function evaluations: 11289
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.910874073250607e-09
#             Iterations: 40
#             Function evaluations: 5520
#             Gradient evaluations: 40
# 2023-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.232670260684334e-06
#             Iterations: 366
#             Function evaluations: 51240
#             Gradient evaluations: 366
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.249437405716857
#             Iterations: 95
#             Function evaluations: 12897
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0505139180837352e-08
#             Iterations: 39
#             Function evaluations: 5460
#             Gradient evaluations: 39
# 2023-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.915312849578195e-06
#             Iterations: 381
#             Function evaluations: 53340
#             Gradient evaluations: 381
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.291757291220199
#             Iterations: 95
#             Function evaluations: 12910
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1488510199880109e-08
#             Iterations: 38
#             Function evaluations: 5321
#             Gradient evaluations: 38
# 2023-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.550980306044208e-06
#             Iterations: 398
#             Function evaluations: 56516
#             Gradient evaluations: 398
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5.5369479072451
#             Iterations: 126
#             Function evaluations: 17738
#             Gradient evaluations: 122
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3692233194863388e-08
#             Iterations: 40
#             Function evaluations: 5681
#             Gradient evaluations: 40
# 2023-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.543574671364165e-06
#             Iterations: 414
#             Function evaluations: 59202
#             Gradient evaluations: 414
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.708738045725955
#             Iterations: 111
#             Function evaluations: 15573
#             Gradient evaluations: 107
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.608166785129323e-09
#             Iterations: 53
#             Function evaluations: 7579
#             Gradient evaluations: 53
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.229085142103424e-06
#             Iterations: 423
#             Function evaluations: 60489
#             Gradient evaluations: 423
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5.767671298297545
#             Iterations: 84
#             Function evaluations: 11553
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.233565175021673e-09
#             Iterations: 53
#             Function evaluations: 7579
#             Gradient evaluations: 53
# 2024-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.894784632371921e-06
#             Iterations: 420
#             Function evaluations: 60481
#             Gradient evaluations: 420
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.028979437288607
#             Iterations: 101
#             Function evaluations: 14156
#             Gradient evaluations: 97
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.390491511681232e-09
#             Iterations: 53
#             Function evaluations: 7632
#             Gradient evaluations: 53
# 2024-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.436023218521e-06
#             Iterations: 469
#             Function evaluations: 67536
#             Gradient evaluations: 469
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.892228850641201
#             Iterations: 153
#             Function evaluations: 21748
#             Gradient evaluations: 149
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0310301744781189e-08
#             Iterations: 41
#             Function evaluations: 5904
#             Gradient evaluations: 41
# 2024-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.206653945378704e-06
#             Iterations: 400
#             Function evaluations: 58800
#             Gradient evaluations: 400
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.327692885056988
#             Iterations: 89
#             Function evaluations: 12635
#             Gradient evaluations: 85
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1893533330299483e-08
#             Iterations: 41
#             Function evaluations: 6028
#             Gradient evaluations: 41
# 2024-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.160293154084221e-06
#             Iterations: 416
#             Function evaluations: 61985
#             Gradient evaluations: 416
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.476456917975266
#             Iterations: 119
#             Function evaluations: 17472
#             Gradient evaluations: 115
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2179563307361383e-08
#             Iterations: 40
#             Function evaluations: 5960
#             Gradient evaluations: 40
# 2024-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.451497430237914e-06
#             Iterations: 411
#             Function evaluations: 61650
#             Gradient evaluations: 411
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5.654164997899568
#             Iterations: 91
#             Function evaluations: 13235
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1370600077092205e-08
#             Iterations: 66
#             Function evaluations: 9900
#             Gradient evaluations: 66
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_JSE.to_csv("returnsWharton_neu_f.csv")

# %% [markdown]
# ## Ledoit-Wolf Shrinkage

# %%
#Definition von Ledoit-Shrinkage

def ledoit_shrink (returns):
    
    shrinkage = LedoitWolf().fit(returns.values)
    
    shrinkage_matrix = pd.DataFrame(
        shrinkage.covariance_,
        index = returns.columns,
        columns = returns.columns)
    
    #print(shrinkage.shrinkage_)
    
    return shrinkage_matrix

# %% [markdown]
# ### Auswertung S&P500 mit Ledoit Wolf

# %% [markdown]
# ### Auswertung JSE mit Ledoit Wolf

# %%
returns = df_JSE.pct_change()
returns = returns.where(~df_JSE.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                 8303     15604     15618     16179     16183     16291  \
# Date
# 2005-06-02 -0.005128 -0.001771  0.006711  0.000690 -0.010465 -0.004525
# 2005-06-03 -0.023110 -0.019516  0.008533 -0.000689 -0.001175 -0.006818
# 2005-06-06 -0.023657 -0.000658  0.037678 -0.044828  0.014118  0.002288
# 2005-06-07 -0.024230  0.002469 -0.007517  0.002888  0.005800  0.011416
# 2005-06-08 -0.027970 -0.003284 -0.005135  0.006479  0.014994  0.006772
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26       NaN       NaN  0.013928       NaN -0.001542       NaN
# 2025-05-27       NaN       NaN -0.003930       NaN  0.010039       NaN
# 2025-05-28       NaN       NaN  0.004102       NaN  0.001529       NaN
# 2025-05-29       NaN       NaN  0.010933       NaN  0.016794       NaN
# 2025-05-30       NaN       NaN -0.016665       NaN  0.012763       NaN
#
#                16305     16355     16356     16610  ...    364340    364439  \
# Date                                                ...
# 2005-06-02  0.001214 -0.015075 -0.008475  0.000000  ...       NaN       NaN
# 2005-06-03  0.001333  0.010204  0.000000 -0.020270  ...       NaN       NaN
# 2005-06-06  0.003510  0.000000  0.004274 -0.010345  ...       NaN       NaN
# 2005-06-07  0.006634  0.000000  0.000000 -0.031359  ...       NaN       NaN
# 2005-06-08 -0.005392  0.000000  0.000000 -0.027158  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-26  0.007235       NaN -0.020518 -0.023906  ...  0.003574  0.010753
# 2025-05-27  0.000178       NaN  0.011664 -0.014960  ...  0.006748  0.004836
# 2025-05-28  0.026828       NaN -0.010118 -0.017033  ...  0.004655  0.000962
# 2025-05-29  0.016127       NaN  0.014500 -0.006117  ... -0.005004 -0.006731
# 2025-05-30 -0.014051       NaN  0.030928 -0.020991  ...  0.007823  0.011617
#
#               364518    364519    364717    365459    365648    366651  \
# Date
# 2005-06-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26  0.009643  0.018182  0.000000  0.011535  0.000395  0.006231
# 2025-05-27  0.001910  0.008929  0.000999  0.002479  0.000099  0.007224
# 2025-05-28  0.005720  0.014749  0.002994  0.000495  0.000494  0.003074
# 2025-05-29  0.000000 -0.006783 -0.005970 -0.007415  0.000395  0.003064
# 2025-05-30  0.002844  0.005854  0.013013  0.013446  0.000000  0.012220
#
#               366185    366905
# Date
# 2005-06-02       NaN       NaN
# 2005-06-03       NaN       NaN
# 2005-06-06       NaN       NaN
# 2005-06-07       NaN       NaN
# 2005-06-08       NaN       NaN
# ...              ...       ...
# 2025-05-26 -0.000984  0.000000
# 2025-05-27  0.000000  0.000000
# 2025-05-28  0.000000  0.000000
# 2025-05-29  0.015764  0.001008
# 2025-05-30  0.000970  0.000000
#
# [5172 rows x 350 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 1
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
     #Inf-Werte in NaN umwandeln
    training_daten = training_daten.replace([np.inf, -np.inf], np.nan)
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = ledoit_shrink(training_daten)
    
    #aus der geschrumpften Matrix die Korrelationsmatrix bauen
    standardabweichung = np.sqrt(np.diag(cov_matrix))
    corr_matrix = cov_matrix / np.outer(standardabweichung, standardabweichung)
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    shrinked_JSE_gewichte_equally_weighted = equally_weighted(training_daten)
    shrinked_JSE_gewichte_min_variance= min_variance_opt(cov_matrix)
    shrinked_JSE_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    shrinked_JSE_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    shrinked_JSE_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    shrinked_JSE_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    shrinked_JSE_gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": shrinked_JSE_gewichte_equally_weighted,
    "Minimum-Variance": shrinked_JSE_gewichte_min_variance,
    "Maximum-Diversification": shrinked_JSE_gewichte_max_diversification,
    "Inverse-Volatility": shrinked_JSE_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": shrinked_JSE_gewichte_risk_parity,
    "HRP": shrinked_JSE_gewichte_hrp,
    "HERC": shrinked_JSE_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
    #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_shrinked_JSE = pd.concat(portfolio_returns_list)
portfolio_returns_df_shrinked_JSE = portfolio_returns_df_shrinked_JSE.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6247173870862578e-05
#             Iterations: 127
#             Function evaluations: 11685
#             Gradient evaluations: 127
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.345559178570461
#             Iterations: 74
#             Function evaluations: 6899
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.604880594385927e-09
#             Iterations: 46
#             Function evaluations: 4232
#             Gradient evaluations: 46
# 2005-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4702393050384904e-05
#             Iterations: 159
#             Function evaluations: 15106
#             Gradient evaluations: 159
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.882262312089232
#             Iterations: 60
#             Function evaluations: 5761
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.9154825191145774e-09
#             Iterations: 55
#             Function evaluations: 5225
#             Gradient evaluations: 55
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2455684340575575e-05
#             Iterations: 181
#             Function evaluations: 17919
#             Gradient evaluations: 181
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.892697421992748
#             Iterations: 58
#             Function evaluations: 5704
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.643649613260857e-09
#             Iterations: 46
#             Function evaluations: 4554
#             Gradient evaluations: 46
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1905721427873455e-05
#             Iterations: 194
#             Function evaluations: 19013
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.838242531516152
#             Iterations: 61
#             Function evaluations: 6035
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.960296792192562e-09
#             Iterations: 71
#             Function evaluations: 6958
#             Gradient evaluations: 71
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.28811116076938e-05
#             Iterations: 182
#             Function evaluations: 18383
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.957422878165596
#             Iterations: 62
#             Function evaluations: 6323
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.912404245710241e-09
#             Iterations: 51
#             Function evaluations: 5152
#             Gradient evaluations: 51
# 2005-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2403024335986753e-05
#             Iterations: 191
#             Function evaluations: 18527
#             Gradient evaluations: 191
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.011775106602727
#             Iterations: 68
#             Function evaluations: 6271
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.639349750108595e-09
#             Iterations: 62
#             Function evaluations: 6016
#             Gradient evaluations: 62
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2803481247877877e-05
#             Iterations: 166
#             Function evaluations: 16102
#             Gradient evaluations: 166
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.1025899245858
#             Iterations: 65
#             Function evaluations: 6380
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.893559859239659e-09
#             Iterations: 63
#             Function evaluations: 6112
#             Gradient evaluations: 63
# 2006-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.149850115775406e-05
#             Iterations: 160
#             Function evaluations: 16161
#             Gradient evaluations: 160
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.325659602066308
#             Iterations: 72
#             Function evaluations: 7349
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.511049827436955e-09
#             Iterations: 63
#             Function evaluations: 6364
#             Gradient evaluations: 63
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0928658320089523e-05
#             Iterations: 156
#             Function evaluations: 15757
#             Gradient evaluations: 156
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.360624685331626
#             Iterations: 70
#             Function evaluations: 7049
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.934176010366078e-09
#             Iterations: 63
#             Function evaluations: 6365
#             Gradient evaluations: 63
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1128111017845855e-05
#             Iterations: 170
#             Function evaluations: 17510
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.412128299231565
#             Iterations: 71
#             Function evaluations: 7293
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.023038547253674e-09
#             Iterations: 67
#             Function evaluations: 6902
#             Gradient evaluations: 67
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.328472998410551e-05
#             Iterations: 173
#             Function evaluations: 18165
#             Gradient evaluations: 173
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.219885390859317
#             Iterations: 72
#             Function evaluations: 7638
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.657065799315488e-09
#             Iterations: 55
#             Function evaluations: 5777
#             Gradient evaluations: 55
# 2006-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5489847249572833e-05
#             Iterations: 157
#             Function evaluations: 16015
#             Gradient evaluations: 157
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.15814624950613
#             Iterations: 72
#             Function evaluations: 7422
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.364824017761812e-09
#             Iterations: 51
#             Function evaluations: 5204
#             Gradient evaluations: 51
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2416412964847692e-05
#             Iterations: 157
#             Function evaluations: 15700
#             Gradient evaluations: 157
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.342927502764112
#             Iterations: 71
#             Function evaluations: 7179
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.877041058441704e-09
#             Iterations: 44
#             Function evaluations: 4402
#             Gradient evaluations: 44
# 2006-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4931463893628331e-05
#             Iterations: 146
#             Function evaluations: 15185
#             Gradient evaluations: 146
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.154491574229016
#             Iterations: 95
#             Function evaluations: 10015
#             Gradient evaluations: 95
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.0770953723720154e-09
#             Iterations: 28
#             Function evaluations: 2915
#             Gradient evaluations: 28
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.457967310772057e-05
#             Iterations: 126
#             Function evaluations: 12852
#             Gradient evaluations: 126
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.406679735445033
#             Iterations: 100
#             Function evaluations: 10357
#             Gradient evaluations: 100
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.167825723564058e-09
#             Iterations: 21
#             Function evaluations: 2146
#             Gradient evaluations: 21
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.772782971797664e-05
#             Iterations: 128
#             Function evaluations: 13184
#             Gradient evaluations: 128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.871304397212636
#             Iterations: 93
#             Function evaluations: 9722
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.137421671183812e-09
#             Iterations: 30
#             Function evaluations: 3090
#             Gradient evaluations: 30
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8101897447918323e-05
#             Iterations: 138
#             Function evaluations: 14353
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.749012244551289
#             Iterations: 99
#             Function evaluations: 10435
#             Gradient evaluations: 99
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.073100105798152e-09
#             Iterations: 32
#             Function evaluations: 3329
#             Gradient evaluations: 32
# 2006-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.786806505545758e-05
#             Iterations: 151
#             Function evaluations: 16158
#             Gradient evaluations: 151
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.7403999434170565
#             Iterations: 100
#             Function evaluations: 10843
#             Gradient evaluations: 100
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.747389924175379e-09
#             Iterations: 19
#             Function evaluations: 2033
#             Gradient evaluations: 19
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7116352753698874e-05
#             Iterations: 162
#             Function evaluations: 18307
#             Gradient evaluations: 162
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.450064934406717
#             Iterations: 94
#             Function evaluations: 10755
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.885855786125629e-09
#             Iterations: 20
#             Function evaluations: 2260
#             Gradient evaluations: 20
# 2007-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6904992302787404e-05
#             Iterations: 194
#             Function evaluations: 22117
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.488817872792923
#             Iterations: 92
#             Function evaluations: 10613
#             Gradient evaluations: 92
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.44767147881491e-09
#             Iterations: 33
#             Function evaluations: 3762
#             Gradient evaluations: 33
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1350737030160556e-05
#             Iterations: 167
#             Function evaluations: 18705
#             Gradient evaluations: 167
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.067597228683276
#             Iterations: 84
#             Function evaluations: 9505
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0619958436406967e-08
#             Iterations: 33
#             Function evaluations: 3696
#             Gradient evaluations: 33
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.188259926329474e-05
#             Iterations: 190
#             Function evaluations: 20711
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.170910441783147
#             Iterations: 85
#             Function evaluations: 9363
#             Gradient evaluations: 85
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.234436220784352e-08
#             Iterations: 44
#             Function evaluations: 4796
#             Gradient evaluations: 44
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2134315121022153e-05
#             Iterations: 161
#             Function evaluations: 17710
#             Gradient evaluations: 161
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.221499630752786
#             Iterations: 81
#             Function evaluations: 9010
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0554160606411377e-08
#             Iterations: 44
#             Function evaluations: 4841
#             Gradient evaluations: 44
# 2007-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.534772959499246e-05
#             Iterations: 160
#             Function evaluations: 17120
#             Gradient evaluations: 160
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.02320751592231
#             Iterations: 78
#             Function evaluations: 8432
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.767123039488868e-09
#             Iterations: 45
#             Function evaluations: 4819
#             Gradient evaluations: 45
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2437028336514513e-05
#             Iterations: 182
#             Function evaluations: 19656
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.203664731953413
#             Iterations: 80
#             Function evaluations: 8734
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2257434060036758e-08
#             Iterations: 47
#             Function evaluations: 5077
#             Gradient evaluations: 47
# 2007-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3860401777413753e-05
#             Iterations: 169
#             Function evaluations: 18421
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.167776861437411
#             Iterations: 76
#             Function evaluations: 8371
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1570440412911411e-08
#             Iterations: 42
#             Function evaluations: 4579
#             Gradient evaluations: 42
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5993620804319552e-05
#             Iterations: 161
#             Function evaluations: 17550
#             Gradient evaluations: 161
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.942103275323025
#             Iterations: 68
#             Function evaluations: 7485
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0249343459214958e-08
#             Iterations: 53
#             Function evaluations: 5779
#             Gradient evaluations: 53
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5536837427130452e-05
#             Iterations: 159
#             Function evaluations: 17808
#             Gradient evaluations: 159
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.155439445652713
#             Iterations: 75
#             Function evaluations: 8484
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.79371263431295e-09
#             Iterations: 57
#             Function evaluations: 6385
#             Gradient evaluations: 57
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.732056852772428e-05
#             Iterations: 165
#             Function evaluations: 17985
#             Gradient evaluations: 165
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.159141547131251
#             Iterations: 67
#             Function evaluations: 7381
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0826489878292585e-08
#             Iterations: 59
#             Function evaluations: 6435
#             Gradient evaluations: 59
# 2007-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.76113303919737e-05
#             Iterations: 157
#             Function evaluations: 17428
#             Gradient evaluations: 157
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.042850796542317
#             Iterations: 67
#             Function evaluations: 7506
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0399450959557895e-08
#             Iterations: 84
#             Function evaluations: 9325
#             Gradient evaluations: 84
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8752384502793744e-05
#             Iterations: 150
#             Function evaluations: 16501
#             Gradient evaluations: 150
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.3340146541228854
#             Iterations: 76
#             Function evaluations: 8333
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.984749809999498e-09
#             Iterations: 92
#             Function evaluations: 10120
#             Gradient evaluations: 92
# 2008-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.074413777667462e-05
#             Iterations: 151
#             Function evaluations: 16610
#             Gradient evaluations: 151
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.372658902974507
#             Iterations: 74
#             Function evaluations: 8224
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0923664531485018e-08
#             Iterations: 94
#             Function evaluations: 10341
#             Gradient evaluations: 94
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.9506936857173834e-05
#             Iterations: 160
#             Function evaluations: 17120
#             Gradient evaluations: 160
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.394599107910732
#             Iterations: 74
#             Function evaluations: 8004
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1664400129339431e-08
#             Iterations: 95
#             Function evaluations: 10166
#             Gradient evaluations: 95
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.0217498561446614e-05
#             Iterations: 169
#             Function evaluations: 17576
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.4772054361382745
#             Iterations: 69
#             Function evaluations: 7152
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1666812646859376e-08
#             Iterations: 103
#             Function evaluations: 10713
#             Gradient evaluations: 103
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.277265614627218e-05
#             Iterations: 157
#             Function evaluations: 16485
#             Gradient evaluations: 157
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.553234438765263
#             Iterations: 76
#             Function evaluations: 8067
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.050322495095272e-08
#             Iterations: 116
#             Function evaluations: 12180
#             Gradient evaluations: 116
# 2008-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.117401749923812e-05
#             Iterations: 154
#             Function evaluations: 16016
#             Gradient evaluations: 154
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.586849011299887
#             Iterations: 74
#             Function evaluations: 7786
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0784904104700126e-08
#             Iterations: 125
#             Function evaluations: 13000
#             Gradient evaluations: 125
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.194374081884922e-05
#             Iterations: 179
#             Function evaluations: 18079
#             Gradient evaluations: 179
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.399863370046222
#             Iterations: 64
#             Function evaluations: 6537
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.23163597022864e-08
#             Iterations: 125
#             Function evaluations: 12625
#             Gradient evaluations: 125
# 2008-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.27827504803786e-05
#             Iterations: 170
#             Function evaluations: 16660
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.104989371413625
#             Iterations: 63
#             Function evaluations: 6242
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3648169546130205e-08
#             Iterations: 135
#             Function evaluations: 13230
#             Gradient evaluations: 135
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8843830593422404e-05
#             Iterations: 184
#             Function evaluations: 17664
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.005519579381129
#             Iterations: 77
#             Function evaluations: 7136
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.396478806699128e-08
#             Iterations: 135
#             Function evaluations: 12961
#             Gradient evaluations: 135
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.680739866783616e-05
#             Iterations: 167
#             Function evaluations: 16366
#             Gradient evaluations: 167
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.0247456865521265
#             Iterations: 66
#             Function evaluations: 6533
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.526173988453833e-08
#             Iterations: 146
#             Function evaluations: 14308
#             Gradient evaluations: 146
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.550382675550114e-05
#             Iterations: 164
#             Function evaluations: 15580
#             Gradient evaluations: 164
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.026937913296828
#             Iterations: 66
#             Function evaluations: 6245
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6392349811363034e-08
#             Iterations: 147
#             Function evaluations: 13966
#             Gradient evaluations: 147
# 2008-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4240232789160742e-05
#             Iterations: 159
#             Function evaluations: 15105
#             Gradient evaluations: 159
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.429902116724187
#             Iterations: 71
#             Function evaluations: 6833
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0614061482417872e-08
#             Iterations: 82
#             Function evaluations: 7790
#             Gradient evaluations: 82
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.084785856446328e-05
#             Iterations: 171
#             Function evaluations: 16587
#             Gradient evaluations: 171
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.581475657566957
#             Iterations: 85
#             Function evaluations: 8251
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3650892407769244e-08
#             Iterations: 84
#             Function evaluations: 8148
#             Gradient evaluations: 84
# 2009-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.868516029495117e-05
#             Iterations: 177
#             Function evaluations: 16816
#             Gradient evaluations: 177
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.626967293885229
#             Iterations: 77
#             Function evaluations: 7317
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3785595374458329e-08
#             Iterations: 72
#             Function evaluations: 6840
#             Gradient evaluations: 72
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.853207888370887e-05
#             Iterations: 170
#             Function evaluations: 15981
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.499220896864666
#             Iterations: 74
#             Function evaluations: 7045
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.399136636141388e-08
#             Iterations: 74
#             Function evaluations: 6957
#             Gradient evaluations: 74
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.691123147112292e-05
#             Iterations: 171
#             Function evaluations: 15903
#             Gradient evaluations: 171
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.512840647249934
#             Iterations: 71
#             Function evaluations: 6686
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3210908508667565e-08
#             Iterations: 63
#             Function evaluations: 5859
#             Gradient evaluations: 63
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4481931803766192e-05
#             Iterations: 194
#             Function evaluations: 18042
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.629136253949625
#             Iterations: 75
#             Function evaluations: 7066
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.627683967283968e-09
#             Iterations: 57
#             Function evaluations: 5301
#             Gradient evaluations: 57
# 2009-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4181011518749293e-05
#             Iterations: 190
#             Function evaluations: 17480
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.430173677812011
#             Iterations: 69
#             Function evaluations: 6432
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.156004621617947e-09
#             Iterations: 45
#             Function evaluations: 4140
#             Gradient evaluations: 45
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4207940955511148e-05
#             Iterations: 189
#             Function evaluations: 17577
#             Gradient evaluations: 189
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.243832473790727
#             Iterations: 170
#             Function evaluations: 16455
#             Gradient evaluations: 166
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.026311245314133e-08
#             Iterations: 65
#             Function evaluations: 6045
#             Gradient evaluations: 65
# 2009-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.597151106734586e-05
#             Iterations: 183
#             Function evaluations: 16470
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9616544731175316
#             Iterations: 127
#             Function evaluations: 11684
#             Gradient evaluations: 123
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.047118508420092e-09
#             Iterations: 64
#             Function evaluations: 5761
#             Gradient evaluations: 64
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4960734549878004e-05
#             Iterations: 193
#             Function evaluations: 17370
#             Gradient evaluations: 193
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8644657889302905
#             Iterations: 64
#             Function evaluations: 5822
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.736774606343668e-09
#             Iterations: 67
#             Function evaluations: 6031
#             Gradient evaluations: 67
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.398699402184751e-05
#             Iterations: 200
#             Function evaluations: 17600
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9323470360189168
#             Iterations: 61
#             Function evaluations: 5430
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.643366918925723e-09
#             Iterations: 57
#             Function evaluations: 5016
#             Gradient evaluations: 57
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2304462795872059e-05
#             Iterations: 208
#             Function evaluations: 18304
#             Gradient evaluations: 208
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.121274012599191
#             Iterations: 68
#             Function evaluations: 6057
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.057301378520848e-09
#             Iterations: 57
#             Function evaluations: 5016
#             Gradient evaluations: 57
# 2009-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.891134282012126e-06
#             Iterations: 230
#             Function evaluations: 20470
#             Gradient evaluations: 230
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.288969904096865
#             Iterations: 71
#             Function evaluations: 6396
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.4347490857932e-09
#             Iterations: 65
#             Function evaluations: 5785
#             Gradient evaluations: 65
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.58532512747955e-06
#             Iterations: 216
#             Function evaluations: 19225
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.258898617562804
#             Iterations: 71
#             Function evaluations: 6311
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.490737343556837e-09
#             Iterations: 64
#             Function evaluations: 5696
#             Gradient evaluations: 64
# 2010-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.044528938670018e-06
#             Iterations: 213
#             Function evaluations: 19597
#             Gradient evaluations: 213
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.447536529548463
#             Iterations: 76
#             Function evaluations: 6707
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.889210313784375e-09
#             Iterations: 53
#             Function evaluations: 4877
#             Gradient evaluations: 53
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.476477484270146e-06
#             Iterations: 172
#             Function evaluations: 15996
#             Gradient evaluations: 172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.575939152234695
#             Iterations: 71
#             Function evaluations: 6598
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.255427209431076e-09
#             Iterations: 56
#             Function evaluations: 5208
#             Gradient evaluations: 56
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.65075931662445e-06
#             Iterations: 192
#             Function evaluations: 17856
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.568527350051617
#             Iterations: 69
#             Function evaluations: 6499
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.50760066050836e-09
#             Iterations: 54
#             Function evaluations: 5022
#             Gradient evaluations: 54
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0004398606458553e-05
#             Iterations: 188
#             Function evaluations: 17672
#             Gradient evaluations: 188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.570353252264298
#             Iterations: 67
#             Function evaluations: 6385
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.555142475131628e-09
#             Iterations: 56
#             Function evaluations: 5264
#             Gradient evaluations: 56
# 2010-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.882996309910225e-06
#             Iterations: 193
#             Function evaluations: 17949
#             Gradient evaluations: 193
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.588449839984358
#             Iterations: 65
#             Function evaluations: 6036
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.711683582701645e-09
#             Iterations: 45
#             Function evaluations: 4186
#             Gradient evaluations: 45
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.08010018093531e-06
#             Iterations: 194
#             Function evaluations: 17848
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.774093665636905
#             Iterations: 71
#             Function evaluations: 6536
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.392556624868916e-09
#             Iterations: 47
#             Function evaluations: 4325
#             Gradient evaluations: 47
# 2010-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.191044027983059e-06
#             Iterations: 185
#             Function evaluations: 17205
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.63334220388152
#             Iterations: 70
#             Function evaluations: 6594
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4069140463199497e-08
#             Iterations: 22
#             Function evaluations: 2047
#             Gradient evaluations: 22
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.031511441983787e-06
#             Iterations: 198
#             Function evaluations: 18613
#             Gradient evaluations: 198
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.688376269670192
#             Iterations: 73
#             Function evaluations: 6957
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.325697566979368e-08
#             Iterations: 22
#             Function evaluations: 2069
#             Gradient evaluations: 22
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.819053262785352e-06
#             Iterations: 228
#             Function evaluations: 21661
#             Gradient evaluations: 228
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.263870447882038
#             Iterations: 69
#             Function evaluations: 6634
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.583125971630971e-09
#             Iterations: 34
#             Function evaluations: 3230
#             Gradient evaluations: 34
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0699658077161083e-05
#             Iterations: 194
#             Function evaluations: 18237
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.065207892969097
#             Iterations: 63
#             Function evaluations: 5987
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0614769063766186e-08
#             Iterations: 33
#             Function evaluations: 3103
#             Gradient evaluations: 33
# 2010-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2056736747138724e-05
#             Iterations: 198
#             Function evaluations: 18612
#             Gradient evaluations: 198
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.13486697553983
#             Iterations: 64
#             Function evaluations: 6082
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.172181484636991e-09
#             Iterations: 46
#             Function evaluations: 4324
#             Gradient evaluations: 46
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1536513095903706e-05
#             Iterations: 204
#             Function evaluations: 19584
#             Gradient evaluations: 204
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.205069232148194
#             Iterations: 63
#             Function evaluations: 6115
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.431343060727216e-09
#             Iterations: 45
#             Function evaluations: 4321
#             Gradient evaluations: 45
# 2011-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1330917432879339e-05
#             Iterations: 208
#             Function evaluations: 19968
#             Gradient evaluations: 208
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.150500702165916
#             Iterations: 61
#             Function evaluations: 5915
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.190469572620686e-09
#             Iterations: 45
#             Function evaluations: 4321
#             Gradient evaluations: 45
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1424546298906294e-05
#             Iterations: 189
#             Function evaluations: 17388
#             Gradient evaluations: 189
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8748571266298106
#             Iterations: 59
#             Function evaluations: 5485
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.473177560310582e-09
#             Iterations: 45
#             Function evaluations: 4141
#             Gradient evaluations: 45
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0759051829362193e-05
#             Iterations: 195
#             Function evaluations: 17941
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.953913205952569
#             Iterations: 63
#             Function evaluations: 5858
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.587051976046785e-09
#             Iterations: 45
#             Function evaluations: 4141
#             Gradient evaluations: 45
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0644009829092493e-05
#             Iterations: 205
#             Function evaluations: 19065
#             Gradient evaluations: 205
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.960119776828759
#             Iterations: 58
#             Function evaluations: 5451
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.981872892690461e-09
#             Iterations: 46
#             Function evaluations: 4278
#             Gradient evaluations: 46
# 2011-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0492021601694714e-05
#             Iterations: 210
#             Function evaluations: 19530
#             Gradient evaluations: 210
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.942140916643908
#             Iterations: 88
#             Function evaluations: 8012
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.143389283115605e-09
#             Iterations: 45
#             Function evaluations: 4186
#             Gradient evaluations: 45
# 2011-06-01 00:00:00
# ...
#             Current function value: 1.1827088884645945e-05
#             Iterations: 238
#             Function evaluations: 32844
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.682658292144751
#             Iterations: 101
#             Function evaluations: 13949
#             Gradient evaluations: 100
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2282135341611305e-08
#             Iterations: 45
#             Function evaluations: 6210
#             Gradient evaluations: 45
# 2022-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0843585346169123e-05
#             Iterations: 211
#             Function evaluations: 28486
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.856102167247887
#             Iterations: 97
#             Function evaluations: 13235
#             Gradient evaluations: 97
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1013899016432121e-08
#             Iterations: 45
#             Function evaluations: 6075
#             Gradient evaluations: 45
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0567633829422069e-05
#             Iterations: 212
#             Function evaluations: 29045
#             Gradient evaluations: 212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.048620909703525
#             Iterations: 99
#             Function evaluations: 13164
#             Gradient evaluations: 95
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0920574143490745e-08
#             Iterations: 28
#             Function evaluations: 3837
#             Gradient evaluations: 28
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0740537788322662e-05
#             Iterations: 217
#             Function evaluations: 29947
#             Gradient evaluations: 217
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.989773181701899
#             Iterations: 112
#             Function evaluations: 15148
#             Gradient evaluations: 108
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1142009762472087e-08
#             Iterations: 33
#             Function evaluations: 4554
#             Gradient evaluations: 33
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0168670500274302e-05
#             Iterations: 235
#             Function evaluations: 31961
#             Gradient evaluations: 235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.046168801695311
#             Iterations: 97
#             Function evaluations: 13334
#             Gradient evaluations: 97
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.816568907465968e-09
#             Iterations: 32
#             Function evaluations: 4352
#             Gradient evaluations: 32
# 2022-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.871793404980249e-06
#             Iterations: 216
#             Function evaluations: 29593
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.113704721644265
#             Iterations: 104
#             Function evaluations: 14272
#             Gradient evaluations: 103
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.952716901131675e-09
#             Iterations: 38
#             Function evaluations: 5206
#             Gradient evaluations: 38
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0457300423590107e-05
#             Iterations: 227
#             Function evaluations: 30418
#             Gradient evaluations: 227
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.886339929513287
#             Iterations: 101
#             Function evaluations: 13685
#             Gradient evaluations: 101
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.770904438612406e-09
#             Iterations: 41
#             Function evaluations: 5494
#             Gradient evaluations: 41
# 2023-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.722548393370332e-06
#             Iterations: 262
#             Function evaluations: 35370
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.691492612579693
#             Iterations: 99
#             Function evaluations: 13509
#             Gradient evaluations: 99
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.617782647778132e-09
#             Iterations: 41
#             Function evaluations: 5535
#             Gradient evaluations: 41
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.460475430232483e-06
#             Iterations: 250
#             Function evaluations: 33751
#             Gradient evaluations: 250
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.807096026216799
#             Iterations: 188
#             Function evaluations: 25737
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0623617894226352e-08
#             Iterations: 30
#             Function evaluations: 4050
#             Gradient evaluations: 30
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.243315352721891e-06
#             Iterations: 263
#             Function evaluations: 35242
#             Gradient evaluations: 263
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.645922002962237
#             Iterations: 91
#             Function evaluations: 12323
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1100701422661062e-08
#             Iterations: 26
#             Function evaluations: 3485
#             Gradient evaluations: 26
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.233324951280637e-06
#             Iterations: 266
#             Function evaluations: 35644
#             Gradient evaluations: 266
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.664602015126922
#             Iterations: 239
#             Function evaluations: 32823
#             Gradient evaluations: 235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.426473082652406e-09
#             Iterations: 29
#             Function evaluations: 3887
#             Gradient evaluations: 29
# 2023-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.072046912548723e-06
#             Iterations: 266
#             Function evaluations: 36442
#             Gradient evaluations: 266
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.657127949496508
#             Iterations: 92
#             Function evaluations: 12606
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.658452778639239e-09
#             Iterations: 42
#             Function evaluations: 5754
#             Gradient evaluations: 42
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.993480735904307e-06
#             Iterations: 273
#             Function evaluations: 36582
#             Gradient evaluations: 273
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.424737207502914
#             Iterations: 91
#             Function evaluations: 12196
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.145986651913978e-09
#             Iterations: 43
#             Function evaluations: 5762
#             Gradient evaluations: 43
# 2023-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0123873975488461e-05
#             Iterations: 263
#             Function evaluations: 36294
#             Gradient evaluations: 263
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.489029668344354
#             Iterations: 189
#             Function evaluations: 26505
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.4332430203959404e-09
#             Iterations: 39
#             Function evaluations: 5382
#             Gradient evaluations: 39
# 2023-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.346489691700065e-06
#             Iterations: 231
#             Function evaluations: 32341
#             Gradient evaluations: 231
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.435630934983512
#             Iterations: 89
#             Function evaluations: 12589
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.984874654659949e-09
#             Iterations: 38
#             Function evaluations: 5320
#             Gradient evaluations: 38
# 2023-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.957377697198311e-06
#             Iterations: 240
#             Function evaluations: 33600
#             Gradient evaluations: 240
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.4942019404676135
#             Iterations: 88
#             Function evaluations: 12312
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.775161817768345e-09
#             Iterations: 36
#             Function evaluations: 5040
#             Gradient evaluations: 36
# 2023-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.330782886929867e-06
#             Iterations: 251
#             Function evaluations: 35642
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.672652934575941
#             Iterations: 106
#             Function evaluations: 14648
#             Gradient evaluations: 102
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0456838318073913e-08
#             Iterations: 41
#             Function evaluations: 5822
#             Gradient evaluations: 41
# 2023-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.962396578501888e-06
#             Iterations: 254
#             Function evaluations: 36323
#             Gradient evaluations: 254
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.797733642373519
#             Iterations: 184
#             Function evaluations: 26628
#             Gradient evaluations: 180
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.409186373434039e-09
#             Iterations: 42
#             Function evaluations: 6006
#             Gradient evaluations: 42
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.326579245715886e-06
#             Iterations: 257
#             Function evaluations: 36751
#             Gradient evaluations: 257
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.830880914190021
#             Iterations: 99
#             Function evaluations: 14304
#             Gradient evaluations: 99
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.014582035287732e-09
#             Iterations: 42
#             Function evaluations: 6006
#             Gradient evaluations: 42
# 2024-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.996920145203658e-06
#             Iterations: 254
#             Function evaluations: 36577
#             Gradient evaluations: 254
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.0592935152125245
#             Iterations: 102
#             Function evaluations: 14692
#             Gradient evaluations: 101
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.620350748066287e-09
#             Iterations: 42
#             Function evaluations: 6048
#             Gradient evaluations: 42
# 2024-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.697440882140926e-06
#             Iterations: 268
#             Function evaluations: 38592
#             Gradient evaluations: 268
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.993577243286805
#             Iterations: 98
#             Function evaluations: 14109
#             Gradient evaluations: 97
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0671151375089124e-08
#             Iterations: 25
#             Function evaluations: 3601
#             Gradient evaluations: 25
# 2024-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.6251093425267045e-06
#             Iterations: 281
#             Function evaluations: 41307
#             Gradient evaluations: 281
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.259590608905088
#             Iterations: 165
#             Function evaluations: 24376
#             Gradient evaluations: 161
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.81809030029891e-09
#             Iterations: 38
#             Function evaluations: 5586
#             Gradient evaluations: 38
# 2024-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.662423866190358e-06
#             Iterations: 291
#             Function evaluations: 43359
#             Gradient evaluations: 291
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.424208057915736
#             Iterations: 108
#             Function evaluations: 15651
#             Gradient evaluations: 104
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.996222729264141e-09
#             Iterations: 38
#             Function evaluations: 5662
#             Gradient evaluations: 38
# 2024-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.610531555899226e-06
#             Iterations: 282
#             Function evaluations: 42300
#             Gradient evaluations: 282
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5.533298299387093
#             Iterations: 95
#             Function evaluations: 13817
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0673463132802844e-08
#             Iterations: 52
#             Function evaluations: 7801
#             Gradient evaluations: 52
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_shrinked_JSE.to_csv("returnsWhartonshrinked_neu_f.csv")

# %% [markdown]
# ### Reduzierter S&P500-Bestand

# %% [markdown]
# ### Reduziert und Ledoit-Shrinkage
