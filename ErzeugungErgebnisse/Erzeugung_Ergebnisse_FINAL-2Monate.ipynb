# %% [markdown]
# Hier werden die Portfolio-Methoden angewandt und mithilfe der Performance-Metriken bewertet. Die Ergebnisse werden in CSV-Dateien festgehalten. Das Akquirieren, modifizieren und beschreiben der Daten befindet sich der Übersicht halber im Notebook Datenbasis. Die Daten werden dort als CSV exportiert und hier als Dataframe wieder eingelesen.
#
# Die Korrektheit der implementierten Methoden und Metriken wird in dem separaten Notebook Verifizierung anhand eines kleinen Teilbestandes aufgezeigt, siehe dazu auch beigefügte Excel-Dateien, in denen die Portfolio-Gewichte "per Hand" nachgerechnet und mit den Ergebnissen aus der Python-Implementierung abgeglichen werden.
#
# ACHTUNG: LANGE LAUFZEIT!

# %% [markdown]
# ## Importe

# %%
#Import der notwendigen Bibliotheken, Installation mit pip bereits erfolgt

import yfinance as yf
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import csv
from scipy.optimize import minimize
import math
import random
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import linkage, dendrogram
import riskfolio as rp
from sklearn.covariance import LedoitWolf
from scipy.spatial.distance import squareform
from riskfolio import HCPortfolio as hc
from pandas.tseries.offsets import MonthBegin
from pandas.tseries.offsets import MonthEnd

# %% [markdown]
# ## Einlesen der Daten

# %%
#Bearbeitete JSE-Daten (Gesamtbestand)

df_JSE = pd.read_csv(
    'df_JSE_Final_V7.csv',
    sep=',',
    encoding='utf-8',
    index_col=0,
    decimal = '.',
    low_memory=False,
    parse_dates=['Date'],
    dayfirst=True
)

# %%
df_JSE.info
# Out:
# <bound method DataFrame.info of             4SI.JO   ABG.JO  ACL.JO  ACT.JO       ADH.JO  AEL.JO  \
# Date
# 2005-06-01     NaN   8240.0  4980.0   130.0   133.701508     NaN
# 2005-06-02     NaN   8250.0  4949.0   130.0   131.749695     NaN
# 2005-06-03     NaN   8261.0  4949.0   130.0   131.749695     NaN
# 2005-06-06     NaN   8290.0  5023.0   130.0   132.725601     NaN
# 2005-06-07     NaN   8345.0  4845.0   149.0   131.749695     NaN
# ...            ...      ...     ...     ...          ...     ...
# 2025-05-26    70.0  16845.0   109.0   160.0  3199.000000  2350.0
# 2025-05-27    70.0  16848.0   105.0   160.0  3210.000000  2350.0
# 2025-05-28    73.0  17300.0   101.0   174.0  3283.000000  2355.0
# 2025-05-29    70.0  17579.0   106.0   166.0  3247.000000  2362.0
# 2025-05-30    70.0  17332.0   116.0   160.0  3215.000000  2358.0
#
#                   AFE.JO  AFH.JO  AFT.JO        AGL.JO  ...  VKE.JO   VOD.JO  \
# Date                                                    ...
# 2005-06-01   4338.178711     NaN     NaN  21158.730469  ...     NaN  11100.0
# 2005-06-02   4427.728516     NaN     NaN  21274.703125  ...     NaN  11290.0
# 2005-06-03   4427.728516     NaN     NaN  21274.703125  ...     NaN  11290.0
# 2005-06-06   4427.728516     NaN     NaN  20868.796875  ...     NaN  11802.0
# 2005-06-07   4428.723633     NaN     NaN  20430.673828  ...     NaN  11800.0
# ...                  ...     ...     ...           ...  ...     ...      ...
# 2025-05-26  10342.000000   920.0  5057.0  53638.527344  ...  1900.0  13465.0
# 2025-05-27  10417.000000   896.0  5191.0  52658.546875  ...  1912.0  13505.0
# 2025-05-28  10444.000000   912.0  5191.0  52193.621094  ...  1914.0  13420.0
# 2025-05-29  10326.000000   900.0  5147.0  51899.722656  ...  1941.0  13849.0
# 2025-05-30  10335.000000   890.0  5200.0  52778.464844  ...  2001.0  13777.0
#
#             WBC.JO   WBO.JO  WEZ.JO       WHL.JO      YRK.JO  YYLBEE.JO  \
# Date
# 2005-06-01     NaN   2650.0     NaN   961.656494  736.937988        NaN
# 2005-06-02     NaN   2675.0     NaN   971.177917  736.937988        NaN
# 2005-06-03     NaN   2675.0     NaN   971.177917  736.937988        NaN
# 2005-06-06     NaN   2700.0     NaN   996.885498  736.937988        NaN
# 2005-06-07     NaN   2700.0     NaN  1009.263306  736.937988        NaN
# ...            ...      ...     ...          ...         ...        ...
# 2025-05-26  4800.0  18172.0    50.0  5730.000000  204.000000     2701.0
# 2025-05-27  4875.0  18317.0    45.0  5680.000000  204.000000     2701.0
# 2025-05-28  4822.0  17983.0    44.0  5765.000000  187.000000     2701.0
# 2025-05-29  4889.0  17884.0    45.0  5858.000000  190.000000     2701.0
# 2025-05-30  4900.0  18152.0    43.0  5860.000000  195.000000     2701.0
#
#             ZED.JO  ZZD.JO
# Date
# 2005-06-01     NaN     NaN
# 2005-06-02     NaN     NaN
# 2005-06-03     NaN     NaN
# 2005-06-06     NaN     NaN
# 2005-06-07     NaN     NaN
# ...            ...     ...
# 2025-05-26   120.0  1157.0
# 2025-05-27   118.0  1200.0
# 2025-05-28   125.0  1210.0
# 2025-05-29   126.0  1200.0
# 2025-05-30   129.0  1185.0
#
# [5171 rows x 217 columns]>

# %%
#Bearbeitete SP500-Daten (Gesamtbestand)

df_SP500 = pd.read_csv(
    'df_SP500_Final_V7.csv',
    sep=',',
    encoding='utf-8',
    index_col=0,
    decimal = '.',
    low_memory=False,
    parse_dates=['Date'],
    dayfirst=True
)

# %%
df_SP500.info
# Out:
# <bound method DataFrame.info of                      A  AAL  AAP        AAPL        ABBV        ABNB  \
# Date
# 2005-06-01   17.296137  NaN  NaN    1.439286         NaN         NaN
# 2005-06-02   17.303289  NaN  NaN    1.430000         NaN         NaN
# 2005-06-03   17.210300  NaN  NaN    1.365714         NaN         NaN
# 2005-06-06   17.539343  NaN  NaN    1.354286         NaN         NaN
# 2005-06-07   17.324751  NaN  NaN    1.305000         NaN         NaN
# ...                ...  ...  ...         ...         ...         ...
# 2025-05-23  108.529999  NaN  NaN  195.270004  183.259995  126.720001
# 2025-05-27  111.260002  NaN  NaN  200.210007  185.720001  129.399994
# 2025-05-28  110.879997  NaN  NaN  200.419998  183.089996  128.669998
# 2025-05-29  113.279999  NaN  NaN  199.949997  185.619995  128.360001
# 2025-05-30  111.919998  NaN  NaN  200.850006  186.110001  129.000000
#
#                    ABT       ACGL         ACN        ADBE  ...        XEL  \
# Date                                                       ...
# 2005-06-01   23.188734        NaN         NaN   33.180000  ...  18.670000
# 2005-06-02   23.155148        NaN         NaN   33.090000  ...  18.719999
# 2005-06-03   23.159946        NaN         NaN   32.540001  ...  18.809999
# 2005-06-06   23.246309        NaN         NaN   32.450001  ...  18.820000
# 2005-06-07   23.395048        NaN         NaN   32.259998  ...  18.900000
# ...                ...        ...         ...         ...  ...        ...
# 2025-05-23  131.300003  92.070000  309.579987  407.690002  ...  69.730003
# 2025-05-27  132.940002  94.620003  315.429993  413.100006  ...  69.809998
# 2025-05-28  132.020004  92.980003  315.989990  412.230011  ...  68.930000
# 2025-05-29  132.850006  94.199997  317.730011  413.359985  ...  69.470001
# 2025-05-30  133.580002  95.040001  316.820007  415.089996  ...  70.099998
#
#                    XOM  XRAY        XRX         XYL         YUM        ZBH  \
# Date
# 2005-06-01   57.150002   NaN  36.100132         NaN   18.508266  74.029129
# 2005-06-02   57.320000   NaN  35.968380         NaN   18.907261  74.242722
# 2005-06-03   57.150002   NaN  35.731224         NaN   18.705967  76.456314
# 2005-06-06   57.599998   NaN  35.335968         NaN   18.691589  76.067963
# 2005-06-07   57.450001   NaN  35.098812         NaN   18.749102  77.106796
# ...                ...   ...        ...         ...         ...        ...
# 2025-05-23  103.029999   NaN        NaN  124.050003  145.449997  92.639999
# 2025-05-27  103.519997   NaN        NaN  126.239998  144.089996  94.209999
# 2025-05-28  102.110001   NaN        NaN  125.650002  143.149994  92.290001
# 2025-05-29  102.690002   NaN        NaN  125.660004  144.039993  93.339996
# 2025-05-30  102.300003   NaN        NaN  126.040001  143.940002  92.169998
#
#                   ZBRA       ZION         ZTS
# Date
# 2005-06-01         NaN  72.330002         NaN
# 2005-06-02         NaN  72.760002         NaN
# 2005-06-03         NaN  72.160004         NaN
# 2005-06-06         NaN  72.150002         NaN
# 2005-06-07         NaN  71.949997         NaN
# ...                ...        ...         ...
# 2025-05-23  284.209992        NaN  162.580002
# 2025-05-27  295.010010        NaN  166.259995
# 2025-05-28  290.799988        NaN  165.399994
# 2025-05-29  292.500000        NaN  167.139999
# 2025-05-30  289.769989        NaN  168.630005
#
# [5032 rows x 598 columns]>

# %%
#Reduzierter SP500-Bestand ohne ausgeschiedene Unternehmen und auf Größe des JSE runtergebrochen

df_SP500_reduziert = pd.read_csv(
    'sp500_gefiltert_neuneu.csv',
    sep=',',
    encoding='utf-8',
    index_col=0,
    decimal = '.',
    low_memory=False,
    dayfirst=True
)

# %%
df_SP500_reduziert.info
# Out:
# <bound method DataFrame.info of                      A        AAPL         ABT         ACN         ADI  \
# Date
# 2005-06-01   17.296137    1.439286         NaN         NaN         NaN
# 2005-06-02   17.303289    1.430000         NaN         NaN         NaN
# 2005-06-03   17.210300    1.365714         NaN         NaN         NaN
# 2005-06-06   17.539343    1.354286         NaN         NaN         NaN
# 2005-06-07   17.324751    1.305000         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2025-05-23  108.529999  195.270004  131.300003  309.579987  210.470001
# 2025-05-27  111.260002  200.210007  132.940002  315.429993  216.889999
# 2025-05-28  110.879997  200.419998  132.020004  315.989990  215.619995
# 2025-05-29  113.279999  199.949997  132.850006  317.730011  215.750000
# 2025-05-30  111.919998  200.850006  133.580002  316.820007  213.979996
#
#                   ADM         ADP        ADSK    AES         AIZ  ...  \
# Date                                                              ...
# 2005-06-01        NaN         NaN         NaN  14.79         NaN  ...
# 2005-06-02        NaN         NaN         NaN  14.57         NaN  ...
# 2005-06-03        NaN         NaN         NaN  14.40         NaN  ...
# 2005-06-06        NaN         NaN         NaN  15.00         NaN  ...
# 2005-06-07        NaN         NaN         NaN  14.94         NaN  ...
# ...               ...         ...         ...    ...         ...  ...
# 2025-05-23  47.939999  321.089996  295.350006   9.99  196.520004  ...
# 2025-05-27  48.630001  325.709992  300.359985  10.07  201.000000  ...
# 2025-05-28  48.349998  324.140015  299.230011   9.70  197.940002  ...
# 2025-05-29  48.369999  324.119995  297.000000  10.05  199.960007  ...
# 2025-05-30  48.270000  325.529999  296.119995  10.09  202.979996  ...
#
#                    VLO        VRSN        VRTX         WAT        WFC  \
# Date
# 2005-06-01         NaN         NaN         NaN   39.450001  30.750000
# 2005-06-02         NaN         NaN         NaN   38.930000  30.764999
# 2005-06-03         NaN         NaN         NaN   38.400002  30.674999
# 2005-06-06         NaN         NaN         NaN   38.119999  30.719999
# 2005-06-07         NaN         NaN         NaN   38.310001  30.684999
# ...                ...         ...         ...         ...        ...
# 2025-05-23  128.550003  279.760010  436.000000  346.369995  72.830002
# 2025-05-27  130.710007  269.559998  446.000000  358.359985  73.989998
# 2025-05-28  126.930000  269.140015  445.100006  354.589996  73.730003
# 2025-05-29  129.160004  268.679993  447.089996  355.299988  74.510002
# 2025-05-30  128.970001  272.470001  442.049988  349.239990  74.779999
#
#                   WRB        XEL         YUM        ZBH         ZTS
# Date
# 2005-06-01        NaN        NaN         NaN  74.029129         NaN
# 2005-06-02        NaN        NaN         NaN  74.242722         NaN
# 2005-06-03        NaN        NaN         NaN  76.456314         NaN
# 2005-06-06        NaN        NaN         NaN  76.067963         NaN
# 2005-06-07        NaN        NaN         NaN  77.106796         NaN
# ...               ...        ...         ...        ...         ...
# 2025-05-23  73.080002  69.730003  145.449997  92.639999  162.580002
# 2025-05-27  74.199997  69.809998  144.089996  94.209999  166.259995
# 2025-05-28  73.290001  68.930000  143.149994  92.290001  165.399994
# 2025-05-29  73.959999  69.470001  144.039993  93.339996  167.139999
# 2025-05-30  74.690002  70.099998  143.940002  92.169998  168.630005
#
# [5032 rows x 217 columns]>

# %% [markdown]
# ## Definition der Methoden und Metriken

# %% [markdown]
# #### Equally-Weighted Portfolio

# %%
#Rückgabe gleicher Gewichte anhand der Anzahl der Unternehmen (Input Returns)

def equally_weighted(returns):
    anzahl_assets = returns.shape[1]

    w0 = 1/anzahl_assets
    gewichte = np.full(anzahl_assets, w0)

    return gewichte

# %% [markdown]
# #### Minimum-Variance Portfolio

# %%
#Minimum-Variance Portfolio
#Code adaptiert von https://medium.com/@BorisGerat/mean-variance-and-minimum-variance-portfolio-models-in-python-64a5c6b57b2d

def min_variance_opt(matrix):
    
    #Compute the minimum-variance portfolio weights subject to the constraints of:
    #- No short-selling (weights must be >= 0)
    #- Full investment (sum of weights must equal 1)
    
    number_of_assets = matrix.shape[0]

    # Define the objective function to minimize portfolio variance
    def objective(w):
        portfolio_variance = np.dot(w, matrix @ w)
        return portfolio_variance

    # Constraint: The sum of portfolio weights must be equal to 1
    constraints = [{'type': 'eq', 'fun': lambda w: np.sum(w) - 1}]

    # Bounds: Each weight must be between 0 and 1 (no short-selling)
    bounds = [[0, 1] for _ in range(number_of_assets)]

    # Initial guess: Equal weights for all assets
    w0 = np.ones(number_of_assets) / number_of_assets

    # Solve the optimization problem using Sequential Least Squares Quadratic Programming (SLSQP)
    res = minimize(objective, w0, method='SLSQP', bounds=bounds, constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    
    return res.x  # Return the optimal weights

# %% [markdown]
# #### Maximum Diversification Portfolio

# %%
#Code von https://thequantmba.wordpress.com/2017/06/06/max-diversification-in-python/ adaptiert

def calc_max_diversification_ratio(weights, matrix):
    
    # gewichtete Volatilität
    average_vol = np.dot(np.sqrt(np.diag(matrix)), weights.T)
    
    # portfolio volatilität
    portfolio_variance = np.dot(weights, matrix @ weights)
    portfolio_vol = np.sqrt(portfolio_variance)
    
    #Bestimmung Ratio
    diversification_ratio = average_vol/portfolio_vol
    
    # Negativer Wert für Minimierung (Maximizieren = Minimieren -)
    return -diversification_ratio

# %%
#Code von https://thequantmba.wordpress.com/2017/06/06/max-diversification-in-python/ adaptiert

def max_diversification_portfolio(matrix):
    
    anzahl_assets = matrix.shape[0]
    
    w0 = 1/anzahl_assets
    w = np.full(anzahl_assets, w0)
    
    # Constraint: The sum of portfolio weights must be equal to 1
    constraints = [{'type': 'eq', 'fun': lambda w: np.sum(w) - 1}]
    
    # Bounds: Each weight must be between 0 and 1 (no short-selling)
    bounds = [[0, 1] for _ in range(anzahl_assets)]
    
    res = minimize(calc_max_diversification_ratio, w, bounds=bounds, args=matrix, method='SLSQP', constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    return res.x

# %% [markdown]
# #### Inverse Volatility Portfolio

# %%
#Code adaptiert von https://www.kaggle.com/code/vijipai/lesson-4-traditional-portfolio-construction-method

def inverse_volatility_portfolio (matrix):
    
    standardabweichungen = np.sqrt(np.diagonal(matrix))
    invertierte_std = 1/standardabweichungen
    summe_invertierte_std = np.sum(invertierte_std)
    
    inverse_volatility_gewichte = invertierte_std / summe_invertierte_std
    
    return inverse_volatility_gewichte

# %% [markdown]
# #### Equal Risk Contribution Portfolio

# %%
#Code adaptiert von https://medium.com/@deepml1818/building-a-python-based-risk-parity-portfolio-for-trading-40441ecdd84d

def calculate_portfolio_volatility(weights, matrix):
    
    portfolio_variance = np.dot(weights, matrix @ weights)
    portfolio_volatility = np.sqrt(portfolio_variance)
    return portfolio_volatility

def calculate_risk_contribution(weights, matrix):
    portfolio_volatility = calculate_portfolio_volatility(weights, matrix)
    marginal_contribution_zaehler = np.dot(matrix, weights)
    risk_contribution = np.multiply(weights, marginal_contribution_zaehler) / portfolio_volatility
    return risk_contribution

def risk_parity_objective(weights, matrix):
    risk_contribution = calculate_risk_contribution(weights, matrix)
    target_risk = np.mean(risk_contribution)
    return np.sum((risk_contribution - target_risk) ** 2)

# %%
def get_risk_parity_weights(matrix):
    
    number_of_assets = matrix.shape[0]
    w0 = 1/number_of_assets
    initial_weights = np.full(number_of_assets, w0)
    
    constraints = ({'type': 'eq', 'fun': lambda initial_weights: np.sum(initial_weights) - 1})
    bounds = [[0, 1] for _ in range(number_of_assets)]
    
    result = minimize(risk_parity_objective, initial_weights, args=(matrix), method='SLSQP', bounds=bounds, constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    
    return result.x

# %% [markdown]
# #### Hierarchical Risk Parity

# %%
#Aus dem Paper von Lopez De Prado (2016)
def getIVP(cov,**kargs): # Compute the inverse-variance portfolio 
    ivp=1./np.diag(cov) 
    ivp/=ivp.sum() 
    return ivp

# %%
#------------------------------------------------------------------------------ 
def getClusterVar(cov,cItems): # Compute variance per cluster 
    cov_=cov.loc[cItems,cItems] # matrix slice 
    w_=getIVP(cov_).reshape(-1,1) 
    cVar=np.dot(np.dot(w_.T,cov_),w_)[0,0] 
    return cVar

# %%
#------------------------------------------------------------------------------ 
def getQuasiDiag(link): # Sort clustered items by distance 
    link=link.astype(int) 
    sortIx=pd.Series([link[-1,0],link[-1,1]]) 
    numItems=link[-1,3] # number of original items 
    while sortIx.max()>=numItems: 
        sortIx.index=range(0,sortIx.shape[0]*2,2) # make space 
        df0=sortIx[sortIx>=numItems] # find clusters
        i=df0.index;j=df0.values-numItems 
        sortIx[i]=link[j,0] # item 1 
        df0=pd.Series(link[j,1],index=i+1) 
        sortIx = pd.concat([sortIx, df0]) # item 2  ####Anpassung wegen neuer Pandas-Version!
        sortIx=sortIx.sort_index() # re-sort 
        sortIx.index=range(sortIx.shape[0]) # re-index 
    return sortIx.tolist()

# %%
#------------------------------------------------------------------------------ 
def getRecBipart(cov,sortIx): # Compute HRP allocation
    w = pd.Series(1,index=sortIx) 
    cItems=[sortIx] # initialize all items in one cluster 
    while len(cItems)>0: 
        #Bi-Section der Cluster
        cItems = [i[j:k] 
                  for i in cItems 
                  for j, k in ((0, len(i)//2), (len(i)//2, len(i))) 
                  if len(i) > 1]
        for i in range(0, len(cItems), 2): # parse in pairs 
            cItems0=cItems[i] # cluster 1 
            cItems1=cItems[i+1] # cluster 2 
            cVar0=getClusterVar(cov,cItems0) 
            cVar1=getClusterVar(cov,cItems1) 
            alpha=1-cVar0/(cVar0+cVar1) 
            w[cItems0]*=alpha # weight 1 
            w[cItems1]*=1-alpha # weight 2 
    return w

# %%
#------------------------------------------------------------------------------ 
def correlDist(corr): 
    # A distance matrix based on correlation, where 0<=d[i,j]<=1 
    # This is a proper distance metric 
    dist=((1-corr)/2.)**.5 # distance matrix 
    
    #Adjustierung zur condensed_distance_matrix
    condensed_distance_matrix = squareform(X=dist, checks=False)
    
    return condensed_distance_matrix

# %%
def hrp_main(corr, cov, returns): 
    
    #3) cluster 
    dist=correlDist(corr) 
    link=sch.linkage(dist,'single') 
    sortIx=getQuasiDiag(link) 
    sortIx=corr.index[sortIx].tolist() # recover labels 
    df0=corr.loc[sortIx,sortIx] # reorder 
    
    #4) Capital allocation 
    hrp=getRecBipart(cov,sortIx) 
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    hrp_sortiert = hrp.reindex(original_reihenfolge)
    
    array = hrp_sortiert.T.values

    return array

# %% [markdown]
# #### Hierarchical Equal Risk Contribution Portfolio

# %%
#Es wird auf die Implementierung der Riskfolio-Lib zurückgegriffen
#Code adaptiert von #Code adaptiert von https://medium.com/@orenji.eirl/hierarchical-equal-risk-contribution-with-python-and-riskfolio-lib-ec45dd0f9899

def herc (returns):

    # Building the portfolio object
    port = hc(returns=returns)

    # Estimate optimal portfolio:

    model='HERC'
    correlation = 'pearson'
    rm = 'MV'
    rf = 0 
    linkage = 'ward' 
    max_k = 10 
    leaf_order = True 

    gewichte = port.optimization(model=model,
                          correlation=correlation,
                          rm=rm,
                          rf=rf,
                          linkage=linkage,
                          max_k=max_k,
                          leaf_order=leaf_order)
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    gewichte_sortiert = gewichte.reindex(original_reihenfolge)
    
    array = gewichte_sortiert.values.flatten()

    return array

# %%
def herc_ledoit (returns):

    #Building the portfolio object
    port = hc(returns=returns)
    
    shrinkage_herc = LedoitWolf().fit(returns.values)
    
    shrinkage_matrix_herc = pd.DataFrame(
        shrinkage_herc.covariance_,
        index = returns.columns,
        columns = returns.columns)

    #Estimate optimal portfolio:

    model='HERC'
    #correlation = 'pearson'
    rm = 'MV'
    rf = 0 
    linkage = 'ward' 
    max_k = 10 
    leaf_order = True 

    gewichte = port.optimization(model=model,
                          custom_cov = shrinkage_matrix_herc,
                          codependence='custom_cov',
                          rm=rm,
                          rf=rf,
                          method_cov='custom_cov',   #gemäß https://riskfolio-lib.readthedocs.io/en/latest/hcportfolio.html
                          linkage=linkage,
                          max_k=max_k,
                          leaf_order=leaf_order)
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    gewichte_sortiert = gewichte.reindex(original_reihenfolge)
    
    array = gewichte_sortiert.values.flatten()

    return array

# %% [markdown]
# #### Vergleichs-Metriken

# %%
def gesamt_return(gewichte, returns):

    daily_returns = returns @ gewichte
    total = np.prod(1 + daily_returns) - 1
    
    return total

# %%
def portfolio_return (gewichte, returns):
    
    avg_returns = []
    avg_returns = returns.mean()
    
    pf_return = sum([gewicht * rendite for gewicht, rendite in zip(gewichte, avg_returns)])
    
    return pf_return

# %%
def portfolio_variance (gewichte, returns):
    daily_returns = []
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    pf_var = np.var(daily_returns)
    
    return pf_var

# %%
def portfolio_volatility (gewichte, returns):
    variance = portfolio_variance(gewichte, returns)
    volatility = np.sqrt(variance)
    
    return volatility

# %%
def annualized_return(gewichte, returns):
    daily_returns = returns @ gewichte
    annual = (np.prod(1 + daily_returns))**(252/daily_returns.shape[0]) - 1
    
    return annual

# %%
def annualized_portfolio_return(gewichte, returns):
    pf_return = portfolio_return(gewichte, returns)
    
    return pf_return*252

# %%
def annualized_portfolio_volatility(gewichte, returns):
    pf_volatility = portfolio_volatility(gewichte, returns)
    
    return pf_volatility*np.sqrt(252)

# %%
def sharpe_ratio (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sharpe_ratio_one (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.01
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sharpe_ratio_two (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.02
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio_one (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.01
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio_two (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.02
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sortino_ratio (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def sortino_ratio_one (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.01
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def sortino_ratio_two (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.02
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio_one (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.01
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio_two (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.02
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def maximum_drawdown (gewichte, returns):
    daily_returns = returns @ gewichte
    returns_kumuliert = (1 + daily_returns).cumprod()
    hochpunkte = returns_kumuliert.cummax()
    
    drawdowns = (returns_kumuliert - hochpunkte) / hochpunkte
    max_drawdown = drawdowns.min()
    
    #print(drawdowns)
    return max_drawdown

# %%
def calmar_ratio (gewichte, returns):
    pf_return = portfolio_return(gewichte, returns)
    max_drawdown = maximum_drawdown(gewichte, returns)
    
    calmar_ratio = pf_return / (-max_drawdown)
    
    return calmar_ratio

# %%
def value_at_risk_func(gewichte, returns):
    daily_returns = returns @ gewichte
    sorted_daily_returns = daily_returns.sort_values(ascending = True)
    value_at_risk = np.percentile(sorted_daily_returns, 100*0.05)
    return value_at_risk

# %%
#https://github.com/malctaylor15/VaR-and-Expected-Shortfall-Python/blob/master/Expected%20Shortfall%20and%20Value%20at%20Risk.ipynb

def expected_shortfall(gewichte, returns):
    daily_returns = returns @ gewichte
    sorted_daily_returns = daily_returns.sort_values(ascending = True)
    value_at_risk = value_at_risk_func(gewichte, returns)
    
    expected_shortfall = daily_returns[daily_returns <= value_at_risk].mean()
    
    return expected_shortfall

# %% [markdown]
# #### Sammel-Funktionen zum Berechnen und Speichern der Metriken

# %%
def metriken_equally_weighted(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile1 = {"Methode": "Equally-Weighted",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile1[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile1])], ignore_index=True)

# %%
def metriken_minimum_variance(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile2 = {"Methode": "Minimum_Variance",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile2[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile2])], ignore_index=True)

# %%
def metriken_max_diversification(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile3 = {"Methode": "Max-Diversification",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile3[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile3])], ignore_index=True)

# %%
def metriken_inverse_volatility(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile4 = {"Methode": "Inverse-Volatility",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile4[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile4])], ignore_index=True)

# %%
def metriken_risk_parity(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile5 = {"Methode": "Risk-Parity",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile5[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile5])], ignore_index=True)

# %%
def metriken_hrp(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile6 = {"Methode": "HRP",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile6[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile6])], ignore_index=True)

# %%
def metriken_herc(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile7 = {"Methode": "HERC",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile7[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile7])], ignore_index=True)

# %% [markdown]
# ## Erzeugung Ergebnisse S&P500

# %%
#Tägliche Renditen für den gesamten Zeitraum von 20 Jahren SP500

returns = df_SP500.pct_change()
returns = returns.where(~df_SP500.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                    A  AAL  AAP      AAPL      ABBV      ABNB       ABT  \
# Date
# 2005-06-02  0.000414  NaN  NaN -0.006452       NaN       NaN -0.001448
# 2005-06-03 -0.005374  NaN  NaN -0.044955       NaN       NaN  0.000207
# 2005-06-06  0.019119  NaN  NaN -0.008368       NaN       NaN  0.003729
# 2005-06-07 -0.012235  NaN  NaN -0.036393       NaN       NaN  0.006398
# 2005-06-08  0.009496  NaN  NaN  0.010399       NaN       NaN -0.002051
# ...              ...  ...  ...       ...       ...       ...       ...
# 2025-05-23 -0.010485  NaN  NaN -0.030244  0.003944 -0.007286 -0.001521
# 2025-05-27  0.025154  NaN  NaN  0.025298  0.013424  0.021149  0.012490
# 2025-05-28 -0.003415  NaN  NaN  0.001049 -0.014161 -0.005641 -0.006920
# 2025-05-29  0.021645  NaN  NaN -0.002345  0.013818 -0.002409  0.006287
# 2025-05-30 -0.012006  NaN  NaN  0.004501  0.002640  0.004986  0.005495
#
#                 ACGL       ACN      ADBE  ...       XEL       XOM  XRAY  \
# Date                                      ...
# 2005-06-02       NaN       NaN -0.002712  ...  0.002678  0.002975   NaN
# 2005-06-03       NaN       NaN -0.016621  ...  0.004808 -0.002966   NaN
# 2005-06-06       NaN       NaN -0.002766  ...  0.000532  0.007874   NaN
# 2005-06-07       NaN       NaN -0.005855  ...  0.004251 -0.002604   NaN
# 2005-06-08       NaN       NaN  0.000000  ...  0.017460 -0.012533   NaN
# ...              ...       ...       ...  ...       ...       ...   ...
# 2025-05-23  0.001087 -0.021710 -0.016026  ...  0.007513  0.000583   NaN
# 2025-05-27  0.027696  0.018897  0.013270  ...  0.001147  0.004756   NaN
# 2025-05-28 -0.017332  0.001775 -0.002106  ... -0.012606 -0.013621   NaN
# 2025-05-29  0.013121  0.005507  0.002741  ...  0.007834  0.005680   NaN
# 2025-05-30  0.008917 -0.002864  0.004185  ...  0.009069 -0.003798   NaN
#
#                  XRX       XYL       YUM       ZBH      ZBRA      ZION  \
# Date
# 2005-06-02 -0.003650       NaN  0.021558  0.002885       NaN  0.005945
# 2005-06-03 -0.006593       NaN -0.010646  0.029816       NaN -0.008246
# 2005-06-06 -0.011062       NaN -0.000769 -0.005079       NaN -0.000139
# 2005-06-07 -0.006711       NaN  0.003077  0.013657       NaN -0.002772
# 2005-06-08  0.039039       NaN -0.006518 -0.005414       NaN -0.002085
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23       NaN -0.009739 -0.000344  0.010581 -0.014392       NaN
# 2025-05-27       NaN  0.017654 -0.009350  0.016947  0.038000       NaN
# 2025-05-28       NaN -0.004674 -0.006524 -0.020380 -0.014271       NaN
# 2025-05-29       NaN  0.000080  0.006217  0.011377  0.005846       NaN
# 2025-05-30       NaN  0.003024 -0.000694 -0.012535 -0.009333       NaN
#
#                  ZTS
# Date
# 2005-06-02       NaN
# 2005-06-03       NaN
# 2005-06-06       NaN
# 2005-06-07       NaN
# 2005-06-08       NaN
# ...              ...
# 2025-05-23  0.003766
# 2025-05-27  0.022635
# 2025-05-28 -0.005173
# 2025-05-29  0.010520
# 2025-05-30  0.008915
#
# [5031 rows x 598 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 2
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = training_daten.cov()
    corr_matrix = training_daten.corr()
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    gewichte_equally_weighted = equally_weighted(training_daten)
    gewichte_min_variance= min_variance_opt(cov_matrix)
    gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": gewichte_equally_weighted,
    "Minimum-Variance": gewichte_min_variance,
    "Maximum-Diversification": gewichte_max_diversification,
    "Inverse-Volatility": gewichte_inverse_volatility,
    "Equal-Risk-Contribution": gewichte_risk_parity,
    "HRP": gewichte_hrp,
    "HERC": gewichte_herc
}
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
     #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
# Alle Testperioden zusammenführen
portfolio_returns_df = pd.concat(portfolio_returns_list)
portfolio_returns_df = portfolio_returns_df.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.560718656371804e-05
#             Iterations: 299
#             Function evaluations: 78936
#             Gradient evaluations: 299
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0661056745424897
#             Iterations: 87
#             Function evaluations: 22007
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6806677955014559e-09
#             Iterations: 21
#             Function evaluations: 5544
#             Gradient evaluations: 21
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.690668950260142e-05
#             Iterations: 318
#             Function evaluations: 84588
#             Gradient evaluations: 318
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8714571734911107
#             Iterations: 76
#             Function evaluations: 19767
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.918444000666588e-09
#             Iterations: 31
#             Function evaluations: 8246
#             Gradient evaluations: 31
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5769545458705043e-05
#             Iterations: 306
#             Function evaluations: 82314
#             Gradient evaluations: 306
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.922602493344259
#             Iterations: 76
#             Function evaluations: 20247
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3601474215166684e-09
#             Iterations: 31
#             Function evaluations: 8339
#             Gradient evaluations: 31
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4559816122957647e-05
#             Iterations: 347
#             Function evaluations: 94037
#             Gradient evaluations: 347
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0831731681363586
#             Iterations: 81
#             Function evaluations: 20955
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3858077582241334e-09
#             Iterations: 26
#             Function evaluations: 7046
#             Gradient evaluations: 26
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2957615381930568e-05
#             Iterations: 329
#             Function evaluations: 90146
#             Gradient evaluations: 329
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.114900759682049
#             Iterations: 67
#             Function evaluations: 18151
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.879440551822173e-09
#             Iterations: 26
#             Function evaluations: 7124
#             Gradient evaluations: 26
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.665008331141351e-05
#             Iterations: 342
#             Function evaluations: 94050
#             Gradient evaluations: 342
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.79903434995049
#             Iterations: 63
#             Function evaluations: 16282
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.667997339316014e-09
#             Iterations: 26
#             Function evaluations: 7151
#             Gradient evaluations: 26
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.622007081358141e-05
#             Iterations: 332
#             Function evaluations: 92296
#             Gradient evaluations: 332
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.920905052892258
#             Iterations: 71
#             Function evaluations: 18702
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4955482396956752e-09
#             Iterations: 38
#             Function evaluations: 10564
#             Gradient evaluations: 38
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.837685443711993e-05
#             Iterations: 312
#             Function evaluations: 86737
#             Gradient evaluations: 312
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0412313106182576
#             Iterations: 65
#             Function evaluations: 17028
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7743853979597804e-09
#             Iterations: 21
#             Function evaluations: 5838
#             Gradient evaluations: 21
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7205091645283506e-05
#             Iterations: 276
#             Function evaluations: 77005
#             Gradient evaluations: 276
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.721229884549377
#             Iterations: 50
#             Function evaluations: 13996
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8931557882883877e-09
#             Iterations: 15
#             Function evaluations: 4186
#             Gradient evaluations: 15
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.148308745181869e-05
#             Iterations: 291
#             Function evaluations: 82353
#             Gradient evaluations: 291
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5229826522261836
#             Iterations: 49
#             Function evaluations: 13634
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7685128002345642e-09
#             Iterations: 30
#             Function evaluations: 8490
#             Gradient evaluations: 30
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.843161187487995e-05
#             Iterations: 287
#             Function evaluations: 81795
#             Gradient evaluations: 287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4680203052465988
#             Iterations: 40
#             Function evaluations: 11440
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.080968475756469e-09
#             Iterations: 47
#             Function evaluations: 13396
#             Gradient evaluations: 47
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.2429465562032166e-05
#             Iterations: 274
#             Function evaluations: 79186
#             Gradient evaluations: 274
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6217252958270936
#             Iterations: 43
#             Function evaluations: 12182
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.916013641175868e-10
#             Iterations: 57
#             Function evaluations: 16473
#             Gradient evaluations: 57
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.384494997283043e-05
#             Iterations: 288
#             Function evaluations: 83809
#             Gradient evaluations: 288
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.609616389400448
#             Iterations: 35
#             Function evaluations: 10218
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.101271457203561e-10
#             Iterations: 66
#             Function evaluations: 19206
#             Gradient evaluations: 66
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.515465372412421e-05
#             Iterations: 234
#             Function evaluations: 68094
#             Gradient evaluations: 234
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.554867540794491
#             Iterations: 55
#             Function evaluations: 14905
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.540393150899734e-10
#             Iterations: 83
#             Function evaluations: 24153
#             Gradient evaluations: 83
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.311114395015498e-05
#             Iterations: 242
#             Function evaluations: 70180
#             Gradient evaluations: 242
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.484780958219656
#             Iterations: 38
#             Function evaluations: 10769
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0437419642578074e-09
#             Iterations: 97
#             Function evaluations: 28131
#             Gradient evaluations: 97
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00018120765660335005
#             Iterations: 161
#             Function evaluations: 46529
#             Gradient evaluations: 161
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9197079911190353
#             Iterations: 25
#             Function evaluations: 7243
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.928611635597754e-10
#             Iterations: 81
#             Function evaluations: 23410
#             Gradient evaluations: 81
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00020119354596347927
#             Iterations: 148
#             Function evaluations: 43069
#             Gradient evaluations: 148
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.872401648975168
#             Iterations: 24
#             Function evaluations: 7002
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6750886628105487e-10
#             Iterations: 88
#             Function evaluations: 25609
#             Gradient evaluations: 88
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002267902185625556
#             Iterations: 145
#             Function evaluations: 42340
#             Gradient evaluations: 145
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7724201488878464
#             Iterations: 28
#             Function evaluations: 8195
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2141123031818701e-10
#             Iterations: 103
#             Function evaluations: 30076
#             Gradient evaluations: 103
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022737312160583248
#             Iterations: 140
#             Function evaluations: 41020
#             Gradient evaluations: 140
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8007067307721083
#             Iterations: 29
#             Function evaluations: 8514
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.060251469829356e-10
#             Iterations: 110
#             Function evaluations: 32230
#             Gradient evaluations: 110
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022569483587998954
#             Iterations: 113
#             Function evaluations: 33335
#             Gradient evaluations: 113
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7949113226240583
#             Iterations: 26
#             Function evaluations: 7687
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1561733152172096e-10
#             Iterations: 110
#             Function evaluations: 32450
#             Gradient evaluations: 110
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00020894945431497274
#             Iterations: 106
#             Function evaluations: 31694
#             Gradient evaluations: 106
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8013380976672233
#             Iterations: 26
#             Function evaluations: 7790
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0008441951967505e-10
#             Iterations: 111
#             Function evaluations: 33189
#             Gradient evaluations: 111
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.719360558102194e-05
#             Iterations: 191
#             Function evaluations: 58447
#             Gradient evaluations: 191
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2426829363824012
#             Iterations: 31
#             Function evaluations: 9513
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.760862395874104e-10
#             Iterations: 147
#             Function evaluations: 44982
#             Gradient evaluations: 147
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.810619321748456e-05
#             Iterations: 207
#             Function evaluations: 63549
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.35383021552422
#             Iterations: 43
#             Function evaluations: 12016
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.223524720149009e-10
#             Iterations: 124
#             Function evaluations: 38068
#             Gradient evaluations: 124
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.273142213497092e-05
#             Iterations: 247
#             Function evaluations: 76817
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5695260600876098
#             Iterations: 44
#             Function evaluations: 12478
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2958105343025384e-09
#             Iterations: 103
#             Function evaluations: 32034
#             Gradient evaluations: 103
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.599124674605381e-05
#             Iterations: 250
#             Function evaluations: 77750
#             Gradient evaluations: 250
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.379747545025048
#             Iterations: 36
#             Function evaluations: 11230
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.58014660323221e-10
#             Iterations: 78
#             Function evaluations: 24258
#             Gradient evaluations: 78
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.697985496953368e-05
#             Iterations: 262
#             Function evaluations: 82530
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3123645265484116
#             Iterations: 40
#             Function evaluations: 11380
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1373323212787251e-09
#             Iterations: 56
#             Function evaluations: 17640
#             Gradient evaluations: 56
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.933226728429815e-05
#             Iterations: 235
#             Function evaluations: 74260
#             Gradient evaluations: 235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.172559117868381
#             Iterations: 32
#             Function evaluations: 8874
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.915389133553364e-10
#             Iterations: 59
#             Function evaluations: 18644
#             Gradient evaluations: 59
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.578197007895788e-05
#             Iterations: 221
#             Function evaluations: 70058
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.154628132683497
#             Iterations: 34
#             Function evaluations: 10806
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.644483717892879e-10
#             Iterations: 50
#             Function evaluations: 15851
#             Gradient evaluations: 50
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3965500334544226e-05
#             Iterations: 197
#             Function evaluations: 62843
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.196175925967969
#             Iterations: 31
#             Function evaluations: 9918
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.907641956193284e-10
#             Iterations: 50
#             Function evaluations: 15951
#             Gradient evaluations: 50
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.449624609961594e-05
#             Iterations: 218
#             Function evaluations: 70197
#             Gradient evaluations: 218
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2299812027009533
#             Iterations: 34
#             Function evaluations: 10978
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.977959768297004e-10
#             Iterations: 51
#             Function evaluations: 16422
#             Gradient evaluations: 51
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7518595389947427e-05
#             Iterations: 242
#             Function evaluations: 77924
#             Gradient evaluations: 242
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.445288602206374
#             Iterations: 44
#             Function evaluations: 13884
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5596859428735478e-09
#             Iterations: 37
#             Function evaluations: 11914
#             Gradient evaluations: 37
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1391291793892782e-05
#             Iterations: 321
#             Function evaluations: 103683
#             Gradient evaluations: 321
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.530535418762508
#             Iterations: 53
#             Function evaluations: 15873
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2888383550497015e-09
#             Iterations: 29
#             Function evaluations: 9368
#             Gradient evaluations: 29
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.833221353774996e-05
#             Iterations: 217
#             Function evaluations: 70091
#             Gradient evaluations: 217
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9675990086287738
#             Iterations: 29
#             Function evaluations: 9393
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.080745832507033e-10
#             Iterations: 50
#             Function evaluations: 16151
#             Gradient evaluations: 50
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7521172899602846e-05
#             Iterations: 214
#             Function evaluations: 68908
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8381808722764228
#             Iterations: 28
#             Function evaluations: 9040
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.417757534672872e-10
#             Iterations: 56
#             Function evaluations: 18032
#             Gradient evaluations: 56
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.060961460358606e-05
#             Iterations: 214
#             Function evaluations: 69337
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.972561247073514
#             Iterations: 25
#             Function evaluations: 8116
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.888953165762983e-10
#             Iterations: 55
#             Function evaluations: 17820
#             Gradient evaluations: 55
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.780939520427841e-05
#             Iterations: 222
#             Function evaluations: 71928
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9504188318180304
#             Iterations: 27
#             Function evaluations: 8767
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0282073704941506e-09
#             Iterations: 55
#             Function evaluations: 17821
#             Gradient evaluations: 55
# 2011-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.8064483049239943e-05
#             Iterations: 180
#             Function evaluations: 58860
#             Gradient evaluations: 180
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9348993199020237
#             Iterations: 28
#             Function evaluations: 9173
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1344104499274078e-09
#             Iterations: 54
#             Function evaluations: 17659
#             Gradient evaluations: 54
# 2011-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7554615338287796e-05
#             Iterations: 214
#             Function evaluations: 70406
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9702056130066234
#             Iterations: 27
#             Function evaluations: 8902
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.756578081164697e-10
#             Iterations: 61
#             Function evaluations: 20070
#             Gradient evaluations: 61
# 2011-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.779886606901843e-05
#             Iterations: 233
#             Function evaluations: 76890
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.283012603836702
#             Iterations: 39
#             Function evaluations: 12904
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6204212580480834e-09
#             Iterations: 57
#             Function evaluations: 18810
#             Gradient evaluations: 57
# 2011-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9476206656634664e-05
#             Iterations: 285
#             Function evaluations: 94336
#             Gradient evaluations: 285
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7044998548492294
#             Iterations: 53
#             Function evaluations: 16270
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3883609015530548e-09
#             Iterations: 43
#             Function evaluations: 14233
#             Gradient evaluations: 43
# 2012-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.951260436519525e-05
#             Iterations: 313
#             Function evaluations: 104855
#             Gradient evaluations: 313
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7345693539800218
#             Iterations: 52
#             Function evaluations: 16130
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.787125501706707e-09
#             Iterations: 37
#             Function evaluations: 12395
#             Gradient evaluations: 37
# 2012-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1178190967058647e-05
#             Iterations: 364
#             Function evaluations: 122304
#             Gradient evaluations: 364
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7341431889225367
#             Iterations: 67
#             Function evaluations: 21244
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.382923112221457e-09
#             Iterations: 25
#             Function evaluations: 8401
#             Gradient evaluations: 25
# 2012-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2806230953764293e-05
#             Iterations: 323
#             Function evaluations: 109497
#             Gradient evaluations: 323
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9056492158748934
#             Iterations: 51
#             Function evaluations: 15981
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5500213468355784e-09
#             Iterations: 26
#             Function evaluations: 8814
#             Gradient evaluations: 26
# 2012-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3642787745142088e-05
#             Iterations: 308
#             Function evaluations: 105029
#             Gradient evaluations: 308
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.066095473311853
#             Iterations: 58
#             Function evaluations: 18478
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6010823471692146e-09
#             Iterations: 17
#             Function evaluations: 5797
#             Gradient evaluations: 17
# 2012-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5025664958568143e-05
#             Iterations: 335
#             Function evaluations: 114570
#             Gradient evaluations: 335
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1128584386529887
#             Iterations: 47
#             Function evaluations: 14741
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.499153897059413e-10
#             Iterations: 20
#             Function evaluations: 6840
#             Gradient evaluations: 20
# 2012-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2588864390861522e-05
#             Iterations: 362
#             Function evaluations: 124166
#             Gradient evaluations: 362
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.043445369727125
#             Iterations: 43
#             Function evaluations: 14443
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.095818482423034e-09
#             Iterations: 20
#             Function evaluations: 6860
#             Gradient evaluations: 20
# 2013-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3468064927290405e-05
#             Iterations: 348
#             Function evaluations: 120060
#             Gradient evaluations: 348
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.114635739166375
#             Iterations: 53
#             Function evaluations: 16950
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0912901753386774e-09
#             Iterations: 20
#             Function evaluations: 6900
#             Gradient evaluations: 20
# 2013-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5150351163814635e-05
#             Iterations: 328
#             Function evaluations: 113488
#             Gradient evaluations: 328
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.99429186293297
#             Iterations: 61
#             Function evaluations: 19799
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.870951891468777e-09
#             Iterations: 8
#             Function evaluations: 2769
#             Gradient evaluations: 8
# 2013-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3156072760856917e-05
#             Iterations: 373
#             Function evaluations: 129058
#             Gradient evaluations: 373
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.853693924636163
#             Iterations: 55
#             Function evaluations: 17699
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1974974884239275e-09
#             Iterations: 17
#             Function evaluations: 5882
#             Gradient evaluations: 17
# 2013-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.891700155901915e-05
#             Iterations: 325
#             Function evaluations: 113425
#             Gradient evaluations: 325
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9128283698343327
#             Iterations: 76
#             Function evaluations: 25205
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.4862375709749555e-09
#             Iterations: 8
#             Function evaluations: 2792
#             Gradient evaluations: 8
# 2013-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.775029877717052e-05
#             Iterations: 363
#             Function evaluations: 127413
#             Gradient evaluations: 363
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0212686964126294
#             Iterations: 59
#             Function evaluations: 19357
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0511037334251625e-09
#             Iterations: 17
#             Function evaluations: 5967
#             Gradient evaluations: 17
# 2013-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8687386302614797e-05
#             Iterations: 328
#             Function evaluations: 115457
#             Gradient evaluations: 328
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.930052057010673
#             Iterations: 59
#             Function evaluations: 19411
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.572919983062627e-09
#             Iterations: 17
#             Function evaluations: 5984
#             Gradient evaluations: 17
# 2014-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1539349353559158e-05
#             Iterations: 291
#             Function evaluations: 103306
#             Gradient evaluations: 291
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.757413992375324
#             Iterations: 51
#             Function evaluations: 17802
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3076324362126933e-09
#             Iterations: 29
#             Function evaluations: 10295
#             Gradient evaluations: 29
# 2014-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5626737730652448e-05
#             Iterations: 296
#             Function evaluations: 104785
#             Gradient evaluations: 296
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.763624955600256
#             Iterations: 57
#             Function evaluations: 18812
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6234959557770292e-09
#             Iterations: 16
#             Function evaluations: 5664
#             Gradient evaluations: 16
# 2014-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6359295001629224e-05
#             Iterations: 314
#             Function evaluations: 112727
#             Gradient evaluations: 314
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8623347845752214
#             Iterations: 54
#             Function evaluations: 19438
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2545120203062113e-09
#             Iterations: 9
#             Function evaluations: 3231
#             Gradient evaluations: 9
# 2014-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8228196892547176e-05
#             Iterations: 346
#             Function evaluations: 124560
#             Gradient evaluations: 346
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8379778841518375
#             Iterations: 47
#             Function evaluations: 16965
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5180834927734875e-09
#             Iterations: 9
#             Function evaluations: 3241
#             Gradient evaluations: 9
# 2014-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.361379431066931e-05
#             Iterations: 302
#             Function evaluations: 109324
#             Gradient evaluations: 302
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4235231373474218
#             Iterations: 35
#             Function evaluations: 12703
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7478834085384875e-09
#             Iterations: 15
#             Function evaluations: 5431
#             Gradient evaluations: 15
# 2014-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.652785653865941e-05
#             Iterations: 334
#             Function evaluations: 120575
#             Gradient evaluations: 334
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.464157079814132
#             Iterations: 37
#             Function evaluations: 13393
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0563038084195224e-10
#             Iterations: 26
#             Function evaluations: 9386
#             Gradient evaluations: 26
# 2015-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.885759870074267e-05
#             Iterations: 307
#             Function evaluations: 111135
#             Gradient evaluations: 307
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4466379256449198
#             Iterations: 43
#             Function evaluations: 14156
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.30812644851801e-10
#             Iterations: 28
#             Function evaluations: 10136
#             Gradient evaluations: 28
# 2015-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.6700698530683624e-05
#             Iterations: 301
#             Function evaluations: 110468
#             Gradient evaluations: 301
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.485366199228348
#             Iterations: 39
#             Function evaluations: 14350
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.327265601228179e-10
#             Iterations: 45
#             Function evaluations: 16516
#             Gradient evaluations: 45
# 2015-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.757333929985946e-05
#             Iterations: 283
#             Function evaluations: 103578
#             Gradient evaluations: 283
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.534053415178769
#             Iterations: 42
#             Function evaluations: 15413
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.193483479034307e-10
#             Iterations: 46
#             Function evaluations: 16837
#             Gradient evaluations: 46
# 2015-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.889427138497173e-05
#             Iterations: 290
#             Function evaluations: 107881
#             Gradient evaluations: 290
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.527060330954796
#             Iterations: 42
#             Function evaluations: 15664
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7391516005503752e-09
#             Iterations: 45
#             Function evaluations: 16741
#             Gradient evaluations: 45
# 2015-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5366183812349686e-05
#             Iterations: 298
#             Function evaluations: 111453
#             Gradient evaluations: 298
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8796359379731653
#             Iterations: 52
#             Function evaluations: 17996
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1270262210501566e-09
#             Iterations: 55
#             Function evaluations: 20570
#             Gradient evaluations: 55
# 2015-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.271948361114539e-05
#             Iterations: 344
#             Function evaluations: 130032
#             Gradient evaluations: 344
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9933100785113216
#             Iterations: 53
#             Function evaluations: 18567
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1548618491837877e-09
#             Iterations: 44
#             Function evaluations: 16633
#             Gradient evaluations: 44
# 2016-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1056647155198885e-05
#             Iterations: 346
#             Function evaluations: 131480
#             Gradient evaluations: 346
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.2547844496814333
#             Iterations: 66
#             Function evaluations: 23625
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7575582327767705e-09
#             Iterations: 44
#             Function evaluations: 16721
#             Gradient evaluations: 44
# 2016-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7851820202040477e-05
#             Iterations: 353
#             Function evaluations: 135552
#             Gradient evaluations: 353
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.401414862001586
#             Iterations: 71
#             Function evaluations: 25789
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2122829499941543e-09
#             Iterations: 35
#             Function evaluations: 13440
#             Gradient evaluations: 35
# 2016-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5384240586407645e-05
#             Iterations: 377
#             Function evaluations: 148161
#             Gradient evaluations: 377
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.3789215463819264
#             Iterations: 75
#             Function evaluations: 27972
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.220311907696423e-09
#             Iterations: 27
#             Function evaluations: 10611
#             Gradient evaluations: 27
# 2016-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3124655876469556e-05
#             Iterations: 363
#             Function evaluations: 141933
#             Gradient evaluations: 363
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.550138345169353
#             Iterations: 77
#             Function evaluations: 28611
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6860656320406127e-09
#             Iterations: 17
#             Function evaluations: 6647
#             Gradient evaluations: 17
# 2016-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.851276253943126e-06
#             Iterations: 433
#             Function evaluations: 169737
#             Gradient evaluations: 433
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.9427415036800646
#             Iterations: 93
#             Function evaluations: 34986
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8179204467393354e-09
#             Iterations: 9
#             Function evaluations: 3528
#             Gradient evaluations: 9
# 2016-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.612799195064647e-06
#             Iterations: 460
#             Function evaluations: 180780
#             Gradient evaluations: 460
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.296053183103063
#             Iterations: 110
#             Function evaluations: 41796
#             Gradient evaluations: 106
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.820294038272212e-09
#             Iterations: 9
#             Function evaluations: 3537
#             Gradient evaluations: 9
# 2017-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.031659119275019e-06
#             Iterations: 479
#             Function evaluations: 189206
#             Gradient evaluations: 479
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.620156864912179
#             Iterations: 111
#             Function evaluations: 42415
#             Gradient evaluations: 107
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.49651489779832e-09
#             Iterations: 8
#             Function evaluations: 3160
#             Gradient evaluations: 8
# 2017-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.731573037188209e-05
#             Iterations: 411
#             Function evaluations: 164401
#             Gradient evaluations: 411
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.58177104786697
#             Iterations: 70
#             Function evaluations: 26464
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
# ...
#             Gradient evaluations: 264
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.984592456686327
#             Iterations: 78
#             Function evaluations: 32270
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.000811028839758e-09
#             Iterations: 67
#             Function evaluations: 29145
#             Gradient evaluations: 67
# 2020-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9359855005240244e-05
#             Iterations: 322
#             Function evaluations: 141036
#             Gradient evaluations: 322
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.318723069462887
#             Iterations: 58
#             Function evaluations: 23701
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3377316213802034e-09
#             Iterations: 38
#             Function evaluations: 16645
#             Gradient evaluations: 38
# 2020-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.644999074330968e-05
#             Iterations: 377
#             Function evaluations: 164750
#             Gradient evaluations: 377
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.418157188471821
#             Iterations: 63
#             Function evaluations: 25836
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.149255958963736e-09
#             Iterations: 37
#             Function evaluations: 16170
#             Gradient evaluations: 37
# 2020-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2570472725114772e-05
#             Iterations: 335
#             Function evaluations: 147065
#             Gradient evaluations: 335
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.460081569409615
#             Iterations: 79
#             Function evaluations: 33011
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.4301739724156193e-09
#             Iterations: 28
#             Function evaluations: 12292
#             Gradient evaluations: 28
# 2021-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5066515137827127e-05
#             Iterations: 371
#             Function evaluations: 162870
#             Gradient evaluations: 371
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.3801425716527946
#             Iterations: 71
#             Function evaluations: 29490
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8250817981596845e-09
#             Iterations: 28
#             Function evaluations: 12292
#             Gradient evaluations: 28
# 2021-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.760392926441833e-05
#             Iterations: 324
#             Function evaluations: 143856
#             Gradient evaluations: 324
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.2779245151787952
#             Iterations: 64
#             Function evaluations: 26695
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4227757723659737e-09
#             Iterations: 39
#             Function evaluations: 17316
#             Gradient evaluations: 39
# 2021-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.781253339320097e-05
#             Iterations: 316
#             Function evaluations: 140621
#             Gradient evaluations: 316
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.882650854529552
#             Iterations: 45
#             Function evaluations: 19624
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.453874666194968e-09
#             Iterations: 49
#             Function evaluations: 21805
#             Gradient evaluations: 49
# 2021-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.702998226770383e-05
#             Iterations: 268
#             Function evaluations: 118992
#             Gradient evaluations: 268
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7081160909629554
#             Iterations: 60
#             Function evaluations: 24932
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.895932053014749e-10
#             Iterations: 58
#             Function evaluations: 25752
#             Gradient evaluations: 58
# 2021-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.406144171734979e-05
#             Iterations: 249
#             Function evaluations: 111054
#             Gradient evaluations: 249
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5124591892635357
#             Iterations: 38
#             Function evaluations: 16983
#             Gradient evaluations: 38
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.035898366480985e-10
#             Iterations: 56
#             Function evaluations: 24976
#             Gradient evaluations: 56
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.336828812328271e-05
#             Iterations: 238
#             Function evaluations: 106386
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3472929859773752
#             Iterations: 40
#             Function evaluations: 16124
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0865034325044437e-09
#             Iterations: 55
#             Function evaluations: 24585
#             Gradient evaluations: 55
# 2022-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.50481394251689e-05
#             Iterations: 251
#             Function evaluations: 112950
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2989549351169014
#             Iterations: 29
#             Function evaluations: 13077
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.572789237949021e-10
#             Iterations: 55
#             Function evaluations: 24750
#             Gradient evaluations: 55
# 2022-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.258582979129759e-05
#             Iterations: 249
#             Function evaluations: 112548
#             Gradient evaluations: 249
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.174081296055219
#             Iterations: 33
#             Function evaluations: 14947
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.788594004811655e-10
#             Iterations: 55
#             Function evaluations: 24860
#             Gradient evaluations: 55
# 2022-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.023085183192138e-05
#             Iterations: 262
#             Function evaluations: 119210
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.337277375256852
#             Iterations: 65
#             Function evaluations: 27820
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0894105617870467e-09
#             Iterations: 57
#             Function evaluations: 25935
#             Gradient evaluations: 57
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.541773445838192e-05
#             Iterations: 272
#             Function evaluations: 125121
#             Gradient evaluations: 272
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4546139851506488
#             Iterations: 61
#             Function evaluations: 26278
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.386926835648967e-09
#             Iterations: 48
#             Function evaluations: 22080
#             Gradient evaluations: 48
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.726780181449732e-05
#             Iterations: 260
#             Function evaluations: 119601
#             Gradient evaluations: 260
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -2.6840217621958504
#             Iterations: 56
#             Function evaluations: 23975
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3326225534179358e-09
#             Iterations: 49
#             Function evaluations: 22540
#             Gradient evaluations: 49
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7129267058505102e-05
#             Iterations: 293
#             Function evaluations: 134488
#             Gradient evaluations: 293
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0425828665257693
#             Iterations: 63
#             Function evaluations: 27137
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1195316375813742e-09
#             Iterations: 38
#             Function evaluations: 17442
#             Gradient evaluations: 38
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2629247224482398e-05
#             Iterations: 314
#             Function evaluations: 144754
#             Gradient evaluations: 314
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.293607626727452
#             Iterations: 65
#             Function evaluations: 28178
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2687045819109084e-09
#             Iterations: 44
#             Function evaluations: 20284
#             Gradient evaluations: 44
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7692467535338406e-05
#             Iterations: 323
#             Function evaluations: 149227
#             Gradient evaluations: 323
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.64099170912072
#             Iterations: 82
#             Function evaluations: 36122
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4771851427151807e-09
#             Iterations: 32
#             Function evaluations: 14784
#             Gradient evaluations: 32
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7611399141609038e-05
#             Iterations: 336
#             Function evaluations: 155232
#             Gradient evaluations: 336
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7415588178401147
#             Iterations: 84
#             Function evaluations: 37046
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1163035187400048e-09
#             Iterations: 38
#             Function evaluations: 17556
#             Gradient evaluations: 38
# 2023-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6413480145897664e-05
#             Iterations: 349
#             Function evaluations: 161239
#             Gradient evaluations: 349
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9597899978850486
#             Iterations: 87
#             Function evaluations: 38439
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2871396144386658e-09
#             Iterations: 34
#             Function evaluations: 15709
#             Gradient evaluations: 34
# 2023-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6184844088630317e-05
#             Iterations: 358
#             Function evaluations: 165754
#             Gradient evaluations: 358
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.099358835944536
#             Iterations: 85
#             Function evaluations: 37580
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5099055123699636e-09
#             Iterations: 44
#             Function evaluations: 20372
#             Gradient evaluations: 44
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4294372767715442e-05
#             Iterations: 321
#             Function evaluations: 149908
#             Gradient evaluations: 321
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.357105474789429
#             Iterations: 94
#             Function evaluations: 42146
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.940671184612122e-09
#             Iterations: 33
#             Function evaluations: 15411
#             Gradient evaluations: 33
# 2024-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4729774907206057e-05
#             Iterations: 385
#             Function evaluations: 179410
#             Gradient evaluations: 385
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.347821600683281
#             Iterations: 99
#             Function evaluations: 44384
#             Gradient evaluations: 95
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.371538395447515e-09
#             Iterations: 16
#             Function evaluations: 7457
#             Gradient evaluations: 16
# 2024-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.586167248381079e-05
#             Iterations: 394
#             Function evaluations: 185574
#             Gradient evaluations: 394
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.432436409410769
#             Iterations: 87
#             Function evaluations: 39192
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9083609879571457e-09
#             Iterations: 18
#             Function evaluations: 8478
#             Gradient evaluations: 18
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df.to_csv("renditensp500_2Monate_f.csv")

# %% [markdown]
# ## Ergebnis-Erzeugung JSE

# %%
returns = df_JSE.pct_change()
returns = returns.where(~df_JSE.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of               4SI.JO    ABG.JO    ACL.JO    ACT.JO    ADH.JO    AEL.JO  \
# Date
# 2005-06-02       NaN  0.001214 -0.006225  0.000000 -0.014598       NaN
# 2005-06-03       NaN  0.001333  0.000000  0.000000  0.000000       NaN
# 2005-06-06       NaN  0.003510  0.014953  0.000000  0.007407       NaN
# 2005-06-07       NaN  0.006634 -0.035437  0.146154 -0.007353       NaN
# 2005-06-08       NaN -0.005392 -0.029721  0.000000  0.007407       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26  0.000000  0.007235 -0.018018  0.000000  0.005975  0.000426
# 2025-05-27  0.000000  0.000178 -0.036697  0.000000  0.003439  0.000000
# 2025-05-28  0.042857  0.026828 -0.038095  0.087500  0.022741  0.002128
# 2025-05-29 -0.041096  0.016127  0.049505 -0.045977 -0.010966  0.002972
# 2025-05-30  0.000000 -0.014051  0.094340 -0.036145 -0.009855 -0.001693
#
#               AFE.JO    AFH.JO    AFT.JO    AGL.JO  ...    VKE.JO    VOD.JO  \
# Date                                                ...
# 2005-06-02  0.020642       NaN       NaN  0.005481  ...       NaN  0.017117
# 2005-06-03  0.000000       NaN       NaN  0.000000  ...       NaN  0.000000
# 2005-06-06  0.000000       NaN       NaN -0.019079  ...       NaN  0.045350
# 2005-06-07  0.000225       NaN       NaN -0.020994  ...       NaN -0.000169
# 2005-06-08  0.011009       NaN       NaN  0.014191  ...       NaN -0.025424
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-26  0.007992  0.032548 -0.002564  0.029137  ... -0.010417 -0.016292
# 2025-05-27  0.007252 -0.026087  0.026498 -0.018270  ...  0.006316  0.002971
# 2025-05-28  0.002592  0.017857  0.000000 -0.008829  ...  0.001046 -0.006294
# 2025-05-29 -0.011298 -0.013158 -0.008476 -0.005631  ...  0.014107  0.031967
# 2025-05-30  0.000872 -0.011111  0.010297  0.016932  ...  0.030912 -0.005199
#
#               WBC.JO    WBO.JO    WEZ.JO    WHL.JO    YRK.JO  YYLBEE.JO  \
# Date
# 2005-06-02       NaN  0.009434       NaN  0.009901  0.000000        NaN
# 2005-06-03       NaN  0.000000       NaN  0.000000  0.000000        NaN
# 2005-06-06       NaN  0.009346       NaN  0.026471  0.000000        NaN
# 2005-06-07       NaN  0.000000       NaN  0.012416  0.000000        NaN
# 2005-06-08       NaN  0.018519       NaN -0.027358  0.000000        NaN
# ...              ...       ...       ...       ...       ...        ...
# 2025-05-26  0.021277 -0.005745  0.111111 -0.000174  0.046154        0.0
# 2025-05-27  0.015625  0.007979 -0.100000 -0.008726  0.000000        0.0
# 2025-05-28 -0.010872 -0.018234 -0.022222  0.014965 -0.083333        0.0
# 2025-05-29  0.013895 -0.005505  0.022727  0.016132  0.016043        0.0
# 2025-05-30  0.002250  0.014985 -0.044444  0.000341  0.026316        0.0
#
#               ZED.JO    ZZD.JO
# Date
# 2005-06-02       NaN       NaN
# 2005-06-03       NaN       NaN
# 2005-06-06       NaN       NaN
# 2005-06-07       NaN       NaN
# 2005-06-08       NaN       NaN
# ...              ...       ...
# 2025-05-26 -0.008264 -0.000864
# 2025-05-27 -0.016667  0.037165
# 2025-05-28  0.059322  0.008333
# 2025-05-29  0.008000 -0.008264
# 2025-05-30  0.023810 -0.012500
#
# [5170 rows x 217 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 2
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = training_daten.cov()
    corr_matrix = training_daten.corr()
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    JSE_gewichte_equally_weighted = equally_weighted(training_daten)
    JSE_gewichte_min_variance= min_variance_opt(cov_matrix)
    JSE_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    JSE_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    JSE_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    JSE_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    JSE_gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": JSE_gewichte_equally_weighted,
    "Minimum-Variance": JSE_gewichte_min_variance,
    "Maximum-Diversification": JSE_gewichte_max_diversification,
    "Inverse-Volatility": JSE_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": JSE_gewichte_risk_parity,
    "HRP": JSE_gewichte_hrp,
    "HERC": JSE_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
     #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
# Alle Testperioden zusammenführen
portfolio_returns_df_JSE = pd.concat(portfolio_returns_list)
portfolio_returns_df_JSE = portfolio_returns_df_JSE.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3134440810290774e-05
#             Iterations: 152
#             Function evaluations: 10184
#             Gradient evaluations: 152
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.653137425667317
#             Iterations: 53
#             Function evaluations: 3590
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1202687138208137e-09
#             Iterations: 44
#             Function evaluations: 2948
#             Gradient evaluations: 44
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.2112396294223096e-05
#             Iterations: 132
#             Function evaluations: 8976
#             Gradient evaluations: 132
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2479692179250157
#             Iterations: 28
#             Function evaluations: 1928
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.004277739155779e-09
#             Iterations: 53
#             Function evaluations: 3604
#             Gradient evaluations: 53
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.118768257769819e-05
#             Iterations: 131
#             Function evaluations: 8777
#             Gradient evaluations: 131
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2198144026852855
#             Iterations: 25
#             Function evaluations: 1698
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4725374248741186e-09
#             Iterations: 53
#             Function evaluations: 3551
#             Gradient evaluations: 53
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.859415038915805e-05
#             Iterations: 118
#             Function evaluations: 7906
#             Gradient evaluations: 118
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.296043847782716
#             Iterations: 34
#             Function evaluations: 2312
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7501750850210062e-09
#             Iterations: 53
#             Function evaluations: 3552
#             Gradient evaluations: 53
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.642058632619605e-05
#             Iterations: 120
#             Function evaluations: 8040
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5397191310792295
#             Iterations: 44
#             Function evaluations: 2980
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.362697223033904e-10
#             Iterations: 65
#             Function evaluations: 4355
#             Gradient evaluations: 65
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.004914997086485e-05
#             Iterations: 149
#             Function evaluations: 10132
#             Gradient evaluations: 149
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5898170232990703
#             Iterations: 39
#             Function evaluations: 2691
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3170971178692126e-10
#             Iterations: 54
#             Function evaluations: 3672
#             Gradient evaluations: 54
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.316667755489626e-05
#             Iterations: 140
#             Function evaluations: 10220
#             Gradient evaluations: 140
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7543156812255716
#             Iterations: 36
#             Function evaluations: 2666
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5276998741108466e-09
#             Iterations: 42
#             Function evaluations: 3067
#             Gradient evaluations: 42
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.285803869269542e-05
#             Iterations: 171
#             Function evaluations: 12996
#             Gradient evaluations: 171
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.46733021652852
#             Iterations: 65
#             Function evaluations: 4995
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6638863386240046e-09
#             Iterations: 45
#             Function evaluations: 3421
#             Gradient evaluations: 45
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.287275039163127e-05
#             Iterations: 148
#             Function evaluations: 11545
#             Gradient evaluations: 148
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1015136959335297
#             Iterations: 57
#             Function evaluations: 4488
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7795671843477796e-09
#             Iterations: 33
#             Function evaluations: 2574
#             Gradient evaluations: 33
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.478208204480234e-05
#             Iterations: 164
#             Function evaluations: 12956
#             Gradient evaluations: 164
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9052155889846007
#             Iterations: 64
#             Function evaluations: 5105
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7702775342306537e-09
#             Iterations: 32
#             Function evaluations: 2529
#             Gradient evaluations: 32
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.864525360519701e-05
#             Iterations: 139
#             Function evaluations: 11120
#             Gradient evaluations: 139
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.736960396203114
#             Iterations: 39
#             Function evaluations: 3159
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9854429343856237e-09
#             Iterations: 31
#             Function evaluations: 2481
#             Gradient evaluations: 31
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.6568036958412397e-05
#             Iterations: 189
#             Function evaluations: 15120
#             Gradient evaluations: 189
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.898518187325527
#             Iterations: 41
#             Function evaluations: 3319
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.905897572195089e-09
#             Iterations: 43
#             Function evaluations: 3440
#             Gradient evaluations: 43
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.015999680449088e-05
#             Iterations: 158
#             Function evaluations: 12166
#             Gradient evaluations: 158
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.877491757511488
#             Iterations: 44
#             Function evaluations: 3432
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.683014382006474e-09
#             Iterations: 43
#             Function evaluations: 3311
#             Gradient evaluations: 43
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.493057894033677e-05
#             Iterations: 133
#             Function evaluations: 10640
#             Gradient evaluations: 133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0375286887945956
#             Iterations: 43
#             Function evaluations: 3480
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2125919608147287e-09
#             Iterations: 44
#             Function evaluations: 3521
#             Gradient evaluations: 44
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.099017965153715e-05
#             Iterations: 156
#             Function evaluations: 12012
#             Gradient evaluations: 156
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.2440977493924046
#             Iterations: 54
#             Function evaluations: 4197
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.656611422037203e-10
#             Iterations: 52
#             Function evaluations: 4004
#             Gradient evaluations: 52
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.202402132898705e-05
#             Iterations: 162
#             Function evaluations: 12798
#             Gradient evaluations: 162
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9390265799580986
#             Iterations: 37
#             Function evaluations: 2956
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.66764580158499e-10
#             Iterations: 82
#             Function evaluations: 6478
#             Gradient evaluations: 82
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.613308742883006e-05
#             Iterations: 150
#             Function evaluations: 11550
#             Gradient evaluations: 150
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9521139070587727
#             Iterations: 42
#             Function evaluations: 3266
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.660572655724805e-10
#             Iterations: 92
#             Function evaluations: 7084
#             Gradient evaluations: 92
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.247322005436656e-05
#             Iterations: 162
#             Function evaluations: 12474
#             Gradient evaluations: 162
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.090891504506812
#             Iterations: 43
#             Function evaluations: 3343
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.338249654609997e-10
#             Iterations: 134
#             Function evaluations: 10318
#             Gradient evaluations: 134
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.904663878338106e-05
#             Iterations: 144
#             Function evaluations: 10944
#             Gradient evaluations: 144
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0787953783759843
#             Iterations: 47
#             Function evaluations: 3607
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.131393225491523e-10
#             Iterations: 111
#             Function evaluations: 8436
#             Gradient evaluations: 111
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.964045892800607e-05
#             Iterations: 138
#             Function evaluations: 10488
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.11343860360847
#             Iterations: 39
#             Function evaluations: 2996
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.14864806929461e-10
#             Iterations: 120
#             Function evaluations: 9120
#             Gradient evaluations: 120
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.36103865286447e-05
#             Iterations: 146
#             Function evaluations: 10951
#             Gradient evaluations: 146
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9604084300432727
#             Iterations: 39
#             Function evaluations: 2960
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.123400174497303e-10
#             Iterations: 100
#             Function evaluations: 7500
#             Gradient evaluations: 100
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.608105600686514e-05
#             Iterations: 137
#             Function evaluations: 10413
#             Gradient evaluations: 137
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.533439398965292
#             Iterations: 51
#             Function evaluations: 3924
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3783486293329875e-09
#             Iterations: 107
#             Function evaluations: 8132
#             Gradient evaluations: 107
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5411435395710477e-05
#             Iterations: 179
#             Function evaluations: 15215
#             Gradient evaluations: 179
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7194694586372865
#             Iterations: 56
#             Function evaluations: 4731
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.225929699992275e-09
#             Iterations: 85
#             Function evaluations: 7226
#             Gradient evaluations: 85
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.750886650300289e-05
#             Iterations: 217
#             Function evaluations: 18228
#             Gradient evaluations: 217
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8810267589327205
#             Iterations: 59
#             Function evaluations: 5011
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.1216320173923685e-09
#             Iterations: 76
#             Function evaluations: 6385
#             Gradient evaluations: 76
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7223491673189227e-05
#             Iterations: 200
#             Function evaluations: 17200
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6340233261636867
#             Iterations: 85
#             Function evaluations: 7252
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.837832603079748e-09
#             Iterations: 76
#             Function evaluations: 6536
#             Gradient evaluations: 76
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6793775693611726e-05
#             Iterations: 208
#             Function evaluations: 17473
#             Gradient evaluations: 208
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.544390252349358
#             Iterations: 57
#             Function evaluations: 4503
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.316071954319211e-09
#             Iterations: 56
#             Function evaluations: 4705
#             Gradient evaluations: 56
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.250891958536064e-05
#             Iterations: 233
#             Function evaluations: 20038
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.775630430490246
#             Iterations: 56
#             Function evaluations: 4783
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.227540443450577e-09
#             Iterations: 56
#             Function evaluations: 4816
#             Gradient evaluations: 56
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.261103504539436e-05
#             Iterations: 215
#             Function evaluations: 18490
#             Gradient evaluations: 215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.686923448426036
#             Iterations: 53
#             Function evaluations: 4609
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.657108988858343e-09
#             Iterations: 57
#             Function evaluations: 4902
#             Gradient evaluations: 57
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2377680964100189e-05
#             Iterations: 240
#             Function evaluations: 21600
#             Gradient evaluations: 240
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.945247603719802
#             Iterations: 57
#             Function evaluations: 5182
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8465484006603205e-09
#             Iterations: 57
#             Function evaluations: 5130
#             Gradient evaluations: 57
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3413686573649772e-05
#             Iterations: 235
#             Function evaluations: 20916
#             Gradient evaluations: 235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.852233115717422
#             Iterations: 52
#             Function evaluations: 4676
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.78641431529536e-09
#             Iterations: 57
#             Function evaluations: 5073
#             Gradient evaluations: 57
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1226748234171139e-05
#             Iterations: 237
#             Function evaluations: 20619
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.04682594292206
#             Iterations: 57
#             Function evaluations: 4928
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.492208989936472e-09
#             Iterations: 42
#             Function evaluations: 3654
#             Gradient evaluations: 42
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0472008943100286e-05
#             Iterations: 201
#             Function evaluations: 18291
#             Gradient evaluations: 201
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.178987604109217
#             Iterations: 58
#             Function evaluations: 5335
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.722634169698766e-09
#             Iterations: 43
#             Function evaluations: 3913
#             Gradient evaluations: 43
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2937545025472699e-05
#             Iterations: 216
#             Function evaluations: 20088
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.046877609134621
#             Iterations: 52
#             Function evaluations: 4887
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9333933142338135e-09
#             Iterations: 46
#             Function evaluations: 4278
#             Gradient evaluations: 46
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3687150043097548e-05
#             Iterations: 212
#             Function evaluations: 19504
#             Gradient evaluations: 212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7490132054974463
#             Iterations: 49
#             Function evaluations: 4552
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6614447934367397e-09
#             Iterations: 57
#             Function evaluations: 5244
#             Gradient evaluations: 57
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3810036328875528e-05
#             Iterations: 195
#             Function evaluations: 17550
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.413806682991515
#             Iterations: 51
#             Function evaluations: 4637
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7980262539798006e-09
#             Iterations: 57
#             Function evaluations: 5131
#             Gradient evaluations: 57
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1844473714327768e-05
#             Iterations: 225
#             Function evaluations: 20250
#             Gradient evaluations: 225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4649097033849237
#             Iterations: 51
#             Function evaluations: 4636
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.697445260281619e-09
#             Iterations: 58
#             Function evaluations: 5220
#             Gradient evaluations: 58
# 2011-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2163698841802925e-05
#             Iterations: 224
#             Function evaluations: 20384
#             Gradient evaluations: 224
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.370528109524003
#             Iterations: 55
#             Function evaluations: 5056
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.517710198813543e-09
#             Iterations: 45
#             Function evaluations: 4096
#             Gradient evaluations: 45
# 2011-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.224677230603339e-05
#             Iterations: 215
#             Function evaluations: 19781
#             Gradient evaluations: 215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.495749693532197
#             Iterations: 55
#             Function evaluations: 5115
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5527298151406096e-09
#             Iterations: 57
#             Function evaluations: 5245
#             Gradient evaluations: 57
# 2011-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.850105490812525e-06
#             Iterations: 248
#             Function evaluations: 22568
#             Gradient evaluations: 248
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.168521605923641
#             Iterations: 64
#             Function evaluations: 5523
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.872337228619579e-09
#             Iterations: 45
#             Function evaluations: 4095
#             Gradient evaluations: 45
# 2011-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.575034363674184e-06
#             Iterations: 262
#             Function evaluations: 23842
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.22556511940308
#             Iterations: 69
#             Function evaluations: 6355
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.375124953748949e-09
#             Iterations: 36
#             Function evaluations: 3276
#             Gradient evaluations: 36
# 2012-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0409069128223218e-05
#             Iterations: 226
#             Function evaluations: 20793
#             Gradient evaluations: 226
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.201466286048039
#             Iterations: 65
#             Function evaluations: 6052
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.551202234949972e-09
#             Iterations: 20
#             Function evaluations: 1841
#             Gradient evaluations: 20
# 2012-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0481438150179953e-05
#             Iterations: 236
#             Function evaluations: 22185
#             Gradient evaluations: 236
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.332112498357394
#             Iterations: 101
#             Function evaluations: 9389
#             Gradient evaluations: 97
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.557831008946999e-09
#             Iterations: 32
#             Function evaluations: 3009
#             Gradient evaluations: 32
# 2012-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1140361132140154e-05
#             Iterations: 225
#             Function evaluations: 21600
#             Gradient evaluations: 225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.3995448537433335
#             Iterations: 68
#             Function evaluations: 6605
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.4501551045966185e-09
#             Iterations: 35
#             Function evaluations: 3360
#             Gradient evaluations: 35
# 2012-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.491865740047313e-05
#             Iterations: 194
#             Function evaluations: 18624
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9636561490935325
#             Iterations: 61
#             Function evaluations: 5917
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.879481228619418e-09
#             Iterations: 32
#             Function evaluations: 3072
#             Gradient evaluations: 32
# 2012-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4229004431518492e-05
#             Iterations: 207
#             Function evaluations: 20493
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.105359585045188
#             Iterations: 68
#             Function evaluations: 6802
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.506097741157137e-09
#             Iterations: 41
#             Function evaluations: 4060
#             Gradient evaluations: 41
# 2012-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.398904318254147e-05
#             Iterations: 213
#             Function evaluations: 21727
#             Gradient evaluations: 213
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.241127773739358
#             Iterations: 66
#             Function evaluations: 6702
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.069375924709182e-09
#             Iterations: 29
#             Function evaluations: 2958
#             Gradient evaluations: 29
# 2013-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4485063208310921e-05
#             Iterations: 203
#             Function evaluations: 21112
#             Gradient evaluations: 203
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.353502528249736
#             Iterations: 68
#             Function evaluations: 7142
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.865344294942966e-09
#             Iterations: 43
#             Function evaluations: 4472
#             Gradient evaluations: 43
# 2013-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4595578318804427e-05
#             Iterations: 176
#             Function evaluations: 18305
#             Gradient evaluations: 176
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.387053907786595
#             Iterations: 67
#             Function evaluations: 6937
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.4607562954919935e-09
#             Iterations: 43
#             Function evaluations: 4472
#             Gradient evaluations: 43
# 2013-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2420205042968393e-05
#             Iterations: 185
#             Function evaluations: 19056
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.389701818372124
#             Iterations: 62
#             Function evaluations: 6356
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.827395306734299e-09
#             Iterations: 31
#             Function evaluations: 3193
#             Gradient evaluations: 31
# 2013-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.761257683379355e-06
#             Iterations: 216
#             Function evaluations: 22249
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.558173688946966
#             Iterations: 76
#             Function evaluations: 7917
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6775506899368875e-09
#             Iterations: 33
#             Function evaluations: 3399
#             Gradient evaluations: 33
# 2013-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.650210676164808e-06
#             Iterations: 219
#             Function evaluations: 22776
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.68674561942134
#             Iterations: 67
#             Function evaluations: 7048
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.895644754795919e-09
#             Iterations: 22
#             Function evaluations: 2288
#             Gradient evaluations: 22
# 2013-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1234681866522788e-05
#             Iterations: 193
#             Function evaluations: 20652
#             Gradient evaluations: 193
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.653388661523133
#             Iterations: 69
#             Function evaluations: 7464
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.925024220106083e-09
#             Iterations: 25
#             Function evaluations: 2675
#             Gradient evaluations: 25
# 2014-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.684539725159314e-06
#             Iterations: 221
#             Function evaluations: 23648
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.241460489444265
#             Iterations: 75
#             Function evaluations: 8122
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.198690984108693e-09
#             Iterations: 42
#             Function evaluations: 4494
#             Gradient evaluations: 42
# 2014-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0064380442317747e-05
#             Iterations: 239
#             Function evaluations: 25812
#             Gradient evaluations: 239
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.0308572577240485
#             Iterations: 143
#             Function evaluations: 15683
#             Gradient evaluations: 139
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.868268354731185e-09
#             Iterations: 42
#             Function evaluations: 4536
#             Gradient evaluations: 42
# 2014-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.187354176197228e-06
#             Iterations: 240
#             Function evaluations: 26400
#             Gradient evaluations: 240
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.529713098521586
#             Iterations: 72
#             Function evaluations: 7910
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.074843516839046e-09
#             Iterations: 32
#             Function evaluations: 3521
#             Gradient evaluations: 32
# 2014-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1289627778459613e-05
#             Iterations: 214
#             Function evaluations: 24182
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.237522589729821
#             Iterations: 146
#             Function evaluations: 16729
#             Gradient evaluations: 142
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.817595911451616e-09
#             Iterations: 42
#             Function evaluations: 4746
#             Gradient evaluations: 42
# 2014-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8676797735608916e-05
#             Iterations: 210
#             Function evaluations: 23520
#             Gradient evaluations: 210
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.497581700581393
#             Iterations: 74
#             Function evaluations: 8366
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5548028623895755e-09
#             Iterations: 53
#             Function evaluations: 5936
#             Gradient evaluations: 53
# 2014-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9016949360606556e-05
#             Iterations: 229
#             Function evaluations: 26106
#             Gradient evaluations: 229
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.525580504705169
#             Iterations: 116
#             Function evaluations: 13173
#             Gradient evaluations: 112
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7483486521497167e-09
#             Iterations: 56
#             Function evaluations: 6384
#             Gradient evaluations: 56
# 2015-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4385882411264044e-05
#             Iterations: 241
#             Function evaluations: 28197
#             Gradient evaluations: 241
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.618474871459888
#             Iterations: 106
#             Function evaluations: 12277
#             Gradient evaluations: 102
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.123766984216293e-09
#             Iterations: 96
#             Function evaluations: 11232
#             Gradient evaluations: 96
# 2015-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5720682035608357e-05
#             Iterations: 224
#             Function evaluations: 25984
#             Gradient evaluations: 224
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.445130867197333
#             Iterations: 67
#             Function evaluations: 7843
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.05048115885811e-09
#             Iterations: 149
#             Function evaluations: 17284
#             Gradient evaluations: 149
# 2015-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5882404019576374e-05
#             Iterations: 223
#             Function evaluations: 25869
#             Gradient evaluations: 223
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.425140535367625
#             Iterations: 72
#             Function evaluations: 7961
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.803750804650525e-09
#             Iterations: 138
#             Function evaluations: 16008
#             Gradient evaluations: 138
# 2015-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.553700541662337e-05
#             Iterations: 209
#             Function evaluations: 24453
#             Gradient evaluations: 209
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.429153277622531
#             Iterations: 68
#             Function evaluations: 7555
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7873585444051588e-08
#             Iterations: 137
#             Function evaluations: 16029
#             Gradient evaluations: 137
# 2015-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2087583309331887e-05
#             Iterations: 198
#             Function evaluations: 23167
#             Gradient evaluations: 198
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.7806908765104135
#             Iterations: 100
#             Function evaluations: 11380
#             Gradient evaluations: 96
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3896128488184162e-08
#             Iterations: 114
#             Function evaluations: 13338
#             Gradient evaluations: 114
# 2015-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.196734054897911e-05
#             Iterations: 192
#             Function evaluations: 22849
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.8205337163009965
#             Iterations: 73
#             Function evaluations: 8303
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0372407950777966e-08
#             Iterations: 89
#             Function evaluations: 10592
#             Gradient evaluations: 89
# 2016-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4637545459857292e-05
#             Iterations: 215
#             Function evaluations: 25800
#             Gradient evaluations: 215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.302380403271778
#             Iterations: 75
#             Function evaluations: 9096
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.555008065378782e-09
#             Iterations: 97
#             Function evaluations: 11641
#             Gradient evaluations: 97
# 2016-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1739480353308346e-05
#             Iterations: 225
#             Function evaluations: 27001
#             Gradient evaluations: 225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.605296925455596
#             Iterations: 73
#             Function evaluations: 8750
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.176048956959557e-09
#             Iterations: 77
#             Function evaluations: 9240
#             Gradient evaluations: 77
# 2016-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.249034470360137e-05
#             Iterations: 252
#             Function evaluations: 30996
#             Gradient evaluations: 252
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.3170785740517745
#             Iterations: 83
#             Function evaluations: 9821
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.220459165023777e-09
#             Iterations: 56
#             Function evaluations: 6888
#             Gradient evaluations: 56
# 2016-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.716182645425711e-06
#             Iterations: 258
#             Function evaluations: 32251
#             Gradient evaluations: 258
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.11384033206042
#             Iterations: 155
#             Function evaluations: 19568
#             Gradient evaluations: 151
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.862269585388539e-09
#             Iterations: 45
#             Function evaluations: 5626
#             Gradient evaluations: 45
# 2016-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.337491346862976e-06
#             Iterations: 276
#             Function evaluations: 35053
#             Gradient evaluations: 276
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.412844629213125
#             Iterations: 109
#             Function evaluations: 13571
#             Gradient evaluations: 105
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0607095367161126e-08
#             Iterations: 41
#             Function evaluations: 5207
#             Gradient evaluations: 41
# 2016-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.700078943231016e-06
#             Iterations: 291
#             Function evaluations: 37248
#             Gradient evaluations: 291
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.072392308061966
#             Iterations: 106
#             Function evaluations: 13231
#             Gradient evaluations: 102
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1519367177619944e-08
#             Iterations: 29
#             Function evaluations: 3713
#             Gradient evaluations: 29
# 2017-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.855449284098391e-06
#             Iterations: 278
#             Function evaluations: 35584
#             Gradient evaluations: 278
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.9473275714134015
#             Iterations: 103
#             Function evaluations: 12890
#             Gradient evaluations: 99
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0813362515464916e-08
#             Iterations: 33
#             Function evaluations: 4225
#             Gradient evaluations: 33
# 2017-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1669106809347865e-05
#             Iterations: 251
#             Function evaluations: 32379
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.468935627962474
#             Iterations: 111
#             Function evaluations: 14035
#             Gradient evaluations: 107
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.315315246930315e-09
#             Iterations: 31
#             Function evaluations: 3999
# ...
#             Function evaluations: 34310
#             Gradient evaluations: 235
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5.895855579058594
#             Iterations: 93
#             Function evaluations: 13126
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.462863030416491e-09
#             Iterations: 91
#             Function evaluations: 13287
#             Gradient evaluations: 91
# 2020-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9658937085876558e-05
#             Iterations: 235
#             Function evaluations: 34075
#             Gradient evaluations: 235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.708209897792519
#             Iterations: 96
#             Function evaluations: 13475
#             Gradient evaluations: 92
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3498431449619635e-09
#             Iterations: 72
#             Function evaluations: 10440
#             Gradient evaluations: 72
# 2020-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.562727412045885e-05
#             Iterations: 269
#             Function evaluations: 40350
#             Gradient evaluations: 269
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.115277239929744
#             Iterations: 97
#             Function evaluations: 14082
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.494601345308417e-09
#             Iterations: 73
#             Function evaluations: 10950
#             Gradient evaluations: 73
# 2020-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3600606143243473e-05
#             Iterations: 242
#             Function evaluations: 36784
#             Gradient evaluations: 242
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.432993241014148
#             Iterations: 115
#             Function evaluations: 17081
#             Gradient evaluations: 111
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5836595107466267e-09
#             Iterations: 63
#             Function evaluations: 9576
#             Gradient evaluations: 63
# 2021-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3233747748853279e-05
#             Iterations: 265
#             Function evaluations: 40546
#             Gradient evaluations: 265
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.09808870357025
#             Iterations: 97
#             Function evaluations: 14361
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.529456721446563e-09
#             Iterations: 45
#             Function evaluations: 6885
#             Gradient evaluations: 45
# 2021-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.705484646781876e-05
#             Iterations: 245
#             Function evaluations: 37486
#             Gradient evaluations: 245
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.718239188985239
#             Iterations: 93
#             Function evaluations: 13742
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.526711042504311e-09
#             Iterations: 33
#             Function evaluations: 5049
#             Gradient evaluations: 33
# 2021-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0239965989158137e-05
#             Iterations: 196
#             Function evaluations: 29989
#             Gradient evaluations: 196
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.124772356650604
#             Iterations: 82
#             Function evaluations: 12030
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.681180557996073e-09
#             Iterations: 44
#             Function evaluations: 6732
#             Gradient evaluations: 44
# 2021-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.503880705737612e-05
#             Iterations: 210
#             Function evaluations: 32131
#             Gradient evaluations: 210
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.858483727385333
#             Iterations: 84
#             Function evaluations: 12342
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5225975781940956e-09
#             Iterations: 55
#             Function evaluations: 8416
#             Gradient evaluations: 55
# 2021-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6512514925600043e-05
#             Iterations: 221
#             Function evaluations: 33371
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.940383990359502
#             Iterations: 79
#             Function evaluations: 11878
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6778631791198616e-09
#             Iterations: 55
#             Function evaluations: 8306
#             Gradient evaluations: 55
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5527687349963467e-05
#             Iterations: 220
#             Function evaluations: 33440
#             Gradient evaluations: 220
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.184237198969174
#             Iterations: 107
#             Function evaluations: 15841
#             Gradient evaluations: 103
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3596794764361764e-09
#             Iterations: 44
#             Function evaluations: 6689
#             Gradient evaluations: 44
# 2022-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.372860682593203e-05
#             Iterations: 221
#             Function evaluations: 33813
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.378087369517768
#             Iterations: 75
#             Function evaluations: 10950
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.589353900452082e-09
#             Iterations: 44
#             Function evaluations: 6733
#             Gradient evaluations: 44
# 2022-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7675503259022067e-05
#             Iterations: 245
#             Function evaluations: 37975
#             Gradient evaluations: 245
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5.50691004281292
#             Iterations: 111
#             Function evaluations: 16881
#             Gradient evaluations: 107
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.512436561137227e-09
#             Iterations: 55
#             Function evaluations: 8526
#             Gradient evaluations: 55
# 2022-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.546786741097154e-05
#             Iterations: 247
#             Function evaluations: 38286
#             Gradient evaluations: 247
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.0320146612446575
#             Iterations: 88
#             Function evaluations: 13147
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.463262316108444e-09
#             Iterations: 56
#             Function evaluations: 8680
#             Gradient evaluations: 56
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2814081746620865e-05
#             Iterations: 237
#             Function evaluations: 37684
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.612487218140196
#             Iterations: 113
#             Function evaluations: 17544
#             Gradient evaluations: 109
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.689922032275674e-09
#             Iterations: 44
#             Function evaluations: 6996
#             Gradient evaluations: 44
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1798537812387731e-05
#             Iterations: 249
#             Function evaluations: 38844
#             Gradient evaluations: 249
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.396765432658553
#             Iterations: 114
#             Function evaluations: 17382
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.8540964883590575e-09
#             Iterations: 57
#             Function evaluations: 8892
#             Gradient evaluations: 57
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0638443984101544e-05
#             Iterations: 262
#             Function evaluations: 39824
#             Gradient evaluations: 262
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.454284185655669
#             Iterations: 98
#             Function evaluations: 14444
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.342262248551165e-09
#             Iterations: 41
#             Function evaluations: 6233
#             Gradient evaluations: 41
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1646390485915314e-05
#             Iterations: 244
#             Function evaluations: 37088
#             Gradient evaluations: 244
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.97073625711648
#             Iterations: 95
#             Function evaluations: 13973
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.46474672838338e-09
#             Iterations: 41
#             Function evaluations: 6232
#             Gradient evaluations: 41
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1097444403864161e-05
#             Iterations: 240
#             Function evaluations: 36481
#             Gradient evaluations: 240
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.330845830415378
#             Iterations: 114
#             Function evaluations: 17041
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.480961611131053e-09
#             Iterations: 54
#             Function evaluations: 8208
#             Gradient evaluations: 54
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1447418857812869e-05
#             Iterations: 251
#             Function evaluations: 38153
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.19533116508335
#             Iterations: 132
#             Function evaluations: 19866
#             Gradient evaluations: 128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.521352585971489e-09
#             Iterations: 50
#             Function evaluations: 7600
#             Gradient evaluations: 50
# 2023-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1422709202129747e-05
#             Iterations: 264
#             Function evaluations: 40128
#             Gradient evaluations: 264
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.231100190427219
#             Iterations: 103
#             Function evaluations: 15219
#             Gradient evaluations: 99
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.031185921833766e-09
#             Iterations: 53
#             Function evaluations: 8056
#             Gradient evaluations: 53
# 2023-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2166903906411595e-05
#             Iterations: 263
#             Function evaluations: 39714
#             Gradient evaluations: 263
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.019509049152355
#             Iterations: 96
#             Function evaluations: 14483
#             Gradient evaluations: 95
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.938520382132033e-09
#             Iterations: 52
#             Function evaluations: 7853
#             Gradient evaluations: 52
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.090650657560652e-05
#             Iterations: 274
#             Function evaluations: 41648
#             Gradient evaluations: 274
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.42072094048574
#             Iterations: 124
#             Function evaluations: 18525
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.288669387680618e-09
#             Iterations: 49
#             Function evaluations: 7448
#             Gradient evaluations: 49
# 2024-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0519396753445875e-05
#             Iterations: 257
#             Function evaluations: 39064
#             Gradient evaluations: 257
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.387403771748381
#             Iterations: 138
#             Function evaluations: 20844
#             Gradient evaluations: 134
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.0320985072202475e-09
#             Iterations: 50
#             Function evaluations: 7600
#             Gradient evaluations: 50
# 2024-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0245149374963766e-05
#             Iterations: 280
#             Function evaluations: 42281
#             Gradient evaluations: 280
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.464131357018838
#             Iterations: 88
#             Function evaluations: 13268
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.180734991124907e-09
#             Iterations: 51
#             Function evaluations: 7701
#             Gradient evaluations: 51
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_JSE.to_csv("returnsJSE_2Monate_f.csv")

# %% [markdown]
# ## Ledoit-Wolf Shrinkage

# %%
#Definition von Ledoit-Shrinkage

def ledoit_shrink (returns):
    
    shrinkage = LedoitWolf().fit(returns.values)
    
    shrinkage_matrix = pd.DataFrame(
        shrinkage.covariance_,
        index = returns.columns,
        columns = returns.columns)
    
    return shrinkage_matrix

# %% [markdown]
# ### Auswertung S&P500 mit Ledoit Wolf

# %%
returns = df_SP500.pct_change()
returns = returns.where(~df_SP500.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                    A  AAL  AAP      AAPL      ABBV      ABNB       ABT  \
# Date
# 2005-06-02  0.000414  NaN  NaN -0.006452       NaN       NaN -0.001448
# 2005-06-03 -0.005374  NaN  NaN -0.044955       NaN       NaN  0.000207
# 2005-06-06  0.019119  NaN  NaN -0.008368       NaN       NaN  0.003729
# 2005-06-07 -0.012235  NaN  NaN -0.036393       NaN       NaN  0.006398
# 2005-06-08  0.009496  NaN  NaN  0.010399       NaN       NaN -0.002051
# ...              ...  ...  ...       ...       ...       ...       ...
# 2025-05-23 -0.010485  NaN  NaN -0.030244  0.003944 -0.007286 -0.001521
# 2025-05-27  0.025154  NaN  NaN  0.025298  0.013424  0.021149  0.012490
# 2025-05-28 -0.003415  NaN  NaN  0.001049 -0.014161 -0.005641 -0.006920
# 2025-05-29  0.021645  NaN  NaN -0.002345  0.013818 -0.002409  0.006287
# 2025-05-30 -0.012006  NaN  NaN  0.004501  0.002640  0.004986  0.005495
#
#                 ACGL       ACN      ADBE  ...       XEL       XOM  XRAY  \
# Date                                      ...
# 2005-06-02       NaN       NaN -0.002712  ...  0.002678  0.002975   NaN
# 2005-06-03       NaN       NaN -0.016621  ...  0.004808 -0.002966   NaN
# 2005-06-06       NaN       NaN -0.002766  ...  0.000532  0.007874   NaN
# 2005-06-07       NaN       NaN -0.005855  ...  0.004251 -0.002604   NaN
# 2005-06-08       NaN       NaN  0.000000  ...  0.017460 -0.012533   NaN
# ...              ...       ...       ...  ...       ...       ...   ...
# 2025-05-23  0.001087 -0.021710 -0.016026  ...  0.007513  0.000583   NaN
# 2025-05-27  0.027696  0.018897  0.013270  ...  0.001147  0.004756   NaN
# 2025-05-28 -0.017332  0.001775 -0.002106  ... -0.012606 -0.013621   NaN
# 2025-05-29  0.013121  0.005507  0.002741  ...  0.007834  0.005680   NaN
# 2025-05-30  0.008917 -0.002864  0.004185  ...  0.009069 -0.003798   NaN
#
#                  XRX       XYL       YUM       ZBH      ZBRA      ZION  \
# Date
# 2005-06-02 -0.003650       NaN  0.021558  0.002885       NaN  0.005945
# 2005-06-03 -0.006593       NaN -0.010646  0.029816       NaN -0.008246
# 2005-06-06 -0.011062       NaN -0.000769 -0.005079       NaN -0.000139
# 2005-06-07 -0.006711       NaN  0.003077  0.013657       NaN -0.002772
# 2005-06-08  0.039039       NaN -0.006518 -0.005414       NaN -0.002085
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23       NaN -0.009739 -0.000344  0.010581 -0.014392       NaN
# 2025-05-27       NaN  0.017654 -0.009350  0.016947  0.038000       NaN
# 2025-05-28       NaN -0.004674 -0.006524 -0.020380 -0.014271       NaN
# 2025-05-29       NaN  0.000080  0.006217  0.011377  0.005846       NaN
# 2025-05-30       NaN  0.003024 -0.000694 -0.012535 -0.009333       NaN
#
#                  ZTS
# Date
# 2005-06-02       NaN
# 2005-06-03       NaN
# 2005-06-06       NaN
# 2005-06-07       NaN
# 2005-06-08       NaN
# ...              ...
# 2025-05-23  0.003766
# 2025-05-27  0.022635
# 2025-05-28 -0.005173
# 2025-05-29  0.010520
# 2025-05-30  0.008915
#
# [5031 rows x 598 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 2
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = ledoit_shrink(training_daten)
    
    #aus der geschrumpften Matrix die Korrelationsmatrix bauen
    standardabweichung = np.sqrt(np.diag(cov_matrix))
    corr_matrix = cov_matrix / np.outer(standardabweichung, standardabweichung)
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    shrinked_gewichte_equally_weighted = equally_weighted(training_daten)
    shrinked_gewichte_min_variance= min_variance_opt(cov_matrix)
    shrinked_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    shrinked_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    shrinked_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    shrinked_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    shrinked_gewichte_herc = herc_ledoit(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": shrinked_gewichte_equally_weighted,
    "Minimum-Variance": shrinked_gewichte_min_variance,
    "Maximum-Diversification": shrinked_gewichte_max_diversification,
    "Inverse-Volatility": shrinked_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": shrinked_gewichte_risk_parity,
    "HRP": shrinked_gewichte_hrp,
    "HERC": shrinked_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
     #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_shrinked = pd.concat(portfolio_returns_list)
portfolio_returns_df_shrinked = portfolio_returns_df_shrinked.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5288862200654737e-05
#             Iterations: 308
#             Function evaluations: 81312
#             Gradient evaluations: 308
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1767340633144645
#             Iterations: 80
#             Function evaluations: 20138
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.367469318835228e-09
#             Iterations: 9
#             Function evaluations: 2376
#             Gradient evaluations: 9
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.67889435502806e-05
#             Iterations: 300
#             Function evaluations: 79800
#             Gradient evaluations: 300
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9599933973857606
#             Iterations: 83
#             Function evaluations: 21102
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.4026876436595614e-09
#             Iterations: 20
#             Function evaluations: 5321
#             Gradient evaluations: 20
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5702565664566613e-05
#             Iterations: 313
#             Function evaluations: 84197
#             Gradient evaluations: 313
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.017946102283101
#             Iterations: 76
#             Function evaluations: 20516
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.172475061620501e-09
#             Iterations: 31
#             Function evaluations: 8339
#             Gradient evaluations: 31
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.437936973290573e-05
#             Iterations: 299
#             Function evaluations: 81029
#             Gradient evaluations: 299
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1814314294424912
#             Iterations: 74
#             Function evaluations: 19038
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1732524466424905e-09
#             Iterations: 23
#             Function evaluations: 6233
#             Gradient evaluations: 23
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2916693463715328e-05
#             Iterations: 301
#             Function evaluations: 82474
#             Gradient evaluations: 301
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.219892394705214
#             Iterations: 81
#             Function evaluations: 21176
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.624470963323754e-09
#             Iterations: 26
#             Function evaluations: 7125
#             Gradient evaluations: 26
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.657100076421387e-05
#             Iterations: 323
#             Function evaluations: 88825
#             Gradient evaluations: 323
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.878340068057983
#             Iterations: 76
#             Function evaluations: 19873
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.458855213768547e-09
#             Iterations: 26
#             Function evaluations: 7150
#             Gradient evaluations: 26
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5854763579769293e-05
#             Iterations: 280
#             Function evaluations: 77840
#             Gradient evaluations: 280
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0076215287471926
#             Iterations: 79
#             Function evaluations: 20930
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.724209090209557e-09
#             Iterations: 27
#             Function evaluations: 7506
#             Gradient evaluations: 27
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.774205682641366e-05
#             Iterations: 267
#             Function evaluations: 74227
#             Gradient evaluations: 267
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.121246259301799
#             Iterations: 66
#             Function evaluations: 17585
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5955538795350288e-09
#             Iterations: 21
#             Function evaluations: 5838
#             Gradient evaluations: 21
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6369080435881867e-05
#             Iterations: 247
#             Function evaluations: 68913
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7710790079086074
#             Iterations: 58
#             Function evaluations: 15120
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7477820932045088e-09
#             Iterations: 19
#             Function evaluations: 5301
#             Gradient evaluations: 19
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1488954114940315e-05
#             Iterations: 262
#             Function evaluations: 74146
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5706775380278493
#             Iterations: 47
#             Function evaluations: 13064
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.659018115558484e-09
#             Iterations: 30
#             Function evaluations: 8490
#             Gradient evaluations: 30
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.89983326460673e-05
#             Iterations: 245
#             Function evaluations: 69826
#             Gradient evaluations: 245
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.509788557319407
#             Iterations: 58
#             Function evaluations: 15448
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0134906036599704e-09
#             Iterations: 48
#             Function evaluations: 13680
#             Gradient evaluations: 48
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3011341760476444e-05
#             Iterations: 253
#             Function evaluations: 73117
#             Gradient evaluations: 253
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6587956963036263
#             Iterations: 47
#             Function evaluations: 13338
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.315488138946422e-10
#             Iterations: 57
#             Function evaluations: 16474
#             Gradient evaluations: 57
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.5411428925910594e-05
#             Iterations: 246
#             Function evaluations: 71586
#             Gradient evaluations: 246
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6422651399028068
#             Iterations: 42
#             Function evaluations: 12262
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1484385309851184e-09
#             Iterations: 57
#             Function evaluations: 16588
#             Gradient evaluations: 57
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7548110958653614e-05
#             Iterations: 215
#             Function evaluations: 62566
#             Gradient evaluations: 215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5978355427899853
#             Iterations: 49
#             Function evaluations: 13139
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1886893305855933e-09
#             Iterations: 73
#             Function evaluations: 21244
#             Gradient evaluations: 73
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.5847626408900054e-05
#             Iterations: 200
#             Function evaluations: 58000
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.551611837851268
#             Iterations: 47
#             Function evaluations: 13380
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2545863386397255e-09
#             Iterations: 88
#             Function evaluations: 25521
#             Gradient evaluations: 88
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001820995126410556
#             Iterations: 138
#             Function evaluations: 39883
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9624980418975846
#             Iterations: 27
#             Function evaluations: 7823
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.726086949250995e-10
#             Iterations: 82
#             Function evaluations: 23698
#             Gradient evaluations: 82
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002013400461159941
#             Iterations: 114
#             Function evaluations: 33175
#             Gradient evaluations: 114
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9098058982135202
#             Iterations: 26
#             Function evaluations: 7586
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3768834027353787e-10
#             Iterations: 97
#             Function evaluations: 28227
#             Gradient evaluations: 97
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022619872851398361
#             Iterations: 129
#             Function evaluations: 37668
#             Gradient evaluations: 129
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8105468922993717
#             Iterations: 29
#             Function evaluations: 8487
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1302435598458933e-10
#             Iterations: 95
#             Function evaluations: 27741
#             Gradient evaluations: 95
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022759051948600625
#             Iterations: 120
#             Function evaluations: 35160
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8382220777257294
#             Iterations: 27
#             Function evaluations: 7931
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0108461465443225e-10
#             Iterations: 110
#             Function evaluations: 32231
#             Gradient evaluations: 110
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022545564587342235
#             Iterations: 95
#             Function evaluations: 28025
#             Gradient evaluations: 95
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.834950715498787
#             Iterations: 24
#             Function evaluations: 7100
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.108716646019016e-10
#             Iterations: 110
#             Function evaluations: 32450
#             Gradient evaluations: 110
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00020837203597747733
#             Iterations: 102
#             Function evaluations: 30498
#             Gradient evaluations: 102
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8462184515202908
#             Iterations: 26
#             Function evaluations: 7792
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.771529675406706e-10
#             Iterations: 103
#             Function evaluations: 30797
#             Gradient evaluations: 103
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.898120367891826e-05
#             Iterations: 186
#             Function evaluations: 56916
#             Gradient evaluations: 186
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -2.3079595422915644
#             Iterations: 42
#             Function evaluations: 11667
#             Gradient evaluations: 38
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.4824526282761064e-10
#             Iterations: 148
#             Function evaluations: 45288
#             Gradient evaluations: 148
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.901084980263468e-05
#             Iterations: 172
#             Function evaluations: 52804
#             Gradient evaluations: 172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.427135970711036
#             Iterations: 60
#             Function evaluations: 17260
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.070982203220988e-10
#             Iterations: 115
#             Function evaluations: 35306
#             Gradient evaluations: 115
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.343062440149899e-05
#             Iterations: 236
#             Function evaluations: 73397
#             Gradient evaluations: 236
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6639537094141743
#             Iterations: 47
#             Function evaluations: 14662
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2025528600755291e-09
#             Iterations: 104
#             Function evaluations: 32344
#             Gradient evaluations: 104
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.606872635936402e-05
#             Iterations: 228
#             Function evaluations: 70908
#             Gradient evaluations: 228
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.418935210854871
#             Iterations: 54
#             Function evaluations: 15605
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0896213777467165e-09
#             Iterations: 68
#             Function evaluations: 21148
#             Gradient evaluations: 68
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6968829416809135e-05
#             Iterations: 222
#             Function evaluations: 69931
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.342686556532796
#             Iterations: 51
#             Function evaluations: 14868
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.095078213397084e-09
#             Iterations: 56
#             Function evaluations: 17640
#             Gradient evaluations: 56
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.917974021894335e-05
#             Iterations: 220
#             Function evaluations: 69520
#             Gradient evaluations: 220
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.195655511719282
#             Iterations: 30
#             Function evaluations: 9508
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1618630887540427e-09
#             Iterations: 48
#             Function evaluations: 15169
#             Gradient evaluations: 48
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5673307771232926e-05
#             Iterations: 229
#             Function evaluations: 72593
#             Gradient evaluations: 229
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.183601304310304
#             Iterations: 32
#             Function evaluations: 10173
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.316995641430549e-10
#             Iterations: 50
#             Function evaluations: 15851
#             Gradient evaluations: 50
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.380654808126132e-05
#             Iterations: 183
#             Function evaluations: 58378
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2259668943448134
#             Iterations: 35
#             Function evaluations: 11197
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.552910895022277e-10
#             Iterations: 51
#             Function evaluations: 16269
#             Gradient evaluations: 51
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.422188937100494e-05
#             Iterations: 187
#             Function evaluations: 60214
#             Gradient evaluations: 187
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.257811741701639
#             Iterations: 36
#             Function evaluations: 11624
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.653631455844135e-10
#             Iterations: 52
#             Function evaluations: 16744
#             Gradient evaluations: 52
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.719010609462341e-05
#             Iterations: 244
#             Function evaluations: 78568
#             Gradient evaluations: 244
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4831922099846517
#             Iterations: 42
#             Function evaluations: 13564
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4846273267511418e-09
#             Iterations: 37
#             Function evaluations: 11914
#             Gradient evaluations: 37
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1177706179202975e-05
#             Iterations: 266
#             Function evaluations: 85918
#             Gradient evaluations: 266
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5731055950866404
#             Iterations: 65
#             Function evaluations: 19776
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1827339467373656e-09
#             Iterations: 29
#             Function evaluations: 9368
#             Gradient evaluations: 29
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.945293311494261e-05
#             Iterations: 190
#             Function evaluations: 61370
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0112627820923783
#             Iterations: 29
#             Function evaluations: 9393
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.654213711735158e-10
#             Iterations: 50
#             Function evaluations: 16151
#             Gradient evaluations: 50
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.8457770639930315e-05
#             Iterations: 199
#             Function evaluations: 64079
#             Gradient evaluations: 199
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8725828217002394
#             Iterations: 28
#             Function evaluations: 9042
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.106455339776744e-10
#             Iterations: 55
#             Function evaluations: 17711
#             Gradient evaluations: 55
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.111610063939757e-05
#             Iterations: 188
#             Function evaluations: 60912
#             Gradient evaluations: 188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0053262489611363
#             Iterations: 25
#             Function evaluations: 8115
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.573897562650746e-10
#             Iterations: 56
#             Function evaluations: 18144
#             Gradient evaluations: 56
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.827908573689174e-05
#             Iterations: 196
#             Function evaluations: 63504
#             Gradient evaluations: 196
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9866453549369887
#             Iterations: 30
#             Function evaluations: 8442
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.285236199559565e-10
#             Iterations: 66
#             Function evaluations: 21384
#             Gradient evaluations: 66
# 2011-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.8603318669103755e-05
#             Iterations: 192
#             Function evaluations: 62784
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9700289863502785
#             Iterations: 28
#             Function evaluations: 8847
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0960326692756335e-09
#             Iterations: 55
#             Function evaluations: 17986
#             Gradient evaluations: 55
# 2011-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.824305208054584e-05
#             Iterations: 178
#             Function evaluations: 58562
#             Gradient evaluations: 178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.000896281004322
#             Iterations: 38
#             Function evaluations: 11212
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.521019865595557e-10
#             Iterations: 64
#             Function evaluations: 21056
#             Gradient evaluations: 64
# 2011-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7831674572538414e-05
#             Iterations: 229
#             Function evaluations: 75571
#             Gradient evaluations: 229
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3276805683401145
#             Iterations: 45
#             Function evaluations: 13566
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5615275972934797e-09
#             Iterations: 57
#             Function evaluations: 18811
#             Gradient evaluations: 57
# 2011-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9335014962132286e-05
#             Iterations: 283
#             Function evaluations: 93674
#             Gradient evaluations: 283
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -2.753876476357252
#             Iterations: 54
#             Function evaluations: 16599
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3134027221119618e-09
#             Iterations: 44
#             Function evaluations: 14564
#             Gradient evaluations: 44
# 2012-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9247751619405397e-05
#             Iterations: 277
#             Function evaluations: 92795
#             Gradient evaluations: 277
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7839619117566445
#             Iterations: 53
#             Function evaluations: 16463
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6866836926495947e-09
#             Iterations: 37
#             Function evaluations: 12395
#             Gradient evaluations: 37
# 2012-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0878784234129455e-05
#             Iterations: 311
#             Function evaluations: 104496
#             Gradient evaluations: 311
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.778502562365898
#             Iterations: 48
#             Function evaluations: 16175
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2410379529715716e-09
#             Iterations: 25
#             Function evaluations: 8401
#             Gradient evaluations: 25
# 2012-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2340183982570044e-05
#             Iterations: 304
#             Function evaluations: 103056
#             Gradient evaluations: 304
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.943986219070745
#             Iterations: 63
#             Function evaluations: 20066
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.449954259817849e-09
#             Iterations: 28
#             Function evaluations: 9492
#             Gradient evaluations: 28
# 2012-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2929030171175268e-05
#             Iterations: 299
#             Function evaluations: 101959
#             Gradient evaluations: 299
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1030608271101805
#             Iterations: 58
#             Function evaluations: 18474
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.493932620996294e-09
#             Iterations: 17
#             Function evaluations: 5797
#             Gradient evaluations: 17
# 2012-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4303778872335664e-05
#             Iterations: 320
#             Function evaluations: 109441
#             Gradient evaluations: 320
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.142282782065964
#             Iterations: 49
#             Function evaluations: 15430
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.821152380852801e-10
#             Iterations: 20
#             Function evaluations: 6840
#             Gradient evaluations: 20
# 2012-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2101113822722085e-05
#             Iterations: 297
#             Function evaluations: 101872
#             Gradient evaluations: 297
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.072848071608814
#             Iterations: 51
#             Function evaluations: 17196
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0228812299240512e-09
#             Iterations: 20
#             Function evaluations: 6860
#             Gradient evaluations: 20
# 2013-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2884377856227454e-05
#             Iterations: 327
#             Function evaluations: 112815
#             Gradient evaluations: 327
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.146998157233521
#             Iterations: 57
#             Function evaluations: 18337
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0223381456410916e-09
#             Iterations: 20
#             Function evaluations: 6900
#             Gradient evaluations: 20
# 2013-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4332940109076093e-05
#             Iterations: 312
#             Function evaluations: 107953
#             Gradient evaluations: 312
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0276070711322633
#             Iterations: 54
#             Function evaluations: 17350
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6971195784829107e-09
#             Iterations: 8
#             Function evaluations: 2769
#             Gradient evaluations: 8
# 2013-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.241691119160509e-05
#             Iterations: 325
#             Function evaluations: 112451
#             Gradient evaluations: 325
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8924460477950333
#             Iterations: 69
#             Function evaluations: 22562
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1224089542487606e-09
#             Iterations: 17
#             Function evaluations: 5882
#             Gradient evaluations: 17
# 2013-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8259985776347174e-05
#             Iterations: 319
#             Function evaluations: 111331
#             Gradient evaluations: 319
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9619839341383067
#             Iterations: 88
#             Function evaluations: 29419
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2748449745563029e-09
#             Iterations: 15
#             Function evaluations: 5235
#             Gradient evaluations: 15
# 2013-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7128904451588232e-05
#             Iterations: 313
#             Function evaluations: 109863
#             Gradient evaluations: 313
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.072654167336018
#             Iterations: 69
#             Function evaluations: 22881
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9008667446362355e-09
#             Iterations: 17
#             Function evaluations: 5967
#             Gradient evaluations: 17
# 2013-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8042824187095885e-05
#             Iterations: 293
#             Function evaluations: 103136
#             Gradient evaluations: 293
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9870217392161025
#             Iterations: 63
#             Function evaluations: 20823
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3872504091361484e-09
#             Iterations: 17
#             Function evaluations: 5984
#             Gradient evaluations: 17
# 2014-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0956397703120196e-05
#             Iterations: 285
#             Function evaluations: 101175
#             Gradient evaluations: 285
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8025833077842903
#             Iterations: 69
#             Function evaluations: 23144
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7768244519310326e-09
#             Iterations: 17
#             Function evaluations: 6036
#             Gradient evaluations: 17
# 2014-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.473651335808459e-05
#             Iterations: 259
#             Function evaluations: 91686
#             Gradient evaluations: 259
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7992359095683663
#             Iterations: 50
#             Function evaluations: 17748
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.524328622118017e-09
#             Iterations: 16
#             Function evaluations: 5664
#             Gradient evaluations: 16
# 2014-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5385269323259534e-05
#             Iterations: 288
#             Function evaluations: 103392
#             Gradient evaluations: 288
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8989502861047494
#             Iterations: 59
#             Function evaluations: 21235
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1126403516726485e-09
#             Iterations: 9
#             Function evaluations: 3231
#             Gradient evaluations: 9
# 2014-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.729003421624939e-05
#             Iterations: 308
#             Function evaluations: 110881
#             Gradient evaluations: 308
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8688445829139875
#             Iterations: 51
#             Function evaluations: 18410
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.374699861854491e-09
#             Iterations: 9
#             Function evaluations: 3240
#             Gradient evaluations: 9
# 2014-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.271724242338241e-05
#             Iterations: 283
#             Function evaluations: 102447
#             Gradient evaluations: 283
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.443458746617534
#             Iterations: 35
#             Function evaluations: 12705
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6686812974765e-09
#             Iterations: 15
#             Function evaluations: 5430
#             Gradient evaluations: 15
# 2014-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.530322012727257e-05
#             Iterations: 270
#             Function evaluations: 97470
#             Gradient evaluations: 270
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.486570997852455
#             Iterations: 41
#             Function evaluations: 14842
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4051173353419573e-09
#             Iterations: 15
#             Function evaluations: 5415
#             Gradient evaluations: 15
# 2015-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.783037253444195e-05
#             Iterations: 299
#             Function evaluations: 108238
#             Gradient evaluations: 299
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4719596884525727
#             Iterations: 41
#             Function evaluations: 14881
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.985225580123567e-10
#             Iterations: 28
#             Function evaluations: 10136
#             Gradient evaluations: 28
# 2015-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.570595004332022e-05
#             Iterations: 295
#             Function evaluations: 108266
#             Gradient evaluations: 295
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.513587944282277
#             Iterations: 40
#             Function evaluations: 14718
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2250326735797866e-09
#             Iterations: 35
#             Function evaluations: 12845
#             Gradient evaluations: 35
# 2015-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.6406844147068126e-05
#             Iterations: 256
#             Function evaluations: 93696
#             Gradient evaluations: 256
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5590255843989813
#             Iterations: 45
#             Function evaluations: 16512
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.858617873928558e-10
#             Iterations: 47
#             Function evaluations: 17202
#             Gradient evaluations: 47
# 2015-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7728493437365614e-05
#             Iterations: 276
#             Function evaluations: 102672
#             Gradient evaluations: 276
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.55111819852269
#             Iterations: 44
#             Function evaluations: 16422
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6576086741878505e-09
#             Iterations: 46
#             Function evaluations: 17112
#             Gradient evaluations: 46
# 2015-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.429249483371104e-05
#             Iterations: 278
#             Function evaluations: 103972
#             Gradient evaluations: 278
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.909570732352028
#             Iterations: 71
#             Function evaluations: 25135
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9700169084537776e-09
#             Iterations: 44
#             Function evaluations: 16456
#             Gradient evaluations: 44
# 2015-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.182537731431589e-05
#             Iterations: 335
#             Function evaluations: 126630
#             Gradient evaluations: 335
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0221174817300716
#             Iterations: 51
#             Function evaluations: 19324
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.028364524480253e-09
#             Iterations: 44
#             Function evaluations: 16632
#             Gradient evaluations: 44
# 2016-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0554639857347174e-05
#             Iterations: 301
#             Function evaluations: 114381
#             Gradient evaluations: 301
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.313330921724791
#             Iterations: 68
#             Function evaluations: 24383
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3592051581552404e-09
#             Iterations: 33
#             Function evaluations: 12541
#             Gradient evaluations: 33
# 2016-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7195311547152633e-05
#             Iterations: 327
#             Function evaluations: 125568
#             Gradient evaluations: 327
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.4759173751230246
#             Iterations: 78
#             Function evaluations: 28488
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0835574495771599e-09
#             Iterations: 35
#             Function evaluations: 13440
#             Gradient evaluations: 35
# 2016-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.474852253332147e-05
#             Iterations: 307
#             Function evaluations: 120652
#             Gradient evaluations: 307
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.477713831605218
#             Iterations: 100
#             Function evaluations: 37830
#             Gradient evaluations: 96
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9730166979299483e-09
#             Iterations: 27
#             Function evaluations: 10611
#             Gradient evaluations: 27
# 2016-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2258704642508053e-05
#             Iterations: 321
#             Function evaluations: 125511
#             Gradient evaluations: 321
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.6950250424311646
#             Iterations: 94
#             Function evaluations: 35282
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4407824769169795e-09
#             Iterations: 17
#             Function evaluations: 6647
#             Gradient evaluations: 17
# 2016-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.162813754232345e-06
#             Iterations: 346
#             Function evaluations: 135632
#             Gradient evaluations: 346
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.174570951598582
#             Iterations: 136
#             Function evaluations: 51927
#             Gradient evaluations: 132
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3422554826356334e-09
#             Iterations: 9
#             Function evaluations: 3528
#             Gradient evaluations: 9
# 2016-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.234309146295767e-06
#             Iterations: 341
#             Function evaluations: 134013
#             Gradient evaluations: 341
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.555929718115689
#             Iterations: 118
#             Function evaluations: 44956
#             Gradient evaluations: 114
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.328112577096068e-09
#             Iterations: 9
#             Function evaluations: 3537
#             Gradient evaluations: 9
# 2017-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.663131179683442e-06
#             Iterations: 333
#             Function evaluations: 131535
#             Gradient evaluations: 333
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.868094513370011
#             Iterations: 125
#             Function evaluations: 47968
#             Gradient evaluations: 121
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8699871645691353e-09
#             Iterations: 9
#             Function evaluations: 3555
#             Gradient evaluations: 9
# 2017-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6506835538894197e-05
#             Iterations: 316
#             Function evaluations: 126400
#             Gradient evaluations: 316
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.651397773564793
#             Iterations: 72
#             Function evaluations: 27262
#             Gradient evaluations: 68
# ...
#             Function evaluations: 103095
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.043819528075898
#             Iterations: 60
#             Function evaluations: 24424
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4422139196253266e-09
#             Iterations: 57
#             Function evaluations: 24795
#             Gradient evaluations: 57
# 2020-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8363348094846885e-05
#             Iterations: 293
#             Function evaluations: 128334
#             Gradient evaluations: 293
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.3907949745404333
#             Iterations: 83
#             Function evaluations: 34702
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9926853649071708e-09
#             Iterations: 39
#             Function evaluations: 17082
#             Gradient evaluations: 39
# 2020-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5351937976704237e-05
#             Iterations: 288
#             Function evaluations: 125857
#             Gradient evaluations: 288
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.504949533262937
#             Iterations: 87
#             Function evaluations: 36372
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3256449298602665e-09
#             Iterations: 49
#             Function evaluations: 21413
#             Gradient evaluations: 49
# 2020-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1927390158292476e-05
#             Iterations: 332
#             Function evaluations: 145749
#             Gradient evaluations: 332
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5151323886742833
#             Iterations: 92
#             Function evaluations: 38738
#             Gradient evaluations: 88
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.223571108605845e-09
#             Iterations: 28
#             Function evaluations: 12292
#             Gradient evaluations: 28
# 2021-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4268016154257438e-05
#             Iterations: 320
#             Function evaluations: 140480
#             Gradient evaluations: 320
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4213324874340985
#             Iterations: 65
#             Function evaluations: 26837
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6637466902825975e-09
#             Iterations: 28
#             Function evaluations: 12293
#             Gradient evaluations: 28
# 2021-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6839077010361184e-05
#             Iterations: 306
#             Function evaluations: 135865
#             Gradient evaluations: 306
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.3201814654909496
#             Iterations: 76
#             Function evaluations: 32053
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2942250675804905e-09
#             Iterations: 39
#             Function evaluations: 17316
#             Gradient evaluations: 39
# 2021-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6877128061027175e-05
#             Iterations: 262
#             Function evaluations: 116590
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.919324002144163
#             Iterations: 57
#             Function evaluations: 23640
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3828458764855572e-09
#             Iterations: 49
#             Function evaluations: 21805
#             Gradient evaluations: 49
# 2021-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.607446453956216e-05
#             Iterations: 255
#             Function evaluations: 113220
#             Gradient evaluations: 255
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.740621662023987
#             Iterations: 45
#             Function evaluations: 18244
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6014748423384728e-09
#             Iterations: 48
#             Function evaluations: 21313
#             Gradient evaluations: 48
# 2021-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.32088462851223e-05
#             Iterations: 238
#             Function evaluations: 106149
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.540543394059197
#             Iterations: 54
#             Function evaluations: 22352
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.704625662799398e-10
#             Iterations: 56
#             Function evaluations: 24976
#             Gradient evaluations: 56
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.241555407363865e-05
#             Iterations: 221
#             Function evaluations: 98787
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3736513283940344
#             Iterations: 39
#             Function evaluations: 15677
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0491657464190775e-09
#             Iterations: 55
#             Function evaluations: 24585
#             Gradient evaluations: 55
# 2022-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.420732382734067e-05
#             Iterations: 245
#             Function evaluations: 110250
#             Gradient evaluations: 245
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.32547771495657
#             Iterations: 52
#             Function evaluations: 21652
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.277886605324244e-10
#             Iterations: 55
#             Function evaluations: 24750
#             Gradient evaluations: 55
# 2022-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.193774101384195e-05
#             Iterations: 236
#             Function evaluations: 106672
#             Gradient evaluations: 236
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.206623499261491
#             Iterations: 43
#             Function evaluations: 17665
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.511622424346736e-10
#             Iterations: 55
#             Function evaluations: 24860
#             Gradient evaluations: 55
# 2022-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.955710483599318e-05
#             Iterations: 259
#             Function evaluations: 117845
#             Gradient evaluations: 259
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.375203312614296
#             Iterations: 51
#             Function evaluations: 21428
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.045396827871205e-09
#             Iterations: 57
#             Function evaluations: 25935
#             Gradient evaluations: 57
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.431541546993007e-05
#             Iterations: 247
#             Function evaluations: 113620
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5010140822101508
#             Iterations: 69
#             Function evaluations: 29987
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3197954617381749e-09
#             Iterations: 48
#             Function evaluations: 22081
#             Gradient evaluations: 48
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6002927942949496e-05
#             Iterations: 243
#             Function evaluations: 111780
#             Gradient evaluations: 243
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -2.745209627779126
#             Iterations: 71
#             Function evaluations: 30896
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2260815219964173e-09
#             Iterations: 38
#             Function evaluations: 17480
#             Gradient evaluations: 38
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6289281518743266e-05
#             Iterations: 307
#             Function evaluations: 140913
#             Gradient evaluations: 307
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1008369745854174
#             Iterations: 64
#             Function evaluations: 27597
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9941818830023595e-09
#             Iterations: 38
#             Function evaluations: 17442
#             Gradient evaluations: 38
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1911861870489047e-05
#             Iterations: 326
#             Function evaluations: 150287
#             Gradient evaluations: 326
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.36236979258372
#             Iterations: 67
#             Function evaluations: 29104
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.117324167290065e-09
#             Iterations: 44
#             Function evaluations: 20284
#             Gradient evaluations: 44
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7041637397719842e-05
#             Iterations: 258
#             Function evaluations: 119196
#             Gradient evaluations: 258
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7227424187879814
#             Iterations: 72
#             Function evaluations: 31486
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2748365559258364e-09
#             Iterations: 32
#             Function evaluations: 14784
#             Gradient evaluations: 32
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.694466767878057e-05
#             Iterations: 333
#             Function evaluations: 153846
#             Gradient evaluations: 333
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8161391473344555
#             Iterations: 91
#             Function evaluations: 40278
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9297177447261065e-09
#             Iterations: 38
#             Function evaluations: 17556
#             Gradient evaluations: 38
# 2023-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5767440272129856e-05
#             Iterations: 303
#             Function evaluations: 139987
#             Gradient evaluations: 303
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.052768067894537
#             Iterations: 109
#             Function evaluations: 48642
#             Gradient evaluations: 105
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.058596513884953e-09
#             Iterations: 35
#             Function evaluations: 16170
#             Gradient evaluations: 35
# 2023-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5668792351431408e-05
#             Iterations: 307
#             Function evaluations: 142142
#             Gradient evaluations: 307
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.18046271229241
#             Iterations: 91
#             Function evaluations: 40368
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3117754170771405e-09
#             Iterations: 33
#             Function evaluations: 15280
#             Gradient evaluations: 33
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3830694044519194e-05
#             Iterations: 306
#             Function evaluations: 142902
#             Gradient evaluations: 306
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.4353991787064535
#             Iterations: 100
#             Function evaluations: 44944
#             Gradient evaluations: 96
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6403127585131448e-09
#             Iterations: 20
#             Function evaluations: 9340
#             Gradient evaluations: 20
# 2024-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4297180957088156e-05
#             Iterations: 262
#             Function evaluations: 122092
#             Gradient evaluations: 262
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.447685774402717
#             Iterations: 110
#             Function evaluations: 49535
#             Gradient evaluations: 106
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8946901252956795e-09
#             Iterations: 16
#             Function evaluations: 7456
#             Gradient evaluations: 16
# 2024-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5608916413832593e-05
#             Iterations: 299
#             Function evaluations: 140830
#             Gradient evaluations: 299
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.50662884245916
#             Iterations: 97
#             Function evaluations: 43906
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.566087983734943e-09
#             Iterations: 18
#             Function evaluations: 8478
#             Gradient evaluations: 18
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_shrinked.to_csv("returnssp500shrinked_2Monate_f.csv")

# %% [markdown]
# ### Auswertung JSE mit Ledoit Wolf

# %%
returns = df_JSE.pct_change()
returns = returns.where(~df_JSE.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of               4SI.JO    ABG.JO    ACL.JO    ACT.JO    ADH.JO    AEL.JO  \
# Date
# 2005-06-02       NaN  0.001214 -0.006225  0.000000 -0.014598       NaN
# 2005-06-03       NaN  0.001333  0.000000  0.000000  0.000000       NaN
# 2005-06-06       NaN  0.003510  0.014953  0.000000  0.007407       NaN
# 2005-06-07       NaN  0.006634 -0.035437  0.146154 -0.007353       NaN
# 2005-06-08       NaN -0.005392 -0.029721  0.000000  0.007407       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26  0.000000  0.007235 -0.018018  0.000000  0.005975  0.000426
# 2025-05-27  0.000000  0.000178 -0.036697  0.000000  0.003439  0.000000
# 2025-05-28  0.042857  0.026828 -0.038095  0.087500  0.022741  0.002128
# 2025-05-29 -0.041096  0.016127  0.049505 -0.045977 -0.010966  0.002972
# 2025-05-30  0.000000 -0.014051  0.094340 -0.036145 -0.009855 -0.001693
#
#               AFE.JO    AFH.JO    AFT.JO    AGL.JO  ...    VKE.JO    VOD.JO  \
# Date                                                ...
# 2005-06-02  0.020642       NaN       NaN  0.005481  ...       NaN  0.017117
# 2005-06-03  0.000000       NaN       NaN  0.000000  ...       NaN  0.000000
# 2005-06-06  0.000000       NaN       NaN -0.019079  ...       NaN  0.045350
# 2005-06-07  0.000225       NaN       NaN -0.020994  ...       NaN -0.000169
# 2005-06-08  0.011009       NaN       NaN  0.014191  ...       NaN -0.025424
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-26  0.007992  0.032548 -0.002564  0.029137  ... -0.010417 -0.016292
# 2025-05-27  0.007252 -0.026087  0.026498 -0.018270  ...  0.006316  0.002971
# 2025-05-28  0.002592  0.017857  0.000000 -0.008829  ...  0.001046 -0.006294
# 2025-05-29 -0.011298 -0.013158 -0.008476 -0.005631  ...  0.014107  0.031967
# 2025-05-30  0.000872 -0.011111  0.010297  0.016932  ...  0.030912 -0.005199
#
#               WBC.JO    WBO.JO    WEZ.JO    WHL.JO    YRK.JO  YYLBEE.JO  \
# Date
# 2005-06-02       NaN  0.009434       NaN  0.009901  0.000000        NaN
# 2005-06-03       NaN  0.000000       NaN  0.000000  0.000000        NaN
# 2005-06-06       NaN  0.009346       NaN  0.026471  0.000000        NaN
# 2005-06-07       NaN  0.000000       NaN  0.012416  0.000000        NaN
# 2005-06-08       NaN  0.018519       NaN -0.027358  0.000000        NaN
# ...              ...       ...       ...       ...       ...        ...
# 2025-05-26  0.021277 -0.005745  0.111111 -0.000174  0.046154        0.0
# 2025-05-27  0.015625  0.007979 -0.100000 -0.008726  0.000000        0.0
# 2025-05-28 -0.010872 -0.018234 -0.022222  0.014965 -0.083333        0.0
# 2025-05-29  0.013895 -0.005505  0.022727  0.016132  0.016043        0.0
# 2025-05-30  0.002250  0.014985 -0.044444  0.000341  0.026316        0.0
#
#               ZED.JO    ZZD.JO
# Date
# 2005-06-02       NaN       NaN
# 2005-06-03       NaN       NaN
# 2005-06-06       NaN       NaN
# 2005-06-07       NaN       NaN
# 2005-06-08       NaN       NaN
# ...              ...       ...
# 2025-05-26 -0.008264 -0.000864
# 2025-05-27 -0.016667  0.037165
# 2025-05-28  0.059322  0.008333
# 2025-05-29  0.008000 -0.008264
# 2025-05-30  0.023810 -0.012500
#
# [5170 rows x 217 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 2
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = ledoit_shrink(training_daten)
    
    #aus der geschrumpften Matrix die Korrelationsmatrix bauen
    standardabweichung = np.sqrt(np.diag(cov_matrix))
    corr_matrix = cov_matrix / np.outer(standardabweichung, standardabweichung)
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    shrinked_JSE_gewichte_equally_weighted = equally_weighted(training_daten)
    shrinked_JSE_gewichte_min_variance= min_variance_opt(cov_matrix)
    shrinked_JSE_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    shrinked_JSE_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    shrinked_JSE_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    shrinked_JSE_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    shrinked_JSE_gewichte_herc = herc_ledoit(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": shrinked_JSE_gewichte_equally_weighted,
    "Minimum-Variance": shrinked_JSE_gewichte_min_variance,
    "Maximum-Diversification": shrinked_JSE_gewichte_max_diversification,
    "Inverse-Volatility": shrinked_JSE_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": shrinked_JSE_gewichte_risk_parity,
    "HRP": shrinked_JSE_gewichte_hrp,
    "HERC": shrinked_JSE_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
    #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_shrinked_JSE = pd.concat(portfolio_returns_list)
portfolio_returns_df_shrinked_JSE = portfolio_returns_df_shrinked_JSE.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.240047133151458e-05
#             Iterations: 135
#             Function evaluations: 9045
#             Gradient evaluations: 135
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.741709713501023
#             Iterations: 43
#             Function evaluations: 2923
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.635081070068458e-09
#             Iterations: 44
#             Function evaluations: 2949
#             Gradient evaluations: 44
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.119348145512657e-05
#             Iterations: 124
#             Function evaluations: 8432
#             Gradient evaluations: 124
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.314781158044826
#             Iterations: 25
#             Function evaluations: 1724
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.559576421899547e-10
#             Iterations: 54
#             Function evaluations: 3672
#             Gradient evaluations: 54
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.05864626641222e-05
#             Iterations: 132
#             Function evaluations: 8844
#             Gradient evaluations: 132
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2844340964754846
#             Iterations: 29
#             Function evaluations: 1971
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2656854167573228e-09
#             Iterations: 53
#             Function evaluations: 3552
#             Gradient evaluations: 53
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.759283023010051e-05
#             Iterations: 111
#             Function evaluations: 7437
#             Gradient evaluations: 111
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3843643115261814
#             Iterations: 35
#             Function evaluations: 2379
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.437453723671651e-09
#             Iterations: 54
#             Function evaluations: 3618
#             Gradient evaluations: 54
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.514797702806699e-05
#             Iterations: 132
#             Function evaluations: 8845
#             Gradient evaluations: 132
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6223504766139833
#             Iterations: 34
#             Function evaluations: 2313
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8229171402530943e-09
#             Iterations: 54
#             Function evaluations: 3619
#             Gradient evaluations: 54
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.822110694824415e-05
#             Iterations: 120
#             Function evaluations: 8161
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6766085835344002
#             Iterations: 41
#             Function evaluations: 2827
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2396298005764247e-10
#             Iterations: 54
#             Function evaluations: 3672
#             Gradient evaluations: 54
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.0941687700587895e-05
#             Iterations: 134
#             Function evaluations: 9783
#             Gradient evaluations: 134
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.860032031297268
#             Iterations: 42
#             Function evaluations: 3109
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1432680447431062e-09
#             Iterations: 43
#             Function evaluations: 3140
#             Gradient evaluations: 43
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.067735707327206e-05
#             Iterations: 132
#             Function evaluations: 10033
#             Gradient evaluations: 132
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8660010989558278
#             Iterations: 64
#             Function evaluations: 4940
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3891540036015953e-09
#             Iterations: 29
#             Function evaluations: 2204
#             Gradient evaluations: 29
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8585454213256543e-05
#             Iterations: 108
#             Function evaluations: 8424
#             Gradient evaluations: 108
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.3962568320486954
#             Iterations: 54
#             Function evaluations: 4267
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.55269487799337e-09
#             Iterations: 32
#             Function evaluations: 2496
#             Gradient evaluations: 32
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.087957926694156e-05
#             Iterations: 110
#             Function evaluations: 8690
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1602935625747772
#             Iterations: 52
#             Function evaluations: 4163
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7372832252766733e-09
#             Iterations: 32
#             Function evaluations: 2529
#             Gradient evaluations: 32
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3430420979139145e-05
#             Iterations: 129
#             Function evaluations: 10320
#             Gradient evaluations: 129
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9140728394129645
#             Iterations: 48
#             Function evaluations: 3890
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3813702495797592e-09
#             Iterations: 32
#             Function evaluations: 2560
#             Gradient evaluations: 32
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.372556773349719e-05
#             Iterations: 143
#             Function evaluations: 11441
#             Gradient evaluations: 143
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.070435281306973
#             Iterations: 55
#             Function evaluations: 4455
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.984661534997014e-09
#             Iterations: 44
#             Function evaluations: 3520
#             Gradient evaluations: 44
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.643368781322188e-05
#             Iterations: 137
#             Function evaluations: 10549
#             Gradient evaluations: 137
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.048045456084472
#             Iterations: 44
#             Function evaluations: 3436
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.311800058952099e-09
#             Iterations: 32
#             Function evaluations: 2465
#             Gradient evaluations: 32
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.0519928358813376e-05
#             Iterations: 115
#             Function evaluations: 9200
#             Gradient evaluations: 115
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.24488714898468
#             Iterations: 57
#             Function evaluations: 4619
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.053327078609027e-09
#             Iterations: 45
#             Function evaluations: 3600
#             Gradient evaluations: 45
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.6127229698629434e-05
#             Iterations: 123
#             Function evaluations: 9471
#             Gradient evaluations: 123
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4087038947848844
#             Iterations: 51
#             Function evaluations: 3978
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6405354506208342e-09
#             Iterations: 41
#             Function evaluations: 3158
#             Gradient evaluations: 41
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.968856024233593e-05
#             Iterations: 131
#             Function evaluations: 10349
#             Gradient evaluations: 131
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0266834390907653
#             Iterations: 45
#             Function evaluations: 3598
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.25467040869184e-10
#             Iterations: 72
#             Function evaluations: 5689
#             Gradient evaluations: 72
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.585597463276997e-05
#             Iterations: 135
#             Function evaluations: 10395
#             Gradient evaluations: 135
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0367579363617563
#             Iterations: 44
#             Function evaluations: 3429
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.249635536283206e-10
#             Iterations: 93
#             Function evaluations: 7161
#             Gradient evaluations: 93
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.276083901735524e-05
#             Iterations: 138
#             Function evaluations: 10626
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1660824258907465
#             Iterations: 41
#             Function evaluations: 3192
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.903653566333232e-10
#             Iterations: 114
#             Function evaluations: 8779
#             Gradient evaluations: 114
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.926593454572408e-05
#             Iterations: 138
#             Function evaluations: 10488
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1478877285111393
#             Iterations: 43
#             Function evaluations: 3308
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.42068619686613e-10
#             Iterations: 102
#             Function evaluations: 7753
#             Gradient evaluations: 102
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.112903238626374e-05
#             Iterations: 141
#             Function evaluations: 10716
#             Gradient evaluations: 141
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.190574165780754
#             Iterations: 43
#             Function evaluations: 3306
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.410817538852791e-10
#             Iterations: 111
#             Function evaluations: 8436
#             Gradient evaluations: 111
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.402900987719253e-05
#             Iterations: 127
#             Function evaluations: 9525
#             Gradient evaluations: 127
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.052632816188929
#             Iterations: 47
#             Function evaluations: 3568
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.128577685633689e-10
#             Iterations: 90
#             Function evaluations: 6751
#             Gradient evaluations: 90
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.647199920292808e-05
#             Iterations: 115
#             Function evaluations: 8740
#             Gradient evaluations: 115
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.654621985421839
#             Iterations: 75
#             Function evaluations: 5573
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9939544023606628e-09
#             Iterations: 97
#             Function evaluations: 7372
#             Gradient evaluations: 97
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6130928458069008e-05
#             Iterations: 146
#             Function evaluations: 12411
#             Gradient evaluations: 146
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.892323797470813
#             Iterations: 65
#             Function evaluations: 5588
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.49205618219176e-09
#             Iterations: 75
#             Function evaluations: 6376
#             Gradient evaluations: 75
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.849520311395176e-05
#             Iterations: 167
#             Function evaluations: 14029
#             Gradient evaluations: 167
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.0707403242120295
#             Iterations: 64
#             Function evaluations: 5366
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.3947777859369866e-09
#             Iterations: 64
#             Function evaluations: 5376
#             Gradient evaluations: 64
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8153770030270403e-05
#             Iterations: 170
#             Function evaluations: 14621
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7886938509749917
#             Iterations: 54
#             Function evaluations: 4697
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.270719421979131e-09
#             Iterations: 65
#             Function evaluations: 5590
#             Gradient evaluations: 65
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.722853830987692e-05
#             Iterations: 167
#             Function evaluations: 14029
#             Gradient evaluations: 167
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6411501206122887
#             Iterations: 52
#             Function evaluations: 4417
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.403606949005002e-09
#             Iterations: 56
#             Function evaluations: 4704
#             Gradient evaluations: 56
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3392120073935244e-05
#             Iterations: 189
#             Function evaluations: 16254
#             Gradient evaluations: 189
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.862848250687799
#             Iterations: 54
#             Function evaluations: 4701
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.910557085249628e-09
#             Iterations: 57
#             Function evaluations: 4902
#             Gradient evaluations: 57
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3425255540648984e-05
#             Iterations: 194
#             Function evaluations: 16685
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.790561769183912
#             Iterations: 53
#             Function evaluations: 4609
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.861520924817331e-09
#             Iterations: 45
#             Function evaluations: 3871
#             Gradient evaluations: 45
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2944974134459726e-05
#             Iterations: 172
#             Function evaluations: 15480
#             Gradient evaluations: 172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.082035975898343
#             Iterations: 67
#             Function evaluations: 5762
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.173179196715741e-09
#             Iterations: 45
#             Function evaluations: 4051
#             Gradient evaluations: 45
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4239249573881232e-05
#             Iterations: 160
#             Function evaluations: 14240
#             Gradient evaluations: 160
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.1465208045585
#             Iterations: 74
#             Function evaluations: 6350
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.8728575196753405e-09
#             Iterations: 45
#             Function evaluations: 4005
#             Gradient evaluations: 45
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1731184282451759e-05
#             Iterations: 140
#             Function evaluations: 12180
#             Gradient evaluations: 140
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.504080772613403
#             Iterations: 70
#             Function evaluations: 6177
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.471360350979723e-09
#             Iterations: 19
#             Function evaluations: 1654
#             Gradient evaluations: 19
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0327100564870833e-05
#             Iterations: 148
#             Function evaluations: 13468
#             Gradient evaluations: 148
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.649559724429751
#             Iterations: 71
#             Function evaluations: 6556
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.193728678611777e-09
#             Iterations: 20
#             Function evaluations: 1820
#             Gradient evaluations: 20
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3103891340986744e-05
#             Iterations: 164
#             Function evaluations: 15252
#             Gradient evaluations: 164
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.332680546385198
#             Iterations: 69
#             Function evaluations: 6495
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2254109177769284e-09
#             Iterations: 34
#             Function evaluations: 3162
#             Gradient evaluations: 34
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4050772268941719e-05
#             Iterations: 173
#             Function evaluations: 15916
#             Gradient evaluations: 173
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.978781073713074
#             Iterations: 54
#             Function evaluations: 5029
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0552948409255226e-09
#             Iterations: 46
#             Function evaluations: 4232
#             Gradient evaluations: 46
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4522323917842545e-05
#             Iterations: 183
#             Function evaluations: 16471
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.697163885843846
#             Iterations: 64
#             Function evaluations: 5825
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0989787357554093e-09
#             Iterations: 46
#             Function evaluations: 4140
#             Gradient evaluations: 46
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2191684270323535e-05
#             Iterations: 214
#             Function evaluations: 19260
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5595874558769145
#             Iterations: 54
#             Function evaluations: 4824
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.209174085716229e-09
#             Iterations: 58
#             Function evaluations: 5220
#             Gradient evaluations: 58
# 2011-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2449660994183539e-05
#             Iterations: 236
#             Function evaluations: 21476
#             Gradient evaluations: 236
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.477138943138827
#             Iterations: 57
#             Function evaluations: 5242
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.6990165342171655e-09
#             Iterations: 45
#             Function evaluations: 4096
#             Gradient evaluations: 45
# 2011-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2471539735383868e-05
#             Iterations: 211
#             Function evaluations: 19413
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.61427278355533
#             Iterations: 61
#             Function evaluations: 5675
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.4769257463180325e-09
#             Iterations: 45
#             Function evaluations: 4141
#             Gradient evaluations: 45
# 2011-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.176701982135874e-06
#             Iterations: 215
#             Function evaluations: 19566
#             Gradient evaluations: 215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.332657421305749
#             Iterations: 66
#             Function evaluations: 6087
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.766299386130062e-09
#             Iterations: 34
#             Function evaluations: 3095
#             Gradient evaluations: 34
# 2011-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.627092253701041e-06
#             Iterations: 211
#             Function evaluations: 19202
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.4454087192788405
#             Iterations: 72
#             Function evaluations: 6644
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.959406747874755e-09
#             Iterations: 23
#             Function evaluations: 2093
#             Gradient evaluations: 23
# 2012-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0312543072277793e-05
#             Iterations: 210
#             Function evaluations: 19321
#             Gradient evaluations: 210
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.408665113297599
#             Iterations: 71
#             Function evaluations: 6618
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.7474788141349505e-09
#             Iterations: 20
#             Function evaluations: 1840
#             Gradient evaluations: 20
# 2012-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0473078801551638e-05
#             Iterations: 199
#             Function evaluations: 18706
#             Gradient evaluations: 199
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.536971484946534
#             Iterations: 72
#             Function evaluations: 6861
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.511171618709385e-09
#             Iterations: 21
#             Function evaluations: 1974
#             Gradient evaluations: 21
# 2012-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1066933515874225e-05
#             Iterations: 185
#             Function evaluations: 17760
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.606323229606496
#             Iterations: 82
#             Function evaluations: 7975
#             Gradient evaluations: 82
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.954653945999391e-09
#             Iterations: 23
#             Function evaluations: 2209
#             Gradient evaluations: 23
# 2012-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.455517701331793e-05
#             Iterations: 179
#             Function evaluations: 17184
#             Gradient evaluations: 179
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.148519311945747
#             Iterations: 71
#             Function evaluations: 6894
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7737556043712227e-09
#             Iterations: 34
#             Function evaluations: 3264
#             Gradient evaluations: 34
# 2012-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3950783932763787e-05
#             Iterations: 178
#             Function evaluations: 17623
#             Gradient evaluations: 178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.273280893737404
#             Iterations: 73
#             Function evaluations: 7316
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.977341715398899e-09
#             Iterations: 34
#             Function evaluations: 3366
#             Gradient evaluations: 34
# 2012-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3664901737745573e-05
#             Iterations: 203
#             Function evaluations: 20706
#             Gradient evaluations: 203
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.401987751887777
#             Iterations: 77
#             Function evaluations: 7946
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.708348168193682e-09
#             Iterations: 33
#             Function evaluations: 3366
#             Gradient evaluations: 33
# 2013-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4055824634663677e-05
#             Iterations: 195
#             Function evaluations: 20280
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.490058800427744
#             Iterations: 79
#             Function evaluations: 8308
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.144520888976503e-09
#             Iterations: 32
#             Function evaluations: 3328
#             Gradient evaluations: 32
# 2013-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4124614941451229e-05
#             Iterations: 172
#             Function evaluations: 17888
#             Gradient evaluations: 172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.524662752582142
#             Iterations: 72
#             Function evaluations: 7575
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.421214338062702e-09
#             Iterations: 29
#             Function evaluations: 3016
#             Gradient evaluations: 29
# 2013-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.216044405350579e-05
#             Iterations: 187
#             Function evaluations: 19261
#             Gradient evaluations: 187
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.545714313127898
#             Iterations: 76
#             Function evaluations: 7920
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.327310007470385e-09
#             Iterations: 34
#             Function evaluations: 3502
#             Gradient evaluations: 34
# 2013-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.594655261775117e-06
#             Iterations: 173
#             Function evaluations: 17820
#             Gradient evaluations: 173
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.7875201718638785
#             Iterations: 79
#             Function evaluations: 8244
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.984646843731761e-09
#             Iterations: 20
#             Function evaluations: 2060
#             Gradient evaluations: 20
# 2013-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.236705230782776e-06
#             Iterations: 171
#             Function evaluations: 17784
#             Gradient evaluations: 171
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.936148628068598
#             Iterations: 87
#             Function evaluations: 9160
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5188573104448916e-09
#             Iterations: 22
#             Function evaluations: 2288
#             Gradient evaluations: 22
# 2013-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.05465269399147e-05
#             Iterations: 188
#             Function evaluations: 20116
#             Gradient evaluations: 188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.894282184664312
#             Iterations: 132
#             Function evaluations: 14169
#             Gradient evaluations: 128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5388516038863008e-09
#             Iterations: 30
#             Function evaluations: 3210
#             Gradient evaluations: 30
# 2014-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.45634928418883e-06
#             Iterations: 175
#             Function evaluations: 18725
#             Gradient evaluations: 175
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.3936347866392795
#             Iterations: 89
#             Function evaluations: 9224
#             Gradient evaluations: 85
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.863471780618176e-09
#             Iterations: 31
#             Function evaluations: 3317
#             Gradient evaluations: 31
# 2014-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0139463350073137e-05
#             Iterations: 178
#             Function evaluations: 19225
#             Gradient evaluations: 178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.171856232118652
#             Iterations: 88
#             Function evaluations: 9620
#             Gradient evaluations: 88
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.236799249044433e-09
#             Iterations: 34
#             Function evaluations: 3672
#             Gradient evaluations: 34
# 2014-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.775519475408268e-06
#             Iterations: 197
#             Function evaluations: 21670
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.583740802871609
#             Iterations: 86
#             Function evaluations: 9468
#             Gradient evaluations: 85
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.361627010061357e-09
#             Iterations: 33
#             Function evaluations: 3630
#             Gradient evaluations: 33
# 2014-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.146586713323534e-05
#             Iterations: 170
#             Function evaluations: 19210
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.366590981627524
#             Iterations: 84
#             Function evaluations: 9604
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.0663644388036115e-09
#             Iterations: 30
#             Function evaluations: 3390
#             Gradient evaluations: 30
# 2014-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8021705267340292e-05
#             Iterations: 168
#             Function evaluations: 18817
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.663851783363698
#             Iterations: 77
#             Function evaluations: 8717
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2809598716866304e-09
#             Iterations: 42
#             Function evaluations: 4704
#             Gradient evaluations: 42
# 2014-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8566013187950675e-05
#             Iterations: 191
#             Function evaluations: 21775
#             Gradient evaluations: 191
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.7279886975414325
#             Iterations: 95
#             Function evaluations: 10577
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1600375681616035e-09
#             Iterations: 45
#             Function evaluations: 5130
#             Gradient evaluations: 45
# 2015-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4217617552424734e-05
#             Iterations: 176
#             Function evaluations: 20593
#             Gradient evaluations: 176
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.786560725251483
#             Iterations: 79
#             Function evaluations: 9338
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.437501240185902e-09
#             Iterations: 74
#             Function evaluations: 8658
#             Gradient evaluations: 74
# 2015-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6309134172984143e-05
#             Iterations: 194
#             Function evaluations: 22504
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.590357243240289
#             Iterations: 83
#             Function evaluations: 9725
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.563180722494284e-09
#             Iterations: 117
#             Function evaluations: 13573
#             Gradient evaluations: 117
# 2015-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6547529994544205e-05
#             Iterations: 183
#             Function evaluations: 21229
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.564974938713104
#             Iterations: 132
#             Function evaluations: 15333
#             Gradient evaluations: 128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8594438800695453e-09
#             Iterations: 127
#             Function evaluations: 14732
#             Gradient evaluations: 127
# 2015-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6194146113226072e-05
#             Iterations: 170
#             Function evaluations: 19890
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.548041921317333
#             Iterations: 71
#             Function evaluations: 8390
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.878545054057707e-09
#             Iterations: 170
#             Function evaluations: 19890
#             Gradient evaluations: 170
# 2015-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2652606574566897e-05
#             Iterations: 176
#             Function evaluations: 20593
#             Gradient evaluations: 176
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.8716009033644045
#             Iterations: 70
#             Function evaluations: 7810
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2662802774366502e-08
#             Iterations: 92
#             Function evaluations: 10764
#             Gradient evaluations: 92
# 2015-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2285118595324022e-05
#             Iterations: 186
#             Function evaluations: 22134
#             Gradient evaluations: 186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.903839156177115
#             Iterations: 73
#             Function evaluations: 8661
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7733937013792835e-08
#             Iterations: 82
#             Function evaluations: 9759
#             Gradient evaluations: 82
# 2016-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4582445616344646e-05
#             Iterations: 177
#             Function evaluations: 21240
#             Gradient evaluations: 177
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.394445323964339
#             Iterations: 121
#             Function evaluations: 14473
#             Gradient evaluations: 117
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.453267781991451e-09
#             Iterations: 86
#             Function evaluations: 10320
#             Gradient evaluations: 86
# 2016-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1913608908522585e-05
#             Iterations: 183
#             Function evaluations: 21961
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.662067292589673
#             Iterations: 81
#             Function evaluations: 9717
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.970362776572157e-09
#             Iterations: 65
#             Function evaluations: 7800
#             Gradient evaluations: 65
# 2016-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2404854818202158e-05
#             Iterations: 174
#             Function evaluations: 21402
#             Gradient evaluations: 174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.438562203746073
#             Iterations: 95
#             Function evaluations: 11321
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.813810542075803e-09
#             Iterations: 45
#             Function evaluations: 5535
#             Gradient evaluations: 45
# 2016-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.026741366085644e-06
#             Iterations: 202
#             Function evaluations: 25251
#             Gradient evaluations: 202
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.151880132381717
#             Iterations: 102
#             Function evaluations: 12904
#             Gradient evaluations: 102
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.032150983976819e-08
#             Iterations: 30
#             Function evaluations: 3750
#             Gradient evaluations: 30
# 2016-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.628018048410223e-06
#             Iterations: 200
#             Function evaluations: 25401
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.459137202153382
#             Iterations: 108
#             Function evaluations: 13761
#             Gradient evaluations: 107
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1416874799517044e-08
#             Iterations: 30
#             Function evaluations: 3810
#             Gradient evaluations: 30
# 2016-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.04940286826913e-06
#             Iterations: 208
#             Function evaluations: 26624
#             Gradient evaluations: 208
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.211149857112404
#             Iterations: 110
#             Function evaluations: 14132
#             Gradient evaluations: 109
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2262799784046653e-08
#             Iterations: 16
#             Function evaluations: 2048
#             Gradient evaluations: 16
# 2017-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.13028727483427e-06
#             Iterations: 189
#             Function evaluations: 24192
#             Gradient evaluations: 189
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.168216081091635
#             Iterations: 182
#             Function evaluations: 23475
#             Gradient evaluations: 178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.4073494763403e-09
#             Iterations: 34
#             Function evaluations: 4352
#             Gradient evaluations: 34
# 2017-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1129365266344513e-05
#             Iterations: 176
#             Function evaluations: 22704
#             Gradient evaluations: 176
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.800287936641743
#             Iterations: 111
#             Function evaluations: 14484
#             Gradient evaluations: 111
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.171107134939678e-09
#             Iterations: 19
#             Function evaluations: 2452
#             Gradient evaluations: 19
# ...
#             Current function value: 2.3658625282578075e-05
#             Iterations: 144
#             Function evaluations: 21024
#             Gradient evaluations: 144
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.150033894953837
#             Iterations: 117
#             Function evaluations: 16681
#             Gradient evaluations: 113
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.961325510871079e-09
#             Iterations: 60
#             Function evaluations: 8761
#             Gradient evaluations: 60
# 2020-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.984265447854179e-05
#             Iterations: 167
#             Function evaluations: 24215
#             Gradient evaluations: 167
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.944179434985963
#             Iterations: 121
#             Function evaluations: 17180
#             Gradient evaluations: 117
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1630625985796784e-09
#             Iterations: 62
#             Function evaluations: 8990
#             Gradient evaluations: 62
# 2020-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.601244007944156e-05
#             Iterations: 147
#             Function evaluations: 22051
#             Gradient evaluations: 147
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.367809832708278
#             Iterations: 119
#             Function evaluations: 17440
#             Gradient evaluations: 115
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.2240624073502015e-09
#             Iterations: 51
#             Function evaluations: 7650
#             Gradient evaluations: 51
# 2020-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4110048482834201e-05
#             Iterations: 178
#             Function evaluations: 27056
#             Gradient evaluations: 178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.6503839497106005
#             Iterations: 147
#             Function evaluations: 22173
#             Gradient evaluations: 143
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5971729097251633e-09
#             Iterations: 41
#             Function evaluations: 6232
#             Gradient evaluations: 41
# 2021-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4111568385443196e-05
#             Iterations: 173
#             Function evaluations: 26469
#             Gradient evaluations: 173
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.306774780815153
#             Iterations: 156
#             Function evaluations: 23705
#             Gradient evaluations: 152
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.101057116169915e-09
#             Iterations: 21
#             Function evaluations: 3214
#             Gradient evaluations: 21
# 2021-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7324266879220548e-05
#             Iterations: 175
#             Function evaluations: 26776
#             Gradient evaluations: 175
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.916303563083679
#             Iterations: 107
#             Function evaluations: 16524
#             Gradient evaluations: 107
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.149009886255186e-09
#             Iterations: 20
#             Function evaluations: 3061
#             Gradient evaluations: 20
# 2021-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9900695134890912e-05
#             Iterations: 168
#             Function evaluations: 25704
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.345024796087156
#             Iterations: 99
#             Function evaluations: 15134
#             Gradient evaluations: 98
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.212569753231496e-09
#             Iterations: 29
#             Function evaluations: 4437
#             Gradient evaluations: 29
# 2021-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4391946181147745e-05
#             Iterations: 182
#             Function evaluations: 27847
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.06116442247701
#             Iterations: 93
#             Function evaluations: 14357
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.087955118772417e-09
#             Iterations: 45
#             Function evaluations: 6885
#             Gradient evaluations: 45
# 2021-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5664606711379582e-05
#             Iterations: 155
#             Function evaluations: 23406
#             Gradient evaluations: 155
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.1046706526965275
#             Iterations: 84
#             Function evaluations: 12647
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.255661596469203e-09
#             Iterations: 33
#             Function evaluations: 4984
#             Gradient evaluations: 33
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4585913732774674e-05
#             Iterations: 165
#             Function evaluations: 25080
#             Gradient evaluations: 165
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.317671964533073
#             Iterations: 94
#             Function evaluations: 13798
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0167320243649784e-09
#             Iterations: 44
#             Function evaluations: 6689
#             Gradient evaluations: 44
# 2022-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3265490413424132e-05
#             Iterations: 157
#             Function evaluations: 24021
#             Gradient evaluations: 157
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.460441927978766
#             Iterations: 91
#             Function evaluations: 13432
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.775838843148243e-09
#             Iterations: 45
#             Function evaluations: 6885
#             Gradient evaluations: 45
# 2022-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8350030940808894e-05
#             Iterations: 185
#             Function evaluations: 28675
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.641239502455209
#             Iterations: 104
#             Function evaluations: 15644
#             Gradient evaluations: 100
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.273628125955032e-09
#             Iterations: 44
#             Function evaluations: 6820
#             Gradient evaluations: 44
# 2022-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5738443665316624e-05
#             Iterations: 200
#             Function evaluations: 31000
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.1126443093321425
#             Iterations: 124
#             Function evaluations: 18888
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.123899862412964e-09
#             Iterations: 42
#             Function evaluations: 6510
#             Gradient evaluations: 42
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3029035865454378e-05
#             Iterations: 182
#             Function evaluations: 28938
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.700975869518392
#             Iterations: 158
#             Function evaluations: 24992
#             Gradient evaluations: 154
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.696207135255889e-09
#             Iterations: 29
#             Function evaluations: 4611
#             Gradient evaluations: 29
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.20670800336536e-05
#             Iterations: 176
#             Function evaluations: 27456
#             Gradient evaluations: 176
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.545720079049139
#             Iterations: 111
#             Function evaluations: 17340
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1637742867560002e-08
#             Iterations: 21
#             Function evaluations: 3276
#             Gradient evaluations: 21
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1409462134752712e-05
#             Iterations: 168
#             Function evaluations: 25537
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.519824718728864
#             Iterations: 196
#             Function evaluations: 30029
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.131715040203033e-09
#             Iterations: 29
#             Function evaluations: 4408
#             Gradient evaluations: 29
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.234609463689579e-05
#             Iterations: 170
#             Function evaluations: 25840
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.136290958441266
#             Iterations: 113
#             Function evaluations: 16781
#             Gradient evaluations: 109
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.428285756848159e-09
#             Iterations: 29
#             Function evaluations: 4408
#             Gradient evaluations: 29
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.156685848786556e-05
#             Iterations: 177
#             Function evaluations: 26904
#             Gradient evaluations: 177
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.435003616589723
#             Iterations: 126
#             Function evaluations: 18773
#             Gradient evaluations: 122
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.0144962616946706e-09
#             Iterations: 30
#             Function evaluations: 4560
#             Gradient evaluations: 30
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1719584563866186e-05
#             Iterations: 195
#             Function evaluations: 29640
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.3702292074409375
#             Iterations: 114
#             Function evaluations: 16896
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.855490068942064e-09
#             Iterations: 43
#             Function evaluations: 6536
#             Gradient evaluations: 43
# 2023-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1969944236368565e-05
#             Iterations: 180
#             Function evaluations: 27360
#             Gradient evaluations: 180
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.353173979795623
#             Iterations: 110
#             Function evaluations: 16739
#             Gradient evaluations: 109
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.8245408439243575e-09
#             Iterations: 41
#             Function evaluations: 6232
#             Gradient evaluations: 41
# 2023-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2553400367930283e-05
#             Iterations: 190
#             Function evaluations: 28690
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.190510729875503
#             Iterations: 117
#             Function evaluations: 17249
#             Gradient evaluations: 113
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.37798480771079e-09
#             Iterations: 41
#             Function evaluations: 6191
#             Gradient evaluations: 41
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1218483406704243e-05
#             Iterations: 182
#             Function evaluations: 27664
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.546489960492811
#             Iterations: 117
#             Function evaluations: 17817
#             Gradient evaluations: 116
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.036273113821135e-09
#             Iterations: 38
#             Function evaluations: 5776
#             Gradient evaluations: 38
# 2024-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.109424478719857e-05
#             Iterations: 184
#             Function evaluations: 27969
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.464805603588694
#             Iterations: 173
#             Function evaluations: 26362
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.141795170693197e-09
#             Iterations: 43
#             Function evaluations: 6536
#             Gradient evaluations: 43
# 2024-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1051335025580025e-05
#             Iterations: 192
#             Function evaluations: 28992
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.456332576771124
#             Iterations: 113
#             Function evaluations: 17237
#             Gradient evaluations: 113
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.435901153007776e-09
#             Iterations: 30
#             Function evaluations: 4531
#             Gradient evaluations: 30
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_shrinked_JSE.to_csv("returnsJSEshrinked_2Monate_f.csv")

# %% [markdown]
# ### Reduzierter S&P500-Bestand

# %%
returns = df_SP500_reduziert.pct_change()
returns = returns.where(~df_SP500_reduziert.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                    A      AAPL       ABT       ACN       ADI       ADM  \
# Date
# 2005-06-02  0.000414 -0.006452       NaN       NaN       NaN       NaN
# 2005-06-03 -0.005374 -0.044955       NaN       NaN       NaN       NaN
# 2005-06-06  0.019119 -0.008368       NaN       NaN       NaN       NaN
# 2005-06-07 -0.012235 -0.036393       NaN       NaN       NaN       NaN
# 2005-06-08  0.009496  0.010399       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23 -0.010485 -0.030244 -0.001521 -0.021710 -0.006889 -0.000417
# 2025-05-27  0.025154  0.025298  0.012490  0.018897  0.030503  0.014393
# 2025-05-28 -0.003415  0.001049 -0.006920  0.001775 -0.005856 -0.005758
# 2025-05-29  0.021645 -0.002345  0.006287  0.005507  0.000603  0.000414
# 2025-05-30 -0.012006  0.004501  0.005495 -0.002864 -0.008204 -0.002067
#
#                  ADP      ADSK       AES       AIZ  ...       VLO      VRSN  \
# Date                                                ...
# 2005-06-02       NaN       NaN -0.014875       NaN  ...       NaN       NaN
# 2005-06-03       NaN       NaN -0.011668       NaN  ...       NaN       NaN
# 2005-06-06       NaN       NaN  0.041667       NaN  ...       NaN       NaN
# 2005-06-07       NaN       NaN -0.004000       NaN  ...       NaN       NaN
# 2005-06-08       NaN       NaN -0.006693       NaN  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-23 -0.001741  0.001186  0.037383  0.018133  ... -0.001321 -0.007450
# 2025-05-27  0.014388  0.016963  0.008008  0.022797  ...  0.016803 -0.036460
# 2025-05-28 -0.004820 -0.003762 -0.036743 -0.015224  ... -0.028919 -0.001558
# 2025-05-29 -0.000062 -0.007452  0.036083  0.010205  ...  0.017569 -0.001709
# 2025-05-30  0.004350 -0.002963  0.003980  0.015103  ... -0.001471  0.014106
#
#                 VRTX       WAT       WFC       WRB       XEL       YUM  \
# Date
# 2005-06-02       NaN -0.013181  0.000488       NaN       NaN       NaN
# 2005-06-03       NaN -0.013614 -0.002925       NaN       NaN       NaN
# 2005-06-06       NaN -0.007292  0.001467       NaN       NaN       NaN
# 2005-06-07       NaN  0.004984 -0.001139       NaN       NaN       NaN
# 2005-06-08       NaN -0.009397  0.002118       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23  0.004539 -0.005998 -0.007630  0.012329  0.007513 -0.000344
# 2025-05-27  0.022936  0.034616  0.015927  0.015326  0.001147 -0.009350
# 2025-05-28 -0.002018 -0.010520 -0.003514 -0.012264 -0.012606 -0.006524
# 2025-05-29  0.004471  0.002002  0.010579  0.009142  0.007834  0.006217
# 2025-05-30 -0.011273 -0.017056  0.003624  0.009870  0.009069 -0.000694
#
#                  ZBH       ZTS
# Date
# 2005-06-02  0.002885       NaN
# 2005-06-03  0.029816       NaN
# 2005-06-06 -0.005079       NaN
# 2005-06-07  0.013657       NaN
# 2005-06-08 -0.005414       NaN
# ...              ...       ...
# 2025-05-23  0.010581  0.003766
# 2025-05-27  0.016947  0.022635
# 2025-05-28 -0.020380 -0.005173
# 2025-05-29  0.011377  0.010520
# 2025-05-30 -0.012535  0.008915
#
# [5031 rows x 217 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 2
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = training_daten.cov()
    corr_matrix = training_daten.corr()
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    reduziert_gewichte_equally_weighted = equally_weighted(training_daten)
    reduziert_gewichte_min_variance= min_variance_opt(cov_matrix)
    reduziert_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    reduziert_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    reduziert_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    reduziert_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    reduziert_gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": reduziert_gewichte_equally_weighted,
    "Minimum-Variance": reduziert_gewichte_min_variance,
    "Maximum-Diversification": reduziert_gewichte_max_diversification,
    "Inverse-Volatility": reduziert_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": reduziert_gewichte_risk_parity,
    "HRP": reduziert_gewichte_hrp,
    "HERC": reduziert_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
   #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_reduziert = pd.concat(portfolio_returns_list)
portfolio_returns_df_reduziert = portfolio_returns_df_reduziert.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.105745668140832e-05
#             Iterations: 279
#             Function evaluations: 28738
#             Gradient evaluations: 279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5646187894305896
#             Iterations: 48
#             Function evaluations: 4992
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3432286542379153e-09
#             Iterations: 21
#             Function evaluations: 2163
#             Gradient evaluations: 21
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1773795573208203e-05
#             Iterations: 278
#             Function evaluations: 29190
#             Gradient evaluations: 278
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.504050023760789
#             Iterations: 42
#             Function evaluations: 4450
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6672372739337508e-09
#             Iterations: 32
#             Function evaluations: 3361
#             Gradient evaluations: 32
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0084647442061822e-05
#             Iterations: 279
#             Function evaluations: 29574
#             Gradient evaluations: 279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.596086344859936
#             Iterations: 41
#             Function evaluations: 4385
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.340404673110822e-09
#             Iterations: 44
#             Function evaluations: 4664
#             Gradient evaluations: 44
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7242320876696093e-05
#             Iterations: 276
#             Function evaluations: 29808
#             Gradient evaluations: 276
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7375779238497473
#             Iterations: 44
#             Function evaluations: 4793
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.717893951070081e-09
#             Iterations: 33
#             Function evaluations: 3565
#             Gradient evaluations: 33
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6083100180238896e-05
#             Iterations: 232
#             Function evaluations: 26680
#             Gradient evaluations: 232
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7002728699670238
#             Iterations: 44
#             Function evaluations: 5104
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.294311184902642e-09
#             Iterations: 33
#             Function evaluations: 3795
#             Gradient evaluations: 33
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9589096523370665e-05
#             Iterations: 242
#             Function evaluations: 27831
#             Gradient evaluations: 242
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.477698155763229
#             Iterations: 39
#             Function evaluations: 4524
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0002300998201723e-09
#             Iterations: 32
#             Function evaluations: 3681
#             Gradient evaluations: 32
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8512426769079306e-05
#             Iterations: 237
#             Function evaluations: 27255
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.63464127491626
#             Iterations: 48
#             Function evaluations: 5566
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.45580888639446e-09
#             Iterations: 33
#             Function evaluations: 3795
#             Gradient evaluations: 33
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1783447828521937e-05
#             Iterations: 260
#             Function evaluations: 29900
#             Gradient evaluations: 260
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7070766262501467
#             Iterations: 41
#             Function evaluations: 4754
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.272760118498112e-09
#             Iterations: 21
#             Function evaluations: 2416
#             Gradient evaluations: 21
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.17315927341517e-05
#             Iterations: 233
#             Function evaluations: 26796
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3887939252022012
#             Iterations: 32
#             Function evaluations: 3711
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2993069381809305e-09
#             Iterations: 28
#             Function evaluations: 3220
#             Gradient evaluations: 28
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.894864466267723e-05
#             Iterations: 196
#             Function evaluations: 22540
#             Gradient evaluations: 196
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2808865280057664
#             Iterations: 29
#             Function evaluations: 3363
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.446095214315517e-10
#             Iterations: 42
#             Function evaluations: 4830
#             Gradient evaluations: 42
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.806373750914333e-05
#             Iterations: 175
#             Function evaluations: 21351
#             Gradient evaluations: 175
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.280312594753324
#             Iterations: 27
#             Function evaluations: 3319
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2834851590052823e-09
#             Iterations: 41
#             Function evaluations: 5002
#             Gradient evaluations: 41
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.205560607335088e-05
#             Iterations: 198
#             Function evaluations: 24156
#             Gradient evaluations: 198
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.450207242786192
#             Iterations: 27
#             Function evaluations: 3323
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1864220962454563e-09
#             Iterations: 51
#             Function evaluations: 6223
#             Gradient evaluations: 51
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.7048490895955775e-05
#             Iterations: 161
#             Function evaluations: 19643
#             Gradient evaluations: 161
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4198426399490716
#             Iterations: 26
#             Function evaluations: 3199
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.963852340402336e-10
#             Iterations: 61
#             Function evaluations: 7442
#             Gradient evaluations: 61
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.96402179645009e-05
#             Iterations: 177
#             Function evaluations: 21594
#             Gradient evaluations: 177
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.364275709503564
#             Iterations: 28
#             Function evaluations: 3440
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.5360053058636926e-10
#             Iterations: 70
#             Function evaluations: 8540
#             Gradient evaluations: 70
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.294983952522596e-05
#             Iterations: 160
#             Function evaluations: 19521
#             Gradient evaluations: 160
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.145134759680279
#             Iterations: 24
#             Function evaluations: 2953
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.115451586280283e-10
#             Iterations: 82
#             Function evaluations: 10004
#             Gradient evaluations: 82
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021683435857420012
#             Iterations: 137
#             Function evaluations: 16851
#             Gradient evaluations: 137
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7548626469308792
#             Iterations: 24
#             Function evaluations: 2964
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3982275054159253e-10
#             Iterations: 77
#             Function evaluations: 9472
#             Gradient evaluations: 77
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002267460279389094
#             Iterations: 128
#             Function evaluations: 16256
#             Gradient evaluations: 128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7231032933540684
#             Iterations: 24
#             Function evaluations: 3061
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.172431746182369e-10
#             Iterations: 93
#             Function evaluations: 11811
#             Gradient evaluations: 93
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00025386362356495716
#             Iterations: 97
#             Function evaluations: 12319
#             Gradient evaluations: 97
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.592897382858236
#             Iterations: 24
#             Function evaluations: 3057
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4653113370879037e-10
#             Iterations: 99
#             Function evaluations: 12573
#             Gradient evaluations: 99
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00025583308322034274
#             Iterations: 124
#             Function evaluations: 15748
#             Gradient evaluations: 124
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.613187884690726
#             Iterations: 23
#             Function evaluations: 2934
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5837761727261757e-10
#             Iterations: 106
#             Function evaluations: 13462
#             Gradient evaluations: 106
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00024815789444111437
#             Iterations: 97
#             Function evaluations: 12319
#             Gradient evaluations: 97
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.6207089351423998
#             Iterations: 24
#             Function evaluations: 3059
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5909245534151443e-10
#             Iterations: 106
#             Function evaluations: 13463
#             Gradient evaluations: 106
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022750562709731803
#             Iterations: 100
#             Function evaluations: 12700
#             Gradient evaluations: 100
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.6721629830490123
#             Iterations: 22
#             Function evaluations: 2805
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0042167774761845e-10
#             Iterations: 99
#             Function evaluations: 12574
#             Gradient evaluations: 99
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.777180197216622e-05
#             Iterations: 133
#             Function evaluations: 17025
#             Gradient evaluations: 133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9268162189633131
#             Iterations: 25
#             Function evaluations: 3222
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.590238221243204e-10
#             Iterations: 169
#             Function evaluations: 21632
#             Gradient evaluations: 169
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.561049457208698e-05
#             Iterations: 154
#             Function evaluations: 22022
#             Gradient evaluations: 154
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0194783076011205
#             Iterations: 25
#             Function evaluations: 3598
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.935452836558466e-10
#             Iterations: 118
#             Function evaluations: 16875
#             Gradient evaluations: 118
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.58726481448374e-05
#             Iterations: 195
#             Function evaluations: 27885
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.337952253451483
#             Iterations: 34
#             Function evaluations: 4893
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.774318549463696e-09
#             Iterations: 91
#             Function evaluations: 13013
#             Gradient evaluations: 91
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.164507629975273e-05
#             Iterations: 216
#             Function evaluations: 30888
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.172109462001486
#             Iterations: 24
#             Function evaluations: 3456
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.022232434998734e-10
#             Iterations: 60
#             Function evaluations: 8580
#             Gradient evaluations: 60
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.2759582445145284e-05
#             Iterations: 191
#             Function evaluations: 27313
#             Gradient evaluations: 191
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0462069905272684
#             Iterations: 23
#             Function evaluations: 3309
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.164847993443566e-10
#             Iterations: 62
#             Function evaluations: 8866
#             Gradient evaluations: 62
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.2663027824794e-05
#             Iterations: 182
#             Function evaluations: 26026
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9578977592730358
#             Iterations: 21
#             Function evaluations: 3022
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.220439250077033e-10
#             Iterations: 62
#             Function evaluations: 8867
#             Gradient evaluations: 62
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.844300962427632e-05
#             Iterations: 202
#             Function evaluations: 28886
#             Gradient evaluations: 202
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8768872885409864
#             Iterations: 22
#             Function evaluations: 3166
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.09847430124309e-10
#             Iterations: 52
#             Function evaluations: 7436
#             Gradient evaluations: 52
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.662247005640746e-05
#             Iterations: 210
#             Function evaluations: 30240
#             Gradient evaluations: 210
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8955029020242473
#             Iterations: 23
#             Function evaluations: 3332
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.429940152098504e-10
#             Iterations: 52
#             Function evaluations: 7489
#             Gradient evaluations: 52
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.670046840514559e-05
#             Iterations: 200
#             Function evaluations: 28800
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9265521678331312
#             Iterations: 26
#             Function evaluations: 3760
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0951695190187686e-09
#             Iterations: 52
#             Function evaluations: 7489
#             Gradient evaluations: 52
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8883020484945623e-05
#             Iterations: 192
#             Function evaluations: 27648
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.090384521476633
#             Iterations: 30
#             Function evaluations: 4345
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5512863541412775e-09
#             Iterations: 42
#             Function evaluations: 6048
#             Gradient evaluations: 42
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.253449689242594e-05
#             Iterations: 241
#             Function evaluations: 34704
#             Gradient evaluations: 241
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2750230248388887
#             Iterations: 31
#             Function evaluations: 4491
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.178591286658813e-09
#             Iterations: 41
#             Function evaluations: 5904
#             Gradient evaluations: 41
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.4717456429456404e-05
#             Iterations: 173
#             Function evaluations: 24913
#             Gradient evaluations: 173
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7234887195165687
#             Iterations: 22
#             Function evaluations: 3186
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.300415030155316e-10
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.505667875658841e-05
#             Iterations: 157
#             Function evaluations: 22608
#             Gradient evaluations: 157
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.640005742680439
#             Iterations: 23
#             Function evaluations: 3320
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.029443784068739e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.758122922210585e-05
#             Iterations: 154
#             Function evaluations: 22177
#             Gradient evaluations: 154
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.712703171500173
#             Iterations: 25
#             Function evaluations: 3614
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.283535155654706e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.440270898474113e-05
#             Iterations: 168
#             Function evaluations: 24192
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.6994023648627021
#             Iterations: 22
#             Function evaluations: 3180
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.88346091546971e-10
#             Iterations: 69
#             Function evaluations: 9936
#             Gradient evaluations: 69
# 2011-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.546143841377588e-05
#             Iterations: 167
#             Function evaluations: 24049
#             Gradient evaluations: 167
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.6881472706116354
#             Iterations: 23
#             Function evaluations: 3327
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.284455640759741e-10
#             Iterations: 69
#             Function evaluations: 9936
#             Gradient evaluations: 69
# 2011-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.6212508961286646e-05
#             Iterations: 148
#             Function evaluations: 21312
#             Gradient evaluations: 148
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.6837778762517404
#             Iterations: 23
#             Function evaluations: 3326
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.465251881483289e-10
#             Iterations: 68
#             Function evaluations: 9792
#             Gradient evaluations: 68
# 2011-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9351581306305057e-05
#             Iterations: 230
#             Function evaluations: 33120
#             Gradient evaluations: 230
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0864724720098033
#             Iterations: 29
#             Function evaluations: 4199
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8274430122543612e-09
#             Iterations: 72
#             Function evaluations: 10369
#             Gradient evaluations: 72
# 2011-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0727917074202175e-05
#             Iterations: 227
#             Function evaluations: 32688
#             Gradient evaluations: 227
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3730815343296707
#             Iterations: 29
#             Function evaluations: 4206
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2912423723529256e-09
#             Iterations: 51
#             Function evaluations: 7344
#             Gradient evaluations: 51
# 2012-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0739416925708343e-05
#             Iterations: 269
#             Function evaluations: 38736
#             Gradient evaluations: 269
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2741502932179056
#             Iterations: 33
#             Function evaluations: 4784
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.550293550119045e-09
#             Iterations: 42
#             Function evaluations: 6049
#             Gradient evaluations: 42
# 2012-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2677370961819856e-05
#             Iterations: 257
#             Function evaluations: 37008
#             Gradient evaluations: 257
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.305506941747494
#             Iterations: 33
#             Function evaluations: 4785
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.667384949533289e-09
#             Iterations: 41
#             Function evaluations: 5905
#             Gradient evaluations: 41
# 2012-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.488922451301833e-05
#             Iterations: 219
#             Function evaluations: 31536
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.328303118811972
#             Iterations: 29
#             Function evaluations: 4204
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1075803627998335e-09
#             Iterations: 42
#             Function evaluations: 6048
#             Gradient evaluations: 42
# 2012-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6146875836354244e-05
#             Iterations: 247
#             Function evaluations: 35568
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.398442797963041
#             Iterations: 31
#             Function evaluations: 4496
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6767948534611335e-09
#             Iterations: 20
#             Function evaluations: 2881
#             Gradient evaluations: 20
# 2012-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6881315581089888e-05
#             Iterations: 251
#             Function evaluations: 36144
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.410363535205257
#             Iterations: 34
#             Function evaluations: 4930
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.179955797145204e-09
#             Iterations: 20
#             Function evaluations: 2881
#             Gradient evaluations: 20
# 2012-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.456568860726161e-05
#             Iterations: 295
#             Function evaluations: 42480
#             Gradient evaluations: 295
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.51147696966176
#             Iterations: 36
#             Function evaluations: 5217
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5203843538537465e-09
#             Iterations: 21
#             Function evaluations: 3024
#             Gradient evaluations: 21
# 2013-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5538592176095935e-05
#             Iterations: 296
#             Function evaluations: 44400
#             Gradient evaluations: 296
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5534644129296
#             Iterations: 37
#             Function evaluations: 5583
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.076783968582812e-09
#             Iterations: 32
#             Function evaluations: 4801
#             Gradient evaluations: 32
# 2013-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7275520083929067e-05
#             Iterations: 297
#             Function evaluations: 44550
#             Gradient evaluations: 297
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.439032995102583
#             Iterations: 40
#             Function evaluations: 6035
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1374841595868285e-09
#             Iterations: 21
#             Function evaluations: 3150
#             Gradient evaluations: 21
# 2013-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.451840393903582e-05
#             Iterations: 270
#             Function evaluations: 40501
#             Gradient evaluations: 270
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4191837788538755
#             Iterations: 30
#             Function evaluations: 4530
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8312719187840977e-09
#             Iterations: 21
#             Function evaluations: 3150
#             Gradient evaluations: 21
# 2013-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0616400807034867e-05
#             Iterations: 275
#             Function evaluations: 41250
#             Gradient evaluations: 275
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.51095663880057
#             Iterations: 38
#             Function evaluations: 5738
#             Gradient evaluations: 38
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.986343755908541e-09
#             Iterations: 20
#             Function evaluations: 3000
#             Gradient evaluations: 20
# 2013-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.967967663577138e-05
#             Iterations: 256
#             Function evaluations: 38400
#             Gradient evaluations: 256
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.460878557187144
#             Iterations: 41
#             Function evaluations: 6190
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8226126812923991e-09
#             Iterations: 20
#             Function evaluations: 3000
#             Gradient evaluations: 20
# 2013-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.063895964394697e-05
#             Iterations: 266
#             Function evaluations: 39900
#             Gradient evaluations: 266
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.374439102676294
#             Iterations: 40
#             Function evaluations: 6040
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2186523183895964e-09
#             Iterations: 21
#             Function evaluations: 3150
#             Gradient evaluations: 21
# 2014-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.486030198450025e-05
#             Iterations: 285
#             Function evaluations: 45316
#             Gradient evaluations: 285
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3796201369259626
#             Iterations: 40
#             Function evaluations: 6401
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.783949961180977e-09
#             Iterations: 21
#             Function evaluations: 3339
#             Gradient evaluations: 21
# 2014-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7361044309539393e-05
#             Iterations: 244
#             Function evaluations: 38796
#             Gradient evaluations: 244
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.321790861258569
#             Iterations: 39
#             Function evaluations: 6238
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2753778061220805e-09
#             Iterations: 20
#             Function evaluations: 3181
#             Gradient evaluations: 20
# 2014-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8614689532931154e-05
#             Iterations: 246
#             Function evaluations: 39114
#             Gradient evaluations: 246
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.337493695358802
#             Iterations: 34
#             Function evaluations: 5440
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1501909764361208e-09
#             Iterations: 20
#             Function evaluations: 3180
#             Gradient evaluations: 20
# 2014-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0870803116800806e-05
#             Iterations: 251
#             Function evaluations: 39910
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3434175029649693
#             Iterations: 30
#             Function evaluations: 4798
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5453533299389954e-09
#             Iterations: 20
#             Function evaluations: 3180
#             Gradient evaluations: 20
# 2014-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7784472361647805e-05
#             Iterations: 233
#             Function evaluations: 37280
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0011919331408263
#             Iterations: 26
#             Function evaluations: 4186
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.74017105450175e-10
#             Iterations: 29
#             Function evaluations: 4640
#             Gradient evaluations: 29
# 2014-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.008895660820242e-05
#             Iterations: 238
#             Function evaluations: 38081
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.068340479112556
#             Iterations: 30
#             Function evaluations: 4827
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.482666260881535e-10
#             Iterations: 30
#             Function evaluations: 4800
#             Gradient evaluations: 30
# 2015-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.143424954695554e-05
#             Iterations: 281
#             Function evaluations: 46927
#             Gradient evaluations: 281
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1194187496009724
#             Iterations: 30
#             Function evaluations: 5039
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0476266495915153e-09
#             Iterations: 28
#             Function evaluations: 4676
#             Gradient evaluations: 28
# 2015-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.842886543881209e-05
#             Iterations: 309
#             Function evaluations: 51604
#             Gradient evaluations: 309
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.170647860258337
#             Iterations: 28
#             Function evaluations: 4701
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1829608066983778e-09
#             Iterations: 37
#             Function evaluations: 6179
#             Gradient evaluations: 37
# 2015-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.0468055149929605e-05
#             Iterations: 276
#             Function evaluations: 46368
#             Gradient evaluations: 276
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.195648290228688
#             Iterations: 30
#             Function evaluations: 5070
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4404843249437167e-09
#             Iterations: 36
#             Function evaluations: 6048
#             Gradient evaluations: 36
# 2015-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.1173239477791865e-05
#             Iterations: 260
#             Function evaluations: 43940
#             Gradient evaluations: 260
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2065465107402567
#             Iterations: 31
#             Function evaluations: 5268
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2334463598452176e-09
#             Iterations: 47
#             Function evaluations: 7943
#             Gradient evaluations: 47
# 2015-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.755078480144621e-05
#             Iterations: 262
#             Function evaluations: 44279
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5242144841808396
#             Iterations: 39
#             Function evaluations: 6630
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4129191080936424e-09
#             Iterations: 48
#             Function evaluations: 8112
#             Gradient evaluations: 48
# 2015-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.544759114630407e-05
#             Iterations: 280
#             Function evaluations: 47600
#             Gradient evaluations: 280
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.636129250340981
#             Iterations: 42
#             Function evaluations: 7181
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3882078968833008e-09
#             Iterations: 49
#             Function evaluations: 8330
#             Gradient evaluations: 49
# 2016-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3764102755335096e-05
#             Iterations: 331
#             Function evaluations: 59250
#             Gradient evaluations: 331
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.908683868628025
#             Iterations: 42
#             Function evaluations: 7561
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0144766630323385e-09
#             Iterations: 39
#             Function evaluations: 6981
#             Gradient evaluations: 39
# 2016-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0086091274889326e-05
#             Iterations: 292
#             Function evaluations: 52269
#             Gradient evaluations: 292
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.072719822749452
#             Iterations: 50
#             Function evaluations: 8996
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6196973945735806e-09
#             Iterations: 28
#             Function evaluations: 5012
#             Gradient evaluations: 28
# 2016-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7604030719818433e-05
#             Iterations: 309
#             Function evaluations: 55311
#             Gradient evaluations: 309
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.092528435809448
#             Iterations: 53
#             Function evaluations: 9360
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6214098242554567e-09
#             Iterations: 29
#             Function evaluations: 5191
#             Gradient evaluations: 29
# 2016-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4745212505291855e-05
#             Iterations: 350
#             Function evaluations: 62651
#             Gradient evaluations: 350
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.263527697358232
#             Iterations: 61
#             Function evaluations: 10973
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7538974887657117e-09
#             Iterations: 16
#             Function evaluations: 2865
#             Gradient evaluations: 16
# 2016-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.100922687507852e-05
#             Iterations: 367
#             Function evaluations: 65694
#             Gradient evaluations: 367
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5922328265917938
#             Iterations: 64
#             Function evaluations: 11339
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.110055573593739e-09
#             Iterations: 9
#             Function evaluations: 1612
#             Gradient evaluations: 9
# 2016-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.001337659757658e-06
#             Iterations: 390
#             Function evaluations: 69811
#             Gradient evaluations: 390
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6868728555839896
#             Iterations: 66
#             Function evaluations: 11880
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.989896058334163e-09
#             Iterations: 10
#             Function evaluations: 1790
#             Gradient evaluations: 10
# 2017-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.100897374239232e-06
#             Iterations: 365
#             Function evaluations: 68620
#             Gradient evaluations: 365
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9675538131843977
#             Iterations: 74
#             Function evaluations: 13802
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.132694182638773e-09
#             Iterations: 9
#             Function evaluations: 1692
#             Gradient evaluations: 9
# 2017-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9308720125878425e-05
#             Iterations: 387
#             Function evaluations: 72756
#             Gradient evaluations: 387
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9670055829923765
#             Iterations: 53
#             Function evaluations: 10016
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0725046532804177e-09
#             Iterations: 20
#             Function evaluations: 3760
#             Gradient evaluations: 20
# ...
#             Current function value: 4.4479845125770424e-05
#             Iterations: 266
#             Function evaluations: 54264
#             Gradient evaluations: 266
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8077413473830024
#             Iterations: 33
#             Function evaluations: 6761
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.852719655710661e-09
#             Iterations: 58
#             Function evaluations: 11833
#             Gradient evaluations: 58
# 2020-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.450900163109201e-05
#             Iterations: 261
#             Function evaluations: 53244
#             Gradient evaluations: 261
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0258140032125334
#             Iterations: 46
#             Function evaluations: 9429
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9488696477342905e-09
#             Iterations: 54
#             Function evaluations: 11016
#             Gradient evaluations: 54
# 2020-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.129344857690335e-05
#             Iterations: 291
#             Function evaluations: 59364
#             Gradient evaluations: 291
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1578830157428204
#             Iterations: 46
#             Function evaluations: 9428
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.9442569059906716e-09
#             Iterations: 51
#             Function evaluations: 10404
#             Gradient evaluations: 51
# 2020-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5646510822079932e-05
#             Iterations: 321
#             Function evaluations: 65484
#             Gradient evaluations: 321
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.185196039759623
#             Iterations: 54
#             Function evaluations: 11070
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1915011509012906e-09
#             Iterations: 41
#             Function evaluations: 8364
#             Gradient evaluations: 41
# 2021-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7616464962265726e-05
#             Iterations: 318
#             Function evaluations: 65191
#             Gradient evaluations: 318
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1554715520195735
#             Iterations: 46
#             Function evaluations: 9478
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.437058052072591e-09
#             Iterations: 41
#             Function evaluations: 8405
#             Gradient evaluations: 41
# 2021-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.241355422406299e-05
#             Iterations: 292
#             Function evaluations: 59860
#             Gradient evaluations: 292
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0782676350158926
#             Iterations: 44
#             Function evaluations: 9061
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.402959246282663e-09
#             Iterations: 27
#             Function evaluations: 5536
#             Gradient evaluations: 27
# 2021-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.316104845959792e-05
#             Iterations: 292
#             Function evaluations: 59860
#             Gradient evaluations: 292
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6920919320365244
#             Iterations: 46
#             Function evaluations: 8648
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.369721823606137e-09
#             Iterations: 38
#             Function evaluations: 7791
#             Gradient evaluations: 38
# 2021-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.376293650109412e-05
#             Iterations: 249
#             Function evaluations: 51046
#             Gradient evaluations: 249
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4836671272314312
#             Iterations: 31
#             Function evaluations: 6384
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6533204716426885e-09
#             Iterations: 48
#             Function evaluations: 9840
#             Gradient evaluations: 48
# 2021-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.185749288951806e-05
#             Iterations: 222
#             Function evaluations: 45511
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3175409239703324
#             Iterations: 35
#             Function evaluations: 7206
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6348088524982074e-09
#             Iterations: 47
#             Function evaluations: 9635
#             Gradient evaluations: 47
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.231610610649447e-05
#             Iterations: 248
#             Function evaluations: 50841
#             Gradient evaluations: 248
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.202603291143996
#             Iterations: 33
#             Function evaluations: 6797
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.936401038241577e-10
#             Iterations: 58
#             Function evaluations: 11890
#             Gradient evaluations: 58
# 2022-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.501780024731217e-05
#             Iterations: 248
#             Function evaluations: 52328
#             Gradient evaluations: 248
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1404886091663036
#             Iterations: 30
#             Function evaluations: 6359
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.007122286101011e-10
#             Iterations: 56
#             Function evaluations: 11817
#             Gradient evaluations: 56
# 2022-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.452517553876786e-05
#             Iterations: 235
#             Function evaluations: 49585
#             Gradient evaluations: 235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.107259075732333
#             Iterations: 28
#             Function evaluations: 5935
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.220749618587493e-09
#             Iterations: 46
#             Function evaluations: 9706
#             Gradient evaluations: 46
# 2022-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.958458023737242e-05
#             Iterations: 253
#             Function evaluations: 53384
#             Gradient evaluations: 253
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2281828414718454
#             Iterations: 32
#             Function evaluations: 6783
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4897523194623026e-09
#             Iterations: 48
#             Function evaluations: 10128
#             Gradient evaluations: 48
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.3232636429024066e-05
#             Iterations: 274
#             Function evaluations: 57814
#             Gradient evaluations: 274
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.332628718743062
#             Iterations: 37
#             Function evaluations: 7841
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.580055031556426e-10
#             Iterations: 51
#             Function evaluations: 10761
#             Gradient evaluations: 51
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3428878571137084e-05
#             Iterations: 275
#             Function evaluations: 58025
#             Gradient evaluations: 275
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5322945947594286
#             Iterations: 36
#             Function evaluations: 7631
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9688482508114073e-09
#             Iterations: 41
#             Function evaluations: 8652
#             Gradient evaluations: 41
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.108549385110914e-05
#             Iterations: 271
#             Function evaluations: 57181
#             Gradient evaluations: 271
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8895974860063958
#             Iterations: 46
#             Function evaluations: 9747
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0345295640017866e-09
#             Iterations: 39
#             Function evaluations: 8229
#             Gradient evaluations: 39
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.53691138639424e-05
#             Iterations: 305
#             Function evaluations: 64356
#             Gradient evaluations: 305
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.154492684116391
#             Iterations: 44
#             Function evaluations: 9323
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.082129355633089e-09
#             Iterations: 39
#             Function evaluations: 8230
#             Gradient evaluations: 39
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.081166227812366e-05
#             Iterations: 292
#             Function evaluations: 61612
#             Gradient evaluations: 292
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.3961971529358106
#             Iterations: 53
#             Function evaluations: 11231
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.263541338774535e-09
#             Iterations: 28
#             Function evaluations: 5908
#             Gradient evaluations: 28
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0453517837100635e-05
#             Iterations: 294
#             Function evaluations: 62035
#             Gradient evaluations: 294
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.482118528374129
#             Iterations: 68
#             Function evaluations: 13571
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5246515637222703e-09
#             Iterations: 26
#             Function evaluations: 5486
#             Gradient evaluations: 26
# 2023-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.929585917695904e-05
#             Iterations: 333
#             Function evaluations: 70263
#             Gradient evaluations: 333
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7066426874483898
#             Iterations: 56
#             Function evaluations: 11869
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3371459511994075e-09
#             Iterations: 33
#             Function evaluations: 6963
#             Gradient evaluations: 33
# 2023-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.948467175939161e-05
#             Iterations: 294
#             Function evaluations: 62034
#             Gradient evaluations: 294
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7153066505746373
#             Iterations: 73
#             Function evaluations: 14650
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5724728678841943e-09
#             Iterations: 32
#             Function evaluations: 6752
#             Gradient evaluations: 32
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8104246525629658e-05
#             Iterations: 305
#             Function evaluations: 64356
#             Gradient evaluations: 305
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7842843929033183
#             Iterations: 68
#             Function evaluations: 13566
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5028171951972646e-09
#             Iterations: 33
#             Function evaluations: 6963
#             Gradient evaluations: 33
# 2024-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.912688213821159e-05
#             Iterations: 298
#             Function evaluations: 64667
#             Gradient evaluations: 298
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.774199469683341
#             Iterations: 66
#             Function evaluations: 14384
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.142608319207489e-09
#             Iterations: 32
#             Function evaluations: 6944
#             Gradient evaluations: 32
# 2024-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.072849788276344e-05
#             Iterations: 343
#             Function evaluations: 74431
#             Gradient evaluations: 343
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.729882231762215
#             Iterations: 61
#             Function evaluations: 13299
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4243398344406325e-09
#             Iterations: 32
#             Function evaluations: 6944
#             Gradient evaluations: 32
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_reduziert.to_csv("returnsreduziert_2Monate_f.csv")

# %% [markdown]
# ### Reduziert und Ledoit-Shrinkage

# %%
returns = df_SP500_reduziert.pct_change()
returns = returns.where(~df_SP500_reduziert.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                    A      AAPL       ABT       ACN       ADI       ADM  \
# Date
# 2005-06-02  0.000414 -0.006452       NaN       NaN       NaN       NaN
# 2005-06-03 -0.005374 -0.044955       NaN       NaN       NaN       NaN
# 2005-06-06  0.019119 -0.008368       NaN       NaN       NaN       NaN
# 2005-06-07 -0.012235 -0.036393       NaN       NaN       NaN       NaN
# 2005-06-08  0.009496  0.010399       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23 -0.010485 -0.030244 -0.001521 -0.021710 -0.006889 -0.000417
# 2025-05-27  0.025154  0.025298  0.012490  0.018897  0.030503  0.014393
# 2025-05-28 -0.003415  0.001049 -0.006920  0.001775 -0.005856 -0.005758
# 2025-05-29  0.021645 -0.002345  0.006287  0.005507  0.000603  0.000414
# 2025-05-30 -0.012006  0.004501  0.005495 -0.002864 -0.008204 -0.002067
#
#                  ADP      ADSK       AES       AIZ  ...       VLO      VRSN  \
# Date                                                ...
# 2005-06-02       NaN       NaN -0.014875       NaN  ...       NaN       NaN
# 2005-06-03       NaN       NaN -0.011668       NaN  ...       NaN       NaN
# 2005-06-06       NaN       NaN  0.041667       NaN  ...       NaN       NaN
# 2005-06-07       NaN       NaN -0.004000       NaN  ...       NaN       NaN
# 2005-06-08       NaN       NaN -0.006693       NaN  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-23 -0.001741  0.001186  0.037383  0.018133  ... -0.001321 -0.007450
# 2025-05-27  0.014388  0.016963  0.008008  0.022797  ...  0.016803 -0.036460
# 2025-05-28 -0.004820 -0.003762 -0.036743 -0.015224  ... -0.028919 -0.001558
# 2025-05-29 -0.000062 -0.007452  0.036083  0.010205  ...  0.017569 -0.001709
# 2025-05-30  0.004350 -0.002963  0.003980  0.015103  ... -0.001471  0.014106
#
#                 VRTX       WAT       WFC       WRB       XEL       YUM  \
# Date
# 2005-06-02       NaN -0.013181  0.000488       NaN       NaN       NaN
# 2005-06-03       NaN -0.013614 -0.002925       NaN       NaN       NaN
# 2005-06-06       NaN -0.007292  0.001467       NaN       NaN       NaN
# 2005-06-07       NaN  0.004984 -0.001139       NaN       NaN       NaN
# 2005-06-08       NaN -0.009397  0.002118       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23  0.004539 -0.005998 -0.007630  0.012329  0.007513 -0.000344
# 2025-05-27  0.022936  0.034616  0.015927  0.015326  0.001147 -0.009350
# 2025-05-28 -0.002018 -0.010520 -0.003514 -0.012264 -0.012606 -0.006524
# 2025-05-29  0.004471  0.002002  0.010579  0.009142  0.007834  0.006217
# 2025-05-30 -0.011273 -0.017056  0.003624  0.009870  0.009069 -0.000694
#
#                  ZBH       ZTS
# Date
# 2005-06-02  0.002885       NaN
# 2005-06-03  0.029816       NaN
# 2005-06-06 -0.005079       NaN
# 2005-06-07  0.013657       NaN
# 2005-06-08 -0.005414       NaN
# ...              ...       ...
# 2025-05-23  0.010581  0.003766
# 2025-05-27  0.016947  0.022635
# 2025-05-28 -0.020380 -0.005173
# 2025-05-29  0.011377  0.010520
# 2025-05-30 -0.012535  0.008915
#
# [5031 rows x 217 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 2
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = ledoit_shrink(training_daten)
    
    #aus der geschrumpften Matrix die Korrelationsmatrix bauen
    standardabweichung = np.sqrt(np.diag(cov_matrix))
    corr_matrix = cov_matrix / np.outer(standardabweichung, standardabweichung)
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    reduziert_shrinked_gewichte_equally_weighted = equally_weighted(training_daten)
    reduziert_shrinked_gewichte_min_variance= min_variance_opt(cov_matrix)
    reduziert_shrinked_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    reduziert_shrinked_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    reduziert_shrinked_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    reduziert_shrinked_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    reduziert_shrinked_gewichte_herc = herc_ledoit(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": reduziert_shrinked_gewichte_equally_weighted,
    "Minimum-Variance": reduziert_shrinked_gewichte_min_variance,
    "Maximum-Diversification": reduziert_shrinked_gewichte_max_diversification,
    "Inverse-Volatility": reduziert_shrinked_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": reduziert_shrinked_gewichte_risk_parity,
    "HRP": reduziert_shrinked_gewichte_hrp,
    "HERC": reduziert_shrinked_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
     #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_reduziert_shrinked = pd.concat(portfolio_returns_list)
portfolio_returns_df_reduziert_shrinked = portfolio_returns_df_reduziert_shrinked.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.068558709922772e-05
#             Iterations: 262
#             Function evaluations: 26986
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6511078138392
#             Iterations: 48
#             Function evaluations: 4991
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9801819573744985e-09
#             Iterations: 20
#             Function evaluations: 2060
#             Gradient evaluations: 20
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.182482490877974e-05
#             Iterations: 240
#             Function evaluations: 25200
#             Gradient evaluations: 240
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.572752583568833
#             Iterations: 46
#             Function evaluations: 4876
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3455359437057664e-09
#             Iterations: 32
#             Function evaluations: 3361
#             Gradient evaluations: 32
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0101814413008057e-05
#             Iterations: 235
#             Function evaluations: 24910
#             Gradient evaluations: 235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.673745125011371
#             Iterations: 44
#             Function evaluations: 4705
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1067301642778304e-09
#             Iterations: 45
#             Function evaluations: 4770
#             Gradient evaluations: 45
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7090695295607643e-05
#             Iterations: 223
#             Function evaluations: 24084
#             Gradient evaluations: 223
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.822690256880799
#             Iterations: 51
#             Function evaluations: 5556
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3301261847075104e-09
#             Iterations: 33
#             Function evaluations: 3564
#             Gradient evaluations: 33
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5845148820999298e-05
#             Iterations: 220
#             Function evaluations: 25300
#             Gradient evaluations: 220
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7940095371808464
#             Iterations: 54
#             Function evaluations: 6261
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.959844752828058e-09
#             Iterations: 33
#             Function evaluations: 3795
#             Gradient evaluations: 33
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9204183955564046e-05
#             Iterations: 219
#             Function evaluations: 25185
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5517120558042072
#             Iterations: 41
#             Function evaluations: 4756
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7280073732869896e-09
#             Iterations: 33
#             Function evaluations: 3795
#             Gradient evaluations: 33
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.79588839349678e-05
#             Iterations: 229
#             Function evaluations: 26335
#             Gradient evaluations: 229
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.716516627849747
#             Iterations: 50
#             Function evaluations: 5800
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1906232743412936e-09
#             Iterations: 33
#             Function evaluations: 3795
#             Gradient evaluations: 33
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.081527486964122e-05
#             Iterations: 222
#             Function evaluations: 25530
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.832946355798508
#             Iterations: 49
#             Function evaluations: 5684
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.68972847580394e-09
#             Iterations: 19
#             Function evaluations: 2186
#             Gradient evaluations: 19
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.096812860592051e-05
#             Iterations: 220
#             Function evaluations: 25300
#             Gradient evaluations: 220
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.458312617208279
#             Iterations: 37
#             Function evaluations: 4293
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2818366064202654e-09
#             Iterations: 20
#             Function evaluations: 2301
#             Gradient evaluations: 20
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.819598606506064e-05
#             Iterations: 177
#             Function evaluations: 20355
#             Gradient evaluations: 177
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3295094710007476
#             Iterations: 30
#             Function evaluations: 3480
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.614478717004363e-10
#             Iterations: 42
#             Function evaluations: 4830
#             Gradient evaluations: 42
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.738881263052411e-05
#             Iterations: 183
#             Function evaluations: 22326
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3227461909647786
#             Iterations: 30
#             Function evaluations: 3690
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1794866342860993e-09
#             Iterations: 41
#             Function evaluations: 5002
#             Gradient evaluations: 41
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.1471032755534995e-05
#             Iterations: 159
#             Function evaluations: 19399
#             Gradient evaluations: 159
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4882703832124844
#             Iterations: 32
#             Function evaluations: 3935
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.077277731456083e-09
#             Iterations: 51
#             Function evaluations: 6223
#             Gradient evaluations: 51
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.6252425712278434e-05
#             Iterations: 153
#             Function evaluations: 18666
#             Gradient evaluations: 153
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4501496718585263
#             Iterations: 29
#             Function evaluations: 3568
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.5274305668087737e-10
#             Iterations: 61
#             Function evaluations: 7442
#             Gradient evaluations: 61
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.902931173855929e-05
#             Iterations: 161
#             Function evaluations: 19642
#             Gradient evaluations: 161
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3996157677387666
#             Iterations: 27
#             Function evaluations: 3322
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.57058040759739e-10
#             Iterations: 60
#             Function evaluations: 7321
#             Gradient evaluations: 60
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.257704798754454e-05
#             Iterations: 151
#             Function evaluations: 18422
#             Gradient evaluations: 151
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.20405099015849
#             Iterations: 32
#             Function evaluations: 3928
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.5961468559191314e-10
#             Iterations: 82
#             Function evaluations: 10004
#             Gradient evaluations: 82
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021483732436094428
#             Iterations: 112
#             Function evaluations: 13776
#             Gradient evaluations: 112
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8025238484959207
#             Iterations: 22
#             Function evaluations: 2723
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1460553778536066e-10
#             Iterations: 78
#             Function evaluations: 9594
#             Gradient evaluations: 78
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022724397209200538
#             Iterations: 107
#             Function evaluations: 13589
#             Gradient evaluations: 107
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7614123081732822
#             Iterations: 24
#             Function evaluations: 3062
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1651799182159867e-10
#             Iterations: 85
#             Function evaluations: 10795
#             Gradient evaluations: 85
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00025413975392719944
#             Iterations: 93
#             Function evaluations: 11811
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.630621138238726
#             Iterations: 22
#             Function evaluations: 2807
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.36540746499655e-10
#             Iterations: 99
#             Function evaluations: 12573
#             Gradient evaluations: 99
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00025754278353979124
#             Iterations: 100
#             Function evaluations: 12700
#             Gradient evaluations: 100
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.6489914692526664
#             Iterations: 23
#             Function evaluations: 2938
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.488965859949403e-10
#             Iterations: 98
#             Function evaluations: 12447
#             Gradient evaluations: 98
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00025008454963154397
#             Iterations: 113
#             Function evaluations: 14352
#             Gradient evaluations: 113
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.6588850353746267
#             Iterations: 21
#             Function evaluations: 2683
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4861282709816408e-10
#             Iterations: 107
#             Function evaluations: 13589
#             Gradient evaluations: 107
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002286629511010598
#             Iterations: 90
#             Function evaluations: 11430
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7145284427728424
#             Iterations: 23
#             Function evaluations: 2932
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8628263925786276e-10
#             Iterations: 100
#             Function evaluations: 12700
#             Gradient evaluations: 100
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.13047979861831e-05
#             Iterations: 129
#             Function evaluations: 16512
#             Gradient evaluations: 129
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9834214809428932
#             Iterations: 25
#             Function evaluations: 3222
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.9992223480307345e-10
#             Iterations: 169
#             Function evaluations: 21633
#             Gradient evaluations: 169
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.747046172819481e-05
#             Iterations: 160
#             Function evaluations: 22881
#             Gradient evaluations: 160
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.095856977005148
#             Iterations: 29
#             Function evaluations: 4175
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.192373011452087e-10
#             Iterations: 119
#             Function evaluations: 17018
#             Gradient evaluations: 119
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.68642717110705e-05
#             Iterations: 194
#             Function evaluations: 27743
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4238407355918485
#             Iterations: 37
#             Function evaluations: 5327
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5947861839121902e-09
#             Iterations: 91
#             Function evaluations: 13014
#             Gradient evaluations: 91
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.126809792754314e-05
#             Iterations: 211
#             Function evaluations: 30173
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1990058615013677
#             Iterations: 29
#             Function evaluations: 4172
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.565722637539197e-10
#             Iterations: 60
#             Function evaluations: 8580
#             Gradient evaluations: 60
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.242193406763155e-05
#             Iterations: 198
#             Function evaluations: 28314
#             Gradient evaluations: 198
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0685705882687615
#             Iterations: 25
#             Function evaluations: 3596
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.891643572263232e-10
#             Iterations: 62
#             Function evaluations: 8867
#             Gradient evaluations: 62
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.248574031909394e-05
#             Iterations: 184
#             Function evaluations: 26312
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9788362790705416
#             Iterations: 21
#             Function evaluations: 3024
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1194740513443192e-09
#             Iterations: 52
#             Function evaluations: 7437
#             Gradient evaluations: 52
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.833302630402602e-05
#             Iterations: 197
#             Function evaluations: 28171
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.904543490153316
#             Iterations: 22
#             Function evaluations: 3165
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.72174801046665e-10
#             Iterations: 52
#             Function evaluations: 7436
#             Gradient evaluations: 52
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.640184097904121e-05
#             Iterations: 163
#             Function evaluations: 23472
#             Gradient evaluations: 163
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.924315170335524
#             Iterations: 25
#             Function evaluations: 3623
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.03106514942338e-10
#             Iterations: 53
#             Function evaluations: 7632
#             Gradient evaluations: 53
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.643852719653256e-05
#             Iterations: 162
#             Function evaluations: 23328
#             Gradient evaluations: 162
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.954820599754859
#             Iterations: 23
#             Function evaluations: 3333
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0495725197873622e-09
#             Iterations: 53
#             Function evaluations: 7632
#             Gradient evaluations: 53
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8550550408859802e-05
#             Iterations: 172
#             Function evaluations: 24768
#             Gradient evaluations: 172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.127017477382424
#             Iterations: 30
#             Function evaluations: 4346
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4331866702524086e-09
#             Iterations: 42
#             Function evaluations: 6049
#             Gradient evaluations: 42
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2313795273507517e-05
#             Iterations: 220
#             Function evaluations: 31680
#             Gradient evaluations: 220
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3084051542401354
#             Iterations: 30
#             Function evaluations: 4348
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0743763637687986e-09
#             Iterations: 41
#             Function evaluations: 5904
#             Gradient evaluations: 41
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.4770135822693567e-05
#             Iterations: 160
#             Function evaluations: 23040
#             Gradient evaluations: 160
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7669923259451465
#             Iterations: 22
#             Function evaluations: 3185
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.732595879152958e-10
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.483693165912601e-05
#             Iterations: 146
#             Function evaluations: 21024
#             Gradient evaluations: 146
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.677017339456309
#             Iterations: 21
#             Function evaluations: 3036
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.753249250335283e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.7390899048339476e-05
#             Iterations: 179
#             Function evaluations: 25777
#             Gradient evaluations: 179
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.749315294516204
#             Iterations: 22
#             Function evaluations: 3180
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.044201306530545e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.435209447998231e-05
#             Iterations: 152
#             Function evaluations: 21889
#             Gradient evaluations: 152
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7387250679012551
#             Iterations: 21
#             Function evaluations: 3037
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.562515900101841e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.535484624477159e-05
#             Iterations: 156
#             Function evaluations: 22464
#             Gradient evaluations: 156
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.725505592507676
#             Iterations: 23
#             Function evaluations: 3326
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.974445511070134e-10
#             Iterations: 69
#             Function evaluations: 9936
#             Gradient evaluations: 69
# 2011-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.606116173794853e-05
#             Iterations: 132
#             Function evaluations: 19008
#             Gradient evaluations: 132
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7173518295781094
#             Iterations: 23
#             Function evaluations: 3329
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.18270574388655e-10
#             Iterations: 69
#             Function evaluations: 9936
#             Gradient evaluations: 69
# 2011-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9387749952384117e-05
#             Iterations: 191
#             Function evaluations: 27504
#             Gradient evaluations: 191
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.129266257657614
#             Iterations: 28
#             Function evaluations: 4056
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7361262289555052e-09
#             Iterations: 72
#             Function evaluations: 10369
#             Gradient evaluations: 72
# 2011-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0651465129527578e-05
#             Iterations: 235
#             Function evaluations: 33840
#             Gradient evaluations: 235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.424350177061322
#             Iterations: 32
#             Function evaluations: 4640
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1430588923012695e-09
#             Iterations: 51
#             Function evaluations: 7344
#             Gradient evaluations: 51
# 2012-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.065178289297698e-05
#             Iterations: 261
#             Function evaluations: 37584
#             Gradient evaluations: 261
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.32018336999659
#             Iterations: 36
#             Function evaluations: 5219
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4036367402884728e-09
#             Iterations: 42
#             Function evaluations: 6048
#             Gradient evaluations: 42
# 2012-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2506220229668297e-05
#             Iterations: 263
#             Function evaluations: 37872
#             Gradient evaluations: 263
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.34372119938344
#             Iterations: 34
#             Function evaluations: 4931
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5643414349188894e-09
#             Iterations: 41
#             Function evaluations: 5905
#             Gradient evaluations: 41
# 2012-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4538276575218678e-05
#             Iterations: 241
#             Function evaluations: 34705
#             Gradient evaluations: 241
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3650000754036595
#             Iterations: 33
#             Function evaluations: 4783
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0348944582843632e-09
#             Iterations: 42
#             Function evaluations: 6048
#             Gradient evaluations: 42
# 2012-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5573641900606427e-05
#             Iterations: 260
#             Function evaluations: 37440
#             Gradient evaluations: 260
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4330351448999954
#             Iterations: 33
#             Function evaluations: 4786
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5106708654728628e-09
#             Iterations: 21
#             Function evaluations: 3025
#             Gradient evaluations: 21
# 2012-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6297755948853498e-05
#             Iterations: 254
#             Function evaluations: 36577
#             Gradient evaluations: 254
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4400575296261167
#             Iterations: 34
#             Function evaluations: 4929
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.047856419650926e-09
#             Iterations: 21
#             Function evaluations: 3024
#             Gradient evaluations: 21
# 2012-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.408783701158818e-05
#             Iterations: 274
#             Function evaluations: 39457
#             Gradient evaluations: 274
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.543750547563549
#             Iterations: 35
#             Function evaluations: 5076
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.364330815821692e-09
#             Iterations: 21
#             Function evaluations: 3024
#             Gradient evaluations: 21
# 2013-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4914168740648393e-05
#             Iterations: 253
#             Function evaluations: 37950
#             Gradient evaluations: 253
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.582134361230298
#             Iterations: 36
#             Function evaluations: 5434
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6033186519093397e-09
#             Iterations: 21
#             Function evaluations: 3150
#             Gradient evaluations: 21
# 2013-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6523633770695348e-05
#             Iterations: 249
#             Function evaluations: 37350
#             Gradient evaluations: 249
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4675433329375753
#             Iterations: 39
#             Function evaluations: 5887
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0228052497980845e-09
#             Iterations: 21
#             Function evaluations: 3150
#             Gradient evaluations: 21
# 2013-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3813400081944086e-05
#             Iterations: 267
#             Function evaluations: 40051
#             Gradient evaluations: 267
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4525310188909275
#             Iterations: 37
#             Function evaluations: 5585
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7271588824091818e-09
#             Iterations: 21
#             Function evaluations: 3150
#             Gradient evaluations: 21
# 2013-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0008193504805446e-05
#             Iterations: 269
#             Function evaluations: 40351
#             Gradient evaluations: 269
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5504625286005402
#             Iterations: 44
#             Function evaluations: 6642
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8606543118409818e-09
#             Iterations: 20
#             Function evaluations: 3000
#             Gradient evaluations: 20
# 2013-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9065299371316638e-05
#             Iterations: 271
#             Function evaluations: 40651
#             Gradient evaluations: 271
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5041930369138656
#             Iterations: 42
#             Function evaluations: 6340
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7009845074522453e-09
#             Iterations: 19
#             Function evaluations: 2851
#             Gradient evaluations: 19
# 2013-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0097322345817476e-05
#             Iterations: 256
#             Function evaluations: 38400
#             Gradient evaluations: 256
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.419728026435166
#             Iterations: 39
#             Function evaluations: 5889
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.080504853456581e-09
#             Iterations: 20
#             Function evaluations: 3000
#             Gradient evaluations: 20
# 2014-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.423067356642874e-05
#             Iterations: 276
#             Function evaluations: 43884
#             Gradient evaluations: 276
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.41486236546808
#             Iterations: 42
#             Function evaluations: 6721
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6298040285980746e-09
#             Iterations: 21
#             Function evaluations: 3339
#             Gradient evaluations: 21
# 2014-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6665782204543585e-05
#             Iterations: 237
#             Function evaluations: 37684
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3551377018796518
#             Iterations: 39
#             Function evaluations: 6241
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.152360064854869e-09
#             Iterations: 20
#             Function evaluations: 3181
#             Gradient evaluations: 20
# 2014-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.783713665508944e-05
#             Iterations: 230
#             Function evaluations: 36570
#             Gradient evaluations: 230
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3692317909181013
#             Iterations: 35
#             Function evaluations: 5600
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.73852002032358e-09
#             Iterations: 9
#             Function evaluations: 1432
#             Gradient evaluations: 9
# 2014-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0089859677286527e-05
#             Iterations: 264
#             Function evaluations: 41976
#             Gradient evaluations: 264
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.373075064301376
#             Iterations: 29
#             Function evaluations: 4641
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4611026174925074e-09
#             Iterations: 20
#             Function evaluations: 3180
#             Gradient evaluations: 20
# 2014-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.692544966305079e-05
#             Iterations: 251
#             Function evaluations: 40160
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0244689752582383
#             Iterations: 31
#             Function evaluations: 4984
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.5093571939482216e-10
#             Iterations: 29
#             Function evaluations: 4641
#             Gradient evaluations: 29
# 2014-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.9004713388664054e-05
#             Iterations: 255
#             Function evaluations: 40800
#             Gradient evaluations: 255
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0899498682986075
#             Iterations: 30
#             Function evaluations: 4829
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.299363774050765e-10
#             Iterations: 30
#             Function evaluations: 4800
#             Gradient evaluations: 30
# 2015-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.053371561192742e-05
#             Iterations: 271
#             Function evaluations: 45258
#             Gradient evaluations: 271
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1431648393547262
#             Iterations: 30
#             Function evaluations: 5039
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.95562977717791e-10
#             Iterations: 28
#             Function evaluations: 4676
#             Gradient evaluations: 28
# 2015-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7729664602709376e-05
#             Iterations: 277
#             Function evaluations: 46259
#             Gradient evaluations: 277
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.195290585790529
#             Iterations: 27
#             Function evaluations: 4536
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1256107177570066e-09
#             Iterations: 37
#             Function evaluations: 6179
#             Gradient evaluations: 37
# 2015-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.9373008978846424e-05
#             Iterations: 227
#             Function evaluations: 38136
#             Gradient evaluations: 227
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2199245623883046
#             Iterations: 36
#             Function evaluations: 6083
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3728992975491576e-09
#             Iterations: 37
#             Function evaluations: 6217
#             Gradient evaluations: 37
# 2015-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.0033688847876086e-05
#             Iterations: 229
#             Function evaluations: 38701
#             Gradient evaluations: 229
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2307645005313743
#             Iterations: 33
#             Function evaluations: 5610
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1758259491185698e-09
#             Iterations: 47
#             Function evaluations: 7943
#             Gradient evaluations: 47
# 2015-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.651827435344933e-05
#             Iterations: 273
#             Function evaluations: 46137
#             Gradient evaluations: 273
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5536665817899604
#             Iterations: 35
#             Function evaluations: 5950
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3325306700801538e-09
#             Iterations: 48
#             Function evaluations: 8112
#             Gradient evaluations: 48
# 2015-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.454183689111872e-05
#             Iterations: 263
#             Function evaluations: 44711
#             Gradient evaluations: 263
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6671309347238568
#             Iterations: 43
#             Function evaluations: 7353
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3009945464747836e-09
#             Iterations: 49
#             Function evaluations: 8330
#             Gradient evaluations: 49
# 2016-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.294525319191106e-05
#             Iterations: 291
#             Function evaluations: 52089
#             Gradient evaluations: 291
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9577003222003584
#             Iterations: 51
#             Function evaluations: 9001
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8455801312676499e-09
#             Iterations: 39
#             Function evaluations: 6981
#             Gradient evaluations: 39
# 2016-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9076503183366154e-05
#             Iterations: 289
#             Function evaluations: 51731
#             Gradient evaluations: 289
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1351506388992343
#             Iterations: 56
#             Function evaluations: 10076
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3524345576364327e-09
#             Iterations: 28
#             Function evaluations: 5013
#             Gradient evaluations: 28
# 2016-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6605645427167005e-05
#             Iterations: 279
#             Function evaluations: 49942
#             Gradient evaluations: 279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1755760401338606
#             Iterations: 60
#             Function evaluations: 10800
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3182952756908822e-09
#             Iterations: 29
#             Function evaluations: 5191
#             Gradient evaluations: 29
# 2016-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.377782130174171e-05
#             Iterations: 294
#             Function evaluations: 52626
#             Gradient evaluations: 294
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.3816254353593833
#             Iterations: 62
#             Function evaluations: 11157
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3611275979286915e-09
#             Iterations: 17
#             Function evaluations: 3043
#             Gradient evaluations: 17
# 2016-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0340887026925326e-05
#             Iterations: 295
#             Function evaluations: 52805
#             Gradient evaluations: 295
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7500627950239656
#             Iterations: 78
#             Function evaluations: 14040
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.342172248880809e-09
#             Iterations: 9
#             Function evaluations: 1612
#             Gradient evaluations: 9
# 2016-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.537879439547573e-06
#             Iterations: 328
#             Function evaluations: 58712
#             Gradient evaluations: 328
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.848939897845526
#             Iterations: 75
#             Function evaluations: 13325
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.260808678904619e-09
#             Iterations: 10
#             Function evaluations: 1790
#             Gradient evaluations: 10
# 2017-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.723597269024427e-06
#             Iterations: 329
#             Function evaluations: 61853
#             Gradient evaluations: 329
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.1371800934313905
#             Iterations: 86
#             Function evaluations: 15501
#             Gradient evaluations: 82
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3115080895361135e-09
#             Iterations: 9
#             Function evaluations: 1692
#             Gradient evaluations: 9
# 2017-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8299473379609405e-05
#             Iterations: 310
#             Function evaluations: 58280
#             Gradient evaluations: 310
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0438295312149317
#             Iterations: 60
#             Function evaluations: 11338
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.745420028887093e-09
#             Iterations: 20
#             Function evaluations: 3760
# ...
#             Current function value: 4.317748638077612e-05
#             Iterations: 221
#             Function evaluations: 45084
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8473124042152054
#             Iterations: 40
#             Function evaluations: 8200
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.442176439386253e-09
#             Iterations: 59
#             Function evaluations: 12037
#             Gradient evaluations: 59
# 2020-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.283210879976224e-05
#             Iterations: 241
#             Function evaluations: 49165
#             Gradient evaluations: 241
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.097467846180449
#             Iterations: 54
#             Function evaluations: 11071
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6896029924996807e-09
#             Iterations: 43
#             Function evaluations: 8772
#             Gradient evaluations: 43
# 2020-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9633131189477348e-05
#             Iterations: 263
#             Function evaluations: 53653
#             Gradient evaluations: 263
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.225528870729858
#             Iterations: 52
#             Function evaluations: 10661
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.483063588313177e-09
#             Iterations: 51
#             Function evaluations: 10405
#             Gradient evaluations: 51
# 2020-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4869255945455282e-05
#             Iterations: 287
#             Function evaluations: 58548
#             Gradient evaluations: 287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.229270202936395
#             Iterations: 57
#             Function evaluations: 11482
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.989243785044526e-09
#             Iterations: 41
#             Function evaluations: 8364
#             Gradient evaluations: 41
# 2021-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6790136882494928e-05
#             Iterations: 320
#             Function evaluations: 65601
#             Gradient evaluations: 320
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1926072583280756
#             Iterations: 52
#             Function evaluations: 10710
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.254399181275017e-09
#             Iterations: 29
#             Function evaluations: 5945
#             Gradient evaluations: 29
# 2021-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1368363950452954e-05
#             Iterations: 271
#             Function evaluations: 55556
#             Gradient evaluations: 271
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.112666478644578
#             Iterations: 46
#             Function evaluations: 9474
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1921825188506082e-09
#             Iterations: 27
#             Function evaluations: 5535
#             Gradient evaluations: 27
# 2021-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.200561133112604e-05
#             Iterations: 259
#             Function evaluations: 53095
#             Gradient evaluations: 259
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7268581666619367
#             Iterations: 43
#             Function evaluations: 8853
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2347313716952904e-09
#             Iterations: 38
#             Function evaluations: 7790
#             Gradient evaluations: 38
# 2021-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.247095464071827e-05
#             Iterations: 249
#             Function evaluations: 51046
#             Gradient evaluations: 249
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.51375544305989
#             Iterations: 38
#             Function evaluations: 7822
#             Gradient evaluations: 38
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5731022849582239e-09
#             Iterations: 48
#             Function evaluations: 9840
#             Gradient evaluations: 48
# 2021-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.067180924868033e-05
#             Iterations: 227
#             Function evaluations: 46535
#             Gradient evaluations: 227
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3452940276388796
#             Iterations: 36
#             Function evaluations: 7414
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5635656995424195e-09
#             Iterations: 47
#             Function evaluations: 9636
#             Gradient evaluations: 47
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.120665236936547e-05
#             Iterations: 250
#             Function evaluations: 51250
#             Gradient evaluations: 250
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.228138697365681
#             Iterations: 32
#             Function evaluations: 6592
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.562408509300391e-10
#             Iterations: 58
#             Function evaluations: 11890
#             Gradient evaluations: 58
# 2022-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.382679294778756e-05
#             Iterations: 246
#             Function evaluations: 51907
#             Gradient evaluations: 246
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1649929813207764
#             Iterations: 30
#             Function evaluations: 6359
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.763522537816792e-10
#             Iterations: 57
#             Function evaluations: 12027
#             Gradient evaluations: 57
# 2022-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.315402296752935e-05
#             Iterations: 221
#             Function evaluations: 46632
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.133730981877416
#             Iterations: 26
#             Function evaluations: 5509
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1725339216270704e-09
#             Iterations: 46
#             Function evaluations: 9706
#             Gradient evaluations: 46
# 2022-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.83027864561891e-05
#             Iterations: 226
#             Function evaluations: 47686
#             Gradient evaluations: 226
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2585587626599475
#             Iterations: 33
#             Function evaluations: 6994
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4232756562717557e-09
#             Iterations: 48
#             Function evaluations: 10128
#             Gradient evaluations: 48
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.171097724372196e-05
#             Iterations: 238
#             Function evaluations: 50218
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3682055195290808
#             Iterations: 40
#             Function evaluations: 8478
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.051217013295981e-10
#             Iterations: 51
#             Function evaluations: 10761
#             Gradient evaluations: 51
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.19664533913992e-05
#             Iterations: 263
#             Function evaluations: 55493
#             Gradient evaluations: 263
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.571080285134857
#             Iterations: 42
#             Function evaluations: 8904
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8444489275396712e-09
#             Iterations: 42
#             Function evaluations: 8862
#             Gradient evaluations: 42
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.999813301548462e-05
#             Iterations: 258
#             Function evaluations: 54438
#             Gradient evaluations: 258
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9315102861577227
#             Iterations: 46
#             Function evaluations: 9747
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9001313199290736e-09
#             Iterations: 39
#             Function evaluations: 8229
#             Gradient evaluations: 39
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4571215564249772e-05
#             Iterations: 300
#             Function evaluations: 63300
#             Gradient evaluations: 300
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.20134013962807
#             Iterations: 47
#             Function evaluations: 9963
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8555565308535785e-09
#             Iterations: 39
#             Function evaluations: 8229
#             Gradient evaluations: 39
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.004620008733058e-05
#             Iterations: 262
#             Function evaluations: 55282
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.448416213661938
#             Iterations: 61
#             Function evaluations: 12931
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.899702747957384e-09
#             Iterations: 28
#             Function evaluations: 5908
#             Gradient evaluations: 28
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9604968886548632e-05
#             Iterations: 262
#             Function evaluations: 55282
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5396286273022137
#             Iterations: 57
#             Function evaluations: 12080
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.209351805185172e-09
#             Iterations: 27
#             Function evaluations: 5697
#             Gradient evaluations: 27
# 2023-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8384378439174443e-05
#             Iterations: 280
#             Function evaluations: 59080
#             Gradient evaluations: 280
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.774293297196307
#             Iterations: 65
#             Function evaluations: 13568
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.77667862257581e-09
#             Iterations: 21
#             Function evaluations: 4431
#             Gradient evaluations: 21
# 2023-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.867064017251489e-05
#             Iterations: 282
#             Function evaluations: 59502
#             Gradient evaluations: 282
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.772946417393852
#             Iterations: 65
#             Function evaluations: 13777
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.189637922067381e-09
#             Iterations: 33
#             Function evaluations: 6963
#             Gradient evaluations: 33
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7142097511704284e-05
#             Iterations: 251
#             Function evaluations: 52962
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8899534090777754
#             Iterations: 68
#             Function evaluations: 14419
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.978264312522957e-09
#             Iterations: 20
#             Function evaluations: 4221
#             Gradient evaluations: 20
# 2024-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8144847695536962e-05
#             Iterations: 263
#             Function evaluations: 57071
#             Gradient evaluations: 263
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.885592599205927
#             Iterations: 80
#             Function evaluations: 16564
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.313626288559921e-09
#             Iterations: 20
#             Function evaluations: 4340
#             Gradient evaluations: 20
# 2024-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.992289822260515e-05
#             Iterations: 277
#             Function evaluations: 60109
#             Gradient evaluations: 277
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8133307964304506
#             Iterations: 70
#             Function evaluations: 15043
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.572768838821377e-09
#             Iterations: 21
#             Function evaluations: 4558
#             Gradient evaluations: 21
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_reduziert_shrinked.to_csv("returnsreduziertshrinked_2Monate_f.csv")
