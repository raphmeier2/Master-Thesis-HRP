# %% [markdown]
# Hier werden die Portfolio-Methoden angewandt und mithilfe der Performance-Metriken bewertet. Die Ergebnisse werden in CSV-Dateien festgehalten. Das Akquirieren, modifizieren und beschreiben der Daten befindet sich der Übersicht halber im Notebook Datenbasis. Die Daten werden dort als CSV exportiert und hier als Dataframe wieder eingelesen.
#
# Die Korrektheit der implementierten Methoden und Metriken wird in dem separaten Notebook Verifizierung anhand eines kleinen Teilbestandes aufgezeigt, siehe dazu auch beigefügte Excel-Dateien, in denen die Portfolio-Gewichte "per Hand" nachgerechnet und mit den Ergebnissen aus der Python-Implementierung abgeglichen werden.
#
# ACHTUNG: LANGE LAUFZEIT!

# %% [markdown]
# ## Importe

# %%
#Import der notwendigen Bibliotheken, Installation mit pip bereits erfolgt

import yfinance as yf
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import csv
from scipy.optimize import minimize
import math
import random
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import linkage, dendrogram
import riskfolio as rp
from sklearn.covariance import LedoitWolf
from scipy.spatial.distance import squareform
from riskfolio import HCPortfolio as hc
from pandas.tseries.offsets import MonthBegin
from pandas.tseries.offsets import MonthEnd

# %% [markdown]
# ## Einlesen der Daten

# %%
#Bearbeitete JSE-Daten (Gesamtbestand)

df_JSE = pd.read_csv(
    'WhartonFinal_neu.csv',
    sep=',',
    encoding='utf-8',
    index_col=0,
    decimal = '.',
    low_memory=False,
    parse_dates=['Date'],
    dayfirst=True
)

# %%
df_JSE.info
# Out:
# <bound method DataFrame.info of                  8303  15604   15618  16179  16183  16291   16305  16355  \
# Date
# 2005-06-01  39.000000  62.11   74.50  14.50   8.60   4.42   82.40   9.95
# 2005-06-02  38.800000  62.00   75.00  14.51   8.51   4.40   82.50   9.80
# 2005-06-03  37.903333  60.79   75.64  14.50   8.50   4.37   82.61   9.90
# 2005-06-06  37.006667  60.75   78.49  13.85   8.62   4.38   82.90   9.90
# 2005-06-07  36.110000  60.90   77.90  13.89   8.67   4.43   83.45   9.90
# ...               ...    ...     ...    ...    ...    ...     ...    ...
# 2025-05-26        NaN    NaN  256.98    NaN  12.95    NaN  168.45    NaN
# 2025-05-27        NaN    NaN  255.97    NaN  13.08    NaN  168.48    NaN
# 2025-05-28        NaN    NaN  257.02    NaN  13.10    NaN  173.00    NaN
# 2025-05-29        NaN    NaN  259.83    NaN  13.32    NaN  175.79    NaN
# 2025-05-30        NaN    NaN  255.50    NaN  13.49    NaN  173.32    NaN
#
#             16356   16610  ...  364340  364439  364518  364519  364717  \
# Date                       ...
# 2005-06-01  23.60  296.00  ...     NaN     NaN     NaN     NaN     NaN
# 2005-06-02  23.40  296.00  ...     NaN     NaN     NaN     NaN     NaN
# 2005-06-03  23.40  290.00  ...     NaN     NaN     NaN     NaN     NaN
# 2005-06-06  23.50  287.00  ...     NaN     NaN     NaN     NaN     NaN
# 2005-06-07  23.50  278.00  ...     NaN     NaN     NaN     NaN     NaN
# ...           ...     ...  ...     ...     ...     ...     ...     ...
# 2025-05-26  42.01  748.00  ...   53.35   10.34   10.47   10.08   10.01
# 2025-05-27  42.50  736.81  ...   53.71   10.39   10.49   10.17   10.02
# 2025-05-28  42.07  724.26  ...   53.96   10.40   10.55   10.32   10.05
# 2025-05-29  42.68  719.83  ...   53.69   10.33   10.55   10.25    9.99
# 2025-05-30  44.00  704.72  ...   54.11   10.45   10.58   10.31   10.12
#
#             365459  365648  366651  366185  366905
# Date
# 2005-06-01     NaN     NaN     NaN     NaN     NaN
# 2005-06-02     NaN     NaN     NaN     NaN     NaN
# 2005-06-03     NaN     NaN     NaN     NaN     NaN
# 2005-06-06     NaN     NaN     NaN     NaN     NaN
# 2005-06-07     NaN     NaN     NaN     NaN     NaN
# ...            ...     ...     ...     ...     ...
# 2025-05-26   20.17  101.22    9.69   10.15    9.92
# 2025-05-27   20.22  101.23    9.76   10.15    9.92
# 2025-05-28   20.23  101.28    9.79   10.15    9.92
# 2025-05-29   20.08  101.32    9.82   10.31    9.93
# 2025-05-30   20.35  101.32    9.94   10.32    9.93
#
# [5173 rows x 350 columns]>

# %% [markdown]
# ## Definition der Methoden und Metriken

# %% [markdown]
# #### Equally-Weighted Portfolio

# %%
#Rückgabe gleicher Gewichte anhand der Anzahl der Unternehmen (Input Returns)

def equally_weighted(returns):
    anzahl_assets = returns.shape[1]

    w0 = 1/anzahl_assets
    gewichte = np.full(anzahl_assets, w0)

    return gewichte

# %% [markdown]
# #### Minimum-Variance Portfolio

# %%
#Minimum-Variance Portfolio
#Code adaptiert von https://medium.com/@BorisGerat/mean-variance-and-minimum-variance-portfolio-models-in-python-64a5c6b57b2d

def min_variance_opt(matrix):
    
    #Compute the minimum-variance portfolio weights subject to the constraints of:
    #- No short-selling (weights must be >= 0)
    #- Full investment (sum of weights must equal 1)
    
    number_of_assets = matrix.shape[0]

    # Define the objective function to minimize portfolio variance
    def objective(w):
        portfolio_variance = np.dot(w, matrix @ w)
        return portfolio_variance

    # Constraint: The sum of portfolio weights must be equal to 1
    constraints = [{'type': 'eq', 'fun': lambda w: np.sum(w) - 1}]

    # Bounds: Each weight must be between 0 and 1 (no short-selling)
    bounds = [[0, 1] for _ in range(number_of_assets)]

    # Initial guess: Equal weights for all assets
    w0 = np.ones(number_of_assets) / number_of_assets

    # Solve the optimization problem using Sequential Least Squares Quadratic Programming (SLSQP)
    res = minimize(objective, w0, method='SLSQP', bounds=bounds, constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    
    return res.x  # Return the optimal weights

# %% [markdown]
# #### Maximum Diversification Portfolio

# %%
#Code von https://thequantmba.wordpress.com/2017/06/06/max-diversification-in-python/ adaptiert

def calc_max_diversification_ratio(weights, matrix):
    
    # gewichtete Volatilität
    average_vol = np.dot(np.sqrt(np.diag(matrix)), weights.T)
    
    # portfolio volatilität
    portfolio_variance = np.dot(weights, matrix @ weights)
    portfolio_vol = np.sqrt(portfolio_variance)
    
    #Bestimmung Ratio
    diversification_ratio = average_vol/portfolio_vol
    
    # Negativer Wert für Minimierung (Maximizieren = Minimieren -)
    return -diversification_ratio

# %%
#Code von https://thequantmba.wordpress.com/2017/06/06/max-diversification-in-python/ adaptiert

def max_diversification_portfolio(matrix):
    
    anzahl_assets = matrix.shape[0]
    
    w0 = 1/anzahl_assets
    w = np.full(anzahl_assets, w0)
    
    # Constraint: The sum of portfolio weights must be equal to 1
    constraints = [{'type': 'eq', 'fun': lambda w: np.sum(w) - 1}]
    
    # Bounds: Each weight must be between 0 and 1 (no short-selling)
    bounds = [[0, 1] for _ in range(anzahl_assets)]
    
    res = minimize(calc_max_diversification_ratio, w, bounds=bounds, args=(matrix), method='SLSQP', constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    return res.x

# %% [markdown]
# #### Inverse Volatility Portfolio

# %%
#Code adaptiert von https://www.kaggle.com/code/vijipai/lesson-4-traditional-portfolio-construction-method

def inverse_volatility_portfolio (matrix):
    
    standardabweichungen = np.sqrt(np.diagonal(matrix))
    invertierte_std = 1/standardabweichungen
    summe_invertierte_std = np.sum(invertierte_std)
    
    inverse_volatility_gewichte = invertierte_std / summe_invertierte_std
    
    return inverse_volatility_gewichte

# %% [markdown]
# #### Equal Risk Contribution Portfolio

# %%
#Code adaptiert von https://medium.com/@deepml1818/building-a-python-based-risk-parity-portfolio-for-trading-40441ecdd84d

def calculate_portfolio_volatility(weights, matrix):
    
    portfolio_variance = np.dot(weights, matrix @ weights)
    portfolio_volatility = np.sqrt(portfolio_variance)
    return portfolio_volatility

def calculate_risk_contribution(weights, matrix):
    portfolio_volatility = calculate_portfolio_volatility(weights, matrix)
    marginal_contribution_zaehler = np.dot(matrix, weights)
    risk_contribution = np.multiply(weights, marginal_contribution_zaehler) / portfolio_volatility
    return risk_contribution

def risk_parity_objective(weights, matrix):
    risk_contribution = calculate_risk_contribution(weights, matrix)
    target_risk = np.mean(risk_contribution)
    return np.sum((risk_contribution - target_risk) ** 2)

# %%
def get_risk_parity_weights(matrix):
    
    number_of_assets = matrix.shape[0]
    w0 = 1/number_of_assets
    initial_weights = np.full(number_of_assets, w0)
    
    constraints = ({'type': 'eq', 'fun': lambda initial_weights: np.sum(initial_weights) - 1})
    bounds = [[0, 1] for _ in range(number_of_assets)]
    
    result = minimize(risk_parity_objective, initial_weights, args=(matrix), method='SLSQP', bounds=bounds, constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    
    return result.x

# %% [markdown]
# #### Hierarchical Risk Parity

# %%
#Aus dem Paper von Lopez De Prado (2016)
def getIVP(cov,**kargs): # Compute the inverse-variance portfolio 
    ivp=1./np.diag(cov) 
    ivp/=ivp.sum() 
    return ivp

# %%
#------------------------------------------------------------------------------ 
def getClusterVar(cov,cItems): # Compute variance per cluster 
    cov_=cov.loc[cItems,cItems] # matrix slice 
    w_=getIVP(cov_).reshape(-1,1) 
    cVar=np.dot(np.dot(w_.T,cov_),w_)[0,0] 
    return cVar

# %%
#------------------------------------------------------------------------------ 
def getQuasiDiag(link): # Sort clustered items by distance 
    link=link.astype(int) 
    sortIx=pd.Series([link[-1,0],link[-1,1]]) 
    numItems=link[-1,3] # number of original items 
    while sortIx.max()>=numItems: 
        sortIx.index=range(0,sortIx.shape[0]*2,2) # make space 
        df0=sortIx[sortIx>=numItems] # find clusters
        i=df0.index;j=df0.values-numItems 
        sortIx[i]=link[j,0] # item 1 
        df0=pd.Series(link[j,1],index=i+1) 
        sortIx = pd.concat([sortIx, df0]) # item 2  ####Anpassung wegen neuer Pandas-Version!
        sortIx=sortIx.sort_index() # re-sort 
        sortIx.index=range(sortIx.shape[0]) # re-index 
    return sortIx.tolist()

# %%
#------------------------------------------------------------------------------ 
def getRecBipart(cov,sortIx): # Compute HRP allocation
    w = pd.Series(1,index=sortIx) 
    cItems=[sortIx] # initialize all items in one cluster 
    while len(cItems)>0: 
        #Bi-Section der Cluster
        cItems = [i[j:k] 
                  for i in cItems 
                  for j, k in ((0, len(i)//2), (len(i)//2, len(i))) 
                  if len(i) > 1]
        for i in range(0, len(cItems), 2): # parse in pairs 
            cItems0=cItems[i] # cluster 1 
            cItems1=cItems[i+1] # cluster 2 
            cVar0=getClusterVar(cov,cItems0) 
            cVar1=getClusterVar(cov,cItems1) 
            alpha=1-cVar0/(cVar0+cVar1) 
            w[cItems0]*=alpha # weight 1 
            w[cItems1]*=1-alpha # weight 2 
    return w

# %%
#------------------------------------------------------------------------------ 
def correlDist(corr): 
    # A distance matrix based on correlation, where 0<=d[i,j]<=1 
    # This is a proper distance metric 
    dist=((1-corr)/2.)**.5 # distance matrix 
    
    #Adjustierung zur condensed_distance_matrix
    condensed_distance_matrix = squareform(X=dist, checks=False)
    
    return condensed_distance_matrix

# %%
def hrp_main(corr, cov, returns): 
    
    #3) cluster 
    dist=correlDist(corr) 
    link=sch.linkage(dist,'single') 
    sortIx=getQuasiDiag(link) 
    sortIx=corr.index[sortIx].tolist() # recover labels 
    df0=corr.loc[sortIx,sortIx] # reorder 
    
    #4) Capital allocation 
    hrp=getRecBipart(cov,sortIx) 
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    hrp_sortiert = hrp.reindex(original_reihenfolge)
    
    array = hrp_sortiert.T.values

    return array

# %% [markdown]
# #### Hierarchical Equal Risk Contribution Portfolio

# %%
#Es wird auf die Implementierung der Riskfolio-Lib zurückgegriffen
#Code adaptiert von #Code adaptiert von https://medium.com/@orenji.eirl/hierarchical-equal-risk-contribution-with-python-and-riskfolio-lib-ec45dd0f9899

def herc (returns):

    # Building the portfolio object
    port = hc(returns=returns)

    # Estimate optimal portfolio:

    model='HERC'
    correlation = 'pearson'
    rm = 'MV'
    rf = 0 
    linkage = 'ward' 
    max_k = 10 
    leaf_order = True 

    gewichte = port.optimization(model=model,
                          correlation=correlation,
                          rm=rm,
                          rf=rf,
                          linkage=linkage,
                          max_k=max_k,
                          leaf_order=leaf_order)
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    gewichte_sortiert = gewichte.reindex(original_reihenfolge)
    
    array = gewichte_sortiert.values.flatten()

    return array

# %% [markdown]
# #### Vergleichs-Metriken

# %%
def gesamt_return(gewichte, returns):

    daily_returns = returns @ gewichte
    total = np.prod(1 + daily_returns) - 1
    
    return total

# %%
def portfolio_return (gewichte, returns):
    
    avg_returns = []
    avg_returns = returns.mean()
    
    pf_return = sum([gewicht * rendite for gewicht, rendite in zip(gewichte, avg_returns)])
    
    return pf_return

# %%
def portfolio_variance (gewichte, returns):
    daily_returns = []
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    pf_var = np.var(daily_returns)
    
    return pf_var

# %%
def portfolio_volatility (gewichte, returns):
    variance = portfolio_variance(gewichte, returns)
    volatility = np.sqrt(variance)
    
    return volatility

# %%
def annualized_return(gewichte, returns):
    daily_returns = returns @ gewichte
    annual = (np.prod(1 + daily_returns))**(252/daily_returns.shape[0]) - 1
    
    return annual

# %%
def annualized_portfolio_return(gewichte, returns):
    pf_return = portfolio_return(gewichte, returns)
    
    return pf_return*252

# %%
def annualized_portfolio_volatility(gewichte, returns):
    pf_volatility = portfolio_volatility(gewichte, returns)
    
    return pf_volatility*np.sqrt(252)

# %%
def sharpe_ratio (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sharpe_ratio_one (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.01
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sharpe_ratio_two (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.02
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio_one (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.01
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio_two (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.02
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sortino_ratio (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def sortino_ratio_one (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.01
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def sortino_ratio_two (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.02
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio_one (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.01
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio_two (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.02
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def maximum_drawdown (gewichte, returns):
    daily_returns = returns @ gewichte
    returns_kumuliert = (1 + daily_returns).cumprod()
    hochpunkte = returns_kumuliert.cummax()
    
    drawdowns = (returns_kumuliert - hochpunkte) / hochpunkte
    max_drawdown = drawdowns.min()
    
    #print(drawdowns)
    return max_drawdown

# %%
def calmar_ratio (gewichte, returns):
    pf_return = portfolio_return(gewichte, returns)
    max_drawdown = maximum_drawdown(gewichte, returns)
    
    calmar_ratio = pf_return / (-max_drawdown)
    
    return calmar_ratio

# %%
def value_at_risk_func(gewichte, returns):
    daily_returns = returns @ gewichte
    sorted_daily_returns = daily_returns.sort_values(ascending = True)
    value_at_risk = np.percentile(sorted_daily_returns, 100*0.05)
    return value_at_risk

# %%
#https://github.com/malctaylor15/VaR-and-Expected-Shortfall-Python/blob/master/Expected%20Shortfall%20and%20Value%20at%20Risk.ipynb

def expected_shortfall(gewichte, returns):
    daily_returns = returns @ gewichte
    sorted_daily_returns = daily_returns.sort_values(ascending = True)
    value_at_risk = value_at_risk_func(gewichte, returns)
    
    expected_shortfall = daily_returns[daily_returns <= value_at_risk].mean()
    
    return expected_shortfall

# %% [markdown]
# #### Sammel-Funktionen zum Berechnen und Speichern der Metriken

# %%
def metriken_equally_weighted(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile1 = {"Methode": "Equally-Weighted",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile1[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile1])], ignore_index=True)

# %%
def metriken_minimum_variance(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile2 = {"Methode": "Minimum_Variance",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile2[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile2])], ignore_index=True)

# %%
def metriken_max_diversification(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile3 = {"Methode": "Max-Diversification",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile3[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile3])], ignore_index=True)

# %%
def metriken_inverse_volatility(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile4 = {"Methode": "Inverse-Volatility",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile4[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile4])], ignore_index=True)

# %%
def metriken_risk_parity(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile5 = {"Methode": "Risk-Parity",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile5[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile5])], ignore_index=True)

# %%
def metriken_hrp(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile6 = {"Methode": "HRP",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile6[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile6])], ignore_index=True)

# %%
def metriken_herc(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile7 = {"Methode": "HERC",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile7[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile7])], ignore_index=True)

# %% [markdown]
# ## Erzeugung Ergebnisse S&P500

# %% [markdown]
# ## Ergebnis-Erzeugung JSE

# %%
returns = df_JSE.pct_change()
returns = returns.where(~df_JSE.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                 8303     15604     15618     16179     16183     16291  \
# Date
# 2005-06-02 -0.005128 -0.001771  0.006711  0.000690 -0.010465 -0.004525
# 2005-06-03 -0.023110 -0.019516  0.008533 -0.000689 -0.001175 -0.006818
# 2005-06-06 -0.023657 -0.000658  0.037678 -0.044828  0.014118  0.002288
# 2005-06-07 -0.024230  0.002469 -0.007517  0.002888  0.005800  0.011416
# 2005-06-08 -0.027970 -0.003284 -0.005135  0.006479  0.014994  0.006772
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26       NaN       NaN  0.013928       NaN -0.001542       NaN
# 2025-05-27       NaN       NaN -0.003930       NaN  0.010039       NaN
# 2025-05-28       NaN       NaN  0.004102       NaN  0.001529       NaN
# 2025-05-29       NaN       NaN  0.010933       NaN  0.016794       NaN
# 2025-05-30       NaN       NaN -0.016665       NaN  0.012763       NaN
#
#                16305     16355     16356     16610  ...    364340    364439  \
# Date                                                ...
# 2005-06-02  0.001214 -0.015075 -0.008475  0.000000  ...       NaN       NaN
# 2005-06-03  0.001333  0.010204  0.000000 -0.020270  ...       NaN       NaN
# 2005-06-06  0.003510  0.000000  0.004274 -0.010345  ...       NaN       NaN
# 2005-06-07  0.006634  0.000000  0.000000 -0.031359  ...       NaN       NaN
# 2005-06-08 -0.005392  0.000000  0.000000 -0.027158  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-26  0.007235       NaN -0.020518 -0.023906  ...  0.003574  0.010753
# 2025-05-27  0.000178       NaN  0.011664 -0.014960  ...  0.006748  0.004836
# 2025-05-28  0.026828       NaN -0.010118 -0.017033  ...  0.004655  0.000962
# 2025-05-29  0.016127       NaN  0.014500 -0.006117  ... -0.005004 -0.006731
# 2025-05-30 -0.014051       NaN  0.030928 -0.020991  ...  0.007823  0.011617
#
#               364518    364519    364717    365459    365648    366651  \
# Date
# 2005-06-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26  0.009643  0.018182  0.000000  0.011535  0.000395  0.006231
# 2025-05-27  0.001910  0.008929  0.000999  0.002479  0.000099  0.007224
# 2025-05-28  0.005720  0.014749  0.002994  0.000495  0.000494  0.003074
# 2025-05-29  0.000000 -0.006783 -0.005970 -0.007415  0.000395  0.003064
# 2025-05-30  0.002844  0.005854  0.013013  0.013446  0.000000  0.012220
#
#               366185    366905
# Date
# 2005-06-02       NaN       NaN
# 2005-06-03       NaN       NaN
# 2005-06-06       NaN       NaN
# 2005-06-07       NaN       NaN
# 2005-06-08       NaN       NaN
# ...              ...       ...
# 2025-05-26 -0.000984  0.000000
# 2025-05-27  0.000000  0.000000
# 2025-05-28  0.000000  0.000000
# 2025-05-29  0.015764  0.001008
# 2025-05-30  0.000970  0.000000
#
# [5172 rows x 350 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 24
test_fenster = 1
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    #Inf-Werte in NaN umwandeln
    training_daten = training_daten.replace([np.inf, -np.inf], np.nan)
    #Spalten entfernen, die nachher noch NaN enthalten
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 126
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = training_daten.cov()
    corr_matrix = training_daten.corr()
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    JSE_gewichte_equally_weighted = equally_weighted(training_daten)
    JSE_gewichte_min_variance= min_variance_opt(cov_matrix)
    JSE_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    JSE_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    JSE_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    JSE_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    JSE_gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": JSE_gewichte_equally_weighted,
    "Minimum-Variance": JSE_gewichte_min_variance,
    "Maximum-Diversification": JSE_gewichte_max_diversification,
    "Inverse-Volatility": JSE_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": JSE_gewichte_risk_parity,
    "HRP": JSE_gewichte_hrp,
    "HERC": JSE_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
    #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
# Alle Testperioden zusammenführen
portfolio_returns_df_JSE = pd.concat(portfolio_returns_list)
portfolio_returns_df_JSE = portfolio_returns_df_JSE.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.820511576969558e-05
#             Iterations: 225
#             Function evaluations: 20925
#             Gradient evaluations: 225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7571745985998604
#             Iterations: 60
#             Function evaluations: 5642
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.239010666692647e-09
#             Iterations: 54
#             Function evaluations: 5024
#             Gradient evaluations: 54
# 2005-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9092587886730358e-05
#             Iterations: 244
#             Function evaluations: 22448
#             Gradient evaluations: 244
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.748654091636428
#             Iterations: 59
#             Function evaluations: 5489
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.4671758312487e-09
#             Iterations: 54
#             Function evaluations: 4970
#             Gradient evaluations: 54
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0118150593302286e-05
#             Iterations: 232
#             Function evaluations: 21112
#             Gradient evaluations: 232
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.650922577673182
#             Iterations: 59
#             Function evaluations: 5433
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.868966463179658e-09
#             Iterations: 48
#             Function evaluations: 4369
#             Gradient evaluations: 48
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0067150104509012e-05
#             Iterations: 214
#             Function evaluations: 20545
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.696893128418197
#             Iterations: 62
#             Function evaluations: 6011
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0813924612685256e-08
#             Iterations: 37
#             Function evaluations: 3552
#             Gradient evaluations: 37
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.045676465123752e-05
#             Iterations: 213
#             Function evaluations: 20236
#             Gradient evaluations: 213
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.660483648186497
#             Iterations: 63
#             Function evaluations: 6049
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.673698000754616e-09
#             Iterations: 50
#             Function evaluations: 4750
#             Gradient evaluations: 50
# 2005-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0254380097259714e-05
#             Iterations: 211
#             Function evaluations: 20257
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6625214860488553
#             Iterations: 62
#             Function evaluations: 6018
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.748488133826171e-09
#             Iterations: 55
#             Function evaluations: 5280
#             Gradient evaluations: 55
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.080745778401037e-05
#             Iterations: 202
#             Function evaluations: 19796
#             Gradient evaluations: 202
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6315295541233272
#             Iterations: 66
#             Function evaluations: 6536
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.011624831018766e-08
#             Iterations: 40
#             Function evaluations: 3922
#             Gradient evaluations: 40
# 2006-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0757902384042176e-05
#             Iterations: 214
#             Function evaluations: 21401
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.726104649472928
#             Iterations: 63
#             Function evaluations: 6366
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.83069038249735e-09
#             Iterations: 41
#             Function evaluations: 4102
#             Gradient evaluations: 41
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.063270369380144e-05
#             Iterations: 230
#             Function evaluations: 23460
#             Gradient evaluations: 230
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.633513449601938
#             Iterations: 63
#             Function evaluations: 6492
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1546914976890883e-08
#             Iterations: 51
#             Function evaluations: 5202
#             Gradient evaluations: 51
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0763266893209675e-05
#             Iterations: 220
#             Function evaluations: 22440
#             Gradient evaluations: 220
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6542997200023555
#             Iterations: 65
#             Function evaluations: 6695
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.416515659333326e-08
#             Iterations: 40
#             Function evaluations: 4081
#             Gradient evaluations: 40
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.152364059269829e-05
#             Iterations: 216
#             Function evaluations: 22465
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6692657725295326
#             Iterations: 65
#             Function evaluations: 6826
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.365436263589509e-08
#             Iterations: 37
#             Function evaluations: 3848
#             Gradient evaluations: 37
# 2006-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1782887228688574e-05
#             Iterations: 217
#             Function evaluations: 22135
#             Gradient evaluations: 217
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.649525469664267
#             Iterations: 60
#             Function evaluations: 6180
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2167246981899955e-08
#             Iterations: 49
#             Function evaluations: 4999
#             Gradient evaluations: 49
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1107346537647464e-05
#             Iterations: 213
#             Function evaluations: 21513
#             Gradient evaluations: 213
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.730343499235631
#             Iterations: 65
#             Function evaluations: 6633
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2478416907656169e-08
#             Iterations: 55
#             Function evaluations: 5556
#             Gradient evaluations: 55
# 2006-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8341277543752784e-05
#             Iterations: 190
#             Function evaluations: 19190
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.945538688837881
#             Iterations: 73
#             Function evaluations: 7453
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4359214264927051e-08
#             Iterations: 42
#             Function evaluations: 4242
#             Gradient evaluations: 42
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0101744280145324e-05
#             Iterations: 213
#             Function evaluations: 21300
#             Gradient evaluations: 213
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8688898669389302
#             Iterations: 69
#             Function evaluations: 6979
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3741673598324266e-08
#             Iterations: 39
#             Function evaluations: 3900
#             Gradient evaluations: 39
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0930204146947134e-05
#             Iterations: 200
#             Function evaluations: 20001
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.859026235027554
#             Iterations: 70
#             Function evaluations: 7074
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4462827385461832e-08
#             Iterations: 39
#             Function evaluations: 3900
#             Gradient evaluations: 39
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.12221225737125e-05
#             Iterations: 205
#             Function evaluations: 20706
#             Gradient evaluations: 205
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.912594063828867
#             Iterations: 73
#             Function evaluations: 7449
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6002049178237268e-08
#             Iterations: 38
#             Function evaluations: 3839
#             Gradient evaluations: 38
# 2006-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4962895079428208e-05
#             Iterations: 189
#             Function evaluations: 19468
#             Gradient evaluations: 189
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.899108679285281
#             Iterations: 68
#             Function evaluations: 7074
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.53148563993075e-08
#             Iterations: 63
#             Function evaluations: 6489
#             Gradient evaluations: 63
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5923912248671503e-05
#             Iterations: 208
#             Function evaluations: 21841
#             Gradient evaluations: 208
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.943031175510135
#             Iterations: 64
#             Function evaluations: 6782
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7484242895014476e-08
#             Iterations: 53
#             Function evaluations: 5566
#             Gradient evaluations: 53
# 2007-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5230041208360814e-05
#             Iterations: 207
#             Function evaluations: 22149
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9650407868733364
#             Iterations: 65
#             Function evaluations: 7022
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3934885128203294e-08
#             Iterations: 75
#             Function evaluations: 8025
#             Gradient evaluations: 75
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.604490964277709e-05
#             Iterations: 183
#             Function evaluations: 18849
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9507720262970665
#             Iterations: 71
#             Function evaluations: 7287
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2942252517095456e-08
#             Iterations: 98
#             Function evaluations: 10095
#             Gradient evaluations: 98
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6825316447927813e-05
#             Iterations: 205
#             Function evaluations: 20910
#             Gradient evaluations: 205
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9808290467349923
#             Iterations: 71
#             Function evaluations: 7315
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0847742894663012e-08
#             Iterations: 120
#             Function evaluations: 12241
#             Gradient evaluations: 120
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.867642616704289e-05
#             Iterations: 206
#             Function evaluations: 21219
#             Gradient evaluations: 206
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.033209007011013
#             Iterations: 66
#             Function evaluations: 6871
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0436595960961896e-08
#             Iterations: 109
#             Function evaluations: 11227
#             Gradient evaluations: 109
# 2007-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8991860361852546e-05
#             Iterations: 207
#             Function evaluations: 20700
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.045777839517085
#             Iterations: 68
#             Function evaluations: 6872
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0327600853411904e-08
#             Iterations: 121
#             Function evaluations: 12100
#             Gradient evaluations: 121
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.939837420831021e-05
#             Iterations: 205
#             Function evaluations: 20705
#             Gradient evaluations: 205
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.981922481893904
#             Iterations: 68
#             Function evaluations: 6942
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0287676711058083e-08
#             Iterations: 121
#             Function evaluations: 12221
#             Gradient evaluations: 121
# 2007-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9946000159954804e-05
#             Iterations: 196
#             Function evaluations: 19601
#             Gradient evaluations: 196
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9877467505227346
#             Iterations: 68
#             Function evaluations: 6867
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.052537546039716e-08
#             Iterations: 120
#             Function evaluations: 12000
#             Gradient evaluations: 120
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0134596285322374e-05
#             Iterations: 183
#             Function evaluations: 18117
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.820959360882917
#             Iterations: 65
#             Function evaluations: 6504
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1177437474743964e-08
#             Iterations: 119
#             Function evaluations: 11781
#             Gradient evaluations: 119
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.99443854369242e-05
#             Iterations: 190
#             Function evaluations: 18621
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.835790378343109
#             Iterations: 67
#             Function evaluations: 6633
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1498505595495534e-08
#             Iterations: 120
#             Function evaluations: 11760
#             Gradient evaluations: 120
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.943396900660962e-05
#             Iterations: 199
#             Function evaluations: 19502
#             Gradient evaluations: 199
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8220850619700193
#             Iterations: 64
#             Function evaluations: 6338
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2342591521139003e-08
#             Iterations: 120
#             Function evaluations: 11760
#             Gradient evaluations: 120
# 2007-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.001169777148512e-05
#             Iterations: 197
#             Function evaluations: 18913
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7854547501248517
#             Iterations: 58
#             Function evaluations: 5628
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2757885825907266e-08
#             Iterations: 120
#             Function evaluations: 11520
#             Gradient evaluations: 120
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9833981704214387e-05
#             Iterations: 212
#             Function evaluations: 20352
#             Gradient evaluations: 212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8050590453768725
#             Iterations: 59
#             Function evaluations: 5722
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.297718499434258e-08
#             Iterations: 120
#             Function evaluations: 11521
#             Gradient evaluations: 120
# 2008-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.995550403006061e-05
#             Iterations: 214
#             Function evaluations: 20330
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.818431212469162
#             Iterations: 57
#             Function evaluations: 5468
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3422577752581977e-08
#             Iterations: 120
#             Function evaluations: 11401
#             Gradient evaluations: 120
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.789267520267972e-05
#             Iterations: 218
#             Function evaluations: 20711
#             Gradient evaluations: 218
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.933600173276093
#             Iterations: 57
#             Function evaluations: 5472
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2532180955177434e-08
#             Iterations: 121
#             Function evaluations: 11495
#             Gradient evaluations: 121
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7858548717750202e-05
#             Iterations: 222
#             Function evaluations: 20868
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9014712151991957
#             Iterations: 57
#             Function evaluations: 5417
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9997386673936584e-08
#             Iterations: 74
#             Function evaluations: 6957
#             Gradient evaluations: 74
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7303922920677862e-05
#             Iterations: 221
#             Function evaluations: 20553
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8851631107342746
#             Iterations: 59
#             Function evaluations: 5547
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2666626255657051e-08
#             Iterations: 120
#             Function evaluations: 11161
#             Gradient evaluations: 120
# 2008-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6343707612317603e-05
#             Iterations: 227
#             Function evaluations: 21111
#             Gradient evaluations: 227
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.906551447519816
#             Iterations: 56
#             Function evaluations: 5264
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0216967736504787e-08
#             Iterations: 74
#             Function evaluations: 6883
#             Gradient evaluations: 74
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5894104523308255e-05
#             Iterations: 221
#             Function evaluations: 20774
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9426945419707025
#             Iterations: 58
#             Function evaluations: 5420
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1987872310997792e-08
#             Iterations: 131
#             Function evaluations: 12314
#             Gradient evaluations: 131
# 2008-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.521433046378554e-05
#             Iterations: 222
#             Function evaluations: 20647
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.960945330432484
#             Iterations: 57
#             Function evaluations: 5363
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.163592037955379e-08
#             Iterations: 142
#             Function evaluations: 13206
#             Gradient evaluations: 142
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6818584772663408e-05
#             Iterations: 222
#             Function evaluations: 20424
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.915472481728858
#             Iterations: 59
#             Function evaluations: 5488
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.75705640679186e-08
#             Iterations: 73
#             Function evaluations: 6717
#             Gradient evaluations: 73
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6167882575719795e-05
#             Iterations: 211
#             Function evaluations: 19413
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9214222604276765
#             Iterations: 96
#             Function evaluations: 8779
#             Gradient evaluations: 92
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8743050915709036e-08
#             Iterations: 62
#             Function evaluations: 5705
#             Gradient evaluations: 62
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2702121665050004e-05
#             Iterations: 219
#             Function evaluations: 19929
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.959083913131924
#             Iterations: 59
#             Function evaluations: 5429
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0074163936293588e-08
#             Iterations: 62
#             Function evaluations: 5643
#             Gradient evaluations: 62
# 2008-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7607479173528356e-05
#             Iterations: 246
#             Function evaluations: 22387
#             Gradient evaluations: 246
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.1253438170666366
#             Iterations: 132
#             Function evaluations: 12265
#             Gradient evaluations: 128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5556719986326286e-08
#             Iterations: 65
#             Function evaluations: 5915
#             Gradient evaluations: 65
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5658441540945277e-05
#             Iterations: 253
#             Function evaluations: 23023
#             Gradient evaluations: 253
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.196547036632263
#             Iterations: 63
#             Function evaluations: 5803
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3308533485787745e-08
#             Iterations: 65
#             Function evaluations: 5916
#             Gradient evaluations: 65
# 2009-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.462238441062134e-05
#             Iterations: 233
#             Function evaluations: 20970
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.134788573632077
#             Iterations: 66
#             Function evaluations: 6013
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2523851754707927e-08
#             Iterations: 66
#             Function evaluations: 5940
#             Gradient evaluations: 66
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4094418465898937e-05
#             Iterations: 246
#             Function evaluations: 22632
#             Gradient evaluations: 246
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.104819519836652
#             Iterations: 65
#             Function evaluations: 6053
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.097220819000136e-08
#             Iterations: 67
#             Function evaluations: 6164
#             Gradient evaluations: 67
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3766634210985771e-05
#             Iterations: 227
#             Function evaluations: 20884
#             Gradient evaluations: 227
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.064056202264648
#             Iterations: 64
#             Function evaluations: 5962
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2087700008578698e-08
#             Iterations: 57
#             Function evaluations: 5244
#             Gradient evaluations: 57
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2722672092321287e-05
#             Iterations: 198
#             Function evaluations: 18018
#             Gradient evaluations: 198
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.081603032767014
#             Iterations: 63
#             Function evaluations: 5801
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.146968360240145e-08
#             Iterations: 57
#             Function evaluations: 5187
#             Gradient evaluations: 57
# 2009-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2328624047714062e-05
#             Iterations: 219
#             Function evaluations: 19710
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.978607675126904
#             Iterations: 62
#             Function evaluations: 5646
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1078726710500424e-08
#             Iterations: 57
#             Function evaluations: 5130
#             Gradient evaluations: 57
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1733127906381763e-05
#             Iterations: 240
#             Function evaluations: 21840
#             Gradient evaluations: 240
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.0150680590524646
#             Iterations: 61
#             Function evaluations: 5619
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0340140183311651e-08
#             Iterations: 57
#             Function evaluations: 5187
#             Gradient evaluations: 57
# 2009-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1274738910947563e-05
#             Iterations: 234
#             Function evaluations: 21528
#             Gradient evaluations: 234
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.032293635222356
#             Iterations: 60
#             Function evaluations: 5585
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1958001024855976e-08
#             Iterations: 45
#             Function evaluations: 4140
#             Gradient evaluations: 45
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.079945755293671e-05
#             Iterations: 207
#             Function evaluations: 19044
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.118621367860547
#             Iterations: 60
#             Function evaluations: 5583
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1279495712571055e-08
#             Iterations: 45
#             Function evaluations: 4140
#             Gradient evaluations: 45
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1765828693839185e-05
#             Iterations: 243
#             Function evaluations: 22356
#             Gradient evaluations: 243
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9966668513717125
#             Iterations: 61
#             Function evaluations: 5679
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.382512458242936e-09
#             Iterations: 45
#             Function evaluations: 4141
#             Gradient evaluations: 45
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1539415856305855e-05
#             Iterations: 232
#             Function evaluations: 21576
#             Gradient evaluations: 232
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.980236019131834
#             Iterations: 63
#             Function evaluations: 5924
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.900453061141012e-09
#             Iterations: 45
#             Function evaluations: 4185
#             Gradient evaluations: 45
# 2009-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.138408718355132e-05
#             Iterations: 234
#             Function evaluations: 21763
#             Gradient evaluations: 234
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.009025764037501
#             Iterations: 63
#             Function evaluations: 5929
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0506751320529162e-08
#             Iterations: 45
#             Function evaluations: 4185
#             Gradient evaluations: 45
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1482897635867462e-05
#             Iterations: 239
#             Function evaluations: 22227
#             Gradient evaluations: 239
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.001677925931718
#             Iterations: 60
#             Function evaluations: 5643
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.45363492261887e-09
#             Iterations: 57
#             Function evaluations: 5302
#             Gradient evaluations: 57
# 2010-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.13722451019006e-05
#             Iterations: 227
#             Function evaluations: 20884
#             Gradient evaluations: 227
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.992895447305351
#             Iterations: 62
#             Function evaluations: 5771
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0463165388695004e-08
#             Iterations: 45
#             Function evaluations: 4141
#             Gradient evaluations: 45
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1447758886407583e-05
#             Iterations: 230
#             Function evaluations: 20700
#             Gradient evaluations: 230
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9168642819215695
#             Iterations: 62
#             Function evaluations: 5641
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0908701027600689e-08
#             Iterations: 45
#             Function evaluations: 4051
#             Gradient evaluations: 45
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1090087476760489e-05
#             Iterations: 250
#             Function evaluations: 22750
#             Gradient evaluations: 250
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.990887377725259
#             Iterations: 64
#             Function evaluations: 5889
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0235704288838494e-08
#             Iterations: 45
#             Function evaluations: 4096
#             Gradient evaluations: 45
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.108976551836516e-05
#             Iterations: 233
#             Function evaluations: 21203
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9977635201829935
#             Iterations: 61
#             Function evaluations: 5615
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0060820790001854e-08
#             Iterations: 45
#             Function evaluations: 4096
#             Gradient evaluations: 45
# 2010-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0535073846689277e-05
#             Iterations: 226
#             Function evaluations: 20792
#             Gradient evaluations: 226
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.023339955855933
#             Iterations: 60
#             Function evaluations: 5578
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0256049902695843e-08
#             Iterations: 45
#             Function evaluations: 4141
#             Gradient evaluations: 45
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0036247704136116e-05
#             Iterations: 220
#             Function evaluations: 19800
#             Gradient evaluations: 220
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.058097852907491
#             Iterations: 64
#             Function evaluations: 5826
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.103043776144284e-09
#             Iterations: 46
#             Function evaluations: 4140
#             Gradient evaluations: 46
# 2010-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0382678581097387e-05
#             Iterations: 202
#             Function evaluations: 18181
#             Gradient evaluations: 202
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.868844084176706
#             Iterations: 62
#             Function evaluations: 5641
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.165311995089923e-08
#             Iterations: 33
#             Function evaluations: 2971
#             Gradient evaluations: 33
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0281255354825908e-05
#             Iterations: 202
#             Function evaluations: 18382
#             Gradient evaluations: 202
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9239993189089506
#             Iterations: 66
#             Function evaluations: 6068
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0815725544300094e-08
#             Iterations: 33
#             Function evaluations: 3004
#             Gradient evaluations: 33
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0576921459758658e-05
#             Iterations: 200
#             Function evaluations: 18200
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9165488335412078
#             Iterations: 67
#             Function evaluations: 6165
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.443464363150276e-09
#             Iterations: 33
#             Function evaluations: 3004
#             Gradient evaluations: 33
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0924695136682888e-05
#             Iterations: 194
#             Function evaluations: 17655
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9198140628910254
#             Iterations: 65
#             Function evaluations: 5985
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.694825836436125e-09
#             Iterations: 33
#             Function evaluations: 3003
#             Gradient evaluations: 33
# 2010-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0229488911755805e-05
#             Iterations: 185
#             Function evaluations: 17390
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.059320355909807
#             Iterations: 65
#             Function evaluations: 6178
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.710582370947745e-09
#             Iterations: 32
#             Function evaluations: 3008
#             Gradient evaluations: 32
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0010281643547643e-05
#             Iterations: 211
#             Function evaluations: 20046
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.114248812784186
#             Iterations: 67
#             Function evaluations: 6436
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.812945471297088e-09
#             Iterations: 32
#             Function evaluations: 3040
#             Gradient evaluations: 32
# 2011-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.977175812093755e-06
#             Iterations: 214
#             Function evaluations: 20330
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.1458468411766365
#             Iterations: 62
#             Function evaluations: 5961
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0075762521114064e-08
#             Iterations: 32
#             Function evaluations: 3040
#             Gradient evaluations: 32
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0212185481410057e-05
#             Iterations: 219
#             Function evaluations: 20587
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.133496879703407
#             Iterations: 65
#             Function evaluations: 6087
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.004191283642546e-08
#             Iterations: 33
#             Function evaluations: 3103
#             Gradient evaluations: 33
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.921144316291287e-06
#             Iterations: 216
#             Function evaluations: 20521
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.22167282609429
#             Iterations: 69
#             Function evaluations: 6635
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.758079863236357e-09
#             Iterations: 34
#             Function evaluations: 3230
#             Gradient evaluations: 34
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.73658324802658e-06
#             Iterations: 219
#             Function evaluations: 20805
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.171031554461446
#             Iterations: 67
#             Function evaluations: 6434
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.981385717597539e-09
#             Iterations: 34
#             Function evaluations: 3230
#             Gradient evaluations: 34
# 2011-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0185949386275719e-05
#             Iterations: 227
#             Function evaluations: 21565
#             Gradient evaluations: 227
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.09460497928149
#             Iterations: 66
#             Function evaluations: 6343
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.365047471996007e-09
#             Iterations: 34
#             Function evaluations: 3230
# ...
#             Current function value: 8.00035371877548e-06
#             Iterations: 392
#             Function evaluations: 50176
#             Gradient evaluations: 392
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.094544407948053
#             Iterations: 87
#             Function evaluations: 11128
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.872199939145391e-08
#             Iterations: 45
#             Function evaluations: 5760
#             Gradient evaluations: 45
# 2021-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.13441561085252e-06
#             Iterations: 412
#             Function evaluations: 53148
#             Gradient evaluations: 412
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.154608752979252
#             Iterations: 120
#             Function evaluations: 15332
#             Gradient evaluations: 116
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8861401516587463e-08
#             Iterations: 45
#             Function evaluations: 5805
#             Gradient evaluations: 45
# 2021-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.060429852204918e-06
#             Iterations: 395
#             Function evaluations: 50955
#             Gradient evaluations: 395
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.241318531451712
#             Iterations: 102
#             Function evaluations: 12877
#             Gradient evaluations: 98
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9038887106890644e-08
#             Iterations: 45
#             Function evaluations: 5805
#             Gradient evaluations: 45
# 2021-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.264502421504863e-06
#             Iterations: 396
#             Function evaluations: 51876
#             Gradient evaluations: 396
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.2146522855449335
#             Iterations: 121
#             Function evaluations: 15702
#             Gradient evaluations: 117
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8281116472319376e-08
#             Iterations: 45
#             Function evaluations: 5895
#             Gradient evaluations: 45
# 2021-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.361021194145177e-06
#             Iterations: 365
#             Function evaluations: 47451
#             Gradient evaluations: 365
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5.150332283243115
#             Iterations: 107
#             Function evaluations: 13627
#             Gradient evaluations: 103
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.765849677585444e-08
#             Iterations: 45
#             Function evaluations: 5850
#             Gradient evaluations: 45
# 2021-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.177104914098722e-06
#             Iterations: 358
#             Function evaluations: 46899
#             Gradient evaluations: 358
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.25976230885995
#             Iterations: 88
#             Function evaluations: 11127
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.768963095580816e-08
#             Iterations: 45
#             Function evaluations: 5895
#             Gradient evaluations: 45
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.474095560585033e-06
#             Iterations: 359
#             Function evaluations: 45952
#             Gradient evaluations: 359
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.052828729081215
#             Iterations: 92
#             Function evaluations: 11442
#             Gradient evaluations: 88
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8712060168077682e-08
#             Iterations: 45
#             Function evaluations: 5760
#             Gradient evaluations: 45
# 2022-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.88374964144961e-06
#             Iterations: 370
#             Function evaluations: 47361
#             Gradient evaluations: 370
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.072499927324513
#             Iterations: 90
#             Function evaluations: 11192
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.90678179308298e-08
#             Iterations: 45
#             Function evaluations: 5760
#             Gradient evaluations: 45
# 2022-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.839427753738668e-06
#             Iterations: 368
#             Function evaluations: 47841
#             Gradient evaluations: 368
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.083019864875754
#             Iterations: 87
#             Function evaluations: 11302
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7485038982070377e-08
#             Iterations: 45
#             Function evaluations: 5850
#             Gradient evaluations: 45
# 2022-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0441661065046047e-05
#             Iterations: 362
#             Function evaluations: 46336
#             Gradient evaluations: 362
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.9379028793057005
#             Iterations: 81
#             Function evaluations: 10478
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.654096075272188e-08
#             Iterations: 44
#             Function evaluations: 5632
#             Gradient evaluations: 44
# 2022-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.19859358629944e-06
#             Iterations: 351
#             Function evaluations: 44928
#             Gradient evaluations: 351
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.182432095834769
#             Iterations: 87
#             Function evaluations: 11127
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5594664541189305e-08
#             Iterations: 42
#             Function evaluations: 5377
#             Gradient evaluations: 42
# 2022-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.487077449096953e-06
#             Iterations: 387
#             Function evaluations: 49924
#             Gradient evaluations: 387
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.097770814210078
#             Iterations: 85
#             Function evaluations: 11084
#             Gradient evaluations: 85
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5062347272954383e-08
#             Iterations: 35
#             Function evaluations: 4515
#             Gradient evaluations: 35
# 2022-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.831025491086646e-06
#             Iterations: 378
#             Function evaluations: 49140
#             Gradient evaluations: 378
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.194820594301028
#             Iterations: 199
#             Function evaluations: 26457
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2122957751474454e-08
#             Iterations: 54
#             Function evaluations: 7021
#             Gradient evaluations: 54
# 2022-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.663185940047932e-06
#             Iterations: 354
#             Function evaluations: 46728
#             Gradient evaluations: 354
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.34263008757891
#             Iterations: 126
#             Function evaluations: 16547
#             Gradient evaluations: 122
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2702217616745327e-08
#             Iterations: 38
#             Function evaluations: 5016
#             Gradient evaluations: 38
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.646912797626804e-06
#             Iterations: 372
#             Function evaluations: 49477
#             Gradient evaluations: 372
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.329558857445096
#             Iterations: 88
#             Function evaluations: 11828
#             Gradient evaluations: 88
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1586677515886318e-08
#             Iterations: 42
#             Function evaluations: 5586
#             Gradient evaluations: 42
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.809483974372788e-06
#             Iterations: 381
#             Function evaluations: 50673
#             Gradient evaluations: 381
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.174620642933962
#             Iterations: 88
#             Function evaluations: 11823
#             Gradient evaluations: 88
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1607472978565177e-08
#             Iterations: 42
#             Function evaluations: 5586
#             Gradient evaluations: 42
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.584305681732505e-06
#             Iterations: 369
#             Function evaluations: 49077
#             Gradient evaluations: 369
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.205913162144178
#             Iterations: 85
#             Function evaluations: 11423
#             Gradient evaluations: 85
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1562450269786542e-08
#             Iterations: 43
#             Function evaluations: 5719
#             Gradient evaluations: 43
# 2022-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.344821267883811e-06
#             Iterations: 369
#             Function evaluations: 49446
#             Gradient evaluations: 369
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.271760955342749
#             Iterations: 86
#             Function evaluations: 11643
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0927111607943177e-08
#             Iterations: 43
#             Function evaluations: 5762
#             Gradient evaluations: 43
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.395996582317136e-06
#             Iterations: 390
#             Function evaluations: 52261
#             Gradient evaluations: 390
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.229254532080386
#             Iterations: 86
#             Function evaluations: 11512
#             Gradient evaluations: 85
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.054402234275208e-08
#             Iterations: 42
#             Function evaluations: 5628
#             Gradient evaluations: 42
# 2023-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.843192579908042e-06
#             Iterations: 400
#             Function evaluations: 53600
#             Gradient evaluations: 400
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.1392406095837595
#             Iterations: 197
#             Function evaluations: 26901
#             Gradient evaluations: 193
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1807460826917439e-08
#             Iterations: 38
#             Function evaluations: 5092
#             Gradient evaluations: 38
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.724759960536637e-06
#             Iterations: 409
#             Function evaluations: 54807
#             Gradient evaluations: 409
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.130130703088078
#             Iterations: 85
#             Function evaluations: 11376
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1284627766068954e-08
#             Iterations: 40
#             Function evaluations: 5360
#             Gradient evaluations: 40
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.675170915706876e-06
#             Iterations: 411
#             Function evaluations: 54663
#             Gradient evaluations: 411
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.116781997691283
#             Iterations: 198
#             Function evaluations: 26871
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1706323901323884e-08
#             Iterations: 42
#             Function evaluations: 5586
#             Gradient evaluations: 42
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.4416055660063235e-06
#             Iterations: 444
#             Function evaluations: 59496
#             Gradient evaluations: 444
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.2153538095569925
#             Iterations: 87
#             Function evaluations: 11779
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1313596497677962e-08
#             Iterations: 41
#             Function evaluations: 5494
#             Gradient evaluations: 41
# 2023-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.952463836923111e-06
#             Iterations: 416
#             Function evaluations: 56576
#             Gradient evaluations: 416
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.800716187803112
#             Iterations: 143
#             Function evaluations: 19464
#             Gradient evaluations: 139
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5455238966653575e-08
#             Iterations: 40
#             Function evaluations: 5440
#             Gradient evaluations: 40
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_JSE.to_csv("returnsWharton_neu_2jahre_f.csv")

# %% [markdown]
# ## Ledoit-Wolf Shrinkage

# %%
#Definition von Ledoit-Shrinkage

def ledoit_shrink (returns):
    
    shrinkage = LedoitWolf().fit(returns.values)
    
    shrinkage_matrix = pd.DataFrame(
        shrinkage.covariance_,
        index = returns.columns,
        columns = returns.columns)
    
    #print(shrinkage.shrinkage_)
    
    return shrinkage_matrix

# %% [markdown]
# ### Auswertung S&P500 mit Ledoit Wolf

# %% [markdown]
# ### Auswertung JSE mit Ledoit Wolf

# %%
returns = df_JSE.pct_change()
returns = returns.where(~df_JSE.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                 8303     15604     15618     16179     16183     16291  \
# Date
# 2005-06-02 -0.005128 -0.001771  0.006711  0.000690 -0.010465 -0.004525
# 2005-06-03 -0.023110 -0.019516  0.008533 -0.000689 -0.001175 -0.006818
# 2005-06-06 -0.023657 -0.000658  0.037678 -0.044828  0.014118  0.002288
# 2005-06-07 -0.024230  0.002469 -0.007517  0.002888  0.005800  0.011416
# 2005-06-08 -0.027970 -0.003284 -0.005135  0.006479  0.014994  0.006772
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26       NaN       NaN  0.013928       NaN -0.001542       NaN
# 2025-05-27       NaN       NaN -0.003930       NaN  0.010039       NaN
# 2025-05-28       NaN       NaN  0.004102       NaN  0.001529       NaN
# 2025-05-29       NaN       NaN  0.010933       NaN  0.016794       NaN
# 2025-05-30       NaN       NaN -0.016665       NaN  0.012763       NaN
#
#                16305     16355     16356     16610  ...    364340    364439  \
# Date                                                ...
# 2005-06-02  0.001214 -0.015075 -0.008475  0.000000  ...       NaN       NaN
# 2005-06-03  0.001333  0.010204  0.000000 -0.020270  ...       NaN       NaN
# 2005-06-06  0.003510  0.000000  0.004274 -0.010345  ...       NaN       NaN
# 2005-06-07  0.006634  0.000000  0.000000 -0.031359  ...       NaN       NaN
# 2005-06-08 -0.005392  0.000000  0.000000 -0.027158  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-26  0.007235       NaN -0.020518 -0.023906  ...  0.003574  0.010753
# 2025-05-27  0.000178       NaN  0.011664 -0.014960  ...  0.006748  0.004836
# 2025-05-28  0.026828       NaN -0.010118 -0.017033  ...  0.004655  0.000962
# 2025-05-29  0.016127       NaN  0.014500 -0.006117  ... -0.005004 -0.006731
# 2025-05-30 -0.014051       NaN  0.030928 -0.020991  ...  0.007823  0.011617
#
#               364518    364519    364717    365459    365648    366651  \
# Date
# 2005-06-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26  0.009643  0.018182  0.000000  0.011535  0.000395  0.006231
# 2025-05-27  0.001910  0.008929  0.000999  0.002479  0.000099  0.007224
# 2025-05-28  0.005720  0.014749  0.002994  0.000495  0.000494  0.003074
# 2025-05-29  0.000000 -0.006783 -0.005970 -0.007415  0.000395  0.003064
# 2025-05-30  0.002844  0.005854  0.013013  0.013446  0.000000  0.012220
#
#               366185    366905
# Date
# 2005-06-02       NaN       NaN
# 2005-06-03       NaN       NaN
# 2005-06-06       NaN       NaN
# 2005-06-07       NaN       NaN
# 2005-06-08       NaN       NaN
# ...              ...       ...
# 2025-05-26 -0.000984  0.000000
# 2025-05-27  0.000000  0.000000
# 2025-05-28  0.000000  0.000000
# 2025-05-29  0.015764  0.001008
# 2025-05-30  0.000970  0.000000
#
# [5172 rows x 350 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 24
test_fenster = 1
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
     #Inf-Werte in NaN umwandeln
    training_daten = training_daten.replace([np.inf, -np.inf], np.nan)
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 126
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = ledoit_shrink(training_daten)
    
    #aus der geschrumpften Matrix die Korrelationsmatrix bauen
    standardabweichung = np.sqrt(np.diag(cov_matrix))
    corr_matrix = cov_matrix / np.outer(standardabweichung, standardabweichung)
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    shrinked_JSE_gewichte_equally_weighted = equally_weighted(training_daten)
    shrinked_JSE_gewichte_min_variance= min_variance_opt(cov_matrix)
    shrinked_JSE_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    shrinked_JSE_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    shrinked_JSE_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    shrinked_JSE_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    shrinked_JSE_gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": shrinked_JSE_gewichte_equally_weighted,
    "Minimum-Variance": shrinked_JSE_gewichte_min_variance,
    "Maximum-Diversification": shrinked_JSE_gewichte_max_diversification,
    "Inverse-Volatility": shrinked_JSE_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": shrinked_JSE_gewichte_risk_parity,
    "HRP": shrinked_JSE_gewichte_hrp,
    "HERC": shrinked_JSE_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
    #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_shrinked_JSE = pd.concat(portfolio_returns_list)
portfolio_returns_df_shrinked_JSE = portfolio_returns_df_shrinked_JSE.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0262572115039524e-05
#             Iterations: 168
#             Function evaluations: 15624
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9083956900557366
#             Iterations: 66
#             Function evaluations: 6206
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.338491895132295e-09
#             Iterations: 42
#             Function evaluations: 3907
#             Gradient evaluations: 42
# 2005-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.145187159505793e-05
#             Iterations: 181
#             Function evaluations: 16652
#             Gradient evaluations: 181
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8885638411058845
#             Iterations: 64
#             Function evaluations: 5954
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.849507219632559e-09
#             Iterations: 54
#             Function evaluations: 4969
#             Gradient evaluations: 54
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2814529397140565e-05
#             Iterations: 167
#             Function evaluations: 15197
#             Gradient evaluations: 167
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8496115918994906
#             Iterations: 68
#             Function evaluations: 6258
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.964391778623462e-09
#             Iterations: 38
#             Function evaluations: 3459
#             Gradient evaluations: 38
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3108566658914022e-05
#             Iterations: 185
#             Function evaluations: 17760
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.892116400381
#             Iterations: 68
#             Function evaluations: 6604
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.561501265862919e-09
#             Iterations: 40
#             Function evaluations: 3840
#             Gradient evaluations: 40
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.338191568694831e-05
#             Iterations: 168
#             Function evaluations: 15960
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.850178379964704
#             Iterations: 67
#             Function evaluations: 6435
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.215305571609196e-09
#             Iterations: 38
#             Function evaluations: 3611
#             Gradient evaluations: 38
# 2005-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.288714992360888e-05
#             Iterations: 174
#             Function evaluations: 16704
#             Gradient evaluations: 174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8474733733440236
#             Iterations: 70
#             Function evaluations: 6790
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.620848476931686e-09
#             Iterations: 38
#             Function evaluations: 3648
#             Gradient evaluations: 38
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.304173646284304e-05
#             Iterations: 159
#             Function evaluations: 15583
#             Gradient evaluations: 159
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.815760844428427
#             Iterations: 72
#             Function evaluations: 7127
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.253520369594684e-09
#             Iterations: 38
#             Function evaluations: 3725
#             Gradient evaluations: 38
# 2006-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3193332944806958e-05
#             Iterations: 168
#             Function evaluations: 16800
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9020599027607092
#             Iterations: 70
#             Function evaluations: 7073
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.022578774606432e-09
#             Iterations: 42
#             Function evaluations: 4201
#             Gradient evaluations: 42
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3434930806682497e-05
#             Iterations: 177
#             Function evaluations: 18055
#             Gradient evaluations: 177
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8027265933580217
#             Iterations: 71
#             Function evaluations: 7315
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1388192566354565e-08
#             Iterations: 43
#             Function evaluations: 4387
#             Gradient evaluations: 43
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3473447249026887e-05
#             Iterations: 170
#             Function evaluations: 17340
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.819286622757626
#             Iterations: 69
#             Function evaluations: 7115
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.946022129857527e-09
#             Iterations: 57
#             Function evaluations: 5814
#             Gradient evaluations: 57
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4009795683916816e-05
#             Iterations: 184
#             Function evaluations: 19137
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8211542203448285
#             Iterations: 66
#             Function evaluations: 6937
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1576711032983103e-08
#             Iterations: 39
#             Function evaluations: 4056
#             Gradient evaluations: 39
# 2006-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.436556056175378e-05
#             Iterations: 197
#             Function evaluations: 20094
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7905431113805013
#             Iterations: 65
#             Function evaluations: 6700
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0140079508166843e-08
#             Iterations: 51
#             Function evaluations: 5202
#             Gradient evaluations: 51
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3961863702525207e-05
#             Iterations: 186
#             Function evaluations: 18786
#             Gradient evaluations: 186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8850178193239913
#             Iterations: 70
#             Function evaluations: 7144
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.017464399662424e-08
#             Iterations: 56
#             Function evaluations: 5656
#             Gradient evaluations: 56
# 2006-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0996215070808544e-05
#             Iterations: 168
#             Function evaluations: 16968
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.1065965982469095
#             Iterations: 77
#             Function evaluations: 7871
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1816767883298925e-08
#             Iterations: 43
#             Function evaluations: 4343
#             Gradient evaluations: 43
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2541747234250058e-05
#             Iterations: 171
#             Function evaluations: 17101
#             Gradient evaluations: 171
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.031251121265595
#             Iterations: 76
#             Function evaluations: 7693
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.142790661709503e-08
#             Iterations: 39
#             Function evaluations: 3900
#             Gradient evaluations: 39
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.344020695261215e-05
#             Iterations: 156
#             Function evaluations: 15600
#             Gradient evaluations: 156
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.020436221455536
#             Iterations: 78
#             Function evaluations: 7888
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1976422861646037e-08
#             Iterations: 39
#             Function evaluations: 3900
#             Gradient evaluations: 39
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3978796280964678e-05
#             Iterations: 175
#             Function evaluations: 17675
#             Gradient evaluations: 175
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.033333629378309
#             Iterations: 76
#             Function evaluations: 7765
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3786754670243207e-08
#             Iterations: 42
#             Function evaluations: 4243
#             Gradient evaluations: 42
# 2006-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.898525338671508e-05
#             Iterations: 170
#             Function evaluations: 17510
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9746683935960365
#             Iterations: 73
#             Function evaluations: 7597
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3003750645203846e-08
#             Iterations: 63
#             Function evaluations: 6490
#             Gradient evaluations: 63
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9870976827746312e-05
#             Iterations: 178
#             Function evaluations: 18691
#             Gradient evaluations: 178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.009556222445687
#             Iterations: 70
#             Function evaluations: 7425
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1803511165837926e-08
#             Iterations: 76
#             Function evaluations: 7980
#             Gradient evaluations: 76
# 2007-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9392670734585446e-05
#             Iterations: 178
#             Function evaluations: 19046
#             Gradient evaluations: 178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.035124781192661
#             Iterations: 69
#             Function evaluations: 7461
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3998446843234533e-08
#             Iterations: 63
#             Function evaluations: 6741
#             Gradient evaluations: 63
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0147988675526194e-05
#             Iterations: 176
#             Function evaluations: 18128
#             Gradient evaluations: 176
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.021387847447007
#             Iterations: 74
#             Function evaluations: 7703
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3692687916962858e-08
#             Iterations: 74
#             Function evaluations: 7622
#             Gradient evaluations: 74
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1211677498637395e-05
#             Iterations: 176
#             Function evaluations: 17953
#             Gradient evaluations: 176
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.051284772703177
#             Iterations: 70
#             Function evaluations: 7214
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4900428013421148e-08
#             Iterations: 75
#             Function evaluations: 7650
#             Gradient evaluations: 75
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2994920162007926e-05
#             Iterations: 159
#             Function evaluations: 16377
#             Gradient evaluations: 159
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.108417353832801
#             Iterations: 68
#             Function evaluations: 7079
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3580401871645263e-08
#             Iterations: 76
#             Function evaluations: 7829
#             Gradient evaluations: 76
# 2007-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.32236661631025e-05
#             Iterations: 165
#             Function evaluations: 16500
#             Gradient evaluations: 165
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.113033167924311
#             Iterations: 68
#             Function evaluations: 6877
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.817025174050218e-09
#             Iterations: 110
#             Function evaluations: 11001
#             Gradient evaluations: 110
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.377629527841089e-05
#             Iterations: 180
#             Function evaluations: 18180
#             Gradient evaluations: 180
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.053252815852334
#             Iterations: 70
#             Function evaluations: 7152
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0818432022652659e-08
#             Iterations: 99
#             Function evaluations: 10000
#             Gradient evaluations: 99
# 2007-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.38981629247908e-05
#             Iterations: 165
#             Function evaluations: 16501
#             Gradient evaluations: 165
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.057952049057705
#             Iterations: 73
#             Function evaluations: 7378
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.004819596358127e-08
#             Iterations: 110
#             Function evaluations: 11000
#             Gradient evaluations: 110
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.323356664523269e-05
#             Iterations: 150
#             Function evaluations: 14850
#             Gradient evaluations: 150
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.87395795389189
#             Iterations: 66
#             Function evaluations: 6606
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0742601438994984e-08
#             Iterations: 109
#             Function evaluations: 10791
#             Gradient evaluations: 109
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2887780592648474e-05
#             Iterations: 172
#             Function evaluations: 16856
#             Gradient evaluations: 172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.885205503734627
#             Iterations: 68
#             Function evaluations: 6740
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1045700401763644e-08
#             Iterations: 109
#             Function evaluations: 10683
#             Gradient evaluations: 109
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.270680830502888e-05
#             Iterations: 178
#             Function evaluations: 17444
#             Gradient evaluations: 178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8692456864951135
#             Iterations: 67
#             Function evaluations: 6640
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1623687740674464e-08
#             Iterations: 110
#             Function evaluations: 10781
#             Gradient evaluations: 110
# 2007-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.29536807396147e-05
#             Iterations: 180
#             Function evaluations: 17280
#             Gradient evaluations: 180
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8317025211637996
#             Iterations: 65
#             Function evaluations: 6307
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2268134075372705e-08
#             Iterations: 109
#             Function evaluations: 10465
#             Gradient evaluations: 109
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2744483350402194e-05
#             Iterations: 185
#             Function evaluations: 17761
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8468583002768404
#             Iterations: 66
#             Function evaluations: 6404
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1524765630845177e-08
#             Iterations: 120
#             Function evaluations: 11520
#             Gradient evaluations: 120
# 2008-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.309687860164698e-05
#             Iterations: 198
#             Function evaluations: 18810
#             Gradient evaluations: 198
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.861417851199933
#             Iterations: 64
#             Function evaluations: 6146
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1846804488898782e-08
#             Iterations: 120
#             Function evaluations: 11400
#             Gradient evaluations: 120
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.091236518241128e-05
#             Iterations: 183
#             Function evaluations: 17385
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.974262049047263
#             Iterations: 64
#             Function evaluations: 6148
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0964017419825706e-08
#             Iterations: 121
#             Function evaluations: 11496
#             Gradient evaluations: 121
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.090162621822404e-05
#             Iterations: 192
#             Function evaluations: 18048
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9411463387062655
#             Iterations: 62
#             Function evaluations: 5894
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.762995802194043e-08
#             Iterations: 75
#             Function evaluations: 7051
#             Gradient evaluations: 75
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0392206057057467e-05
#             Iterations: 191
#             Function evaluations: 17764
#             Gradient evaluations: 191
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.929961057891699
#             Iterations: 62
#             Function evaluations: 5828
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.09362117924673e-08
#             Iterations: 121
#             Function evaluations: 11253
#             Gradient evaluations: 121
# 2008-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.921372628580253e-05
#             Iterations: 197
#             Function evaluations: 18321
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.943353555926271
#             Iterations: 61
#             Function evaluations: 5741
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7828764531444864e-08
#             Iterations: 75
#             Function evaluations: 6976
#             Gradient evaluations: 75
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8786884056852977e-05
#             Iterations: 200
#             Function evaluations: 18801
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.962403253390212
#             Iterations: 63
#             Function evaluations: 5992
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1430408971164633e-08
#             Iterations: 121
#             Function evaluations: 11374
#             Gradient evaluations: 121
# 2008-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8053096444969595e-05
#             Iterations: 196
#             Function evaluations: 18228
#             Gradient evaluations: 196
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9794430372057605
#             Iterations: 59
#             Function evaluations: 5551
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2207714455061583e-08
#             Iterations: 120
#             Function evaluations: 11160
#             Gradient evaluations: 120
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9153957136539266e-05
#             Iterations: 170
#             Function evaluations: 15640
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.93480515883266
#             Iterations: 62
#             Function evaluations: 5675
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6080400982761468e-08
#             Iterations: 74
#             Function evaluations: 6808
#             Gradient evaluations: 74
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8544456541054523e-05
#             Iterations: 171
#             Function evaluations: 15732
#             Gradient evaluations: 171
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.937432094913916
#             Iterations: 60
#             Function evaluations: 5586
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7058292292456144e-08
#             Iterations: 62
#             Function evaluations: 5705
#             Gradient evaluations: 62
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5797220757069828e-05
#             Iterations: 187
#             Function evaluations: 17017
#             Gradient evaluations: 187
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9679255921717744
#             Iterations: 63
#             Function evaluations: 5796
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8188828330772636e-08
#             Iterations: 62
#             Function evaluations: 5642
#             Gradient evaluations: 62
# 2008-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9517708078765885e-05
#             Iterations: 200
#             Function evaluations: 18201
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.175751010857421
#             Iterations: 69
#             Function evaluations: 6353
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4027207925184485e-08
#             Iterations: 65
#             Function evaluations: 5915
#             Gradient evaluations: 65
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.742319868857448e-05
#             Iterations: 198
#             Function evaluations: 18018
#             Gradient evaluations: 198
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.242267547444119
#             Iterations: 67
#             Function evaluations: 6170
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2246723157095321e-08
#             Iterations: 67
#             Function evaluations: 6098
#             Gradient evaluations: 67
# 2009-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.588302631632499e-05
#             Iterations: 185
#             Function evaluations: 16650
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.190474169758502
#             Iterations: 71
#             Function evaluations: 6477
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1085436048165845e-08
#             Iterations: 67
#             Function evaluations: 6030
#             Gradient evaluations: 67
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.528644149374846e-05
#             Iterations: 204
#             Function evaluations: 18769
#             Gradient evaluations: 204
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.166361735781214
#             Iterations: 71
#             Function evaluations: 6612
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1411484147473033e-08
#             Iterations: 56
#             Function evaluations: 5153
#             Gradient evaluations: 56
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4738668022121869e-05
#             Iterations: 186
#             Function evaluations: 17112
#             Gradient evaluations: 186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.146151579760045
#             Iterations: 66
#             Function evaluations: 6151
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.254075976653943e-08
#             Iterations: 45
#             Function evaluations: 4140
#             Gradient evaluations: 45
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.366407189527899e-05
#             Iterations: 173
#             Function evaluations: 15743
#             Gradient evaluations: 173
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.1641509481289445
#             Iterations: 71
#             Function evaluations: 6538
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2644445101653129e-08
#             Iterations: 45
#             Function evaluations: 4096
#             Gradient evaluations: 45
# 2009-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3059457017337004e-05
#             Iterations: 202
#             Function evaluations: 18180
#             Gradient evaluations: 202
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.050937153678146
#             Iterations: 64
#             Function evaluations: 5835
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2485003310410983e-08
#             Iterations: 45
#             Function evaluations: 4051
#             Gradient evaluations: 45
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2300053692637787e-05
#             Iterations: 208
#             Function evaluations: 18929
#             Gradient evaluations: 208
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.077829881928111
#             Iterations: 64
#             Function evaluations: 5893
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.237919393283631e-08
#             Iterations: 45
#             Function evaluations: 4096
#             Gradient evaluations: 45
# 2009-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1759467813244625e-05
#             Iterations: 209
#             Function evaluations: 19228
#             Gradient evaluations: 209
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.082384821897027
#             Iterations: 62
#             Function evaluations: 5774
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.085162003634942e-08
#             Iterations: 45
#             Function evaluations: 4140
#             Gradient evaluations: 45
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1224917636279115e-05
#             Iterations: 185
#             Function evaluations: 17020
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.1695995900307405
#             Iterations: 64
#             Function evaluations: 5959
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0231938721862698e-08
#             Iterations: 45
#             Function evaluations: 4140
#             Gradient evaluations: 45
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2152024488971108e-05
#             Iterations: 247
#             Function evaluations: 22724
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.048825273105257
#             Iterations: 63
#             Function evaluations: 5866
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.649661364926655e-09
#             Iterations: 45
#             Function evaluations: 4141
#             Gradient evaluations: 45
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.191782996340746e-05
#             Iterations: 224
#             Function evaluations: 20832
#             Gradient evaluations: 224
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.039923485163888
#             Iterations: 61
#             Function evaluations: 5746
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.178648783077087e-09
#             Iterations: 45
#             Function evaluations: 4185
#             Gradient evaluations: 45
# 2009-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1697151391484886e-05
#             Iterations: 211
#             Function evaluations: 19624
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.065852061273185
#             Iterations: 63
#             Function evaluations: 5928
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.752363303095715e-09
#             Iterations: 45
#             Function evaluations: 4185
#             Gradient evaluations: 45
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1734787973893505e-05
#             Iterations: 191
#             Function evaluations: 17763
#             Gradient evaluations: 191
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.055046330548892
#             Iterations: 62
#             Function evaluations: 5830
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.812676503158959e-09
#             Iterations: 45
#             Function evaluations: 4186
#             Gradient evaluations: 45
# 2010-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1568183758582717e-05
#             Iterations: 194
#             Function evaluations: 17848
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.045612430521617
#             Iterations: 60
#             Function evaluations: 5584
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.762955224214535e-09
#             Iterations: 45
#             Function evaluations: 4140
#             Gradient evaluations: 45
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1592673549112191e-05
#             Iterations: 211
#             Function evaluations: 18990
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.96594185064766
#             Iterations: 66
#             Function evaluations: 5915
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0215399643438444e-08
#             Iterations: 45
#             Function evaluations: 4050
#             Gradient evaluations: 45
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1237557553017255e-05
#             Iterations: 231
#             Function evaluations: 21021
#             Gradient evaluations: 231
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.037605170041754
#             Iterations: 64
#             Function evaluations: 5890
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.583098284390032e-09
#             Iterations: 45
#             Function evaluations: 4095
#             Gradient evaluations: 45
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1231834400589746e-05
#             Iterations: 211
#             Function evaluations: 19201
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.044110167892875
#             Iterations: 62
#             Function evaluations: 5708
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.439976722397887e-09
#             Iterations: 45
#             Function evaluations: 4095
#             Gradient evaluations: 45
# 2010-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0690558777110751e-05
#             Iterations: 209
#             Function evaluations: 19228
#             Gradient evaluations: 209
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.070487900764316
#             Iterations: 59
#             Function evaluations: 5491
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.60287849254836e-09
#             Iterations: 45
#             Function evaluations: 4141
#             Gradient evaluations: 45
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0112522358938624e-05
#             Iterations: 183
#             Function evaluations: 16471
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.116112585453035
#             Iterations: 69
#             Function evaluations: 6286
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.14230195976471e-08
#             Iterations: 33
#             Function evaluations: 2971
#             Gradient evaluations: 33
# 2010-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.040330158716712e-05
#             Iterations: 202
#             Function evaluations: 18180
#             Gradient evaluations: 202
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.925862219571589
#             Iterations: 66
#             Function evaluations: 6011
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.07748682653264e-08
#             Iterations: 33
#             Function evaluations: 2971
#             Gradient evaluations: 33
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0286996530054137e-05
#             Iterations: 201
#             Function evaluations: 18291
#             Gradient evaluations: 201
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9853315660168755
#             Iterations: 67
#             Function evaluations: 6077
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.941910158324518e-09
#             Iterations: 33
#             Function evaluations: 3003
#             Gradient evaluations: 33
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0536304813068771e-05
#             Iterations: 201
#             Function evaluations: 18291
#             Gradient evaluations: 201
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9807553172523726
#             Iterations: 68
#             Function evaluations: 6263
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.618454990741709e-09
#             Iterations: 33
#             Function evaluations: 3003
#             Gradient evaluations: 33
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0883213618571244e-05
#             Iterations: 183
#             Function evaluations: 16653
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9917997730958708
#             Iterations: 69
#             Function evaluations: 6352
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.864001278902829e-09
#             Iterations: 33
#             Function evaluations: 3003
#             Gradient evaluations: 33
# 2010-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0251293357591637e-05
#             Iterations: 171
#             Function evaluations: 16074
#             Gradient evaluations: 171
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.138207167861398
#             Iterations: 68
#             Function evaluations: 6464
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.75156390125873e-09
#             Iterations: 34
#             Function evaluations: 3196
#             Gradient evaluations: 34
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.006044854129191e-05
#             Iterations: 190
#             Function evaluations: 18050
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.1898896359963835
#             Iterations: 70
#             Function evaluations: 6730
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.817496764507652e-09
#             Iterations: 34
#             Function evaluations: 3230
#             Gradient evaluations: 34
# 2011-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0018384212736504e-05
#             Iterations: 214
#             Function evaluations: 20330
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.219790332876843
#             Iterations: 71
#             Function evaluations: 6826
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.061405101872313e-09
#             Iterations: 34
#             Function evaluations: 3230
#             Gradient evaluations: 34
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0221645980159446e-05
#             Iterations: 195
#             Function evaluations: 18331
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.205788968219676
#             Iterations: 70
#             Function evaluations: 6664
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.032208182324126e-09
#             Iterations: 34
#             Function evaluations: 3196
#             Gradient evaluations: 34
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.937045947678892e-06
#             Iterations: 206
#             Function evaluations: 19570
#             Gradient evaluations: 206
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.297648780447359
#             Iterations: 73
#             Function evaluations: 7017
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.733353971226727e-09
#             Iterations: 34
#             Function evaluations: 3230
#             Gradient evaluations: 34
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.770878957798619e-06
#             Iterations: 204
#             Function evaluations: 19381
#             Gradient evaluations: 204
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.246357542215443
#             Iterations: 71
#             Function evaluations: 6831
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.312226356606612e-08
#             Iterations: 22
#             Function evaluations: 2090
#             Gradient evaluations: 22
# 2011-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0202013342039403e-05
#             Iterations: 184
#             Function evaluations: 17480
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.174941024041147
#             Iterations: 69
#             Function evaluations: 6631
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2511315907680223e-08
#             Iterations: 22
#             Function evaluations: 2091
# ...
#             Current function value: 1.2848270750248e-05
#             Iterations: 266
#             Function evaluations: 34048
#             Gradient evaluations: 266
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.215777881968494
#             Iterations: 88
#             Function evaluations: 11269
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.825174239421158e-08
#             Iterations: 33
#             Function evaluations: 4225
#             Gradient evaluations: 33
# 2021-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2937110425557538e-05
#             Iterations: 271
#             Function evaluations: 34960
#             Gradient evaluations: 271
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.26421560204673
#             Iterations: 88
#             Function evaluations: 11357
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6395770455410275e-08
#             Iterations: 45
#             Function evaluations: 5805
#             Gradient evaluations: 45
# 2021-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2564763267343516e-05
#             Iterations: 279
#             Function evaluations: 35991
#             Gradient evaluations: 279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.349739688004533
#             Iterations: 92
#             Function evaluations: 11996
#             Gradient evaluations: 92
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6354625847265384e-08
#             Iterations: 45
#             Function evaluations: 5805
#             Gradient evaluations: 45
# 2021-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2555792340601012e-05
#             Iterations: 256
#             Function evaluations: 33537
#             Gradient evaluations: 256
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.329195006424354
#             Iterations: 94
#             Function evaluations: 11920
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5675417101167045e-08
#             Iterations: 45
#             Function evaluations: 5895
#             Gradient evaluations: 45
# 2021-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.207659509258336e-05
#             Iterations: 272
#             Function evaluations: 35361
#             Gradient evaluations: 272
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.238732695101166
#             Iterations: 82
#             Function evaluations: 10779
#             Gradient evaluations: 82
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.795824483458156e-08
#             Iterations: 33
#             Function evaluations: 4291
#             Gradient evaluations: 33
# 2021-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1867718458156022e-05
#             Iterations: 255
#             Function evaluations: 33406
#             Gradient evaluations: 255
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.315533743592712
#             Iterations: 81
#             Function evaluations: 10732
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5685119715893274e-08
#             Iterations: 45
#             Function evaluations: 5895
#             Gradient evaluations: 45
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1990030747127441e-05
#             Iterations: 251
#             Function evaluations: 32128
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.130111516203622
#             Iterations: 81
#             Function evaluations: 10481
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6746462305961375e-08
#             Iterations: 45
#             Function evaluations: 5760
#             Gradient evaluations: 45
# 2022-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2285982716099409e-05
#             Iterations: 288
#             Function evaluations: 36865
#             Gradient evaluations: 288
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.1444393621017985
#             Iterations: 177
#             Function evaluations: 23049
#             Gradient evaluations: 173
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7091101384822473e-08
#             Iterations: 45
#             Function evaluations: 5760
#             Gradient evaluations: 45
# 2022-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2275726928691966e-05
#             Iterations: 282
#             Function evaluations: 36661
#             Gradient evaluations: 282
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.171689902133842
#             Iterations: 148
#             Function evaluations: 19328
#             Gradient evaluations: 144
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5531049320545128e-08
#             Iterations: 45
#             Function evaluations: 5850
#             Gradient evaluations: 45
# 2022-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3185175761706875e-05
#             Iterations: 254
#             Function evaluations: 32513
#             Gradient evaluations: 254
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.036155713973607
#             Iterations: 97
#             Function evaluations: 12094
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4631425515042718e-08
#             Iterations: 45
#             Function evaluations: 5760
#             Gradient evaluations: 45
# 2022-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.186288485054798e-05
#             Iterations: 268
#             Function evaluations: 34304
#             Gradient evaluations: 268
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.2605773280602515
#             Iterations: 86
#             Function evaluations: 11003
#             Gradient evaluations: 85
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3668550122485453e-08
#             Iterations: 43
#             Function evaluations: 5504
#             Gradient evaluations: 43
# 2022-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2085623420459946e-05
#             Iterations: 248
#             Function evaluations: 31992
#             Gradient evaluations: 248
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.188992589596225
#             Iterations: 93
#             Function evaluations: 11608
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3199028228079106e-08
#             Iterations: 40
#             Function evaluations: 5161
#             Gradient evaluations: 40
# 2022-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.142033611250072e-05
#             Iterations: 257
#             Function evaluations: 33410
#             Gradient evaluations: 257
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.281838404252842
#             Iterations: 90
#             Function evaluations: 11831
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1850195658707431e-08
#             Iterations: 43
#             Function evaluations: 5590
#             Gradient evaluations: 43
# 2022-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1082965312099418e-05
#             Iterations: 258
#             Function evaluations: 34057
#             Gradient evaluations: 258
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.434889960207101
#             Iterations: 86
#             Function evaluations: 11482
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.083141509111815e-08
#             Iterations: 41
#             Function evaluations: 5412
#             Gradient evaluations: 41
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1042463191435094e-05
#             Iterations: 271
#             Function evaluations: 36044
#             Gradient evaluations: 271
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.42062399296273
#             Iterations: 87
#             Function evaluations: 11572
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2082462358410724e-08
#             Iterations: 30
#             Function evaluations: 3990
#             Gradient evaluations: 30
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1275559250674986e-05
#             Iterations: 270
#             Function evaluations: 35910
#             Gradient evaluations: 270
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.282147450212769
#             Iterations: 92
#             Function evaluations: 12367
#             Gradient evaluations: 92
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.211730200095789e-08
#             Iterations: 30
#             Function evaluations: 3990
#             Gradient evaluations: 30
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0889750474230413e-05
#             Iterations: 272
#             Function evaluations: 36177
#             Gradient evaluations: 272
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.316028405810312
#             Iterations: 92
#             Function evaluations: 12366
#             Gradient evaluations: 92
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2213842687742868e-08
#             Iterations: 30
#             Function evaluations: 3990
#             Gradient evaluations: 30
# 2022-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0557122244253183e-05
#             Iterations: 278
#             Function evaluations: 37252
#             Gradient evaluations: 278
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.387015898192852
#             Iterations: 90
#             Function evaluations: 12194
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1543243426703216e-08
#             Iterations: 28
#             Function evaluations: 3752
#             Gradient evaluations: 28
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0511990484496364e-05
#             Iterations: 295
#             Function evaluations: 39531
#             Gradient evaluations: 295
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.348243297738249
#             Iterations: 94
#             Function evaluations: 12600
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1104598645153818e-08
#             Iterations: 27
#             Function evaluations: 3618
#             Gradient evaluations: 27
# 2023-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.718861007262598e-06
#             Iterations: 291
#             Function evaluations: 38994
#             Gradient evaluations: 291
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.264879416281165
#             Iterations: 91
#             Function evaluations: 12329
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.268989183161459e-08
#             Iterations: 25
#             Function evaluations: 3350
#             Gradient evaluations: 25
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.516783378244341e-06
#             Iterations: 316
#             Function evaluations: 42345
#             Gradient evaluations: 316
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.24937957997103
#             Iterations: 111
#             Function evaluations: 14554
#             Gradient evaluations: 107
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.854787783749304e-09
#             Iterations: 37
#             Function evaluations: 4958
#             Gradient evaluations: 37
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.446961113053232e-06
#             Iterations: 332
#             Function evaluations: 44156
#             Gradient evaluations: 332
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.230316405913598
#             Iterations: 92
#             Function evaluations: 12363
#             Gradient evaluations: 92
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0243673560896564e-08
#             Iterations: 42
#             Function evaluations: 5586
#             Gradient evaluations: 42
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.019840618785852e-06
#             Iterations: 304
#             Function evaluations: 40737
#             Gradient evaluations: 304
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.337115197262525
#             Iterations: 94
#             Function evaluations: 12735
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.81810702134027e-09
#             Iterations: 40
#             Function evaluations: 5360
#             Gradient evaluations: 40
# 2023-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.801948902890165e-06
#             Iterations: 321
#             Function evaluations: 43656
#             Gradient evaluations: 321
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.906280295361449
#             Iterations: 90
#             Function evaluations: 12224
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3916221625623542e-08
#             Iterations: 42
#             Function evaluations: 5713
#             Gradient evaluations: 42
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_shrinked_JSE.to_csv("returnsWhartonshrinked_neu_2jahre_f.csv")

# %% [markdown]
# ### Reduzierter S&P500-Bestand

# %% [markdown]
# ### Reduziert und Ledoit-Shrinkage
