# %% [markdown]
# Hier werden die Portfolio-Methoden angewandt und mithilfe der Performance-Metriken bewertet. Die Ergebnisse werden in CSV-Dateien festgehalten. Das Akquirieren, modifizieren und beschreiben der Daten befindet sich der Übersicht halber im Notebook Datenbasis. Die Daten werden dort als CSV exportiert und hier als Dataframe wieder eingelesen.
#
# Die Korrektheit der implementierten Methoden und Metriken wird in dem separaten Notebook Verifizierung anhand eines kleinen Teilbestandes aufgezeigt, siehe dazu auch beigefügte Excel-Dateien, in denen die Portfolio-Gewichte "per Hand" nachgerechnet und mit den Ergebnissen aus der Python-Implementierung abgeglichen werden.
#
# ACHTUNG: LANGE LAUFZEIT!

# %% [markdown]
# ## Importe

# %%
#Import der notwendigen Bibliotheken, Installation mit pip bereits erfolgt

import yfinance as yf
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import csv
from scipy.optimize import minimize
import math
import random
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import linkage, dendrogram
import riskfolio as rp
from sklearn.covariance import LedoitWolf
from scipy.spatial.distance import squareform
from riskfolio import HCPortfolio as hc
from pandas.tseries.offsets import MonthBegin
from pandas.tseries.offsets import MonthEnd

# %% [markdown]
# ## Einlesen der Daten

# %%
#Bearbeitete JSE-Daten (Gesamtbestand)

df_JSE = pd.read_csv(
    'WhartonFinal_neu.csv',
    sep=',',
    encoding='utf-8',
    index_col=0,
    decimal = '.',
    low_memory=False,
    parse_dates=['Date'],
    dayfirst=True
)

# %%
df_JSE.info
# Out:
# <bound method DataFrame.info of                  8303  15604   15618  16179  16183  16291   16305  16355  \
# Date
# 2005-06-01  39.000000  62.11   74.50  14.50   8.60   4.42   82.40   9.95
# 2005-06-02  38.800000  62.00   75.00  14.51   8.51   4.40   82.50   9.80
# 2005-06-03  37.903333  60.79   75.64  14.50   8.50   4.37   82.61   9.90
# 2005-06-06  37.006667  60.75   78.49  13.85   8.62   4.38   82.90   9.90
# 2005-06-07  36.110000  60.90   77.90  13.89   8.67   4.43   83.45   9.90
# ...               ...    ...     ...    ...    ...    ...     ...    ...
# 2025-05-26        NaN    NaN  256.98    NaN  12.95    NaN  168.45    NaN
# 2025-05-27        NaN    NaN  255.97    NaN  13.08    NaN  168.48    NaN
# 2025-05-28        NaN    NaN  257.02    NaN  13.10    NaN  173.00    NaN
# 2025-05-29        NaN    NaN  259.83    NaN  13.32    NaN  175.79    NaN
# 2025-05-30        NaN    NaN  255.50    NaN  13.49    NaN  173.32    NaN
#
#             16356   16610  ...  364340  364439  364518  364519  364717  \
# Date                       ...
# 2005-06-01  23.60  296.00  ...     NaN     NaN     NaN     NaN     NaN
# 2005-06-02  23.40  296.00  ...     NaN     NaN     NaN     NaN     NaN
# 2005-06-03  23.40  290.00  ...     NaN     NaN     NaN     NaN     NaN
# 2005-06-06  23.50  287.00  ...     NaN     NaN     NaN     NaN     NaN
# 2005-06-07  23.50  278.00  ...     NaN     NaN     NaN     NaN     NaN
# ...           ...     ...  ...     ...     ...     ...     ...     ...
# 2025-05-26  42.01  748.00  ...   53.35   10.34   10.47   10.08   10.01
# 2025-05-27  42.50  736.81  ...   53.71   10.39   10.49   10.17   10.02
# 2025-05-28  42.07  724.26  ...   53.96   10.40   10.55   10.32   10.05
# 2025-05-29  42.68  719.83  ...   53.69   10.33   10.55   10.25    9.99
# 2025-05-30  44.00  704.72  ...   54.11   10.45   10.58   10.31   10.12
#
#             365459  365648  366651  366185  366905
# Date
# 2005-06-01     NaN     NaN     NaN     NaN     NaN
# 2005-06-02     NaN     NaN     NaN     NaN     NaN
# 2005-06-03     NaN     NaN     NaN     NaN     NaN
# 2005-06-06     NaN     NaN     NaN     NaN     NaN
# 2005-06-07     NaN     NaN     NaN     NaN     NaN
# ...            ...     ...     ...     ...     ...
# 2025-05-26   20.17  101.22    9.69   10.15    9.92
# 2025-05-27   20.22  101.23    9.76   10.15    9.92
# 2025-05-28   20.23  101.28    9.79   10.15    9.92
# 2025-05-29   20.08  101.32    9.82   10.31    9.93
# 2025-05-30   20.35  101.32    9.94   10.32    9.93
#
# [5173 rows x 350 columns]>

# %% [markdown]
# ## Definition der Methoden und Metriken

# %% [markdown]
# #### Equally-Weighted Portfolio

# %%
#Rückgabe gleicher Gewichte anhand der Anzahl der Unternehmen (Input Returns)

def equally_weighted(returns):
    anzahl_assets = returns.shape[1]

    w0 = 1/anzahl_assets
    gewichte = np.full(anzahl_assets, w0)

    return gewichte

# %% [markdown]
# #### Minimum-Variance Portfolio

# %%
#Minimum-Variance Portfolio
#Code adaptiert von https://medium.com/@BorisGerat/mean-variance-and-minimum-variance-portfolio-models-in-python-64a5c6b57b2d

def min_variance_opt(matrix):
    
    #Compute the minimum-variance portfolio weights subject to the constraints of:
    #- No short-selling (weights must be >= 0)
    #- Full investment (sum of weights must equal 1)
    
    number_of_assets = matrix.shape[0]

    # Define the objective function to minimize portfolio variance
    def objective(w):
        portfolio_variance = np.dot(w, matrix @ w)
        return portfolio_variance

    # Constraint: The sum of portfolio weights must be equal to 1
    constraints = [{'type': 'eq', 'fun': lambda w: np.sum(w) - 1}]

    # Bounds: Each weight must be between 0 and 1 (no short-selling)
    bounds = [[0, 1] for _ in range(number_of_assets)]

    # Initial guess: Equal weights for all assets
    w0 = np.ones(number_of_assets) / number_of_assets

    # Solve the optimization problem using Sequential Least Squares Quadratic Programming (SLSQP)
    res = minimize(objective, w0, method='SLSQP', bounds=bounds, constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    
    return res.x  # Return the optimal weights

# %% [markdown]
# #### Maximum Diversification Portfolio

# %%
#Code von https://thequantmba.wordpress.com/2017/06/06/max-diversification-in-python/ adaptiert

def calc_max_diversification_ratio(weights, matrix):
    
    # gewichtete Volatilität
    average_vol = np.dot(np.sqrt(np.diag(matrix)), weights.T)
    
    # portfolio volatilität
    portfolio_variance = np.dot(weights, matrix @ weights)
    portfolio_vol = np.sqrt(portfolio_variance)
    
    #Bestimmung Ratio
    diversification_ratio = average_vol/portfolio_vol
    
    # Negativer Wert für Minimierung (Maximizieren = Minimieren -)
    return -diversification_ratio

# %%
#Code von https://thequantmba.wordpress.com/2017/06/06/max-diversification-in-python/ adaptiert

def max_diversification_portfolio(matrix):
    
    anzahl_assets = matrix.shape[0]
    
    w0 = 1/anzahl_assets
    w = np.full(anzahl_assets, w0)
    
    # Constraint: The sum of portfolio weights must be equal to 1
    constraints = [{'type': 'eq', 'fun': lambda w: np.sum(w) - 1}]
    
    # Bounds: Each weight must be between 0 and 1 (no short-selling)
    bounds = [[0, 1] for _ in range(anzahl_assets)]
    
    res = minimize(calc_max_diversification_ratio, w, bounds=bounds, args=(matrix), method='SLSQP', constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    return res.x

# %% [markdown]
# #### Inverse Volatility Portfolio

# %%
#Code adaptiert von https://www.kaggle.com/code/vijipai/lesson-4-traditional-portfolio-construction-method

def inverse_volatility_portfolio (matrix):
    
    standardabweichungen = np.sqrt(np.diagonal(matrix))
    invertierte_std = 1/standardabweichungen
    summe_invertierte_std = np.sum(invertierte_std)
    
    inverse_volatility_gewichte = invertierte_std / summe_invertierte_std
    
    return inverse_volatility_gewichte

# %% [markdown]
# #### Equal Risk Contribution Portfolio

# %%
#Code adaptiert von https://medium.com/@deepml1818/building-a-python-based-risk-parity-portfolio-for-trading-40441ecdd84d

def calculate_portfolio_volatility(weights, matrix):
    
    portfolio_variance = np.dot(weights, matrix @ weights)
    portfolio_volatility = np.sqrt(portfolio_variance)
    return portfolio_volatility

def calculate_risk_contribution(weights, matrix):
    portfolio_volatility = calculate_portfolio_volatility(weights, matrix)
    marginal_contribution_zaehler = np.dot(matrix, weights)
    risk_contribution = np.multiply(weights, marginal_contribution_zaehler) / portfolio_volatility
    return risk_contribution

def risk_parity_objective(weights, matrix):
    risk_contribution = calculate_risk_contribution(weights, matrix)
    target_risk = np.mean(risk_contribution)
    return np.sum((risk_contribution - target_risk) ** 2)

# %%
def get_risk_parity_weights(matrix):
    
    number_of_assets = matrix.shape[0]
    w0 = 1/number_of_assets
    initial_weights = np.full(number_of_assets, w0)
    
    constraints = ({'type': 'eq', 'fun': lambda initial_weights: np.sum(initial_weights) - 1})
    bounds = [[0, 1] for _ in range(number_of_assets)]
    
    result = minimize(risk_parity_objective, initial_weights, args=(matrix), method='SLSQP', bounds=bounds, constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    
    return result.x

# %% [markdown]
# #### Hierarchical Risk Parity

# %%
#Aus dem Paper von Lopez De Prado (2016)
def getIVP(cov,**kargs): # Compute the inverse-variance portfolio 
    ivp=1./np.diag(cov) 
    ivp/=ivp.sum() 
    return ivp

# %%
#------------------------------------------------------------------------------ 
def getClusterVar(cov,cItems): # Compute variance per cluster 
    cov_=cov.loc[cItems,cItems] # matrix slice 
    w_=getIVP(cov_).reshape(-1,1) 
    cVar=np.dot(np.dot(w_.T,cov_),w_)[0,0] 
    return cVar

# %%
#------------------------------------------------------------------------------ 
def getQuasiDiag(link): # Sort clustered items by distance 
    link=link.astype(int) 
    sortIx=pd.Series([link[-1,0],link[-1,1]]) 
    numItems=link[-1,3] # number of original items 
    while sortIx.max()>=numItems: 
        sortIx.index=range(0,sortIx.shape[0]*2,2) # make space 
        df0=sortIx[sortIx>=numItems] # find clusters
        i=df0.index;j=df0.values-numItems 
        sortIx[i]=link[j,0] # item 1 
        df0=pd.Series(link[j,1],index=i+1) 
        sortIx = pd.concat([sortIx, df0]) # item 2  ####Anpassung wegen neuer Pandas-Version!
        sortIx=sortIx.sort_index() # re-sort 
        sortIx.index=range(sortIx.shape[0]) # re-index 
    return sortIx.tolist()

# %%
#------------------------------------------------------------------------------ 
def getRecBipart(cov,sortIx): # Compute HRP allocation
    w = pd.Series(1,index=sortIx) 
    cItems=[sortIx] # initialize all items in one cluster 
    while len(cItems)>0: 
        #Bi-Section der Cluster
        cItems = [i[j:k] 
                  for i in cItems 
                  for j, k in ((0, len(i)//2), (len(i)//2, len(i))) 
                  if len(i) > 1]
        for i in range(0, len(cItems), 2): # parse in pairs 
            cItems0=cItems[i] # cluster 1 
            cItems1=cItems[i+1] # cluster 2 
            cVar0=getClusterVar(cov,cItems0) 
            cVar1=getClusterVar(cov,cItems1) 
            alpha=1-cVar0/(cVar0+cVar1) 
            w[cItems0]*=alpha # weight 1 
            w[cItems1]*=1-alpha # weight 2 
    return w

# %%
#------------------------------------------------------------------------------ 
def correlDist(corr): 
    # A distance matrix based on correlation, where 0<=d[i,j]<=1 
    # This is a proper distance metric 
    dist=((1-corr)/2.)**.5 # distance matrix 
    
    #Adjustierung zur condensed_distance_matrix
    condensed_distance_matrix = squareform(X=dist, checks=False)
    
    return condensed_distance_matrix

# %%
def hrp_main(corr, cov, returns): 
    
    #3) cluster 
    dist=correlDist(corr) 
    link=sch.linkage(dist,'single') 
    sortIx=getQuasiDiag(link) 
    sortIx=corr.index[sortIx].tolist() # recover labels 
    df0=corr.loc[sortIx,sortIx] # reorder 
    
    #4) Capital allocation 
    hrp=getRecBipart(cov,sortIx) 
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    hrp_sortiert = hrp.reindex(original_reihenfolge)
    
    array = hrp_sortiert.T.values

    return array

# %% [markdown]
# #### Hierarchical Equal Risk Contribution Portfolio

# %%
#Es wird auf die Implementierung der Riskfolio-Lib zurückgegriffen
#Code adaptiert von #Code adaptiert von https://medium.com/@orenji.eirl/hierarchical-equal-risk-contribution-with-python-and-riskfolio-lib-ec45dd0f9899

def herc (returns):

    # Building the portfolio object
    port = hc(returns=returns)

    # Estimate optimal portfolio:

    model='HERC'
    correlation = 'pearson'
    rm = 'MV'
    rf = 0 
    linkage = 'ward' 
    max_k = 10 
    leaf_order = True 

    gewichte = port.optimization(model=model,
                          correlation=correlation,
                          rm=rm,
                          rf=rf,
                          linkage=linkage,
                          max_k=max_k,
                          leaf_order=leaf_order)
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    gewichte_sortiert = gewichte.reindex(original_reihenfolge)
    
    array = gewichte_sortiert.values.flatten()

    return array

# %% [markdown]
# #### Vergleichs-Metriken

# %%
def gesamt_return(gewichte, returns):

    daily_returns = returns @ gewichte
    total = np.prod(1 + daily_returns) - 1
    
    return total

# %%
def portfolio_return (gewichte, returns):
    
    avg_returns = []
    avg_returns = returns.mean()
    
    pf_return = sum([gewicht * rendite for gewicht, rendite in zip(gewichte, avg_returns)])
    
    return pf_return

# %%
def portfolio_variance (gewichte, returns):
    daily_returns = []
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    pf_var = np.var(daily_returns)
    
    return pf_var

# %%
def portfolio_volatility (gewichte, returns):
    variance = portfolio_variance(gewichte, returns)
    volatility = np.sqrt(variance)
    
    return volatility

# %%
def annualized_return(gewichte, returns):
    daily_returns = returns @ gewichte
    annual = (np.prod(1 + daily_returns))**(252/daily_returns.shape[0]) - 1
    
    return annual

# %%
def annualized_portfolio_return(gewichte, returns):
    pf_return = portfolio_return(gewichte, returns)
    
    return pf_return*252

# %%
def annualized_portfolio_volatility(gewichte, returns):
    pf_volatility = portfolio_volatility(gewichte, returns)
    
    return pf_volatility*np.sqrt(252)

# %%
def sharpe_ratio (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sharpe_ratio_one (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.01
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sharpe_ratio_two (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.02
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio_one (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.01
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio_two (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.02
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sortino_ratio (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def sortino_ratio_one (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.01
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def sortino_ratio_two (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.02
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio_one (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.01
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio_two (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.02
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def maximum_drawdown (gewichte, returns):
    daily_returns = returns @ gewichte
    returns_kumuliert = (1 + daily_returns).cumprod()
    hochpunkte = returns_kumuliert.cummax()
    
    drawdowns = (returns_kumuliert - hochpunkte) / hochpunkte
    max_drawdown = drawdowns.min()
    
    #print(drawdowns)
    return max_drawdown

# %%
def calmar_ratio (gewichte, returns):
    pf_return = portfolio_return(gewichte, returns)
    max_drawdown = maximum_drawdown(gewichte, returns)
    
    calmar_ratio = pf_return / (-max_drawdown)
    
    return calmar_ratio

# %%
def value_at_risk_func(gewichte, returns):
    daily_returns = returns @ gewichte
    sorted_daily_returns = daily_returns.sort_values(ascending = True)
    value_at_risk = np.percentile(sorted_daily_returns, 100*0.05)
    return value_at_risk

# %%
#https://github.com/malctaylor15/VaR-and-Expected-Shortfall-Python/blob/master/Expected%20Shortfall%20and%20Value%20at%20Risk.ipynb

def expected_shortfall(gewichte, returns):
    daily_returns = returns @ gewichte
    sorted_daily_returns = daily_returns.sort_values(ascending = True)
    value_at_risk = value_at_risk_func(gewichte, returns)
    
    expected_shortfall = daily_returns[daily_returns <= value_at_risk].mean()
    
    return expected_shortfall

# %% [markdown]
# #### Sammel-Funktionen zum Berechnen und Speichern der Metriken

# %%
def metriken_equally_weighted(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile1 = {"Methode": "Equally-Weighted",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile1[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile1])], ignore_index=True)

# %%
def metriken_minimum_variance(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile2 = {"Methode": "Minimum_Variance",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile2[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile2])], ignore_index=True)

# %%
def metriken_max_diversification(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile3 = {"Methode": "Max-Diversification",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile3[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile3])], ignore_index=True)

# %%
def metriken_inverse_volatility(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile4 = {"Methode": "Inverse-Volatility",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile4[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile4])], ignore_index=True)

# %%
def metriken_risk_parity(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile5 = {"Methode": "Risk-Parity",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile5[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile5])], ignore_index=True)

# %%
def metriken_hrp(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile6 = {"Methode": "HRP",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile6[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile6])], ignore_index=True)

# %%
def metriken_herc(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile7 = {"Methode": "HERC",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile7[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile7])], ignore_index=True)

# %% [markdown]
# ## Erzeugung Ergebnisse S&P500

# %% [markdown]
# ## Ergebnis-Erzeugung JSE

# %%
returns = df_JSE.pct_change()
returns = returns.where(~df_JSE.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                 8303     15604     15618     16179     16183     16291  \
# Date
# 2005-06-02 -0.005128 -0.001771  0.006711  0.000690 -0.010465 -0.004525
# 2005-06-03 -0.023110 -0.019516  0.008533 -0.000689 -0.001175 -0.006818
# 2005-06-06 -0.023657 -0.000658  0.037678 -0.044828  0.014118  0.002288
# 2005-06-07 -0.024230  0.002469 -0.007517  0.002888  0.005800  0.011416
# 2005-06-08 -0.027970 -0.003284 -0.005135  0.006479  0.014994  0.006772
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26       NaN       NaN  0.013928       NaN -0.001542       NaN
# 2025-05-27       NaN       NaN -0.003930       NaN  0.010039       NaN
# 2025-05-28       NaN       NaN  0.004102       NaN  0.001529       NaN
# 2025-05-29       NaN       NaN  0.010933       NaN  0.016794       NaN
# 2025-05-30       NaN       NaN -0.016665       NaN  0.012763       NaN
#
#                16305     16355     16356     16610  ...    364340    364439  \
# Date                                                ...
# 2005-06-02  0.001214 -0.015075 -0.008475  0.000000  ...       NaN       NaN
# 2005-06-03  0.001333  0.010204  0.000000 -0.020270  ...       NaN       NaN
# 2005-06-06  0.003510  0.000000  0.004274 -0.010345  ...       NaN       NaN
# 2005-06-07  0.006634  0.000000  0.000000 -0.031359  ...       NaN       NaN
# 2005-06-08 -0.005392  0.000000  0.000000 -0.027158  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-26  0.007235       NaN -0.020518 -0.023906  ...  0.003574  0.010753
# 2025-05-27  0.000178       NaN  0.011664 -0.014960  ...  0.006748  0.004836
# 2025-05-28  0.026828       NaN -0.010118 -0.017033  ...  0.004655  0.000962
# 2025-05-29  0.016127       NaN  0.014500 -0.006117  ... -0.005004 -0.006731
# 2025-05-30 -0.014051       NaN  0.030928 -0.020991  ...  0.007823  0.011617
#
#               364518    364519    364717    365459    365648    366651  \
# Date
# 2005-06-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26  0.009643  0.018182  0.000000  0.011535  0.000395  0.006231
# 2025-05-27  0.001910  0.008929  0.000999  0.002479  0.000099  0.007224
# 2025-05-28  0.005720  0.014749  0.002994  0.000495  0.000494  0.003074
# 2025-05-29  0.000000 -0.006783 -0.005970 -0.007415  0.000395  0.003064
# 2025-05-30  0.002844  0.005854  0.013013  0.013446  0.000000  0.012220
#
#               366185    366905
# Date
# 2005-06-02       NaN       NaN
# 2005-06-03       NaN       NaN
# 2005-06-06       NaN       NaN
# 2005-06-07       NaN       NaN
# 2005-06-08       NaN       NaN
# ...              ...       ...
# 2025-05-26 -0.000984  0.000000
# 2025-05-27  0.000000  0.000000
# 2025-05-28  0.000000  0.000000
# 2025-05-29  0.015764  0.001008
# 2025-05-30  0.000970  0.000000
#
# [5172 rows x 350 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 36
test_fenster = 1
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    #Inf-Werte in NaN umwandeln
    training_daten = training_daten.replace([np.inf, -np.inf], np.nan)
    #Spalten entfernen, die nachher noch NaN enthalten
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 189
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = training_daten.cov()
    corr_matrix = training_daten.corr()
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    JSE_gewichte_equally_weighted = equally_weighted(training_daten)
    JSE_gewichte_min_variance= min_variance_opt(cov_matrix)
    JSE_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    JSE_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    JSE_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    JSE_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    JSE_gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": JSE_gewichte_equally_weighted,
    "Minimum-Variance": JSE_gewichte_min_variance,
    "Maximum-Diversification": JSE_gewichte_max_diversification,
    "Inverse-Volatility": JSE_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": JSE_gewichte_risk_parity,
    "HRP": JSE_gewichte_hrp,
    "HERC": JSE_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
    #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
# Alle Testperioden zusammenführen
portfolio_returns_df_JSE = pd.concat(portfolio_returns_list)
portfolio_returns_df_JSE = portfolio_returns_df_JSE.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.140247654123246e-05
#             Iterations: 214
#             Function evaluations: 19689
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6107736720313213
#             Iterations: 60
#             Function evaluations: 5579
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.433367165256956e-09
#             Iterations: 56
#             Function evaluations: 5152
#             Gradient evaluations: 56
# 2005-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.207062012568762e-05
#             Iterations: 233
#             Function evaluations: 21903
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6644584067399184
#             Iterations: 60
#             Function evaluations: 5701
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1069954283120343e-08
#             Iterations: 44
#             Function evaluations: 4136
#             Gradient evaluations: 44
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4219787106981768e-05
#             Iterations: 194
#             Function evaluations: 18237
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5908352228267018
#             Iterations: 59
#             Function evaluations: 5604
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.423862291358962e-09
#             Iterations: 44
#             Function evaluations: 4136
#             Gradient evaluations: 44
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4737608834920705e-05
#             Iterations: 194
#             Function evaluations: 18430
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.648943969609723
#             Iterations: 59
#             Function evaluations: 5663
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.877062786203158e-09
#             Iterations: 39
#             Function evaluations: 3705
#             Gradient evaluations: 39
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5846387846876065e-05
#             Iterations: 195
#             Function evaluations: 18916
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6425790680957846
#             Iterations: 58
#             Function evaluations: 5682
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.857775456106456e-09
#             Iterations: 39
#             Function evaluations: 3783
#             Gradient evaluations: 39
# 2005-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0972858150400256e-05
#             Iterations: 182
#             Function evaluations: 17654
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4702527947533737
#             Iterations: 56
#             Function evaluations: 5485
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.598454110796146e-09
#             Iterations: 54
#             Function evaluations: 5238
#             Gradient evaluations: 54
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.206148953652686e-05
#             Iterations: 174
#             Function evaluations: 16704
#             Gradient evaluations: 174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4820032268174823
#             Iterations: 55
#             Function evaluations: 5332
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.928085321259378e-09
#             Iterations: 54
#             Function evaluations: 5185
#             Gradient evaluations: 54
# 2006-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.253343295150405e-05
#             Iterations: 188
#             Function evaluations: 18049
#             Gradient evaluations: 188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.423768631844621
#             Iterations: 61
#             Function evaluations: 5912
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.040751358677896e-09
#             Iterations: 65
#             Function evaluations: 6241
#             Gradient evaluations: 65
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6258025195078044e-05
#             Iterations: 179
#             Function evaluations: 17363
#             Gradient evaluations: 179
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7076991596683397
#             Iterations: 63
#             Function evaluations: 6173
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5326903338302346e-08
#             Iterations: 87
#             Function evaluations: 8439
#             Gradient evaluations: 87
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.681375100572491e-05
#             Iterations: 169
#             Function evaluations: 16393
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7288379948072525
#             Iterations: 64
#             Function evaluations: 6275
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6983945775754216e-08
#             Iterations: 74
#             Function evaluations: 7179
#             Gradient evaluations: 74
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.781388770124544e-05
#             Iterations: 176
#             Function evaluations: 17249
#             Gradient evaluations: 176
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7488481721860167
#             Iterations: 61
#             Function evaluations: 6041
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7329525220652686e-08
#             Iterations: 76
#             Function evaluations: 7448
#             Gradient evaluations: 76
# 2006-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8289177743280573e-05
#             Iterations: 190
#             Function evaluations: 18240
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6940359148562534
#             Iterations: 62
#             Function evaluations: 6015
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.917198875692824e-08
#             Iterations: 75
#             Function evaluations: 7201
#             Gradient evaluations: 75
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.769268861523692e-05
#             Iterations: 201
#             Function evaluations: 19296
#             Gradient evaluations: 201
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7619569346564123
#             Iterations: 66
#             Function evaluations: 6402
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.01570418142266e-08
#             Iterations: 64
#             Function evaluations: 6145
#             Gradient evaluations: 64
# 2006-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.592713324620554e-05
#             Iterations: 191
#             Function evaluations: 18145
#             Gradient evaluations: 191
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.856604967040928
#             Iterations: 68
#             Function evaluations: 6528
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.924005978097399e-08
#             Iterations: 63
#             Function evaluations: 5985
#             Gradient evaluations: 63
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5788118272704826e-05
#             Iterations: 204
#             Function evaluations: 19381
#             Gradient evaluations: 204
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8500683133212386
#             Iterations: 65
#             Function evaluations: 6247
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9330925616287202e-08
#             Iterations: 64
#             Function evaluations: 6080
#             Gradient evaluations: 64
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6034147592857412e-05
#             Iterations: 208
#             Function evaluations: 19344
#             Gradient evaluations: 208
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.712316296776791
#             Iterations: 64
#             Function evaluations: 6018
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.205609125884784e-08
#             Iterations: 64
#             Function evaluations: 5953
#             Gradient evaluations: 64
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5949294330296895e-05
#             Iterations: 204
#             Function evaluations: 18768
#             Gradient evaluations: 204
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6940138137071465
#             Iterations: 65
#             Function evaluations: 6045
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.334482778429832e-08
#             Iterations: 54
#             Function evaluations: 4968
#             Gradient evaluations: 54
# 2006-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5987993167490537e-05
#             Iterations: 215
#             Function evaluations: 19780
#             Gradient evaluations: 215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7610885418470836
#             Iterations: 59
#             Function evaluations: 5493
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1462649064611196e-08
#             Iterations: 65
#             Function evaluations: 5980
#             Gradient evaluations: 65
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5960120032307592e-05
#             Iterations: 219
#             Function evaluations: 21024
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.806912252777541
#             Iterations: 61
#             Function evaluations: 5921
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9525698120664464e-08
#             Iterations: 65
#             Function evaluations: 6240
#             Gradient evaluations: 65
# 2007-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.55193601719683e-05
#             Iterations: 217
#             Function evaluations: 20615
#             Gradient evaluations: 217
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7779780535855956
#             Iterations: 61
#             Function evaluations: 5856
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0212653602315043e-08
#             Iterations: 64
#             Function evaluations: 6080
#             Gradient evaluations: 64
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5470788091029622e-05
#             Iterations: 204
#             Function evaluations: 19176
#             Gradient evaluations: 204
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7543110512420896
#             Iterations: 61
#             Function evaluations: 5795
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0741366726659763e-08
#             Iterations: 64
#             Function evaluations: 6016
#             Gradient evaluations: 64
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5185106167690325e-05
#             Iterations: 194
#             Function evaluations: 18043
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.754362937382085
#             Iterations: 62
#             Function evaluations: 5830
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1168003514354857e-08
#             Iterations: 64
#             Function evaluations: 5952
#             Gradient evaluations: 64
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.531265383494326e-05
#             Iterations: 216
#             Function evaluations: 20089
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7877615133740803
#             Iterations: 60
#             Function evaluations: 5646
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1064695823664827e-08
#             Iterations: 112
#             Function evaluations: 10416
#             Gradient evaluations: 112
# 2007-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5095778661606845e-05
#             Iterations: 197
#             Function evaluations: 17927
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7481068535346687
#             Iterations: 60
#             Function evaluations: 5516
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1460712286161255e-08
#             Iterations: 112
#             Function evaluations: 10193
#             Gradient evaluations: 112
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5295131935980357e-05
#             Iterations: 210
#             Function evaluations: 19111
#             Gradient evaluations: 210
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7446556780855773
#             Iterations: 58
#             Function evaluations: 5340
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0836681786641476e-08
#             Iterations: 123
#             Function evaluations: 11193
#             Gradient evaluations: 123
# 2007-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5235567928049415e-05
#             Iterations: 201
#             Function evaluations: 18292
#             Gradient evaluations: 201
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7778584876837247
#             Iterations: 57
#             Function evaluations: 5245
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0788360795860455e-08
#             Iterations: 122
#             Function evaluations: 11103
#             Gradient evaluations: 122
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.511299192532446e-05
#             Iterations: 206
#             Function evaluations: 18747
#             Gradient evaluations: 206
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7700410229105676
#             Iterations: 56
#             Function evaluations: 5153
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0861409111789251e-08
#             Iterations: 122
#             Function evaluations: 11102
#             Gradient evaluations: 122
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4528273042498224e-05
#             Iterations: 210
#             Function evaluations: 19110
#             Gradient evaluations: 210
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8160815011357023
#             Iterations: 57
#             Function evaluations: 5249
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3851356981017774e-08
#             Iterations: 53
#             Function evaluations: 4824
#             Gradient evaluations: 53
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3981371820132178e-05
#             Iterations: 203
#             Function evaluations: 18474
#             Gradient evaluations: 203
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.84833313994955
#             Iterations: 58
#             Function evaluations: 5336
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3792125163551417e-08
#             Iterations: 53
#             Function evaluations: 4824
#             Gradient evaluations: 53
# 2007-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3936094164919083e-05
#             Iterations: 211
#             Function evaluations: 19202
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8450765591033367
#             Iterations: 59
#             Function evaluations: 5428
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0121038399657264e-08
#             Iterations: 76
#             Function evaluations: 6917
#             Gradient evaluations: 76
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.382603729492563e-05
#             Iterations: 204
#             Function evaluations: 18768
#             Gradient evaluations: 204
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.859370005644156
#             Iterations: 67
#             Function evaluations: 6231
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9609944521799216e-08
#             Iterations: 76
#             Function evaluations: 6993
#             Gradient evaluations: 76
# 2008-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3797010539080882e-05
#             Iterations: 220
#             Function evaluations: 20680
#             Gradient evaluations: 220
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.870261073346276
#             Iterations: 63
#             Function evaluations: 5989
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8195308899656038e-08
#             Iterations: 76
#             Function evaluations: 7144
#             Gradient evaluations: 76
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.217466860619961e-05
#             Iterations: 211
#             Function evaluations: 19835
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.968074911849192
#             Iterations: 64
#             Function evaluations: 6082
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.006866533569075e-08
#             Iterations: 53
#             Function evaluations: 4983
#             Gradient evaluations: 53
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1909049253227913e-05
#             Iterations: 219
#             Function evaluations: 20586
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.964174206178806
#             Iterations: 66
#             Function evaluations: 6273
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9210264973265605e-08
#             Iterations: 53
#             Function evaluations: 4983
#             Gradient evaluations: 53
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1494034851635393e-05
#             Iterations: 219
#             Function evaluations: 20367
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.953395044620324
#             Iterations: 68
#             Function evaluations: 6391
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7666858007620368e-08
#             Iterations: 65
#             Function evaluations: 6046
#             Gradient evaluations: 65
# 2008-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1397600462514656e-05
#             Iterations: 194
#             Function evaluations: 18043
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.805232796164624
#             Iterations: 61
#             Function evaluations: 5737
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7154947445002536e-08
#             Iterations: 65
#             Function evaluations: 6045
#             Gradient evaluations: 65
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1366936169832338e-05
#             Iterations: 216
#             Function evaluations: 19440
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8104146579332148
#             Iterations: 59
#             Function evaluations: 5371
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.936296731808834e-08
#             Iterations: 64
#             Function evaluations: 5760
#             Gradient evaluations: 64
# 2008-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.070168514039482e-05
#             Iterations: 214
#             Function evaluations: 19046
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7905597046286092
#             Iterations: 62
#             Function evaluations: 5576
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9630883671983283e-08
#             Iterations: 65
#             Function evaluations: 5786
#             Gradient evaluations: 65
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8657764474230258e-05
#             Iterations: 194
#             Function evaluations: 17267
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8572852183091983
#             Iterations: 64
#             Function evaluations: 5679
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.996911704773508e-08
#             Iterations: 65
#             Function evaluations: 5786
#             Gradient evaluations: 65
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.033437108940839e-05
#             Iterations: 204
#             Function evaluations: 18361
#             Gradient evaluations: 204
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7842841020546203
#             Iterations: 61
#             Function evaluations: 5552
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5900988157650855e-08
#             Iterations: 64
#             Function evaluations: 5760
#             Gradient evaluations: 64
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.017921751578228e-05
#             Iterations: 198
#             Function evaluations: 18019
#             Gradient evaluations: 198
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.758219205984567
#             Iterations: 62
#             Function evaluations: 5704
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5022800546275573e-08
#             Iterations: 61
#             Function evaluations: 5551
#             Gradient evaluations: 61
# 2008-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6740388334864688e-05
#             Iterations: 195
#             Function evaluations: 17745
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9239285522579452
#             Iterations: 65
#             Function evaluations: 5891
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2143803846399432e-08
#             Iterations: 67
#             Function evaluations: 6097
#             Gradient evaluations: 67
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.587621124780907e-05
#             Iterations: 185
#             Function evaluations: 16650
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.937220048207986
#             Iterations: 66
#             Function evaluations: 6009
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.022862584192228e-08
#             Iterations: 67
#             Function evaluations: 6030
#             Gradient evaluations: 67
# 2009-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.510187774172168e-05
#             Iterations: 182
#             Function evaluations: 16380
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.953863701340308
#             Iterations: 63
#             Function evaluations: 5738
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.070817972883602e-08
#             Iterations: 56
#             Function evaluations: 5040
#             Gradient evaluations: 56
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4546420849131515e-05
#             Iterations: 213
#             Function evaluations: 19170
#             Gradient evaluations: 213
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.915532249761947
#             Iterations: 64
#             Function evaluations: 5826
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0369550551701531e-08
#             Iterations: 57
#             Function evaluations: 5130
#             Gradient evaluations: 57
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4107354737723848e-05
#             Iterations: 229
#             Function evaluations: 20839
#             Gradient evaluations: 229
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.92839737982825
#             Iterations: 66
#             Function evaluations: 5986
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.179893609707719e-08
#             Iterations: 45
#             Function evaluations: 4095
#             Gradient evaluations: 45
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.289192915026383e-05
#             Iterations: 222
#             Function evaluations: 20202
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.953775719372436
#             Iterations: 59
#             Function evaluations: 5431
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0854900270098987e-08
#             Iterations: 45
#             Function evaluations: 4095
#             Gradient evaluations: 45
# 2009-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2504415902967547e-05
#             Iterations: 238
#             Function evaluations: 21896
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9193939274995513
#             Iterations: 58
#             Function evaluations: 5398
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0896781807318371e-08
#             Iterations: 45
#             Function evaluations: 4140
#             Gradient evaluations: 45
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2226027122457905e-05
#             Iterations: 237
#             Function evaluations: 21805
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8867492591821873
#             Iterations: 60
#             Function evaluations: 5581
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1058342034122319e-08
#             Iterations: 45
#             Function evaluations: 4140
#             Gradient evaluations: 45
# 2009-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.205924341953813e-05
#             Iterations: 238
#             Function evaluations: 21897
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9140345174557423
#             Iterations: 57
#             Function evaluations: 5302
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0477270372399053e-08
#             Iterations: 45
#             Function evaluations: 4140
#             Gradient evaluations: 45
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1787096928903132e-05
#             Iterations: 233
#             Function evaluations: 21203
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9262450179278274
#             Iterations: 59
#             Function evaluations: 5433
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0035234851429239e-08
#             Iterations: 45
#             Function evaluations: 4095
#             Gradient evaluations: 45
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1863480951607267e-05
#             Iterations: 210
#             Function evaluations: 18901
#             Gradient evaluations: 210
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9254519155387197
#             Iterations: 63
#             Function evaluations: 5735
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.66075727423908e-09
#             Iterations: 45
#             Function evaluations: 4051
#             Gradient evaluations: 45
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1785366645111966e-05
#             Iterations: 199
#             Function evaluations: 18109
#             Gradient evaluations: 199
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9489919846972947
#             Iterations: 62
#             Function evaluations: 5705
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.340004182319385e-09
#             Iterations: 45
#             Function evaluations: 4095
#             Gradient evaluations: 45
# 2009-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1730125115337657e-05
#             Iterations: 240
#             Function evaluations: 21601
#             Gradient evaluations: 240
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.866195812288586
#             Iterations: 66
#             Function evaluations: 6010
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.51520929416891e-09
#             Iterations: 45
#             Function evaluations: 4050
#             Gradient evaluations: 45
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1644105885528572e-05
#             Iterations: 217
#             Function evaluations: 19314
#             Gradient evaluations: 217
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.865744766951314
#             Iterations: 60
#             Function evaluations: 5403
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1702118406119955e-08
#             Iterations: 33
#             Function evaluations: 2938
#             Gradient evaluations: 33
# 2010-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1540208607484383e-05
#             Iterations: 231
#             Function evaluations: 20559
#             Gradient evaluations: 231
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8873167250784113
#             Iterations: 66
#             Function evaluations: 5943
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1211941097730068e-08
#             Iterations: 33
#             Function evaluations: 2938
#             Gradient evaluations: 33
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1483055371247201e-05
#             Iterations: 230
#             Function evaluations: 20470
#             Gradient evaluations: 230
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.92006935270433
#             Iterations: 64
#             Function evaluations: 5768
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1211150901910991e-08
#             Iterations: 33
#             Function evaluations: 2938
#             Gradient evaluations: 33
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1126880835877922e-05
#             Iterations: 233
#             Function evaluations: 20970
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.987040014043954
#             Iterations: 64
#             Function evaluations: 5833
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0794793268158763e-08
#             Iterations: 33
#             Function evaluations: 2970
#             Gradient evaluations: 33
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1144748994064599e-05
#             Iterations: 205
#             Function evaluations: 18451
#             Gradient evaluations: 205
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9878059934974104
#             Iterations: 66
#             Function evaluations: 6012
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0703265559118963e-08
#             Iterations: 33
#             Function evaluations: 2971
#             Gradient evaluations: 33
# 2010-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1416745320609934e-05
#             Iterations: 199
#             Function evaluations: 17910
#             Gradient evaluations: 199
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9366958954470603
#             Iterations: 65
#             Function evaluations: 5918
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0629510139575824e-08
#             Iterations: 33
#             Function evaluations: 2970
#             Gradient evaluations: 33
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.132752641238893e-05
#             Iterations: 212
#             Function evaluations: 19081
#             Gradient evaluations: 212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9926809440821485
#             Iterations: 71
#             Function evaluations: 6469
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.298662078461603e-09
#             Iterations: 34
#             Function evaluations: 3060
#             Gradient evaluations: 34
# 2010-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2218545661310702e-05
#             Iterations: 208
#             Function evaluations: 19137
#             Gradient evaluations: 208
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.996595803218433
#             Iterations: 69
#             Function evaluations: 6421
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.493245882575254e-09
#             Iterations: 34
#             Function evaluations: 3128
#             Gradient evaluations: 34
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2334567200497634e-05
#             Iterations: 214
#             Function evaluations: 19688
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9951369515252884
#             Iterations: 66
#             Function evaluations: 6143
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.508601062569111e-09
#             Iterations: 34
#             Function evaluations: 3128
#             Gradient evaluations: 34
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2468504680005248e-05
#             Iterations: 212
#             Function evaluations: 19292
#             Gradient evaluations: 212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.957397707264071
#             Iterations: 70
#             Function evaluations: 6442
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.470489201866944e-09
#             Iterations: 34
#             Function evaluations: 3094
#             Gradient evaluations: 34
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.152045341312301e-05
#             Iterations: 186
#             Function evaluations: 17113
#             Gradient evaluations: 186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.0127286775488855
#             Iterations: 66
#             Function evaluations: 6144
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.837386814133518e-09
#             Iterations: 34
#             Function evaluations: 3128
#             Gradient evaluations: 34
# 2010-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.255940602092124e-05
#             Iterations: 195
#             Function evaluations: 17745
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.933666455345365
#             Iterations: 68
#             Function evaluations: 6260
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.540818350516833e-09
#             Iterations: 34
#             Function evaluations: 3094
#             Gradient evaluations: 34
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1484797515045028e-05
#             Iterations: 207
#             Function evaluations: 19251
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.016730993857383
#             Iterations: 72
#             Function evaluations: 6774
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.068176944095095e-09
#             Iterations: 34
#             Function evaluations: 3162
#             Gradient evaluations: 34
# 2011-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1172628357881038e-05
#             Iterations: 188
#             Function evaluations: 17672
#             Gradient evaluations: 188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.021367184750777
#             Iterations: 75
#             Function evaluations: 7136
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.050483898430572e-09
#             Iterations: 34
#             Function evaluations: 3196
#             Gradient evaluations: 34
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3230231851410672e-05
#             Iterations: 186
#             Function evaluations: 17113
#             Gradient evaluations: 186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.869658974614794
#             Iterations: 71
#             Function evaluations: 6599
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.235111222445794e-09
#             Iterations: 33
#             Function evaluations: 3036
#             Gradient evaluations: 33
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3074711462507378e-05
#             Iterations: 201
#             Function evaluations: 18492
#             Gradient evaluations: 201
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8791413434060975
#             Iterations: 71
#             Function evaluations: 6608
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1090924220097669e-08
#             Iterations: 21
#             Function evaluations: 1933
#             Gradient evaluations: 21
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.301452955640929e-05
#             Iterations: 172
#             Function evaluations: 15652
#             Gradient evaluations: 172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.876303024135914
#             Iterations: 69
#             Function evaluations: 6349
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.148543340577904e-08
#             Iterations: 21
#             Function evaluations: 1912
#             Gradient evaluations: 21
# 2011-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2939542729772752e-05
#             Iterations: 203
#             Function evaluations: 18676
#             Gradient evaluations: 203
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.91958984180252
#             Iterations: 73
#             Function evaluations: 6794
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.100080544804853e-09
#             Iterations: 34
#             Function evaluations: 3128
# ...
#             Current function value: 8.82386432431903e-06
#             Iterations: 379
#             Function evaluations: 45481
#             Gradient evaluations: 379
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.097677843482721
#             Iterations: 90
#             Function evaluations: 10441
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.838225778087195e-08
#             Iterations: 52
#             Function evaluations: 6241
#             Gradient evaluations: 52
# 2020-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.746140572364618e-06
#             Iterations: 388
#             Function evaluations: 46173
#             Gradient evaluations: 388
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.06732757084797
#             Iterations: 87
#             Function evaluations: 10476
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9346713494918326e-08
#             Iterations: 38
#             Function evaluations: 4523
#             Gradient evaluations: 38
# 2020-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.66537460944625e-06
#             Iterations: 395
#             Function evaluations: 47005
#             Gradient evaluations: 395
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.936850881286998
#             Iterations: 81
#             Function evaluations: 9753
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.853044725327623e-08
#             Iterations: 44
#             Function evaluations: 5237
#             Gradient evaluations: 44
# 2020-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.273680741565648e-06
#             Iterations: 374
#             Function evaluations: 44881
#             Gradient evaluations: 374
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.993020177229097
#             Iterations: 84
#             Function evaluations: 10077
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2571134042807418e-08
#             Iterations: 44
#             Function evaluations: 5281
#             Gradient evaluations: 44
# 2020-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.959008308991068e-06
#             Iterations: 391
#             Function evaluations: 48093
#             Gradient evaluations: 391
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.1639117204234655
#             Iterations: 119
#             Function evaluations: 14518
#             Gradient evaluations: 115
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0268315916081446e-08
#             Iterations: 45
#             Function evaluations: 5535
#             Gradient evaluations: 45
# 2020-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.143122674559335e-06
#             Iterations: 405
#             Function evaluations: 49815
#             Gradient evaluations: 405
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.168110164706431
#             Iterations: 142
#             Function evaluations: 17559
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9277135670818477e-08
#             Iterations: 44
#             Function evaluations: 5413
#             Gradient evaluations: 44
# 2020-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.949902864827433e-06
#             Iterations: 365
#             Function evaluations: 44530
#             Gradient evaluations: 365
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.152623760706609
#             Iterations: 83
#             Function evaluations: 10244
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9338506242371758e-08
#             Iterations: 45
#             Function evaluations: 5490
#             Gradient evaluations: 45
# 2021-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.235486571727329e-06
#             Iterations: 412
#             Function evaluations: 50264
#             Gradient evaluations: 412
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.177470648534835
#             Iterations: 120
#             Function evaluations: 14526
#             Gradient evaluations: 116
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9282203531248158e-08
#             Iterations: 45
#             Function evaluations: 5490
#             Gradient evaluations: 45
# 2021-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.08709009219381e-06
#             Iterations: 414
#             Function evaluations: 50922
#             Gradient evaluations: 414
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.214154514790013
#             Iterations: 87
#             Function evaluations: 10828
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8695036339066033e-08
#             Iterations: 43
#             Function evaluations: 5289
#             Gradient evaluations: 43
# 2021-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.081554976943534e-06
#             Iterations: 430
#             Function evaluations: 52030
#             Gradient evaluations: 430
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.082296000699302
#             Iterations: 83
#             Function evaluations: 10163
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8952503922682004e-08
#             Iterations: 45
#             Function evaluations: 5445
#             Gradient evaluations: 45
# 2021-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.973411723655915e-06
#             Iterations: 407
#             Function evaluations: 48841
#             Gradient evaluations: 407
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.092800952792119
#             Iterations: 93
#             Function evaluations: 10801
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9456172844173014e-08
#             Iterations: 40
#             Function evaluations: 4800
#             Gradient evaluations: 40
# 2021-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.139607419308123e-06
#             Iterations: 405
#             Function evaluations: 49005
#             Gradient evaluations: 405
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.064244770886784
#             Iterations: 82
#             Function evaluations: 10035
#             Gradient evaluations: 82
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9310056032361473e-08
#             Iterations: 40
#             Function evaluations: 4841
#             Gradient evaluations: 40
# 2021-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.20131091854643e-06
#             Iterations: 416
#             Function evaluations: 50752
#             Gradient evaluations: 416
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.0282848338991855
#             Iterations: 86
#             Function evaluations: 10609
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8706615402230205e-08
#             Iterations: 44
#             Function evaluations: 5368
#             Gradient evaluations: 44
# 2021-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.172539754293472e-06
#             Iterations: 388
#             Function evaluations: 48112
#             Gradient evaluations: 388
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.0667959980112425
#             Iterations: 88
#             Function evaluations: 10917
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.923163851191456e-08
#             Iterations: 43
#             Function evaluations: 5332
#             Gradient evaluations: 43
# 2021-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.227866180436606e-06
#             Iterations: 406
#             Function evaluations: 50750
#             Gradient evaluations: 406
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.1015406117743085
#             Iterations: 88
#             Function evaluations: 11126
#             Gradient evaluations: 88
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8499852009398164e-08
#             Iterations: 44
#             Function evaluations: 5501
#             Gradient evaluations: 44
# 2021-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.211982709054086e-06
#             Iterations: 375
#             Function evaluations: 48000
#             Gradient evaluations: 375
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.094846453512531
#             Iterations: 89
#             Function evaluations: 11518
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7961611567251116e-08
#             Iterations: 43
#             Function evaluations: 5504
#             Gradient evaluations: 43
# 2021-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.204916280013176e-06
#             Iterations: 420
#             Function evaluations: 54180
#             Gradient evaluations: 420
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.090078808224521
#             Iterations: 89
#             Function evaluations: 11610
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.758642861790255e-08
#             Iterations: 43
#             Function evaluations: 5547
#             Gradient evaluations: 43
# 2021-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.110581869834022e-06
#             Iterations: 415
#             Function evaluations: 53951
#             Gradient evaluations: 415
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.1812416782298945
#             Iterations: 94
#             Function evaluations: 12224
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.736073659947652e-08
#             Iterations: 43
#             Function evaluations: 5590
#             Gradient evaluations: 43
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.077750878389717e-06
#             Iterations: 415
#             Function evaluations: 54366
#             Gradient evaluations: 415
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.177085650073752
#             Iterations: 95
#             Function evaluations: 12450
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.631893807211175e-08
#             Iterations: 44
#             Function evaluations: 5764
#             Gradient evaluations: 44
# 2022-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.991413869457676e-06
#             Iterations: 405
#             Function evaluations: 53056
#             Gradient evaluations: 405
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.203785480567553
#             Iterations: 152
#             Function evaluations: 20002
#             Gradient evaluations: 148
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.610506928103697e-08
#             Iterations: 43
#             Function evaluations: 5633
#             Gradient evaluations: 43
# 2022-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.946579869501244e-06
#             Iterations: 401
#             Function evaluations: 52532
#             Gradient evaluations: 401
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.165888580920206
#             Iterations: 86
#             Function evaluations: 11390
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5508112932833168e-08
#             Iterations: 44
#             Function evaluations: 5764
#             Gradient evaluations: 44
# 2022-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.632582833699416e-06
#             Iterations: 396
#             Function evaluations: 51480
#             Gradient evaluations: 396
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.952673390961324
#             Iterations: 87
#             Function evaluations: 11301
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5277095808200125e-08
#             Iterations: 43
#             Function evaluations: 5590
#             Gradient evaluations: 43
# 2022-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.943958384998546e-06
#             Iterations: 377
#             Function evaluations: 48256
#             Gradient evaluations: 377
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.040555269052803
#             Iterations: 168
#             Function evaluations: 21753
#             Gradient evaluations: 164
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.332628696118961e-08
#             Iterations: 55
#             Function evaluations: 7040
#             Gradient evaluations: 55
# 2022-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.8266602601988e-06
#             Iterations: 368
#             Function evaluations: 47105
#             Gradient evaluations: 368
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.696370709825854
#             Iterations: 81
#             Function evaluations: 10351
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5236479987522956e-08
#             Iterations: 54
#             Function evaluations: 6912
#             Gradient evaluations: 54
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_JSE.to_csv("returnsWharton_neu_3jahre_f.csv")

# %% [markdown]
# ## Ledoit-Wolf Shrinkage

# %%
#Definition von Ledoit-Shrinkage

def ledoit_shrink (returns):
    
    shrinkage = LedoitWolf().fit(returns.values)
    
    shrinkage_matrix = pd.DataFrame(
        shrinkage.covariance_,
        index = returns.columns,
        columns = returns.columns)
    
    #print(shrinkage.shrinkage_)
    
    return shrinkage_matrix

# %% [markdown]
# ### Auswertung S&P500 mit Ledoit Wolf

# %% [markdown]
# ### Auswertung JSE mit Ledoit Wolf

# %%
returns = df_JSE.pct_change()
returns = returns.where(~df_JSE.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                 8303     15604     15618     16179     16183     16291  \
# Date
# 2005-06-02 -0.005128 -0.001771  0.006711  0.000690 -0.010465 -0.004525
# 2005-06-03 -0.023110 -0.019516  0.008533 -0.000689 -0.001175 -0.006818
# 2005-06-06 -0.023657 -0.000658  0.037678 -0.044828  0.014118  0.002288
# 2005-06-07 -0.024230  0.002469 -0.007517  0.002888  0.005800  0.011416
# 2005-06-08 -0.027970 -0.003284 -0.005135  0.006479  0.014994  0.006772
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26       NaN       NaN  0.013928       NaN -0.001542       NaN
# 2025-05-27       NaN       NaN -0.003930       NaN  0.010039       NaN
# 2025-05-28       NaN       NaN  0.004102       NaN  0.001529       NaN
# 2025-05-29       NaN       NaN  0.010933       NaN  0.016794       NaN
# 2025-05-30       NaN       NaN -0.016665       NaN  0.012763       NaN
#
#                16305     16355     16356     16610  ...    364340    364439  \
# Date                                                ...
# 2005-06-02  0.001214 -0.015075 -0.008475  0.000000  ...       NaN       NaN
# 2005-06-03  0.001333  0.010204  0.000000 -0.020270  ...       NaN       NaN
# 2005-06-06  0.003510  0.000000  0.004274 -0.010345  ...       NaN       NaN
# 2005-06-07  0.006634  0.000000  0.000000 -0.031359  ...       NaN       NaN
# 2005-06-08 -0.005392  0.000000  0.000000 -0.027158  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-26  0.007235       NaN -0.020518 -0.023906  ...  0.003574  0.010753
# 2025-05-27  0.000178       NaN  0.011664 -0.014960  ...  0.006748  0.004836
# 2025-05-28  0.026828       NaN -0.010118 -0.017033  ...  0.004655  0.000962
# 2025-05-29  0.016127       NaN  0.014500 -0.006117  ... -0.005004 -0.006731
# 2025-05-30 -0.014051       NaN  0.030928 -0.020991  ...  0.007823  0.011617
#
#               364518    364519    364717    365459    365648    366651  \
# Date
# 2005-06-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2005-06-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26  0.009643  0.018182  0.000000  0.011535  0.000395  0.006231
# 2025-05-27  0.001910  0.008929  0.000999  0.002479  0.000099  0.007224
# 2025-05-28  0.005720  0.014749  0.002994  0.000495  0.000494  0.003074
# 2025-05-29  0.000000 -0.006783 -0.005970 -0.007415  0.000395  0.003064
# 2025-05-30  0.002844  0.005854  0.013013  0.013446  0.000000  0.012220
#
#               366185    366905
# Date
# 2005-06-02       NaN       NaN
# 2005-06-03       NaN       NaN
# 2005-06-06       NaN       NaN
# 2005-06-07       NaN       NaN
# 2005-06-08       NaN       NaN
# ...              ...       ...
# 2025-05-26 -0.000984  0.000000
# 2025-05-27  0.000000  0.000000
# 2025-05-28  0.000000  0.000000
# 2025-05-29  0.015764  0.001008
# 2025-05-30  0.000970  0.000000
#
# [5172 rows x 350 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 36
test_fenster = 1
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
     #Inf-Werte in NaN umwandeln
    training_daten = training_daten.replace([np.inf, -np.inf], np.nan)
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 189
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = ledoit_shrink(training_daten)
    
    #aus der geschrumpften Matrix die Korrelationsmatrix bauen
    standardabweichung = np.sqrt(np.diag(cov_matrix))
    corr_matrix = cov_matrix / np.outer(standardabweichung, standardabweichung)
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    shrinked_JSE_gewichte_equally_weighted = equally_weighted(training_daten)
    shrinked_JSE_gewichte_min_variance= min_variance_opt(cov_matrix)
    shrinked_JSE_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    shrinked_JSE_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    shrinked_JSE_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    shrinked_JSE_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    shrinked_JSE_gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": shrinked_JSE_gewichte_equally_weighted,
    "Minimum-Variance": shrinked_JSE_gewichte_min_variance,
    "Maximum-Diversification": shrinked_JSE_gewichte_max_diversification,
    "Inverse-Volatility": shrinked_JSE_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": shrinked_JSE_gewichte_risk_parity,
    "HRP": shrinked_JSE_gewichte_hrp,
    "HERC": shrinked_JSE_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
    #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_shrinked_JSE = pd.concat(portfolio_returns_list)
portfolio_returns_df_shrinked_JSE = portfolio_returns_df_shrinked_JSE.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3370717934394173e-05
#             Iterations: 172
#             Function evaluations: 15824
#             Gradient evaluations: 172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7093681458752172
#             Iterations: 65
#             Function evaluations: 6045
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0126676189220253e-08
#             Iterations: 41
#             Function evaluations: 3772
#             Gradient evaluations: 41
# 2005-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.419697595145844e-05
#             Iterations: 195
#             Function evaluations: 18330
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7537106204270843
#             Iterations: 65
#             Function evaluations: 6176
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.83031328677515e-09
#             Iterations: 42
#             Function evaluations: 3948
#             Gradient evaluations: 42
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5985892882590682e-05
#             Iterations: 187
#             Function evaluations: 17578
#             Gradient evaluations: 187
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.682002163466052
#             Iterations: 64
#             Function evaluations: 6081
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0328374944508764e-08
#             Iterations: 31
#             Function evaluations: 2915
#             Gradient evaluations: 31
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6449595786932166e-05
#             Iterations: 183
#             Function evaluations: 17385
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.738571616854545
#             Iterations: 64
#             Function evaluations: 6148
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.779762866060505e-09
#             Iterations: 39
#             Function evaluations: 3705
#             Gradient evaluations: 39
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.752865453894504e-05
#             Iterations: 192
#             Function evaluations: 18624
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7309827833498406
#             Iterations: 60
#             Function evaluations: 5885
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.830998256418177e-09
#             Iterations: 39
#             Function evaluations: 3783
#             Gradient evaluations: 39
# 2005-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.340723674006988e-05
#             Iterations: 170
#             Function evaluations: 16490
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5612331325651887
#             Iterations: 59
#             Function evaluations: 5780
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.554989549631626e-09
#             Iterations: 54
#             Function evaluations: 5238
#             Gradient evaluations: 54
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.461182093265454e-05
#             Iterations: 150
#             Function evaluations: 14400
#             Gradient evaluations: 150
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5747118026977485
#             Iterations: 62
#             Function evaluations: 6011
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.737139670637837e-09
#             Iterations: 54
#             Function evaluations: 5184
#             Gradient evaluations: 54
# 2006-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.538389648507611e-05
#             Iterations: 167
#             Function evaluations: 16032
#             Gradient evaluations: 167
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.520082388331777
#             Iterations: 61
#             Function evaluations: 5914
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.416396659296337e-09
#             Iterations: 54
#             Function evaluations: 5185
#             Gradient evaluations: 54
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8988157967969398e-05
#             Iterations: 148
#             Function evaluations: 14356
#             Gradient evaluations: 148
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7798088450072336
#             Iterations: 63
#             Function evaluations: 6175
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3275404878915361e-08
#             Iterations: 89
#             Function evaluations: 8633
#             Gradient evaluations: 89
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9489682625932673e-05
#             Iterations: 170
#             Function evaluations: 16490
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7957236290739407
#             Iterations: 63
#             Function evaluations: 6177
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5115051727250444e-08
#             Iterations: 76
#             Function evaluations: 7373
#             Gradient evaluations: 76
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0516071865082913e-05
#             Iterations: 150
#             Function evaluations: 14701
#             Gradient evaluations: 150
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8121529639482157
#             Iterations: 66
#             Function evaluations: 6538
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5492720625379915e-08
#             Iterations: 76
#             Function evaluations: 7448
#             Gradient evaluations: 76
# 2006-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.107520929030105e-05
#             Iterations: 166
#             Function evaluations: 15936
#             Gradient evaluations: 166
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7544574741271712
#             Iterations: 64
#             Function evaluations: 6211
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.722645271000496e-08
#             Iterations: 76
#             Function evaluations: 7296
#             Gradient evaluations: 76
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0602154199321974e-05
#             Iterations: 171
#             Function evaluations: 16417
#             Gradient evaluations: 171
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.822902175166995
#             Iterations: 67
#             Function evaluations: 6498
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.70694265810574e-08
#             Iterations: 76
#             Function evaluations: 7296
#             Gradient evaluations: 76
# 2006-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.859336722614699e-05
#             Iterations: 185
#             Function evaluations: 17575
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9189283526408087
#             Iterations: 72
#             Function evaluations: 6922
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7341121836785657e-08
#             Iterations: 61
#             Function evaluations: 5795
#             Gradient evaluations: 61
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.848211581640726e-05
#             Iterations: 193
#             Function evaluations: 18335
#             Gradient evaluations: 193
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9138400093513686
#             Iterations: 74
#             Function evaluations: 7110
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7372244999146125e-08
#             Iterations: 64
#             Function evaluations: 6080
#             Gradient evaluations: 64
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.879894591106696e-05
#             Iterations: 171
#             Function evaluations: 15904
#             Gradient evaluations: 171
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.777664138850294
#             Iterations: 66
#             Function evaluations: 6209
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9520871939527587e-08
#             Iterations: 65
#             Function evaluations: 6045
#             Gradient evaluations: 65
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8498700044167204e-05
#             Iterations: 175
#             Function evaluations: 16100
#             Gradient evaluations: 175
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7496689825298715
#             Iterations: 70
#             Function evaluations: 6514
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.095577838774675e-08
#             Iterations: 54
#             Function evaluations: 4968
#             Gradient evaluations: 54
# 2006-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8497221172709398e-05
#             Iterations: 175
#             Function evaluations: 16101
#             Gradient evaluations: 175
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8185710461493176
#             Iterations: 68
#             Function evaluations: 6326
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0152664331088358e-08
#             Iterations: 54
#             Function evaluations: 4969
#             Gradient evaluations: 54
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8258207158484133e-05
#             Iterations: 169
#             Function evaluations: 16224
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8600926287944164
#             Iterations: 68
#             Function evaluations: 6601
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7628881952974482e-08
#             Iterations: 65
#             Function evaluations: 6240
#             Gradient evaluations: 65
# 2007-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.774228791145775e-05
#             Iterations: 188
#             Function evaluations: 17860
#             Gradient evaluations: 188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8292225703675133
#             Iterations: 66
#             Function evaluations: 6338
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8316762300091817e-08
#             Iterations: 64
#             Function evaluations: 6080
#             Gradient evaluations: 64
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7751953917641728e-05
#             Iterations: 183
#             Function evaluations: 17203
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.803397797075611
#             Iterations: 67
#             Function evaluations: 6368
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8797583083189998e-08
#             Iterations: 64
#             Function evaluations: 6016
#             Gradient evaluations: 64
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7516865644601815e-05
#             Iterations: 186
#             Function evaluations: 17299
#             Gradient evaluations: 186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8017437949646453
#             Iterations: 67
#             Function evaluations: 6302
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9186988617134264e-08
#             Iterations: 64
#             Function evaluations: 5953
#             Gradient evaluations: 64
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7664097110933476e-05
#             Iterations: 172
#             Function evaluations: 15997
#             Gradient evaluations: 172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8362923803031426
#             Iterations: 65
#             Function evaluations: 6115
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7797883193813216e-08
#             Iterations: 65
#             Function evaluations: 6045
#             Gradient evaluations: 65
# 2007-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7219946664820252e-05
#             Iterations: 168
#             Function evaluations: 15289
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7915297817783262
#             Iterations: 67
#             Function evaluations: 6169
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9111879712577267e-08
#             Iterations: 65
#             Function evaluations: 5915
#             Gradient evaluations: 65
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7419616911325995e-05
#             Iterations: 177
#             Function evaluations: 16107
#             Gradient evaluations: 177
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.782132099330936
#             Iterations: 65
#             Function evaluations: 5981
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0840218671325276e-08
#             Iterations: 112
#             Function evaluations: 10192
#             Gradient evaluations: 112
# 2007-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7396853545887523e-05
#             Iterations: 179
#             Function evaluations: 16289
#             Gradient evaluations: 179
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.811521535484661
#             Iterations: 63
#             Function evaluations: 5796
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.083958923393602e-08
#             Iterations: 112
#             Function evaluations: 10192
#             Gradient evaluations: 112
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.693962605470126e-05
#             Iterations: 173
#             Function evaluations: 15744
#             Gradient evaluations: 173
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.796489678560132
#             Iterations: 59
#             Function evaluations: 5431
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3031817160400894e-08
#             Iterations: 53
#             Function evaluations: 4824
#             Gradient evaluations: 53
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6357613123748554e-05
#             Iterations: 184
#             Function evaluations: 16744
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.84215631903125
#             Iterations: 59
#             Function evaluations: 5429
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8541803475817104e-08
#             Iterations: 77
#             Function evaluations: 7008
#             Gradient evaluations: 77
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.586322916480075e-05
#             Iterations: 178
#             Function evaluations: 16198
#             Gradient evaluations: 178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8714814499565735
#             Iterations: 62
#             Function evaluations: 5704
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.206737195358215e-08
#             Iterations: 53
#             Function evaluations: 4824
#             Gradient evaluations: 53
# 2007-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.57910789815069e-05
#             Iterations: 184
#             Function evaluations: 16745
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8684028258519065
#             Iterations: 65
#             Function evaluations: 5986
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1948415826841504e-08
#             Iterations: 53
#             Function evaluations: 4824
#             Gradient evaluations: 53
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5758471488050682e-05
#             Iterations: 185
#             Function evaluations: 17020
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.883001163071057
#             Iterations: 63
#             Function evaluations: 5864
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1366683415504856e-08
#             Iterations: 53
#             Function evaluations: 4877
#             Gradient evaluations: 53
# 2008-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5646629539060847e-05
#             Iterations: 185
#             Function evaluations: 17390
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.897810968455996
#             Iterations: 67
#             Function evaluations: 6374
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9786652750111568e-08
#             Iterations: 53
#             Function evaluations: 4983
#             Gradient evaluations: 53
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3981641624274002e-05
#             Iterations: 200
#             Function evaluations: 18800
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.992853530912346
#             Iterations: 70
#             Function evaluations: 6661
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5568148084852073e-08
#             Iterations: 77
#             Function evaluations: 7238
#             Gradient evaluations: 77
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3688944703632502e-05
#             Iterations: 182
#             Function evaluations: 17109
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.988182711582669
#             Iterations: 71
#             Function evaluations: 6656
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7571181290182715e-08
#             Iterations: 54
#             Function evaluations: 5077
#             Gradient evaluations: 54
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.328936410719261e-05
#             Iterations: 186
#             Function evaluations: 17298
#             Gradient evaluations: 186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9828791771284426
#             Iterations: 69
#             Function evaluations: 6492
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.78863629042233e-08
#             Iterations: 54
#             Function evaluations: 5022
#             Gradient evaluations: 54
# 2008-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.290447924928248e-05
#             Iterations: 182
#             Function evaluations: 16927
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8355470903006177
#             Iterations: 67
#             Function evaluations: 6302
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.572872796873821e-08
#             Iterations: 66
#             Function evaluations: 6138
#             Gradient evaluations: 66
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.292885001973641e-05
#             Iterations: 193
#             Function evaluations: 17371
#             Gradient evaluations: 193
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8276655816604532
#             Iterations: 62
#             Function evaluations: 5651
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7707773052186027e-08
#             Iterations: 65
#             Function evaluations: 5850
#             Gradient evaluations: 65
# 2008-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2097166763145687e-05
#             Iterations: 188
#             Function evaluations: 16732
#             Gradient evaluations: 188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.811585772941292
#             Iterations: 63
#             Function evaluations: 5673
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6960256591147298e-08
#             Iterations: 77
#             Function evaluations: 6853
#             Gradient evaluations: 77
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.008922165344392e-05
#             Iterations: 187
#             Function evaluations: 16643
#             Gradient evaluations: 187
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.880528462193917
#             Iterations: 64
#             Function evaluations: 5763
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.738540665547264e-08
#             Iterations: 77
#             Function evaluations: 6853
#             Gradient evaluations: 77
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1746963276223782e-05
#             Iterations: 178
#             Function evaluations: 16020
#             Gradient evaluations: 178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.802804330880123
#             Iterations: 65
#             Function evaluations: 5916
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.478666736240905e-08
#             Iterations: 62
#             Function evaluations: 5580
#             Gradient evaluations: 62
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.160461351521644e-05
#             Iterations: 174
#             Function evaluations: 15834
#             Gradient evaluations: 174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7906809085224302
#             Iterations: 64
#             Function evaluations: 5891
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.546302448459052e-08
#             Iterations: 52
#             Function evaluations: 4733
#             Gradient evaluations: 52
# 2008-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.752900726053111e-05
#             Iterations: 154
#             Function evaluations: 14015
#             Gradient evaluations: 154
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9786226596152585
#             Iterations: 65
#             Function evaluations: 5988
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1156007788824816e-08
#             Iterations: 67
#             Function evaluations: 6097
#             Gradient evaluations: 67
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6426647808612825e-05
#             Iterations: 170
#             Function evaluations: 15300
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.984968525652589
#             Iterations: 67
#             Function evaluations: 6102
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.48890452923364e-09
#             Iterations: 68
#             Function evaluations: 6120
#             Gradient evaluations: 68
# 2009-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.557272772313357e-05
#             Iterations: 180
#             Function evaluations: 16200
#             Gradient evaluations: 180
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.003311777222558
#             Iterations: 69
#             Function evaluations: 6286
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0039329544073006e-08
#             Iterations: 57
#             Function evaluations: 5130
#             Gradient evaluations: 57
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4959275936066065e-05
#             Iterations: 182
#             Function evaluations: 16381
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9695033278737797
#             Iterations: 67
#             Function evaluations: 6107
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2449555764501302e-08
#             Iterations: 45
#             Function evaluations: 4051
#             Gradient evaluations: 45
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4412624137867186e-05
#             Iterations: 212
#             Function evaluations: 19292
#             Gradient evaluations: 212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.987650236669764
#             Iterations: 70
#             Function evaluations: 6443
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1002270513305682e-08
#             Iterations: 45
#             Function evaluations: 4095
#             Gradient evaluations: 45
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3149228554381234e-05
#             Iterations: 184
#             Function evaluations: 16744
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.012672067577578
#             Iterations: 65
#             Function evaluations: 5983
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0117920740252691e-08
#             Iterations: 45
#             Function evaluations: 4095
#             Gradient evaluations: 45
# 2009-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2759816708876583e-05
#             Iterations: 197
#             Function evaluations: 18124
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9755252244141155
#             Iterations: 62
#             Function evaluations: 5772
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.014722118329238e-08
#             Iterations: 45
#             Function evaluations: 4140
#             Gradient evaluations: 45
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2440147968821738e-05
#             Iterations: 184
#             Function evaluations: 16928
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9379849610427873
#             Iterations: 63
#             Function evaluations: 5864
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0350002062410654e-08
#             Iterations: 45
#             Function evaluations: 4140
#             Gradient evaluations: 45
# 2009-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.224039506077227e-05
#             Iterations: 192
#             Function evaluations: 17664
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.957540228964773
#             Iterations: 63
#             Function evaluations: 5865
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.864665106648274e-09
#             Iterations: 45
#             Function evaluations: 4140
#             Gradient evaluations: 45
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.192163490223978e-05
#             Iterations: 209
#             Function evaluations: 19019
#             Gradient evaluations: 209
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.967585665962645
#             Iterations: 64
#             Function evaluations: 5891
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.477435806032482e-09
#             Iterations: 45
#             Function evaluations: 4095
#             Gradient evaluations: 45
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1947180593844054e-05
#             Iterations: 224
#             Function evaluations: 20160
#             Gradient evaluations: 224
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9672745189518155
#             Iterations: 64
#             Function evaluations: 5826
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1348504165680591e-08
#             Iterations: 33
#             Function evaluations: 2971
#             Gradient evaluations: 33
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.186821413511566e-05
#             Iterations: 176
#             Function evaluations: 16016
#             Gradient evaluations: 176
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9981499280409136
#             Iterations: 67
#             Function evaluations: 6168
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.836659216499244e-09
#             Iterations: 45
#             Function evaluations: 4095
#             Gradient evaluations: 45
# 2009-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1810514113872948e-05
#             Iterations: 207
#             Function evaluations: 18630
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.912661248431007
#             Iterations: 66
#             Function evaluations: 6013
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1087016470350742e-08
#             Iterations: 33
#             Function evaluations: 2971
#             Gradient evaluations: 33
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1702763071885827e-05
#             Iterations: 214
#             Function evaluations: 19046
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.908567372366583
#             Iterations: 66
#             Function evaluations: 5942
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1009345079385682e-08
#             Iterations: 33
#             Function evaluations: 2938
#             Gradient evaluations: 33
# 2010-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1587936958867923e-05
#             Iterations: 222
#             Function evaluations: 19759
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.930462479331814
#             Iterations: 65
#             Function evaluations: 5856
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0559173001677814e-08
#             Iterations: 33
#             Function evaluations: 2937
#             Gradient evaluations: 33
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1514245531913933e-05
#             Iterations: 197
#             Function evaluations: 17533
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9624131414699866
#             Iterations: 70
#             Function evaluations: 6304
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0558141527760709e-08
#             Iterations: 33
#             Function evaluations: 2937
#             Gradient evaluations: 33
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1168276247972789e-05
#             Iterations: 185
#             Function evaluations: 16650
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.028362609653034
#             Iterations: 66
#             Function evaluations: 6015
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0159841433838894e-08
#             Iterations: 32
#             Function evaluations: 2881
#             Gradient evaluations: 32
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1177858174979662e-05
#             Iterations: 199
#             Function evaluations: 17910
#             Gradient evaluations: 199
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.028568104717582
#             Iterations: 71
#             Function evaluations: 6466
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.008431545448643e-08
#             Iterations: 32
#             Function evaluations: 2881
#             Gradient evaluations: 32
# 2010-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1449947229964789e-05
#             Iterations: 178
#             Function evaluations: 16021
#             Gradient evaluations: 178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9796816704437408
#             Iterations: 66
#             Function evaluations: 6008
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.997482133194316e-09
#             Iterations: 33
#             Function evaluations: 2970
#             Gradient evaluations: 33
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.131234574245231e-05
#             Iterations: 202
#             Function evaluations: 18180
#             Gradient evaluations: 202
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.049140687277183
#             Iterations: 75
#             Function evaluations: 6833
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.677783689712275e-09
#             Iterations: 34
#             Function evaluations: 3060
#             Gradient evaluations: 34
# 2010-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2173719738049303e-05
#             Iterations: 184
#             Function evaluations: 16929
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.050669058918973
#             Iterations: 73
#             Function evaluations: 6792
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.957567107488833e-09
#             Iterations: 34
#             Function evaluations: 3128
#             Gradient evaluations: 34
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2284518392833594e-05
#             Iterations: 196
#             Function evaluations: 18033
#             Gradient evaluations: 196
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.052021377399112
#             Iterations: 70
#             Function evaluations: 6518
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.970709719200275e-09
#             Iterations: 34
#             Function evaluations: 3128
#             Gradient evaluations: 34
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2430638844272873e-05
#             Iterations: 187
#             Function evaluations: 17018
#             Gradient evaluations: 187
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.012623580253958
#             Iterations: 73
#             Function evaluations: 6721
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.939044788780081e-09
#             Iterations: 34
#             Function evaluations: 3094
#             Gradient evaluations: 34
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1532523998919532e-05
#             Iterations: 183
#             Function evaluations: 16837
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.069293759428236
#             Iterations: 71
#             Function evaluations: 6610
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.200489675689115e-09
#             Iterations: 34
#             Function evaluations: 3128
#             Gradient evaluations: 34
# 2010-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2535705835880732e-05
#             Iterations: 195
#             Function evaluations: 17745
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9897526982895015
#             Iterations: 69
#             Function evaluations: 6356
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.004662917813097e-09
#             Iterations: 34
#             Function evaluations: 3094
#             Gradient evaluations: 34
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1516327220457008e-05
#             Iterations: 179
#             Function evaluations: 16647
#             Gradient evaluations: 179
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.074655764351112
#             Iterations: 72
#             Function evaluations: 6777
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.411634976035174e-09
#             Iterations: 34
#             Function evaluations: 3162
#             Gradient evaluations: 34
# 2011-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1230278020529585e-05
#             Iterations: 185
#             Function evaluations: 17390
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.080013947233863
#             Iterations: 71
#             Function evaluations: 6753
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.391916689069692e-09
#             Iterations: 34
#             Function evaluations: 3196
#             Gradient evaluations: 34
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3143818255664502e-05
#             Iterations: 181
#             Function evaluations: 16653
#             Gradient evaluations: 181
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9274841755826966
#             Iterations: 72
#             Function evaluations: 6698
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.712708175206343e-09
#             Iterations: 34
#             Function evaluations: 3128
#             Gradient evaluations: 34
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2982476376089299e-05
#             Iterations: 191
#             Function evaluations: 17573
#             Gradient evaluations: 191
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9365746470916463
#             Iterations: 72
#             Function evaluations: 6704
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.676929075154482e-09
#             Iterations: 34
#             Function evaluations: 3128
#             Gradient evaluations: 34
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2921940966027736e-05
#             Iterations: 166
#             Function evaluations: 15106
#             Gradient evaluations: 166
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.937597431937515
#             Iterations: 72
#             Function evaluations: 6628
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.970370274254192e-09
#             Iterations: 34
#             Function evaluations: 3094
#             Gradient evaluations: 34
# 2011-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2843352773717294e-05
#             Iterations: 190
#             Function evaluations: 17480
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9824813638848644
#             Iterations: 72
#             Function evaluations: 6702
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0025569470256309e-08
#             Iterations: 22
#             Function evaluations: 2025
# ...
#             Current function value: 1.4061249407721736e-05
#             Iterations: 251
#             Function evaluations: 30121
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.182432320170411
#             Iterations: 86
#             Function evaluations: 10442
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8906880534926433e-08
#             Iterations: 38
#             Function evaluations: 4560
#             Gradient evaluations: 38
# 2020-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3105976984704513e-05
#             Iterations: 258
#             Function evaluations: 30702
#             Gradient evaluations: 258
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.139592310324112
#             Iterations: 88
#             Function evaluations: 10599
#             Gradient evaluations: 88
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.508316522908584e-08
#             Iterations: 52
#             Function evaluations: 6188
#             Gradient evaluations: 52
# 2020-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3203873311013886e-05
#             Iterations: 265
#             Function evaluations: 31536
#             Gradient evaluations: 265
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.019870891996972
#             Iterations: 87
#             Function evaluations: 10473
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6836525643345486e-08
#             Iterations: 44
#             Function evaluations: 5237
#             Gradient evaluations: 44
# 2020-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2159942409154618e-05
#             Iterations: 271
#             Function evaluations: 32520
#             Gradient evaluations: 271
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.087858519116964
#             Iterations: 95
#             Function evaluations: 11062
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.070498583076194e-08
#             Iterations: 44
#             Function evaluations: 5281
#             Gradient evaluations: 44
# 2020-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1761580134882781e-05
#             Iterations: 286
#             Function evaluations: 35178
#             Gradient evaluations: 286
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.250947717847296
#             Iterations: 93
#             Function evaluations: 11568
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8377605992132478e-08
#             Iterations: 44
#             Function evaluations: 5413
#             Gradient evaluations: 44
# 2020-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2046807795730703e-05
#             Iterations: 261
#             Function evaluations: 32104
#             Gradient evaluations: 261
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.246931296347366
#             Iterations: 93
#             Function evaluations: 11573
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7493281461975763e-08
#             Iterations: 44
#             Function evaluations: 5413
#             Gradient evaluations: 44
# 2020-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1675814238834481e-05
#             Iterations: 281
#             Function evaluations: 34282
#             Gradient evaluations: 281
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.223144691740968
#             Iterations: 93
#             Function evaluations: 11478
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7580629892993912e-08
#             Iterations: 44
#             Function evaluations: 5369
#             Gradient evaluations: 44
# 2021-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1550904009045738e-05
#             Iterations: 277
#             Function evaluations: 33795
#             Gradient evaluations: 277
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.238863578574811
#             Iterations: 90
#             Function evaluations: 11111
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.770959219044438e-08
#             Iterations: 45
#             Function evaluations: 5490
#             Gradient evaluations: 45
# 2021-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1415852364490744e-05
#             Iterations: 283
#             Function evaluations: 34809
#             Gradient evaluations: 283
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.280021141628906
#             Iterations: 92
#             Function evaluations: 11452
#             Gradient evaluations: 92
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7156579929706467e-08
#             Iterations: 45
#             Function evaluations: 5535
#             Gradient evaluations: 45
# 2021-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1446357739078232e-05
#             Iterations: 299
#             Function evaluations: 36179
#             Gradient evaluations: 299
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.15228271010477
#             Iterations: 90
#             Function evaluations: 11022
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9578604979218956e-08
#             Iterations: 31
#             Function evaluations: 3752
#             Gradient evaluations: 31
# 2021-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.133264014682544e-05
#             Iterations: 301
#             Function evaluations: 36120
#             Gradient evaluations: 301
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.163389834560726
#             Iterations: 87
#             Function evaluations: 10571
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7832846378786148e-08
#             Iterations: 44
#             Function evaluations: 5280
#             Gradient evaluations: 44
# 2021-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1387749674263859e-05
#             Iterations: 284
#             Function evaluations: 34365
#             Gradient evaluations: 284
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.13354361959772
#             Iterations: 84
#             Function evaluations: 10288
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7688311046588135e-08
#             Iterations: 45
#             Function evaluations: 5445
#             Gradient evaluations: 45
# 2021-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1406006886986887e-05
#             Iterations: 295
#             Function evaluations: 35991
#             Gradient evaluations: 295
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.095450791043072
#             Iterations: 85
#             Function evaluations: 10497
#             Gradient evaluations: 85
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.713421399405979e-08
#             Iterations: 45
#             Function evaluations: 5490
#             Gradient evaluations: 45
# 2021-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1481406854441585e-05
#             Iterations: 280
#             Function evaluations: 34721
#             Gradient evaluations: 280
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.130470072339099
#             Iterations: 86
#             Function evaluations: 10790
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7651308330794668e-08
#             Iterations: 39
#             Function evaluations: 4836
#             Gradient evaluations: 39
# 2021-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1540562400862898e-05
#             Iterations: 282
#             Function evaluations: 35250
#             Gradient evaluations: 282
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.1726124086524035
#             Iterations: 169
#             Function evaluations: 21394
#             Gradient evaluations: 165
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6943606727114876e-08
#             Iterations: 44
#             Function evaluations: 5500
#             Gradient evaluations: 44
# 2021-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.142023705883947e-05
#             Iterations: 285
#             Function evaluations: 36480
#             Gradient evaluations: 285
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.15995897145018
#             Iterations: 89
#             Function evaluations: 11522
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6471727082272478e-08
#             Iterations: 43
#             Function evaluations: 5504
#             Gradient evaluations: 43
# 2021-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1327308817049432e-05
#             Iterations: 295
#             Function evaluations: 38055
#             Gradient evaluations: 295
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.157301382982434
#             Iterations: 89
#             Function evaluations: 11614
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.609313742721186e-08
#             Iterations: 44
#             Function evaluations: 5676
#             Gradient evaluations: 44
# 2021-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1011236663764686e-05
#             Iterations: 288
#             Function evaluations: 37441
#             Gradient evaluations: 288
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.241373219641934
#             Iterations: 92
#             Function evaluations: 12095
#             Gradient evaluations: 92
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5919638409165734e-08
#             Iterations: 44
#             Function evaluations: 5720
#             Gradient evaluations: 44
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0929315004488973e-05
#             Iterations: 297
#             Function evaluations: 38908
#             Gradient evaluations: 297
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.2389263006399265
#             Iterations: 92
#             Function evaluations: 12182
#             Gradient evaluations: 92
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4957668204951477e-08
#             Iterations: 44
#             Function evaluations: 5764
#             Gradient evaluations: 44
# 2022-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0786801394116696e-05
#             Iterations: 297
#             Function evaluations: 38908
#             Gradient evaluations: 297
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.264825383339145
#             Iterations: 90
#             Function evaluations: 11920
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4775578873396823e-08
#             Iterations: 44
#             Function evaluations: 5764
#             Gradient evaluations: 44
# 2022-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.076375001981741e-05
#             Iterations: 295
#             Function evaluations: 38646
#             Gradient evaluations: 295
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.232317573245395
#             Iterations: 91
#             Function evaluations: 12051
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4195888871512032e-08
#             Iterations: 44
#             Function evaluations: 5764
#             Gradient evaluations: 44
# 2022-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1536498102148533e-05
#             Iterations: 291
#             Function evaluations: 37830
#             Gradient evaluations: 291
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.0355077410757945
#             Iterations: 90
#             Function evaluations: 11830
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3967484236187856e-08
#             Iterations: 44
#             Function evaluations: 5720
#             Gradient evaluations: 44
# 2022-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0680486905027005e-05
#             Iterations: 277
#             Function evaluations: 35457
#             Gradient evaluations: 277
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.116076021252605
#             Iterations: 194
#             Function evaluations: 25366
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4163499990505707e-08
#             Iterations: 43
#             Function evaluations: 5504
#             Gradient evaluations: 43
# 2022-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1614853830799375e-05
#             Iterations: 314
#             Function evaluations: 40192
#             Gradient evaluations: 314
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.770136384056668
#             Iterations: 80
#             Function evaluations: 10351
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6297237545990562e-08
#             Iterations: 42
#             Function evaluations: 5377
#             Gradient evaluations: 42
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_shrinked_JSE.to_csv("returnsWhartonshrinked_neu_3jahre_f.csv")

# %% [markdown]
# ### Reduzierter S&P500-Bestand

# %% [markdown]
# ### Reduziert und Ledoit-Shrinkage
