# %% [markdown]
# Hier werden die Portfolio-Methoden angewandt und mithilfe der Performance-Metriken bewertet. Die Ergebnisse werden in CSV-Dateien festgehalten. Das Akquirieren, modifizieren und beschreiben der Daten befindet sich der Übersicht halber im Notebook Datenbasis. Die Daten werden dort als CSV exportiert und hier als Dataframe wieder eingelesen.
#
# Die Korrektheit der implementierten Methoden und Metriken wird in dem separaten Notebook Verifizierung anhand eines kleinen Teilbestandes aufgezeigt, siehe dazu auch beigefügte Excel-Dateien, in denen die Portfolio-Gewichte "per Hand" nachgerechnet und mit den Ergebnissen aus der Python-Implementierung abgeglichen werden.
#
# ACHTUNG: LANGE LAUFZEIT!

# %% [markdown]
# ## Importe

# %%
#Import der notwendigen Bibliotheken, Installation mit pip bereits erfolgt

import yfinance as yf
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import csv
from scipy.optimize import minimize
import math
import random
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import linkage, dendrogram
import riskfolio as rp
from sklearn.covariance import LedoitWolf
from scipy.spatial.distance import squareform
from riskfolio import HCPortfolio as hc
from pandas.tseries.offsets import MonthBegin
from pandas.tseries.offsets import MonthEnd

# %% [markdown]
# ## Einlesen der Daten

# %%
#Bearbeitete JSE-Daten (Gesamtbestand)

df_JSE = pd.read_csv(
    'df_JSE_Final_V7.csv',
    sep=',',
    encoding='utf-8',
    index_col=0,
    decimal = '.',
    low_memory=False,
    parse_dates=['Date'],
    dayfirst=True
)

# %%
df_JSE.info
# Out:
# <bound method DataFrame.info of             4SI.JO   ABG.JO  ACL.JO  ACT.JO       ADH.JO  AEL.JO  \
# Date
# 2005-06-01     NaN   8240.0  4980.0   130.0   133.701508     NaN
# 2005-06-02     NaN   8250.0  4949.0   130.0   131.749695     NaN
# 2005-06-03     NaN   8261.0  4949.0   130.0   131.749695     NaN
# 2005-06-06     NaN   8290.0  5023.0   130.0   132.725601     NaN
# 2005-06-07     NaN   8345.0  4845.0   149.0   131.749695     NaN
# ...            ...      ...     ...     ...          ...     ...
# 2025-05-26    70.0  16845.0   109.0   160.0  3199.000000  2350.0
# 2025-05-27    70.0  16848.0   105.0   160.0  3210.000000  2350.0
# 2025-05-28    73.0  17300.0   101.0   174.0  3283.000000  2355.0
# 2025-05-29    70.0  17579.0   106.0   166.0  3247.000000  2362.0
# 2025-05-30    70.0  17332.0   116.0   160.0  3215.000000  2358.0
#
#                   AFE.JO  AFH.JO  AFT.JO        AGL.JO  ...  VKE.JO   VOD.JO  \
# Date                                                    ...
# 2005-06-01   4338.178711     NaN     NaN  21158.730469  ...     NaN  11100.0
# 2005-06-02   4427.728516     NaN     NaN  21274.703125  ...     NaN  11290.0
# 2005-06-03   4427.728516     NaN     NaN  21274.703125  ...     NaN  11290.0
# 2005-06-06   4427.728516     NaN     NaN  20868.796875  ...     NaN  11802.0
# 2005-06-07   4428.723633     NaN     NaN  20430.673828  ...     NaN  11800.0
# ...                  ...     ...     ...           ...  ...     ...      ...
# 2025-05-26  10342.000000   920.0  5057.0  53638.527344  ...  1900.0  13465.0
# 2025-05-27  10417.000000   896.0  5191.0  52658.546875  ...  1912.0  13505.0
# 2025-05-28  10444.000000   912.0  5191.0  52193.621094  ...  1914.0  13420.0
# 2025-05-29  10326.000000   900.0  5147.0  51899.722656  ...  1941.0  13849.0
# 2025-05-30  10335.000000   890.0  5200.0  52778.464844  ...  2001.0  13777.0
#
#             WBC.JO   WBO.JO  WEZ.JO       WHL.JO      YRK.JO  YYLBEE.JO  \
# Date
# 2005-06-01     NaN   2650.0     NaN   961.656494  736.937988        NaN
# 2005-06-02     NaN   2675.0     NaN   971.177917  736.937988        NaN
# 2005-06-03     NaN   2675.0     NaN   971.177917  736.937988        NaN
# 2005-06-06     NaN   2700.0     NaN   996.885498  736.937988        NaN
# 2005-06-07     NaN   2700.0     NaN  1009.263306  736.937988        NaN
# ...            ...      ...     ...          ...         ...        ...
# 2025-05-26  4800.0  18172.0    50.0  5730.000000  204.000000     2701.0
# 2025-05-27  4875.0  18317.0    45.0  5680.000000  204.000000     2701.0
# 2025-05-28  4822.0  17983.0    44.0  5765.000000  187.000000     2701.0
# 2025-05-29  4889.0  17884.0    45.0  5858.000000  190.000000     2701.0
# 2025-05-30  4900.0  18152.0    43.0  5860.000000  195.000000     2701.0
#
#             ZED.JO  ZZD.JO
# Date
# 2005-06-01     NaN     NaN
# 2005-06-02     NaN     NaN
# 2005-06-03     NaN     NaN
# 2005-06-06     NaN     NaN
# 2005-06-07     NaN     NaN
# ...            ...     ...
# 2025-05-26   120.0  1157.0
# 2025-05-27   118.0  1200.0
# 2025-05-28   125.0  1210.0
# 2025-05-29   126.0  1200.0
# 2025-05-30   129.0  1185.0
#
# [5171 rows x 217 columns]>

# %%
#Bearbeitete SP500-Daten (Gesamtbestand)

df_SP500 = pd.read_csv(
    'df_SP500_Final_V7.csv',
    sep=',',
    encoding='utf-8',
    index_col=0,
    decimal = '.',
    low_memory=False,
    parse_dates=['Date'],
    dayfirst=True
)

# %%
df_SP500.info
# Out:
# <bound method DataFrame.info of                      A  AAL  AAP        AAPL        ABBV        ABNB  \
# Date
# 2005-06-01   17.296137  NaN  NaN    1.439286         NaN         NaN
# 2005-06-02   17.303289  NaN  NaN    1.430000         NaN         NaN
# 2005-06-03   17.210300  NaN  NaN    1.365714         NaN         NaN
# 2005-06-06   17.539343  NaN  NaN    1.354286         NaN         NaN
# 2005-06-07   17.324751  NaN  NaN    1.305000         NaN         NaN
# ...                ...  ...  ...         ...         ...         ...
# 2025-05-23  108.529999  NaN  NaN  195.270004  183.259995  126.720001
# 2025-05-27  111.260002  NaN  NaN  200.210007  185.720001  129.399994
# 2025-05-28  110.879997  NaN  NaN  200.419998  183.089996  128.669998
# 2025-05-29  113.279999  NaN  NaN  199.949997  185.619995  128.360001
# 2025-05-30  111.919998  NaN  NaN  200.850006  186.110001  129.000000
#
#                    ABT       ACGL         ACN        ADBE  ...        XEL  \
# Date                                                       ...
# 2005-06-01   23.188734        NaN         NaN   33.180000  ...  18.670000
# 2005-06-02   23.155148        NaN         NaN   33.090000  ...  18.719999
# 2005-06-03   23.159946        NaN         NaN   32.540001  ...  18.809999
# 2005-06-06   23.246309        NaN         NaN   32.450001  ...  18.820000
# 2005-06-07   23.395048        NaN         NaN   32.259998  ...  18.900000
# ...                ...        ...         ...         ...  ...        ...
# 2025-05-23  131.300003  92.070000  309.579987  407.690002  ...  69.730003
# 2025-05-27  132.940002  94.620003  315.429993  413.100006  ...  69.809998
# 2025-05-28  132.020004  92.980003  315.989990  412.230011  ...  68.930000
# 2025-05-29  132.850006  94.199997  317.730011  413.359985  ...  69.470001
# 2025-05-30  133.580002  95.040001  316.820007  415.089996  ...  70.099998
#
#                    XOM  XRAY        XRX         XYL         YUM        ZBH  \
# Date
# 2005-06-01   57.150002   NaN  36.100132         NaN   18.508266  74.029129
# 2005-06-02   57.320000   NaN  35.968380         NaN   18.907261  74.242722
# 2005-06-03   57.150002   NaN  35.731224         NaN   18.705967  76.456314
# 2005-06-06   57.599998   NaN  35.335968         NaN   18.691589  76.067963
# 2005-06-07   57.450001   NaN  35.098812         NaN   18.749102  77.106796
# ...                ...   ...        ...         ...         ...        ...
# 2025-05-23  103.029999   NaN        NaN  124.050003  145.449997  92.639999
# 2025-05-27  103.519997   NaN        NaN  126.239998  144.089996  94.209999
# 2025-05-28  102.110001   NaN        NaN  125.650002  143.149994  92.290001
# 2025-05-29  102.690002   NaN        NaN  125.660004  144.039993  93.339996
# 2025-05-30  102.300003   NaN        NaN  126.040001  143.940002  92.169998
#
#                   ZBRA       ZION         ZTS
# Date
# 2005-06-01         NaN  72.330002         NaN
# 2005-06-02         NaN  72.760002         NaN
# 2005-06-03         NaN  72.160004         NaN
# 2005-06-06         NaN  72.150002         NaN
# 2005-06-07         NaN  71.949997         NaN
# ...                ...        ...         ...
# 2025-05-23  284.209992        NaN  162.580002
# 2025-05-27  295.010010        NaN  166.259995
# 2025-05-28  290.799988        NaN  165.399994
# 2025-05-29  292.500000        NaN  167.139999
# 2025-05-30  289.769989        NaN  168.630005
#
# [5032 rows x 598 columns]>

# %%
#Reduzierter SP500-Bestand ohne ausgeschiedene Unternehmen und auf Größe des JSE runtergebrochen

df_SP500_reduziert = pd.read_csv(
    'sp500_gefiltert_neuneu.csv',
    sep=',',
    encoding='utf-8',
    index_col=0,
    decimal = '.',
    low_memory=False,
    dayfirst=True
)

# %%
df_SP500_reduziert.info
# Out:
# <bound method DataFrame.info of                      A        AAPL         ABT        ADM         ADP  \
# Date
# 2005-06-01   17.296137    1.439286         NaN  20.100000   34.918613
# 2005-06-02   17.303289    1.430000         NaN  20.430000   35.053432
# 2005-06-03   17.210300    1.365714         NaN  20.219999   34.617249
# 2005-06-06   17.539343    1.354286         NaN  20.150000   34.728275
# 2005-06-07   17.324751    1.305000         NaN  20.690001   34.664829
# ...                ...         ...         ...        ...         ...
# 2025-05-23  108.529999  195.270004  131.300003  47.939999  321.089996
# 2025-05-27  111.260002  200.210007  132.940002  48.630001  325.709991
# 2025-05-28  110.879997  200.419998  132.020004  48.349998  324.140015
# 2025-05-29  113.279999  199.949997  132.850006  48.369999  324.119995
# 2025-05-30  111.919998  200.850006  133.580002  48.270000  325.529999
#
#                   ADSK        AEE         AEP    AES         AFL  ...  \
# Date                                                              ...
# 2005-06-01         NaN  55.000000   35.910000  14.79   20.940001  ...
# 2005-06-02         NaN  55.070000   35.820000  14.57   21.205000  ...
# 2005-06-03         NaN  54.820000   35.799999  14.40   21.145000  ...
# 2005-06-06         NaN  53.400002   35.919998  15.00   21.280001  ...
# 2005-06-07         NaN  53.709999   35.799999  14.94   20.900000  ...
# ...                ...        ...         ...    ...         ...  ...
# 2025-05-23  295.350006  96.300003  102.879997   9.99  102.529999  ...
# 2025-05-27  300.359985  96.690002  102.910004  10.07  103.410004  ...
# 2025-05-28  299.230011  95.320000  101.680000   9.70  101.989998  ...
# 2025-05-29  297.000000  96.169998  102.529999  10.05  102.809998  ...
# 2025-05-30  296.119995  96.879997  103.489998  10.09  103.540001  ...
#
#                   WELL        WFC          WM        WMB        WMT  \
# Date
# 2005-06-01         NaN        NaN   29.610001  15.244240  15.973333
# 2005-06-02         NaN        NaN   29.580000  15.203480  16.073334
# 2005-06-03         NaN        NaN   29.690001  15.325760  15.783333
# 2005-06-06         NaN        NaN   29.559999  15.350216  15.910000
# 2005-06-07         NaN        NaN   29.180000  15.219784  15.920000
# ...                ...        ...         ...        ...        ...
# 2025-05-23  149.169998  72.830002  236.809998  58.990002  96.339996
# 2025-05-27  152.470001  73.989998  238.029999  60.099998  97.580002
# 2025-05-28  151.699997  73.730003  237.149994  60.619999  97.239998
# 2025-05-29  153.070007  74.510002  237.759995  60.270000  97.099998
# 2025-05-30  154.279999  74.779999  240.970001  60.509998  98.720001
#
#                    WST         WTW         WY         YUM        ZBH
# Date
# 2005-06-01         NaN         NaN  64.919998         NaN  74.029129
# 2005-06-02         NaN         NaN  64.889999         NaN  74.242722
# 2005-06-03         NaN         NaN  64.110001         NaN  76.456314
# 2005-06-06         NaN         NaN  64.739998         NaN  76.067963
# 2005-06-07         NaN         NaN  65.410004         NaN  77.106796
# ...                ...         ...        ...         ...        ...
# 2025-05-23  205.589996  309.019989  25.230000  145.449997  92.639999
# 2025-05-27  211.020004  312.649994  25.830000  144.089996  94.209999
# 2025-05-28  211.389999  311.010010  25.889999  143.149994  92.290001
# 2025-05-29  210.460007  315.279999  26.040001  144.039993  93.339996
# 2025-05-30  210.850006  316.549988  25.910000  143.940002  92.169998
#
# [5032 rows x 219 columns]>

# %% [markdown]
# ## Definition der Methoden und Metriken

# %% [markdown]
# #### Equally-Weighted Portfolio

# %%
#Rückgabe gleicher Gewichte anhand der Anzahl der Unternehmen (Input Returns)

def equally_weighted(returns):
    anzahl_assets = returns.shape[1]

    w0 = 1/anzahl_assets
    gewichte = np.full(anzahl_assets, w0)

    return gewichte

# %% [markdown]
# #### Minimum-Variance Portfolio

# %%
#Minimum-Variance Portfolio
#Code adaptiert von https://medium.com/@BorisGerat/mean-variance-and-minimum-variance-portfolio-models-in-python-64a5c6b57b2d

def min_variance_opt(matrix):
    
    #Compute the minimum-variance portfolio weights subject to the constraints of:
    #- No short-selling (weights must be >= 0)
    #- Full investment (sum of weights must equal 1)
    
    number_of_assets = matrix.shape[0]

    # Define the objective function to minimize portfolio variance
    def objective(w):
        portfolio_variance = np.dot(w, matrix @ w)
        return portfolio_variance

    # Constraint: The sum of portfolio weights must be equal to 1
    constraints = [{'type': 'eq', 'fun': lambda w: np.sum(w) - 1}]

    # Bounds: Each weight must be between 0 and 1 (no short-selling)
    bounds = [[0, 1] for _ in range(number_of_assets)]

    # Initial guess: Equal weights for all assets
    w0 = np.ones(number_of_assets) / number_of_assets

    # Solve the optimization problem using Sequential Least Squares Quadratic Programming (SLSQP)
    res = minimize(objective, w0, method='SLSQP', bounds=bounds, constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    
    return res.x  # Return the optimal weights

# %% [markdown]
# #### Maximum Diversification Portfolio

# %%
#Code von https://thequantmba.wordpress.com/2017/06/06/max-diversification-in-python/ adaptiert

def calc_max_diversification_ratio(weights, matrix):
    
    # gewichtete Volatilität
    average_vol = np.dot(np.sqrt(np.diag(matrix)), weights.T)
    
    # portfolio volatilität
    portfolio_variance = np.dot(weights, matrix @ weights)
    portfolio_vol = np.sqrt(portfolio_variance)
    
    #Bestimmung Ratio
    diversification_ratio = average_vol/portfolio_vol
    
    # Negativer Wert für Minimierung (Maximizieren = Minimieren -)
    return -diversification_ratio

# %%
#Code von https://thequantmba.wordpress.com/2017/06/06/max-diversification-in-python/ adaptiert

def max_diversification_portfolio(matrix):
    
    anzahl_assets = matrix.shape[0]
    
    w0 = 1/anzahl_assets
    w = np.full(anzahl_assets, w0)
    
    # Constraint: The sum of portfolio weights must be equal to 1
    constraints = [{'type': 'eq', 'fun': lambda w: np.sum(w) - 1}]
    
    # Bounds: Each weight must be between 0 and 1 (no short-selling)
    bounds = [[0, 1] for _ in range(anzahl_assets)]
    
    res = minimize(calc_max_diversification_ratio, w, bounds=bounds, args=matrix, method='SLSQP', constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    return res.x

# %% [markdown]
# #### Inverse Volatility Portfolio

# %%
#Code adaptiert von https://www.kaggle.com/code/vijipai/lesson-4-traditional-portfolio-construction-method

def inverse_volatility_portfolio (matrix):
    
    standardabweichungen = np.sqrt(np.diagonal(matrix))
    invertierte_std = 1/standardabweichungen
    summe_invertierte_std = np.sum(invertierte_std)
    
    inverse_volatility_gewichte = invertierte_std / summe_invertierte_std
    
    return inverse_volatility_gewichte

# %% [markdown]
# #### Equal Risk Contribution Portfolio

# %%
#Code adaptiert von https://medium.com/@deepml1818/building-a-python-based-risk-parity-portfolio-for-trading-40441ecdd84d

def calculate_portfolio_volatility(weights, matrix):
    
    portfolio_variance = np.dot(weights, matrix @ weights)
    portfolio_volatility = np.sqrt(portfolio_variance)
    return portfolio_volatility

def calculate_risk_contribution(weights, matrix):
    portfolio_volatility = calculate_portfolio_volatility(weights, matrix)
    marginal_contribution_zaehler = np.dot(matrix, weights)
    risk_contribution = np.multiply(weights, marginal_contribution_zaehler) / portfolio_volatility
    return risk_contribution

def risk_parity_objective(weights, matrix):
    risk_contribution = calculate_risk_contribution(weights, matrix)
    target_risk = np.mean(risk_contribution)
    return np.sum((risk_contribution - target_risk) ** 2)

# %%
def get_risk_parity_weights(matrix):
    
    number_of_assets = matrix.shape[0]
    w0 = 1/number_of_assets
    initial_weights = np.full(number_of_assets, w0)
    
    constraints = ({'type': 'eq', 'fun': lambda initial_weights: np.sum(initial_weights) - 1})
    bounds = [[0, 1] for _ in range(number_of_assets)]
    
    result = minimize(risk_parity_objective, initial_weights, args=(matrix), method='SLSQP', bounds=bounds, constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    
    return result.x

# %% [markdown]
# #### Hierarchical Risk Parity

# %%
#Aus dem Paper von Lopez De Prado (2016)
def getIVP(cov,**kargs): # Compute the inverse-variance portfolio 
    ivp=1./np.diag(cov) 
    ivp/=ivp.sum() 
    return ivp

# %%
#------------------------------------------------------------------------------ 
def getClusterVar(cov,cItems): # Compute variance per cluster 
    cov_=cov.loc[cItems,cItems] # matrix slice 
    w_=getIVP(cov_).reshape(-1,1) 
    cVar=np.dot(np.dot(w_.T,cov_),w_)[0,0] 
    return cVar

# %%
#------------------------------------------------------------------------------ 
def getQuasiDiag(link): # Sort clustered items by distance 
    link=link.astype(int) 
    sortIx=pd.Series([link[-1,0],link[-1,1]]) 
    numItems=link[-1,3] # number of original items 
    while sortIx.max()>=numItems: 
        sortIx.index=range(0,sortIx.shape[0]*2,2) # make space 
        df0=sortIx[sortIx>=numItems] # find clusters
        i=df0.index;j=df0.values-numItems 
        sortIx[i]=link[j,0] # item 1 
        df0=pd.Series(link[j,1],index=i+1) 
        sortIx = pd.concat([sortIx, df0]) # item 2  ####Anpassung wegen neuer Pandas-Version!
        sortIx=sortIx.sort_index() # re-sort 
        sortIx.index=range(sortIx.shape[0]) # re-index 
    return sortIx.tolist()

# %%
#------------------------------------------------------------------------------ 
def getRecBipart(cov,sortIx): # Compute HRP allocation
    w = pd.Series(1,index=sortIx) 
    cItems=[sortIx] # initialize all items in one cluster 
    while len(cItems)>0: 
        #Bi-Section der Cluster
        cItems = [i[j:k] 
                  for i in cItems 
                  for j, k in ((0, len(i)//2), (len(i)//2, len(i))) 
                  if len(i) > 1]
        for i in range(0, len(cItems), 2): # parse in pairs 
            cItems0=cItems[i] # cluster 1 
            cItems1=cItems[i+1] # cluster 2 
            cVar0=getClusterVar(cov,cItems0) 
            cVar1=getClusterVar(cov,cItems1) 
            alpha=1-cVar0/(cVar0+cVar1) 
            w[cItems0]*=alpha # weight 1 
            w[cItems1]*=1-alpha # weight 2 
    return w

# %%
#------------------------------------------------------------------------------ 
def correlDist(corr): 
    # A distance matrix based on correlation, where 0<=d[i,j]<=1 
    # This is a proper distance metric 
    dist=((1-corr)/2.)**.5 # distance matrix 
    
    #Adjustierung zur condensed_distance_matrix
    condensed_distance_matrix = squareform(X=dist, checks=False)
    
    return condensed_distance_matrix

# %%
def hrp_main(corr, cov, returns): 
    
    #3) cluster 
    dist=correlDist(corr) 
    link=sch.linkage(dist,'single') 
    sortIx=getQuasiDiag(link) 
    sortIx=corr.index[sortIx].tolist() # recover labels 
    df0=corr.loc[sortIx,sortIx] # reorder 
    
    #4) Capital allocation 
    hrp=getRecBipart(cov,sortIx) 
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    hrp_sortiert = hrp.reindex(original_reihenfolge)
    
    array = hrp_sortiert.T.values

    return array

# %% [markdown]
# #### Hierarchical Equal Risk Contribution Portfolio

# %%
#Es wird auf die Implementierung der Riskfolio-Lib zurückgegriffen
#Code adaptiert von #Code adaptiert von https://medium.com/@orenji.eirl/hierarchical-equal-risk-contribution-with-python-and-riskfolio-lib-ec45dd0f9899

def herc (returns):

    # Building the portfolio object
    port = hc(returns=returns)

    # Estimate optimal portfolio:

    model='HERC'
    correlation = 'pearson'
    rm = 'MV'
    rf = 0 
    linkage = 'ward' 
    max_k = 10 
    leaf_order = True 

    gewichte = port.optimization(model=model,
                          correlation=correlation,
                          rm=rm,
                          rf=rf,
                          linkage=linkage,
                          max_k=max_k,
                          leaf_order=leaf_order)
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    gewichte_sortiert = gewichte.reindex(original_reihenfolge)
    
    array = gewichte_sortiert.values.flatten()

    return array

# %%
def herc_ledoit (returns):

    #Building the portfolio object
    port = hc(returns=returns)
    
    shrinkage_herc = LedoitWolf().fit(returns.values)
    
    shrinkage_matrix_herc = pd.DataFrame(
        shrinkage_herc.covariance_,
        index = returns.columns,
        columns = returns.columns)

    #Estimate optimal portfolio:

    model='HERC'
    #correlation = 'pearson'
    rm = 'MV'
    rf = 0 
    linkage = 'ward' 
    max_k = 10 
    leaf_order = True 

    gewichte = port.optimization(model=model,
                          custom_cov = shrinkage_matrix_herc,
                          codependence='custom_cov',
                          rm=rm,
                          rf=rf,
                          method_cov='custom_cov',   #gemäß https://riskfolio-lib.readthedocs.io/en/latest/hcportfolio.html
                          linkage=linkage,
                          max_k=max_k,
                          leaf_order=leaf_order)
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    gewichte_sortiert = gewichte.reindex(original_reihenfolge)
    
    array = gewichte_sortiert.values.flatten()

    return array

# %% [markdown]
# #### Vergleichs-Metriken

# %%
def gesamt_return(gewichte, returns):

    daily_returns = returns @ gewichte
    total = np.prod(1 + daily_returns) - 1
    
    return total

# %%
def portfolio_return (gewichte, returns):
    
    avg_returns = []
    avg_returns = returns.mean()
    
    pf_return = sum([gewicht * rendite for gewicht, rendite in zip(gewichte, avg_returns)])
    
    return pf_return

# %%
def portfolio_variance (gewichte, returns):
    daily_returns = []
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    pf_var = np.var(daily_returns)
    
    return pf_var

# %%
def portfolio_volatility (gewichte, returns):
    variance = portfolio_variance(gewichte, returns)
    volatility = np.sqrt(variance)
    
    return volatility

# %%
def annualized_return(gewichte, returns):
    daily_returns = returns @ gewichte
    annual = (np.prod(1 + daily_returns))**(252/daily_returns.shape[0]) - 1
    
    return annual

# %%
def annualized_portfolio_return(gewichte, returns):
    pf_return = portfolio_return(gewichte, returns)
    
    return pf_return*252

# %%
def annualized_portfolio_volatility(gewichte, returns):
    pf_volatility = portfolio_volatility(gewichte, returns)
    
    return pf_volatility*np.sqrt(252)

# %%
def sharpe_ratio (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sharpe_ratio_one (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.01
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sharpe_ratio_two (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.02
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio_one (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.01
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio_two (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.02
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sortino_ratio (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def sortino_ratio_one (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.01
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def sortino_ratio_two (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.02
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio_one (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.01
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio_two (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.02
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def maximum_drawdown (gewichte, returns):
    daily_returns = returns @ gewichte
    returns_kumuliert = (1 + daily_returns).cumprod()
    hochpunkte = returns_kumuliert.cummax()
    
    drawdowns = (returns_kumuliert - hochpunkte) / hochpunkte
    max_drawdown = drawdowns.min()
    
    #print(drawdowns)
    return max_drawdown

# %%
def calmar_ratio (gewichte, returns):
    pf_return = portfolio_return(gewichte, returns)
    max_drawdown = maximum_drawdown(gewichte, returns)
    
    calmar_ratio = pf_return / (-max_drawdown)
    
    return calmar_ratio

# %%
def value_at_risk_func(gewichte, returns):
    daily_returns = returns @ gewichte
    sorted_daily_returns = daily_returns.sort_values(ascending = True)
    value_at_risk = np.percentile(sorted_daily_returns, 100*0.05)
    return value_at_risk

# %%
#https://github.com/malctaylor15/VaR-and-Expected-Shortfall-Python/blob/master/Expected%20Shortfall%20and%20Value%20at%20Risk.ipynb

def expected_shortfall(gewichte, returns):
    daily_returns = returns @ gewichte
    sorted_daily_returns = daily_returns.sort_values(ascending = True)
    value_at_risk = value_at_risk_func(gewichte, returns)
    
    expected_shortfall = daily_returns[daily_returns <= value_at_risk].mean()
    
    return expected_shortfall

# %% [markdown]
# #### Sammel-Funktionen zum Berechnen und Speichern der Metriken

# %%
def metriken_equally_weighted(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile1 = {"Methode": "Equally-Weighted",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile1[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile1])], ignore_index=True)

# %%
def metriken_minimum_variance(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile2 = {"Methode": "Minimum_Variance",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile2[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile2])], ignore_index=True)

# %%
def metriken_max_diversification(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile3 = {"Methode": "Max-Diversification",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile3[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile3])], ignore_index=True)

# %%
def metriken_inverse_volatility(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile4 = {"Methode": "Inverse-Volatility",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile4[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile4])], ignore_index=True)

# %%
def metriken_risk_parity(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile5 = {"Methode": "Risk-Parity",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile5[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile5])], ignore_index=True)

# %%
def metriken_hrp(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile6 = {"Methode": "HRP",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile6[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile6])], ignore_index=True)

# %%
def metriken_herc(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile7 = {"Methode": "HERC",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile7[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile7])], ignore_index=True)

# %% [markdown]
# ## Erzeugung Ergebnisse S&P500

# %%
#Tägliche Renditen für den gesamten Zeitraum von 20 Jahren SP500

returns = df_SP500.pct_change()
returns = returns.where(~df_SP500.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                    A  AAL  AAP      AAPL      ABBV      ABNB       ABT  \
# Date
# 2005-06-02  0.000414  NaN  NaN -0.006452       NaN       NaN -0.001448
# 2005-06-03 -0.005374  NaN  NaN -0.044955       NaN       NaN  0.000207
# 2005-06-06  0.019119  NaN  NaN -0.008368       NaN       NaN  0.003729
# 2005-06-07 -0.012235  NaN  NaN -0.036393       NaN       NaN  0.006398
# 2005-06-08  0.009496  NaN  NaN  0.010399       NaN       NaN -0.002051
# ...              ...  ...  ...       ...       ...       ...       ...
# 2025-05-23 -0.010485  NaN  NaN -0.030244  0.003944 -0.007286 -0.001521
# 2025-05-27  0.025154  NaN  NaN  0.025298  0.013424  0.021149  0.012490
# 2025-05-28 -0.003415  NaN  NaN  0.001049 -0.014161 -0.005641 -0.006920
# 2025-05-29  0.021645  NaN  NaN -0.002345  0.013818 -0.002409  0.006287
# 2025-05-30 -0.012006  NaN  NaN  0.004501  0.002640  0.004986  0.005495
#
#                 ACGL       ACN      ADBE  ...       XEL       XOM  XRAY  \
# Date                                      ...
# 2005-06-02       NaN       NaN -0.002712  ...  0.002678  0.002975   NaN
# 2005-06-03       NaN       NaN -0.016621  ...  0.004808 -0.002966   NaN
# 2005-06-06       NaN       NaN -0.002766  ...  0.000532  0.007874   NaN
# 2005-06-07       NaN       NaN -0.005855  ...  0.004251 -0.002604   NaN
# 2005-06-08       NaN       NaN  0.000000  ...  0.017460 -0.012533   NaN
# ...              ...       ...       ...  ...       ...       ...   ...
# 2025-05-23  0.001087 -0.021710 -0.016026  ...  0.007513  0.000583   NaN
# 2025-05-27  0.027696  0.018897  0.013270  ...  0.001147  0.004756   NaN
# 2025-05-28 -0.017332  0.001775 -0.002106  ... -0.012606 -0.013621   NaN
# 2025-05-29  0.013121  0.005507  0.002741  ...  0.007834  0.005680   NaN
# 2025-05-30  0.008917 -0.002864  0.004185  ...  0.009069 -0.003798   NaN
#
#                  XRX       XYL       YUM       ZBH      ZBRA      ZION  \
# Date
# 2005-06-02 -0.003650       NaN  0.021558  0.002885       NaN  0.005945
# 2005-06-03 -0.006593       NaN -0.010646  0.029816       NaN -0.008246
# 2005-06-06 -0.011062       NaN -0.000769 -0.005079       NaN -0.000139
# 2005-06-07 -0.006711       NaN  0.003077  0.013657       NaN -0.002772
# 2005-06-08  0.039039       NaN -0.006518 -0.005414       NaN -0.002085
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23       NaN -0.009739 -0.000344  0.010581 -0.014392       NaN
# 2025-05-27       NaN  0.017654 -0.009350  0.016947  0.038000       NaN
# 2025-05-28       NaN -0.004674 -0.006524 -0.020380 -0.014271       NaN
# 2025-05-29       NaN  0.000080  0.006217  0.011377  0.005846       NaN
# 2025-05-30       NaN  0.003024 -0.000694 -0.012535 -0.009333       NaN
#
#                  ZTS
# Date
# 2005-06-02       NaN
# 2005-06-03       NaN
# 2005-06-06       NaN
# 2005-06-07       NaN
# 2005-06-08       NaN
# ...              ...
# 2025-05-23  0.003766
# 2025-05-27  0.022635
# 2025-05-28 -0.005173
# 2025-05-29  0.010520
# 2025-05-30  0.008915
#
# [5031 rows x 598 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 1
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = training_daten.cov()
    corr_matrix = training_daten.corr()
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    gewichte_equally_weighted = equally_weighted(training_daten)
    gewichte_min_variance= min_variance_opt(cov_matrix)
    gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": gewichte_equally_weighted,
    "Minimum-Variance": gewichte_min_variance,
    "Maximum-Diversification": gewichte_max_diversification,
    "Inverse-Volatility": gewichte_inverse_volatility,
    "Equal-Risk-Contribution": gewichte_risk_parity,
    "HRP": gewichte_hrp,
    "HERC": gewichte_herc
}
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
    #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
# Alle Testperioden zusammenführen
portfolio_returns_df = pd.concat(portfolio_returns_list)
portfolio_returns_df = portfolio_returns_df.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.560718656371804e-05
#             Iterations: 299
#             Function evaluations: 78936
#             Gradient evaluations: 299
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0661056745424897
#             Iterations: 87
#             Function evaluations: 22007
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6806677955014559e-09
#             Iterations: 21
#             Function evaluations: 5544
#             Gradient evaluations: 21
# 2005-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6806473037277397e-05
#             Iterations: 275
#             Function evaluations: 72600
#             Gradient evaluations: 275
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8676104449615516
#             Iterations: 68
#             Function evaluations: 18020
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.829295698519673e-09
#             Iterations: 21
#             Function evaluations: 5545
#             Gradient evaluations: 21
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.690668950260142e-05
#             Iterations: 318
#             Function evaluations: 84588
#             Gradient evaluations: 318
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8714571734911107
#             Iterations: 76
#             Function evaluations: 19767
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.918444000666588e-09
#             Iterations: 31
#             Function evaluations: 8246
#             Gradient evaluations: 31
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6665595056604733e-05
#             Iterations: 314
#             Function evaluations: 84466
#             Gradient evaluations: 314
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.936948205695343
#             Iterations: 69
#             Function evaluations: 18361
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.56635060457177e-09
#             Iterations: 20
#             Function evaluations: 5381
#             Gradient evaluations: 20
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5769545458705043e-05
#             Iterations: 306
#             Function evaluations: 82314
#             Gradient evaluations: 306
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.922602493344259
#             Iterations: 76
#             Function evaluations: 20247
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3601474215166684e-09
#             Iterations: 31
#             Function evaluations: 8339
#             Gradient evaluations: 31
# 2005-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4349616644590295e-05
#             Iterations: 344
#             Function evaluations: 93224
#             Gradient evaluations: 344
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1183610339016603
#             Iterations: 76
#             Function evaluations: 19585
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.415566172544893e-09
#             Iterations: 28
#             Function evaluations: 7588
#             Gradient evaluations: 28
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4559816122957647e-05
#             Iterations: 347
#             Function evaluations: 94037
#             Gradient evaluations: 347
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0831731681363586
#             Iterations: 81
#             Function evaluations: 20955
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3858077582241334e-09
#             Iterations: 26
#             Function evaluations: 7046
#             Gradient evaluations: 26
# 2006-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4266866423866963e-05
#             Iterations: 327
#             Function evaluations: 89272
#             Gradient evaluations: 327
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.092161768394809
#             Iterations: 74
#             Function evaluations: 19178
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.717867168074133e-09
#             Iterations: 27
#             Function evaluations: 7371
#             Gradient evaluations: 27
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2957615381930568e-05
#             Iterations: 329
#             Function evaluations: 90146
#             Gradient evaluations: 329
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.114900759682049
#             Iterations: 67
#             Function evaluations: 18151
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.879440551822173e-09
#             Iterations: 26
#             Function evaluations: 7124
#             Gradient evaluations: 26
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4534526447339444e-05
#             Iterations: 341
#             Function evaluations: 93775
#             Gradient evaluations: 341
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.952215156303736
#             Iterations: 76
#             Function evaluations: 19879
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.617602024904684e-09
#             Iterations: 38
#             Function evaluations: 10450
#             Gradient evaluations: 38
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.665008331141351e-05
#             Iterations: 342
#             Function evaluations: 94050
#             Gradient evaluations: 342
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.79903434995049
#             Iterations: 63
#             Function evaluations: 16282
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.667997339316014e-09
#             Iterations: 26
#             Function evaluations: 7151
#             Gradient evaluations: 26
# 2006-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6353531833775692e-05
#             Iterations: 338
#             Function evaluations: 93964
#             Gradient evaluations: 338
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8531847124156733
#             Iterations: 68
#             Function evaluations: 17854
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.590985868535298e-09
#             Iterations: 38
#             Function evaluations: 10564
#             Gradient evaluations: 38
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.622007081358141e-05
#             Iterations: 332
#             Function evaluations: 92296
#             Gradient evaluations: 332
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.920905052892258
#             Iterations: 71
#             Function evaluations: 18702
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4955482396956752e-09
#             Iterations: 38
#             Function evaluations: 10564
#             Gradient evaluations: 38
# 2006-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.646540406222078e-05
#             Iterations: 371
#             Function evaluations: 103510
#             Gradient evaluations: 371
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9854150581059447
#             Iterations: 84
#             Function evaluations: 22412
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6096719942643213e-09
#             Iterations: 27
#             Function evaluations: 7533
#             Gradient evaluations: 27
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.837685443711993e-05
#             Iterations: 312
#             Function evaluations: 86737
#             Gradient evaluations: 312
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0412313106182576
#             Iterations: 65
#             Function evaluations: 17028
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7743853979597804e-09
#             Iterations: 21
#             Function evaluations: 5838
#             Gradient evaluations: 21
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5480826700440394e-05
#             Iterations: 279
#             Function evaluations: 77841
#             Gradient evaluations: 279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.815910464073311
#             Iterations: 51
#             Function evaluations: 14281
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.758245505214993e-09
#             Iterations: 18
#             Function evaluations: 5023
#             Gradient evaluations: 18
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7205091645283506e-05
#             Iterations: 276
#             Function evaluations: 77005
#             Gradient evaluations: 276
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.721229884549377
#             Iterations: 50
#             Function evaluations: 13996
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8931557882883877e-09
#             Iterations: 15
#             Function evaluations: 4186
#             Gradient evaluations: 15
# 2006-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.836432506496722e-05
#             Iterations: 296
#             Function evaluations: 82880
#             Gradient evaluations: 296
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.672162548618776
#             Iterations: 45
#             Function evaluations: 12644
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9469953878570707e-09
#             Iterations: 19
#             Function evaluations: 5320
#             Gradient evaluations: 19
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.148308745181869e-05
#             Iterations: 291
#             Function evaluations: 82353
#             Gradient evaluations: 291
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5229826522261836
#             Iterations: 49
#             Function evaluations: 13634
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7685128002345642e-09
#             Iterations: 30
#             Function evaluations: 8490
#             Gradient evaluations: 30
# 2007-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.293730915945418e-05
#             Iterations: 285
#             Function evaluations: 81225
#             Gradient evaluations: 285
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4887599107933243
#             Iterations: 56
#             Function evaluations: 14875
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9696031588723116e-09
#             Iterations: 30
#             Function evaluations: 8551
#             Gradient evaluations: 30
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.843161187487995e-05
#             Iterations: 287
#             Function evaluations: 81795
#             Gradient evaluations: 287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4680203052465988
#             Iterations: 40
#             Function evaluations: 11440
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.080968475756469e-09
#             Iterations: 47
#             Function evaluations: 13396
#             Gradient evaluations: 47
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.97115286928344e-05
#             Iterations: 281
#             Function evaluations: 80367
#             Gradient evaluations: 281
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4625481438645918
#             Iterations: 37
#             Function evaluations: 10619
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.153679294969222e-09
#             Iterations: 47
#             Function evaluations: 13442
#             Gradient evaluations: 47
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.2429465562032166e-05
#             Iterations: 274
#             Function evaluations: 79186
#             Gradient evaluations: 274
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6217252958270936
#             Iterations: 43
#             Function evaluations: 12182
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.916013641175868e-10
#             Iterations: 57
#             Function evaluations: 16473
#             Gradient evaluations: 57
# 2007-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3504338724232144e-05
#             Iterations: 268
#             Function evaluations: 77988
#             Gradient evaluations: 268
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6095498266337516
#             Iterations: 41
#             Function evaluations: 11683
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.009880321673257e-09
#             Iterations: 56
#             Function evaluations: 16296
#             Gradient evaluations: 56
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.384494997283043e-05
#             Iterations: 288
#             Function evaluations: 83809
#             Gradient evaluations: 288
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.609616389400448
#             Iterations: 35
#             Function evaluations: 10218
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.101271457203561e-10
#             Iterations: 66
#             Function evaluations: 19206
#             Gradient evaluations: 66
# 2007-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.6933110341184316e-05
#             Iterations: 272
#             Function evaluations: 78881
#             Gradient evaluations: 272
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5615330120689617
#             Iterations: 36
#             Function evaluations: 10474
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.409747818559429e-10
#             Iterations: 66
#             Function evaluations: 19140
#             Gradient evaluations: 66
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.515465372412421e-05
#             Iterations: 234
#             Function evaluations: 68094
#             Gradient evaluations: 234
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.554867540794491
#             Iterations: 55
#             Function evaluations: 14905
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.540393150899734e-10
#             Iterations: 83
#             Function evaluations: 24153
#             Gradient evaluations: 83
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.201619656757493e-05
#             Iterations: 282
#             Function evaluations: 81780
#             Gradient evaluations: 282
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.639715281737878
#             Iterations: 49
#             Function evaluations: 13099
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3363145920425187e-09
#             Iterations: 83
#             Function evaluations: 24070
#             Gradient evaluations: 83
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.311114395015498e-05
#             Iterations: 242
#             Function evaluations: 70180
#             Gradient evaluations: 242
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.484780958219656
#             Iterations: 38
#             Function evaluations: 10769
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0437419642578074e-09
#             Iterations: 97
#             Function evaluations: 28131
#             Gradient evaluations: 97
# 2007-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00014745826975129343
#             Iterations: 200
#             Function evaluations: 58200
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.025707345896236
#             Iterations: 26
#             Function evaluations: 7592
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.772782337606255e-10
#             Iterations: 75
#             Function evaluations: 21826
#             Gradient evaluations: 75
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00018120765660335005
#             Iterations: 161
#             Function evaluations: 46529
#             Gradient evaluations: 161
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9197079911190353
#             Iterations: 25
#             Function evaluations: 7243
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.928611635597754e-10
#             Iterations: 81
#             Function evaluations: 23410
#             Gradient evaluations: 81
# 2008-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00020114618096345657
#             Iterations: 150
#             Function evaluations: 43650
#             Gradient evaluations: 150
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8856731219482337
#             Iterations: 26
#             Function evaluations: 7580
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8510537398740266e-10
#             Iterations: 89
#             Function evaluations: 25899
#             Gradient evaluations: 89
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00020119354596347927
#             Iterations: 148
#             Function evaluations: 43069
#             Gradient evaluations: 148
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.872401648975168
#             Iterations: 24
#             Function evaluations: 7002
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6750886628105487e-10
#             Iterations: 88
#             Function evaluations: 25609
#             Gradient evaluations: 88
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00020934590169396217
#             Iterations: 134
#             Function evaluations: 38994
#             Gradient evaluations: 134
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.887772172704881
#             Iterations: 28
#             Function evaluations: 8167
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6767847157591986e-10
#             Iterations: 96
#             Function evaluations: 27937
#             Gradient evaluations: 96
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002267902185625556
#             Iterations: 145
#             Function evaluations: 42340
#             Gradient evaluations: 145
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7724201488878464
#             Iterations: 28
#             Function evaluations: 8195
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2141123031818701e-10
#             Iterations: 103
#             Function evaluations: 30076
#             Gradient evaluations: 103
# 2008-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022692488876273613
#             Iterations: 124
#             Function evaluations: 36208
#             Gradient evaluations: 124
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7967689568284242
#             Iterations: 26
#             Function evaluations: 7611
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.449925480392438e-10
#             Iterations: 103
#             Function evaluations: 30076
#             Gradient evaluations: 103
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022737312160583248
#             Iterations: 140
#             Function evaluations: 41020
#             Gradient evaluations: 140
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8007067307721083
#             Iterations: 29
#             Function evaluations: 8514
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.060251469829356e-10
#             Iterations: 110
#             Function evaluations: 32230
#             Gradient evaluations: 110
# 2008-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022394867292430918
#             Iterations: 124
#             Function evaluations: 36332
#             Gradient evaluations: 124
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7955009315292858
#             Iterations: 29
#             Function evaluations: 8513
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.233255502579023e-10
#             Iterations: 110
#             Function evaluations: 32230
#             Gradient evaluations: 110
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022569483587998954
#             Iterations: 113
#             Function evaluations: 33335
#             Gradient evaluations: 113
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7949113226240583
#             Iterations: 26
#             Function evaluations: 7687
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1561733152172096e-10
#             Iterations: 110
#             Function evaluations: 32450
#             Gradient evaluations: 110
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021785950399401069
#             Iterations: 103
#             Function evaluations: 30591
#             Gradient evaluations: 103
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7961748327521527
#             Iterations: 28
#             Function evaluations: 8333
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3683145155027784e-10
#             Iterations: 110
#             Function evaluations: 32670
#             Gradient evaluations: 110
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00020894945431497274
#             Iterations: 106
#             Function evaluations: 31694
#             Gradient evaluations: 106
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8013380976672233
#             Iterations: 26
#             Function evaluations: 7790
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0008441951967505e-10
#             Iterations: 111
#             Function evaluations: 33189
#             Gradient evaluations: 111
# 2008-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00012012699782385635
#             Iterations: 138
#             Function evaluations: 41814
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9601501607466527
#             Iterations: 34
#             Function evaluations: 9113
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.442950453995177e-10
#             Iterations: 129
#             Function evaluations: 39088
#             Gradient evaluations: 129
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.719360558102194e-05
#             Iterations: 191
#             Function evaluations: 58447
#             Gradient evaluations: 191
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2426829363824012
#             Iterations: 31
#             Function evaluations: 9513
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.760862395874104e-10
#             Iterations: 147
#             Function evaluations: 44982
#             Gradient evaluations: 147
# 2009-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.104735391001802e-05
#             Iterations: 199
#             Function evaluations: 60496
#             Gradient evaluations: 199
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.370592654848575
#             Iterations: 39
#             Function evaluations: 10676
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.154545229762158e-10
#             Iterations: 149
#             Function evaluations: 45296
#             Gradient evaluations: 149
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.810619321748456e-05
#             Iterations: 207
#             Function evaluations: 63549
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.35383021552422
#             Iterations: 43
#             Function evaluations: 12016
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.223524720149009e-10
#             Iterations: 124
#             Function evaluations: 38068
#             Gradient evaluations: 124
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7997855005585396e-05
#             Iterations: 169
#             Function evaluations: 51883
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4013410133120487
#             Iterations: 37
#             Function evaluations: 10173
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.536092328176696e-10
#             Iterations: 127
#             Function evaluations: 38989
#             Gradient evaluations: 127
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.273142213497092e-05
#             Iterations: 247
#             Function evaluations: 76817
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5695260600876098
#             Iterations: 44
#             Function evaluations: 12478
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2958105343025384e-09
#             Iterations: 103
#             Function evaluations: 32034
#             Gradient evaluations: 103
# 2009-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1244172976020464e-05
#             Iterations: 253
#             Function evaluations: 78683
#             Gradient evaluations: 253
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.552678248050781
#             Iterations: 57
#             Function evaluations: 16547
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.996167712689256e-10
#             Iterations: 87
#             Function evaluations: 27057
#             Gradient evaluations: 87
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.599124674605381e-05
#             Iterations: 250
#             Function evaluations: 77750
#             Gradient evaluations: 250
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.379747545025048
#             Iterations: 36
#             Function evaluations: 11230
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.58014660323221e-10
#             Iterations: 78
#             Function evaluations: 24258
#             Gradient evaluations: 78
# 2009-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.670931712893084e-05
#             Iterations: 228
#             Function evaluations: 71364
#             Gradient evaluations: 228
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3215314804758673
#             Iterations: 42
#             Function evaluations: 11931
#             Gradient evaluations: 38
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.969583184721256e-10
#             Iterations: 67
#             Function evaluations: 20971
#             Gradient evaluations: 67
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.697985496953368e-05
#             Iterations: 262
#             Function evaluations: 82530
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3123645265484116
#             Iterations: 40
#             Function evaluations: 11380
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1373323212787251e-09
#             Iterations: 56
#             Function evaluations: 17640
#             Gradient evaluations: 56
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.859770697521892e-05
#             Iterations: 239
#             Function evaluations: 75525
#             Gradient evaluations: 239
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2278114229673838
#             Iterations: 37
#             Function evaluations: 10455
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.690847946995073e-10
#             Iterations: 57
#             Function evaluations: 18012
#             Gradient evaluations: 57
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.933226728429815e-05
#             Iterations: 235
#             Function evaluations: 74260
#             Gradient evaluations: 235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.172559117868381
#             Iterations: 32
#             Function evaluations: 8874
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.915389133553364e-10
#             Iterations: 59
#             Function evaluations: 18644
#             Gradient evaluations: 59
# 2009-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.734318456619756e-05
#             Iterations: 225
#             Function evaluations: 71100
#             Gradient evaluations: 225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.167997818634883
#             Iterations: 31
#             Function evaluations: 9823
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.065403707165239e-10
#             Iterations: 50
#             Function evaluations: 15801
#             Gradient evaluations: 50
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.578197007895788e-05
#             Iterations: 221
#             Function evaluations: 70058
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.154628132683497
#             Iterations: 34
#             Function evaluations: 10806
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.644483717892879e-10
#             Iterations: 50
#             Function evaluations: 15851
#             Gradient evaluations: 50
# 2010-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.498515498571155e-05
#             Iterations: 204
#             Function evaluations: 64872
#             Gradient evaluations: 204
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.194908313711366
#             Iterations: 36
#             Function evaluations: 10205
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.778318119796485e-10
#             Iterations: 48
#             Function evaluations: 15264
#             Gradient evaluations: 48
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3965500334544226e-05
#             Iterations: 197
#             Function evaluations: 62843
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.196175925967969
#             Iterations: 31
#             Function evaluations: 9918
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.907641956193284e-10
#             Iterations: 50
#             Function evaluations: 15951
#             Gradient evaluations: 50
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2966375928351446e-05
#             Iterations: 217
#             Function evaluations: 69440
#             Gradient evaluations: 217
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2436836191427716
#             Iterations: 29
#             Function evaluations: 9309
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6000989775920426e-09
#             Iterations: 41
#             Function evaluations: 13120
#             Gradient evaluations: 41
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.449624609961594e-05
#             Iterations: 218
#             Function evaluations: 70197
#             Gradient evaluations: 218
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2299812027009533
#             Iterations: 34
#             Function evaluations: 10978
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.977959768297004e-10
#             Iterations: 51
#             Function evaluations: 16422
#             Gradient evaluations: 51
# 2010-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.497465041680936e-05
#             Iterations: 222
#             Function evaluations: 71485
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2228868854471626
#             Iterations: 35
#             Function evaluations: 11302
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.8477552950121e-10
#             Iterations: 52
#             Function evaluations: 16744
#             Gradient evaluations: 52
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7518595389947427e-05
#             Iterations: 242
#             Function evaluations: 77924
#             Gradient evaluations: 242
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.445288602206374
#             Iterations: 44
#             Function evaluations: 13884
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5596859428735478e-09
#             Iterations: 37
#             Function evaluations: 11914
#             Gradient evaluations: 37
# 2010-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3941210951993524e-05
#             Iterations: 266
#             Function evaluations: 85919
#             Gradient evaluations: 266
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5505694455010395
#             Iterations: 45
#             Function evaluations: 14576
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2097775336919562e-09
#             Iterations: 31
#             Function evaluations: 10014
#             Gradient evaluations: 31
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1391291793892782e-05
#             Iterations: 321
#             Function evaluations: 103683
#             Gradient evaluations: 321
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.530535418762508
#             Iterations: 53
#             Function evaluations: 15873
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2888383550497015e-09
#             Iterations: 29
#             Function evaluations: 9368
#             Gradient evaluations: 29
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.486374086979512e-05
#             Iterations: 211
#             Function evaluations: 68153
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.039724329096922
#             Iterations: 30
#             Function evaluations: 9717
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.645227390393789e-10
#             Iterations: 51
#             Function evaluations: 16473
#             Gradient evaluations: 51
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.833221353774996e-05
#             Iterations: 217
#             Function evaluations: 70091
#             Gradient evaluations: 217
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9675990086287738
#             Iterations: 29
#             Function evaluations: 9393
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.080745832507033e-10
#             Iterations: 50
#             Function evaluations: 16151
#             Gradient evaluations: 50
# 2010-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.1757879463790605e-05
#             Iterations: 224
#             Function evaluations: 72352
#             Gradient evaluations: 224
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9097790488614075
#             Iterations: 31
#             Function evaluations: 10039
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.699804845024541e-10
#             Iterations: 59
#             Function evaluations: 19057
#             Gradient evaluations: 59
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7521172899602846e-05
#             Iterations: 214
#             Function evaluations: 68908
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8381808722764228
#             Iterations: 28
#             Function evaluations: 9040
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.417757534672872e-10
#             Iterations: 56
#             Function evaluations: 18032
#             Gradient evaluations: 56
# 2011-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.0479127492526894e-05
#             Iterations: 218
#             Function evaluations: 70632
#             Gradient evaluations: 218
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9681084204568475
#             Iterations: 29
#             Function evaluations: 9095
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.479326554490914e-10
#             Iterations: 54
#             Function evaluations: 17497
#             Gradient evaluations: 54
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.060961460358606e-05
#             Iterations: 214
#             Function evaluations: 69337
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.972561247073514
#             Iterations: 25
#             Function evaluations: 8116
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.888953165762983e-10
#             Iterations: 55
#             Function evaluations: 17820
#             Gradient evaluations: 55
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.946024184079027e-05
#             Iterations: 197
#             Function evaluations: 63828
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.965748906328976
#             Iterations: 33
#             Function evaluations: 9412
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.821968486216466e-10
#             Iterations: 55
#             Function evaluations: 17820
#             Gradient evaluations: 55
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.780939520427841e-05
#             Iterations: 222
#             Function evaluations: 71928
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9504188318180304
#             Iterations: 27
#             Function evaluations: 8767
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0282073704941506e-09
#             Iterations: 55
#             Function evaluations: 17821
#             Gradient evaluations: 55
# 2011-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.878745694713052e-05
#             Iterations: 190
#             Function evaluations: 62130
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.934504827724624
#             Iterations: 28
#             Function evaluations: 9173
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.595247081168326e-10
# ...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.337277375256852
#             Iterations: 65
#             Function evaluations: 27820
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0894105617870467e-09
#             Iterations: 57
#             Function evaluations: 25935
#             Gradient evaluations: 57
# 2022-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.541635691624028e-05
#             Iterations: 303
#             Function evaluations: 139381
#             Gradient evaluations: 303
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4222483818351748
#             Iterations: 50
#             Function evaluations: 21202
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6091080429335797e-09
#             Iterations: 48
#             Function evaluations: 22080
#             Gradient evaluations: 48
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.541773445838192e-05
#             Iterations: 272
#             Function evaluations: 125121
#             Gradient evaluations: 272
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4546139851506488
#             Iterations: 61
#             Function evaluations: 26278
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.386926835648967e-09
#             Iterations: 48
#             Function evaluations: 22080
#             Gradient evaluations: 48
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.464682160843345e-05
#             Iterations: 272
#             Function evaluations: 124848
#             Gradient evaluations: 272
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.518411872727149
#             Iterations: 55
#             Function evaluations: 23454
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2562068915902268e-09
#             Iterations: 49
#             Function evaluations: 22491
#             Gradient evaluations: 49
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.726780181449732e-05
#             Iterations: 260
#             Function evaluations: 119601
#             Gradient evaluations: 260
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -2.6840217621958504
#             Iterations: 56
#             Function evaluations: 23975
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3326225534179358e-09
#             Iterations: 49
#             Function evaluations: 22540
#             Gradient evaluations: 49
# 2022-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.955212718208711e-05
#             Iterations: 281
#             Function evaluations: 128417
#             Gradient evaluations: 281
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -2.900300291658556
#             Iterations: 60
#             Function evaluations: 25644
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.696241554975139e-09
#             Iterations: 37
#             Function evaluations: 16910
#             Gradient evaluations: 37
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7129267058505102e-05
#             Iterations: 293
#             Function evaluations: 134488
#             Gradient evaluations: 293
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0425828665257693
#             Iterations: 63
#             Function evaluations: 27137
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1195316375813742e-09
#             Iterations: 38
#             Function evaluations: 17442
#             Gradient evaluations: 38
# 2023-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.606209756485792e-05
#             Iterations: 302
#             Function evaluations: 138920
#             Gradient evaluations: 302
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.1147046917398424
#             Iterations: 69
#             Function evaluations: 29960
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5460324746723696e-09
#             Iterations: 32
#             Function evaluations: 14721
#             Gradient evaluations: 32
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2629247224482398e-05
#             Iterations: 314
#             Function evaluations: 144754
#             Gradient evaluations: 314
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.293607626727452
#             Iterations: 65
#             Function evaluations: 28178
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2687045819109084e-09
#             Iterations: 44
#             Function evaluations: 20284
#             Gradient evaluations: 44
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.158795649160474e-05
#             Iterations: 298
#             Function evaluations: 137379
#             Gradient evaluations: 298
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.343294835255038
#             Iterations: 72
#             Function evaluations: 31410
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1274763015005423e-09
#             Iterations: 44
#             Function evaluations: 20284
#             Gradient evaluations: 44
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7692467535338406e-05
#             Iterations: 323
#             Function evaluations: 149227
#             Gradient evaluations: 323
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.64099170912072
#             Iterations: 82
#             Function evaluations: 36122
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4771851427151807e-09
#             Iterations: 32
#             Function evaluations: 14784
#             Gradient evaluations: 32
# 2023-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7778433798112006e-05
#             Iterations: 342
#             Function evaluations: 157321
#             Gradient evaluations: 342
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.727536307656066
#             Iterations: 78
#             Function evaluations: 34111
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.253841164797087e-09
#             Iterations: 37
#             Function evaluations: 17020
#             Gradient evaluations: 37
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7611399141609038e-05
#             Iterations: 336
#             Function evaluations: 155232
#             Gradient evaluations: 336
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7415588178401147
#             Iterations: 84
#             Function evaluations: 37046
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1163035187400048e-09
#             Iterations: 38
#             Function evaluations: 17556
#             Gradient evaluations: 38
# 2023-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.62879812837584e-05
#             Iterations: 397
#             Function evaluations: 183414
#             Gradient evaluations: 397
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.887625307253408
#             Iterations: 88
#             Function evaluations: 38910
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.466563940250019e-09
#             Iterations: 33
#             Function evaluations: 15247
#             Gradient evaluations: 33
# 2023-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6413480145897664e-05
#             Iterations: 349
#             Function evaluations: 161239
#             Gradient evaluations: 349
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9597899978850486
#             Iterations: 87
#             Function evaluations: 38439
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2871396144386658e-09
#             Iterations: 34
#             Function evaluations: 15709
#             Gradient evaluations: 34
# 2023-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.590828777923799e-05
#             Iterations: 328
#             Function evaluations: 152192
#             Gradient evaluations: 328
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.0724274649572365
#             Iterations: 86
#             Function evaluations: 38133
#             Gradient evaluations: 82
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.631254942002307e-09
#             Iterations: 36
#             Function evaluations: 16704
#             Gradient evaluations: 36
# 2023-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6184844088630317e-05
#             Iterations: 358
#             Function evaluations: 165754
#             Gradient evaluations: 358
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.099358835944536
#             Iterations: 85
#             Function evaluations: 37580
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5099055123699636e-09
#             Iterations: 44
#             Function evaluations: 20372
#             Gradient evaluations: 44
# 2023-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4471897869333911e-05
#             Iterations: 337
#             Function evaluations: 157380
#             Gradient evaluations: 337
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.324573032704614
#             Iterations: 87
#             Function evaluations: 38855
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1117333869192894e-09
#             Iterations: 33
#             Function evaluations: 15411
#             Gradient evaluations: 33
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4294372767715442e-05
#             Iterations: 321
#             Function evaluations: 149908
#             Gradient evaluations: 321
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.357105474789429
#             Iterations: 94
#             Function evaluations: 42146
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.940671184612122e-09
#             Iterations: 33
#             Function evaluations: 15411
#             Gradient evaluations: 33
# 2024-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4384818409346062e-05
#             Iterations: 382
#             Function evaluations: 178013
#             Gradient evaluations: 382
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.344128395582824
#             Iterations: 94
#             Function evaluations: 42047
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4830920293443193e-09
#             Iterations: 28
#             Function evaluations: 13048
#             Gradient evaluations: 28
# 2024-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4729774907206057e-05
#             Iterations: 385
#             Function evaluations: 179410
#             Gradient evaluations: 385
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.347821600683281
#             Iterations: 99
#             Function evaluations: 44384
#             Gradient evaluations: 95
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.371538395447515e-09
#             Iterations: 16
#             Function evaluations: 7457
#             Gradient evaluations: 16
# 2024-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4741685893009108e-05
#             Iterations: 358
#             Function evaluations: 167187
#             Gradient evaluations: 358
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.492396070486934
#             Iterations: 89
#             Function evaluations: 39787
#             Gradient evaluations: 85
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.044409270680055e-09
#             Iterations: 28
#             Function evaluations: 13076
#             Gradient evaluations: 28
# 2024-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.586167248381079e-05
#             Iterations: 394
#             Function evaluations: 185574
#             Gradient evaluations: 394
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.432436409410769
#             Iterations: 87
#             Function evaluations: 39192
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9083609879571457e-09
#             Iterations: 18
#             Function evaluations: 8478
#             Gradient evaluations: 18
# 2024-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8182225025100992e-05
#             Iterations: 386
#             Function evaluations: 182578
#             Gradient evaluations: 386
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.511264760090157
#             Iterations: 67
#             Function evaluations: 29860
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.507663126809866e-09
#             Iterations: 48
#             Function evaluations: 22704
#             Gradient evaluations: 48
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df.to_csv("renditensp500_neu_f.csv")

# %% [markdown]
# ## Ergebnis-Erzeugung JSE

# %%
returns = df_JSE.pct_change()
returns = returns.where(~df_JSE.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of               4SI.JO    ABG.JO    ACL.JO    ACT.JO    ADH.JO    AEL.JO  \
# Date
# 2005-06-02       NaN  0.001214 -0.006225  0.000000 -0.014598       NaN
# 2005-06-03       NaN  0.001333  0.000000  0.000000  0.000000       NaN
# 2005-06-06       NaN  0.003510  0.014953  0.000000  0.007407       NaN
# 2005-06-07       NaN  0.006634 -0.035437  0.146154 -0.007353       NaN
# 2005-06-08       NaN -0.005392 -0.029721  0.000000  0.007407       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26  0.000000  0.007235 -0.018018  0.000000  0.005975  0.000426
# 2025-05-27  0.000000  0.000178 -0.036697  0.000000  0.003439  0.000000
# 2025-05-28  0.042857  0.026828 -0.038095  0.087500  0.022741  0.002128
# 2025-05-29 -0.041096  0.016127  0.049505 -0.045977 -0.010966  0.002972
# 2025-05-30  0.000000 -0.014051  0.094340 -0.036145 -0.009855 -0.001693
#
#               AFE.JO    AFH.JO    AFT.JO    AGL.JO  ...    VKE.JO    VOD.JO  \
# Date                                                ...
# 2005-06-02  0.020642       NaN       NaN  0.005481  ...       NaN  0.017117
# 2005-06-03  0.000000       NaN       NaN  0.000000  ...       NaN  0.000000
# 2005-06-06  0.000000       NaN       NaN -0.019079  ...       NaN  0.045350
# 2005-06-07  0.000225       NaN       NaN -0.020994  ...       NaN -0.000169
# 2005-06-08  0.011009       NaN       NaN  0.014191  ...       NaN -0.025424
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-26  0.007992  0.032548 -0.002564  0.029137  ... -0.010417 -0.016292
# 2025-05-27  0.007252 -0.026087  0.026498 -0.018270  ...  0.006316  0.002971
# 2025-05-28  0.002592  0.017857  0.000000 -0.008829  ...  0.001046 -0.006294
# 2025-05-29 -0.011298 -0.013158 -0.008476 -0.005631  ...  0.014107  0.031967
# 2025-05-30  0.000872 -0.011111  0.010297  0.016932  ...  0.030912 -0.005199
#
#               WBC.JO    WBO.JO    WEZ.JO    WHL.JO    YRK.JO  YYLBEE.JO  \
# Date
# 2005-06-02       NaN  0.009434       NaN  0.009901  0.000000        NaN
# 2005-06-03       NaN  0.000000       NaN  0.000000  0.000000        NaN
# 2005-06-06       NaN  0.009346       NaN  0.026471  0.000000        NaN
# 2005-06-07       NaN  0.000000       NaN  0.012416  0.000000        NaN
# 2005-06-08       NaN  0.018519       NaN -0.027358  0.000000        NaN
# ...              ...       ...       ...       ...       ...        ...
# 2025-05-26  0.021277 -0.005745  0.111111 -0.000174  0.046154        0.0
# 2025-05-27  0.015625  0.007979 -0.100000 -0.008726  0.000000        0.0
# 2025-05-28 -0.010872 -0.018234 -0.022222  0.014965 -0.083333        0.0
# 2025-05-29  0.013895 -0.005505  0.022727  0.016132  0.016043        0.0
# 2025-05-30  0.002250  0.014985 -0.044444  0.000341  0.026316        0.0
#
#               ZED.JO    ZZD.JO
# Date
# 2005-06-02       NaN       NaN
# 2005-06-03       NaN       NaN
# 2005-06-06       NaN       NaN
# 2005-06-07       NaN       NaN
# 2005-06-08       NaN       NaN
# ...              ...       ...
# 2025-05-26 -0.008264 -0.000864
# 2025-05-27 -0.016667  0.037165
# 2025-05-28  0.059322  0.008333
# 2025-05-29  0.008000 -0.008264
# 2025-05-30  0.023810 -0.012500
#
# [5170 rows x 217 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 1
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = training_daten.cov()
    corr_matrix = training_daten.corr()
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    JSE_gewichte_equally_weighted = equally_weighted(training_daten)
    JSE_gewichte_min_variance= min_variance_opt(cov_matrix)
    JSE_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    JSE_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    JSE_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    JSE_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    JSE_gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": JSE_gewichte_equally_weighted,
    "Minimum-Variance": JSE_gewichte_min_variance,
    "Maximum-Diversification": JSE_gewichte_max_diversification,
    "Inverse-Volatility": JSE_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": JSE_gewichte_risk_parity,
    "HRP": JSE_gewichte_hrp,
    "HERC": JSE_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    #Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
    #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
# Alle Testperioden zusammenführen
portfolio_returns_df_JSE = pd.concat(portfolio_returns_list)
portfolio_returns_df_JSE = portfolio_returns_df_JSE.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3134440810290774e-05
#             Iterations: 152
#             Function evaluations: 10184
#             Gradient evaluations: 152
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.653137425667317
#             Iterations: 53
#             Function evaluations: 3590
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1202687138208137e-09
#             Iterations: 44
#             Function evaluations: 2948
#             Gradient evaluations: 44
# 2005-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.223441138083902e-05
#             Iterations: 131
#             Function evaluations: 8778
#             Gradient evaluations: 131
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.235185806557561
#             Iterations: 43
#             Function evaluations: 2911
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.891460438867834e-10
#             Iterations: 54
#             Function evaluations: 3618
#             Gradient evaluations: 54
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.2112396294223096e-05
#             Iterations: 132
#             Function evaluations: 8976
#             Gradient evaluations: 132
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2479692179250157
#             Iterations: 28
#             Function evaluations: 1928
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.004277739155779e-09
#             Iterations: 53
#             Function evaluations: 3604
#             Gradient evaluations: 53
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.2087758665013425e-05
#             Iterations: 122
#             Function evaluations: 8053
#             Gradient evaluations: 122
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.233447253489587
#             Iterations: 27
#             Function evaluations: 1806
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4325462281688088e-09
#             Iterations: 53
#             Function evaluations: 3498
#             Gradient evaluations: 53
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.118768257769819e-05
#             Iterations: 131
#             Function evaluations: 8777
#             Gradient evaluations: 131
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2198144026852855
#             Iterations: 25
#             Function evaluations: 1698
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4725374248741186e-09
#             Iterations: 53
#             Function evaluations: 3551
#             Gradient evaluations: 53
# 2005-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.849248706969756e-05
#             Iterations: 140
#             Function evaluations: 9380
#             Gradient evaluations: 140
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2708143918080976
#             Iterations: 41
#             Function evaluations: 2778
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5942304419793573e-09
#             Iterations: 53
#             Function evaluations: 3552
#             Gradient evaluations: 53
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.859415038915805e-05
#             Iterations: 118
#             Function evaluations: 7906
#             Gradient evaluations: 118
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.296043847782716
#             Iterations: 34
#             Function evaluations: 2312
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7501750850210062e-09
#             Iterations: 53
#             Function evaluations: 3552
#             Gradient evaluations: 53
# 2006-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.689525934548346e-05
#             Iterations: 132
#             Function evaluations: 8976
#             Gradient evaluations: 132
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5406654088724125
#             Iterations: 43
#             Function evaluations: 2957
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.793949339649013e-10
#             Iterations: 65
#             Function evaluations: 4420
#             Gradient evaluations: 65
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.642058632619605e-05
#             Iterations: 120
#             Function evaluations: 8040
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5397191310792295
#             Iterations: 44
#             Function evaluations: 2980
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.362697223033904e-10
#             Iterations: 65
#             Function evaluations: 4355
#             Gradient evaluations: 65
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.627167062020266e-05
#             Iterations: 133
#             Function evaluations: 8911
#             Gradient evaluations: 133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5697138027572857
#             Iterations: 46
#             Function evaluations: 3116
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.110280145497366e-10
#             Iterations: 65
#             Function evaluations: 4355
#             Gradient evaluations: 65
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.004914997086485e-05
#             Iterations: 149
#             Function evaluations: 10132
#             Gradient evaluations: 149
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5898170232990703
#             Iterations: 39
#             Function evaluations: 2691
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3170971178692126e-10
#             Iterations: 54
#             Function evaluations: 3672
#             Gradient evaluations: 54
# 2006-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.737362017555402e-05
#             Iterations: 124
#             Function evaluations: 8928
#             Gradient evaluations: 124
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.677175263552932
#             Iterations: 35
#             Function evaluations: 2555
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.305082135875626e-10
#             Iterations: 54
#             Function evaluations: 3888
#             Gradient evaluations: 54
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.316667755489626e-05
#             Iterations: 140
#             Function evaluations: 10220
#             Gradient evaluations: 140
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7543156812255716
#             Iterations: 36
#             Function evaluations: 2666
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5276998741108466e-09
#             Iterations: 42
#             Function evaluations: 3067
#             Gradient evaluations: 42
# 2006-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3064556389717537e-05
#             Iterations: 140
#             Function evaluations: 10360
#             Gradient evaluations: 140
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.381970760045858
#             Iterations: 60
#             Function evaluations: 4491
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.854170012627015e-09
#             Iterations: 41
#             Function evaluations: 3035
#             Gradient evaluations: 41
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.285803869269542e-05
#             Iterations: 171
#             Function evaluations: 12996
#             Gradient evaluations: 171
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.46733021652852
#             Iterations: 65
#             Function evaluations: 4995
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6638863386240046e-09
#             Iterations: 45
#             Function evaluations: 3421
#             Gradient evaluations: 45
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2521172414402488e-05
#             Iterations: 197
#             Function evaluations: 15563
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1621187521236425
#             Iterations: 59
#             Function evaluations: 4708
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.08218102786104e-09
#             Iterations: 33
#             Function evaluations: 2608
#             Gradient evaluations: 33
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.287275039163127e-05
#             Iterations: 148
#             Function evaluations: 11545
#             Gradient evaluations: 148
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1015136959335297
#             Iterations: 57
#             Function evaluations: 4488
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7795671843477796e-09
#             Iterations: 33
#             Function evaluations: 2574
#             Gradient evaluations: 33
# 2006-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.363951523770541e-05
#             Iterations: 136
#             Function evaluations: 10473
#             Gradient evaluations: 136
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.016655115640611
#             Iterations: 43
#             Function evaluations: 3349
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7480726305763897e-09
#             Iterations: 32
#             Function evaluations: 2465
#             Gradient evaluations: 32
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.478208204480234e-05
#             Iterations: 164
#             Function evaluations: 12956
#             Gradient evaluations: 164
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9052155889846007
#             Iterations: 64
#             Function evaluations: 5105
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7702775342306537e-09
#             Iterations: 32
#             Function evaluations: 2529
#             Gradient evaluations: 32
# 2007-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5717769605751425e-05
#             Iterations: 146
#             Function evaluations: 11826
#             Gradient evaluations: 146
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9594222302745683
#             Iterations: 46
#             Function evaluations: 3772
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7916907188486615e-09
#             Iterations: 31
#             Function evaluations: 2512
#             Gradient evaluations: 31
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.864525360519701e-05
#             Iterations: 139
#             Function evaluations: 11120
#             Gradient evaluations: 139
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.736960396203114
#             Iterations: 39
#             Function evaluations: 3159
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9854429343856237e-09
#             Iterations: 31
#             Function evaluations: 2481
#             Gradient evaluations: 31
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.2437936965525545e-05
#             Iterations: 173
#             Function evaluations: 13668
#             Gradient evaluations: 173
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8242697516535276
#             Iterations: 43
#             Function evaluations: 3438
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.686009616180634e-10
#             Iterations: 43
#             Function evaluations: 3397
#             Gradient evaluations: 43
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.6568036958412397e-05
#             Iterations: 189
#             Function evaluations: 15120
#             Gradient evaluations: 189
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.898518187325527
#             Iterations: 41
#             Function evaluations: 3319
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.905897572195089e-09
#             Iterations: 43
#             Function evaluations: 3440
#             Gradient evaluations: 43
# 2007-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.6745368555708874e-05
#             Iterations: 187
#             Function evaluations: 14960
#             Gradient evaluations: 187
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9461398469451408
#             Iterations: 43
#             Function evaluations: 3481
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.946538812941408e-09
#             Iterations: 43
#             Function evaluations: 3440
#             Gradient evaluations: 43
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.015999680449088e-05
#             Iterations: 158
#             Function evaluations: 12166
#             Gradient evaluations: 158
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.877491757511488
#             Iterations: 44
#             Function evaluations: 3432
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.683014382006474e-09
#             Iterations: 43
#             Function evaluations: 3311
#             Gradient evaluations: 43
# 2007-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.9412981543266865e-05
#             Iterations: 161
#             Function evaluations: 12559
#             Gradient evaluations: 161
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.84209872102518
#             Iterations: 43
#             Function evaluations: 3393
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.498560217486251e-09
#             Iterations: 43
#             Function evaluations: 3354
#             Gradient evaluations: 43
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.493057894033677e-05
#             Iterations: 133
#             Function evaluations: 10640
#             Gradient evaluations: 133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0375286887945956
#             Iterations: 43
#             Function evaluations: 3480
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2125919608147287e-09
#             Iterations: 44
#             Function evaluations: 3521
#             Gradient evaluations: 44
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.2185038010872135e-05
#             Iterations: 149
#             Function evaluations: 11771
#             Gradient evaluations: 149
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.3242589167202286
#             Iterations: 44
#             Function evaluations: 3520
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6241572785185804e-09
#             Iterations: 42
#             Function evaluations: 3319
#             Gradient evaluations: 42
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.099017965153715e-05
#             Iterations: 156
#             Function evaluations: 12012
#             Gradient evaluations: 156
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.2440977493924046
#             Iterations: 54
#             Function evaluations: 4197
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.656611422037203e-10
#             Iterations: 52
#             Function evaluations: 4004
#             Gradient evaluations: 52
# 2007-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.254776342479657e-05
#             Iterations: 133
#             Function evaluations: 10374
#             Gradient evaluations: 133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.012239501416448
#             Iterations: 37
#             Function evaluations: 2919
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.854157956555348e-10
#             Iterations: 72
#             Function evaluations: 5616
#             Gradient evaluations: 72
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.202402132898705e-05
#             Iterations: 162
#             Function evaluations: 12798
#             Gradient evaluations: 162
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9390265799580986
#             Iterations: 37
#             Function evaluations: 2956
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.66764580158499e-10
#             Iterations: 82
#             Function evaluations: 6478
#             Gradient evaluations: 82
# 2008-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.764470787871135e-05
#             Iterations: 153
#             Function evaluations: 11934
#             Gradient evaluations: 153
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8406378800744045
#             Iterations: 42
#             Function evaluations: 3310
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.855057037133563e-10
#             Iterations: 81
#             Function evaluations: 6319
#             Gradient evaluations: 81
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.613308742883006e-05
#             Iterations: 150
#             Function evaluations: 11550
#             Gradient evaluations: 150
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9521139070587727
#             Iterations: 42
#             Function evaluations: 3266
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.660572655724805e-10
#             Iterations: 92
#             Function evaluations: 7084
#             Gradient evaluations: 92
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.165740827801172e-05
#             Iterations: 154
#             Function evaluations: 11858
#             Gradient evaluations: 154
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0216309001895882
#             Iterations: 45
#             Function evaluations: 3497
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.847184879797634e-10
#             Iterations: 103
#             Function evaluations: 7931
#             Gradient evaluations: 103
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.247322005436656e-05
#             Iterations: 162
#             Function evaluations: 12474
#             Gradient evaluations: 162
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.090891504506812
#             Iterations: 43
#             Function evaluations: 3343
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.338249654609997e-10
#             Iterations: 134
#             Function evaluations: 10318
#             Gradient evaluations: 134
# 2008-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.500359588454596e-05
#             Iterations: 167
#             Function evaluations: 12692
#             Gradient evaluations: 167
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0907487626794197
#             Iterations: 47
#             Function evaluations: 3607
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.515974136771395e-10
#             Iterations: 122
#             Function evaluations: 9273
#             Gradient evaluations: 122
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.904663878338106e-05
#             Iterations: 144
#             Function evaluations: 10944
#             Gradient evaluations: 144
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0787953783759843
#             Iterations: 47
#             Function evaluations: 3607
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.131393225491523e-10
#             Iterations: 111
#             Function evaluations: 8436
#             Gradient evaluations: 111
# 2008-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.826234078414551e-05
#             Iterations: 142
#             Function evaluations: 10792
#             Gradient evaluations: 142
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0873662395432135
#             Iterations: 37
#             Function evaluations: 2845
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.25794543476294e-10
#             Iterations: 99
#             Function evaluations: 7525
#             Gradient evaluations: 99
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.964045892800607e-05
#             Iterations: 138
#             Function evaluations: 10488
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.11343860360847
#             Iterations: 39
#             Function evaluations: 2996
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.14864806929461e-10
#             Iterations: 120
#             Function evaluations: 9120
#             Gradient evaluations: 120
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.876018550733002e-05
#             Iterations: 153
#             Function evaluations: 11628
#             Gradient evaluations: 153
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.989239863956551
#             Iterations: 41
#             Function evaluations: 3152
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.162066781630115e-10
#             Iterations: 109
#             Function evaluations: 8284
#             Gradient evaluations: 109
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.36103865286447e-05
#             Iterations: 146
#             Function evaluations: 10951
#             Gradient evaluations: 146
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9604084300432727
#             Iterations: 39
#             Function evaluations: 2960
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.123400174497303e-10
#             Iterations: 100
#             Function evaluations: 7500
#             Gradient evaluations: 100
# 2008-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.421477286643637e-05
#             Iterations: 159
#             Function evaluations: 11766
#             Gradient evaluations: 159
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.312783550149356
#             Iterations: 47
#             Function evaluations: 3518
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2910297960019993e-09
#             Iterations: 136
#             Function evaluations: 10064
#             Gradient evaluations: 136
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.608105600686514e-05
#             Iterations: 137
#             Function evaluations: 10413
#             Gradient evaluations: 137
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.533439398965292
#             Iterations: 51
#             Function evaluations: 3924
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3783486293329875e-09
#             Iterations: 107
#             Function evaluations: 8132
#             Gradient evaluations: 107
# 2009-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.294888637740016e-05
#             Iterations: 174
#             Function evaluations: 13746
#             Gradient evaluations: 174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.585901572790216
#             Iterations: 53
#             Function evaluations: 4157
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.594433834172159e-09
#             Iterations: 86
#             Function evaluations: 6795
#             Gradient evaluations: 86
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5411435395710477e-05
#             Iterations: 179
#             Function evaluations: 15215
#             Gradient evaluations: 179
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7194694586372865
#             Iterations: 56
#             Function evaluations: 4731
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.225929699992275e-09
#             Iterations: 85
#             Function evaluations: 7226
#             Gradient evaluations: 85
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2108404001062312e-05
#             Iterations: 195
#             Function evaluations: 16576
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8017558532734754
#             Iterations: 59
#             Function evaluations: 5070
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.914048721489231e-09
#             Iterations: 84
#             Function evaluations: 7140
#             Gradient evaluations: 84
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.750886650300289e-05
#             Iterations: 217
#             Function evaluations: 18228
#             Gradient evaluations: 217
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8810267589327205
#             Iterations: 59
#             Function evaluations: 5011
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.1216320173923685e-09
#             Iterations: 76
#             Function evaluations: 6385
#             Gradient evaluations: 76
# 2009-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.569364134772663e-05
#             Iterations: 185
#             Function evaluations: 15540
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.87198893007534
#             Iterations: 54
#             Function evaluations: 4589
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.506563386655085e-09
#             Iterations: 64
#             Function evaluations: 5377
#             Gradient evaluations: 64
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7223491673189227e-05
#             Iterations: 200
#             Function evaluations: 17200
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6340233261636867
#             Iterations: 85
#             Function evaluations: 7252
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.837832603079748e-09
#             Iterations: 76
#             Function evaluations: 6536
#             Gradient evaluations: 76
# 2009-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7486740447978734e-05
#             Iterations: 211
#             Function evaluations: 17935
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.50242489381647
#             Iterations: 50
#             Function evaluations: 4295
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.49565840810712e-09
#             Iterations: 68
#             Function evaluations: 5780
#             Gradient evaluations: 68
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6793775693611726e-05
#             Iterations: 208
#             Function evaluations: 17473
#             Gradient evaluations: 208
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.544390252349358
#             Iterations: 57
#             Function evaluations: 4503
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.316071954319211e-09
#             Iterations: 56
#             Function evaluations: 4705
#             Gradient evaluations: 56
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6517564005544384e-05
#             Iterations: 195
#             Function evaluations: 16575
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5731510164651388
#             Iterations: 51
#             Function evaluations: 4380
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3644385948810775e-09
#             Iterations: 56
#             Function evaluations: 4760
#             Gradient evaluations: 56
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.250891958536064e-05
#             Iterations: 233
#             Function evaluations: 20038
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.775630430490246
#             Iterations: 56
#             Function evaluations: 4783
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.227540443450577e-09
#             Iterations: 56
#             Function evaluations: 4816
#             Gradient evaluations: 56
# 2009-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3101163724954388e-05
#             Iterations: 221
#             Function evaluations: 19007
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7582793682889406
#             Iterations: 53
#             Function evaluations: 4521
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.319677518808092e-09
#             Iterations: 57
#             Function evaluations: 4902
#             Gradient evaluations: 57
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.261103504539436e-05
#             Iterations: 215
#             Function evaluations: 18490
#             Gradient evaluations: 215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.686923448426036
#             Iterations: 53
#             Function evaluations: 4609
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.657108988858343e-09
#             Iterations: 57
#             Function evaluations: 4902
#             Gradient evaluations: 57
# 2010-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2122781113403088e-05
#             Iterations: 234
#             Function evaluations: 20359
#             Gradient evaluations: 234
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.915594127627967
#             Iterations: 55
#             Function evaluations: 4755
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.921497278639507e-09
#             Iterations: 57
#             Function evaluations: 4959
#             Gradient evaluations: 57
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2377680964100189e-05
#             Iterations: 240
#             Function evaluations: 21600
#             Gradient evaluations: 240
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.945247603719802
#             Iterations: 57
#             Function evaluations: 5182
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8465484006603205e-09
#             Iterations: 57
#             Function evaluations: 5130
#             Gradient evaluations: 57
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2826819379717429e-05
#             Iterations: 223
#             Function evaluations: 19847
#             Gradient evaluations: 223
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.039279448609274
#             Iterations: 61
#             Function evaluations: 5128
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.500090940196717e-09
#             Iterations: 57
#             Function evaluations: 5073
#             Gradient evaluations: 57
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3413686573649772e-05
#             Iterations: 235
#             Function evaluations: 20916
#             Gradient evaluations: 235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.852233115717422
#             Iterations: 52
#             Function evaluations: 4676
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.78641431529536e-09
#             Iterations: 57
#             Function evaluations: 5073
#             Gradient evaluations: 57
# 2010-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3070723473231971e-05
#             Iterations: 246
#             Function evaluations: 21894
#             Gradient evaluations: 246
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9059897338934175
#             Iterations: 56
#             Function evaluations: 4950
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.420974030309264e-09
#             Iterations: 57
#             Function evaluations: 5073
#             Gradient evaluations: 57
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1226748234171139e-05
#             Iterations: 237
#             Function evaluations: 20619
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.04682594292206
#             Iterations: 57
#             Function evaluations: 4928
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.492208989936472e-09
#             Iterations: 42
#             Function evaluations: 3654
#             Gradient evaluations: 42
# 2010-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.121033485031064e-05
#             Iterations: 244
#             Function evaluations: 21228
#             Gradient evaluations: 244
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.929138413462669
#             Iterations: 55
#             Function evaluations: 4836
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.622188216021423e-09
#             Iterations: 41
#             Function evaluations: 3567
#             Gradient evaluations: 41
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0472008943100286e-05
#             Iterations: 201
#             Function evaluations: 18291
#             Gradient evaluations: 201
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.178987604109217
#             Iterations: 58
#             Function evaluations: 5335
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.722634169698766e-09
#             Iterations: 43
#             Function evaluations: 3913
#             Gradient evaluations: 43
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2180120466558345e-05
#             Iterations: 233
#             Function evaluations: 21204
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8679891978916836
#             Iterations: 51
#             Function evaluations: 4692
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.254044339067941e-09
#             Iterations: 42
#             Function evaluations: 3822
#             Gradient evaluations: 42
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2937545025472699e-05
#             Iterations: 216
#             Function evaluations: 20088
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.046877609134621
#             Iterations: 52
#             Function evaluations: 4887
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9333933142338135e-09
#             Iterations: 46
#             Function evaluations: 4278
#             Gradient evaluations: 46
# 2010-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3844387126890872e-05
#             Iterations: 216
#             Function evaluations: 19872
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.675731280572719
#             Iterations: 49
#             Function evaluations: 4552
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.748533827865167e-09
#             Iterations: 45
#             Function evaluations: 4140
#             Gradient evaluations: 45
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3687150043097548e-05
#             Iterations: 212
#             Function evaluations: 19504
#             Gradient evaluations: 212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7490132054974463
#             Iterations: 49
#             Function evaluations: 4552
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6614447934367397e-09
#             Iterations: 57
#             Function evaluations: 5244
#             Gradient evaluations: 57
# 2011-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4529468958537211e-05
#             Iterations: 203
#             Function evaluations: 18271
#             Gradient evaluations: 203
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.3842228193765442
#             Iterations: 48
#             Function evaluations: 4368
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.475526810480392e-09
#             Iterations: 45
#             Function evaluations: 4051
#             Gradient evaluations: 45
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3810036328875528e-05
#             Iterations: 195
#             Function evaluations: 17550
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.413806682991515
#             Iterations: 51
#             Function evaluations: 4637
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7980262539798006e-09
#             Iterations: 57
#             Function evaluations: 5131
#             Gradient evaluations: 57
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.237215599368564e-05
#             Iterations: 206
#             Function evaluations: 18541
#             Gradient evaluations: 206
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4619774673549144
#             Iterations: 51
#             Function evaluations: 4637
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9760280397540073e-09
#             Iterations: 57
#             Function evaluations: 5130
#             Gradient evaluations: 57
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1844473714327768e-05
#             Iterations: 225
#             Function evaluations: 20250
#             Gradient evaluations: 225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4649097033849237
#             Iterations: 51
#             Function evaluations: 4636
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.697445260281619e-09
#             Iterations: 58
#             Function evaluations: 5220
#             Gradient evaluations: 58
# 2011-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.168681964294581e-05
#             Iterations: 235
#             Function evaluations: 21385
#             Gradient evaluations: 235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.539661892748205
#             Iterations: 57
#             Function evaluations: 4871
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.9800978594551835e-09
#             Iterations: 45
#             Function evaluations: 4096
#             Gradient evaluations: 45
# 2011-06-01 00:00:00
# ...
#             Iterations: 247
#             Function evaluations: 38286
#             Gradient evaluations: 247
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.0320146612446575
#             Iterations: 88
#             Function evaluations: 13147
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.463262316108444e-09
#             Iterations: 56
#             Function evaluations: 8680
#             Gradient evaluations: 56
# 2022-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3887250456272652e-05
#             Iterations: 231
#             Function evaluations: 36267
#             Gradient evaluations: 231
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.365854140131816
#             Iterations: 123
#             Function evaluations: 19097
#             Gradient evaluations: 119
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.7115848701636375e-09
#             Iterations: 42
#             Function evaluations: 6595
#             Gradient evaluations: 42
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2814081746620865e-05
#             Iterations: 237
#             Function evaluations: 37684
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.612487218140196
#             Iterations: 113
#             Function evaluations: 17544
#             Gradient evaluations: 109
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.689922032275674e-09
#             Iterations: 44
#             Function evaluations: 6996
#             Gradient evaluations: 44
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2294353817072064e-05
#             Iterations: 246
#             Function evaluations: 38622
#             Gradient evaluations: 246
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.444898212459175
#             Iterations: 98
#             Function evaluations: 14891
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.47255262819187e-09
#             Iterations: 44
#             Function evaluations: 6908
#             Gradient evaluations: 44
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1798537812387731e-05
#             Iterations: 249
#             Function evaluations: 38844
#             Gradient evaluations: 249
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.396765432658553
#             Iterations: 114
#             Function evaluations: 17382
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.8540964883590575e-09
#             Iterations: 57
#             Function evaluations: 8892
#             Gradient evaluations: 57
# 2022-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0987218367806257e-05
#             Iterations: 276
#             Function evaluations: 42505
#             Gradient evaluations: 276
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.436664590457963
#             Iterations: 98
#             Function evaluations: 14618
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.999862661400244e-09
#             Iterations: 42
#             Function evaluations: 6468
#             Gradient evaluations: 42
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0638443984101544e-05
#             Iterations: 262
#             Function evaluations: 39824
#             Gradient evaluations: 262
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.454284185655669
#             Iterations: 98
#             Function evaluations: 14444
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.342262248551165e-09
#             Iterations: 41
#             Function evaluations: 6233
#             Gradient evaluations: 41
# 2023-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1674366517199752e-05
#             Iterations: 262
#             Function evaluations: 40087
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.067689826152124
#             Iterations: 87
#             Function evaluations: 13292
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.73995259797539e-09
#             Iterations: 38
#             Function evaluations: 5814
#             Gradient evaluations: 38
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1646390485915314e-05
#             Iterations: 244
#             Function evaluations: 37088
#             Gradient evaluations: 244
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.97073625711648
#             Iterations: 95
#             Function evaluations: 13973
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.46474672838338e-09
#             Iterations: 41
#             Function evaluations: 6232
#             Gradient evaluations: 41
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.063284841313195e-05
#             Iterations: 238
#             Function evaluations: 36414
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.3270842433776835
#             Iterations: 106
#             Function evaluations: 15777
#             Gradient evaluations: 102
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.321299048435709e-09
#             Iterations: 53
#             Function evaluations: 8109
#             Gradient evaluations: 53
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1097444403864161e-05
#             Iterations: 240
#             Function evaluations: 36481
#             Gradient evaluations: 240
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.330845830415378
#             Iterations: 114
#             Function evaluations: 17041
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.480961611131053e-09
#             Iterations: 54
#             Function evaluations: 8208
#             Gradient evaluations: 54
# 2023-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1292244936812047e-05
#             Iterations: 243
#             Function evaluations: 36693
#             Gradient evaluations: 243
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.275504929588708
#             Iterations: 98
#             Function evaluations: 14340
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.337565459827926e-09
#             Iterations: 53
#             Function evaluations: 8003
#             Gradient evaluations: 53
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1447418857812869e-05
#             Iterations: 251
#             Function evaluations: 38153
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.19533116508335
#             Iterations: 132
#             Function evaluations: 19866
#             Gradient evaluations: 128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.521352585971489e-09
#             Iterations: 50
#             Function evaluations: 7600
#             Gradient evaluations: 50
# 2023-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1770874236662738e-05
#             Iterations: 239
#             Function evaluations: 36090
#             Gradient evaluations: 239
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.1771933912290065
#             Iterations: 143
#             Function evaluations: 21241
#             Gradient evaluations: 139
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.196723176859241e-09
#             Iterations: 52
#             Function evaluations: 7852
#             Gradient evaluations: 52
# 2023-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1422709202129747e-05
#             Iterations: 264
#             Function evaluations: 40128
#             Gradient evaluations: 264
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.231100190427219
#             Iterations: 103
#             Function evaluations: 15219
#             Gradient evaluations: 99
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.031185921833766e-09
#             Iterations: 53
#             Function evaluations: 8056
#             Gradient evaluations: 53
# 2023-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2372712447469051e-05
#             Iterations: 271
#             Function evaluations: 41192
#             Gradient evaluations: 271
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.937598664593337
#             Iterations: 90
#             Function evaluations: 13659
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.144905305434035e-09
#             Iterations: 52
#             Function evaluations: 7904
#             Gradient evaluations: 52
# 2023-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2166903906411595e-05
#             Iterations: 263
#             Function evaluations: 39714
#             Gradient evaluations: 263
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.019509049152355
#             Iterations: 96
#             Function evaluations: 14483
#             Gradient evaluations: 95
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.938520382132033e-09
#             Iterations: 52
#             Function evaluations: 7853
#             Gradient evaluations: 52
# 2023-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1379043060892592e-05
#             Iterations: 280
#             Function evaluations: 42281
#             Gradient evaluations: 280
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.297994585923236
#             Iterations: 105
#             Function evaluations: 15459
#             Gradient evaluations: 101
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.653128045569433e-09
#             Iterations: 54
#             Function evaluations: 8154
#             Gradient evaluations: 54
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.090650657560652e-05
#             Iterations: 274
#             Function evaluations: 41648
#             Gradient evaluations: 274
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.42072094048574
#             Iterations: 124
#             Function evaluations: 18525
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.288669387680618e-09
#             Iterations: 49
#             Function evaluations: 7448
#             Gradient evaluations: 49
# 2024-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.979513492822373e-06
#             Iterations: 273
#             Function evaluations: 41770
#             Gradient evaluations: 273
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.587006372008517
#             Iterations: 94
#             Function evaluations: 14376
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.261228630339873e-09
#             Iterations: 50
#             Function evaluations: 7650
#             Gradient evaluations: 50
# 2024-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0519396753445875e-05
#             Iterations: 257
#             Function evaluations: 39064
#             Gradient evaluations: 257
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.387403771748381
#             Iterations: 138
#             Function evaluations: 20844
#             Gradient evaluations: 134
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.0320985072202475e-09
#             Iterations: 50
#             Function evaluations: 7600
#             Gradient evaluations: 50
# 2024-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0351648265315334e-05
#             Iterations: 262
#             Function evaluations: 39824
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.32699970952182
#             Iterations: 93
#             Function evaluations: 14121
#             Gradient evaluations: 92
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.679937232841723e-09
#             Iterations: 54
#             Function evaluations: 8208
#             Gradient evaluations: 54
# 2024-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0245149374963766e-05
#             Iterations: 280
#             Function evaluations: 42281
#             Gradient evaluations: 280
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.464131357018838
#             Iterations: 88
#             Function evaluations: 13268
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.180734991124907e-09
#             Iterations: 51
#             Function evaluations: 7701
#             Gradient evaluations: 51
# 2024-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.613647437859872e-05
#             Iterations: 257
#             Function evaluations: 39578
#             Gradient evaluations: 257
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5.2848170879329786
#             Iterations: 83
#             Function evaluations: 12267
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.2371265062415355e-09
#             Iterations: 66
#             Function evaluations: 10164
#             Gradient evaluations: 66
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_JSE.to_csv("returnsJSE_neu_f.csv")

# %% [markdown]
# ## Ledoit-Wolf Shrinkage

# %%
#Definition von Ledoit-Shrinkage

def ledoit_shrink (returns):
    
    shrinkage = LedoitWolf().fit(returns.values)
    
    shrinkage_matrix = pd.DataFrame(
        shrinkage.covariance_,
        index = returns.columns,
        columns = returns.columns)
    
    return shrinkage_matrix

# %% [markdown]
# ### Auswertung S&P500 mit Ledoit Wolf

# %%
returns = df_SP500.pct_change()
returns = returns.where(~df_SP500.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                    A  AAL  AAP      AAPL      ABBV      ABNB       ABT  \
# Date
# 2005-06-02  0.000414  NaN  NaN -0.006452       NaN       NaN -0.001448
# 2005-06-03 -0.005374  NaN  NaN -0.044955       NaN       NaN  0.000207
# 2005-06-06  0.019119  NaN  NaN -0.008368       NaN       NaN  0.003729
# 2005-06-07 -0.012235  NaN  NaN -0.036393       NaN       NaN  0.006398
# 2005-06-08  0.009496  NaN  NaN  0.010399       NaN       NaN -0.002051
# ...              ...  ...  ...       ...       ...       ...       ...
# 2025-05-23 -0.010485  NaN  NaN -0.030244  0.003944 -0.007286 -0.001521
# 2025-05-27  0.025154  NaN  NaN  0.025298  0.013424  0.021149  0.012490
# 2025-05-28 -0.003415  NaN  NaN  0.001049 -0.014161 -0.005641 -0.006920
# 2025-05-29  0.021645  NaN  NaN -0.002345  0.013818 -0.002409  0.006287
# 2025-05-30 -0.012006  NaN  NaN  0.004501  0.002640  0.004986  0.005495
#
#                 ACGL       ACN      ADBE  ...       XEL       XOM  XRAY  \
# Date                                      ...
# 2005-06-02       NaN       NaN -0.002712  ...  0.002678  0.002975   NaN
# 2005-06-03       NaN       NaN -0.016621  ...  0.004808 -0.002966   NaN
# 2005-06-06       NaN       NaN -0.002766  ...  0.000532  0.007874   NaN
# 2005-06-07       NaN       NaN -0.005855  ...  0.004251 -0.002604   NaN
# 2005-06-08       NaN       NaN  0.000000  ...  0.017460 -0.012533   NaN
# ...              ...       ...       ...  ...       ...       ...   ...
# 2025-05-23  0.001087 -0.021710 -0.016026  ...  0.007513  0.000583   NaN
# 2025-05-27  0.027696  0.018897  0.013270  ...  0.001147  0.004756   NaN
# 2025-05-28 -0.017332  0.001775 -0.002106  ... -0.012606 -0.013621   NaN
# 2025-05-29  0.013121  0.005507  0.002741  ...  0.007834  0.005680   NaN
# 2025-05-30  0.008917 -0.002864  0.004185  ...  0.009069 -0.003798   NaN
#
#                  XRX       XYL       YUM       ZBH      ZBRA      ZION  \
# Date
# 2005-06-02 -0.003650       NaN  0.021558  0.002885       NaN  0.005945
# 2005-06-03 -0.006593       NaN -0.010646  0.029816       NaN -0.008246
# 2005-06-06 -0.011062       NaN -0.000769 -0.005079       NaN -0.000139
# 2005-06-07 -0.006711       NaN  0.003077  0.013657       NaN -0.002772
# 2005-06-08  0.039039       NaN -0.006518 -0.005414       NaN -0.002085
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23       NaN -0.009739 -0.000344  0.010581 -0.014392       NaN
# 2025-05-27       NaN  0.017654 -0.009350  0.016947  0.038000       NaN
# 2025-05-28       NaN -0.004674 -0.006524 -0.020380 -0.014271       NaN
# 2025-05-29       NaN  0.000080  0.006217  0.011377  0.005846       NaN
# 2025-05-30       NaN  0.003024 -0.000694 -0.012535 -0.009333       NaN
#
#                  ZTS
# Date
# 2005-06-02       NaN
# 2005-06-03       NaN
# 2005-06-06       NaN
# 2005-06-07       NaN
# 2005-06-08       NaN
# ...              ...
# 2025-05-23  0.003766
# 2025-05-27  0.022635
# 2025-05-28 -0.005173
# 2025-05-29  0.010520
# 2025-05-30  0.008915
#
# [5031 rows x 598 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 1
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = ledoit_shrink(training_daten)
    
    #aus der geschrumpften Matrix die Korrelationsmatrix bauen
    standardabweichung = np.sqrt(np.diag(cov_matrix))
    corr_matrix = cov_matrix / np.outer(standardabweichung, standardabweichung)
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    shrinked_gewichte_equally_weighted = equally_weighted(training_daten)
    shrinked_gewichte_min_variance= min_variance_opt(cov_matrix)
    shrinked_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    shrinked_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    shrinked_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    shrinked_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    shrinked_gewichte_herc = herc_ledoit(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": shrinked_gewichte_equally_weighted,
    "Minimum-Variance": shrinked_gewichte_min_variance,
    "Maximum-Diversification": shrinked_gewichte_max_diversification,
    "Inverse-Volatility": shrinked_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": shrinked_gewichte_risk_parity,
    "HRP": shrinked_gewichte_hrp,
    "HERC": shrinked_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
    #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_shrinked = pd.concat(portfolio_returns_list)
portfolio_returns_df_shrinked = portfolio_returns_df_shrinked.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5288862200654737e-05
#             Iterations: 308
#             Function evaluations: 81312
#             Gradient evaluations: 308
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1767340633144645
#             Iterations: 80
#             Function evaluations: 20138
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.367469318835228e-09
#             Iterations: 9
#             Function evaluations: 2376
#             Gradient evaluations: 9
# 2005-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6505292460375198e-05
#             Iterations: 293
#             Function evaluations: 77352
#             Gradient evaluations: 293
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.959153347945711
#             Iterations: 78
#             Function evaluations: 19607
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.588551456119902e-09
#             Iterations: 21
#             Function evaluations: 5544
#             Gradient evaluations: 21
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.67889435502806e-05
#             Iterations: 300
#             Function evaluations: 79800
#             Gradient evaluations: 300
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9599933973857606
#             Iterations: 83
#             Function evaluations: 21102
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.4026876436595614e-09
#             Iterations: 20
#             Function evaluations: 5321
#             Gradient evaluations: 20
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6519176079888082e-05
#             Iterations: 259
#             Function evaluations: 69672
#             Gradient evaluations: 259
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.025200118337369
#             Iterations: 84
#             Function evaluations: 21605
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.285383763712697e-09
#             Iterations: 20
#             Function evaluations: 5381
#             Gradient evaluations: 20
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5702565664566613e-05
#             Iterations: 313
#             Function evaluations: 84197
#             Gradient evaluations: 313
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.017946102283101
#             Iterations: 76
#             Function evaluations: 20516
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.172475061620501e-09
#             Iterations: 31
#             Function evaluations: 8339
#             Gradient evaluations: 31
# 2005-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.418111722803791e-05
#             Iterations: 314
#             Function evaluations: 85094
#             Gradient evaluations: 314
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.2181293422917014
#             Iterations: 79
#             Function evaluations: 20399
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.201062606114319e-09
#             Iterations: 28
#             Function evaluations: 7588
#             Gradient evaluations: 28
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.437936973290573e-05
#             Iterations: 299
#             Function evaluations: 81029
#             Gradient evaluations: 299
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1814314294424912
#             Iterations: 74
#             Function evaluations: 19038
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1732524466424905e-09
#             Iterations: 23
#             Function evaluations: 6233
#             Gradient evaluations: 23
# 2006-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4093510616437325e-05
#             Iterations: 310
#             Function evaluations: 84630
#             Gradient evaluations: 310
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.193196189408138
#             Iterations: 78
#             Function evaluations: 21371
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4744177914719502e-09
#             Iterations: 27
#             Function evaluations: 7371
#             Gradient evaluations: 27
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2916693463715328e-05
#             Iterations: 301
#             Function evaluations: 82474
#             Gradient evaluations: 301
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.219892394705214
#             Iterations: 81
#             Function evaluations: 21176
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.624470963323754e-09
#             Iterations: 26
#             Function evaluations: 7125
#             Gradient evaluations: 26
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4495305558664684e-05
#             Iterations: 313
#             Function evaluations: 86075
#             Gradient evaluations: 313
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.049913410877277
#             Iterations: 74
#             Function evaluations: 20422
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5569513681205894e-09
#             Iterations: 27
#             Function evaluations: 7425
#             Gradient evaluations: 27
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.657100076421387e-05
#             Iterations: 323
#             Function evaluations: 88825
#             Gradient evaluations: 323
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.878340068057983
#             Iterations: 76
#             Function evaluations: 19873
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.458855213768547e-09
#             Iterations: 26
#             Function evaluations: 7150
#             Gradient evaluations: 26
# 2006-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6167318701082265e-05
#             Iterations: 303
#             Function evaluations: 84235
#             Gradient evaluations: 303
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9330103283187747
#             Iterations: 76
#             Function evaluations: 20085
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4629326809719041e-09
#             Iterations: 38
#             Function evaluations: 10564
#             Gradient evaluations: 38
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5854763579769293e-05
#             Iterations: 280
#             Function evaluations: 77840
#             Gradient evaluations: 280
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0076215287471926
#             Iterations: 79
#             Function evaluations: 20930
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.724209090209557e-09
#             Iterations: 27
#             Function evaluations: 7506
#             Gradient evaluations: 27
# 2006-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.621151098493346e-05
#             Iterations: 295
#             Function evaluations: 82306
#             Gradient evaluations: 295
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.075824564769627
#             Iterations: 64
#             Function evaluations: 17641
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4618719221454564e-09
#             Iterations: 27
#             Function evaluations: 7533
#             Gradient evaluations: 27
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.774205682641366e-05
#             Iterations: 267
#             Function evaluations: 74227
#             Gradient evaluations: 267
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.121246259301799
#             Iterations: 66
#             Function evaluations: 17585
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5955538795350288e-09
#             Iterations: 21
#             Function evaluations: 5838
#             Gradient evaluations: 21
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4630086756328893e-05
#             Iterations: 284
#             Function evaluations: 79236
#             Gradient evaluations: 284
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8709766024123082
#             Iterations: 81
#             Function evaluations: 21583
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6100921805939988e-09
#             Iterations: 20
#             Function evaluations: 5580
#             Gradient evaluations: 20
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6369080435881867e-05
#             Iterations: 247
#             Function evaluations: 68913
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7710790079086074
#             Iterations: 58
#             Function evaluations: 15120
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7477820932045088e-09
#             Iterations: 19
#             Function evaluations: 5301
#             Gradient evaluations: 19
# 2006-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7759707185557492e-05
#             Iterations: 262
#             Function evaluations: 73361
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7205221710804914
#             Iterations: 59
#             Function evaluations: 15459
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8071903340224977e-09
#             Iterations: 16
#             Function evaluations: 4480
#             Gradient evaluations: 16
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1488954114940315e-05
#             Iterations: 262
#             Function evaluations: 74146
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5706775380278493
#             Iterations: 47
#             Function evaluations: 13064
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.659018115558484e-09
#             Iterations: 30
#             Function evaluations: 8490
#             Gradient evaluations: 30
# 2007-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3195953224061374e-05
#             Iterations: 235
#             Function evaluations: 66976
#             Gradient evaluations: 235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5325101453662398
#             Iterations: 58
#             Function evaluations: 15459
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8587827783888429e-09
#             Iterations: 30
#             Function evaluations: 8550
#             Gradient evaluations: 30
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.89983326460673e-05
#             Iterations: 245
#             Function evaluations: 69826
#             Gradient evaluations: 245
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.509788557319407
#             Iterations: 58
#             Function evaluations: 15448
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0134906036599704e-09
#             Iterations: 48
#             Function evaluations: 13680
#             Gradient evaluations: 48
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.0396231206694467e-05
#             Iterations: 223
#             Function evaluations: 63778
#             Gradient evaluations: 223
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5039352536128314
#             Iterations: 50
#             Function evaluations: 13201
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0867096287037956e-09
#             Iterations: 47
#             Function evaluations: 13442
#             Gradient evaluations: 47
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3011341760476444e-05
#             Iterations: 253
#             Function evaluations: 73117
#             Gradient evaluations: 253
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6587956963036263
#             Iterations: 47
#             Function evaluations: 13338
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.315488138946422e-10
#             Iterations: 57
#             Function evaluations: 16474
#             Gradient evaluations: 57
# 2007-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.448685914879543e-05
#             Iterations: 225
#             Function evaluations: 65475
#             Gradient evaluations: 225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.643628601408893
#             Iterations: 64
#             Function evaluations: 17529
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.523987642619557e-10
#             Iterations: 56
#             Function evaluations: 16296
#             Gradient evaluations: 56
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.5411428925910594e-05
#             Iterations: 246
#             Function evaluations: 71586
#             Gradient evaluations: 246
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6422651399028068
#             Iterations: 42
#             Function evaluations: 12262
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1484385309851184e-09
#             Iterations: 57
#             Function evaluations: 16588
#             Gradient evaluations: 57
# 2007-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.878743690956813e-05
#             Iterations: 246
#             Function evaluations: 71340
#             Gradient evaluations: 246
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.59186858309651
#             Iterations: 36
#             Function evaluations: 10477
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.080176662333151e-10
#             Iterations: 66
#             Function evaluations: 19140
#             Gradient evaluations: 66
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7548110958653614e-05
#             Iterations: 215
#             Function evaluations: 62566
#             Gradient evaluations: 215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5978355427899853
#             Iterations: 49
#             Function evaluations: 13139
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1886893305855933e-09
#             Iterations: 73
#             Function evaluations: 21244
#             Gradient evaluations: 73
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.482210527535818e-05
#             Iterations: 250
#             Function evaluations: 72500
#             Gradient evaluations: 250
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.685644465879097
#             Iterations: 78
#             Function evaluations: 21549
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.26720622307314e-09
#             Iterations: 83
#             Function evaluations: 24070
#             Gradient evaluations: 83
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.5847626408900054e-05
#             Iterations: 200
#             Function evaluations: 58000
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.551611837851268
#             Iterations: 47
#             Function evaluations: 13380
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2545863386397255e-09
#             Iterations: 88
#             Function evaluations: 25521
#             Gradient evaluations: 88
# 2007-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00014689034717036136
#             Iterations: 158
#             Function evaluations: 45978
#             Gradient evaluations: 158
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0758811164768587
#             Iterations: 35
#             Function evaluations: 10209
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.294207390876197e-10
#             Iterations: 76
#             Function evaluations: 22117
#             Gradient evaluations: 76
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001820995126410556
#             Iterations: 138
#             Function evaluations: 39883
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9624980418975846
#             Iterations: 27
#             Function evaluations: 7823
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.726086949250995e-10
#             Iterations: 82
#             Function evaluations: 23698
#             Gradient evaluations: 82
# 2008-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00020107646644832464
#             Iterations: 126
#             Function evaluations: 36666
#             Gradient evaluations: 126
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9237810240079751
#             Iterations: 25
#             Function evaluations: 7291
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7341696445994477e-10
#             Iterations: 89
#             Function evaluations: 25900
#             Gradient evaluations: 89
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002013400461159941
#             Iterations: 114
#             Function evaluations: 33175
#             Gradient evaluations: 114
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9098058982135202
#             Iterations: 26
#             Function evaluations: 7586
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3768834027353787e-10
#             Iterations: 97
#             Function evaluations: 28227
#             Gradient evaluations: 97
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021007277721837105
#             Iterations: 125
#             Function evaluations: 36376
#             Gradient evaluations: 125
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.920480095588607
#             Iterations: 28
#             Function evaluations: 8169
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5900742891644159e-10
#             Iterations: 97
#             Function evaluations: 28227
#             Gradient evaluations: 97
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022619872851398361
#             Iterations: 129
#             Function evaluations: 37668
#             Gradient evaluations: 129
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8105468922993717
#             Iterations: 29
#             Function evaluations: 8487
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1302435598458933e-10
#             Iterations: 95
#             Function evaluations: 27741
#             Gradient evaluations: 95
# 2008-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022682186899558804
#             Iterations: 110
#             Function evaluations: 32120
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.833600960178783
#             Iterations: 28
#             Function evaluations: 8197
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3891180669550942e-10
#             Iterations: 103
#             Function evaluations: 30076
#             Gradient evaluations: 103
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022759051948600625
#             Iterations: 120
#             Function evaluations: 35160
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8382220777257294
#             Iterations: 27
#             Function evaluations: 7931
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0108461465443225e-10
#             Iterations: 110
#             Function evaluations: 32231
#             Gradient evaluations: 110
# 2008-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022412743683273808
#             Iterations: 106
#             Function evaluations: 31058
#             Gradient evaluations: 106
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8341259710400808
#             Iterations: 29
#             Function evaluations: 8516
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1828531031731546e-10
#             Iterations: 110
#             Function evaluations: 32230
#             Gradient evaluations: 110
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022545564587342235
#             Iterations: 95
#             Function evaluations: 28025
#             Gradient evaluations: 95
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.834950715498787
#             Iterations: 24
#             Function evaluations: 7100
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.108716646019016e-10
#             Iterations: 110
#             Function evaluations: 32450
#             Gradient evaluations: 110
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021805138601100731
#             Iterations: 104
#             Function evaluations: 30889
#             Gradient evaluations: 104
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.837479755165867
#             Iterations: 27
#             Function evaluations: 8035
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3112231541240667e-10
#             Iterations: 110
#             Function evaluations: 32670
#             Gradient evaluations: 110
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00020837203597747733
#             Iterations: 102
#             Function evaluations: 30498
#             Gradient evaluations: 102
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8462184515202908
#             Iterations: 26
#             Function evaluations: 7792
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.771529675406706e-10
#             Iterations: 103
#             Function evaluations: 30797
#             Gradient evaluations: 103
# 2008-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00012110771651956335
#             Iterations: 137
#             Function evaluations: 41511
#             Gradient evaluations: 137
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.016825191166704
#             Iterations: 39
#             Function evaluations: 10630
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.326828866293253e-10
#             Iterations: 130
#             Function evaluations: 39390
#             Gradient evaluations: 130
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.898120367891826e-05
#             Iterations: 186
#             Function evaluations: 56916
#             Gradient evaluations: 186
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -2.3079595422915644
#             Iterations: 42
#             Function evaluations: 11667
#             Gradient evaluations: 38
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.4824526282761064e-10
#             Iterations: 148
#             Function evaluations: 45288
#             Gradient evaluations: 148
# 2009-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.21511240260932e-05
#             Iterations: 146
#             Function evaluations: 44384
#             Gradient evaluations: 146
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4436863316500017
#             Iterations: 44
#             Function evaluations: 12205
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.601381674161685e-10
#             Iterations: 140
#             Function evaluations: 42561
#             Gradient evaluations: 140
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.901084980263468e-05
#             Iterations: 172
#             Function evaluations: 52804
#             Gradient evaluations: 172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.427135970711036
#             Iterations: 60
#             Function evaluations: 17260
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.070982203220988e-10
#             Iterations: 115
#             Function evaluations: 35306
#             Gradient evaluations: 115
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.902836578490208e-05
#             Iterations: 175
#             Function evaluations: 53725
#             Gradient evaluations: 175
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -2.486760970765997
#             Iterations: 39
#             Function evaluations: 10786
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.224913529862806e-10
#             Iterations: 118
#             Function evaluations: 36226
#             Gradient evaluations: 118
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.343062440149899e-05
#             Iterations: 236
#             Function evaluations: 73397
#             Gradient evaluations: 236
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6639537094141743
#             Iterations: 47
#             Function evaluations: 14662
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2025528600755291e-09
#             Iterations: 104
#             Function evaluations: 32344
#             Gradient evaluations: 104
# 2009-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.161699004248509e-05
#             Iterations: 250
#             Function evaluations: 77750
#             Gradient evaluations: 250
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6189158351090702
#             Iterations: 52
#             Function evaluations: 14972
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.471502454115865e-10
#             Iterations: 87
#             Function evaluations: 27057
#             Gradient evaluations: 87
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.606872635936402e-05
#             Iterations: 228
#             Function evaluations: 70908
#             Gradient evaluations: 228
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.418935210854871
#             Iterations: 54
#             Function evaluations: 15605
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0896213777467165e-09
#             Iterations: 68
#             Function evaluations: 21148
#             Gradient evaluations: 68
# 2009-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.670777225181692e-05
#             Iterations: 238
#             Function evaluations: 74494
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.35551475153263
#             Iterations: 35
#             Function evaluations: 10986
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.65405891768136e-10
#             Iterations: 67
#             Function evaluations: 20972
#             Gradient evaluations: 67
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6968829416809135e-05
#             Iterations: 222
#             Function evaluations: 69931
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.342686556532796
#             Iterations: 51
#             Function evaluations: 14868
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.095078213397084e-09
#             Iterations: 56
#             Function evaluations: 17640
#             Gradient evaluations: 56
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.844419088174146e-05
#             Iterations: 222
#             Function evaluations: 70152
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2531944750889914
#             Iterations: 33
#             Function evaluations: 10457
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.446205292114152e-10
#             Iterations: 57
#             Function evaluations: 18012
#             Gradient evaluations: 57
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.917974021894335e-05
#             Iterations: 220
#             Function evaluations: 69520
#             Gradient evaluations: 220
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.195655511719282
#             Iterations: 30
#             Function evaluations: 9508
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1618630887540427e-09
#             Iterations: 48
#             Function evaluations: 15169
#             Gradient evaluations: 48
# 2009-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.722448924906405e-05
#             Iterations: 230
#             Function evaluations: 72680
#             Gradient evaluations: 230
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1954937941214676
#             Iterations: 43
#             Function evaluations: 12366
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.763511139593954e-10
#             Iterations: 50
#             Function evaluations: 15801
#             Gradient evaluations: 50
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5673307771232926e-05
#             Iterations: 229
#             Function evaluations: 72593
#             Gradient evaluations: 229
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.183601304310304
#             Iterations: 32
#             Function evaluations: 10173
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.316995641430549e-10
#             Iterations: 50
#             Function evaluations: 15851
#             Gradient evaluations: 50
# 2010-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.486073474799194e-05
#             Iterations: 209
#             Function evaluations: 66463
#             Gradient evaluations: 209
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2232552196320188
#             Iterations: 39
#             Function evaluations: 11160
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.396069261032491e-10
#             Iterations: 48
#             Function evaluations: 15264
#             Gradient evaluations: 48
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.380654808126132e-05
#             Iterations: 183
#             Function evaluations: 58378
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2259668943448134
#             Iterations: 35
#             Function evaluations: 11197
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.552910895022277e-10
#             Iterations: 51
#             Function evaluations: 16269
#             Gradient evaluations: 51
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.263717698879505e-05
#             Iterations: 219
#             Function evaluations: 70081
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2748445871117693
#             Iterations: 34
#             Function evaluations: 10912
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.534600173238857e-09
#             Iterations: 41
#             Function evaluations: 13120
#             Gradient evaluations: 41
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.422188937100494e-05
#             Iterations: 187
#             Function evaluations: 60214
#             Gradient evaluations: 187
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.257811741701639
#             Iterations: 36
#             Function evaluations: 11624
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.653631455844135e-10
#             Iterations: 52
#             Function evaluations: 16744
#             Gradient evaluations: 52
# 2010-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.459683823870078e-05
#             Iterations: 216
#             Function evaluations: 69553
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2524970892898812
#             Iterations: 33
#             Function evaluations: 10658
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4067984258599862e-09
#             Iterations: 41
#             Function evaluations: 13202
#             Gradient evaluations: 41
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.719010609462341e-05
#             Iterations: 244
#             Function evaluations: 78568
#             Gradient evaluations: 244
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4831922099846517
#             Iterations: 42
#             Function evaluations: 13564
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4846273267511418e-09
#             Iterations: 37
#             Function evaluations: 11914
#             Gradient evaluations: 37
# 2010-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.353359693988628e-05
#             Iterations: 243
#             Function evaluations: 78489
#             Gradient evaluations: 243
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.596247237424957
#             Iterations: 48
#             Function evaluations: 14253
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.100730751303082e-09
#             Iterations: 31
#             Function evaluations: 10013
#             Gradient evaluations: 31
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1177706179202975e-05
#             Iterations: 266
#             Function evaluations: 85918
#             Gradient evaluations: 266
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5731055950866404
#             Iterations: 65
#             Function evaluations: 19776
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1827339467373656e-09
#             Iterations: 29
#             Function evaluations: 9368
#             Gradient evaluations: 29
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5855919012863404e-05
#             Iterations: 213
#             Function evaluations: 68799
#             Gradient evaluations: 213
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0897764810406687
#             Iterations: 35
#             Function evaluations: 11335
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.156088721598232e-10
#             Iterations: 51
#             Function evaluations: 16473
#             Gradient evaluations: 51
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.945293311494261e-05
#             Iterations: 190
#             Function evaluations: 61370
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0112627820923783
#             Iterations: 29
#             Function evaluations: 9393
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.654213711735158e-10
#             Iterations: 50
#             Function evaluations: 16151
#             Gradient evaluations: 50
# 2010-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.274543496606597e-05
#             Iterations: 206
#             Function evaluations: 66538
#             Gradient evaluations: 206
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9498187287314996
#             Iterations: 30
#             Function evaluations: 9716
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.389672941998454e-09
#             Iterations: 49
#             Function evaluations: 15828
#             Gradient evaluations: 49
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.8457770639930315e-05
#             Iterations: 199
#             Function evaluations: 64079
#             Gradient evaluations: 199
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8725828217002394
#             Iterations: 28
#             Function evaluations: 9042
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.106455339776744e-10
#             Iterations: 55
#             Function evaluations: 17711
#             Gradient evaluations: 55
# 2011-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.118496853935205e-05
#             Iterations: 199
#             Function evaluations: 64476
#             Gradient evaluations: 199
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9990807449882217
#             Iterations: 27
#             Function evaluations: 8442
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.180145552752318e-10
#             Iterations: 55
#             Function evaluations: 17821
#             Gradient evaluations: 55
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.111610063939757e-05
#             Iterations: 188
#             Function evaluations: 60912
#             Gradient evaluations: 188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0053262489611363
#             Iterations: 25
#             Function evaluations: 8115
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.573897562650746e-10
#             Iterations: 56
#             Function evaluations: 18144
#             Gradient evaluations: 56
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.992773102249184e-05
#             Iterations: 183
#             Function evaluations: 59293
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9995316483952912
#             Iterations: 35
#             Function evaluations: 10066
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.50653793320934e-10
#             Iterations: 56
#             Function evaluations: 18144
#             Gradient evaluations: 56
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.827908573689174e-05
#             Iterations: 196
#             Function evaluations: 63504
#             Gradient evaluations: 196
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9866453549369887
#             Iterations: 30
#             Function evaluations: 8442
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.285236199559565e-10
#             Iterations: 66
#             Function evaluations: 21384
#             Gradient evaluations: 66
# 2011-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.9295252883887585e-05
#             Iterations: 185
#             Function evaluations: 60496
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9695279859542527
#             Iterations: 27
#             Function evaluations: 8847
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
# ...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.375203312614296
#             Iterations: 51
#             Function evaluations: 21428
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.045396827871205e-09
#             Iterations: 57
#             Function evaluations: 25935
#             Gradient evaluations: 57
# 2022-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.469650928096985e-05
#             Iterations: 288
#             Function evaluations: 132480
#             Gradient evaluations: 288
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4665871874212715
#             Iterations: 54
#             Function evaluations: 23045
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5376073663499606e-09
#             Iterations: 48
#             Function evaluations: 22080
#             Gradient evaluations: 48
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.431541546993007e-05
#             Iterations: 247
#             Function evaluations: 113620
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5010140822101508
#             Iterations: 69
#             Function evaluations: 29987
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3197954617381749e-09
#             Iterations: 48
#             Function evaluations: 22081
#             Gradient evaluations: 48
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.331026049584358e-05
#             Iterations: 257
#             Function evaluations: 117963
#             Gradient evaluations: 257
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.565059554281029
#             Iterations: 57
#             Function evaluations: 24378
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1902923412066283e-09
#             Iterations: 49
#             Function evaluations: 22491
#             Gradient evaluations: 49
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6002927942949496e-05
#             Iterations: 243
#             Function evaluations: 111780
#             Gradient evaluations: 243
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -2.745209627779126
#             Iterations: 71
#             Function evaluations: 30896
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2260815219964173e-09
#             Iterations: 38
#             Function evaluations: 17480
#             Gradient evaluations: 38
# 2022-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8630968858324916e-05
#             Iterations: 270
#             Function evaluations: 123390
#             Gradient evaluations: 270
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9696745629239887
#             Iterations: 71
#             Function evaluations: 30687
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5161138361228742e-09
#             Iterations: 38
#             Function evaluations: 17367
#             Gradient evaluations: 38
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6289281518743266e-05
#             Iterations: 307
#             Function evaluations: 140913
#             Gradient evaluations: 307
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1008369745854174
#             Iterations: 64
#             Function evaluations: 27597
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9941818830023595e-09
#             Iterations: 38
#             Function evaluations: 17442
#             Gradient evaluations: 38
# 2023-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.515709527466449e-05
#             Iterations: 262
#             Function evaluations: 120520
#             Gradient evaluations: 262
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.178622873459946
#             Iterations: 71
#             Function evaluations: 30883
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.38809952919784e-09
#             Iterations: 35
#             Function evaluations: 16100
#             Gradient evaluations: 35
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1911861870489047e-05
#             Iterations: 326
#             Function evaluations: 150287
#             Gradient evaluations: 326
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.36236979258372
#             Iterations: 67
#             Function evaluations: 29104
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.117324167290065e-09
#             Iterations: 44
#             Function evaluations: 20284
#             Gradient evaluations: 44
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0867412983171988e-05
#             Iterations: 274
#             Function evaluations: 126315
#             Gradient evaluations: 274
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.410704314315158
#             Iterations: 83
#             Function evaluations: 36506
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.982401576935507e-09
#             Iterations: 44
#             Function evaluations: 20285
#             Gradient evaluations: 44
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7041637397719842e-05
#             Iterations: 258
#             Function evaluations: 119196
#             Gradient evaluations: 258
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7227424187879814
#             Iterations: 72
#             Function evaluations: 31486
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2748365559258364e-09
#             Iterations: 32
#             Function evaluations: 14784
#             Gradient evaluations: 32
# 2023-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7128013930209253e-05
#             Iterations: 285
#             Function evaluations: 131100
#             Gradient evaluations: 285
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.799092148982856
#             Iterations: 86
#             Function evaluations: 37800
#             Gradient evaluations: 82
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3241846681481307e-09
#             Iterations: 26
#             Function evaluations: 11961
#             Gradient evaluations: 26
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.694466767878057e-05
#             Iterations: 333
#             Function evaluations: 153846
#             Gradient evaluations: 333
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8161391473344555
#             Iterations: 91
#             Function evaluations: 40278
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9297177447261065e-09
#             Iterations: 38
#             Function evaluations: 17556
#             Gradient evaluations: 38
# 2023-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5638189027024226e-05
#             Iterations: 343
#             Function evaluations: 158467
#             Gradient evaluations: 343
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.9773525314519835
#             Iterations: 92
#             Function evaluations: 40745
#             Gradient evaluations: 88
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2253031925298567e-09
#             Iterations: 33
#             Function evaluations: 15247
#             Gradient evaluations: 33
# 2023-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5767440272129856e-05
#             Iterations: 303
#             Function evaluations: 139987
#             Gradient evaluations: 303
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.052768067894537
#             Iterations: 109
#             Function evaluations: 48642
#             Gradient evaluations: 105
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.058596513884953e-09
#             Iterations: 35
#             Function evaluations: 16170
#             Gradient evaluations: 35
# 2023-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.54419531492404e-05
#             Iterations: 278
#             Function evaluations: 128992
#             Gradient evaluations: 278
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.144359064483878
#             Iterations: 95
#             Function evaluations: 42322
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3870891804065046e-09
#             Iterations: 36
#             Function evaluations: 16704
#             Gradient evaluations: 36
# 2023-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5668792351431408e-05
#             Iterations: 307
#             Function evaluations: 142142
#             Gradient evaluations: 307
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.18046271229241
#             Iterations: 91
#             Function evaluations: 40368
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3117754170771405e-09
#             Iterations: 33
#             Function evaluations: 15280
#             Gradient evaluations: 33
# 2023-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4011168818514066e-05
#             Iterations: 292
#             Function evaluations: 136365
#             Gradient evaluations: 292
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.402787164890951
#             Iterations: 102
#             Function evaluations: 45882
#             Gradient evaluations: 98
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7919179934072946e-09
#             Iterations: 33
#             Function evaluations: 15411
#             Gradient evaluations: 33
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3830694044519194e-05
#             Iterations: 306
#             Function evaluations: 142902
#             Gradient evaluations: 306
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.4353991787064535
#             Iterations: 100
#             Function evaluations: 44944
#             Gradient evaluations: 96
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6403127585131448e-09
#             Iterations: 20
#             Function evaluations: 9340
#             Gradient evaluations: 20
# 2024-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3842053995495165e-05
#             Iterations: 284
#             Function evaluations: 132344
#             Gradient evaluations: 284
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.43520844825738
#             Iterations: 109
#             Function evaluations: 49062
#             Gradient evaluations: 105
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1820226567294947e-09
#             Iterations: 28
#             Function evaluations: 13049
#             Gradient evaluations: 28
# 2024-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4297180957088156e-05
#             Iterations: 262
#             Function evaluations: 122092
#             Gradient evaluations: 262
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.447685774402717
#             Iterations: 110
#             Function evaluations: 49535
#             Gradient evaluations: 106
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8946901252956795e-09
#             Iterations: 16
#             Function evaluations: 7456
#             Gradient evaluations: 16
# 2024-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.428331056071716e-05
#             Iterations: 267
#             Function evaluations: 124689
#             Gradient evaluations: 267
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.5833688030994955
#             Iterations: 114
#             Function evaluations: 51513
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7579113537867115e-09
#             Iterations: 28
#             Function evaluations: 13076
#             Gradient evaluations: 28
# 2024-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5608916413832593e-05
#             Iterations: 299
#             Function evaluations: 140830
#             Gradient evaluations: 299
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.50662884245916
#             Iterations: 97
#             Function evaluations: 43906
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.566087983734943e-09
#             Iterations: 18
#             Function evaluations: 8478
#             Gradient evaluations: 18
# 2024-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7654611433825032e-05
#             Iterations: 249
#             Function evaluations: 117778
#             Gradient evaluations: 249
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.6185760716312565
#             Iterations: 86
#             Function evaluations: 38884
#             Gradient evaluations: 82
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1784001753036397e-09
#             Iterations: 48
#             Function evaluations: 22704
#             Gradient evaluations: 48
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_shrinked.to_csv("returnssp500shrinked_neu_f.csv")

# %% [markdown]
# ### Auswertung JSE mit Ledoit Wolf

# %%
returns = df_JSE.pct_change()
returns = returns.where(~df_JSE.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of               4SI.JO    ABG.JO    ACL.JO    ACT.JO    ADH.JO    AEL.JO  \
# Date
# 2005-06-02       NaN  0.001214 -0.006225  0.000000 -0.014598       NaN
# 2005-06-03       NaN  0.001333  0.000000  0.000000  0.000000       NaN
# 2005-06-06       NaN  0.003510  0.014953  0.000000  0.007407       NaN
# 2005-06-07       NaN  0.006634 -0.035437  0.146154 -0.007353       NaN
# 2005-06-08       NaN -0.005392 -0.029721  0.000000  0.007407       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26  0.000000  0.007235 -0.018018  0.000000  0.005975  0.000426
# 2025-05-27  0.000000  0.000178 -0.036697  0.000000  0.003439  0.000000
# 2025-05-28  0.042857  0.026828 -0.038095  0.087500  0.022741  0.002128
# 2025-05-29 -0.041096  0.016127  0.049505 -0.045977 -0.010966  0.002972
# 2025-05-30  0.000000 -0.014051  0.094340 -0.036145 -0.009855 -0.001693
#
#               AFE.JO    AFH.JO    AFT.JO    AGL.JO  ...    VKE.JO    VOD.JO  \
# Date                                                ...
# 2005-06-02  0.020642       NaN       NaN  0.005481  ...       NaN  0.017117
# 2005-06-03  0.000000       NaN       NaN  0.000000  ...       NaN  0.000000
# 2005-06-06  0.000000       NaN       NaN -0.019079  ...       NaN  0.045350
# 2005-06-07  0.000225       NaN       NaN -0.020994  ...       NaN -0.000169
# 2005-06-08  0.011009       NaN       NaN  0.014191  ...       NaN -0.025424
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-26  0.007992  0.032548 -0.002564  0.029137  ... -0.010417 -0.016292
# 2025-05-27  0.007252 -0.026087  0.026498 -0.018270  ...  0.006316  0.002971
# 2025-05-28  0.002592  0.017857  0.000000 -0.008829  ...  0.001046 -0.006294
# 2025-05-29 -0.011298 -0.013158 -0.008476 -0.005631  ...  0.014107  0.031967
# 2025-05-30  0.000872 -0.011111  0.010297  0.016932  ...  0.030912 -0.005199
#
#               WBC.JO    WBO.JO    WEZ.JO    WHL.JO    YRK.JO  YYLBEE.JO  \
# Date
# 2005-06-02       NaN  0.009434       NaN  0.009901  0.000000        NaN
# 2005-06-03       NaN  0.000000       NaN  0.000000  0.000000        NaN
# 2005-06-06       NaN  0.009346       NaN  0.026471  0.000000        NaN
# 2005-06-07       NaN  0.000000       NaN  0.012416  0.000000        NaN
# 2005-06-08       NaN  0.018519       NaN -0.027358  0.000000        NaN
# ...              ...       ...       ...       ...       ...        ...
# 2025-05-26  0.021277 -0.005745  0.111111 -0.000174  0.046154        0.0
# 2025-05-27  0.015625  0.007979 -0.100000 -0.008726  0.000000        0.0
# 2025-05-28 -0.010872 -0.018234 -0.022222  0.014965 -0.083333        0.0
# 2025-05-29  0.013895 -0.005505  0.022727  0.016132  0.016043        0.0
# 2025-05-30  0.002250  0.014985 -0.044444  0.000341  0.026316        0.0
#
#               ZED.JO    ZZD.JO
# Date
# 2005-06-02       NaN       NaN
# 2005-06-03       NaN       NaN
# 2005-06-06       NaN       NaN
# 2005-06-07       NaN       NaN
# 2005-06-08       NaN       NaN
# ...              ...       ...
# 2025-05-26 -0.008264 -0.000864
# 2025-05-27 -0.016667  0.037165
# 2025-05-28  0.059322  0.008333
# 2025-05-29  0.008000 -0.008264
# 2025-05-30  0.023810 -0.012500
#
# [5170 rows x 217 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 1
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = ledoit_shrink(training_daten)
    
    #aus der geschrumpften Matrix die Korrelationsmatrix bauen
    standardabweichung = np.sqrt(np.diag(cov_matrix))
    corr_matrix = cov_matrix / np.outer(standardabweichung, standardabweichung)
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    shrinked_JSE_gewichte_equally_weighted = equally_weighted(training_daten)
    shrinked_JSE_gewichte_min_variance= min_variance_opt(cov_matrix)
    shrinked_JSE_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    shrinked_JSE_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    shrinked_JSE_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    shrinked_JSE_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    shrinked_JSE_gewichte_herc = herc_ledoit(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": shrinked_JSE_gewichte_equally_weighted,
    "Minimum-Variance": shrinked_JSE_gewichte_min_variance,
    "Maximum-Diversification": shrinked_JSE_gewichte_max_diversification,
    "Inverse-Volatility": shrinked_JSE_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": shrinked_JSE_gewichte_risk_parity,
    "HRP": shrinked_JSE_gewichte_hrp,
    "HERC": shrinked_JSE_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
    #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_shrinked_JSE = pd.concat(portfolio_returns_list)
portfolio_returns_df_shrinked_JSE = portfolio_returns_df_shrinked_JSE.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.240047133151458e-05
#             Iterations: 135
#             Function evaluations: 9045
#             Gradient evaluations: 135
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.741709713501023
#             Iterations: 43
#             Function evaluations: 2923
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.635081070068458e-09
#             Iterations: 44
#             Function evaluations: 2949
#             Gradient evaluations: 44
# 2005-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.1064523258628265e-05
#             Iterations: 127
#             Function evaluations: 8509
#             Gradient evaluations: 127
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3106326289776384
#             Iterations: 32
#             Function evaluations: 2176
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.892659634993165e-09
#             Iterations: 43
#             Function evaluations: 2881
#             Gradient evaluations: 43
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.119348145512657e-05
#             Iterations: 124
#             Function evaluations: 8432
#             Gradient evaluations: 124
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.314781158044826
#             Iterations: 25
#             Function evaluations: 1724
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.559576421899547e-10
#             Iterations: 54
#             Function evaluations: 3672
#             Gradient evaluations: 54
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.140650188809402e-05
#             Iterations: 128
#             Function evaluations: 8449
#             Gradient evaluations: 128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.298075148819085
#             Iterations: 25
#             Function evaluations: 1675
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2267500347011322e-09
#             Iterations: 54
#             Function evaluations: 3564
#             Gradient evaluations: 54
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.05864626641222e-05
#             Iterations: 132
#             Function evaluations: 8844
#             Gradient evaluations: 132
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2844340964754846
#             Iterations: 29
#             Function evaluations: 1971
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2656854167573228e-09
#             Iterations: 53
#             Function evaluations: 3552
#             Gradient evaluations: 53
# 2005-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7770585133842216e-05
#             Iterations: 126
#             Function evaluations: 8442
#             Gradient evaluations: 126
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.345001339066522
#             Iterations: 34
#             Function evaluations: 2310
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3427772426620143e-09
#             Iterations: 54
#             Function evaluations: 3618
#             Gradient evaluations: 54
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.759283023010051e-05
#             Iterations: 111
#             Function evaluations: 7437
#             Gradient evaluations: 111
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3843643115261814
#             Iterations: 35
#             Function evaluations: 2379
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.437453723671651e-09
#             Iterations: 54
#             Function evaluations: 3618
#             Gradient evaluations: 54
# 2006-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.587281678928444e-05
#             Iterations: 121
#             Function evaluations: 8228
#             Gradient evaluations: 121
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.624284318288669
#             Iterations: 35
#             Function evaluations: 2416
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3814035104210994e-09
#             Iterations: 54
#             Function evaluations: 3672
#             Gradient evaluations: 54
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.514797702806699e-05
#             Iterations: 132
#             Function evaluations: 8845
#             Gradient evaluations: 132
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6223504766139833
#             Iterations: 34
#             Function evaluations: 2313
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8229171402530943e-09
#             Iterations: 54
#             Function evaluations: 3619
#             Gradient evaluations: 54
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.477274564945196e-05
#             Iterations: 121
#             Function evaluations: 8107
#             Gradient evaluations: 121
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.657441344982965
#             Iterations: 37
#             Function evaluations: 2517
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3843497511213926e-10
#             Iterations: 66
#             Function evaluations: 4422
#             Gradient evaluations: 66
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.822110694824415e-05
#             Iterations: 120
#             Function evaluations: 8161
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6766085835344002
#             Iterations: 41
#             Function evaluations: 2827
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2396298005764247e-10
#             Iterations: 54
#             Function evaluations: 3672
#             Gradient evaluations: 54
# 2006-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.539614552843522e-05
#             Iterations: 131
#             Function evaluations: 9433
#             Gradient evaluations: 131
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.76610591973289
#             Iterations: 38
#             Function evaluations: 2775
#             Gradient evaluations: 38
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1956062893839316e-09
#             Iterations: 43
#             Function evaluations: 3096
#             Gradient evaluations: 43
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.0941687700587895e-05
#             Iterations: 134
#             Function evaluations: 9783
#             Gradient evaluations: 134
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.860032031297268
#             Iterations: 42
#             Function evaluations: 3109
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1432680447431062e-09
#             Iterations: 43
#             Function evaluations: 3140
#             Gradient evaluations: 43
# 2006-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1022622534486556e-05
#             Iterations: 114
#             Function evaluations: 8436
#             Gradient evaluations: 114
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.765161464093286
#             Iterations: 57
#             Function evaluations: 4285
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.933777645566643e-09
#             Iterations: 42
#             Function evaluations: 3108
#             Gradient evaluations: 42
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.067735707327206e-05
#             Iterations: 132
#             Function evaluations: 10033
#             Gradient evaluations: 132
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8660010989558278
#             Iterations: 64
#             Function evaluations: 4940
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3891540036015953e-09
#             Iterations: 29
#             Function evaluations: 2204
#             Gradient evaluations: 29
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3792189085924488e-05
#             Iterations: 126
#             Function evaluations: 9954
#             Gradient evaluations: 126
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.476428286234817
#             Iterations: 59
#             Function evaluations: 4725
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.717964459954263e-09
#             Iterations: 32
#             Function evaluations: 2528
#             Gradient evaluations: 32
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8585454213256543e-05
#             Iterations: 108
#             Function evaluations: 8424
#             Gradient evaluations: 108
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.3962568320486954
#             Iterations: 54
#             Function evaluations: 4267
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.55269487799337e-09
#             Iterations: 32
#             Function evaluations: 2496
#             Gradient evaluations: 32
# 2006-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9426880460272126e-05
#             Iterations: 121
#             Function evaluations: 9317
#             Gradient evaluations: 121
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.2974672788858395
#             Iterations: 55
#             Function evaluations: 4289
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5779594120492532e-09
#             Iterations: 31
#             Function evaluations: 2388
#             Gradient evaluations: 31
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.087957926694156e-05
#             Iterations: 110
#             Function evaluations: 8690
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1602935625747772
#             Iterations: 52
#             Function evaluations: 4163
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7372832252766733e-09
#             Iterations: 32
#             Function evaluations: 2529
#             Gradient evaluations: 32
# 2007-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.193635999914887e-05
#             Iterations: 127
#             Function evaluations: 10287
#             Gradient evaluations: 127
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.2120344271034935
#             Iterations: 56
#             Function evaluations: 4592
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1000924835680036e-09
#             Iterations: 33
#             Function evaluations: 2673
#             Gradient evaluations: 33
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3430420979139145e-05
#             Iterations: 129
#             Function evaluations: 10320
#             Gradient evaluations: 129
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9140728394129645
#             Iterations: 48
#             Function evaluations: 3890
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3813702495797592e-09
#             Iterations: 32
#             Function evaluations: 2560
#             Gradient evaluations: 32
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.72847097516905e-05
#             Iterations: 131
#             Function evaluations: 10349
#             Gradient evaluations: 131
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9847225437806864
#             Iterations: 47
#             Function evaluations: 3762
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.420404610443119e-09
#             Iterations: 32
#             Function evaluations: 2528
#             Gradient evaluations: 32
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.372556773349719e-05
#             Iterations: 143
#             Function evaluations: 11441
#             Gradient evaluations: 143
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.070435281306973
#             Iterations: 55
#             Function evaluations: 4455
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.984661534997014e-09
#             Iterations: 44
#             Function evaluations: 3520
#             Gradient evaluations: 44
# 2007-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3873370114161004e-05
#             Iterations: 142
#             Function evaluations: 11360
#             Gradient evaluations: 142
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1135165968184544
#             Iterations: 50
#             Function evaluations: 4050
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.022754635162811e-09
#             Iterations: 44
#             Function evaluations: 3520
#             Gradient evaluations: 44
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.643368781322188e-05
#             Iterations: 137
#             Function evaluations: 10549
#             Gradient evaluations: 137
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.048045456084472
#             Iterations: 44
#             Function evaluations: 3436
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.311800058952099e-09
#             Iterations: 32
#             Function evaluations: 2465
#             Gradient evaluations: 32
# 2007-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.700906009196339e-05
#             Iterations: 143
#             Function evaluations: 11154
#             Gradient evaluations: 143
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9470234714474755
#             Iterations: 49
#             Function evaluations: 3869
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0014079952513354e-09
#             Iterations: 43
#             Function evaluations: 3355
#             Gradient evaluations: 43
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.0519928358813376e-05
#             Iterations: 115
#             Function evaluations: 9200
#             Gradient evaluations: 115
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.24488714898468
#             Iterations: 57
#             Function evaluations: 4619
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.053327078609027e-09
#             Iterations: 45
#             Function evaluations: 3600
#             Gradient evaluations: 45
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7374717646565137e-05
#             Iterations: 129
#             Function evaluations: 10191
#             Gradient evaluations: 129
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5415046180404945
#             Iterations: 56
#             Function evaluations: 4482
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4927633065416513e-09
#             Iterations: 42
#             Function evaluations: 3319
#             Gradient evaluations: 42
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.6127229698629434e-05
#             Iterations: 123
#             Function evaluations: 9471
#             Gradient evaluations: 123
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4087038947848844
#             Iterations: 51
#             Function evaluations: 3978
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6405354506208342e-09
#             Iterations: 41
#             Function evaluations: 3158
#             Gradient evaluations: 41
# 2007-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.899037991043779e-05
#             Iterations: 125
#             Function evaluations: 9751
#             Gradient evaluations: 125
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1162924280015614
#             Iterations: 41
#             Function evaluations: 3238
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.836801035290678e-10
#             Iterations: 63
#             Function evaluations: 4914
#             Gradient evaluations: 63
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.968856024233593e-05
#             Iterations: 131
#             Function evaluations: 10349
#             Gradient evaluations: 131
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0266834390907653
#             Iterations: 45
#             Function evaluations: 3598
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.25467040869184e-10
#             Iterations: 72
#             Function evaluations: 5689
#             Gradient evaluations: 72
# 2008-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.548912844624972e-05
#             Iterations: 120
#             Function evaluations: 9360
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.927179468509231
#             Iterations: 43
#             Function evaluations: 3395
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.959755309421537e-10
#             Iterations: 82
#             Function evaluations: 6396
#             Gradient evaluations: 82
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.585597463276997e-05
#             Iterations: 135
#             Function evaluations: 10395
#             Gradient evaluations: 135
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0367579363617563
#             Iterations: 44
#             Function evaluations: 3429
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.249635536283206e-10
#             Iterations: 93
#             Function evaluations: 7161
#             Gradient evaluations: 93
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.18240230419097e-05
#             Iterations: 139
#             Function evaluations: 10703
#             Gradient evaluations: 139
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.106911290040022
#             Iterations: 41
#             Function evaluations: 3191
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.646488257211404e-10
#             Iterations: 93
#             Function evaluations: 7162
#             Gradient evaluations: 93
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.276083901735524e-05
#             Iterations: 138
#             Function evaluations: 10626
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1660824258907465
#             Iterations: 41
#             Function evaluations: 3192
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.903653566333232e-10
#             Iterations: 114
#             Function evaluations: 8779
#             Gradient evaluations: 114
# 2008-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.556822877367019e-05
#             Iterations: 133
#             Function evaluations: 10108
#             Gradient evaluations: 133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.160559229571988
#             Iterations: 42
#             Function evaluations: 3232
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.234478418082601e-10
#             Iterations: 113
#             Function evaluations: 8588
#             Gradient evaluations: 113
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.926593454572408e-05
#             Iterations: 138
#             Function evaluations: 10488
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1478877285111393
#             Iterations: 43
#             Function evaluations: 3308
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.42068619686613e-10
#             Iterations: 102
#             Function evaluations: 7753
#             Gradient evaluations: 102
# 2008-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.893064538128503e-05
#             Iterations: 138
#             Function evaluations: 10489
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.156467487131176
#             Iterations: 42
#             Function evaluations: 3232
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.597926470366044e-10
#             Iterations: 90
#             Function evaluations: 6840
#             Gradient evaluations: 90
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.112903238626374e-05
#             Iterations: 141
#             Function evaluations: 10716
#             Gradient evaluations: 141
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.190574165780754
#             Iterations: 43
#             Function evaluations: 3306
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.410817538852791e-10
#             Iterations: 111
#             Function evaluations: 8436
#             Gradient evaluations: 111
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.92960378759943e-05
#             Iterations: 133
#             Function evaluations: 10108
#             Gradient evaluations: 133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0724485311548997
#             Iterations: 41
#             Function evaluations: 3154
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.224914217875113e-10
#             Iterations: 100
#             Function evaluations: 7600
#             Gradient evaluations: 100
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.402900987719253e-05
#             Iterations: 127
#             Function evaluations: 9525
#             Gradient evaluations: 127
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.052632816188929
#             Iterations: 47
#             Function evaluations: 3568
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.128577685633689e-10
#             Iterations: 90
#             Function evaluations: 6751
#             Gradient evaluations: 90
# 2008-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.506188325384282e-05
#             Iterations: 118
#             Function evaluations: 8732
#             Gradient evaluations: 118
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.418547999266041
#             Iterations: 54
#             Function evaluations: 4047
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.037559502440664e-09
#             Iterations: 126
#             Function evaluations: 9324
#             Gradient evaluations: 126
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.647199920292808e-05
#             Iterations: 115
#             Function evaluations: 8740
#             Gradient evaluations: 115
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.654621985421839
#             Iterations: 75
#             Function evaluations: 5573
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9939544023606628e-09
#             Iterations: 97
#             Function evaluations: 7372
#             Gradient evaluations: 97
# 2009-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.361359956056519e-05
#             Iterations: 150
#             Function evaluations: 11851
#             Gradient evaluations: 150
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7315897311319777
#             Iterations: 58
#             Function evaluations: 4637
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.302191626798361e-09
#             Iterations: 75
#             Function evaluations: 5926
#             Gradient evaluations: 75
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6130928458069008e-05
#             Iterations: 146
#             Function evaluations: 12411
#             Gradient evaluations: 146
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.892323797470813
#             Iterations: 65
#             Function evaluations: 5588
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.49205618219176e-09
#             Iterations: 75
#             Function evaluations: 6376
#             Gradient evaluations: 75
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.267154347622474e-05
#             Iterations: 147
#             Function evaluations: 12496
#             Gradient evaluations: 147
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.983834041477756
#             Iterations: 66
#             Function evaluations: 5678
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.879356792868467e-09
#             Iterations: 74
#             Function evaluations: 6290
#             Gradient evaluations: 74
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.849520311395176e-05
#             Iterations: 167
#             Function evaluations: 14029
#             Gradient evaluations: 167
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.0707403242120295
#             Iterations: 64
#             Function evaluations: 5366
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.3947777859369866e-09
#             Iterations: 64
#             Function evaluations: 5376
#             Gradient evaluations: 64
# 2009-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6903039631172774e-05
#             Iterations: 162
#             Function evaluations: 13608
#             Gradient evaluations: 162
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.060316166307579
#             Iterations: 62
#             Function evaluations: 5276
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.835476249617599e-09
#             Iterations: 65
#             Function evaluations: 5460
#             Gradient evaluations: 65
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8153770030270403e-05
#             Iterations: 170
#             Function evaluations: 14621
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7886938509749917
#             Iterations: 54
#             Function evaluations: 4697
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.270719421979131e-09
#             Iterations: 65
#             Function evaluations: 5590
#             Gradient evaluations: 65
# 2009-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.790412195109052e-05
#             Iterations: 181
#             Function evaluations: 15385
#             Gradient evaluations: 181
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.606103782804759
#             Iterations: 52
#             Function evaluations: 4468
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.690096735506445e-09
#             Iterations: 56
#             Function evaluations: 4760
#             Gradient evaluations: 56
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.722853830987692e-05
#             Iterations: 167
#             Function evaluations: 14029
#             Gradient evaluations: 167
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6411501206122887
#             Iterations: 52
#             Function evaluations: 4417
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.403606949005002e-09
#             Iterations: 56
#             Function evaluations: 4704
#             Gradient evaluations: 56
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6819380345921573e-05
#             Iterations: 157
#             Function evaluations: 13345
#             Gradient evaluations: 157
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6642304044306746
#             Iterations: 52
#             Function evaluations: 4470
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.652015033217826e-09
#             Iterations: 57
#             Function evaluations: 4845
#             Gradient evaluations: 57
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3392120073935244e-05
#             Iterations: 189
#             Function evaluations: 16254
#             Gradient evaluations: 189
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.862848250687799
#             Iterations: 54
#             Function evaluations: 4701
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.910557085249628e-09
#             Iterations: 57
#             Function evaluations: 4902
#             Gradient evaluations: 57
# 2009-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3778469794619774e-05
#             Iterations: 186
#             Function evaluations: 15996
#             Gradient evaluations: 186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8587032074098766
#             Iterations: 51
#             Function evaluations: 4436
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.367520886339624e-09
#             Iterations: 57
#             Function evaluations: 4902
#             Gradient evaluations: 57
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3425255540648984e-05
#             Iterations: 194
#             Function evaluations: 16685
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.790561769183912
#             Iterations: 53
#             Function evaluations: 4609
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.861520924817331e-09
#             Iterations: 45
#             Function evaluations: 3871
#             Gradient evaluations: 45
# 2010-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2912284557012808e-05
#             Iterations: 194
#             Function evaluations: 16878
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.036455883088198
#             Iterations: 55
#             Function evaluations: 4841
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.729810570285238e-09
#             Iterations: 45
#             Function evaluations: 3915
#             Gradient evaluations: 45
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2944974134459726e-05
#             Iterations: 172
#             Function evaluations: 15480
#             Gradient evaluations: 172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.082035975898343
#             Iterations: 67
#             Function evaluations: 5762
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.173179196715741e-09
#             Iterations: 45
#             Function evaluations: 4051
#             Gradient evaluations: 45
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.320457799439238e-05
#             Iterations: 198
#             Function evaluations: 17623
#             Gradient evaluations: 198
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.1555827594152435
#             Iterations: 60
#             Function evaluations: 5403
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.560884187719331e-09
#             Iterations: 45
#             Function evaluations: 4006
#             Gradient evaluations: 45
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4239249573881232e-05
#             Iterations: 160
#             Function evaluations: 14240
#             Gradient evaluations: 160
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.1465208045585
#             Iterations: 74
#             Function evaluations: 6350
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.8728575196753405e-09
#             Iterations: 45
#             Function evaluations: 4005
#             Gradient evaluations: 45
# 2010-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3926786242142263e-05
#             Iterations: 156
#             Function evaluations: 13884
#             Gradient evaluations: 156
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.210837328989972
#             Iterations: 91
#             Function evaluations: 7987
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.339299806343943e-09
#             Iterations: 45
#             Function evaluations: 4005
#             Gradient evaluations: 45
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1731184282451759e-05
#             Iterations: 140
#             Function evaluations: 12180
#             Gradient evaluations: 140
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.504080772613403
#             Iterations: 70
#             Function evaluations: 6177
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.471360350979723e-09
#             Iterations: 19
#             Function evaluations: 1654
#             Gradient evaluations: 19
# 2010-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1412068592645046e-05
#             Iterations: 156
#             Function evaluations: 13572
#             Gradient evaluations: 156
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.387255688111026
#             Iterations: 70
#             Function evaluations: 6180
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.142602849994875e-09
#             Iterations: 21
#             Function evaluations: 1827
#             Gradient evaluations: 21
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0327100564870833e-05
#             Iterations: 148
#             Function evaluations: 13468
#             Gradient evaluations: 148
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.649559724429751
#             Iterations: 71
#             Function evaluations: 6556
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.193728678611777e-09
#             Iterations: 20
#             Function evaluations: 1820
#             Gradient evaluations: 20
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2247991509230852e-05
#             Iterations: 169
#             Function evaluations: 15379
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.303989571545447
#             Iterations: 71
#             Function evaluations: 6546
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.944582451963373e-09
#             Iterations: 22
#             Function evaluations: 2002
#             Gradient evaluations: 22
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3103891340986744e-05
#             Iterations: 164
#             Function evaluations: 15252
#             Gradient evaluations: 164
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.332680546385198
#             Iterations: 69
#             Function evaluations: 6495
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2254109177769284e-09
#             Iterations: 34
#             Function evaluations: 3162
#             Gradient evaluations: 34
# 2010-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3929487405996617e-05
#             Iterations: 156
#             Function evaluations: 14352
#             Gradient evaluations: 156
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.982555940024518
#             Iterations: 67
#             Function evaluations: 6231
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9442034587081934e-09
#             Iterations: 46
#             Function evaluations: 4232
#             Gradient evaluations: 46
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4050772268941719e-05
#             Iterations: 173
#             Function evaluations: 15916
#             Gradient evaluations: 173
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.978781073713074
#             Iterations: 54
#             Function evaluations: 5029
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0552948409255226e-09
#             Iterations: 46
#             Function evaluations: 4232
#             Gradient evaluations: 46
# 2011-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.48738212724062e-05
#             Iterations: 158
#             Function evaluations: 14220
#             Gradient evaluations: 158
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.663004119408136
#             Iterations: 57
#             Function evaluations: 5189
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.280865299124326e-09
#             Iterations: 46
#             Function evaluations: 4140
#             Gradient evaluations: 46
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4522323917842545e-05
#             Iterations: 183
#             Function evaluations: 16471
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.697163885843846
#             Iterations: 64
#             Function evaluations: 5825
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0989787357554093e-09
#             Iterations: 46
#             Function evaluations: 4140
#             Gradient evaluations: 46
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3276772878053364e-05
#             Iterations: 188
#             Function evaluations: 16920
#             Gradient evaluations: 188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.778654766079397
#             Iterations: 67
#             Function evaluations: 6095
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1768392202319173e-09
#             Iterations: 46
#             Function evaluations: 4140
#             Gradient evaluations: 46
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2191684270323535e-05
#             Iterations: 214
#             Function evaluations: 19260
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5595874558769145
#             Iterations: 54
#             Function evaluations: 4824
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.209174085716229e-09
#             Iterations: 58
#             Function evaluations: 5220
#             Gradient evaluations: 58
# 2011-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2027062824418514e-05
#             Iterations: 206
#             Function evaluations: 18746
#             Gradient evaluations: 206
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6368409465562155
#             Iterations: 57
#             Function evaluations: 5241
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.184442599940591e-09
#             Iterations: 45
#             Function evaluations: 4096
#             Gradient evaluations: 45
# 2011-06-01 00:00:00
# ...
#             Iterations: 200
#             Function evaluations: 31000
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.1126443093321425
#             Iterations: 124
#             Function evaluations: 18888
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.123899862412964e-09
#             Iterations: 42
#             Function evaluations: 6510
#             Gradient evaluations: 42
# 2022-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4211973949683523e-05
#             Iterations: 175
#             Function evaluations: 27475
#             Gradient evaluations: 175
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.457363327117339
#             Iterations: 105
#             Function evaluations: 16012
#             Gradient evaluations: 101
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.246519262916062e-09
#             Iterations: 29
#             Function evaluations: 4553
#             Gradient evaluations: 29
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3029035865454378e-05
#             Iterations: 182
#             Function evaluations: 28938
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.700975869518392
#             Iterations: 158
#             Function evaluations: 24992
#             Gradient evaluations: 154
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.696207135255889e-09
#             Iterations: 29
#             Function evaluations: 4611
#             Gradient evaluations: 29
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.277227946825808e-05
#             Iterations: 178
#             Function evaluations: 27946
#             Gradient evaluations: 178
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.565085157911257
#             Iterations: 111
#             Function evaluations: 16964
#             Gradient evaluations: 107
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.758286945165632e-09
#             Iterations: 29
#             Function evaluations: 4553
#             Gradient evaluations: 29
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.20670800336536e-05
#             Iterations: 176
#             Function evaluations: 27456
#             Gradient evaluations: 176
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.545720079049139
#             Iterations: 111
#             Function evaluations: 17340
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1637742867560002e-08
#             Iterations: 21
#             Function evaluations: 3276
#             Gradient evaluations: 21
# 2022-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1332819907687174e-05
#             Iterations: 183
#             Function evaluations: 28182
#             Gradient evaluations: 183
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.58799141341914
#             Iterations: 124
#             Function evaluations: 18677
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.536213275778372e-09
#             Iterations: 33
#             Function evaluations: 5083
#             Gradient evaluations: 33
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1409462134752712e-05
#             Iterations: 168
#             Function evaluations: 25537
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.519824718728864
#             Iterations: 196
#             Function evaluations: 30029
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.131715040203033e-09
#             Iterations: 29
#             Function evaluations: 4408
#             Gradient evaluations: 29
# 2023-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.227764187672788e-05
#             Iterations: 177
#             Function evaluations: 27082
#             Gradient evaluations: 177
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.244276101734425
#             Iterations: 112
#             Function evaluations: 17157
#             Gradient evaluations: 111
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.5969052102268085e-09
#             Iterations: 26
#             Function evaluations: 3978
#             Gradient evaluations: 26
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.234609463689579e-05
#             Iterations: 170
#             Function evaluations: 25840
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.136290958441266
#             Iterations: 113
#             Function evaluations: 16781
#             Gradient evaluations: 109
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.428285756848159e-09
#             Iterations: 29
#             Function evaluations: 4408
#             Gradient evaluations: 29
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1511398837042306e-05
#             Iterations: 174
#             Function evaluations: 26622
#             Gradient evaluations: 174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.387257971855816
#             Iterations: 112
#             Function evaluations: 17156
#             Gradient evaluations: 111
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.026968865276022e-09
#             Iterations: 32
#             Function evaluations: 4896
#             Gradient evaluations: 32
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.156685848786556e-05
#             Iterations: 177
#             Function evaluations: 26904
#             Gradient evaluations: 177
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.435003616589723
#             Iterations: 126
#             Function evaluations: 18773
#             Gradient evaluations: 122
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.0144962616946706e-09
#             Iterations: 30
#             Function evaluations: 4560
#             Gradient evaluations: 30
# 2023-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1812995851014466e-05
#             Iterations: 177
#             Function evaluations: 26728
#             Gradient evaluations: 177
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.409569338273054
#             Iterations: 136
#             Function evaluations: 20294
#             Gradient evaluations: 132
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7898348841178325e-09
#             Iterations: 43
#             Function evaluations: 6493
#             Gradient evaluations: 43
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1719584563866186e-05
#             Iterations: 195
#             Function evaluations: 29640
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.3702292074409375
#             Iterations: 114
#             Function evaluations: 16896
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.855490068942064e-09
#             Iterations: 43
#             Function evaluations: 6536
#             Gradient evaluations: 43
# 2023-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2098178398001516e-05
#             Iterations: 187
#             Function evaluations: 28237
#             Gradient evaluations: 187
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.311439222671516
#             Iterations: 119
#             Function evaluations: 17550
#             Gradient evaluations: 115
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.844097787438462e-09
#             Iterations: 37
#             Function evaluations: 5587
#             Gradient evaluations: 37
# 2023-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1969944236368565e-05
#             Iterations: 180
#             Function evaluations: 27360
#             Gradient evaluations: 180
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.353173979795623
#             Iterations: 110
#             Function evaluations: 16739
#             Gradient evaluations: 109
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.8245408439243575e-09
#             Iterations: 41
#             Function evaluations: 6232
#             Gradient evaluations: 41
# 2023-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2787933231790488e-05
#             Iterations: 190
#             Function evaluations: 28881
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.139025531300283
#             Iterations: 114
#             Function evaluations: 16909
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.9313089676045015e-09
#             Iterations: 40
#             Function evaluations: 6081
#             Gradient evaluations: 40
# 2023-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2553400367930283e-05
#             Iterations: 190
#             Function evaluations: 28690
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.190510729875503
#             Iterations: 117
#             Function evaluations: 17249
#             Gradient evaluations: 113
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.37798480771079e-09
#             Iterations: 41
#             Function evaluations: 6191
#             Gradient evaluations: 41
# 2023-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1959054870801266e-05
#             Iterations: 198
#             Function evaluations: 29899
#             Gradient evaluations: 198
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.408053781755924
#             Iterations: 113
#             Function evaluations: 16629
#             Gradient evaluations: 109
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.253514661498393e-09
#             Iterations: 38
#             Function evaluations: 5738
#             Gradient evaluations: 38
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1218483406704243e-05
#             Iterations: 182
#             Function evaluations: 27664
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.546489960492811
#             Iterations: 117
#             Function evaluations: 17817
#             Gradient evaluations: 116
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.036273113821135e-09
#             Iterations: 38
#             Function evaluations: 5776
#             Gradient evaluations: 38
# 2024-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0595812918574394e-05
#             Iterations: 204
#             Function evaluations: 31212
#             Gradient evaluations: 204
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.6321851480962035
#             Iterations: 196
#             Function evaluations: 30226
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.581193956223355e-09
#             Iterations: 42
#             Function evaluations: 6427
#             Gradient evaluations: 42
# 2024-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.109424478719857e-05
#             Iterations: 184
#             Function evaluations: 27969
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.464805603588694
#             Iterations: 173
#             Function evaluations: 26362
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.141795170693197e-09
#             Iterations: 43
#             Function evaluations: 6536
#             Gradient evaluations: 43
# 2024-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1006025477233864e-05
#             Iterations: 192
#             Function evaluations: 29184
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.400094271349917
#             Iterations: 130
#             Function evaluations: 19373
#             Gradient evaluations: 126
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.07647594165725e-09
#             Iterations: 30
#             Function evaluations: 4561
#             Gradient evaluations: 30
# 2024-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1051335025580025e-05
#             Iterations: 192
#             Function evaluations: 28992
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.456332576771124
#             Iterations: 113
#             Function evaluations: 17237
#             Gradient evaluations: 113
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.435901153007776e-09
#             Iterations: 30
#             Function evaluations: 4531
#             Gradient evaluations: 30
# 2024-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6879853993750023e-05
#             Iterations: 188
#             Function evaluations: 28953
#             Gradient evaluations: 188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.429935363130979
#             Iterations: 90
#             Function evaluations: 13983
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.380176278661583e-09
#             Iterations: 43
#             Function evaluations: 6623
#             Gradient evaluations: 43
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_shrinked_JSE.to_csv("returnsJSEshrinked_neu_f.csv")

# %% [markdown]
# ### Reduzierter S&P500-Bestand

# %%
returns = df_SP500_reduziert.pct_change()
returns = returns.where(~df_SP500_reduziert.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                    A      AAPL       ABT       ADM       ADP      ADSK  \
# Date
# 2005-06-02  0.000414 -0.006452       NaN  0.016418  0.003861       NaN
# 2005-06-03 -0.005374 -0.044955       NaN -0.010279 -0.012443       NaN
# 2005-06-06  0.019119 -0.008368       NaN -0.003462  0.003207       NaN
# 2005-06-07 -0.012235 -0.036393       NaN  0.026799 -0.001827       NaN
# 2005-06-08  0.009496  0.010399       NaN  0.014983 -0.014642       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23 -0.010485 -0.030244 -0.001521 -0.000417 -0.001741  0.001186
# 2025-05-27  0.025154  0.025298  0.012490  0.014393  0.014388  0.016963
# 2025-05-28 -0.003415  0.001049 -0.006920 -0.005758 -0.004820 -0.003762
# 2025-05-29  0.021645 -0.002345  0.006287  0.000414 -0.000062 -0.007452
# 2025-05-30 -0.012006  0.004501  0.005495 -0.002067  0.004350 -0.002963
#
#                  AEE       AEP       AES       AFL  ...      WELL       WFC  \
# Date                                                ...
# 2005-06-02  0.001273 -0.002506 -0.014875  0.012655  ...       NaN       NaN
# 2005-06-03 -0.004540 -0.000558 -0.011668 -0.002829  ...       NaN       NaN
# 2005-06-06 -0.025903  0.003352  0.041667  0.006384  ...       NaN       NaN
# 2005-06-07  0.005805 -0.003341 -0.004000 -0.017857  ...       NaN       NaN
# 2005-06-08  0.001676  0.000559 -0.006693  0.000000  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-23  0.009434  0.010609  0.037383  0.000781  ...  0.015453 -0.007630
# 2025-05-27  0.004050  0.000292  0.008008  0.008583  ...  0.022122  0.015927
# 2025-05-28 -0.014169 -0.011952 -0.036743 -0.013732  ... -0.005050 -0.003514
# 2025-05-29  0.008917  0.008360  0.036083  0.008040  ...  0.009031  0.010579
# 2025-05-30  0.007383  0.009363  0.003980  0.007101  ...  0.007905  0.003624
#
#                   WM       WMB       WMT       WST       WTW        WY  \
# Date
# 2005-06-02 -0.001013 -0.002674  0.006260       NaN       NaN -0.000462
# 2005-06-03  0.003719  0.008043 -0.018042       NaN       NaN -0.012020
# 2005-06-06 -0.004379  0.001596  0.008025       NaN       NaN  0.009827
# 2005-06-07 -0.012855 -0.008497  0.000629       NaN       NaN  0.010349
# 2005-06-08 -0.001028 -0.004285 -0.003978       NaN       NaN -0.005351
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23  0.014958  0.021472  0.004274 -0.013910  0.003084 -0.000792
# 2025-05-27  0.005152  0.018817  0.012871  0.026412  0.011747  0.023781
# 2025-05-28 -0.003697  0.008652 -0.003484  0.001753 -0.005245  0.002323
# 2025-05-29  0.002572 -0.005774 -0.001440 -0.004399  0.013729  0.005794
# 2025-05-30  0.013501  0.003982  0.016684  0.001853  0.004028 -0.004992
#
#                  YUM       ZBH
# Date
# 2005-06-02       NaN  0.002885
# 2005-06-03       NaN  0.029816
# 2005-06-06       NaN -0.005079
# 2005-06-07       NaN  0.013657
# 2005-06-08       NaN -0.005414
# ...              ...       ...
# 2025-05-23 -0.000344  0.010581
# 2025-05-27 -0.009350  0.016947
# 2025-05-28 -0.006524 -0.020380
# 2025-05-29  0.006217  0.011377
# 2025-05-30 -0.000694 -0.012535
#
# [5031 rows x 219 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 1
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = training_daten.cov()
    corr_matrix = training_daten.corr()
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    reduziert_gewichte_equally_weighted = equally_weighted(training_daten)
    reduziert_gewichte_min_variance= min_variance_opt(cov_matrix)
    reduziert_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    reduziert_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    reduziert_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    reduziert_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    reduziert_gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": reduziert_gewichte_equally_weighted,
    "Minimum-Variance": reduziert_gewichte_min_variance,
    "Maximum-Diversification": reduziert_gewichte_max_diversification,
    "Inverse-Volatility": reduziert_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": reduziert_gewichte_risk_parity,
    "HRP": reduziert_gewichte_hrp,
    "HERC": reduziert_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
    #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_reduziert = pd.concat(portfolio_returns_list)
portfolio_returns_df_reduziert = portfolio_returns_df_reduziert.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9017992899290135e-05
#             Iterations: 280
#             Function evaluations: 29121
#             Gradient evaluations: 280
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.652219442909011
#             Iterations: 47
#             Function evaluations: 4930
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.365055186761163e-09
#             Iterations: 20
#             Function evaluations: 2080
#             Gradient evaluations: 20
# 2005-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0021735577945475e-05
#             Iterations: 257
#             Function evaluations: 26728
#             Gradient evaluations: 257
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5522089555105656
#             Iterations: 44
#             Function evaluations: 4616
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8315919225406216e-09
#             Iterations: 33
#             Function evaluations: 3432
#             Gradient evaluations: 33
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0935482525955812e-05
#             Iterations: 263
#             Function evaluations: 27615
#             Gradient evaluations: 263
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4763421717035397
#             Iterations: 45
#             Function evaluations: 4764
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.7222664002753807e-09
#             Iterations: 33
#             Function evaluations: 3466
#             Gradient evaluations: 33
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.088962208446139e-05
#             Iterations: 265
#             Function evaluations: 28090
#             Gradient evaluations: 265
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5547461664618325
#             Iterations: 43
#             Function evaluations: 4599
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3217118361345674e-09
#             Iterations: 44
#             Function evaluations: 4664
#             Gradient evaluations: 44
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0186889796145374e-05
#             Iterations: 294
#             Function evaluations: 31164
#             Gradient evaluations: 294
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5747378396560987
#             Iterations: 45
#             Function evaluations: 4811
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.736732741827729e-09
#             Iterations: 43
#             Function evaluations: 4559
#             Gradient evaluations: 43
# 2005-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8943860688470752e-05
#             Iterations: 246
#             Function evaluations: 26322
#             Gradient evaluations: 246
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7600738028523737
#             Iterations: 46
#             Function evaluations: 4966
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3802451792869785e-09
#             Iterations: 37
#             Function evaluations: 3959
#             Gradient evaluations: 37
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8887065821860133e-05
#             Iterations: 230
#             Function evaluations: 24841
#             Gradient evaluations: 230
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.707146452390596
#             Iterations: 43
#             Function evaluations: 4686
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.283575703982452e-09
#             Iterations: 39
#             Function evaluations: 4212
#             Gradient evaluations: 39
# 2006-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.851330047487494e-05
#             Iterations: 205
#             Function evaluations: 22141
#             Gradient evaluations: 205
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7094376037220114
#             Iterations: 46
#             Function evaluations: 5012
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5874119737904205e-09
#             Iterations: 39
#             Function evaluations: 4212
#             Gradient evaluations: 39
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6803005103154148e-05
#             Iterations: 229
#             Function evaluations: 26336
#             Gradient evaluations: 229
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7128329936123006
#             Iterations: 43
#             Function evaluations: 4988
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0889587155280394e-09
#             Iterations: 39
#             Function evaluations: 4485
#             Gradient evaluations: 39
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8683480011154963e-05
#             Iterations: 264
#             Function evaluations: 30360
#             Gradient evaluations: 264
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.632997322079691
#             Iterations: 43
#             Function evaluations: 4986
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9896760010559917e-09
#             Iterations: 39
#             Function evaluations: 4485
#             Gradient evaluations: 39
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0932740657284597e-05
#             Iterations: 250
#             Function evaluations: 28751
#             Gradient evaluations: 250
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5207841962998145
#             Iterations: 36
#             Function evaluations: 4176
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9363276561109653e-09
#             Iterations: 38
#             Function evaluations: 4370
#             Gradient evaluations: 38
# 2006-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0170851454709996e-05
#             Iterations: 279
#             Function evaluations: 32085
#             Gradient evaluations: 279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.581139739922948
#             Iterations: 46
#             Function evaluations: 5334
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9150043867645534e-09
#             Iterations: 38
#             Function evaluations: 4370
#             Gradient evaluations: 38
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8781763891344987e-05
#             Iterations: 294
#             Function evaluations: 33811
#             Gradient evaluations: 294
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6155153176558943
#             Iterations: 49
#             Function evaluations: 5682
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8101393045322594e-09
#             Iterations: 39
#             Function evaluations: 4485
#             Gradient evaluations: 39
# 2006-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.906849094834389e-05
#             Iterations: 274
#             Function evaluations: 31510
#             Gradient evaluations: 274
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6400833433064386
#             Iterations: 48
#             Function evaluations: 5565
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1923717473136432e-09
#             Iterations: 23
#             Function evaluations: 2645
#             Gradient evaluations: 23
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1408084422113406e-05
#             Iterations: 253
#             Function evaluations: 29095
#             Gradient evaluations: 253
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6242126622301045
#             Iterations: 44
#             Function evaluations: 5101
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.786451974421181e-09
#             Iterations: 21
#             Function evaluations: 2416
#             Gradient evaluations: 21
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9267399601576698e-05
#             Iterations: 243
#             Function evaluations: 27946
#             Gradient evaluations: 243
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4588858122898256
#             Iterations: 37
#             Function evaluations: 4287
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0925212337077457e-09
#             Iterations: 31
#             Function evaluations: 3565
#             Gradient evaluations: 31
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1820456049687994e-05
#             Iterations: 238
#             Function evaluations: 27370
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3806385226427125
#             Iterations: 33
#             Function evaluations: 3824
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.940699486247673e-09
#             Iterations: 28
#             Function evaluations: 3220
#             Gradient evaluations: 28
# 2006-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3036640360271536e-05
#             Iterations: 241
#             Function evaluations: 27715
#             Gradient evaluations: 241
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3412874733088334
#             Iterations: 31
#             Function evaluations: 3595
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6811531627195673e-09
#             Iterations: 31
#             Function evaluations: 3565
#             Gradient evaluations: 31
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.7421330447682834e-05
#             Iterations: 212
#             Function evaluations: 24380
#             Gradient evaluations: 212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2254790369866626
#             Iterations: 31
#             Function evaluations: 3595
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8195119643637268e-09
#             Iterations: 31
#             Function evaluations: 3565
#             Gradient evaluations: 31
# 2007-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8901299964605014e-05
#             Iterations: 234
#             Function evaluations: 26910
#             Gradient evaluations: 234
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.19710801926585
#             Iterations: 32
#             Function evaluations: 3708
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.00949017196006e-09
#             Iterations: 42
#             Function evaluations: 4830
#             Gradient evaluations: 42
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.587427980080176e-05
#             Iterations: 201
#             Function evaluations: 24522
#             Gradient evaluations: 201
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.174436705395521
#             Iterations: 29
#             Function evaluations: 3566
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7061841076718198e-09
#             Iterations: 42
#             Function evaluations: 5124
#             Gradient evaluations: 42
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.868291632833433e-05
#             Iterations: 183
#             Function evaluations: 22326
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1541909731214663
#             Iterations: 29
#             Function evaluations: 3563
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8312070168091434e-09
#             Iterations: 41
#             Function evaluations: 5002
#             Gradient evaluations: 41
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.102723785770433e-05
#             Iterations: 186
#             Function evaluations: 22693
#             Gradient evaluations: 186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3184054479222964
#             Iterations: 26
#             Function evaluations: 3199
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.982602168267027e-10
#             Iterations: 52
#             Function evaluations: 6344
#             Gradient evaluations: 52
# 2007-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.267649049897749e-05
#             Iterations: 192
#             Function evaluations: 23424
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2906174626399594
#             Iterations: 30
#             Function evaluations: 3684
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.820320262343032e-10
#             Iterations: 52
#             Function evaluations: 6344
#             Gradient evaluations: 52
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.4995120767060236e-05
#             Iterations: 185
#             Function evaluations: 22570
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2936358128633407
#             Iterations: 30
#             Function evaluations: 3685
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.104976855330307e-09
#             Iterations: 51
#             Function evaluations: 6222
#             Gradient evaluations: 51
# 2007-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.9337898612931195e-05
#             Iterations: 170
#             Function evaluations: 20740
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2711677774667747
#             Iterations: 27
#             Function evaluations: 3321
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1113257428256717e-09
#             Iterations: 51
#             Function evaluations: 6223
#             Gradient evaluations: 51
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.8621949180970374e-05
#             Iterations: 213
#             Function evaluations: 25986
#             Gradient evaluations: 213
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3730553314807805
#             Iterations: 28
#             Function evaluations: 3446
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.739846031813648e-10
#             Iterations: 71
#             Function evaluations: 8662
#             Gradient evaluations: 71
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.362072549593693e-05
#             Iterations: 196
#             Function evaluations: 23912
#             Gradient evaluations: 196
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.466438477676465
#             Iterations: 28
#             Function evaluations: 3443
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8652660863630943e-09
#             Iterations: 82
#             Function evaluations: 10004
#             Gradient evaluations: 82
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.168697408497534e-05
#             Iterations: 174
#             Function evaluations: 21228
#             Gradient evaluations: 174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3552590644718525
#             Iterations: 30
#             Function evaluations: 3686
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.06586289573344e-10
#             Iterations: 145
#             Function evaluations: 17690
#             Gradient evaluations: 145
# 2007-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001504386786079484
#             Iterations: 144
#             Function evaluations: 17712
#             Gradient evaluations: 144
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9015801621654036
#             Iterations: 22
#             Function evaluations: 2722
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9044922232271593e-10
#             Iterations: 92
#             Function evaluations: 11316
#             Gradient evaluations: 92
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.000187852623392505
#             Iterations: 125
#             Function evaluations: 15375
#             Gradient evaluations: 125
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8271311419971497
#             Iterations: 24
#             Function evaluations: 2965
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.013686006339449e-10
#             Iterations: 87
#             Function evaluations: 10702
#             Gradient evaluations: 87
# 2008-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00020868475022125653
#             Iterations: 128
#             Function evaluations: 15744
#             Gradient evaluations: 128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7984606527633413
#             Iterations: 24
#             Function evaluations: 2966
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2060809056631597e-10
#             Iterations: 95
#             Function evaluations: 11685
#             Gradient evaluations: 95
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00020887478481779816
#             Iterations: 121
#             Function evaluations: 15488
#             Gradient evaluations: 121
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8010327210406987
#             Iterations: 23
#             Function evaluations: 2962
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8572174944637976e-10
#             Iterations: 93
#             Function evaluations: 11904
#             Gradient evaluations: 93
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021747357162482927
#             Iterations: 136
#             Function evaluations: 17408
#             Gradient evaluations: 136
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8213534941476606
#             Iterations: 24
#             Function evaluations: 3087
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5453313949833617e-10
#             Iterations: 101
#             Function evaluations: 12929
#             Gradient evaluations: 101
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002355734146042825
#             Iterations: 120
#             Function evaluations: 15360
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.709044063285686
#             Iterations: 24
#             Function evaluations: 3082
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8193292240585653e-10
#             Iterations: 99
#             Function evaluations: 12673
#             Gradient evaluations: 99
# 2008-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00023685778805843105
#             Iterations: 126
#             Function evaluations: 16128
#             Gradient evaluations: 126
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7227204046001843
#             Iterations: 21
#             Function evaluations: 2700
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0485973951525894e-10
#             Iterations: 107
#             Function evaluations: 13696
#             Gradient evaluations: 107
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00023558217148640252
#             Iterations: 124
#             Function evaluations: 15872
#             Gradient evaluations: 124
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7225113340691758
#             Iterations: 22
#             Function evaluations: 2831
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.090239734580926e-10
#             Iterations: 107
#             Function evaluations: 13696
#             Gradient evaluations: 107
# 2008-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00023194308735485647
#             Iterations: 132
#             Function evaluations: 16896
#             Gradient evaluations: 132
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.715495262506066
#             Iterations: 23
#             Function evaluations: 2959
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3364525497407257e-10
#             Iterations: 107
#             Function evaluations: 13696
#             Gradient evaluations: 107
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00023285493115072874
#             Iterations: 124
#             Function evaluations: 15873
#             Gradient evaluations: 124
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7079868213417
#             Iterations: 22
#             Function evaluations: 2826
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1517324813655738e-10
#             Iterations: 107
#             Function evaluations: 13696
#             Gradient evaluations: 107
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022484899116513633
#             Iterations: 113
#             Function evaluations: 14465
#             Gradient evaluations: 113
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7092661348667826
#             Iterations: 21
#             Function evaluations: 2700
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2746318970667996e-10
#             Iterations: 107
#             Function evaluations: 13696
#             Gradient evaluations: 107
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002150317158432619
#             Iterations: 98
#             Function evaluations: 12544
#             Gradient evaluations: 98
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7072171686665236
#             Iterations: 22
#             Function evaluations: 2827
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7085529198951876e-10
#             Iterations: 99
#             Function evaluations: 12673
#             Gradient evaluations: 99
# 2008-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00012243605040767079
#             Iterations: 136
#             Function evaluations: 17408
#             Gradient evaluations: 136
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8535782530231688
#             Iterations: 24
#             Function evaluations: 3087
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.684145080916425e-10
#             Iterations: 121
#             Function evaluations: 15489
#             Gradient evaluations: 121
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.166747564893628e-05
#             Iterations: 148
#             Function evaluations: 18944
#             Gradient evaluations: 148
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.088187189932685
#             Iterations: 30
#             Function evaluations: 3862
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.497760198336761e-10
#             Iterations: 152
#             Function evaluations: 19456
#             Gradient evaluations: 152
# 2009-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.466943267012572e-05
#             Iterations: 153
#             Function evaluations: 19584
#             Gradient evaluations: 153
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1689630990461466
#             Iterations: 25
#             Function evaluations: 3222
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.741047419912109e-10
#             Iterations: 144
#             Function evaluations: 18432
#             Gradient evaluations: 144
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.232764143649401e-05
#             Iterations: 161
#             Function evaluations: 23184
#             Gradient evaluations: 161
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1718666804887294
#             Iterations: 31
#             Function evaluations: 4493
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.94990134554115e-10
#             Iterations: 113
#             Function evaluations: 16273
#             Gradient evaluations: 113
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.127068491206573e-05
#             Iterations: 175
#             Function evaluations: 25200
#             Gradient evaluations: 175
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.194459262531681
#             Iterations: 29
#             Function evaluations: 4204
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.754996200917577e-10
#             Iterations: 116
#             Function evaluations: 16705
#             Gradient evaluations: 116
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.511899070334007e-05
#             Iterations: 201
#             Function evaluations: 28944
#             Gradient evaluations: 201
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3681353078521594
#             Iterations: 37
#             Function evaluations: 5365
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.012352701298921e-09
#             Iterations: 99
#             Function evaluations: 14257
#             Gradient evaluations: 99
# 2009-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.349784420761696e-05
#             Iterations: 207
#             Function evaluations: 29809
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3605320056832566
#             Iterations: 37
#             Function evaluations: 5365
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4627331599089762e-09
#             Iterations: 69
#             Function evaluations: 9936
#             Gradient evaluations: 69
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.7929974666817126e-05
#             Iterations: 214
#             Function evaluations: 30816
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2520336834178387
#             Iterations: 31
#             Function evaluations: 4492
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.470141301441663e-09
#             Iterations: 61
#             Function evaluations: 8784
#             Gradient evaluations: 61
# 2009-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.834947765928838e-05
#             Iterations: 195
#             Function evaluations: 28080
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.163895746368488
#             Iterations: 27
#             Function evaluations: 3913
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1948961345467531e-09
#             Iterations: 62
#             Function evaluations: 8928
#             Gradient evaluations: 62
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.9534404206007455e-05
#             Iterations: 212
#             Function evaluations: 30528
#             Gradient evaluations: 212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1585972134560723
#             Iterations: 25
#             Function evaluations: 3626
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.49980288490844e-10
#             Iterations: 62
#             Function evaluations: 8929
#             Gradient evaluations: 62
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.128217209697132e-05
#             Iterations: 172
#             Function evaluations: 24769
#             Gradient evaluations: 172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.074219795895728
#             Iterations: 25
#             Function evaluations: 3624
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.880585050559184e-10
#             Iterations: 62
#             Function evaluations: 8928
#             Gradient evaluations: 62
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.187914662074888e-05
#             Iterations: 203
#             Function evaluations: 29233
#             Gradient evaluations: 203
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0325254490371667
#             Iterations: 25
#             Function evaluations: 3621
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.912410878353216e-10
#             Iterations: 62
#             Function evaluations: 8928
#             Gradient evaluations: 62
# 2009-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.9892907259952234e-05
#             Iterations: 183
#             Function evaluations: 26352
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0146822513179306
#             Iterations: 25
#             Function evaluations: 3622
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.91175071081258e-10
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.7708325324443815e-05
#             Iterations: 174
#             Function evaluations: 25056
#             Gradient evaluations: 174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9808457598834999
#             Iterations: 25
#             Function evaluations: 3624
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.049509241072265e-09
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2010-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6502420342561834e-05
#             Iterations: 208
#             Function evaluations: 29952
#             Gradient evaluations: 208
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.016970410645986
#             Iterations: 27
#             Function evaluations: 3910
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1740690468913142e-09
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5364830472177994e-05
#             Iterations: 190
#             Function evaluations: 27360
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.03575980440509
#             Iterations: 24
#             Function evaluations: 3477
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0717222089062987e-09
#             Iterations: 53
#             Function evaluations: 7632
#             Gradient evaluations: 53
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.51407439802159e-05
#             Iterations: 186
#             Function evaluations: 26784
#             Gradient evaluations: 186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0746741105224626
#             Iterations: 26
#             Function evaluations: 3768
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1527140387506488e-09
#             Iterations: 53
#             Function evaluations: 7632
#             Gradient evaluations: 53
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6388225692484095e-05
#             Iterations: 184
#             Function evaluations: 26497
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.065287182188885
#             Iterations: 24
#             Function evaluations: 3478
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0861600427380064e-09
#             Iterations: 53
#             Function evaluations: 7632
#             Gradient evaluations: 53
# 2010-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.7098373791887975e-05
#             Iterations: 206
#             Function evaluations: 29664
#             Gradient evaluations: 206
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0892839112051007
#             Iterations: 26
#             Function evaluations: 3765
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.071295062799012e-10
#             Iterations: 52
#             Function evaluations: 7489
#             Gradient evaluations: 52
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.057107508337295e-05
#             Iterations: 212
#             Function evaluations: 30528
#             Gradient evaluations: 212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.284811378417457
#             Iterations: 28
#             Function evaluations: 4054
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.060844704717548e-09
#             Iterations: 42
#             Function evaluations: 6048
#             Gradient evaluations: 42
# 2010-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6576412379105382e-05
#             Iterations: 259
#             Function evaluations: 37297
#             Gradient evaluations: 259
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3578823511440814
#             Iterations: 33
#             Function evaluations: 4783
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5973231657515614e-09
#             Iterations: 42
#             Function evaluations: 6049
#             Gradient evaluations: 42
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.389269875217935e-05
#             Iterations: 236
#             Function evaluations: 33984
#             Gradient evaluations: 236
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3385912177106034
#             Iterations: 33
#             Function evaluations: 4782
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0303876010499016e-09
#             Iterations: 39
#             Function evaluations: 5616
#             Gradient evaluations: 39
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.888709067615482e-05
#             Iterations: 201
#             Function evaluations: 28944
#             Gradient evaluations: 201
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.91020894443162
#             Iterations: 23
#             Function evaluations: 3334
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1895492507876344e-09
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.216897838940675e-05
#             Iterations: 183
#             Function evaluations: 26352
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8457979313319026
#             Iterations: 25
#             Function evaluations: 3620
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1786701541502719e-09
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2010-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.545094079158688e-05
#             Iterations: 164
#             Function evaluations: 23616
#             Gradient evaluations: 164
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8031496154167668
#             Iterations: 27
#             Function evaluations: 3904
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.040969583434734e-09
#             Iterations: 62
#             Function evaluations: 8929
#             Gradient evaluations: 62
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.158239841657278e-05
#             Iterations: 222
#             Function evaluations: 31968
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7550584713388624
#             Iterations: 20
#             Function evaluations: 2894
#             Gradient evaluations: 20
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0850792071916978e-09
#             Iterations: 60
#             Function evaluations: 8641
#             Gradient evaluations: 60
# 2011-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.55495531019562e-05
#             Iterations: 208
#             Function evaluations: 29952
#             Gradient evaluations: 208
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7974463566696823
#             Iterations: 23
#             Function evaluations: 3328
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0452560428934194e-09
#             Iterations: 59
#             Function evaluations: 8497
#             Gradient evaluations: 59
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.588199829110609e-05
#             Iterations: 216
#             Function evaluations: 31104
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.797905733083265
#             Iterations: 23
#             Function evaluations: 3330
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.659010001960473e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.493880115779792e-05
#             Iterations: 191
#             Function evaluations: 27504
#             Gradient evaluations: 191
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7959135983169192
#             Iterations: 23
#             Function evaluations: 3326
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.878176908902632e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.311419720805511e-05
#             Iterations: 168
#             Function evaluations: 24192
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7987024808062229
#             Iterations: 23
#             Function evaluations: 3328
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.633681632468805e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.384033029273357e-05
#             Iterations: 221
#             Function evaluations: 31824
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7904781737005793
#             Iterations: 26
#             Function evaluations: 3758
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.365762179082662e-10
#             Iterations: 69
# ...
#             Current function value: 6.267153536467891e-05
#             Iterations: 234
#             Function evaluations: 49608
#             Gradient evaluations: 234
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.203321324801693
#             Iterations: 32
#             Function evaluations: 6813
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.943448332663186e-10
#             Iterations: 55
#             Function evaluations: 11661
#             Gradient evaluations: 55
# 2022-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.670668678237255e-05
#             Iterations: 254
#             Function evaluations: 53849
#             Gradient evaluations: 254
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.243381359150054
#             Iterations: 35
#             Function evaluations: 7454
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0420588673598198e-09
#             Iterations: 40
#             Function evaluations: 8480
#             Gradient evaluations: 40
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.5232686196069485e-05
#             Iterations: 225
#             Function evaluations: 47700
#             Gradient evaluations: 225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.263793238281578
#             Iterations: 36
#             Function evaluations: 7664
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.152025306223177e-10
#             Iterations: 51
#             Function evaluations: 10812
#             Gradient evaluations: 51
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.226480282260656e-05
#             Iterations: 231
#             Function evaluations: 48973
#             Gradient evaluations: 231
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3363133739153796
#             Iterations: 37
#             Function evaluations: 7879
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6531553200874286e-09
#             Iterations: 41
#             Function evaluations: 8692
#             Gradient evaluations: 41
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.298596169534428e-05
#             Iterations: 255
#             Function evaluations: 54060
#             Gradient evaluations: 255
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.472243646309138
#             Iterations: 44
#             Function evaluations: 9372
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1201533829967725e-09
#             Iterations: 39
#             Function evaluations: 8269
#             Gradient evaluations: 39
# 2022-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.377326522131818e-05
#             Iterations: 238
#             Function evaluations: 50457
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6650433928436863
#             Iterations: 49
#             Function evaluations: 10434
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6838674268885635e-09
#             Iterations: 49
#             Function evaluations: 10388
#             Gradient evaluations: 49
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.106005586456038e-05
#             Iterations: 254
#             Function evaluations: 53848
#             Gradient evaluations: 254
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8087680715598307
#             Iterations: 47
#             Function evaluations: 10004
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.025838224048078e-09
#             Iterations: 38
#             Function evaluations: 8057
#             Gradient evaluations: 38
# 2023-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.898204169006905e-05
#             Iterations: 230
#             Function evaluations: 48761
#             Gradient evaluations: 230
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.924191141179505
#             Iterations: 46
#             Function evaluations: 9793
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.292278565984269e-09
#             Iterations: 39
#             Function evaluations: 8269
#             Gradient evaluations: 39
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.488522306604793e-05
#             Iterations: 316
#             Function evaluations: 66992
#             Gradient evaluations: 316
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0927194843078625
#             Iterations: 52
#             Function evaluations: 11073
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.775828982935176e-09
#             Iterations: 50
#             Function evaluations: 10600
#             Gradient evaluations: 50
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3729011084895513e-05
#             Iterations: 311
#             Function evaluations: 65932
#             Gradient evaluations: 311
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1671100561391667
#             Iterations: 54
#             Function evaluations: 11498
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.061298230540137e-09
#             Iterations: 50
#             Function evaluations: 10600
#             Gradient evaluations: 50
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0536394389499704e-05
#             Iterations: 308
#             Function evaluations: 65296
#             Gradient evaluations: 308
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.383970100709039
#             Iterations: 63
#             Function evaluations: 13203
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.229509800469942e-09
#             Iterations: 39
#             Function evaluations: 8269
#             Gradient evaluations: 39
# 2023-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0572388931329517e-05
#             Iterations: 281
#             Function evaluations: 59572
#             Gradient evaluations: 281
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4326743770715575
#             Iterations: 61
#             Function evaluations: 12774
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.4675724567464472e-09
#             Iterations: 39
#             Function evaluations: 8268
#             Gradient evaluations: 39
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.038925699948426e-05
#             Iterations: 248
#             Function evaluations: 52577
#             Gradient evaluations: 248
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4512995572540963
#             Iterations: 69
#             Function evaluations: 13845
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.69235841260676e-09
#             Iterations: 27
#             Function evaluations: 5724
#             Gradient evaluations: 27
# 2023-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.883146226472456e-05
#             Iterations: 279
#             Function evaluations: 59148
#             Gradient evaluations: 279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6015346343713968
#             Iterations: 61
#             Function evaluations: 12989
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3962931884138045e-09
#             Iterations: 27
#             Function evaluations: 5724
#             Gradient evaluations: 27
# 2023-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8749640387615298e-05
#             Iterations: 286
#             Function evaluations: 60632
#             Gradient evaluations: 286
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5967995416165808
#             Iterations: 62
#             Function evaluations: 12348
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3732662415519384e-09
#             Iterations: 28
#             Function evaluations: 5936
#             Gradient evaluations: 28
# 2023-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.926478841179717e-05
#             Iterations: 285
#             Function evaluations: 60420
#             Gradient evaluations: 285
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6439475119314606
#             Iterations: 59
#             Function evaluations: 12566
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.8513087300326226e-09
#             Iterations: 27
#             Function evaluations: 5725
#             Gradient evaluations: 27
# 2023-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.995887326024965e-05
#             Iterations: 297
#             Function evaluations: 62964
#             Gradient evaluations: 297
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.661596765821605
#             Iterations: 59
#             Function evaluations: 12566
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.079845340292606e-09
#             Iterations: 27
#             Function evaluations: 5725
#             Gradient evaluations: 27
# 2023-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.788338281261243e-05
#             Iterations: 300
#             Function evaluations: 63600
#             Gradient evaluations: 300
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.772158241484212
#             Iterations: 65
#             Function evaluations: 12992
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.887497421326273e-09
#             Iterations: 27
#             Function evaluations: 5725
#             Gradient evaluations: 27
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7993405559428317e-05
#             Iterations: 265
#             Function evaluations: 56181
#             Gradient evaluations: 265
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7373131331280534
#             Iterations: 62
#             Function evaluations: 12993
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.800858914074732e-09
#             Iterations: 27
#             Function evaluations: 5725
#             Gradient evaluations: 27
# 2024-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8095451612740614e-05
#             Iterations: 296
#             Function evaluations: 62753
#             Gradient evaluations: 296
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.712038753602316
#             Iterations: 60
#             Function evaluations: 12778
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1694204835769156e-09
#             Iterations: 27
#             Function evaluations: 5725
#             Gradient evaluations: 27
# 2024-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8714621647232616e-05
#             Iterations: 317
#             Function evaluations: 68790
#             Gradient evaluations: 317
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.73029977571836
#             Iterations: 91
#             Function evaluations: 18994
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7530154026463367e-09
#             Iterations: 27
#             Function evaluations: 5859
#             Gradient evaluations: 27
# 2024-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8805560899335218e-05
#             Iterations: 321
#             Function evaluations: 69658
#             Gradient evaluations: 321
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.787940916576481
#             Iterations: 69
#             Function evaluations: 14169
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0907209390885397e-09
#             Iterations: 27
#             Function evaluations: 5859
#             Gradient evaluations: 27
# 2024-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0427251677950425e-05
#             Iterations: 284
#             Function evaluations: 61629
#             Gradient evaluations: 284
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6973248577687485
#             Iterations: 62
#             Function evaluations: 13299
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5255877813278843e-09
#             Iterations: 21
#             Function evaluations: 4557
#             Gradient evaluations: 21
# 2024-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.389661237761142e-05
#             Iterations: 326
#             Function evaluations: 71068
#             Gradient evaluations: 326
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.034477627543447
#             Iterations: 44
#             Function evaluations: 9633
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7700862678597455e-09
#             Iterations: 50
#             Function evaluations: 10900
#             Gradient evaluations: 50
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_reduziert.to_csv("returnsreduziert_neu_f.csv")

# %% [markdown]
# ### Reduziert und Ledoit-Shrinkage

# %%
returns = df_SP500_reduziert.pct_change()
returns = returns.where(~df_SP500_reduziert.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                    A      AAPL       ABT       ADM       ADP      ADSK  \
# Date
# 2005-06-02  0.000414 -0.006452       NaN  0.016418  0.003861       NaN
# 2005-06-03 -0.005374 -0.044955       NaN -0.010279 -0.012443       NaN
# 2005-06-06  0.019119 -0.008368       NaN -0.003462  0.003207       NaN
# 2005-06-07 -0.012235 -0.036393       NaN  0.026799 -0.001827       NaN
# 2005-06-08  0.009496  0.010399       NaN  0.014983 -0.014642       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23 -0.010485 -0.030244 -0.001521 -0.000417 -0.001741  0.001186
# 2025-05-27  0.025154  0.025298  0.012490  0.014393  0.014388  0.016963
# 2025-05-28 -0.003415  0.001049 -0.006920 -0.005758 -0.004820 -0.003762
# 2025-05-29  0.021645 -0.002345  0.006287  0.000414 -0.000062 -0.007452
# 2025-05-30 -0.012006  0.004501  0.005495 -0.002067  0.004350 -0.002963
#
#                  AEE       AEP       AES       AFL  ...      WELL       WFC  \
# Date                                                ...
# 2005-06-02  0.001273 -0.002506 -0.014875  0.012655  ...       NaN       NaN
# 2005-06-03 -0.004540 -0.000558 -0.011668 -0.002829  ...       NaN       NaN
# 2005-06-06 -0.025903  0.003352  0.041667  0.006384  ...       NaN       NaN
# 2005-06-07  0.005805 -0.003341 -0.004000 -0.017857  ...       NaN       NaN
# 2005-06-08  0.001676  0.000559 -0.006693  0.000000  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-23  0.009434  0.010609  0.037383  0.000781  ...  0.015453 -0.007630
# 2025-05-27  0.004050  0.000292  0.008008  0.008583  ...  0.022122  0.015927
# 2025-05-28 -0.014169 -0.011952 -0.036743 -0.013732  ... -0.005050 -0.003514
# 2025-05-29  0.008917  0.008360  0.036083  0.008040  ...  0.009031  0.010579
# 2025-05-30  0.007383  0.009363  0.003980  0.007101  ...  0.007905  0.003624
#
#                   WM       WMB       WMT       WST       WTW        WY  \
# Date
# 2005-06-02 -0.001013 -0.002674  0.006260       NaN       NaN -0.000462
# 2005-06-03  0.003719  0.008043 -0.018042       NaN       NaN -0.012020
# 2005-06-06 -0.004379  0.001596  0.008025       NaN       NaN  0.009827
# 2005-06-07 -0.012855 -0.008497  0.000629       NaN       NaN  0.010349
# 2005-06-08 -0.001028 -0.004285 -0.003978       NaN       NaN -0.005351
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23  0.014958  0.021472  0.004274 -0.013910  0.003084 -0.000792
# 2025-05-27  0.005152  0.018817  0.012871  0.026412  0.011747  0.023781
# 2025-05-28 -0.003697  0.008652 -0.003484  0.001753 -0.005245  0.002323
# 2025-05-29  0.002572 -0.005774 -0.001440 -0.004399  0.013729  0.005794
# 2025-05-30  0.013501  0.003982  0.016684  0.001853  0.004028 -0.004992
#
#                  YUM       ZBH
# Date
# 2005-06-02       NaN  0.002885
# 2005-06-03       NaN  0.029816
# 2005-06-06       NaN -0.005079
# 2005-06-07       NaN  0.013657
# 2005-06-08       NaN -0.005414
# ...              ...       ...
# 2025-05-23 -0.000344  0.010581
# 2025-05-27 -0.009350  0.016947
# 2025-05-28 -0.006524 -0.020380
# 2025-05-29  0.006217  0.011377
# 2025-05-30 -0.000694 -0.012535
#
# [5031 rows x 219 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 1
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = ledoit_shrink(training_daten)
    
    #aus der geschrumpften Matrix die Korrelationsmatrix bauen
    standardabweichung = np.sqrt(np.diag(cov_matrix))
    corr_matrix = cov_matrix / np.outer(standardabweichung, standardabweichung)
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    reduziert_shrinked_gewichte_equally_weighted = equally_weighted(training_daten)
    reduziert_shrinked_gewichte_min_variance= min_variance_opt(cov_matrix)
    reduziert_shrinked_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    reduziert_shrinked_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    reduziert_shrinked_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    reduziert_shrinked_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    reduziert_shrinked_gewichte_herc = herc_ledoit(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": reduziert_shrinked_gewichte_equally_weighted,
    "Minimum-Variance": reduziert_shrinked_gewichte_min_variance,
    "Maximum-Diversification": reduziert_shrinked_gewichte_max_diversification,
    "Inverse-Volatility": reduziert_shrinked_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": reduziert_shrinked_gewichte_risk_parity,
    "HRP": reduziert_shrinked_gewichte_hrp,
    "HERC": reduziert_shrinked_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
    #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_reduziert_shrinked = pd.concat(portfolio_returns_list)
portfolio_returns_df_reduziert_shrinked = portfolio_returns_df_reduziert_shrinked.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8537208164551943e-05
#             Iterations: 247
#             Function evaluations: 25688
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.739509480282772
#             Iterations: 53
#             Function evaluations: 5558
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.881345984878581e-09
#             Iterations: 21
#             Function evaluations: 2184
#             Gradient evaluations: 21
# 2005-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.958513194585269e-05
#             Iterations: 244
#             Function evaluations: 25376
#             Gradient evaluations: 244
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6258799909140076
#             Iterations: 45
#             Function evaluations: 4725
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5454367074130893e-09
#             Iterations: 33
#             Function evaluations: 3432
#             Gradient evaluations: 33
# 2005-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0621343687257674e-05
#             Iterations: 241
#             Function evaluations: 25306
#             Gradient evaluations: 241
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5440638158999542
#             Iterations: 42
#             Function evaluations: 4452
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.401051078783178e-09
#             Iterations: 33
#             Function evaluations: 3465
#             Gradient evaluations: 33
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0562808286751492e-05
#             Iterations: 255
#             Function evaluations: 27030
#             Gradient evaluations: 255
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.622013985874994
#             Iterations: 46
#             Function evaluations: 4919
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0912526402666536e-09
#             Iterations: 44
#             Function evaluations: 4665
#             Gradient evaluations: 44
# 2005-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9948819487412234e-05
#             Iterations: 250
#             Function evaluations: 26500
#             Gradient evaluations: 250
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6455779360941403
#             Iterations: 47
#             Function evaluations: 5027
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4712779756377678e-09
#             Iterations: 44
#             Function evaluations: 4664
#             Gradient evaluations: 44
# 2005-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8334897516685678e-05
#             Iterations: 230
#             Function evaluations: 24610
#             Gradient evaluations: 230
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.839200339939595
#             Iterations: 48
#             Function evaluations: 5182
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.592198195602443e-09
#             Iterations: 27
#             Function evaluations: 2890
#             Gradient evaluations: 27
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8337321799939524e-05
#             Iterations: 227
#             Function evaluations: 24516
#             Gradient evaluations: 227
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7899543314121242
#             Iterations: 51
#             Function evaluations: 5559
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.025155853880061e-09
#             Iterations: 39
#             Function evaluations: 4212
#             Gradient evaluations: 39
# 2006-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7993109900283175e-05
#             Iterations: 214
#             Function evaluations: 23112
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7939340383614675
#             Iterations: 51
#             Function evaluations: 5557
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3013587429780874e-09
#             Iterations: 39
#             Function evaluations: 4212
#             Gradient evaluations: 39
# 2006-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6515133981481522e-05
#             Iterations: 221
#             Function evaluations: 25415
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7938054987773753
#             Iterations: 53
#             Function evaluations: 6148
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8595939010982921e-09
#             Iterations: 38
#             Function evaluations: 4370
#             Gradient evaluations: 38
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.838288007469662e-05
#             Iterations: 229
#             Function evaluations: 26335
#             Gradient evaluations: 229
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.704751529389057
#             Iterations: 49
#             Function evaluations: 5684
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7739969313282592e-09
#             Iterations: 39
#             Function evaluations: 4485
#             Gradient evaluations: 39
# 2006-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0514489176572222e-05
#             Iterations: 236
#             Function evaluations: 27140
#             Gradient evaluations: 236
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.584790652149451
#             Iterations: 42
#             Function evaluations: 4872
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7524864435254192e-09
#             Iterations: 36
#             Function evaluations: 4140
#             Gradient evaluations: 36
# 2006-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9756608048712643e-05
#             Iterations: 250
#             Function evaluations: 28751
#             Gradient evaluations: 250
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.649068280830438
#             Iterations: 54
#             Function evaluations: 6262
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7226597605907539e-09
#             Iterations: 38
#             Function evaluations: 4370
#             Gradient evaluations: 38
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8380115610120903e-05
#             Iterations: 233
#             Function evaluations: 26796
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.691647965059688
#             Iterations: 50
#             Function evaluations: 5801
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6113527269492173e-09
#             Iterations: 39
#             Function evaluations: 4485
#             Gradient evaluations: 39
# 2006-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8793787664926943e-05
#             Iterations: 254
#             Function evaluations: 29210
#             Gradient evaluations: 254
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.715673076932975
#             Iterations: 57
#             Function evaluations: 6611
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.852315334815508e-09
#             Iterations: 29
#             Function evaluations: 3335
#             Gradient evaluations: 29
# 2006-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0757678537808397e-05
#             Iterations: 233
#             Function evaluations: 26796
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.69147253053748
#             Iterations: 46
#             Function evaluations: 5335
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3028173074704255e-09
#             Iterations: 21
#             Function evaluations: 2415
#             Gradient evaluations: 21
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.852270449978928e-05
#             Iterations: 194
#             Function evaluations: 22311
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.50634074031898
#             Iterations: 38
#             Function evaluations: 4406
#             Gradient evaluations: 38
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.895973924726424e-09
#             Iterations: 32
#             Function evaluations: 3680
#             Gradient evaluations: 32
# 2006-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.087900025780327e-05
#             Iterations: 190
#             Function evaluations: 21850
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.424314813308793
#             Iterations: 35
#             Function evaluations: 4056
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7724430688913825e-09
#             Iterations: 32
#             Function evaluations: 3680
#             Gradient evaluations: 32
# 2006-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.228276036941618e-05
#             Iterations: 210
#             Function evaluations: 24150
#             Gradient evaluations: 210
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3838045725221217
#             Iterations: 32
#             Function evaluations: 3711
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.85207698602949e-09
#             Iterations: 16
#             Function evaluations: 1841
#             Gradient evaluations: 16
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.683575435018027e-05
#             Iterations: 207
#             Function evaluations: 23806
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2653221783985
#             Iterations: 29
#             Function evaluations: 3363
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.637061308847825e-09
#             Iterations: 31
#             Function evaluations: 3565
#             Gradient evaluations: 31
# 2007-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8502388818961286e-05
#             Iterations: 207
#             Function evaluations: 23805
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.234737929900673
#             Iterations: 30
#             Function evaluations: 3479
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.88289106236741e-09
#             Iterations: 42
#             Function evaluations: 4830
#             Gradient evaluations: 42
# 2007-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.516095601341139e-05
#             Iterations: 181
#             Function evaluations: 22083
#             Gradient evaluations: 181
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2094705581305796
#             Iterations: 31
#             Function evaluations: 3810
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6055869401389573e-09
#             Iterations: 42
#             Function evaluations: 5124
#             Gradient evaluations: 42
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.789668140081211e-05
#             Iterations: 170
#             Function evaluations: 20740
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1846851284421693
#             Iterations: 29
#             Function evaluations: 3562
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.730545300912887e-09
#             Iterations: 41
#             Function evaluations: 5002
#             Gradient evaluations: 41
# 2007-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.0230826447712266e-05
#             Iterations: 184
#             Function evaluations: 22448
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.355934151319096
#             Iterations: 28
#             Function evaluations: 3444
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.200579439139574e-10
#             Iterations: 52
#             Function evaluations: 6344
#             Gradient evaluations: 52
# 2007-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.192373147336126e-05
#             Iterations: 192
#             Function evaluations: 23424
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3264559143378
#             Iterations: 25
#             Function evaluations: 3076
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.112399776007497e-10
#             Iterations: 52
#             Function evaluations: 6344
#             Gradient evaluations: 52
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.4206738154006597e-05
#             Iterations: 164
#             Function evaluations: 20009
#             Gradient evaluations: 164
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.326443136789398
#             Iterations: 28
#             Function evaluations: 3442
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.029154585725517e-09
#             Iterations: 51
#             Function evaluations: 6223
#             Gradient evaluations: 51
# 2007-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.8476363060463746e-05
#             Iterations: 162
#             Function evaluations: 19764
#             Gradient evaluations: 162
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3028576860097836
#             Iterations: 29
#             Function evaluations: 3566
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.03996591974305e-09
#             Iterations: 51
#             Function evaluations: 6222
#             Gradient evaluations: 51
# 2007-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.779139414738037e-05
#             Iterations: 179
#             Function evaluations: 21838
#             Gradient evaluations: 179
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4130606393465626
#             Iterations: 28
#             Function evaluations: 3446
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.045366249579281e-10
#             Iterations: 71
#             Function evaluations: 8663
#             Gradient evaluations: 71
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.300727254198547e-05
#             Iterations: 181
#             Function evaluations: 22082
#             Gradient evaluations: 181
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5081480587168734
#             Iterations: 31
#             Function evaluations: 3814
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7119215305395108e-09
#             Iterations: 83
#             Function evaluations: 10126
#             Gradient evaluations: 83
# 2007-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.146718288936686e-05
#             Iterations: 184
#             Function evaluations: 22448
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4244055502721005
#             Iterations: 34
#             Function evaluations: 4178
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.374384912600012e-10
#             Iterations: 146
#             Function evaluations: 17812
#             Gradient evaluations: 146
# 2007-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015173658387059225
#             Iterations: 145
#             Function evaluations: 17835
#             Gradient evaluations: 145
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9603241813955523
#             Iterations: 23
#             Function evaluations: 2850
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.336796038436606e-10
#             Iterations: 83
#             Function evaluations: 10209
#             Gradient evaluations: 83
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001895709039183685
#             Iterations: 129
#             Function evaluations: 15867
#             Gradient evaluations: 129
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8734134935648066
#             Iterations: 24
#             Function evaluations: 2969
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.679261598880518e-10
#             Iterations: 88
#             Function evaluations: 10824
#             Gradient evaluations: 88
# 2008-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00020943669747698862
#             Iterations: 124
#             Function evaluations: 15252
#             Gradient evaluations: 124
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8402757327113426
#             Iterations: 21
#             Function evaluations: 2601
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9893975112837078e-10
#             Iterations: 95
#             Function evaluations: 11685
#             Gradient evaluations: 95
# 2008-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002092659700564848
#             Iterations: 125
#             Function evaluations: 16001
#             Gradient evaluations: 125
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8394825634496925
#             Iterations: 23
#             Function evaluations: 2965
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6093170897997734e-10
#             Iterations: 93
#             Function evaluations: 11905
#             Gradient evaluations: 93
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002184410224442841
#             Iterations: 122
#             Function evaluations: 15616
#             Gradient evaluations: 122
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8553489718984497
#             Iterations: 24
#             Function evaluations: 3089
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2015691433193783e-10
#             Iterations: 93
#             Function evaluations: 11905
#             Gradient evaluations: 93
# 2008-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00023536414109377653
#             Iterations: 92
#             Function evaluations: 11776
#             Gradient evaluations: 92
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7460504067139848
#             Iterations: 23
#             Function evaluations: 2957
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6899554835409658e-10
#             Iterations: 100
#             Function evaluations: 12800
#             Gradient evaluations: 100
# 2008-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00023711674922819223
#             Iterations: 107
#             Function evaluations: 13696
#             Gradient evaluations: 107
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7586626159884078
#             Iterations: 22
#             Function evaluations: 2831
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9135436324550833e-10
#             Iterations: 99
#             Function evaluations: 12673
#             Gradient evaluations: 99
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00023670979153290507
#             Iterations: 97
#             Function evaluations: 12416
#             Gradient evaluations: 97
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.75749855274368
#             Iterations: 21
#             Function evaluations: 2703
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0614602439938533e-10
#             Iterations: 99
#             Function evaluations: 12673
#             Gradient evaluations: 99
# 2008-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.000233094752151223
#             Iterations: 95
#             Function evaluations: 12160
#             Gradient evaluations: 95
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7514355024500927
#             Iterations: 26
#             Function evaluations: 3340
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3943592277915643e-10
#             Iterations: 99
#             Function evaluations: 12673
#             Gradient evaluations: 99
# 2008-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00023355383184768086
#             Iterations: 95
#             Function evaluations: 12160
#             Gradient evaluations: 95
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7450937251447167
#             Iterations: 22
#             Function evaluations: 2827
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1442195501812068e-10
#             Iterations: 99
#             Function evaluations: 12673
#             Gradient evaluations: 99
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002260579629921432
#             Iterations: 107
#             Function evaluations: 13696
#             Gradient evaluations: 107
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.74759882008148
#             Iterations: 20
#             Function evaluations: 2573
#             Gradient evaluations: 20
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4107478509630217e-10
#             Iterations: 99
#             Function evaluations: 12673
#             Gradient evaluations: 99
# 2008-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021540559378882145
#             Iterations: 91
#             Function evaluations: 11648
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.749403485026219
#             Iterations: 23
#             Function evaluations: 2957
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5848295365099848e-10
#             Iterations: 100
#             Function evaluations: 12800
#             Gradient evaluations: 100
# 2008-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00012387637638940476
#             Iterations: 129
#             Function evaluations: 16512
#             Gradient evaluations: 129
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9073872748970404
#             Iterations: 28
#             Function evaluations: 3600
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4685750477342294e-10
#             Iterations: 121
#             Function evaluations: 15489
#             Gradient evaluations: 121
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.383859650079348e-05
#             Iterations: 122
#             Function evaluations: 15616
#             Gradient evaluations: 122
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.15495864787664
#             Iterations: 25
#             Function evaluations: 3226
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.746976709668843e-10
#             Iterations: 152
#             Function evaluations: 19456
#             Gradient evaluations: 152
# 2009-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.639369596324698e-05
#             Iterations: 142
#             Function evaluations: 18176
#             Gradient evaluations: 142
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.249552321595582
#             Iterations: 30
#             Function evaluations: 3865
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.010081883680559e-10
#             Iterations: 145
#             Function evaluations: 18560
#             Gradient evaluations: 145
# 2009-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.32379714296482e-05
#             Iterations: 138
#             Function evaluations: 19872
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.258299545055541
#             Iterations: 28
#             Function evaluations: 4061
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3856272346962004e-10
#             Iterations: 115
#             Function evaluations: 16561
#             Gradient evaluations: 115
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.2560609225390674e-05
#             Iterations: 149
#             Function evaluations: 21456
#             Gradient evaluations: 149
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2903939590034503
#             Iterations: 33
#             Function evaluations: 4786
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.703321201350147e-10
#             Iterations: 116
#             Function evaluations: 16704
#             Gradient evaluations: 116
# 2009-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.60846435032455e-05
#             Iterations: 186
#             Function evaluations: 26784
#             Gradient evaluations: 186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4744668014602187
#             Iterations: 39
#             Function evaluations: 5656
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.48587138147597e-09
#             Iterations: 90
#             Function evaluations: 12960
#             Gradient evaluations: 90
# 2009-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.4156017598160406e-05
#             Iterations: 225
#             Function evaluations: 32400
#             Gradient evaluations: 225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4319128190736414
#             Iterations: 42
#             Function evaluations: 5947
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3394122649060617e-09
#             Iterations: 69
#             Function evaluations: 9937
#             Gradient evaluations: 69
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.812893071175514e-05
#             Iterations: 188
#             Function evaluations: 27072
#             Gradient evaluations: 188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.296501770801132
#             Iterations: 32
#             Function evaluations: 4636
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3815009421521609e-09
#             Iterations: 61
#             Function evaluations: 8784
#             Gradient evaluations: 61
# 2009-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.871316388514282e-05
#             Iterations: 180
#             Function evaluations: 25921
#             Gradient evaluations: 180
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.202820428381147
#             Iterations: 30
#             Function evaluations: 4348
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1300236268714454e-09
#             Iterations: 62
#             Function evaluations: 8928
#             Gradient evaluations: 62
# 2009-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.959486783546945e-05
#             Iterations: 170
#             Function evaluations: 24481
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.198358752141978
#             Iterations: 26
#             Function evaluations: 3771
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.991320645731453e-10
#             Iterations: 63
#             Function evaluations: 9072
#             Gradient evaluations: 63
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.122109003264287e-05
#             Iterations: 179
#             Function evaluations: 25776
#             Gradient evaluations: 179
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1047508958525434
#             Iterations: 25
#             Function evaluations: 3622
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2249629118659712e-09
#             Iterations: 52
#             Function evaluations: 7489
#             Gradient evaluations: 52
# 2009-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.185595937142036e-05
#             Iterations: 184
#             Function evaluations: 26496
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.059702754468268
#             Iterations: 24
#             Function evaluations: 3477
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1552870267109854e-09
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2009-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.993920831027929e-05
#             Iterations: 182
#             Function evaluations: 26208
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.045681290536551
#             Iterations: 24
#             Function evaluations: 3481
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.450132080297667e-10
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.780915028725172e-05
#             Iterations: 169
#             Function evaluations: 24337
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0136513704791446
#             Iterations: 29
#             Function evaluations: 4201
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.955344442968485e-10
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2010-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.662146859952268e-05
#             Iterations: 173
#             Function evaluations: 24912
#             Gradient evaluations: 173
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.049904498875511
#             Iterations: 25
#             Function evaluations: 3622
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1137236479977635e-09
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2010-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5399260214431746e-05
#             Iterations: 197
#             Function evaluations: 28368
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0704314337455925
#             Iterations: 27
#             Function evaluations: 3912
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0140594500994953e-09
#             Iterations: 53
#             Function evaluations: 7632
#             Gradient evaluations: 53
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.485422215256716e-05
#             Iterations: 174
#             Function evaluations: 25056
#             Gradient evaluations: 174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.111806251869544
#             Iterations: 28
#             Function evaluations: 4056
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0879809316420642e-09
#             Iterations: 53
#             Function evaluations: 7632
#             Gradient evaluations: 53
# 2010-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.618031184369048e-05
#             Iterations: 178
#             Function evaluations: 25632
#             Gradient evaluations: 178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0975534004382212
#             Iterations: 26
#             Function evaluations: 3768
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0291317789845785e-09
#             Iterations: 53
#             Function evaluations: 7632
#             Gradient evaluations: 53
# 2010-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.677226083689601e-05
#             Iterations: 160
#             Function evaluations: 23040
#             Gradient evaluations: 160
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.121716579641597
#             Iterations: 24
#             Function evaluations: 3479
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.570337635299973e-10
#             Iterations: 53
#             Function evaluations: 7632
#             Gradient evaluations: 53
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.018823450640322e-05
#             Iterations: 217
#             Function evaluations: 31248
#             Gradient evaluations: 217
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3248919535790096
#             Iterations: 28
#             Function evaluations: 4058
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9310371980799106e-09
#             Iterations: 42
#             Function evaluations: 6048
#             Gradient evaluations: 42
# 2010-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6203053388617023e-05
#             Iterations: 239
#             Function evaluations: 34416
#             Gradient evaluations: 239
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4053652396003553
#             Iterations: 31
#             Function evaluations: 4495
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4802480651800711e-09
#             Iterations: 42
#             Function evaluations: 6049
#             Gradient evaluations: 42
# 2010-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.375809786515107e-05
#             Iterations: 219
#             Function evaluations: 31537
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3706304543874994
#             Iterations: 34
#             Function evaluations: 4928
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9226745345174443e-09
#             Iterations: 39
#             Function evaluations: 5616
#             Gradient evaluations: 39
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.970020201576523e-05
#             Iterations: 174
#             Function evaluations: 25056
#             Gradient evaluations: 174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9571326571129093
#             Iterations: 26
#             Function evaluations: 3767
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0995999844675315e-09
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2010-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.327855525519107e-05
#             Iterations: 175
#             Function evaluations: 25200
#             Gradient evaluations: 175
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.887134833723005
#             Iterations: 26
#             Function evaluations: 3764
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1058680928253828e-09
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2010-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.672805276757691e-05
#             Iterations: 177
#             Function evaluations: 25488
#             Gradient evaluations: 177
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8402523543485303
#             Iterations: 23
#             Function evaluations: 3331
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.88044823407325e-10
#             Iterations: 62
#             Function evaluations: 8928
#             Gradient evaluations: 62
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.2974485566161855e-05
#             Iterations: 171
#             Function evaluations: 24625
#             Gradient evaluations: 171
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.783620874520706
#             Iterations: 21
#             Function evaluations: 3040
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0374807606054851e-09
#             Iterations: 60
#             Function evaluations: 8641
#             Gradient evaluations: 60
# 2011-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.692979659005e-05
#             Iterations: 181
#             Function evaluations: 26065
#             Gradient evaluations: 181
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.824333183363831
#             Iterations: 25
#             Function evaluations: 3618
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.814390615751817e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.704541868299495e-05
#             Iterations: 197
#             Function evaluations: 28368
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8279382921733296
#             Iterations: 23
#             Function evaluations: 3329
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.407349420137966e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.601194779314876e-05
#             Iterations: 192
#             Function evaluations: 27648
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.825847828291212
#             Iterations: 23
#             Function evaluations: 3327
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.615638315641904e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.423098347549666e-05
#             Iterations: 177
#             Function evaluations: 25488
#             Gradient evaluations: 177
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.830141296454116
#             Iterations: 24
#             Function evaluations: 3472
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.2903035691656e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.508196004287893e-05
#             Iterations: 202
#             Function evaluations: 29089
#             Gradient evaluations: 202
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8219134240590866
#             Iterations: 24
#             Function evaluations: 3475
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.004753120264996e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# ...
#             Current function value: 6.103646723084271e-05
#             Iterations: 215
#             Function evaluations: 45581
#             Gradient evaluations: 215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2312480590581742
#             Iterations: 32
#             Function evaluations: 6812
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4248927785287336e-09
#             Iterations: 46
#             Function evaluations: 9752
#             Gradient evaluations: 46
# 2022-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.5077994635306065e-05
#             Iterations: 224
#             Function evaluations: 47488
#             Gradient evaluations: 224
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2747551953428418
#             Iterations: 38
#             Function evaluations: 8093
#             Gradient evaluations: 38
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2206818513862108e-09
#             Iterations: 34
#             Function evaluations: 7209
#             Gradient evaluations: 34
# 2022-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.3513934366298174e-05
#             Iterations: 211
#             Function evaluations: 44733
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2971233307927226
#             Iterations: 35
#             Function evaluations: 7455
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.648436150946815e-10
#             Iterations: 51
#             Function evaluations: 10812
#             Gradient evaluations: 51
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.053159860724051e-05
#             Iterations: 199
#             Function evaluations: 42189
#             Gradient evaluations: 199
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3723166269384297
#             Iterations: 39
#             Function evaluations: 8306
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5583596013553187e-09
#             Iterations: 41
#             Function evaluations: 8692
#             Gradient evaluations: 41
# 2022-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.1530801087756864e-05
#             Iterations: 235
#             Function evaluations: 49821
#             Gradient evaluations: 235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5171860297929998
#             Iterations: 48
#             Function evaluations: 10224
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9850157944116254e-09
#             Iterations: 40
#             Function evaluations: 8480
#             Gradient evaluations: 40
# 2022-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.253780210348761e-05
#             Iterations: 247
#             Function evaluations: 52364
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7213618699787974
#             Iterations: 49
#             Function evaluations: 10436
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0181479476007934e-09
#             Iterations: 38
#             Function evaluations: 8056
#             Gradient evaluations: 38
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9970406724244605e-05
#             Iterations: 252
#             Function evaluations: 53425
#             Gradient evaluations: 252
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8549916478006305
#             Iterations: 43
#             Function evaluations: 9156
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8931966784702504e-09
#             Iterations: 39
#             Function evaluations: 8268
#             Gradient evaluations: 39
# 2023-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7944811530893703e-05
#             Iterations: 210
#             Function evaluations: 44520
#             Gradient evaluations: 210
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9717881292369026
#             Iterations: 50
#             Function evaluations: 10649
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.135375395683364e-09
#             Iterations: 39
#             Function evaluations: 8268
#             Gradient evaluations: 39
# 2023-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4091314226016995e-05
#             Iterations: 290
#             Function evaluations: 61481
#             Gradient evaluations: 290
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.144924876518036
#             Iterations: 65
#             Function evaluations: 13004
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9934411844967873e-09
#             Iterations: 39
#             Function evaluations: 8268
#             Gradient evaluations: 39
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3004510126713202e-05
#             Iterations: 272
#             Function evaluations: 57665
#             Gradient evaluations: 272
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.2218014760143836
#             Iterations: 62
#             Function evaluations: 12352
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2751997826317685e-09
#             Iterations: 39
#             Function evaluations: 8269
#             Gradient evaluations: 39
# 2023-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9731336145861103e-05
#             Iterations: 262
#             Function evaluations: 55545
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4480185305550703
#             Iterations: 70
#             Function evaluations: 14905
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9414754177299603e-09
#             Iterations: 40
#             Function evaluations: 8480
#             Gradient evaluations: 40
# 2023-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9794687035388484e-05
#             Iterations: 278
#             Function evaluations: 58936
#             Gradient evaluations: 278
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4883445869662824
#             Iterations: 63
#             Function evaluations: 13206
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.621375055135365e-09
#             Iterations: 28
#             Function evaluations: 5937
#             Gradient evaluations: 28
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9517729868022722e-05
#             Iterations: 259
#             Function evaluations: 54908
#             Gradient evaluations: 259
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5118894971701065
#             Iterations: 64
#             Function evaluations: 13626
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.265924369687264e-09
#             Iterations: 27
#             Function evaluations: 5724
#             Gradient evaluations: 27
# 2023-07-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7982574262665806e-05
#             Iterations: 255
#             Function evaluations: 54061
#             Gradient evaluations: 255
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.669481561086758
#             Iterations: 68
#             Function evaluations: 14479
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.949111845387102e-09
#             Iterations: 27
#             Function evaluations: 5724
#             Gradient evaluations: 27
# 2023-08-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7977067478938108e-05
#             Iterations: 265
#             Function evaluations: 56181
#             Gradient evaluations: 265
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6698895232094957
#             Iterations: 78
#             Function evaluations: 15791
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.936009380890493e-09
#             Iterations: 28
#             Function evaluations: 5936
#             Gradient evaluations: 28
# 2023-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8623254022441985e-05
#             Iterations: 243
#             Function evaluations: 51517
#             Gradient evaluations: 243
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6846610806950753
#             Iterations: 72
#             Function evaluations: 14482
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.389947684316733e-09
#             Iterations: 27
#             Function evaluations: 5725
#             Gradient evaluations: 27
# 2023-10-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9139833717955602e-05
#             Iterations: 247
#             Function evaluations: 52365
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7108906882285733
#             Iterations: 66
#             Function evaluations: 14052
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.5870100607741655e-09
#             Iterations: 27
#             Function evaluations: 5725
#             Gradient evaluations: 27
# 2023-11-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7185927769462298e-05
#             Iterations: 284
#             Function evaluations: 60208
#             Gradient evaluations: 284
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8286835581717202
#             Iterations: 67
#             Function evaluations: 14268
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.354149276353606e-09
#             Iterations: 28
#             Function evaluations: 5936
#             Gradient evaluations: 28
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7007507461161723e-05
#             Iterations: 259
#             Function evaluations: 54909
#             Gradient evaluations: 259
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.837883415102487
#             Iterations: 72
#             Function evaluations: 15335
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2787455436146e-09
#             Iterations: 28
#             Function evaluations: 5936
#             Gradient evaluations: 28
# 2024-01-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.724010924601169e-05
#             Iterations: 261
#             Function evaluations: 55332
#             Gradient evaluations: 261
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8174437660529437
#             Iterations: 82
#             Function evaluations: 17254
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.726270150576439e-09
#             Iterations: 28
#             Function evaluations: 5936
#             Gradient evaluations: 28
# 2024-02-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7898534701724917e-05
#             Iterations: 266
#             Function evaluations: 57722
#             Gradient evaluations: 266
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.832189493924616
#             Iterations: 78
#             Function evaluations: 16130
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3708905614834437e-09
#             Iterations: 28
#             Function evaluations: 6076
#             Gradient evaluations: 28
# 2024-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.791203966404536e-05
#             Iterations: 251
#             Function evaluations: 54467
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.897632227900305
#             Iterations: 84
#             Function evaluations: 17442
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.503445654721651e-09
#             Iterations: 15
#             Function evaluations: 3255
#             Gradient evaluations: 15
# 2024-04-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9650457747606546e-05
#             Iterations: 289
#             Function evaluations: 62714
#             Gradient evaluations: 289
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7846756337399325
#             Iterations: 75
#             Function evaluations: 15476
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.091318637207342e-09
#             Iterations: 20
#             Function evaluations: 4340
#             Gradient evaluations: 20
# 2024-05-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.303702751316044e-05
#             Iterations: 231
#             Function evaluations: 50359
#             Gradient evaluations: 231
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.137882264778219
#             Iterations: 51
#             Function evaluations: 11168
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.4213396692349287e-09
#             Iterations: 39
#             Function evaluations: 8502
#             Gradient evaluations: 39
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_reduziert_shrinked.to_csv("returnsreduziertshrinked_neu_f.csv")
