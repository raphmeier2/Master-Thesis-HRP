# %% [markdown]
# Hier werden die Portfolio-Methoden angewandt und mithilfe der Performance-Metriken bewertet. Die Ergebnisse werden in CSV-Dateien festgehalten. Das Akquirieren, modifizieren und beschreiben der Daten befindet sich der Übersicht halber im Notebook Datenbasis. Die Daten werden dort als CSV exportiert und hier als Dataframe wieder eingelesen.
#
# Die Korrektheit der implementierten Methoden und Metriken wird in dem separaten Notebook Verifizierung anhand eines kleinen Teilbestandes aufgezeigt, siehe dazu auch beigefügte Excel-Dateien, in denen die Portfolio-Gewichte "per Hand" nachgerechnet und mit den Ergebnissen aus der Python-Implementierung abgeglichen werden.
#
# ACHTUNG: LANGE LAUFZEIT!

# %% [markdown]
# ## Importe

# %%
#Import der notwendigen Bibliotheken, Installation mit pip bereits erfolgt

import yfinance as yf
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import csv
from scipy.optimize import minimize
import math
import random
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import linkage, dendrogram
import riskfolio as rp
from sklearn.covariance import LedoitWolf
from scipy.spatial.distance import squareform
from riskfolio import HCPortfolio as hc
from pandas.tseries.offsets import MonthBegin
from pandas.tseries.offsets import MonthEnd

# %% [markdown]
# ## Einlesen der Daten

# %%
#Bearbeitete JSE-Daten (Gesamtbestand)

df_JSE = pd.read_csv(
    'df_JSE_Final_V7.csv',
    sep=',',
    encoding='utf-8',
    index_col=0,
    decimal = '.',
    low_memory=False,
    parse_dates=['Date'],
    dayfirst=True
)

# %%
df_JSE.info
# Out:
# <bound method DataFrame.info of             4SI.JO   ABG.JO  ACL.JO  ACT.JO       ADH.JO  AEL.JO  \
# Date
# 2005-06-01     NaN   8240.0  4980.0   130.0   133.701508     NaN
# 2005-06-02     NaN   8250.0  4949.0   130.0   131.749695     NaN
# 2005-06-03     NaN   8261.0  4949.0   130.0   131.749695     NaN
# 2005-06-06     NaN   8290.0  5023.0   130.0   132.725601     NaN
# 2005-06-07     NaN   8345.0  4845.0   149.0   131.749695     NaN
# ...            ...      ...     ...     ...          ...     ...
# 2025-05-26    70.0  16845.0   109.0   160.0  3199.000000  2350.0
# 2025-05-27    70.0  16848.0   105.0   160.0  3210.000000  2350.0
# 2025-05-28    73.0  17300.0   101.0   174.0  3283.000000  2355.0
# 2025-05-29    70.0  17579.0   106.0   166.0  3247.000000  2362.0
# 2025-05-30    70.0  17332.0   116.0   160.0  3215.000000  2358.0
#
#                   AFE.JO  AFH.JO  AFT.JO        AGL.JO  ...  VKE.JO   VOD.JO  \
# Date                                                    ...
# 2005-06-01   4338.178711     NaN     NaN  21158.730469  ...     NaN  11100.0
# 2005-06-02   4427.728516     NaN     NaN  21274.703125  ...     NaN  11290.0
# 2005-06-03   4427.728516     NaN     NaN  21274.703125  ...     NaN  11290.0
# 2005-06-06   4427.728516     NaN     NaN  20868.796875  ...     NaN  11802.0
# 2005-06-07   4428.723633     NaN     NaN  20430.673828  ...     NaN  11800.0
# ...                  ...     ...     ...           ...  ...     ...      ...
# 2025-05-26  10342.000000   920.0  5057.0  53638.527344  ...  1900.0  13465.0
# 2025-05-27  10417.000000   896.0  5191.0  52658.546875  ...  1912.0  13505.0
# 2025-05-28  10444.000000   912.0  5191.0  52193.621094  ...  1914.0  13420.0
# 2025-05-29  10326.000000   900.0  5147.0  51899.722656  ...  1941.0  13849.0
# 2025-05-30  10335.000000   890.0  5200.0  52778.464844  ...  2001.0  13777.0
#
#             WBC.JO   WBO.JO  WEZ.JO       WHL.JO      YRK.JO  YYLBEE.JO  \
# Date
# 2005-06-01     NaN   2650.0     NaN   961.656494  736.937988        NaN
# 2005-06-02     NaN   2675.0     NaN   971.177917  736.937988        NaN
# 2005-06-03     NaN   2675.0     NaN   971.177917  736.937988        NaN
# 2005-06-06     NaN   2700.0     NaN   996.885498  736.937988        NaN
# 2005-06-07     NaN   2700.0     NaN  1009.263306  736.937988        NaN
# ...            ...      ...     ...          ...         ...        ...
# 2025-05-26  4800.0  18172.0    50.0  5730.000000  204.000000     2701.0
# 2025-05-27  4875.0  18317.0    45.0  5680.000000  204.000000     2701.0
# 2025-05-28  4822.0  17983.0    44.0  5765.000000  187.000000     2701.0
# 2025-05-29  4889.0  17884.0    45.0  5858.000000  190.000000     2701.0
# 2025-05-30  4900.0  18152.0    43.0  5860.000000  195.000000     2701.0
#
#             ZED.JO  ZZD.JO
# Date
# 2005-06-01     NaN     NaN
# 2005-06-02     NaN     NaN
# 2005-06-03     NaN     NaN
# 2005-06-06     NaN     NaN
# 2005-06-07     NaN     NaN
# ...            ...     ...
# 2025-05-26   120.0  1157.0
# 2025-05-27   118.0  1200.0
# 2025-05-28   125.0  1210.0
# 2025-05-29   126.0  1200.0
# 2025-05-30   129.0  1185.0
#
# [5171 rows x 217 columns]>

# %%
#Bearbeitete SP500-Daten (Gesamtbestand)

df_SP500 = pd.read_csv(
    'df_SP500_Final_V7.csv',
    sep=',',
    encoding='utf-8',
    index_col=0,
    decimal = '.',
    low_memory=False,
    parse_dates=['Date'],
    dayfirst=True
)

# %%
df_SP500.info
# Out:
# <bound method DataFrame.info of                      A  AAL  AAP        AAPL        ABBV        ABNB  \
# Date
# 2005-06-01   17.296137  NaN  NaN    1.439286         NaN         NaN
# 2005-06-02   17.303289  NaN  NaN    1.430000         NaN         NaN
# 2005-06-03   17.210300  NaN  NaN    1.365714         NaN         NaN
# 2005-06-06   17.539343  NaN  NaN    1.354286         NaN         NaN
# 2005-06-07   17.324751  NaN  NaN    1.305000         NaN         NaN
# ...                ...  ...  ...         ...         ...         ...
# 2025-05-23  108.529999  NaN  NaN  195.270004  183.259995  126.720001
# 2025-05-27  111.260002  NaN  NaN  200.210007  185.720001  129.399994
# 2025-05-28  110.879997  NaN  NaN  200.419998  183.089996  128.669998
# 2025-05-29  113.279999  NaN  NaN  199.949997  185.619995  128.360001
# 2025-05-30  111.919998  NaN  NaN  200.850006  186.110001  129.000000
#
#                    ABT       ACGL         ACN        ADBE  ...        XEL  \
# Date                                                       ...
# 2005-06-01   23.188734        NaN         NaN   33.180000  ...  18.670000
# 2005-06-02   23.155148        NaN         NaN   33.090000  ...  18.719999
# 2005-06-03   23.159946        NaN         NaN   32.540001  ...  18.809999
# 2005-06-06   23.246309        NaN         NaN   32.450001  ...  18.820000
# 2005-06-07   23.395048        NaN         NaN   32.259998  ...  18.900000
# ...                ...        ...         ...         ...  ...        ...
# 2025-05-23  131.300003  92.070000  309.579987  407.690002  ...  69.730003
# 2025-05-27  132.940002  94.620003  315.429993  413.100006  ...  69.809998
# 2025-05-28  132.020004  92.980003  315.989990  412.230011  ...  68.930000
# 2025-05-29  132.850006  94.199997  317.730011  413.359985  ...  69.470001
# 2025-05-30  133.580002  95.040001  316.820007  415.089996  ...  70.099998
#
#                    XOM  XRAY        XRX         XYL         YUM        ZBH  \
# Date
# 2005-06-01   57.150002   NaN  36.100132         NaN   18.508266  74.029129
# 2005-06-02   57.320000   NaN  35.968380         NaN   18.907261  74.242722
# 2005-06-03   57.150002   NaN  35.731224         NaN   18.705967  76.456314
# 2005-06-06   57.599998   NaN  35.335968         NaN   18.691589  76.067963
# 2005-06-07   57.450001   NaN  35.098812         NaN   18.749102  77.106796
# ...                ...   ...        ...         ...         ...        ...
# 2025-05-23  103.029999   NaN        NaN  124.050003  145.449997  92.639999
# 2025-05-27  103.519997   NaN        NaN  126.239998  144.089996  94.209999
# 2025-05-28  102.110001   NaN        NaN  125.650002  143.149994  92.290001
# 2025-05-29  102.690002   NaN        NaN  125.660004  144.039993  93.339996
# 2025-05-30  102.300003   NaN        NaN  126.040001  143.940002  92.169998
#
#                   ZBRA       ZION         ZTS
# Date
# 2005-06-01         NaN  72.330002         NaN
# 2005-06-02         NaN  72.760002         NaN
# 2005-06-03         NaN  72.160004         NaN
# 2005-06-06         NaN  72.150002         NaN
# 2005-06-07         NaN  71.949997         NaN
# ...                ...        ...         ...
# 2025-05-23  284.209992        NaN  162.580002
# 2025-05-27  295.010010        NaN  166.259995
# 2025-05-28  290.799988        NaN  165.399994
# 2025-05-29  292.500000        NaN  167.139999
# 2025-05-30  289.769989        NaN  168.630005
#
# [5032 rows x 598 columns]>

# %%
#Reduzierter SP500-Bestand ohne ausgeschiedene Unternehmen und auf Größe des JSE runtergebrochen

df_SP500_reduziert = pd.read_csv(
    'sp500_gefiltert_neuneu.csv',
    sep=',',
    encoding='utf-8',
    index_col=0,
    decimal = '.',
    low_memory=False,
    dayfirst=True
)

# %%
df_SP500_reduziert.info
# Out:
# <bound method DataFrame.info of                      A        AAPL         ABT         ACN         ADI  \
# Date
# 2005-06-01   17.296137    1.439286         NaN         NaN         NaN
# 2005-06-02   17.303289    1.430000         NaN         NaN         NaN
# 2005-06-03   17.210300    1.365714         NaN         NaN         NaN
# 2005-06-06   17.539343    1.354286         NaN         NaN         NaN
# 2005-06-07   17.324751    1.305000         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2025-05-23  108.529999  195.270004  131.300003  309.579987  210.470001
# 2025-05-27  111.260002  200.210007  132.940002  315.429993  216.889999
# 2025-05-28  110.879997  200.419998  132.020004  315.989990  215.619995
# 2025-05-29  113.279999  199.949997  132.850006  317.730011  215.750000
# 2025-05-30  111.919998  200.850006  133.580002  316.820007  213.979996
#
#                   ADM         ADP        ADSK    AES         AIZ  ...  \
# Date                                                              ...
# 2005-06-01        NaN         NaN         NaN  14.79         NaN  ...
# 2005-06-02        NaN         NaN         NaN  14.57         NaN  ...
# 2005-06-03        NaN         NaN         NaN  14.40         NaN  ...
# 2005-06-06        NaN         NaN         NaN  15.00         NaN  ...
# 2005-06-07        NaN         NaN         NaN  14.94         NaN  ...
# ...               ...         ...         ...    ...         ...  ...
# 2025-05-23  47.939999  321.089996  295.350006   9.99  196.520004  ...
# 2025-05-27  48.630001  325.709992  300.359985  10.07  201.000000  ...
# 2025-05-28  48.349998  324.140015  299.230011   9.70  197.940002  ...
# 2025-05-29  48.369999  324.119995  297.000000  10.05  199.960007  ...
# 2025-05-30  48.270000  325.529999  296.119995  10.09  202.979996  ...
#
#                    VLO        VRSN        VRTX         WAT        WFC  \
# Date
# 2005-06-01         NaN         NaN         NaN   39.450001  30.750000
# 2005-06-02         NaN         NaN         NaN   38.930000  30.764999
# 2005-06-03         NaN         NaN         NaN   38.400002  30.674999
# 2005-06-06         NaN         NaN         NaN   38.119999  30.719999
# 2005-06-07         NaN         NaN         NaN   38.310001  30.684999
# ...                ...         ...         ...         ...        ...
# 2025-05-23  128.550003  279.760010  436.000000  346.369995  72.830002
# 2025-05-27  130.710007  269.559998  446.000000  358.359985  73.989998
# 2025-05-28  126.930000  269.140015  445.100006  354.589996  73.730003
# 2025-05-29  129.160004  268.679993  447.089996  355.299988  74.510002
# 2025-05-30  128.970001  272.470001  442.049988  349.239990  74.779999
#
#                   WRB        XEL         YUM        ZBH         ZTS
# Date
# 2005-06-01        NaN        NaN         NaN  74.029129         NaN
# 2005-06-02        NaN        NaN         NaN  74.242722         NaN
# 2005-06-03        NaN        NaN         NaN  76.456314         NaN
# 2005-06-06        NaN        NaN         NaN  76.067963         NaN
# 2005-06-07        NaN        NaN         NaN  77.106796         NaN
# ...               ...        ...         ...        ...         ...
# 2025-05-23  73.080002  69.730003  145.449997  92.639999  162.580002
# 2025-05-27  74.199997  69.809998  144.089996  94.209999  166.259995
# 2025-05-28  73.290001  68.930000  143.149994  92.290001  165.399994
# 2025-05-29  73.959999  69.470001  144.039993  93.339996  167.139999
# 2025-05-30  74.690002  70.099998  143.940002  92.169998  168.630005
#
# [5032 rows x 217 columns]>

# %% [markdown]
# ## Definition der Methoden und Metriken

# %% [markdown]
# #### Equally-Weighted Portfolio

# %%
#Rückgabe gleicher Gewichte anhand der Anzahl der Unternehmen (Input Returns)

def equally_weighted(returns):
    anzahl_assets = returns.shape[1]

    w0 = 1/anzahl_assets
    gewichte = np.full(anzahl_assets, w0)

    return gewichte

# %% [markdown]
# #### Minimum-Variance Portfolio

# %%
#Minimum-Variance Portfolio
#Code adaptiert von https://medium.com/@BorisGerat/mean-variance-and-minimum-variance-portfolio-models-in-python-64a5c6b57b2d

def min_variance_opt(matrix):
    
    #Compute the minimum-variance portfolio weights subject to the constraints of:
    #- No short-selling (weights must be >= 0)
    #- Full investment (sum of weights must equal 1)
    
    number_of_assets = matrix.shape[0]

    # Define the objective function to minimize portfolio variance
    def objective(w):
        portfolio_variance = np.dot(w, matrix @ w)
        return portfolio_variance

    # Constraint: The sum of portfolio weights must be equal to 1
    constraints = [{'type': 'eq', 'fun': lambda w: np.sum(w) - 1}]

    # Bounds: Each weight must be between 0 and 1 (no short-selling)
    bounds = [[0, 1] for _ in range(number_of_assets)]

    # Initial guess: Equal weights for all assets
    w0 = np.ones(number_of_assets) / number_of_assets

    # Solve the optimization problem using Sequential Least Squares Quadratic Programming (SLSQP)
    res = minimize(objective, w0, method='SLSQP', bounds=bounds, constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    
    return res.x  # Return the optimal weights

# %% [markdown]
# #### Maximum Diversification Portfolio

# %%
#Code von https://thequantmba.wordpress.com/2017/06/06/max-diversification-in-python/ adaptiert

def calc_max_diversification_ratio(weights, matrix):
    
    # gewichtete Volatilität
    average_vol = np.dot(np.sqrt(np.diag(matrix)), weights.T)
    
    # portfolio volatilität
    portfolio_variance = np.dot(weights, matrix @ weights)
    portfolio_vol = np.sqrt(portfolio_variance)
    
    #Bestimmung Ratio
    diversification_ratio = average_vol/portfolio_vol
    
    # Negativer Wert für Minimierung (Maximizieren = Minimieren -)
    return -diversification_ratio

# %%
#Code von https://thequantmba.wordpress.com/2017/06/06/max-diversification-in-python/ adaptiert

def max_diversification_portfolio(matrix):
    
    anzahl_assets = matrix.shape[0]
    
    w0 = 1/anzahl_assets
    w = np.full(anzahl_assets, w0)
    
    # Constraint: The sum of portfolio weights must be equal to 1
    constraints = [{'type': 'eq', 'fun': lambda w: np.sum(w) - 1}]
    
    # Bounds: Each weight must be between 0 and 1 (no short-selling)
    bounds = [[0, 1] for _ in range(anzahl_assets)]
    
    res = minimize(calc_max_diversification_ratio, w, bounds=bounds, args=matrix, method='SLSQP', constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    return res.x

# %% [markdown]
# #### Inverse Volatility Portfolio

# %%
#Code adaptiert von https://www.kaggle.com/code/vijipai/lesson-4-traditional-portfolio-construction-method

def inverse_volatility_portfolio (matrix):
    
    standardabweichungen = np.sqrt(np.diagonal(matrix))
    invertierte_std = 1/standardabweichungen
    summe_invertierte_std = np.sum(invertierte_std)
    
    inverse_volatility_gewichte = invertierte_std / summe_invertierte_std
    
    return inverse_volatility_gewichte

# %% [markdown]
# #### Equal Risk Contribution Portfolio

# %%
#Code adaptiert von https://medium.com/@deepml1818/building-a-python-based-risk-parity-portfolio-for-trading-40441ecdd84d

def calculate_portfolio_volatility(weights, matrix):
    
    portfolio_variance = np.dot(weights, matrix @ weights)
    portfolio_volatility = np.sqrt(portfolio_variance)
    return portfolio_volatility

def calculate_risk_contribution(weights, matrix):
    portfolio_volatility = calculate_portfolio_volatility(weights, matrix)
    marginal_contribution_zaehler = np.dot(matrix, weights)
    risk_contribution = np.multiply(weights, marginal_contribution_zaehler) / portfolio_volatility
    return risk_contribution

def risk_parity_objective(weights, matrix):
    risk_contribution = calculate_risk_contribution(weights, matrix)
    target_risk = np.mean(risk_contribution)
    return np.sum((risk_contribution - target_risk) ** 2)

# %%
def get_risk_parity_weights(matrix):
    
    number_of_assets = matrix.shape[0]
    w0 = 1/number_of_assets
    initial_weights = np.full(number_of_assets, w0)
    
    constraints = ({'type': 'eq', 'fun': lambda initial_weights: np.sum(initial_weights) - 1})
    bounds = [[0, 1] for _ in range(number_of_assets)]
    
    result = minimize(risk_parity_objective, initial_weights, args=(matrix), method='SLSQP', bounds=bounds, constraints=constraints, options={'ftol': 1e-12, 'disp': True, 'maxiter': 1000})
    
    return result.x

# %% [markdown]
# #### Hierarchical Risk Parity

# %%
#Aus dem Paper von Lopez De Prado (2016)
def getIVP(cov,**kargs): # Compute the inverse-variance portfolio 
    ivp=1./np.diag(cov) 
    ivp/=ivp.sum() 
    return ivp

# %%
#------------------------------------------------------------------------------ 
def getClusterVar(cov,cItems): # Compute variance per cluster 
    cov_=cov.loc[cItems,cItems] # matrix slice 
    w_=getIVP(cov_).reshape(-1,1) 
    cVar=np.dot(np.dot(w_.T,cov_),w_)[0,0] 
    return cVar

# %%
#------------------------------------------------------------------------------ 
def getQuasiDiag(link): # Sort clustered items by distance 
    link=link.astype(int) 
    sortIx=pd.Series([link[-1,0],link[-1,1]]) 
    numItems=link[-1,3] # number of original items 
    while sortIx.max()>=numItems: 
        sortIx.index=range(0,sortIx.shape[0]*2,2) # make space 
        df0=sortIx[sortIx>=numItems] # find clusters
        i=df0.index;j=df0.values-numItems 
        sortIx[i]=link[j,0] # item 1 
        df0=pd.Series(link[j,1],index=i+1) 
        sortIx = pd.concat([sortIx, df0]) # item 2  ####Anpassung wegen neuer Pandas-Version!
        sortIx=sortIx.sort_index() # re-sort 
        sortIx.index=range(sortIx.shape[0]) # re-index 
    return sortIx.tolist()

# %%
#------------------------------------------------------------------------------ 
def getRecBipart(cov,sortIx): # Compute HRP allocation
    w = pd.Series(1,index=sortIx) 
    cItems=[sortIx] # initialize all items in one cluster 
    while len(cItems)>0: 
        #Bi-Section der Cluster
        cItems = [i[j:k] 
                  for i in cItems 
                  for j, k in ((0, len(i)//2), (len(i)//2, len(i))) 
                  if len(i) > 1]
        for i in range(0, len(cItems), 2): # parse in pairs 
            cItems0=cItems[i] # cluster 1 
            cItems1=cItems[i+1] # cluster 2 
            cVar0=getClusterVar(cov,cItems0) 
            cVar1=getClusterVar(cov,cItems1) 
            alpha=1-cVar0/(cVar0+cVar1) 
            w[cItems0]*=alpha # weight 1 
            w[cItems1]*=1-alpha # weight 2 
    return w

# %%
#------------------------------------------------------------------------------ 
def correlDist(corr): 
    # A distance matrix based on correlation, where 0<=d[i,j]<=1 
    # This is a proper distance metric 
    dist=((1-corr)/2.)**.5 # distance matrix 
    
    #Adjustierung zur condensed_distance_matrix
    condensed_distance_matrix = squareform(X=dist, checks=False)
    
    return condensed_distance_matrix

# %%
def hrp_main(corr, cov, returns): 
    
    #3) cluster 
    dist=correlDist(corr) 
    link=sch.linkage(dist,'single') 
    sortIx=getQuasiDiag(link) 
    sortIx=corr.index[sortIx].tolist() # recover labels 
    df0=corr.loc[sortIx,sortIx] # reorder 
    
    #4) Capital allocation 
    hrp=getRecBipart(cov,sortIx) 
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    hrp_sortiert = hrp.reindex(original_reihenfolge)
    
    array = hrp_sortiert.T.values

    return array

# %% [markdown]
# #### Hierarchical Equal Risk Contribution Portfolio

# %%
#Es wird auf die Implementierung der Riskfolio-Lib zurückgegriffen
#Code adaptiert von #Code adaptiert von https://medium.com/@orenji.eirl/hierarchical-equal-risk-contribution-with-python-and-riskfolio-lib-ec45dd0f9899

def herc (returns):

    # Building the portfolio object
    port = hc(returns=returns)

    # Estimate optimal portfolio:

    model='HERC'
    correlation = 'pearson'
    rm = 'MV'
    rf = 0 
    linkage = 'ward' 
    max_k = 10 
    leaf_order = True 

    gewichte = port.optimization(model=model,
                          correlation=correlation,
                          rm=rm,
                          rf=rf,
                          linkage=linkage,
                          max_k=max_k,
                          leaf_order=leaf_order)
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    gewichte_sortiert = gewichte.reindex(original_reihenfolge)
    
    array = gewichte_sortiert.values.flatten()

    return array

# %%
def herc_ledoit (returns):

    #Building the portfolio object
    port = hc(returns=returns)
    
    shrinkage_herc = LedoitWolf().fit(returns.values)
    
    shrinkage_matrix_herc = pd.DataFrame(
        shrinkage_herc.covariance_,
        index = returns.columns,
        columns = returns.columns)

    #Estimate optimal portfolio:

    model='HERC'
    #correlation = 'pearson'
    rm = 'MV'
    rf = 0 
    linkage = 'ward' 
    max_k = 10 
    leaf_order = True 

    gewichte = port.optimization(model=model,
                          custom_cov = shrinkage_matrix_herc,
                          codependence='custom_cov',
                          rm=rm,
                          rf=rf,
                          method_cov='custom_cov',   #gemäß https://riskfolio-lib.readthedocs.io/en/latest/hcportfolio.html
                          linkage=linkage,
                          max_k=max_k,
                          leaf_order=leaf_order)
    
    #Sortierung der Gewichte zurück zur Reihenfolge der Returns
    original_reihenfolge = returns.columns
    gewichte_sortiert = gewichte.reindex(original_reihenfolge)
    
    array = gewichte_sortiert.values.flatten()

    return array

# %% [markdown]
# #### Vergleichs-Metriken

# %%
def gesamt_return(gewichte, returns):

    daily_returns = returns @ gewichte
    total = np.prod(1 + daily_returns) - 1
    
    return total

# %%
def portfolio_return (gewichte, returns):
    
    avg_returns = []
    avg_returns = returns.mean()
    
    pf_return = sum([gewicht * rendite for gewicht, rendite in zip(gewichte, avg_returns)])
    
    return pf_return

# %%
def portfolio_variance (gewichte, returns):
    daily_returns = []
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    pf_var = np.var(daily_returns)
    
    return pf_var

# %%
def portfolio_volatility (gewichte, returns):
    variance = portfolio_variance(gewichte, returns)
    volatility = np.sqrt(variance)
    
    return volatility

# %%
def annualized_return(gewichte, returns):
    daily_returns = returns @ gewichte
    annual = (np.prod(1 + daily_returns))**(252/daily_returns.shape[0]) - 1
    
    return annual

# %%
def annualized_portfolio_return(gewichte, returns):
    pf_return = portfolio_return(gewichte, returns)
    
    return pf_return*252

# %%
def annualized_portfolio_volatility(gewichte, returns):
    pf_volatility = portfolio_volatility(gewichte, returns)
    
    return pf_volatility*np.sqrt(252)

# %%
def sharpe_ratio (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sharpe_ratio_one (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.01
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sharpe_ratio_two (gewichte, returns):
    pf_return = portfolio_return (gewichte, returns)
    volatility = portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.02
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio_one (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.01
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def annualized_sharpe_ratio_two (gewichte, returns):
    pf_return = annualized_portfolio_return (gewichte, returns)
    volatility = annualized_portfolio_volatility (gewichte, returns)
    zins_risikofrei = 0.02
    
    sharpe_ratio = (pf_return - zins_risikofrei) / volatility
    
    return sharpe_ratio

# %%
def sortino_ratio (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def sortino_ratio_one (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.01
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def sortino_ratio_two (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.02
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio_one (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.01
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def annualized_sortino_ratio_two (gewichte, returns):    
    daily_returns = []
    zins_risikofrei = 0.02
    
    for index, zeile in returns.iterrows():
        daily_returns.append(np.dot(gewichte, zeile))
    
    daily_returns = np.array(daily_returns)
        
    temp = np.minimum(0, daily_returns - zins_risikofrei)**2
    temp = np.mean(temp)
    
    downside_dev = np.sqrt(temp)
    
    pf_return = annualized_portfolio_return (gewichte, returns)
    
    sortino_ratio = (pf_return - zins_risikofrei) / downside_dev
    
    return sortino_ratio

# %%
def maximum_drawdown (gewichte, returns):
    daily_returns = returns @ gewichte
    returns_kumuliert = (1 + daily_returns).cumprod()
    hochpunkte = returns_kumuliert.cummax()
    
    drawdowns = (returns_kumuliert - hochpunkte) / hochpunkte
    max_drawdown = drawdowns.min()
    
    #print(drawdowns)
    return max_drawdown

# %%
def calmar_ratio (gewichte, returns):
    pf_return = portfolio_return(gewichte, returns)
    max_drawdown = maximum_drawdown(gewichte, returns)
    
    calmar_ratio = pf_return / (-max_drawdown)
    
    return calmar_ratio

# %%
def value_at_risk_func(gewichte, returns):
    daily_returns = returns @ gewichte
    sorted_daily_returns = daily_returns.sort_values(ascending = True)
    value_at_risk = np.percentile(sorted_daily_returns, 100*0.05)
    return value_at_risk

# %%
#https://github.com/malctaylor15/VaR-and-Expected-Shortfall-Python/blob/master/Expected%20Shortfall%20and%20Value%20at%20Risk.ipynb

def expected_shortfall(gewichte, returns):
    daily_returns = returns @ gewichte
    sorted_daily_returns = daily_returns.sort_values(ascending = True)
    value_at_risk = value_at_risk_func(gewichte, returns)
    
    expected_shortfall = daily_returns[daily_returns <= value_at_risk].mean()
    
    return expected_shortfall

# %% [markdown]
# #### Sammel-Funktionen zum Berechnen und Speichern der Metriken

# %%
def metriken_equally_weighted(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile1 = {"Methode": "Equally-Weighted",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile1[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile1])], ignore_index=True)

# %%
def metriken_minimum_variance(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile2 = {"Methode": "Minimum_Variance",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile2[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile2])], ignore_index=True)

# %%
def metriken_max_diversification(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile3 = {"Methode": "Max-Diversification",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile3[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile3])], ignore_index=True)

# %%
def metriken_inverse_volatility(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile4 = {"Methode": "Inverse-Volatility",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile4[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile4])], ignore_index=True)

# %%
def metriken_risk_parity(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile5 = {"Methode": "Risk-Parity",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile5[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile5])], ignore_index=True)

# %%
def metriken_hrp(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile6 = {"Methode": "HRP",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile6[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile6])], ignore_index=True)

# %%
def metriken_herc(gewichte, returns, start_datum, end_datum, df):
    
    ergebnisse = np.zeros(10)
    
    metriken = ["Return","Mean_Return","Variance","Volatility","Sharpe","Sortino","Max Draw","Calmar","VaR","ES"]
    
    ergebnisse[0] = gesamt_return(gewichte, returns)
    ergebnisse[1] = portfolio_return (gewichte, returns)
    ergebnisse[2] = portfolio_variance (gewichte, returns)
    ergebnisse[3] = portfolio_volatility(gewichte, returns)
    ergebnisse[4] = sharpe_ratio (gewichte, returns)
    ergebnisse[5] = sortino_ratio (gewichte, returns)
    ergebnisse[6] = maximum_drawdown (gewichte, returns)
    ergebnisse[7] = calmar_ratio (gewichte, returns)
    ergebnisse[8] = value_at_risk_func(gewichte, returns)
    ergebnisse[9] = expected_shortfall(gewichte, returns)
    
    neue_zeile7 = {"Methode": "HERC",
                "Startdatum": start_datum,
               "Enddatum": end_datum}
    
    for m, e in zip(metriken, ergebnisse):
        neue_zeile7[m] = e
    
    # Anhängen
    return pd.concat([df, pd.DataFrame([neue_zeile7])], ignore_index=True)

# %% [markdown]
# ## Erzeugung Ergebnisse S&P500

# %%
#Tägliche Renditen für den gesamten Zeitraum von 20 Jahren SP500

returns = df_SP500.pct_change()
returns = returns.where(~df_SP500.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                    A  AAL  AAP      AAPL      ABBV      ABNB       ABT  \
# Date
# 2005-06-02  0.000414  NaN  NaN -0.006452       NaN       NaN -0.001448
# 2005-06-03 -0.005374  NaN  NaN -0.044955       NaN       NaN  0.000207
# 2005-06-06  0.019119  NaN  NaN -0.008368       NaN       NaN  0.003729
# 2005-06-07 -0.012235  NaN  NaN -0.036393       NaN       NaN  0.006398
# 2005-06-08  0.009496  NaN  NaN  0.010399       NaN       NaN -0.002051
# ...              ...  ...  ...       ...       ...       ...       ...
# 2025-05-23 -0.010485  NaN  NaN -0.030244  0.003944 -0.007286 -0.001521
# 2025-05-27  0.025154  NaN  NaN  0.025298  0.013424  0.021149  0.012490
# 2025-05-28 -0.003415  NaN  NaN  0.001049 -0.014161 -0.005641 -0.006920
# 2025-05-29  0.021645  NaN  NaN -0.002345  0.013818 -0.002409  0.006287
# 2025-05-30 -0.012006  NaN  NaN  0.004501  0.002640  0.004986  0.005495
#
#                 ACGL       ACN      ADBE  ...       XEL       XOM  XRAY  \
# Date                                      ...
# 2005-06-02       NaN       NaN -0.002712  ...  0.002678  0.002975   NaN
# 2005-06-03       NaN       NaN -0.016621  ...  0.004808 -0.002966   NaN
# 2005-06-06       NaN       NaN -0.002766  ...  0.000532  0.007874   NaN
# 2005-06-07       NaN       NaN -0.005855  ...  0.004251 -0.002604   NaN
# 2005-06-08       NaN       NaN  0.000000  ...  0.017460 -0.012533   NaN
# ...              ...       ...       ...  ...       ...       ...   ...
# 2025-05-23  0.001087 -0.021710 -0.016026  ...  0.007513  0.000583   NaN
# 2025-05-27  0.027696  0.018897  0.013270  ...  0.001147  0.004756   NaN
# 2025-05-28 -0.017332  0.001775 -0.002106  ... -0.012606 -0.013621   NaN
# 2025-05-29  0.013121  0.005507  0.002741  ...  0.007834  0.005680   NaN
# 2025-05-30  0.008917 -0.002864  0.004185  ...  0.009069 -0.003798   NaN
#
#                  XRX       XYL       YUM       ZBH      ZBRA      ZION  \
# Date
# 2005-06-02 -0.003650       NaN  0.021558  0.002885       NaN  0.005945
# 2005-06-03 -0.006593       NaN -0.010646  0.029816       NaN -0.008246
# 2005-06-06 -0.011062       NaN -0.000769 -0.005079       NaN -0.000139
# 2005-06-07 -0.006711       NaN  0.003077  0.013657       NaN -0.002772
# 2005-06-08  0.039039       NaN -0.006518 -0.005414       NaN -0.002085
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23       NaN -0.009739 -0.000344  0.010581 -0.014392       NaN
# 2025-05-27       NaN  0.017654 -0.009350  0.016947  0.038000       NaN
# 2025-05-28       NaN -0.004674 -0.006524 -0.020380 -0.014271       NaN
# 2025-05-29       NaN  0.000080  0.006217  0.011377  0.005846       NaN
# 2025-05-30       NaN  0.003024 -0.000694 -0.012535 -0.009333       NaN
#
#                  ZTS
# Date
# 2005-06-02       NaN
# 2005-06-03       NaN
# 2005-06-06       NaN
# 2005-06-07       NaN
# 2005-06-08       NaN
# ...              ...
# 2025-05-23  0.003766
# 2025-05-27  0.022635
# 2025-05-28 -0.005173
# 2025-05-29  0.010520
# 2025-05-30  0.008915
#
# [5031 rows x 598 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 3
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = training_daten.cov()
    corr_matrix = training_daten.corr()
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    gewichte_equally_weighted = equally_weighted(training_daten)
    gewichte_min_variance= min_variance_opt(cov_matrix)
    gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": gewichte_equally_weighted,
    "Minimum-Variance": gewichte_min_variance,
    "Maximum-Diversification": gewichte_max_diversification,
    "Inverse-Volatility": gewichte_inverse_volatility,
    "Equal-Risk-Contribution": gewichte_risk_parity,
    "HRP": gewichte_hrp,
    "HERC": gewichte_herc
}
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
     #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
# Alle Testperioden zusammenführen
portfolio_returns_df = pd.concat(portfolio_returns_list)
portfolio_returns_df = portfolio_returns_df.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.560718656371804e-05
#             Iterations: 299
#             Function evaluations: 78936
#             Gradient evaluations: 299
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0661056745424897
#             Iterations: 87
#             Function evaluations: 22007
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6806677955014559e-09
#             Iterations: 21
#             Function evaluations: 5544
#             Gradient evaluations: 21
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6665595056604733e-05
#             Iterations: 314
#             Function evaluations: 84466
#             Gradient evaluations: 314
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.936948205695343
#             Iterations: 69
#             Function evaluations: 18361
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.56635060457177e-09
#             Iterations: 20
#             Function evaluations: 5381
#             Gradient evaluations: 20
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4559816122957647e-05
#             Iterations: 347
#             Function evaluations: 94037
#             Gradient evaluations: 347
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0831731681363586
#             Iterations: 81
#             Function evaluations: 20955
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3858077582241334e-09
#             Iterations: 26
#             Function evaluations: 7046
#             Gradient evaluations: 26
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4534526447339444e-05
#             Iterations: 341
#             Function evaluations: 93775
#             Gradient evaluations: 341
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.952215156303736
#             Iterations: 76
#             Function evaluations: 19879
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.617602024904684e-09
#             Iterations: 38
#             Function evaluations: 10450
#             Gradient evaluations: 38
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.622007081358141e-05
#             Iterations: 332
#             Function evaluations: 92296
#             Gradient evaluations: 332
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.920905052892258
#             Iterations: 71
#             Function evaluations: 18702
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4955482396956752e-09
#             Iterations: 38
#             Function evaluations: 10564
#             Gradient evaluations: 38
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5480826700440394e-05
#             Iterations: 279
#             Function evaluations: 77841
#             Gradient evaluations: 279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.815910464073311
#             Iterations: 51
#             Function evaluations: 14281
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.758245505214993e-09
#             Iterations: 18
#             Function evaluations: 5023
#             Gradient evaluations: 18
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.148308745181869e-05
#             Iterations: 291
#             Function evaluations: 82353
#             Gradient evaluations: 291
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5229826522261836
#             Iterations: 49
#             Function evaluations: 13634
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7685128002345642e-09
#             Iterations: 30
#             Function evaluations: 8490
#             Gradient evaluations: 30
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.97115286928344e-05
#             Iterations: 281
#             Function evaluations: 80367
#             Gradient evaluations: 281
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4625481438645918
#             Iterations: 37
#             Function evaluations: 10619
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.153679294969222e-09
#             Iterations: 47
#             Function evaluations: 13442
#             Gradient evaluations: 47
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.384494997283043e-05
#             Iterations: 288
#             Function evaluations: 83809
#             Gradient evaluations: 288
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.609616389400448
#             Iterations: 35
#             Function evaluations: 10218
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.101271457203561e-10
#             Iterations: 66
#             Function evaluations: 19206
#             Gradient evaluations: 66
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.201619656757493e-05
#             Iterations: 282
#             Function evaluations: 81780
#             Gradient evaluations: 282
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.639715281737878
#             Iterations: 49
#             Function evaluations: 13099
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3363145920425187e-09
#             Iterations: 83
#             Function evaluations: 24070
#             Gradient evaluations: 83
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00018120765660335005
#             Iterations: 161
#             Function evaluations: 46529
#             Gradient evaluations: 161
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9197079911190353
#             Iterations: 25
#             Function evaluations: 7243
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.928611635597754e-10
#             Iterations: 81
#             Function evaluations: 23410
#             Gradient evaluations: 81
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00020934590169396217
#             Iterations: 134
#             Function evaluations: 38994
#             Gradient evaluations: 134
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.887772172704881
#             Iterations: 28
#             Function evaluations: 8167
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6767847157591986e-10
#             Iterations: 96
#             Function evaluations: 27937
#             Gradient evaluations: 96
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022737312160583248
#             Iterations: 140
#             Function evaluations: 41020
#             Gradient evaluations: 140
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8007067307721083
#             Iterations: 29
#             Function evaluations: 8514
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.060251469829356e-10
#             Iterations: 110
#             Function evaluations: 32230
#             Gradient evaluations: 110
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021785950399401069
#             Iterations: 103
#             Function evaluations: 30591
#             Gradient evaluations: 103
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7961748327521527
#             Iterations: 28
#             Function evaluations: 8333
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3683145155027784e-10
#             Iterations: 110
#             Function evaluations: 32670
#             Gradient evaluations: 110
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.719360558102194e-05
#             Iterations: 191
#             Function evaluations: 58447
#             Gradient evaluations: 191
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2426829363824012
#             Iterations: 31
#             Function evaluations: 9513
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.760862395874104e-10
#             Iterations: 147
#             Function evaluations: 44982
#             Gradient evaluations: 147
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7997855005585396e-05
#             Iterations: 169
#             Function evaluations: 51883
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4013410133120487
#             Iterations: 37
#             Function evaluations: 10173
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.536092328176696e-10
#             Iterations: 127
#             Function evaluations: 38989
#             Gradient evaluations: 127
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.599124674605381e-05
#             Iterations: 250
#             Function evaluations: 77750
#             Gradient evaluations: 250
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.379747545025048
#             Iterations: 36
#             Function evaluations: 11230
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.58014660323221e-10
#             Iterations: 78
#             Function evaluations: 24258
#             Gradient evaluations: 78
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.859770697521892e-05
#             Iterations: 239
#             Function evaluations: 75525
#             Gradient evaluations: 239
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2278114229673838
#             Iterations: 37
#             Function evaluations: 10455
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.690847946995073e-10
#             Iterations: 57
#             Function evaluations: 18012
#             Gradient evaluations: 57
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.578197007895788e-05
#             Iterations: 221
#             Function evaluations: 70058
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.154628132683497
#             Iterations: 34
#             Function evaluations: 10806
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.644483717892879e-10
#             Iterations: 50
#             Function evaluations: 15851
#             Gradient evaluations: 50
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2966375928351446e-05
#             Iterations: 217
#             Function evaluations: 69440
#             Gradient evaluations: 217
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2436836191427716
#             Iterations: 29
#             Function evaluations: 9309
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6000989775920426e-09
#             Iterations: 41
#             Function evaluations: 13120
#             Gradient evaluations: 41
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7518595389947427e-05
#             Iterations: 242
#             Function evaluations: 77924
#             Gradient evaluations: 242
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.445288602206374
#             Iterations: 44
#             Function evaluations: 13884
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5596859428735478e-09
#             Iterations: 37
#             Function evaluations: 11914
#             Gradient evaluations: 37
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.486374086979512e-05
#             Iterations: 211
#             Function evaluations: 68153
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.039724329096922
#             Iterations: 30
#             Function evaluations: 9717
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.645227390393789e-10
#             Iterations: 51
#             Function evaluations: 16473
#             Gradient evaluations: 51
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7521172899602846e-05
#             Iterations: 214
#             Function evaluations: 68908
#             Gradient evaluations: 214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8381808722764228
#             Iterations: 28
#             Function evaluations: 9040
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.417757534672872e-10
#             Iterations: 56
#             Function evaluations: 18032
#             Gradient evaluations: 56
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.946024184079027e-05
#             Iterations: 197
#             Function evaluations: 63828
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.965748906328976
#             Iterations: 33
#             Function evaluations: 9412
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.821968486216466e-10
#             Iterations: 55
#             Function evaluations: 17820
#             Gradient evaluations: 55
# 2011-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.8064483049239943e-05
#             Iterations: 180
#             Function evaluations: 58860
#             Gradient evaluations: 180
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9348993199020237
#             Iterations: 28
#             Function evaluations: 9173
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1344104499274078e-09
#             Iterations: 54
#             Function evaluations: 17659
#             Gradient evaluations: 54
# 2011-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.003279946988477e-05
#             Iterations: 247
#             Function evaluations: 81263
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2148984941533705
#             Iterations: 41
#             Function evaluations: 12201
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0174910689044592e-09
#             Iterations: 69
#             Function evaluations: 22701
#             Gradient evaluations: 69
# 2011-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9476206656634664e-05
#             Iterations: 285
#             Function evaluations: 94336
#             Gradient evaluations: 285
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7044998548492294
#             Iterations: 53
#             Function evaluations: 16270
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3883609015530548e-09
#             Iterations: 43
#             Function evaluations: 14233
#             Gradient evaluations: 43
# 2012-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0229336061402833e-05
#             Iterations: 321
#             Function evaluations: 107535
#             Gradient evaluations: 321
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.726060061855378
#             Iterations: 60
#             Function evaluations: 18825
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2731428925039467e-09
#             Iterations: 41
#             Function evaluations: 13735
#             Gradient evaluations: 41
# 2012-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2806230953764293e-05
#             Iterations: 323
#             Function evaluations: 109497
#             Gradient evaluations: 323
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9056492158748934
#             Iterations: 51
#             Function evaluations: 15981
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5500213468355784e-09
#             Iterations: 26
#             Function evaluations: 8814
#             Gradient evaluations: 26
# 2012-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4797505772361804e-05
#             Iterations: 317
#             Function evaluations: 108097
#             Gradient evaluations: 317
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0372627858943995
#             Iterations: 41
#             Function evaluations: 14019
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2623193065579733e-09
#             Iterations: 19
#             Function evaluations: 6479
#             Gradient evaluations: 19
# 2012-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2588864390861522e-05
#             Iterations: 362
#             Function evaluations: 124166
#             Gradient evaluations: 362
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.043445369727125
#             Iterations: 43
#             Function evaluations: 14443
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.095818482423034e-09
#             Iterations: 20
#             Function evaluations: 6860
#             Gradient evaluations: 20
# 2013-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4620251864559602e-05
#             Iterations: 340
#             Function evaluations: 117641
#             Gradient evaluations: 340
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0391264533044215
#             Iterations: 46
#             Function evaluations: 14572
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.568787828835036e-10
#             Iterations: 20
#             Function evaluations: 6920
#             Gradient evaluations: 20
# 2013-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3156072760856917e-05
#             Iterations: 373
#             Function evaluations: 129058
#             Gradient evaluations: 373
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.853693924636163
#             Iterations: 55
#             Function evaluations: 17699
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1974974884239275e-09
#             Iterations: 17
#             Function evaluations: 5882
#             Gradient evaluations: 17
# 2013-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8427168263003586e-05
#             Iterations: 307
#             Function evaluations: 107144
#             Gradient evaluations: 307
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9905066665666657
#             Iterations: 61
#             Function evaluations: 19946
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1219430922837133e-09
#             Iterations: 9
#             Function evaluations: 3141
#             Gradient evaluations: 9
# 2013-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8687386302614797e-05
#             Iterations: 328
#             Function evaluations: 115457
#             Gradient evaluations: 328
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.930052057010673
#             Iterations: 59
#             Function evaluations: 19411
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.572919983062627e-09
#             Iterations: 17
#             Function evaluations: 5984
#             Gradient evaluations: 17
# 2014-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.121514998499477e-05
#             Iterations: 314
#             Function evaluations: 111470
#             Gradient evaluations: 314
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.853542922523241
#             Iterations: 50
#             Function evaluations: 17801
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4567377525833527e-09
#             Iterations: 29
#             Function evaluations: 10295
#             Gradient evaluations: 29
# 2014-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6359295001629224e-05
#             Iterations: 314
#             Function evaluations: 112727
#             Gradient evaluations: 314
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8623347845752214
#             Iterations: 54
#             Function evaluations: 19438
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2545120203062113e-09
#             Iterations: 9
#             Function evaluations: 3231
#             Gradient evaluations: 9
# 2014-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8497664736703935e-05
#             Iterations: 295
#             Function evaluations: 106200
#             Gradient evaluations: 295
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.519850585120738
#             Iterations: 39
#             Function evaluations: 14077
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2051056722236238e-09
#             Iterations: 15
#             Function evaluations: 5400
#             Gradient evaluations: 15
# 2014-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.652785653865941e-05
#             Iterations: 334
#             Function evaluations: 120575
#             Gradient evaluations: 334
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.464157079814132
#             Iterations: 37
#             Function evaluations: 13393
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0563038084195224e-10
#             Iterations: 26
#             Function evaluations: 9386
#             Gradient evaluations: 26
# 2015-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.949104575294913e-05
#             Iterations: 298
#             Function evaluations: 107876
#             Gradient evaluations: 298
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4354373728146834
#             Iterations: 37
#             Function evaluations: 13431
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.515242940266989e-10
#             Iterations: 35
#             Function evaluations: 12670
#             Gradient evaluations: 35
# 2015-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.757333929985946e-05
#             Iterations: 283
#             Function evaluations: 103578
#             Gradient evaluations: 283
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.534053415178769
#             Iterations: 42
#             Function evaluations: 15413
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.193483479034307e-10
#             Iterations: 46
#             Function evaluations: 16837
#             Gradient evaluations: 46
# 2015-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.869940828699413e-05
#             Iterations: 343
#             Function evaluations: 127597
#             Gradient evaluations: 343
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.759108173054187
#             Iterations: 60
#             Function evaluations: 20891
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.205198584729706e-09
#             Iterations: 55
#             Function evaluations: 20460
#             Gradient evaluations: 55
# 2015-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.271948361114539e-05
#             Iterations: 344
#             Function evaluations: 130032
#             Gradient evaluations: 344
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9933100785113216
#             Iterations: 53
#             Function evaluations: 18567
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1548618491837877e-09
#             Iterations: 44
#             Function evaluations: 16633
#             Gradient evaluations: 44
# 2016-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8322450347067538e-05
#             Iterations: 342
#             Function evaluations: 130645
#             Gradient evaluations: 342
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.3940182519592397
#             Iterations: 64
#             Function evaluations: 22975
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.22984793044664e-09
#             Iterations: 33
#             Function evaluations: 12607
#             Gradient evaluations: 33
# 2016-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5384240586407645e-05
#             Iterations: 377
#             Function evaluations: 148161
#             Gradient evaluations: 377
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.3789215463819264
#             Iterations: 75
#             Function evaluations: 27972
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.220311907696423e-09
#             Iterations: 27
#             Function evaluations: 10611
#             Gradient evaluations: 27
# 2016-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3625102110765585e-05
#             Iterations: 381
#             Function evaluations: 148590
#             Gradient evaluations: 381
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4869139523396755
#             Iterations: 79
#             Function evaluations: 29321
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6698797313669626e-09
#             Iterations: 17
#             Function evaluations: 6630
#             Gradient evaluations: 17
# 2016-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.612799195064647e-06
#             Iterations: 460
#             Function evaluations: 180780
#             Gradient evaluations: 460
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.296053183103063
#             Iterations: 110
#             Function evaluations: 41796
#             Gradient evaluations: 106
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.820294038272212e-09
#             Iterations: 9
#             Function evaluations: 3537
#             Gradient evaluations: 9
# 2017-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5101083132319623e-05
#             Iterations: 462
#             Function evaluations: 182952
#             Gradient evaluations: 462
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7016831287980647
#             Iterations: 74
#             Function evaluations: 27798
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.995636497966824e-09
#             Iterations: 9
#             Function evaluations: 3564
#             Gradient evaluations: 9
# 2017-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.948599632467309e-05
#             Iterations: 422
#             Function evaluations: 169644
#             Gradient evaluations: 422
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4061797843418917
#             Iterations: 65
#             Function evaluations: 24580
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9647370985427657e-09
#             Iterations: 16
#             Function evaluations: 6432
#             Gradient evaluations: 16
# 2017-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.237575502400547e-05
#             Iterations: 395
#             Function evaluations: 160370
#             Gradient evaluations: 395
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.243407367905203
#             Iterations: 70
#             Function evaluations: 26856
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8409430955294662e-09
#             Iterations: 19
#             Function evaluations: 7715
#             Gradient evaluations: 19
# 2017-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8323271810440742e-05
#             Iterations: 394
#             Function evaluations: 161146
#             Gradient evaluations: 394
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1327031448446028
#             Iterations: 52
#             Function evaluations: 19676
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5553824393302443e-09
#             Iterations: 26
#             Function evaluations: 10635
#             Gradient evaluations: 26
# 2018-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8956432160018155e-05
#             Iterations: 374
#             Function evaluations: 152593
#             Gradient evaluations: 374
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.86783694357766
#             Iterations: 71
#             Function evaluations: 27404
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0096258877466775e-09
#             Iterations: 29
#             Function evaluations: 11833
#             Gradient evaluations: 29
# 2018-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3768153142770126e-05
#             Iterations: 403
#             Function evaluations: 165634
#             Gradient evaluations: 403
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0964537205479252
#             Iterations: 60
#             Function evaluations: 24715
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8159928044469695e-09
#             Iterations: 26
#             Function evaluations: 10687
#             Gradient evaluations: 26
# 2018-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9613230836748316e-05
#             Iterations: 315
#             Function evaluations: 129781
#             Gradient evaluations: 315
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8624829380593155
#             Iterations: 58
#             Function evaluations: 22298
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8631802579304487e-09
#             Iterations: 38
#             Function evaluations: 15656
#             Gradient evaluations: 38
# 2018-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.660618114372203e-05
#             Iterations: 350
#             Function evaluations: 145250
#             Gradient evaluations: 350
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0279123692764314
#             Iterations: 63
#             Function evaluations: 24547
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.867763302991304e-09
#             Iterations: 38
#             Function evaluations: 15770
#             Gradient evaluations: 38
# 2019-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6193253612336696e-05
#             Iterations: 371
#             Function evaluations: 154707
#             Gradient evaluations: 371
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.000590414487259
#             Iterations: 68
#             Function evaluations: 26751
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5802120930835942e-09
#             Iterations: 31
#             Function evaluations: 12928
#             Gradient evaluations: 31
# 2019-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00014685482780481002
#             Iterations: 177
#             Function evaluations: 73986
#             Gradient evaluations: 177
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.016893249380178
#             Iterations: 26
#             Function evaluations: 10889
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.161654643256055e-10
#             Iterations: 81
#             Function evaluations: 33858
#             Gradient evaluations: 81
# 2019-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00014863990230425754
#             Iterations: 211
#             Function evaluations: 89253
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0296755999510645
#             Iterations: 39
#             Function evaluations: 14840
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.400274098103772e-10
#             Iterations: 89
#             Function evaluations: 37648
#             Gradient evaluations: 89
# 2019-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.000159027604595843
#             Iterations: 207
#             Function evaluations: 87976
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.028847680699448
#             Iterations: 25
#             Function evaluations: 10647
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1343457402598383e-09
#             Iterations: 87
#             Function evaluations: 36976
#             Gradient evaluations: 87
# 2020-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015905854344613614
#             Iterations: 200
#             Function evaluations: 86201
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0921176290855
#             Iterations: 26
#             Function evaluations: 11227
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2964582712123412e-09
#             Iterations: 97
#             Function evaluations: 41808
#             Gradient evaluations: 97
# 2020-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8060345379608415e-05
#             Iterations: 264
#             Function evaluations: 114841
#             Gradient evaluations: 264
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.984592456686327
#             Iterations: 78
#             Function evaluations: 32270
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.000811028839758e-09
#             Iterations: 67
#             Function evaluations: 29145
#             Gradient evaluations: 67
# 2020-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.923608662317729e-05
#             Iterations: 325
#             Function evaluations: 142351
#             Gradient evaluations: 325
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.3355310871003474
#             Iterations: 71
#             Function evaluations: 29429
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2116690237596855e-09
#             Iterations: 50
#             Function evaluations: 21900
#             Gradient evaluations: 50
# 2020-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2570472725114772e-05
#             Iterations: 335
#             Function evaluations: 147065
#             Gradient evaluations: 335
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.460081569409615
#             Iterations: 79
#             Function evaluations: 33011
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.4301739724156193e-09
#             Iterations: 28
#             Function evaluations: 12292
#             Gradient evaluations: 28
# 2021-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6954571316725794e-05
#             Iterations: 313
#             Function evaluations: 137720
#             Gradient evaluations: 313
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.2649900945172146
#             Iterations: 75
#             Function evaluations: 31331
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7831910929180145e-09
#             Iterations: 29
#             Function evaluations: 12760
#             Gradient evaluations: 29
# 2021-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.781253339320097e-05
#             Iterations: 316
#             Function evaluations: 140621
#             Gradient evaluations: 316
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.882650854529552
#             Iterations: 45
#             Function evaluations: 19624
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.453874666194968e-09
#             Iterations: 49
#             Function evaluations: 21805
#             Gradient evaluations: 49
# 2021-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.898700887428538e-05
#             Iterations: 271
#             Function evaluations: 120867
#             Gradient evaluations: 271
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6368494184220075
#             Iterations: 38
#             Function evaluations: 16538
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0373004325731639e-09
#             Iterations: 58
#             Function evaluations: 25868
#             Gradient evaluations: 58
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.336828812328271e-05
#             Iterations: 238
#             Function evaluations: 106386
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3472929859773752
#             Iterations: 40
#             Function evaluations: 16124
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0865034325044437e-09
#             Iterations: 55
#             Function evaluations: 24585
#             Gradient evaluations: 55
# 2022-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.308814709855061e-05
#             Iterations: 264
#             Function evaluations: 119328
#             Gradient evaluations: 264
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2622634732583906
#             Iterations: 35
#             Function evaluations: 15851
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.17765631800722e-10
#             Iterations: 55
#             Function evaluations: 24861
#             Gradient evaluations: 55
# 2022-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.023085183192138e-05
#             Iterations: 262
#             Function evaluations: 119210
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.337277375256852
#             Iterations: 65
#             Function evaluations: 27820
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0894105617870467e-09
#             Iterations: 57
#             Function evaluations: 25935
#             Gradient evaluations: 57
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.464682160843345e-05
#             Iterations: 272
#             Function evaluations: 124848
#             Gradient evaluations: 272
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.518411872727149
#             Iterations: 55
#             Function evaluations: 23454
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2562068915902268e-09
#             Iterations: 49
#             Function evaluations: 22491
#             Gradient evaluations: 49
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7129267058505102e-05
#             Iterations: 293
#             Function evaluations: 134488
#             Gradient evaluations: 293
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0425828665257693
#             Iterations: 63
#             Function evaluations: 27137
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1195316375813742e-09
#             Iterations: 38
#             Function evaluations: 17442
#             Gradient evaluations: 38
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.158795649160474e-05
#             Iterations: 298
#             Function evaluations: 137379
#             Gradient evaluations: 298
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.343294835255038
#             Iterations: 72
#             Function evaluations: 31410
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1274763015005423e-09
#             Iterations: 44
#             Function evaluations: 20284
#             Gradient evaluations: 44
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7611399141609038e-05
#             Iterations: 336
#             Function evaluations: 155232
#             Gradient evaluations: 336
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7415588178401147
#             Iterations: 84
#             Function evaluations: 37046
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1163035187400048e-09
#             Iterations: 38
#             Function evaluations: 17556
#             Gradient evaluations: 38
# 2023-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.590828777923799e-05
#             Iterations: 328
#             Function evaluations: 152192
#             Gradient evaluations: 328
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.0724274649572365
#             Iterations: 86
#             Function evaluations: 38133
#             Gradient evaluations: 82
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.631254942002307e-09
#             Iterations: 36
#             Function evaluations: 16704
#             Gradient evaluations: 36
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4294372767715442e-05
#             Iterations: 321
#             Function evaluations: 149908
#             Gradient evaluations: 321
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.357105474789429
#             Iterations: 94
#             Function evaluations: 42146
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.940671184612122e-09
#             Iterations: 33
#             Function evaluations: 15411
#             Gradient evaluations: 33
# 2024-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4741685893009108e-05
#             Iterations: 358
#             Function evaluations: 167187
#             Gradient evaluations: 358
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.492396070486934
#             Iterations: 89
#             Function evaluations: 39787
#             Gradient evaluations: 85
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.044409270680055e-09
#             Iterations: 28
#             Function evaluations: 13076
#             Gradient evaluations: 28
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df.to_csv("renditensp500_3Monate_f.csv")

# %% [markdown]
# ## Ergebnis-Erzeugung JSE

# %%
returns = df_JSE.pct_change()
returns = returns.where(~df_JSE.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of               4SI.JO    ABG.JO    ACL.JO    ACT.JO    ADH.JO    AEL.JO  \
# Date
# 2005-06-02       NaN  0.001214 -0.006225  0.000000 -0.014598       NaN
# 2005-06-03       NaN  0.001333  0.000000  0.000000  0.000000       NaN
# 2005-06-06       NaN  0.003510  0.014953  0.000000  0.007407       NaN
# 2005-06-07       NaN  0.006634 -0.035437  0.146154 -0.007353       NaN
# 2005-06-08       NaN -0.005392 -0.029721  0.000000  0.007407       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26  0.000000  0.007235 -0.018018  0.000000  0.005975  0.000426
# 2025-05-27  0.000000  0.000178 -0.036697  0.000000  0.003439  0.000000
# 2025-05-28  0.042857  0.026828 -0.038095  0.087500  0.022741  0.002128
# 2025-05-29 -0.041096  0.016127  0.049505 -0.045977 -0.010966  0.002972
# 2025-05-30  0.000000 -0.014051  0.094340 -0.036145 -0.009855 -0.001693
#
#               AFE.JO    AFH.JO    AFT.JO    AGL.JO  ...    VKE.JO    VOD.JO  \
# Date                                                ...
# 2005-06-02  0.020642       NaN       NaN  0.005481  ...       NaN  0.017117
# 2005-06-03  0.000000       NaN       NaN  0.000000  ...       NaN  0.000000
# 2005-06-06  0.000000       NaN       NaN -0.019079  ...       NaN  0.045350
# 2005-06-07  0.000225       NaN       NaN -0.020994  ...       NaN -0.000169
# 2005-06-08  0.011009       NaN       NaN  0.014191  ...       NaN -0.025424
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-26  0.007992  0.032548 -0.002564  0.029137  ... -0.010417 -0.016292
# 2025-05-27  0.007252 -0.026087  0.026498 -0.018270  ...  0.006316  0.002971
# 2025-05-28  0.002592  0.017857  0.000000 -0.008829  ...  0.001046 -0.006294
# 2025-05-29 -0.011298 -0.013158 -0.008476 -0.005631  ...  0.014107  0.031967
# 2025-05-30  0.000872 -0.011111  0.010297  0.016932  ...  0.030912 -0.005199
#
#               WBC.JO    WBO.JO    WEZ.JO    WHL.JO    YRK.JO  YYLBEE.JO  \
# Date
# 2005-06-02       NaN  0.009434       NaN  0.009901  0.000000        NaN
# 2005-06-03       NaN  0.000000       NaN  0.000000  0.000000        NaN
# 2005-06-06       NaN  0.009346       NaN  0.026471  0.000000        NaN
# 2005-06-07       NaN  0.000000       NaN  0.012416  0.000000        NaN
# 2005-06-08       NaN  0.018519       NaN -0.027358  0.000000        NaN
# ...              ...       ...       ...       ...       ...        ...
# 2025-05-26  0.021277 -0.005745  0.111111 -0.000174  0.046154        0.0
# 2025-05-27  0.015625  0.007979 -0.100000 -0.008726  0.000000        0.0
# 2025-05-28 -0.010872 -0.018234 -0.022222  0.014965 -0.083333        0.0
# 2025-05-29  0.013895 -0.005505  0.022727  0.016132  0.016043        0.0
# 2025-05-30  0.002250  0.014985 -0.044444  0.000341  0.026316        0.0
#
#               ZED.JO    ZZD.JO
# Date
# 2005-06-02       NaN       NaN
# 2005-06-03       NaN       NaN
# 2005-06-06       NaN       NaN
# 2005-06-07       NaN       NaN
# 2005-06-08       NaN       NaN
# ...              ...       ...
# 2025-05-26 -0.008264 -0.000864
# 2025-05-27 -0.016667  0.037165
# 2025-05-28  0.059322  0.008333
# 2025-05-29  0.008000 -0.008264
# 2025-05-30  0.023810 -0.012500
#
# [5170 rows x 217 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 3
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = training_daten.cov()
    corr_matrix = training_daten.corr()
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    JSE_gewichte_equally_weighted = equally_weighted(training_daten)
    JSE_gewichte_min_variance= min_variance_opt(cov_matrix)
    JSE_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    JSE_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    JSE_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    JSE_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    JSE_gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": JSE_gewichte_equally_weighted,
    "Minimum-Variance": JSE_gewichte_min_variance,
    "Maximum-Diversification": JSE_gewichte_max_diversification,
    "Inverse-Volatility": JSE_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": JSE_gewichte_risk_parity,
    "HRP": JSE_gewichte_hrp,
    "HERC": JSE_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
     #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
# Alle Testperioden zusammenführen
portfolio_returns_df_JSE = pd.concat(portfolio_returns_list)
portfolio_returns_df_JSE = portfolio_returns_df_JSE.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3134440810290774e-05
#             Iterations: 152
#             Function evaluations: 10184
#             Gradient evaluations: 152
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.653137425667317
#             Iterations: 53
#             Function evaluations: 3590
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1202687138208137e-09
#             Iterations: 44
#             Function evaluations: 2948
#             Gradient evaluations: 44
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.2087758665013425e-05
#             Iterations: 122
#             Function evaluations: 8053
#             Gradient evaluations: 122
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.233447253489587
#             Iterations: 27
#             Function evaluations: 1806
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4325462281688088e-09
#             Iterations: 53
#             Function evaluations: 3498
#             Gradient evaluations: 53
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.859415038915805e-05
#             Iterations: 118
#             Function evaluations: 7906
#             Gradient evaluations: 118
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.296043847782716
#             Iterations: 34
#             Function evaluations: 2312
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7501750850210062e-09
#             Iterations: 53
#             Function evaluations: 3552
#             Gradient evaluations: 53
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.627167062020266e-05
#             Iterations: 133
#             Function evaluations: 8911
#             Gradient evaluations: 133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5697138027572857
#             Iterations: 46
#             Function evaluations: 3116
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.110280145497366e-10
#             Iterations: 65
#             Function evaluations: 4355
#             Gradient evaluations: 65
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.316667755489626e-05
#             Iterations: 140
#             Function evaluations: 10220
#             Gradient evaluations: 140
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7543156812255716
#             Iterations: 36
#             Function evaluations: 2666
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5276998741108466e-09
#             Iterations: 42
#             Function evaluations: 3067
#             Gradient evaluations: 42
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2521172414402488e-05
#             Iterations: 197
#             Function evaluations: 15563
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1621187521236425
#             Iterations: 59
#             Function evaluations: 4708
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.08218102786104e-09
#             Iterations: 33
#             Function evaluations: 2608
#             Gradient evaluations: 33
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.478208204480234e-05
#             Iterations: 164
#             Function evaluations: 12956
#             Gradient evaluations: 164
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9052155889846007
#             Iterations: 64
#             Function evaluations: 5105
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7702775342306537e-09
#             Iterations: 32
#             Function evaluations: 2529
#             Gradient evaluations: 32
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.2437936965525545e-05
#             Iterations: 173
#             Function evaluations: 13668
#             Gradient evaluations: 173
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8242697516535276
#             Iterations: 43
#             Function evaluations: 3438
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.686009616180634e-10
#             Iterations: 43
#             Function evaluations: 3397
#             Gradient evaluations: 43
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.015999680449088e-05
#             Iterations: 158
#             Function evaluations: 12166
#             Gradient evaluations: 158
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.877491757511488
#             Iterations: 44
#             Function evaluations: 3432
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.683014382006474e-09
#             Iterations: 43
#             Function evaluations: 3311
#             Gradient evaluations: 43
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.2185038010872135e-05
#             Iterations: 149
#             Function evaluations: 11771
#             Gradient evaluations: 149
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.3242589167202286
#             Iterations: 44
#             Function evaluations: 3520
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6241572785185804e-09
#             Iterations: 42
#             Function evaluations: 3319
#             Gradient evaluations: 42
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.202402132898705e-05
#             Iterations: 162
#             Function evaluations: 12798
#             Gradient evaluations: 162
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9390265799580986
#             Iterations: 37
#             Function evaluations: 2956
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.66764580158499e-10
#             Iterations: 82
#             Function evaluations: 6478
#             Gradient evaluations: 82
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.165740827801172e-05
#             Iterations: 154
#             Function evaluations: 11858
#             Gradient evaluations: 154
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0216309001895882
#             Iterations: 45
#             Function evaluations: 3497
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.847184879797634e-10
#             Iterations: 103
#             Function evaluations: 7931
#             Gradient evaluations: 103
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.904663878338106e-05
#             Iterations: 144
#             Function evaluations: 10944
#             Gradient evaluations: 144
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0787953783759843
#             Iterations: 47
#             Function evaluations: 3607
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.131393225491523e-10
#             Iterations: 111
#             Function evaluations: 8436
#             Gradient evaluations: 111
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.876018550733002e-05
#             Iterations: 153
#             Function evaluations: 11628
#             Gradient evaluations: 153
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.989239863956551
#             Iterations: 41
#             Function evaluations: 3152
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.162066781630115e-10
#             Iterations: 109
#             Function evaluations: 8284
#             Gradient evaluations: 109
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.608105600686514e-05
#             Iterations: 137
#             Function evaluations: 10413
#             Gradient evaluations: 137
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.533439398965292
#             Iterations: 51
#             Function evaluations: 3924
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3783486293329875e-09
#             Iterations: 107
#             Function evaluations: 8132
#             Gradient evaluations: 107
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2108404001062312e-05
#             Iterations: 195
#             Function evaluations: 16576
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8017558532734754
#             Iterations: 59
#             Function evaluations: 5070
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.914048721489231e-09
#             Iterations: 84
#             Function evaluations: 7140
#             Gradient evaluations: 84
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7223491673189227e-05
#             Iterations: 200
#             Function evaluations: 17200
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6340233261636867
#             Iterations: 85
#             Function evaluations: 7252
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.837832603079748e-09
#             Iterations: 76
#             Function evaluations: 6536
#             Gradient evaluations: 76
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6517564005544384e-05
#             Iterations: 195
#             Function evaluations: 16575
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5731510164651388
#             Iterations: 51
#             Function evaluations: 4380
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3644385948810775e-09
#             Iterations: 56
#             Function evaluations: 4760
#             Gradient evaluations: 56
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.261103504539436e-05
#             Iterations: 215
#             Function evaluations: 18490
#             Gradient evaluations: 215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.686923448426036
#             Iterations: 53
#             Function evaluations: 4609
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.657108988858343e-09
#             Iterations: 57
#             Function evaluations: 4902
#             Gradient evaluations: 57
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2826819379717429e-05
#             Iterations: 223
#             Function evaluations: 19847
#             Gradient evaluations: 223
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.039279448609274
#             Iterations: 61
#             Function evaluations: 5128
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.500090940196717e-09
#             Iterations: 57
#             Function evaluations: 5073
#             Gradient evaluations: 57
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1226748234171139e-05
#             Iterations: 237
#             Function evaluations: 20619
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.04682594292206
#             Iterations: 57
#             Function evaluations: 4928
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.492208989936472e-09
#             Iterations: 42
#             Function evaluations: 3654
#             Gradient evaluations: 42
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2180120466558345e-05
#             Iterations: 233
#             Function evaluations: 21204
#             Gradient evaluations: 233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8679891978916836
#             Iterations: 51
#             Function evaluations: 4692
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.254044339067941e-09
#             Iterations: 42
#             Function evaluations: 3822
#             Gradient evaluations: 42
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3687150043097548e-05
#             Iterations: 212
#             Function evaluations: 19504
#             Gradient evaluations: 212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7490132054974463
#             Iterations: 49
#             Function evaluations: 4552
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6614447934367397e-09
#             Iterations: 57
#             Function evaluations: 5244
#             Gradient evaluations: 57
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.237215599368564e-05
#             Iterations: 206
#             Function evaluations: 18541
#             Gradient evaluations: 206
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4619774673549144
#             Iterations: 51
#             Function evaluations: 4637
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9760280397540073e-09
#             Iterations: 57
#             Function evaluations: 5130
#             Gradient evaluations: 57
# 2011-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2163698841802925e-05
#             Iterations: 224
#             Function evaluations: 20384
#             Gradient evaluations: 224
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.370528109524003
#             Iterations: 55
#             Function evaluations: 5056
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.517710198813543e-09
#             Iterations: 45
#             Function evaluations: 4096
#             Gradient evaluations: 45
# 2011-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.016842576135813e-05
#             Iterations: 204
#             Function evaluations: 18768
#             Gradient evaluations: 204
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9652678972243303
#             Iterations: 61
#             Function evaluations: 5584
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.312570565569058e-09
#             Iterations: 46
#             Function evaluations: 4232
#             Gradient evaluations: 46
# 2011-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.575034363674184e-06
#             Iterations: 262
#             Function evaluations: 23842
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.22556511940308
#             Iterations: 69
#             Function evaluations: 6355
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.375124953748949e-09
#             Iterations: 36
#             Function evaluations: 3276
#             Gradient evaluations: 36
# 2012-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0312060115105909e-05
#             Iterations: 225
#             Function evaluations: 21151
#             Gradient evaluations: 225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.30898480817009
#             Iterations: 63
#             Function evaluations: 5994
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.0150661762229145e-09
#             Iterations: 33
#             Function evaluations: 3102
#             Gradient evaluations: 33
# 2012-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1140361132140154e-05
#             Iterations: 225
#             Function evaluations: 21600
#             Gradient evaluations: 225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.3995448537433335
#             Iterations: 68
#             Function evaluations: 6605
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.4501551045966185e-09
#             Iterations: 35
#             Function evaluations: 3360
#             Gradient evaluations: 35
# 2012-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5829297535662714e-05
#             Iterations: 203
#             Function evaluations: 19691
#             Gradient evaluations: 203
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.899907812398432
#             Iterations: 126
#             Function evaluations: 12396
#             Gradient evaluations: 122
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.120838678940798e-09
#             Iterations: 28
#             Function evaluations: 2716
#             Gradient evaluations: 28
# 2012-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.398904318254147e-05
#             Iterations: 213
#             Function evaluations: 21727
#             Gradient evaluations: 213
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.241127773739358
#             Iterations: 66
#             Function evaluations: 6702
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.069375924709182e-09
#             Iterations: 29
#             Function evaluations: 2958
#             Gradient evaluations: 29
# 2013-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4496386067113689e-05
#             Iterations: 208
#             Function evaluations: 21632
#             Gradient evaluations: 208
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.385756114897195
#             Iterations: 82
#             Function evaluations: 8226
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.650949635860371e-09
#             Iterations: 44
#             Function evaluations: 4576
#             Gradient evaluations: 44
# 2013-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2420205042968393e-05
#             Iterations: 185
#             Function evaluations: 19056
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.389701818372124
#             Iterations: 62
#             Function evaluations: 6356
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.827395306734299e-09
#             Iterations: 31
#             Function evaluations: 3193
#             Gradient evaluations: 31
# 2013-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.1339392162241e-06
#             Iterations: 201
#             Function evaluations: 20704
#             Gradient evaluations: 201
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.630404273044908
#             Iterations: 74
#             Function evaluations: 7711
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.264775460874857e-09
#             Iterations: 22
#             Function evaluations: 2266
#             Gradient evaluations: 22
# 2013-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1234681866522788e-05
#             Iterations: 193
#             Function evaluations: 20652
#             Gradient evaluations: 193
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.653388661523133
#             Iterations: 69
#             Function evaluations: 7464
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.925024220106083e-09
#             Iterations: 25
#             Function evaluations: 2675
#             Gradient evaluations: 25
# 2014-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.589225717456336e-06
#             Iterations: 213
#             Function evaluations: 22791
#             Gradient evaluations: 213
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.441751326867563
#             Iterations: 85
#             Function evaluations: 8776
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.625538331630073e-09
#             Iterations: 31
#             Function evaluations: 3318
#             Gradient evaluations: 31
# 2014-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.187354176197228e-06
#             Iterations: 240
#             Function evaluations: 26400
#             Gradient evaluations: 240
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.529713098521586
#             Iterations: 72
#             Function evaluations: 7910
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.074843516839046e-09
#             Iterations: 32
#             Function evaluations: 3521
#             Gradient evaluations: 32
# 2014-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.731418793408144e-05
#             Iterations: 220
#             Function evaluations: 24421
#             Gradient evaluations: 220
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.611761564708866
#             Iterations: 73
#             Function evaluations: 7736
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7458579156896695e-09
#             Iterations: 41
#             Function evaluations: 4551
#             Gradient evaluations: 41
# 2014-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9016949360606556e-05
#             Iterations: 229
#             Function evaluations: 26106
#             Gradient evaluations: 229
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.525580504705169
#             Iterations: 116
#             Function evaluations: 13173
#             Gradient evaluations: 112
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7483486521497167e-09
#             Iterations: 56
#             Function evaluations: 6384
#             Gradient evaluations: 56
# 2015-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5974043413196587e-05
#             Iterations: 219
#             Function evaluations: 25842
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.572756307065056
#             Iterations: 62
#             Function evaluations: 7382
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1594799931561814e-08
#             Iterations: 105
#             Function evaluations: 12390
#             Gradient evaluations: 105
# 2015-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5882404019576374e-05
#             Iterations: 223
#             Function evaluations: 25869
#             Gradient evaluations: 223
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.425140535367625
#             Iterations: 72
#             Function evaluations: 7961
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.803750804650525e-09
#             Iterations: 138
#             Function evaluations: 16008
#             Gradient evaluations: 138
# 2015-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.162934525577546e-05
#             Iterations: 194
#             Function evaluations: 22699
#             Gradient evaluations: 194
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.849402714277183
#             Iterations: 65
#             Function evaluations: 7219
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.090397328640064e-08
#             Iterations: 127
#             Function evaluations: 14860
#             Gradient evaluations: 127
# 2015-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.196734054897911e-05
#             Iterations: 192
#             Function evaluations: 22849
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.8205337163009965
#             Iterations: 73
#             Function evaluations: 8303
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0372407950777966e-08
#             Iterations: 89
#             Function evaluations: 10592
#             Gradient evaluations: 89
# 2016-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2479363276689685e-05
#             Iterations: 218
#             Function evaluations: 26160
#             Gradient evaluations: 218
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.495072901480373
#             Iterations: 77
#             Function evaluations: 9229
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.0573858451572414e-09
#             Iterations: 87
#             Function evaluations: 10440
#             Gradient evaluations: 87
# 2016-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.249034470360137e-05
#             Iterations: 252
#             Function evaluations: 30996
#             Gradient evaluations: 252
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.3170785740517745
#             Iterations: 83
#             Function evaluations: 9821
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.220459165023777e-09
#             Iterations: 56
#             Function evaluations: 6888
#             Gradient evaluations: 56
# 2016-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.859441211080812e-06
#             Iterations: 255
#             Function evaluations: 31621
#             Gradient evaluations: 255
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.126815666105456
#             Iterations: 97
#             Function evaluations: 11702
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.177289634071136e-08
#             Iterations: 43
#             Function evaluations: 5332
#             Gradient evaluations: 43
# 2016-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.700078943231016e-06
#             Iterations: 291
#             Function evaluations: 37248
#             Gradient evaluations: 291
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.072392308061966
#             Iterations: 106
#             Function evaluations: 13231
#             Gradient evaluations: 102
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1519367177619944e-08
#             Iterations: 29
#             Function evaluations: 3713
#             Gradient evaluations: 29
# 2017-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.135775406149373e-05
#             Iterations: 273
#             Function evaluations: 34945
#             Gradient evaluations: 273
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.2634379691518856
#             Iterations: 103
#             Function evaluations: 12915
#             Gradient evaluations: 99
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.537569719291355e-09
#             Iterations: 32
#             Function evaluations: 4096
#             Gradient evaluations: 32
# 2017-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2248243126161929e-05
#             Iterations: 244
#             Function evaluations: 31721
#             Gradient evaluations: 244
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.522193551657461
#             Iterations: 80
#             Function evaluations: 10512
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.025674553143205e-09
#             Iterations: 40
#             Function evaluations: 5201
#             Gradient evaluations: 40
# 2017-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2613569709541966e-05
#             Iterations: 254
#             Function evaluations: 32766
#             Gradient evaluations: 254
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.627634522652788
#             Iterations: 94
#             Function evaluations: 11792
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.793813600985576e-09
#             Iterations: 35
#             Function evaluations: 4516
#             Gradient evaluations: 35
# 2017-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6313420519127e-05
#             Iterations: 258
#             Function evaluations: 34830
#             Gradient evaluations: 258
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.854387669049658
#             Iterations: 175
#             Function evaluations: 23959
#             Gradient evaluations: 171
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3810356888071356e-09
#             Iterations: 57
#             Function evaluations: 7695
#             Gradient evaluations: 57
# 2018-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2772203740083162e-05
#             Iterations: 320
#             Function evaluations: 43521
#             Gradient evaluations: 320
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.094078415495233
#             Iterations: 236
#             Function evaluations: 32929
#             Gradient evaluations: 232
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.113278398986389e-08
#             Iterations: 29
#             Function evaluations: 3946
#             Gradient evaluations: 29
# 2018-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2702327660731919e-05
#             Iterations: 255
#             Function evaluations: 34170
#             Gradient evaluations: 255
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.192678557768289
#             Iterations: 172
#             Function evaluations: 23322
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.522270308677283e-09
#             Iterations: 54
#             Function evaluations: 7236
#             Gradient evaluations: 54
# 2018-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.282150419667626e-05
#             Iterations: 259
#             Function evaluations: 34707
#             Gradient evaluations: 259
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.319875802219611
#             Iterations: 189
#             Function evaluations: 25724
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.403806382812547e-09
#             Iterations: 43
#             Function evaluations: 5763
#             Gradient evaluations: 43
# 2018-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.252425724459968e-05
#             Iterations: 272
#             Function evaluations: 36177
#             Gradient evaluations: 272
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.258902388486191
#             Iterations: 119
#             Function evaluations: 15639
#             Gradient evaluations: 115
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.815305452770347e-09
#             Iterations: 39
#             Function evaluations: 5187
#             Gradient evaluations: 39
# 2019-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.871955144261823e-05
#             Iterations: 253
#             Function evaluations: 33143
#             Gradient evaluations: 253
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.163536459594349
#             Iterations: 84
#             Function evaluations: 11111
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2073631047917515e-09
#             Iterations: 40
#             Function evaluations: 5240
#             Gradient evaluations: 40
# 2019-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.581225284500052e-05
#             Iterations: 155
#             Function evaluations: 20616
#             Gradient evaluations: 155
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.602078107311391
#             Iterations: 65
#             Function evaluations: 8188
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.771378846044075e-10
#             Iterations: 94
#             Function evaluations: 12502
#             Gradient evaluations: 94
# 2019-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.165330452585465e-05
#             Iterations: 168
#             Function evaluations: 22848
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7828361199382794
#             Iterations: 92
#             Function evaluations: 12236
#             Gradient evaluations: 88
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.960409741837521e-10
#             Iterations: 93
#             Function evaluations: 12648
#             Gradient evaluations: 93
# 2019-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.099400897374872e-05
#             Iterations: 174
#             Function evaluations: 24708
#             Gradient evaluations: 174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.849662376664347
#             Iterations: 67
#             Function evaluations: 9005
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2225191339160474e-08
#             Iterations: 90
#             Function evaluations: 12781
#             Gradient evaluations: 90
# 2020-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.116359740513077e-05
#             Iterations: 168
#             Function evaluations: 24025
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.9658616460934715
#             Iterations: 68
#             Function evaluations: 9235
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.583536368223831e-10
#             Iterations: 98
#             Function evaluations: 14014
#             Gradient evaluations: 98
# 2020-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3115692857568978e-05
#             Iterations: 235
#             Function evaluations: 34310
#             Gradient evaluations: 235
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5.895855579058594
#             Iterations: 93
#             Function evaluations: 13126
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.462863030416491e-09
#             Iterations: 91
#             Function evaluations: 13287
#             Gradient evaluations: 91
# 2020-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9020893726018777e-05
#             Iterations: 268
#             Function evaluations: 39397
#             Gradient evaluations: 268
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.825841335654539
#             Iterations: 90
#             Function evaluations: 12761
#             Gradient evaluations: 86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.843814025626564e-09
#             Iterations: 61
#             Function evaluations: 8968
#             Gradient evaluations: 61
# 2020-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3600606143243473e-05
#             Iterations: 242
#             Function evaluations: 36784
#             Gradient evaluations: 242
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.432993241014148
#             Iterations: 115
#             Function evaluations: 17081
#             Gradient evaluations: 111
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5836595107466267e-09
#             Iterations: 63
#             Function evaluations: 9576
#             Gradient evaluations: 63
# 2021-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4665457552187402e-05
#             Iterations: 261
#             Function evaluations: 39672
#             Gradient evaluations: 261
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.722037226231271
#             Iterations: 90
#             Function evaluations: 13658
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.11603967053989e-09
#             Iterations: 32
#             Function evaluations: 4865
#             Gradient evaluations: 32
# 2021-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0239965989158137e-05
#             Iterations: 196
#             Function evaluations: 29989
#             Gradient evaluations: 196
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.124772356650604
#             Iterations: 82
#             Function evaluations: 12030
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.681180557996073e-09
#             Iterations: 44
#             Function evaluations: 6732
#             Gradient evaluations: 44
# 2021-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5462113421804e-05
#             Iterations: 213
#             Function evaluations: 32590
#             Gradient evaluations: 213
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.906055995575819
#             Iterations: 81
#             Function evaluations: 11874
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2292704468074918e-09
#             Iterations: 55
#             Function evaluations: 8416
#             Gradient evaluations: 55
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5527687349963467e-05
#             Iterations: 220
#             Function evaluations: 33440
#             Gradient evaluations: 220
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.184237198969174
#             Iterations: 107
#             Function evaluations: 15841
#             Gradient evaluations: 103
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3596794764361764e-09
#             Iterations: 44
#             Function evaluations: 6689
#             Gradient evaluations: 44
# 2022-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.347654587941491e-05
#             Iterations: 237
#             Function evaluations: 36498
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.302048877678489
#             Iterations: 79
#             Function evaluations: 12124
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.467616459442019e-09
#             Iterations: 56
#             Function evaluations: 8624
#             Gradient evaluations: 56
# 2022-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.546786741097154e-05
#             Iterations: 247
#             Function evaluations: 38286
#             Gradient evaluations: 247
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.0320146612446575
#             Iterations: 88
#             Function evaluations: 13147
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.463262316108444e-09
#             Iterations: 56
#             Function evaluations: 8680
#             Gradient evaluations: 56
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2294353817072064e-05
#             Iterations: 246
#             Function evaluations: 38622
#             Gradient evaluations: 246
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.444898212459175
#             Iterations: 98
#             Function evaluations: 14891
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.47255262819187e-09
#             Iterations: 44
#             Function evaluations: 6908
#             Gradient evaluations: 44
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0638443984101544e-05
#             Iterations: 262
#             Function evaluations: 39824
#             Gradient evaluations: 262
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.454284185655669
#             Iterations: 98
#             Function evaluations: 14444
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.342262248551165e-09
#             Iterations: 41
#             Function evaluations: 6233
#             Gradient evaluations: 41
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.063284841313195e-05
#             Iterations: 238
#             Function evaluations: 36414
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.3270842433776835
#             Iterations: 106
#             Function evaluations: 15777
#             Gradient evaluations: 102
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.321299048435709e-09
#             Iterations: 53
#             Function evaluations: 8109
#             Gradient evaluations: 53
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1447418857812869e-05
#             Iterations: 251
#             Function evaluations: 38153
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.19533116508335
#             Iterations: 132
#             Function evaluations: 19866
#             Gradient evaluations: 128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.521352585971489e-09
#             Iterations: 50
#             Function evaluations: 7600
#             Gradient evaluations: 50
# 2023-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2372712447469051e-05
#             Iterations: 271
#             Function evaluations: 41192
#             Gradient evaluations: 271
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.937598664593337
#             Iterations: 90
#             Function evaluations: 13659
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.144905305434035e-09
#             Iterations: 52
#             Function evaluations: 7904
#             Gradient evaluations: 52
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.090650657560652e-05
#             Iterations: 274
#             Function evaluations: 41648
#             Gradient evaluations: 274
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.42072094048574
#             Iterations: 124
#             Function evaluations: 18525
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.288669387680618e-09
#             Iterations: 49
#             Function evaluations: 7448
#             Gradient evaluations: 49
# 2024-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0351648265315334e-05
#             Iterations: 262
#             Function evaluations: 39824
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.32699970952182
#             Iterations: 93
#             Function evaluations: 14121
#             Gradient evaluations: 92
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.679937232841723e-09
#             Iterations: 54
#             Function evaluations: 8208
#             Gradient evaluations: 54
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_JSE.to_csv("returnsJSE_3Monate_f.csv")

# %% [markdown]
# ## Ledoit-Wolf Shrinkage

# %%
#Definition von Ledoit-Shrinkage

def ledoit_shrink (returns):
    
    shrinkage = LedoitWolf().fit(returns.values)
    
    shrinkage_matrix = pd.DataFrame(
        shrinkage.covariance_,
        index = returns.columns,
        columns = returns.columns)
    
    return shrinkage_matrix

# %% [markdown]
# ### Auswertung S&P500 mit Ledoit Wolf

# %%
returns = df_SP500.pct_change()
returns = returns.where(~df_SP500.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                    A  AAL  AAP      AAPL      ABBV      ABNB       ABT  \
# Date
# 2005-06-02  0.000414  NaN  NaN -0.006452       NaN       NaN -0.001448
# 2005-06-03 -0.005374  NaN  NaN -0.044955       NaN       NaN  0.000207
# 2005-06-06  0.019119  NaN  NaN -0.008368       NaN       NaN  0.003729
# 2005-06-07 -0.012235  NaN  NaN -0.036393       NaN       NaN  0.006398
# 2005-06-08  0.009496  NaN  NaN  0.010399       NaN       NaN -0.002051
# ...              ...  ...  ...       ...       ...       ...       ...
# 2025-05-23 -0.010485  NaN  NaN -0.030244  0.003944 -0.007286 -0.001521
# 2025-05-27  0.025154  NaN  NaN  0.025298  0.013424  0.021149  0.012490
# 2025-05-28 -0.003415  NaN  NaN  0.001049 -0.014161 -0.005641 -0.006920
# 2025-05-29  0.021645  NaN  NaN -0.002345  0.013818 -0.002409  0.006287
# 2025-05-30 -0.012006  NaN  NaN  0.004501  0.002640  0.004986  0.005495
#
#                 ACGL       ACN      ADBE  ...       XEL       XOM  XRAY  \
# Date                                      ...
# 2005-06-02       NaN       NaN -0.002712  ...  0.002678  0.002975   NaN
# 2005-06-03       NaN       NaN -0.016621  ...  0.004808 -0.002966   NaN
# 2005-06-06       NaN       NaN -0.002766  ...  0.000532  0.007874   NaN
# 2005-06-07       NaN       NaN -0.005855  ...  0.004251 -0.002604   NaN
# 2005-06-08       NaN       NaN  0.000000  ...  0.017460 -0.012533   NaN
# ...              ...       ...       ...  ...       ...       ...   ...
# 2025-05-23  0.001087 -0.021710 -0.016026  ...  0.007513  0.000583   NaN
# 2025-05-27  0.027696  0.018897  0.013270  ...  0.001147  0.004756   NaN
# 2025-05-28 -0.017332  0.001775 -0.002106  ... -0.012606 -0.013621   NaN
# 2025-05-29  0.013121  0.005507  0.002741  ...  0.007834  0.005680   NaN
# 2025-05-30  0.008917 -0.002864  0.004185  ...  0.009069 -0.003798   NaN
#
#                  XRX       XYL       YUM       ZBH      ZBRA      ZION  \
# Date
# 2005-06-02 -0.003650       NaN  0.021558  0.002885       NaN  0.005945
# 2005-06-03 -0.006593       NaN -0.010646  0.029816       NaN -0.008246
# 2005-06-06 -0.011062       NaN -0.000769 -0.005079       NaN -0.000139
# 2005-06-07 -0.006711       NaN  0.003077  0.013657       NaN -0.002772
# 2005-06-08  0.039039       NaN -0.006518 -0.005414       NaN -0.002085
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23       NaN -0.009739 -0.000344  0.010581 -0.014392       NaN
# 2025-05-27       NaN  0.017654 -0.009350  0.016947  0.038000       NaN
# 2025-05-28       NaN -0.004674 -0.006524 -0.020380 -0.014271       NaN
# 2025-05-29       NaN  0.000080  0.006217  0.011377  0.005846       NaN
# 2025-05-30       NaN  0.003024 -0.000694 -0.012535 -0.009333       NaN
#
#                  ZTS
# Date
# 2005-06-02       NaN
# 2005-06-03       NaN
# 2005-06-06       NaN
# 2005-06-07       NaN
# 2005-06-08       NaN
# ...              ...
# 2025-05-23  0.003766
# 2025-05-27  0.022635
# 2025-05-28 -0.005173
# 2025-05-29  0.010520
# 2025-05-30  0.008915
#
# [5031 rows x 598 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 3
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = ledoit_shrink(training_daten)
    
    #aus der geschrumpften Matrix die Korrelationsmatrix bauen
    standardabweichung = np.sqrt(np.diag(cov_matrix))
    corr_matrix = cov_matrix / np.outer(standardabweichung, standardabweichung)
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    shrinked_gewichte_equally_weighted = equally_weighted(training_daten)
    shrinked_gewichte_min_variance= min_variance_opt(cov_matrix)
    shrinked_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    shrinked_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    shrinked_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    shrinked_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    shrinked_gewichte_herc = herc_ledoit(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": shrinked_gewichte_equally_weighted,
    "Minimum-Variance": shrinked_gewichte_min_variance,
    "Maximum-Diversification": shrinked_gewichte_max_diversification,
    "Inverse-Volatility": shrinked_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": shrinked_gewichte_risk_parity,
    "HRP": shrinked_gewichte_hrp,
    "HERC": shrinked_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
     #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_shrinked = pd.concat(portfolio_returns_list)
portfolio_returns_df_shrinked = portfolio_returns_df_shrinked.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5288862200654737e-05
#             Iterations: 308
#             Function evaluations: 81312
#             Gradient evaluations: 308
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1767340633144645
#             Iterations: 80
#             Function evaluations: 20138
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.367469318835228e-09
#             Iterations: 9
#             Function evaluations: 2376
#             Gradient evaluations: 9
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6519176079888082e-05
#             Iterations: 259
#             Function evaluations: 69672
#             Gradient evaluations: 259
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.025200118337369
#             Iterations: 84
#             Function evaluations: 21605
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.285383763712697e-09
#             Iterations: 20
#             Function evaluations: 5381
#             Gradient evaluations: 20
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.437936973290573e-05
#             Iterations: 299
#             Function evaluations: 81029
#             Gradient evaluations: 299
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1814314294424912
#             Iterations: 74
#             Function evaluations: 19038
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1732524466424905e-09
#             Iterations: 23
#             Function evaluations: 6233
#             Gradient evaluations: 23
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4495305558664684e-05
#             Iterations: 313
#             Function evaluations: 86075
#             Gradient evaluations: 313
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.049913410877277
#             Iterations: 74
#             Function evaluations: 20422
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5569513681205894e-09
#             Iterations: 27
#             Function evaluations: 7425
#             Gradient evaluations: 27
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5854763579769293e-05
#             Iterations: 280
#             Function evaluations: 77840
#             Gradient evaluations: 280
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0076215287471926
#             Iterations: 79
#             Function evaluations: 20930
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.724209090209557e-09
#             Iterations: 27
#             Function evaluations: 7506
#             Gradient evaluations: 27
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4630086756328893e-05
#             Iterations: 284
#             Function evaluations: 79236
#             Gradient evaluations: 284
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8709766024123082
#             Iterations: 81
#             Function evaluations: 21583
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6100921805939988e-09
#             Iterations: 20
#             Function evaluations: 5580
#             Gradient evaluations: 20
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1488954114940315e-05
#             Iterations: 262
#             Function evaluations: 74146
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5706775380278493
#             Iterations: 47
#             Function evaluations: 13064
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.659018115558484e-09
#             Iterations: 30
#             Function evaluations: 8490
#             Gradient evaluations: 30
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.0396231206694467e-05
#             Iterations: 223
#             Function evaluations: 63778
#             Gradient evaluations: 223
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5039352536128314
#             Iterations: 50
#             Function evaluations: 13201
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0867096287037956e-09
#             Iterations: 47
#             Function evaluations: 13442
#             Gradient evaluations: 47
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.5411428925910594e-05
#             Iterations: 246
#             Function evaluations: 71586
#             Gradient evaluations: 246
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6422651399028068
#             Iterations: 42
#             Function evaluations: 12262
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1484385309851184e-09
#             Iterations: 57
#             Function evaluations: 16588
#             Gradient evaluations: 57
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.482210527535818e-05
#             Iterations: 250
#             Function evaluations: 72500
#             Gradient evaluations: 250
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.685644465879097
#             Iterations: 78
#             Function evaluations: 21549
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.26720622307314e-09
#             Iterations: 83
#             Function evaluations: 24070
#             Gradient evaluations: 83
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001820995126410556
#             Iterations: 138
#             Function evaluations: 39883
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9624980418975846
#             Iterations: 27
#             Function evaluations: 7823
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.726086949250995e-10
#             Iterations: 82
#             Function evaluations: 23698
#             Gradient evaluations: 82
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021007277721837105
#             Iterations: 125
#             Function evaluations: 36376
#             Gradient evaluations: 125
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.920480095588607
#             Iterations: 28
#             Function evaluations: 8169
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5900742891644159e-10
#             Iterations: 97
#             Function evaluations: 28227
#             Gradient evaluations: 97
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00022759051948600625
#             Iterations: 120
#             Function evaluations: 35160
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8382220777257294
#             Iterations: 27
#             Function evaluations: 7931
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0108461465443225e-10
#             Iterations: 110
#             Function evaluations: 32231
#             Gradient evaluations: 110
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021805138601100731
#             Iterations: 104
#             Function evaluations: 30889
#             Gradient evaluations: 104
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.837479755165867
#             Iterations: 27
#             Function evaluations: 8035
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3112231541240667e-10
#             Iterations: 110
#             Function evaluations: 32670
#             Gradient evaluations: 110
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.898120367891826e-05
#             Iterations: 186
#             Function evaluations: 56916
#             Gradient evaluations: 186
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -2.3079595422915644
#             Iterations: 42
#             Function evaluations: 11667
#             Gradient evaluations: 38
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.4824526282761064e-10
#             Iterations: 148
#             Function evaluations: 45288
#             Gradient evaluations: 148
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.902836578490208e-05
#             Iterations: 175
#             Function evaluations: 53725
#             Gradient evaluations: 175
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -2.486760970765997
#             Iterations: 39
#             Function evaluations: 10786
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.224913529862806e-10
#             Iterations: 118
#             Function evaluations: 36226
#             Gradient evaluations: 118
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.606872635936402e-05
#             Iterations: 228
#             Function evaluations: 70908
#             Gradient evaluations: 228
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.418935210854871
#             Iterations: 54
#             Function evaluations: 15605
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0896213777467165e-09
#             Iterations: 68
#             Function evaluations: 21148
#             Gradient evaluations: 68
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.844419088174146e-05
#             Iterations: 222
#             Function evaluations: 70152
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2531944750889914
#             Iterations: 33
#             Function evaluations: 10457
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.446205292114152e-10
#             Iterations: 57
#             Function evaluations: 18012
#             Gradient evaluations: 57
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5673307771232926e-05
#             Iterations: 229
#             Function evaluations: 72593
#             Gradient evaluations: 229
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.183601304310304
#             Iterations: 32
#             Function evaluations: 10173
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.316995641430549e-10
#             Iterations: 50
#             Function evaluations: 15851
#             Gradient evaluations: 50
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.263717698879505e-05
#             Iterations: 219
#             Function evaluations: 70081
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2748445871117693
#             Iterations: 34
#             Function evaluations: 10912
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.534600173238857e-09
#             Iterations: 41
#             Function evaluations: 13120
#             Gradient evaluations: 41
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.719010609462341e-05
#             Iterations: 244
#             Function evaluations: 78568
#             Gradient evaluations: 244
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4831922099846517
#             Iterations: 42
#             Function evaluations: 13564
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4846273267511418e-09
#             Iterations: 37
#             Function evaluations: 11914
#             Gradient evaluations: 37
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5855919012863404e-05
#             Iterations: 213
#             Function evaluations: 68799
#             Gradient evaluations: 213
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0897764810406687
#             Iterations: 35
#             Function evaluations: 11335
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.156088721598232e-10
#             Iterations: 51
#             Function evaluations: 16473
#             Gradient evaluations: 51
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.8457770639930315e-05
#             Iterations: 199
#             Function evaluations: 64079
#             Gradient evaluations: 199
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8725828217002394
#             Iterations: 28
#             Function evaluations: 9042
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.106455339776744e-10
#             Iterations: 55
#             Function evaluations: 17711
#             Gradient evaluations: 55
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.992773102249184e-05
#             Iterations: 183
#             Function evaluations: 59293
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9995316483952912
#             Iterations: 35
#             Function evaluations: 10066
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.50653793320934e-10
#             Iterations: 56
#             Function evaluations: 18144
#             Gradient evaluations: 56
# 2011-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.8603318669103755e-05
#             Iterations: 192
#             Function evaluations: 62784
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9700289863502785
#             Iterations: 28
#             Function evaluations: 8847
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0960326692756335e-09
#             Iterations: 55
#             Function evaluations: 17986
#             Gradient evaluations: 55
# 2011-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0355934422769565e-05
#             Iterations: 230
#             Function evaluations: 75670
#             Gradient evaluations: 230
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2540966887926555
#             Iterations: 43
#             Function evaluations: 12864
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.83960097191843e-10
#             Iterations: 69
#             Function evaluations: 22701
#             Gradient evaluations: 69
# 2011-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9335014962132286e-05
#             Iterations: 283
#             Function evaluations: 93674
#             Gradient evaluations: 283
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -2.753876476357252
#             Iterations: 54
#             Function evaluations: 16599
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3134027221119618e-09
#             Iterations: 44
#             Function evaluations: 14564
#             Gradient evaluations: 44
# 2012-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0069355096303907e-05
#             Iterations: 293
#             Function evaluations: 98156
#             Gradient evaluations: 293
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7690303429187413
#             Iterations: 53
#             Function evaluations: 16479
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2040860573071035e-09
#             Iterations: 41
#             Function evaluations: 13735
#             Gradient evaluations: 41
# 2012-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2340183982570044e-05
#             Iterations: 304
#             Function evaluations: 103056
#             Gradient evaluations: 304
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.943986219070745
#             Iterations: 63
#             Function evaluations: 20066
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.449954259817849e-09
#             Iterations: 28
#             Function evaluations: 9492
#             Gradient evaluations: 28
# 2012-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4164345582536265e-05
#             Iterations: 305
#             Function evaluations: 104005
#             Gradient evaluations: 305
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0673104678714314
#             Iterations: 44
#             Function evaluations: 15045
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1763032051978054e-09
#             Iterations: 20
#             Function evaluations: 6820
#             Gradient evaluations: 20
# 2012-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2101113822722085e-05
#             Iterations: 297
#             Function evaluations: 101872
#             Gradient evaluations: 297
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.072848071608814
#             Iterations: 51
#             Function evaluations: 17196
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0228812299240512e-09
#             Iterations: 20
#             Function evaluations: 6860
#             Gradient evaluations: 20
# 2013-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3895509128982477e-05
#             Iterations: 323
#             Function evaluations: 111758
#             Gradient evaluations: 323
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0719672520357344
#             Iterations: 51
#             Function evaluations: 16306
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.012797801534697e-10
#             Iterations: 20
#             Function evaluations: 6920
#             Gradient evaluations: 20
# 2013-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.241691119160509e-05
#             Iterations: 325
#             Function evaluations: 112451
#             Gradient evaluations: 325
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8924460477950333
#             Iterations: 69
#             Function evaluations: 22562
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1224089542487606e-09
#             Iterations: 17
#             Function evaluations: 5882
#             Gradient evaluations: 17
# 2013-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7697071868276047e-05
#             Iterations: 330
#             Function evaluations: 115170
#             Gradient evaluations: 330
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0411213540940185
#             Iterations: 85
#             Function evaluations: 28358
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8987146743596675e-09
#             Iterations: 9
#             Function evaluations: 3141
#             Gradient evaluations: 9
# 2013-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8042824187095885e-05
#             Iterations: 293
#             Function evaluations: 103136
#             Gradient evaluations: 293
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9870217392161025
#             Iterations: 63
#             Function evaluations: 20823
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3872504091361484e-09
#             Iterations: 17
#             Function evaluations: 5984
#             Gradient evaluations: 17
# 2014-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.05385928015422e-05
#             Iterations: 330
#             Function evaluations: 117150
#             Gradient evaluations: 330
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8989875557801925
#             Iterations: 53
#             Function evaluations: 18868
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.362858835552247e-09
#             Iterations: 29
#             Function evaluations: 10295
#             Gradient evaluations: 29
# 2014-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5385269323259534e-05
#             Iterations: 288
#             Function evaluations: 103392
#             Gradient evaluations: 288
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8989502861047494
#             Iterations: 59
#             Function evaluations: 21235
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1126403516726485e-09
#             Iterations: 9
#             Function evaluations: 3231
#             Gradient evaluations: 9
# 2014-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.744460783183104e-05
#             Iterations: 281
#             Function evaluations: 101160
#             Gradient evaluations: 281
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.545225387864155
#             Iterations: 50
#             Function evaluations: 18050
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.155189270604822e-09
#             Iterations: 15
#             Function evaluations: 5400
#             Gradient evaluations: 15
# 2014-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.530322012727257e-05
#             Iterations: 270
#             Function evaluations: 97470
#             Gradient evaluations: 270
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.486570997852455
#             Iterations: 41
#             Function evaluations: 14842
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4051173353419573e-09
#             Iterations: 15
#             Function evaluations: 5415
#             Gradient evaluations: 15
# 2015-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.8586850372964555e-05
#             Iterations: 279
#             Function evaluations: 100999
#             Gradient evaluations: 279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4628900895410464
#             Iterations: 41
#             Function evaluations: 14882
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.198996661271112e-10
#             Iterations: 35
#             Function evaluations: 12670
#             Gradient evaluations: 35
# 2015-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.6406844147068126e-05
#             Iterations: 256
#             Function evaluations: 93696
#             Gradient evaluations: 256
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5590255843989813
#             Iterations: 45
#             Function evaluations: 16512
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.858617873928558e-10
#             Iterations: 47
#             Function evaluations: 17202
#             Gradient evaluations: 47
# 2015-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.773388281499987e-05
#             Iterations: 311
#             Function evaluations: 115692
#             Gradient evaluations: 311
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.786668618309396
#             Iterations: 67
#             Function evaluations: 23501
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1204516873031707e-09
#             Iterations: 44
#             Function evaluations: 16368
#             Gradient evaluations: 44
# 2015-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.182537731431589e-05
#             Iterations: 335
#             Function evaluations: 126630
#             Gradient evaluations: 335
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0221174817300716
#             Iterations: 51
#             Function evaluations: 19324
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.028364524480253e-09
#             Iterations: 44
#             Function evaluations: 16632
#             Gradient evaluations: 44
# 2016-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7701647847870905e-05
#             Iterations: 320
#             Function evaluations: 122241
#             Gradient evaluations: 320
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4627235203347357
#             Iterations: 67
#             Function evaluations: 24126
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.021599951223805e-09
#             Iterations: 33
#             Function evaluations: 12607
#             Gradient evaluations: 33
# 2016-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.474852253332147e-05
#             Iterations: 307
#             Function evaluations: 120652
#             Gradient evaluations: 307
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.477713831605218
#             Iterations: 100
#             Function evaluations: 37830
#             Gradient evaluations: 96
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9730166979299483e-09
#             Iterations: 27
#             Function evaluations: 10611
#             Gradient evaluations: 27
# 2016-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2730402661519455e-05
#             Iterations: 335
#             Function evaluations: 130651
#             Gradient evaluations: 335
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6307941290999017
#             Iterations: 94
#             Function evaluations: 35187
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4284501380370063e-09
#             Iterations: 17
#             Function evaluations: 6630
#             Gradient evaluations: 17
# 2016-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.234309146295767e-06
#             Iterations: 341
#             Function evaluations: 134013
#             Gradient evaluations: 341
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.555929718115689
#             Iterations: 118
#             Function evaluations: 44956
#             Gradient evaluations: 114
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.328112577096068e-09
#             Iterations: 9
#             Function evaluations: 3537
#             Gradient evaluations: 9
# 2017-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4298245269429804e-05
#             Iterations: 351
#             Function evaluations: 138996
#             Gradient evaluations: 351
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.804301091127934
#             Iterations: 93
#             Function evaluations: 35341
#             Gradient evaluations: 89
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.595200263452484e-09
#             Iterations: 9
#             Function evaluations: 3564
#             Gradient evaluations: 9
# 2017-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8915287300123126e-05
#             Iterations: 326
#             Function evaluations: 131052
#             Gradient evaluations: 326
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.4729103651229027
#             Iterations: 96
#             Function evaluations: 37089
#             Gradient evaluations: 92
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.996106257523446e-09
#             Iterations: 9
#             Function evaluations: 3619
#             Gradient evaluations: 9
# 2017-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.119474566583355e-05
#             Iterations: 346
#             Function evaluations: 140477
#             Gradient evaluations: 346
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.319475362111676
#             Iterations: 78
#             Function evaluations: 30117
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.053140322402451e-09
#             Iterations: 9
#             Function evaluations: 3655
#             Gradient evaluations: 9
# 2017-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.726437042699659e-05
#             Iterations: 310
#             Function evaluations: 126790
#             Gradient evaluations: 310
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.182355268261843
#             Iterations: 57
#             Function evaluations: 21724
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3933042177635975e-09
#             Iterations: 27
#             Function evaluations: 11044
#             Gradient evaluations: 27
# 2018-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.818420976684824e-05
#             Iterations: 342
#             Function evaluations: 139537
#             Gradient evaluations: 342
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9242026185563983
#             Iterations: 66
#             Function evaluations: 26582
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.819410191084081e-09
#             Iterations: 29
#             Function evaluations: 11832
#             Gradient evaluations: 29
# 2018-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3292154040244976e-05
#             Iterations: 312
#             Function evaluations: 128233
#             Gradient evaluations: 312
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1557063718252407
#             Iterations: 83
#             Function evaluations: 32558
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5432551846703383e-09
#             Iterations: 26
#             Function evaluations: 10687
#             Gradient evaluations: 26
# 2018-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9146992023260757e-05
#             Iterations: 299
#             Function evaluations: 123188
#             Gradient evaluations: 299
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.902636430279543
#             Iterations: 81
#             Function evaluations: 31803
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.707569550793781e-09
#             Iterations: 38
#             Function evaluations: 15656
#             Gradient evaluations: 38
# 2018-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.602191101496661e-05
#             Iterations: 313
#             Function evaluations: 129895
#             Gradient evaluations: 313
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.063561356350724
#             Iterations: 64
#             Function evaluations: 24956
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.091574734469855e-09
#             Iterations: 27
#             Function evaluations: 11206
#             Gradient evaluations: 27
# 2019-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5294166568282976e-05
#             Iterations: 329
#             Function evaluations: 137193
#             Gradient evaluations: 329
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.049616302048624
#             Iterations: 67
#             Function evaluations: 28004
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3122951646706552e-09
#             Iterations: 20
#             Function evaluations: 8341
#             Gradient evaluations: 20
# 2019-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.000141316680693862
#             Iterations: 163
#             Function evaluations: 68134
#             Gradient evaluations: 163
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0934910929549906
#             Iterations: 33
#             Function evaluations: 12147
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.35479783677063e-10
#             Iterations: 72
#             Function evaluations: 30097
#             Gradient evaluations: 72
# 2019-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00014481701350273538
#             Iterations: 182
#             Function evaluations: 76987
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.096322351804586
#             Iterations: 38
#             Function evaluations: 14407
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.763910647126907e-10
#             Iterations: 89
#             Function evaluations: 37647
#             Gradient evaluations: 89
# 2019-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015730036926424058
#             Iterations: 176
#             Function evaluations: 74800
#             Gradient evaluations: 176
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.08139264756494
#             Iterations: 39
#             Function evaluations: 14906
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0571410942232066e-09
#             Iterations: 87
#             Function evaluations: 36976
#             Gradient evaluations: 87
# 2020-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015712068901810322
#             Iterations: 183
#             Function evaluations: 78873
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.143548827737798
#             Iterations: 31
#             Function evaluations: 11662
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.206225577848953e-09
#             Iterations: 98
#             Function evaluations: 42239
#             Gradient evaluations: 98
# 2020-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.7037901978692004e-05
#             Iterations: 237
#             Function evaluations: 103095
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.043819528075898
#             Iterations: 60
#             Function evaluations: 24424
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4422139196253266e-09
#             Iterations: 57
#             Function evaluations: 24795
#             Gradient evaluations: 57
# 2020-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8175598275734862e-05
#             Iterations: 275
#             Function evaluations: 120450
#             Gradient evaluations: 275
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -3.3992728232226828
#             Iterations: 77
#             Function evaluations: 32065
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1836628441719586e-09
#             Iterations: 38
#             Function evaluations: 16645
#             Gradient evaluations: 38
# 2020-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1927390158292476e-05
#             Iterations: 332
#             Function evaluations: 145749
#             Gradient evaluations: 332
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5151323886742833
#             Iterations: 92
#             Function evaluations: 38738
#             Gradient evaluations: 88
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.223571108605845e-09
#             Iterations: 28
#             Function evaluations: 12292
#             Gradient evaluations: 28
# 2021-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.613924576809407e-05
#             Iterations: 301
#             Function evaluations: 132441
#             Gradient evaluations: 301
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.305864486725887
#             Iterations: 63
#             Function evaluations: 26018
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.682481331938526e-09
#             Iterations: 29
#             Function evaluations: 12760
#             Gradient evaluations: 29
# 2021-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6877128061027175e-05
#             Iterations: 262
#             Function evaluations: 116590
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.919324002144163
#             Iterations: 57
#             Function evaluations: 23640
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3828458764855572e-09
#             Iterations: 49
#             Function evaluations: 21805
#             Gradient evaluations: 49
# 2021-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.81144344044298e-05
#             Iterations: 223
#             Function evaluations: 99459
#             Gradient evaluations: 223
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.668170166838102
#             Iterations: 45
#             Function evaluations: 18323
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.968617572350938e-10
#             Iterations: 58
#             Function evaluations: 25868
#             Gradient evaluations: 58
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.241555407363865e-05
#             Iterations: 221
#             Function evaluations: 98787
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3736513283940344
#             Iterations: 39
#             Function evaluations: 15677
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0491657464190775e-09
#             Iterations: 55
#             Function evaluations: 24585
#             Gradient evaluations: 55
# 2022-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.23504545448216e-05
#             Iterations: 247
#             Function evaluations: 111645
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2919781302503823
#             Iterations: 37
#             Function evaluations: 16758
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.854199738425759e-10
#             Iterations: 56
#             Function evaluations: 25312
#             Gradient evaluations: 56
# 2022-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.955710483599318e-05
#             Iterations: 259
#             Function evaluations: 117845
#             Gradient evaluations: 259
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.375203312614296
#             Iterations: 51
#             Function evaluations: 21428
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.045396827871205e-09
#             Iterations: 57
#             Function evaluations: 25935
#             Gradient evaluations: 57
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.331026049584358e-05
#             Iterations: 257
#             Function evaluations: 117963
#             Gradient evaluations: 257
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.565059554281029
#             Iterations: 57
#             Function evaluations: 24378
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1902923412066283e-09
#             Iterations: 49
#             Function evaluations: 22491
#             Gradient evaluations: 49
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6289281518743266e-05
#             Iterations: 307
#             Function evaluations: 140913
#             Gradient evaluations: 307
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1008369745854174
#             Iterations: 64
#             Function evaluations: 27597
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9941818830023595e-09
#             Iterations: 38
#             Function evaluations: 17442
#             Gradient evaluations: 38
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0867412983171988e-05
#             Iterations: 274
#             Function evaluations: 126315
#             Gradient evaluations: 274
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.410704314315158
#             Iterations: 83
#             Function evaluations: 36506
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.982401576935507e-09
#             Iterations: 44
#             Function evaluations: 20285
#             Gradient evaluations: 44
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.694466767878057e-05
#             Iterations: 333
#             Function evaluations: 153846
#             Gradient evaluations: 333
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8161391473344555
#             Iterations: 91
#             Function evaluations: 40278
#             Gradient evaluations: 87
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9297177447261065e-09
#             Iterations: 38
#             Function evaluations: 17556
#             Gradient evaluations: 38
# 2023-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.54419531492404e-05
#             Iterations: 278
#             Function evaluations: 128992
#             Gradient evaluations: 278
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.144359064483878
#             Iterations: 95
#             Function evaluations: 42322
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3870891804065046e-09
#             Iterations: 36
#             Function evaluations: 16704
#             Gradient evaluations: 36
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3830694044519194e-05
#             Iterations: 306
#             Function evaluations: 142902
#             Gradient evaluations: 306
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.4353991787064535
#             Iterations: 100
#             Function evaluations: 44944
#             Gradient evaluations: 96
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6403127585131448e-09
#             Iterations: 20
#             Function evaluations: 9340
#             Gradient evaluations: 20
# 2024-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.428331056071716e-05
#             Iterations: 267
#             Function evaluations: 124689
#             Gradient evaluations: 267
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4.5833688030994955
#             Iterations: 114
#             Function evaluations: 51513
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7579113537867115e-09
#             Iterations: 28
#             Function evaluations: 13076
#             Gradient evaluations: 28
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_shrinked.to_csv("returnssp500shrinked_3Monate_f.csv")

# %% [markdown]
# ### Auswertung JSE mit Ledoit Wolf

# %%
returns = df_JSE.pct_change()
returns = returns.where(~df_JSE.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of               4SI.JO    ABG.JO    ACL.JO    ACT.JO    ADH.JO    AEL.JO  \
# Date
# 2005-06-02       NaN  0.001214 -0.006225  0.000000 -0.014598       NaN
# 2005-06-03       NaN  0.001333  0.000000  0.000000  0.000000       NaN
# 2005-06-06       NaN  0.003510  0.014953  0.000000  0.007407       NaN
# 2005-06-07       NaN  0.006634 -0.035437  0.146154 -0.007353       NaN
# 2005-06-08       NaN -0.005392 -0.029721  0.000000  0.007407       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-26  0.000000  0.007235 -0.018018  0.000000  0.005975  0.000426
# 2025-05-27  0.000000  0.000178 -0.036697  0.000000  0.003439  0.000000
# 2025-05-28  0.042857  0.026828 -0.038095  0.087500  0.022741  0.002128
# 2025-05-29 -0.041096  0.016127  0.049505 -0.045977 -0.010966  0.002972
# 2025-05-30  0.000000 -0.014051  0.094340 -0.036145 -0.009855 -0.001693
#
#               AFE.JO    AFH.JO    AFT.JO    AGL.JO  ...    VKE.JO    VOD.JO  \
# Date                                                ...
# 2005-06-02  0.020642       NaN       NaN  0.005481  ...       NaN  0.017117
# 2005-06-03  0.000000       NaN       NaN  0.000000  ...       NaN  0.000000
# 2005-06-06  0.000000       NaN       NaN -0.019079  ...       NaN  0.045350
# 2005-06-07  0.000225       NaN       NaN -0.020994  ...       NaN -0.000169
# 2005-06-08  0.011009       NaN       NaN  0.014191  ...       NaN -0.025424
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-26  0.007992  0.032548 -0.002564  0.029137  ... -0.010417 -0.016292
# 2025-05-27  0.007252 -0.026087  0.026498 -0.018270  ...  0.006316  0.002971
# 2025-05-28  0.002592  0.017857  0.000000 -0.008829  ...  0.001046 -0.006294
# 2025-05-29 -0.011298 -0.013158 -0.008476 -0.005631  ...  0.014107  0.031967
# 2025-05-30  0.000872 -0.011111  0.010297  0.016932  ...  0.030912 -0.005199
#
#               WBC.JO    WBO.JO    WEZ.JO    WHL.JO    YRK.JO  YYLBEE.JO  \
# Date
# 2005-06-02       NaN  0.009434       NaN  0.009901  0.000000        NaN
# 2005-06-03       NaN  0.000000       NaN  0.000000  0.000000        NaN
# 2005-06-06       NaN  0.009346       NaN  0.026471  0.000000        NaN
# 2005-06-07       NaN  0.000000       NaN  0.012416  0.000000        NaN
# 2005-06-08       NaN  0.018519       NaN -0.027358  0.000000        NaN
# ...              ...       ...       ...       ...       ...        ...
# 2025-05-26  0.021277 -0.005745  0.111111 -0.000174  0.046154        0.0
# 2025-05-27  0.015625  0.007979 -0.100000 -0.008726  0.000000        0.0
# 2025-05-28 -0.010872 -0.018234 -0.022222  0.014965 -0.083333        0.0
# 2025-05-29  0.013895 -0.005505  0.022727  0.016132  0.016043        0.0
# 2025-05-30  0.002250  0.014985 -0.044444  0.000341  0.026316        0.0
#
#               ZED.JO    ZZD.JO
# Date
# 2005-06-02       NaN       NaN
# 2005-06-03       NaN       NaN
# 2005-06-06       NaN       NaN
# 2005-06-07       NaN       NaN
# 2005-06-08       NaN       NaN
# ...              ...       ...
# 2025-05-26 -0.008264 -0.000864
# 2025-05-27 -0.016667  0.037165
# 2025-05-28  0.059322  0.008333
# 2025-05-29  0.008000 -0.008264
# 2025-05-30  0.023810 -0.012500
#
# [5170 rows x 217 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 3
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = ledoit_shrink(training_daten)
    
    #aus der geschrumpften Matrix die Korrelationsmatrix bauen
    standardabweichung = np.sqrt(np.diag(cov_matrix))
    corr_matrix = cov_matrix / np.outer(standardabweichung, standardabweichung)
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    shrinked_JSE_gewichte_equally_weighted = equally_weighted(training_daten)
    shrinked_JSE_gewichte_min_variance= min_variance_opt(cov_matrix)
    shrinked_JSE_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    shrinked_JSE_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    shrinked_JSE_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    shrinked_JSE_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    shrinked_JSE_gewichte_herc = herc_ledoit(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": shrinked_JSE_gewichte_equally_weighted,
    "Minimum-Variance": shrinked_JSE_gewichte_min_variance,
    "Maximum-Diversification": shrinked_JSE_gewichte_max_diversification,
    "Inverse-Volatility": shrinked_JSE_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": shrinked_JSE_gewichte_risk_parity,
    "HRP": shrinked_JSE_gewichte_hrp,
    "HERC": shrinked_JSE_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
    #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_shrinked_JSE = pd.concat(portfolio_returns_list)
portfolio_returns_df_shrinked_JSE = portfolio_returns_df_shrinked_JSE.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.240047133151458e-05
#             Iterations: 135
#             Function evaluations: 9045
#             Gradient evaluations: 135
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.741709713501023
#             Iterations: 43
#             Function evaluations: 2923
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.635081070068458e-09
#             Iterations: 44
#             Function evaluations: 2949
#             Gradient evaluations: 44
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.140650188809402e-05
#             Iterations: 128
#             Function evaluations: 8449
#             Gradient evaluations: 128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.298075148819085
#             Iterations: 25
#             Function evaluations: 1675
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2267500347011322e-09
#             Iterations: 54
#             Function evaluations: 3564
#             Gradient evaluations: 54
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.759283023010051e-05
#             Iterations: 111
#             Function evaluations: 7437
#             Gradient evaluations: 111
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3843643115261814
#             Iterations: 35
#             Function evaluations: 2379
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.437453723671651e-09
#             Iterations: 54
#             Function evaluations: 3618
#             Gradient evaluations: 54
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.477274564945196e-05
#             Iterations: 121
#             Function evaluations: 8107
#             Gradient evaluations: 121
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.657441344982965
#             Iterations: 37
#             Function evaluations: 2517
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3843497511213926e-10
#             Iterations: 66
#             Function evaluations: 4422
#             Gradient evaluations: 66
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.0941687700587895e-05
#             Iterations: 134
#             Function evaluations: 9783
#             Gradient evaluations: 134
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.860032031297268
#             Iterations: 42
#             Function evaluations: 3109
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1432680447431062e-09
#             Iterations: 43
#             Function evaluations: 3140
#             Gradient evaluations: 43
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3792189085924488e-05
#             Iterations: 126
#             Function evaluations: 9954
#             Gradient evaluations: 126
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.476428286234817
#             Iterations: 59
#             Function evaluations: 4725
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.717964459954263e-09
#             Iterations: 32
#             Function evaluations: 2528
#             Gradient evaluations: 32
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.087957926694156e-05
#             Iterations: 110
#             Function evaluations: 8690
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1602935625747772
#             Iterations: 52
#             Function evaluations: 4163
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7372832252766733e-09
#             Iterations: 32
#             Function evaluations: 2529
#             Gradient evaluations: 32
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.72847097516905e-05
#             Iterations: 131
#             Function evaluations: 10349
#             Gradient evaluations: 131
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9847225437806864
#             Iterations: 47
#             Function evaluations: 3762
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.420404610443119e-09
#             Iterations: 32
#             Function evaluations: 2528
#             Gradient evaluations: 32
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.643368781322188e-05
#             Iterations: 137
#             Function evaluations: 10549
#             Gradient evaluations: 137
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.048045456084472
#             Iterations: 44
#             Function evaluations: 3436
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.311800058952099e-09
#             Iterations: 32
#             Function evaluations: 2465
#             Gradient evaluations: 32
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7374717646565137e-05
#             Iterations: 129
#             Function evaluations: 10191
#             Gradient evaluations: 129
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5415046180404945
#             Iterations: 56
#             Function evaluations: 4482
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4927633065416513e-09
#             Iterations: 42
#             Function evaluations: 3319
#             Gradient evaluations: 42
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.968856024233593e-05
#             Iterations: 131
#             Function evaluations: 10349
#             Gradient evaluations: 131
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0266834390907653
#             Iterations: 45
#             Function evaluations: 3598
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.25467040869184e-10
#             Iterations: 72
#             Function evaluations: 5689
#             Gradient evaluations: 72
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.18240230419097e-05
#             Iterations: 139
#             Function evaluations: 10703
#             Gradient evaluations: 139
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.106911290040022
#             Iterations: 41
#             Function evaluations: 3191
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.646488257211404e-10
#             Iterations: 93
#             Function evaluations: 7162
#             Gradient evaluations: 93
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.926593454572408e-05
#             Iterations: 138
#             Function evaluations: 10488
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1478877285111393
#             Iterations: 43
#             Function evaluations: 3308
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.42068619686613e-10
#             Iterations: 102
#             Function evaluations: 7753
#             Gradient evaluations: 102
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.92960378759943e-05
#             Iterations: 133
#             Function evaluations: 10108
#             Gradient evaluations: 133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0724485311548997
#             Iterations: 41
#             Function evaluations: 3154
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.224914217875113e-10
#             Iterations: 100
#             Function evaluations: 7600
#             Gradient evaluations: 100
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.647199920292808e-05
#             Iterations: 115
#             Function evaluations: 8740
#             Gradient evaluations: 115
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.654621985421839
#             Iterations: 75
#             Function evaluations: 5573
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9939544023606628e-09
#             Iterations: 97
#             Function evaluations: 7372
#             Gradient evaluations: 97
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.267154347622474e-05
#             Iterations: 147
#             Function evaluations: 12496
#             Gradient evaluations: 147
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.983834041477756
#             Iterations: 66
#             Function evaluations: 5678
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.879356792868467e-09
#             Iterations: 74
#             Function evaluations: 6290
#             Gradient evaluations: 74
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8153770030270403e-05
#             Iterations: 170
#             Function evaluations: 14621
#             Gradient evaluations: 170
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7886938509749917
#             Iterations: 54
#             Function evaluations: 4697
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.270719421979131e-09
#             Iterations: 65
#             Function evaluations: 5590
#             Gradient evaluations: 65
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6819380345921573e-05
#             Iterations: 157
#             Function evaluations: 13345
#             Gradient evaluations: 157
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6642304044306746
#             Iterations: 52
#             Function evaluations: 4470
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.652015033217826e-09
#             Iterations: 57
#             Function evaluations: 4845
#             Gradient evaluations: 57
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3425255540648984e-05
#             Iterations: 194
#             Function evaluations: 16685
#             Gradient evaluations: 194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.790561769183912
#             Iterations: 53
#             Function evaluations: 4609
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.861520924817331e-09
#             Iterations: 45
#             Function evaluations: 3871
#             Gradient evaluations: 45
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.320457799439238e-05
#             Iterations: 198
#             Function evaluations: 17623
#             Gradient evaluations: 198
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.1555827594152435
#             Iterations: 60
#             Function evaluations: 5403
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.560884187719331e-09
#             Iterations: 45
#             Function evaluations: 4006
#             Gradient evaluations: 45
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1731184282451759e-05
#             Iterations: 140
#             Function evaluations: 12180
#             Gradient evaluations: 140
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.504080772613403
#             Iterations: 70
#             Function evaluations: 6177
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.471360350979723e-09
#             Iterations: 19
#             Function evaluations: 1654
#             Gradient evaluations: 19
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2247991509230852e-05
#             Iterations: 169
#             Function evaluations: 15379
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.303989571545447
#             Iterations: 71
#             Function evaluations: 6546
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.944582451963373e-09
#             Iterations: 22
#             Function evaluations: 2002
#             Gradient evaluations: 22
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4050772268941719e-05
#             Iterations: 173
#             Function evaluations: 15916
#             Gradient evaluations: 173
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.978781073713074
#             Iterations: 54
#             Function evaluations: 5029
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0552948409255226e-09
#             Iterations: 46
#             Function evaluations: 4232
#             Gradient evaluations: 46
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3276772878053364e-05
#             Iterations: 188
#             Function evaluations: 16920
#             Gradient evaluations: 188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.778654766079397
#             Iterations: 67
#             Function evaluations: 6095
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1768392202319173e-09
#             Iterations: 46
#             Function evaluations: 4140
#             Gradient evaluations: 46
# 2011-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2449660994183539e-05
#             Iterations: 236
#             Function evaluations: 21476
#             Gradient evaluations: 236
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.477138943138827
#             Iterations: 57
#             Function evaluations: 5242
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.6990165342171655e-09
#             Iterations: 45
#             Function evaluations: 4096
#             Gradient evaluations: 45
# 2011-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.031471054283104e-05
#             Iterations: 184
#             Function evaluations: 16928
#             Gradient evaluations: 184
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.087361893195729
#             Iterations: 63
#             Function evaluations: 5859
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.128987067954324e-09
#             Iterations: 46
#             Function evaluations: 4232
#             Gradient evaluations: 46
# 2011-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.627092253701041e-06
#             Iterations: 211
#             Function evaluations: 19202
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.4454087192788405
#             Iterations: 72
#             Function evaluations: 6644
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.959406747874755e-09
#             Iterations: 23
#             Function evaluations: 2093
#             Gradient evaluations: 23
# 2012-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0299547753998776e-05
#             Iterations: 203
#             Function evaluations: 19083
#             Gradient evaluations: 203
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.504434542571547
#             Iterations: 74
#             Function evaluations: 7047
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.999208205351631e-09
#             Iterations: 20
#             Function evaluations: 1880
#             Gradient evaluations: 20
# 2012-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1066933515874225e-05
#             Iterations: 185
#             Function evaluations: 17760
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.606323229606496
#             Iterations: 82
#             Function evaluations: 7975
#             Gradient evaluations: 82
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.954653945999391e-09
#             Iterations: 23
#             Function evaluations: 2209
#             Gradient evaluations: 23
# 2012-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5308729653365244e-05
#             Iterations: 178
#             Function evaluations: 17266
#             Gradient evaluations: 178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.089678174434176
#             Iterations: 69
#             Function evaluations: 6771
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0078177502602953e-09
#             Iterations: 30
#             Function evaluations: 2910
#             Gradient evaluations: 30
# 2012-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3664901737745573e-05
#             Iterations: 203
#             Function evaluations: 20706
#             Gradient evaluations: 203
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.401987751887777
#             Iterations: 77
#             Function evaluations: 7946
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.708348168193682e-09
#             Iterations: 33
#             Function evaluations: 3366
#             Gradient evaluations: 33
# 2013-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4128484217860057e-05
#             Iterations: 169
#             Function evaluations: 17577
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.519580117537739
#             Iterations: 76
#             Function evaluations: 7888
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.679106285686064e-09
#             Iterations: 41
#             Function evaluations: 4264
#             Gradient evaluations: 41
# 2013-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.216044405350579e-05
#             Iterations: 187
#             Function evaluations: 19261
#             Gradient evaluations: 187
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.545714313127898
#             Iterations: 76
#             Function evaluations: 7920
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.327310007470385e-09
#             Iterations: 34
#             Function evaluations: 3502
#             Gradient evaluations: 34
# 2013-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.89743692357566e-06
#             Iterations: 193
#             Function evaluations: 19879
#             Gradient evaluations: 193
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.8914753849011054
#             Iterations: 84
#             Function evaluations: 8764
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.513653614232996e-09
#             Iterations: 23
#             Function evaluations: 2369
#             Gradient evaluations: 23
# 2013-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.05465269399147e-05
#             Iterations: 188
#             Function evaluations: 20116
#             Gradient evaluations: 188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.894282184664312
#             Iterations: 132
#             Function evaluations: 14169
#             Gradient evaluations: 128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5388516038863008e-09
#             Iterations: 30
#             Function evaluations: 3210
#             Gradient evaluations: 30
# 2014-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.949950094717613e-06
#             Iterations: 175
#             Function evaluations: 18726
#             Gradient evaluations: 175
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.5364366030276555
#             Iterations: 142
#             Function evaluations: 15290
#             Gradient evaluations: 138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.3480777045195925e-09
#             Iterations: 27
#             Function evaluations: 2889
#             Gradient evaluations: 27
# 2014-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.775519475408268e-06
#             Iterations: 197
#             Function evaluations: 21670
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.583740802871609
#             Iterations: 86
#             Function evaluations: 9468
#             Gradient evaluations: 85
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.361627010061357e-09
#             Iterations: 33
#             Function evaluations: 3630
#             Gradient evaluations: 33
# 2014-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6676292689534363e-05
#             Iterations: 180
#             Function evaluations: 19980
#             Gradient evaluations: 180
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.773148238486261
#             Iterations: 124
#             Function evaluations: 13708
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.893687363371446e-09
#             Iterations: 43
#             Function evaluations: 4773
#             Gradient evaluations: 43
# 2014-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8566013187950675e-05
#             Iterations: 191
#             Function evaluations: 21775
#             Gradient evaluations: 191
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.7279886975414325
#             Iterations: 95
#             Function evaluations: 10577
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1600375681616035e-09
#             Iterations: 45
#             Function evaluations: 5130
#             Gradient evaluations: 45
# 2015-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.600218558200902e-05
#             Iterations: 171
#             Function evaluations: 20179
#             Gradient evaluations: 171
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.707335111509649
#             Iterations: 72
#             Function evaluations: 8579
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.030480214337207e-08
#             Iterations: 98
#             Function evaluations: 11565
#             Gradient evaluations: 98
# 2015-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6547529994544205e-05
#             Iterations: 183
#             Function evaluations: 21229
#             Gradient evaluations: 183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.564974938713104
#             Iterations: 132
#             Function evaluations: 15333
#             Gradient evaluations: 128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8594438800695453e-09
#             Iterations: 127
#             Function evaluations: 14732
#             Gradient evaluations: 127
# 2015-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2461890559207135e-05
#             Iterations: 181
#             Function evaluations: 21177
#             Gradient evaluations: 181
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.924266991542334
#             Iterations: 70
#             Function evaluations: 7800
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.067311367548393e-09
#             Iterations: 127
#             Function evaluations: 14859
#             Gradient evaluations: 127
# 2015-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2285118595324022e-05
#             Iterations: 186
#             Function evaluations: 22134
#             Gradient evaluations: 186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.903839156177115
#             Iterations: 73
#             Function evaluations: 8661
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7733937013792835e-08
#             Iterations: 82
#             Function evaluations: 9759
#             Gradient evaluations: 82
# 2016-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2577266973034856e-05
#             Iterations: 191
#             Function evaluations: 22920
#             Gradient evaluations: 191
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.576467031050202
#             Iterations: 98
#             Function evaluations: 11480
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8646413258457405e-09
#             Iterations: 76
#             Function evaluations: 9121
#             Gradient evaluations: 76
# 2016-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2404854818202158e-05
#             Iterations: 174
#             Function evaluations: 21402
#             Gradient evaluations: 174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.438562203746073
#             Iterations: 95
#             Function evaluations: 11321
#             Gradient evaluations: 91
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.813810542075803e-09
#             Iterations: 45
#             Function evaluations: 5535
#             Gradient evaluations: 45
# 2016-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.291705216497402e-06
#             Iterations: 190
#             Function evaluations: 23561
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.134250829011642
#             Iterations: 99
#             Function evaluations: 12305
#             Gradient evaluations: 98
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1164741175240055e-08
#             Iterations: 32
#             Function evaluations: 3968
#             Gradient evaluations: 32
# 2016-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.04940286826913e-06
#             Iterations: 208
#             Function evaluations: 26624
#             Gradient evaluations: 208
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.211149857112404
#             Iterations: 110
#             Function evaluations: 14132
#             Gradient evaluations: 109
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2262799784046653e-08
#             Iterations: 16
#             Function evaluations: 2048
#             Gradient evaluations: 16
# 2017-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1142269048372632e-05
#             Iterations: 185
#             Function evaluations: 23680
#             Gradient evaluations: 185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.517256132923581
#             Iterations: 102
#             Function evaluations: 13207
#             Gradient evaluations: 102
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.610600384285589e-09
#             Iterations: 34
#             Function evaluations: 4352
#             Gradient evaluations: 34
# 2017-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1717734080043806e-05
#             Iterations: 172
#             Function evaluations: 22361
#             Gradient evaluations: 172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.8054425182221046
#             Iterations: 110
#             Function evaluations: 14469
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.287192744002389e-09
#             Iterations: 29
#             Function evaluations: 3770
#             Gradient evaluations: 29
# 2017-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2808214819876585e-05
#             Iterations: 190
#             Function evaluations: 24510
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.770773860884618
#             Iterations: 95
#             Function evaluations: 12274
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.697522570557363e-09
#             Iterations: 40
#             Function evaluations: 5160
#             Gradient evaluations: 40
# 2017-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6109168058748373e-05
#             Iterations: 182
#             Function evaluations: 24570
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.998788344708309
#             Iterations: 102
#             Function evaluations: 13919
#             Gradient evaluations: 102
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.678727277228395e-09
#             Iterations: 45
#             Function evaluations: 6075
#             Gradient evaluations: 45
# 2018-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3597767883886157e-05
#             Iterations: 216
#             Function evaluations: 29376
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.283085391894829
#             Iterations: 107
#             Function evaluations: 14588
#             Gradient evaluations: 106
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.304177871374576e-09
#             Iterations: 32
#             Function evaluations: 4352
#             Gradient evaluations: 32
# 2018-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3297534114161534e-05
#             Iterations: 169
#             Function evaluations: 22647
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.387354260684945
#             Iterations: 104
#             Function evaluations: 14105
#             Gradient evaluations: 104
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.612544769991324e-09
#             Iterations: 31
#             Function evaluations: 4155
#             Gradient evaluations: 31
# 2018-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3570191512253911e-05
#             Iterations: 200
#             Function evaluations: 26801
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.450788219350911
#             Iterations: 103
#             Function evaluations: 13964
#             Gradient evaluations: 103
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.496024098148731e-09
#             Iterations: 47
#             Function evaluations: 6298
#             Gradient evaluations: 47
# 2018-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2778639202509757e-05
#             Iterations: 161
#             Function evaluations: 21413
#             Gradient evaluations: 161
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.591666280114728
#             Iterations: 116
#             Function evaluations: 15485
#             Gradient evaluations: 115
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.17660969113484e-09
#             Iterations: 21
#             Function evaluations: 2793
#             Gradient evaluations: 21
# 2019-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.790630533791902e-05
#             Iterations: 169
#             Function evaluations: 22140
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.448914485498906
#             Iterations: 99
#             Function evaluations: 13114
#             Gradient evaluations: 99
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.163043052238617e-09
#             Iterations: 28
#             Function evaluations: 3669
#             Gradient evaluations: 28
# 2019-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.337347582208673e-05
#             Iterations: 124
#             Function evaluations: 16492
#             Gradient evaluations: 124
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7924168099205358
#             Iterations: 70
#             Function evaluations: 9243
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.894477368222492e-10
#             Iterations: 85
#             Function evaluations: 11305
#             Gradient evaluations: 85
# 2019-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.062707413305782e-05
#             Iterations: 143
#             Function evaluations: 19448
#             Gradient evaluations: 143
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.001811867117194
#             Iterations: 70
#             Function evaluations: 9458
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.539377401232612e-10
#             Iterations: 84
#             Function evaluations: 11424
#             Gradient evaluations: 84
# 2019-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.958425790605818e-05
#             Iterations: 135
#             Function evaluations: 19170
#             Gradient evaluations: 135
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.0454098129435065
#             Iterations: 98
#             Function evaluations: 13565
#             Gradient evaluations: 94
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0178346886192908e-08
#             Iterations: 82
#             Function evaluations: 11644
#             Gradient evaluations: 82
# 2020-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.861630528387871e-05
#             Iterations: 109
#             Function evaluations: 15587
#             Gradient evaluations: 109
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -4.16294947539072
#             Iterations: 84
#             Function evaluations: 11557
#             Gradient evaluations: 80
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8604160167874334e-10
#             Iterations: 92
#             Function evaluations: 13156
#             Gradient evaluations: 92
# 2020-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3658625282578075e-05
#             Iterations: 144
#             Function evaluations: 21024
#             Gradient evaluations: 144
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.150033894953837
#             Iterations: 117
#             Function evaluations: 16681
#             Gradient evaluations: 113
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.961325510871079e-09
#             Iterations: 60
#             Function evaluations: 8761
#             Gradient evaluations: 60
# 2020-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8997467903475833e-05
#             Iterations: 157
#             Function evaluations: 23080
#             Gradient evaluations: 157
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.07041565542315
#             Iterations: 108
#             Function evaluations: 15892
#             Gradient evaluations: 107
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.839125326981554e-09
#             Iterations: 51
#             Function evaluations: 7498
#             Gradient evaluations: 51
# 2020-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4110048482834201e-05
#             Iterations: 178
#             Function evaluations: 27056
#             Gradient evaluations: 178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.6503839497106005
#             Iterations: 147
#             Function evaluations: 22173
#             Gradient evaluations: 143
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5971729097251633e-09
#             Iterations: 41
#             Function evaluations: 6232
#             Gradient evaluations: 41
# 2021-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.495547121193198e-05
#             Iterations: 162
#             Function evaluations: 24624
#             Gradient evaluations: 162
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.0190045973549395
#             Iterations: 129
#             Function evaluations: 19274
#             Gradient evaluations: 125
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.570441097146769e-09
#             Iterations: 21
#             Function evaluations: 3193
#             Gradient evaluations: 21
# 2021-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9900695134890912e-05
#             Iterations: 168
#             Function evaluations: 25704
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.345024796087156
#             Iterations: 99
#             Function evaluations: 15134
#             Gradient evaluations: 98
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.212569753231496e-09
#             Iterations: 29
#             Function evaluations: 4437
#             Gradient evaluations: 29
# 2021-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.479784779773589e-05
#             Iterations: 165
#             Function evaluations: 25246
#             Gradient evaluations: 165
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.105403879874858
#             Iterations: 104
#             Function evaluations: 15469
#             Gradient evaluations: 100
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.113786339267937e-09
#             Iterations: 33
#             Function evaluations: 5050
#             Gradient evaluations: 33
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4585913732774674e-05
#             Iterations: 165
#             Function evaluations: 25080
#             Gradient evaluations: 165
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.317671964533073
#             Iterations: 94
#             Function evaluations: 13798
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0167320243649784e-09
#             Iterations: 44
#             Function evaluations: 6689
#             Gradient evaluations: 44
# 2022-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2872282794757623e-05
#             Iterations: 159
#             Function evaluations: 24486
#             Gradient evaluations: 159
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5.418158766846241
#             Iterations: 103
#             Function evaluations: 15426
#             Gradient evaluations: 99
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.872179400998011e-09
#             Iterations: 45
#             Function evaluations: 6930
#             Gradient evaluations: 45
# 2022-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5738443665316624e-05
#             Iterations: 200
#             Function evaluations: 31000
#             Gradient evaluations: 200
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.1126443093321425
#             Iterations: 124
#             Function evaluations: 18888
#             Gradient evaluations: 120
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.123899862412964e-09
#             Iterations: 42
#             Function evaluations: 6510
#             Gradient evaluations: 42
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.277227946825808e-05
#             Iterations: 178
#             Function evaluations: 27946
#             Gradient evaluations: 178
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6.565085157911257
#             Iterations: 111
#             Function evaluations: 16964
#             Gradient evaluations: 107
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.758286945165632e-09
#             Iterations: 29
#             Function evaluations: 4553
#             Gradient evaluations: 29
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1409462134752712e-05
#             Iterations: 168
#             Function evaluations: 25537
#             Gradient evaluations: 168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.519824718728864
#             Iterations: 196
#             Function evaluations: 30029
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.131715040203033e-09
#             Iterations: 29
#             Function evaluations: 4408
#             Gradient evaluations: 29
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1511398837042306e-05
#             Iterations: 174
#             Function evaluations: 26622
#             Gradient evaluations: 174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.387257971855816
#             Iterations: 112
#             Function evaluations: 17156
#             Gradient evaluations: 111
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.026968865276022e-09
#             Iterations: 32
#             Function evaluations: 4896
#             Gradient evaluations: 32
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1719584563866186e-05
#             Iterations: 195
#             Function evaluations: 29640
#             Gradient evaluations: 195
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.3702292074409375
#             Iterations: 114
#             Function evaluations: 16896
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.855490068942064e-09
#             Iterations: 43
#             Function evaluations: 6536
#             Gradient evaluations: 43
# 2023-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2787933231790488e-05
#             Iterations: 190
#             Function evaluations: 28881
#             Gradient evaluations: 190
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.139025531300283
#             Iterations: 114
#             Function evaluations: 16909
#             Gradient evaluations: 110
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.9313089676045015e-09
#             Iterations: 40
#             Function evaluations: 6081
#             Gradient evaluations: 40
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1218483406704243e-05
#             Iterations: 182
#             Function evaluations: 27664
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.546489960492811
#             Iterations: 117
#             Function evaluations: 17817
#             Gradient evaluations: 116
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.036273113821135e-09
#             Iterations: 38
#             Function evaluations: 5776
#             Gradient evaluations: 38
# 2024-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1006025477233864e-05
#             Iterations: 192
#             Function evaluations: 29184
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -6.400094271349917
#             Iterations: 130
#             Function evaluations: 19373
#             Gradient evaluations: 126
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.07647594165725e-09
#             Iterations: 30
#             Function evaluations: 4561
#             Gradient evaluations: 30
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_shrinked_JSE.to_csv("returnsJSEshrinked_3Monate_f.csv")

# %% [markdown]
# ### Reduzierter S&P500-Bestand

# %%
returns = df_SP500_reduziert.pct_change()
returns = returns.where(~df_SP500_reduziert.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                    A      AAPL       ABT       ACN       ADI       ADM  \
# Date
# 2005-06-02  0.000414 -0.006452       NaN       NaN       NaN       NaN
# 2005-06-03 -0.005374 -0.044955       NaN       NaN       NaN       NaN
# 2005-06-06  0.019119 -0.008368       NaN       NaN       NaN       NaN
# 2005-06-07 -0.012235 -0.036393       NaN       NaN       NaN       NaN
# 2005-06-08  0.009496  0.010399       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23 -0.010485 -0.030244 -0.001521 -0.021710 -0.006889 -0.000417
# 2025-05-27  0.025154  0.025298  0.012490  0.018897  0.030503  0.014393
# 2025-05-28 -0.003415  0.001049 -0.006920  0.001775 -0.005856 -0.005758
# 2025-05-29  0.021645 -0.002345  0.006287  0.005507  0.000603  0.000414
# 2025-05-30 -0.012006  0.004501  0.005495 -0.002864 -0.008204 -0.002067
#
#                  ADP      ADSK       AES       AIZ  ...       VLO      VRSN  \
# Date                                                ...
# 2005-06-02       NaN       NaN -0.014875       NaN  ...       NaN       NaN
# 2005-06-03       NaN       NaN -0.011668       NaN  ...       NaN       NaN
# 2005-06-06       NaN       NaN  0.041667       NaN  ...       NaN       NaN
# 2005-06-07       NaN       NaN -0.004000       NaN  ...       NaN       NaN
# 2005-06-08       NaN       NaN -0.006693       NaN  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-23 -0.001741  0.001186  0.037383  0.018133  ... -0.001321 -0.007450
# 2025-05-27  0.014388  0.016963  0.008008  0.022797  ...  0.016803 -0.036460
# 2025-05-28 -0.004820 -0.003762 -0.036743 -0.015224  ... -0.028919 -0.001558
# 2025-05-29 -0.000062 -0.007452  0.036083  0.010205  ...  0.017569 -0.001709
# 2025-05-30  0.004350 -0.002963  0.003980  0.015103  ... -0.001471  0.014106
#
#                 VRTX       WAT       WFC       WRB       XEL       YUM  \
# Date
# 2005-06-02       NaN -0.013181  0.000488       NaN       NaN       NaN
# 2005-06-03       NaN -0.013614 -0.002925       NaN       NaN       NaN
# 2005-06-06       NaN -0.007292  0.001467       NaN       NaN       NaN
# 2005-06-07       NaN  0.004984 -0.001139       NaN       NaN       NaN
# 2005-06-08       NaN -0.009397  0.002118       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23  0.004539 -0.005998 -0.007630  0.012329  0.007513 -0.000344
# 2025-05-27  0.022936  0.034616  0.015927  0.015326  0.001147 -0.009350
# 2025-05-28 -0.002018 -0.010520 -0.003514 -0.012264 -0.012606 -0.006524
# 2025-05-29  0.004471  0.002002  0.010579  0.009142  0.007834  0.006217
# 2025-05-30 -0.011273 -0.017056  0.003624  0.009870  0.009069 -0.000694
#
#                  ZBH       ZTS
# Date
# 2005-06-02  0.002885       NaN
# 2005-06-03  0.029816       NaN
# 2005-06-06 -0.005079       NaN
# 2005-06-07  0.013657       NaN
# 2005-06-08 -0.005414       NaN
# ...              ...       ...
# 2025-05-23  0.010581  0.003766
# 2025-05-27  0.016947  0.022635
# 2025-05-28 -0.020380 -0.005173
# 2025-05-29  0.011377  0.010520
# 2025-05-30 -0.012535  0.008915
#
# [5031 rows x 217 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 3
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = training_daten.cov()
    corr_matrix = training_daten.corr()
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    reduziert_gewichte_equally_weighted = equally_weighted(training_daten)
    reduziert_gewichte_min_variance= min_variance_opt(cov_matrix)
    reduziert_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    reduziert_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    reduziert_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    reduziert_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    reduziert_gewichte_herc = herc(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": reduziert_gewichte_equally_weighted,
    "Minimum-Variance": reduziert_gewichte_min_variance,
    "Maximum-Diversification": reduziert_gewichte_max_diversification,
    "Inverse-Volatility": reduziert_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": reduziert_gewichte_risk_parity,
    "HRP": reduziert_gewichte_hrp,
    "HERC": reduziert_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
   #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_reduziert = pd.concat(portfolio_returns_list)
portfolio_returns_df_reduziert = portfolio_returns_df_reduziert.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.105745668140832e-05
#             Iterations: 279
#             Function evaluations: 28738
#             Gradient evaluations: 279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5646187894305896
#             Iterations: 48
#             Function evaluations: 4992
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3432286542379153e-09
#             Iterations: 21
#             Function evaluations: 2163
#             Gradient evaluations: 21
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1384621664736484e-05
#             Iterations: 283
#             Function evaluations: 29998
#             Gradient evaluations: 283
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5506938445117453
#             Iterations: 48
#             Function evaluations: 5131
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.913641850174231e-09
#             Iterations: 44
#             Function evaluations: 4664
#             Gradient evaluations: 44
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7242320876696093e-05
#             Iterations: 276
#             Function evaluations: 29808
#             Gradient evaluations: 276
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7375779238497473
#             Iterations: 44
#             Function evaluations: 4793
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.717893951070081e-09
#             Iterations: 33
#             Function evaluations: 3565
#             Gradient evaluations: 33
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8045309010623236e-05
#             Iterations: 232
#             Function evaluations: 26680
#             Gradient evaluations: 232
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5664963921865174
#             Iterations: 42
#             Function evaluations: 4871
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2103762411994074e-09
#             Iterations: 31
#             Function evaluations: 3565
#             Gradient evaluations: 31
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8512426769079306e-05
#             Iterations: 237
#             Function evaluations: 27255
#             Gradient evaluations: 237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.63464127491626
#             Iterations: 48
#             Function evaluations: 5566
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.45580888639446e-09
#             Iterations: 33
#             Function evaluations: 3795
#             Gradient evaluations: 33
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9051931845714717e-05
#             Iterations: 251
#             Function evaluations: 28865
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.503623245548528
#             Iterations: 35
#             Function evaluations: 4060
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.500219846103343e-09
#             Iterations: 31
#             Function evaluations: 3565
#             Gradient evaluations: 31
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.894864466267723e-05
#             Iterations: 196
#             Function evaluations: 22540
#             Gradient evaluations: 196
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2808865280057664
#             Iterations: 29
#             Function evaluations: 3363
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.446095214315517e-10
#             Iterations: 42
#             Function evaluations: 4830
#             Gradient evaluations: 42
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.979803493782623e-05
#             Iterations: 189
#             Function evaluations: 23058
#             Gradient evaluations: 189
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2607593090196136
#             Iterations: 28
#             Function evaluations: 3444
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.489963421677195e-10
#             Iterations: 52
#             Function evaluations: 6344
#             Gradient evaluations: 52
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.7048490895955775e-05
#             Iterations: 161
#             Function evaluations: 19643
#             Gradient evaluations: 161
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4198426399490716
#             Iterations: 26
#             Function evaluations: 3199
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.963852340402336e-10
#             Iterations: 61
#             Function evaluations: 7442
#             Gradient evaluations: 61
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.76141911573211e-05
#             Iterations: 181
#             Function evaluations: 22082
#             Gradient evaluations: 181
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4054828533999832
#             Iterations: 30
#             Function evaluations: 3687
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.107971396405399e-10
#             Iterations: 70
#             Function evaluations: 8540
#             Gradient evaluations: 70
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021683435857420012
#             Iterations: 137
#             Function evaluations: 16851
#             Gradient evaluations: 137
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7548626469308792
#             Iterations: 24
#             Function evaluations: 2964
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3982275054159253e-10
#             Iterations: 77
#             Function evaluations: 9472
#             Gradient evaluations: 77
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002384597536128936
#             Iterations: 128
#             Function evaluations: 16256
#             Gradient evaluations: 128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7404743931877384
#             Iterations: 20
#             Function evaluations: 2553
#             Gradient evaluations: 20
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5426438708922725e-10
#             Iterations: 92
#             Function evaluations: 11684
#             Gradient evaluations: 92
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00025583308322034274
#             Iterations: 124
#             Function evaluations: 15748
#             Gradient evaluations: 124
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.613187884690726
#             Iterations: 23
#             Function evaluations: 2934
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5837761727261757e-10
#             Iterations: 106
#             Function evaluations: 13462
#             Gradient evaluations: 106
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00023929683855949025
#             Iterations: 102
#             Function evaluations: 12954
#             Gradient evaluations: 102
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.6256061268392614
#             Iterations: 21
#             Function evaluations: 2678
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9477510387760127e-10
#             Iterations: 106
#             Function evaluations: 13463
#             Gradient evaluations: 106
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.777180197216622e-05
#             Iterations: 133
#             Function evaluations: 17025
#             Gradient evaluations: 133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9268162189633131
#             Iterations: 25
#             Function evaluations: 3222
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.590238221243204e-10
#             Iterations: 169
#             Function evaluations: 21632
#             Gradient evaluations: 169
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.2535248871501326e-05
#             Iterations: 174
#             Function evaluations: 24882
#             Gradient evaluations: 174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0940980244381833
#             Iterations: 30
#             Function evaluations: 4317
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.863064335660634e-10
#             Iterations: 124
#             Function evaluations: 17733
#             Gradient evaluations: 124
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.164507629975273e-05
#             Iterations: 216
#             Function evaluations: 30888
#             Gradient evaluations: 216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.172109462001486
#             Iterations: 24
#             Function evaluations: 3456
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.022232434998734e-10
#             Iterations: 60
#             Function evaluations: 8580
#             Gradient evaluations: 60
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.364155368295026e-05
#             Iterations: 204
#             Function evaluations: 29173
#             Gradient evaluations: 204
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.001268803694354
#             Iterations: 26
#             Function evaluations: 3736
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0553798428779177e-09
#             Iterations: 52
#             Function evaluations: 7437
#             Gradient evaluations: 52
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.844300962427632e-05
#             Iterations: 202
#             Function evaluations: 28886
#             Gradient evaluations: 202
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8768872885409864
#             Iterations: 22
#             Function evaluations: 3166
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.09847430124309e-10
#             Iterations: 52
#             Function evaluations: 7436
#             Gradient evaluations: 52
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5012311343739265e-05
#             Iterations: 219
#             Function evaluations: 31536
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9565537207827712
#             Iterations: 24
#             Function evaluations: 3478
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1833132953379095e-09
#             Iterations: 53
#             Function evaluations: 7632
#             Gradient evaluations: 53
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8883020484945623e-05
#             Iterations: 192
#             Function evaluations: 27648
#             Gradient evaluations: 192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.090384521476633
#             Iterations: 30
#             Function evaluations: 4345
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5512863541412775e-09
#             Iterations: 42
#             Function evaluations: 6048
#             Gradient evaluations: 42
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.015478876308629e-05
#             Iterations: 169
#             Function evaluations: 24336
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.770580941452506
#             Iterations: 22
#             Function evaluations: 3185
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0968027155596644e-09
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.505667875658841e-05
#             Iterations: 157
#             Function evaluations: 22608
#             Gradient evaluations: 157
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.640005742680439
#             Iterations: 23
#             Function evaluations: 3320
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.029443784068739e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.601508771402036e-05
#             Iterations: 153
#             Function evaluations: 22032
#             Gradient evaluations: 153
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.6937673384354575
#             Iterations: 23
#             Function evaluations: 3327
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.412881440174825e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.546143841377588e-05
#             Iterations: 167
#             Function evaluations: 24049
#             Gradient evaluations: 167
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.6881472706116354
#             Iterations: 23
#             Function evaluations: 3327
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.284455640759741e-10
#             Iterations: 69
#             Function evaluations: 9936
#             Gradient evaluations: 69
# 2011-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3326024854814725e-05
#             Iterations: 182
#             Function evaluations: 26208
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.985403756274886
#             Iterations: 25
#             Function evaluations: 3624
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.405250404735937e-10
#             Iterations: 79
#             Function evaluations: 11376
#             Gradient evaluations: 79
# 2011-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0727917074202175e-05
#             Iterations: 227
#             Function evaluations: 32688
#             Gradient evaluations: 227
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3730815343296707
#             Iterations: 29
#             Function evaluations: 4206
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2912423723529256e-09
#             Iterations: 51
#             Function evaluations: 7344
#             Gradient evaluations: 51
# 2012-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.165499640947141e-05
#             Iterations: 222
#             Function evaluations: 31968
#             Gradient evaluations: 222
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2920915840044294
#             Iterations: 33
#             Function evaluations: 4779
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1813111072516415e-09
#             Iterations: 42
#             Function evaluations: 6048
#             Gradient evaluations: 42
# 2012-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.488922451301833e-05
#             Iterations: 219
#             Function evaluations: 31536
#             Gradient evaluations: 219
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.328303118811972
#             Iterations: 29
#             Function evaluations: 4204
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1075803627998335e-09
#             Iterations: 42
#             Function evaluations: 6048
#             Gradient evaluations: 42
# 2012-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6864996510681324e-05
#             Iterations: 293
#             Function evaluations: 42192
#             Gradient evaluations: 293
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.38783220995233
#             Iterations: 30
#             Function evaluations: 4349
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5971785543767424e-09
#             Iterations: 20
#             Function evaluations: 2881
#             Gradient evaluations: 20
# 2012-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.456568860726161e-05
#             Iterations: 295
#             Function evaluations: 42480
#             Gradient evaluations: 295
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.51147696966176
#             Iterations: 36
#             Function evaluations: 5217
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5203843538537465e-09
#             Iterations: 21
#             Function evaluations: 3024
#             Gradient evaluations: 21
# 2013-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.668296696100088e-05
#             Iterations: 295
#             Function evaluations: 44250
#             Gradient evaluations: 295
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4461518012393153
#             Iterations: 36
#             Function evaluations: 5434
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.223392393764197e-09
#             Iterations: 21
#             Function evaluations: 3150
#             Gradient evaluations: 21
# 2013-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.451840393903582e-05
#             Iterations: 270
#             Function evaluations: 40501
#             Gradient evaluations: 270
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4191837788538755
#             Iterations: 30
#             Function evaluations: 4530
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8312719187840977e-09
#             Iterations: 21
#             Function evaluations: 3150
#             Gradient evaluations: 21
# 2013-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.00457040908652e-05
#             Iterations: 275
#             Function evaluations: 41250
#             Gradient evaluations: 275
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.483708789151378
#             Iterations: 44
#             Function evaluations: 6640
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7709789897772997e-09
#             Iterations: 20
#             Function evaluations: 3000
#             Gradient evaluations: 20
# 2013-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.063895964394697e-05
#             Iterations: 266
#             Function evaluations: 39900
#             Gradient evaluations: 266
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.374439102676294
#             Iterations: 40
#             Function evaluations: 6040
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2186523183895964e-09
#             Iterations: 21
#             Function evaluations: 3150
#             Gradient evaluations: 21
# 2014-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3254642070109836e-05
#             Iterations: 273
#             Function evaluations: 43407
#             Gradient evaluations: 273
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.479173070109636
#             Iterations: 40
#             Function evaluations: 6400
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4690041936665439e-09
#             Iterations: 33
#             Function evaluations: 5247
#             Gradient evaluations: 33
# 2014-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8614689532931154e-05
#             Iterations: 246
#             Function evaluations: 39114
#             Gradient evaluations: 246
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.337493695358802
#             Iterations: 34
#             Function evaluations: 5440
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1501909764361208e-09
#             Iterations: 20
#             Function evaluations: 3180
#             Gradient evaluations: 20
# 2014-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.195036326640111e-05
#             Iterations: 253
#             Function evaluations: 40227
#             Gradient evaluations: 253
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0890213975264187
#             Iterations: 30
#             Function evaluations: 4800
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8679385328812764e-09
#             Iterations: 20
#             Function evaluations: 3180
#             Gradient evaluations: 20
# 2014-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.008895660820242e-05
#             Iterations: 238
#             Function evaluations: 38081
#             Gradient evaluations: 238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.068340479112556
#             Iterations: 30
#             Function evaluations: 4827
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.482666260881535e-10
#             Iterations: 30
#             Function evaluations: 4800
#             Gradient evaluations: 30
# 2015-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.1213480953968884e-05
#             Iterations: 287
#             Function evaluations: 47929
#             Gradient evaluations: 287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.111339153895346
#             Iterations: 26
#             Function evaluations: 4368
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587894518337096e-10
#             Iterations: 39
#             Function evaluations: 6513
#             Gradient evaluations: 39
# 2015-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.0468055149929605e-05
#             Iterations: 276
#             Function evaluations: 46368
#             Gradient evaluations: 276
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.195648290228688
#             Iterations: 30
#             Function evaluations: 5070
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4404843249437167e-09
#             Iterations: 36
#             Function evaluations: 6048
#             Gradient evaluations: 36
# 2015-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.090329061664656e-05
#             Iterations: 226
#             Function evaluations: 38194
#             Gradient evaluations: 226
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4130442998279547
#             Iterations: 38
#             Function evaluations: 6460
#             Gradient evaluations: 38
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6574071438769462e-09
#             Iterations: 48
#             Function evaluations: 8112
#             Gradient evaluations: 48
# 2015-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.544759114630407e-05
#             Iterations: 280
#             Function evaluations: 47600
#             Gradient evaluations: 280
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.636129250340981
#             Iterations: 42
#             Function evaluations: 7181
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3882078968833008e-09
#             Iterations: 49
#             Function evaluations: 8330
#             Gradient evaluations: 49
# 2016-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0594537195568054e-05
#             Iterations: 303
#             Function evaluations: 54238
#             Gradient evaluations: 303
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.0493850469620973
#             Iterations: 54
#             Function evaluations: 9717
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5381301999618654e-09
#             Iterations: 28
#             Function evaluations: 5012
#             Gradient evaluations: 28
# 2016-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7604030719818433e-05
#             Iterations: 309
#             Function evaluations: 55311
#             Gradient evaluations: 309
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.092528435809448
#             Iterations: 53
#             Function evaluations: 9360
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6214098242554567e-09
#             Iterations: 29
#             Function evaluations: 5191
#             Gradient evaluations: 29
# 2016-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.512258088035261e-05
#             Iterations: 313
#             Function evaluations: 56027
#             Gradient evaluations: 313
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.151370325596866
#             Iterations: 58
#             Function evaluations: 10434
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7101787741613396e-09
#             Iterations: 16
#             Function evaluations: 2865
#             Gradient evaluations: 16
# 2016-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.001337659757658e-06
#             Iterations: 390
#             Function evaluations: 69811
#             Gradient evaluations: 390
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.6868728555839896
#             Iterations: 66
#             Function evaluations: 11880
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.989896058334163e-09
#             Iterations: 10
#             Function evaluations: 1790
#             Gradient evaluations: 10
# 2017-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7264328101343765e-05
#             Iterations: 319
#             Function evaluations: 59972
#             Gradient evaluations: 319
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.028817189726197
#             Iterations: 59
#             Function evaluations: 11149
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.675260233577244e-09
#             Iterations: 9
#             Function evaluations: 1692
#             Gradient evaluations: 9
# 2017-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2225455925159908e-05
#             Iterations: 338
#             Function evaluations: 63544
#             Gradient evaluations: 338
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.867270140822428
#             Iterations: 48
#             Function evaluations: 9068
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.465707792630149e-09
#             Iterations: 20
#             Function evaluations: 3760
#             Gradient evaluations: 20
# 2017-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4922659737905843e-05
#             Iterations: 326
#             Function evaluations: 60962
#             Gradient evaluations: 326
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.807990244878377
#             Iterations: 49
#             Function evaluations: 9211
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6836073475159696e-09
#             Iterations: 20
#             Function evaluations: 3740
#             Gradient evaluations: 20
# 2017-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1371516057450396e-05
#             Iterations: 260
#             Function evaluations: 48620
#             Gradient evaluations: 260
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.69384151352532
#             Iterations: 45
#             Function evaluations: 8460
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1957864928884883e-09
#             Iterations: 22
#             Function evaluations: 4114
#             Gradient evaluations: 22
# 2018-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.200264842944741e-05
#             Iterations: 286
#             Function evaluations: 55199
#             Gradient evaluations: 286
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6786903642937547
#             Iterations: 48
#             Function evaluations: 9310
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.539699205234364e-09
#             Iterations: 41
#             Function evaluations: 7914
#             Gradient evaluations: 41
# 2018-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6578970887603103e-05
#             Iterations: 324
#             Function evaluations: 62533
#             Gradient evaluations: 324
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8608978345313387
#             Iterations: 52
#             Function evaluations: 10085
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.094455582568908e-09
#             Iterations: 38
#             Function evaluations: 7334
#             Gradient evaluations: 38
# 2018-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.389434611093665e-05
#             Iterations: 306
#             Function evaluations: 59059
#             Gradient evaluations: 306
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.670661674035206
#             Iterations: 39
#             Function evaluations: 7563
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8129064362805698e-09
#             Iterations: 50
#             Function evaluations: 9650
#             Gradient evaluations: 50
# 2018-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.048504143824518e-05
#             Iterations: 311
#             Function evaluations: 60335
#             Gradient evaluations: 311
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.741205076441886
#             Iterations: 45
#             Function evaluations: 8772
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.709485184870319e-09
#             Iterations: 43
#             Function evaluations: 8342
#             Gradient evaluations: 43
# 2019-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9276497534592775e-05
#             Iterations: 312
#             Function evaluations: 61777
#             Gradient evaluations: 312
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7821369665785185
#             Iterations: 50
#             Function evaluations: 9947
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3900401931405264e-09
#             Iterations: 32
#             Function evaluations: 6337
#             Gradient evaluations: 32
# 2019-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015630367681996097
#             Iterations: 159
#             Function evaluations: 31483
#             Gradient evaluations: 159
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9054239921656275
#             Iterations: 23
#             Function evaluations: 4571
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.035453318189515e-10
#             Iterations: 86
#             Function evaluations: 17028
#             Gradient evaluations: 86
# 2019-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015717781553770891
#             Iterations: 164
#             Function evaluations: 32637
#             Gradient evaluations: 164
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9081736348630296
#             Iterations: 22
#             Function evaluations: 4395
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.714601914125004e-10
#             Iterations: 104
#             Function evaluations: 20697
#             Gradient evaluations: 104
# 2019-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001738678734999268
#             Iterations: 162
#             Function evaluations: 32239
#             Gradient evaluations: 162
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.961729977689875
#             Iterations: 20
#             Function evaluations: 3992
#             Gradient evaluations: 20
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.366140755582507e-10
#             Iterations: 113
#             Function evaluations: 22487
#             Gradient evaluations: 113
# 2020-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00017445683794920227
#             Iterations: 176
#             Function evaluations: 35728
#             Gradient evaluations: 176
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9957738671842753
#             Iterations: 22
#             Function evaluations: 4482
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.294525444352265e-10
#             Iterations: 123
#             Function evaluations: 24970
#             Gradient evaluations: 123
# 2020-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.4479845125770424e-05
#             Iterations: 266
#             Function evaluations: 54264
#             Gradient evaluations: 266
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8077413473830024
#             Iterations: 33
#             Function evaluations: 6761
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.852719655710661e-09
#             Iterations: 58
#             Function evaluations: 11833
#             Gradient evaluations: 58
# 2020-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.479211453447486e-05
#             Iterations: 251
#             Function evaluations: 51204
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.047679187205324
#             Iterations: 43
#             Function evaluations: 8813
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.304042260909686e-09
#             Iterations: 41
#             Function evaluations: 8365
#             Gradient evaluations: 41
# 2020-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5646510822079932e-05
#             Iterations: 321
#             Function evaluations: 65484
#             Gradient evaluations: 321
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.185196039759623
#             Iterations: 54
#             Function evaluations: 11070
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1915011509012906e-09
#             Iterations: 41
#             Function evaluations: 8364
#             Gradient evaluations: 41
# 2021-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.970660715581106e-05
#             Iterations: 312
#             Function evaluations: 63960
#             Gradient evaluations: 312
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.120624557396856
#             Iterations: 41
#             Function evaluations: 8242
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3511150988095723e-09
#             Iterations: 32
#             Function evaluations: 6561
#             Gradient evaluations: 32
# 2021-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.316104845959792e-05
#             Iterations: 292
#             Function evaluations: 59860
#             Gradient evaluations: 292
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6920919320365244
#             Iterations: 46
#             Function evaluations: 8648
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.369721823606137e-09
#             Iterations: 38
#             Function evaluations: 7791
#             Gradient evaluations: 38
# 2021-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.6902910255240166e-05
#             Iterations: 241
#             Function evaluations: 49405
#             Gradient evaluations: 241
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3946652495031993
#             Iterations: 34
#             Function evaluations: 7004
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5953800380107023e-09
#             Iterations: 47
#             Function evaluations: 9635
#             Gradient evaluations: 47
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.231610610649447e-05
#             Iterations: 248
#             Function evaluations: 50841
#             Gradient evaluations: 248
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.202603291143996
#             Iterations: 33
#             Function evaluations: 6797
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.936401038241577e-10
#             Iterations: 58
#             Function evaluations: 11890
#             Gradient evaluations: 58
# 2022-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.348271393621996e-05
#             Iterations: 249
#             Function evaluations: 52539
#             Gradient evaluations: 249
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1572843002398034
#             Iterations: 30
#             Function evaluations: 6358
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.886043066076074e-10
#             Iterations: 56
#             Function evaluations: 11817
#             Gradient evaluations: 56
# 2022-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.958458023737242e-05
#             Iterations: 253
#             Function evaluations: 53384
#             Gradient evaluations: 253
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2281828414718454
#             Iterations: 32
#             Function evaluations: 6783
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4897523194623026e-09
#             Iterations: 48
#             Function evaluations: 10128
#             Gradient evaluations: 48
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.1151531262350334e-05
#             Iterations: 265
#             Function evaluations: 55915
#             Gradient evaluations: 265
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.40263858691349
#             Iterations: 36
#             Function evaluations: 7631
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6512827184744449e-09
#             Iterations: 41
#             Function evaluations: 8652
#             Gradient evaluations: 41
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.108549385110914e-05
#             Iterations: 271
#             Function evaluations: 57181
#             Gradient evaluations: 271
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8895974860063958
#             Iterations: 46
#             Function evaluations: 9747
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0345295640017866e-09
#             Iterations: 39
#             Function evaluations: 8229
#             Gradient evaluations: 39
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4498007295133784e-05
#             Iterations: 316
#             Function evaluations: 66676
#             Gradient evaluations: 316
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.2011627534730436
#             Iterations: 49
#             Function evaluations: 10174
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1448304611683767e-09
#             Iterations: 38
#             Function evaluations: 8019
#             Gradient evaluations: 38
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0453517837100635e-05
#             Iterations: 294
#             Function evaluations: 62035
#             Gradient evaluations: 294
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.482118528374129
#             Iterations: 68
#             Function evaluations: 13571
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5246515637222703e-09
#             Iterations: 26
#             Function evaluations: 5486
#             Gradient evaluations: 26
# 2023-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9321698617059978e-05
#             Iterations: 302
#             Function evaluations: 63722
#             Gradient evaluations: 302
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.714053158351852
#             Iterations: 63
#             Function evaluations: 12504
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2798766168525553e-09
#             Iterations: 32
#             Function evaluations: 6752
#             Gradient evaluations: 32
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8104246525629658e-05
#             Iterations: 305
#             Function evaluations: 64356
#             Gradient evaluations: 305
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7842843929033183
#             Iterations: 68
#             Function evaluations: 13566
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5028171951972646e-09
#             Iterations: 33
#             Function evaluations: 6963
#             Gradient evaluations: 33
# 2024-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9527648592660317e-05
#             Iterations: 312
#             Function evaluations: 67704
#             Gradient evaluations: 312
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8053089904656034
#             Iterations: 69
#             Function evaluations: 14172
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5998499302144255e-09
#             Iterations: 21
#             Function evaluations: 4558
#             Gradient evaluations: 21
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_reduziert.to_csv("returnsreduziert_3Monate_f.csv")

# %% [markdown]
# ### Reduziert und Ledoit-Shrinkage

# %%
returns = df_SP500_reduziert.pct_change()
returns = returns.where(~df_SP500_reduziert.isna())
returns = returns.iloc[1:]
returns.index = pd.to_datetime(returns.index)
returns.info
# Out:
# <bound method DataFrame.info of                    A      AAPL       ABT       ACN       ADI       ADM  \
# Date
# 2005-06-02  0.000414 -0.006452       NaN       NaN       NaN       NaN
# 2005-06-03 -0.005374 -0.044955       NaN       NaN       NaN       NaN
# 2005-06-06  0.019119 -0.008368       NaN       NaN       NaN       NaN
# 2005-06-07 -0.012235 -0.036393       NaN       NaN       NaN       NaN
# 2005-06-08  0.009496  0.010399       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23 -0.010485 -0.030244 -0.001521 -0.021710 -0.006889 -0.000417
# 2025-05-27  0.025154  0.025298  0.012490  0.018897  0.030503  0.014393
# 2025-05-28 -0.003415  0.001049 -0.006920  0.001775 -0.005856 -0.005758
# 2025-05-29  0.021645 -0.002345  0.006287  0.005507  0.000603  0.000414
# 2025-05-30 -0.012006  0.004501  0.005495 -0.002864 -0.008204 -0.002067
#
#                  ADP      ADSK       AES       AIZ  ...       VLO      VRSN  \
# Date                                                ...
# 2005-06-02       NaN       NaN -0.014875       NaN  ...       NaN       NaN
# 2005-06-03       NaN       NaN -0.011668       NaN  ...       NaN       NaN
# 2005-06-06       NaN       NaN  0.041667       NaN  ...       NaN       NaN
# 2005-06-07       NaN       NaN -0.004000       NaN  ...       NaN       NaN
# 2005-06-08       NaN       NaN -0.006693       NaN  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-23 -0.001741  0.001186  0.037383  0.018133  ... -0.001321 -0.007450
# 2025-05-27  0.014388  0.016963  0.008008  0.022797  ...  0.016803 -0.036460
# 2025-05-28 -0.004820 -0.003762 -0.036743 -0.015224  ... -0.028919 -0.001558
# 2025-05-29 -0.000062 -0.007452  0.036083  0.010205  ...  0.017569 -0.001709
# 2025-05-30  0.004350 -0.002963  0.003980  0.015103  ... -0.001471  0.014106
#
#                 VRTX       WAT       WFC       WRB       XEL       YUM  \
# Date
# 2005-06-02       NaN -0.013181  0.000488       NaN       NaN       NaN
# 2005-06-03       NaN -0.013614 -0.002925       NaN       NaN       NaN
# 2005-06-06       NaN -0.007292  0.001467       NaN       NaN       NaN
# 2005-06-07       NaN  0.004984 -0.001139       NaN       NaN       NaN
# 2005-06-08       NaN -0.009397  0.002118       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23  0.004539 -0.005998 -0.007630  0.012329  0.007513 -0.000344
# 2025-05-27  0.022936  0.034616  0.015927  0.015326  0.001147 -0.009350
# 2025-05-28 -0.002018 -0.010520 -0.003514 -0.012264 -0.012606 -0.006524
# 2025-05-29  0.004471  0.002002  0.010579  0.009142  0.007834  0.006217
# 2025-05-30 -0.011273 -0.017056  0.003624  0.009870  0.009069 -0.000694
#
#                  ZBH       ZTS
# Date
# 2005-06-02  0.002885       NaN
# 2005-06-03  0.029816       NaN
# 2005-06-06 -0.005079       NaN
# 2005-06-07  0.013657       NaN
# 2005-06-08 -0.005414       NaN
# ...              ...       ...
# 2025-05-23  0.010581  0.003766
# 2025-05-27  0.016947  0.022635
# 2025-05-28 -0.020380 -0.005173
# 2025-05-29  0.011377  0.010520
# 2025-05-30 -0.012535  0.008915
#
# [5031 rows x 217 columns]>

# %%
#Definieren von Start und Ende des gesamten Datenbestandes
start_datum = pd.Timestamp('2005-06-01')
end_datum = pd.Timestamp('2025-05-31')

#Liste der Portfolio-Tagesrenditen
portfolio_returns_list = []

#Definieren der Trainings- und Testzeitfenster in Monaten
training_fenster = 12
test_fenster = 3
 
#Setzen der Start-und Endzeitpunkte
training_anfang = start_datum
training_ende = start_datum + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
training_ende = training_ende + MonthEnd(0)
test_anfang = training_ende + pd.DateOffset(days = 1)
test_anfang = test_anfang + MonthBegin(0)
test_ende = training_ende + pd.DateOffset(months = test_fenster)
test_ende = test_ende + MonthEnd(0)

#Rollierende Ergebniserzeugung
while training_ende + pd.DateOffset(months = test_fenster) <= end_datum:
    
    print(training_anfang)
    
    #Definition des Trainingsdatensatzes und des Testdatensatzes
    training_daten = returns.loc[training_anfang:training_ende]
    test_daten = returns.loc[test_anfang:test_ende]
    training_daten = training_daten.dropna(axis=1)
    
    #Um aussagekräftige Kovarianzmatrizen erzeugen zu können, werden nur Assets berücksichtigt, die nicht zu viele 0-Renditen im Datensatz haben
    max_null_tage = 63
    null_zaehler = (training_daten == 0).sum()
    valide_tickers = null_zaehler[null_zaehler <= max_null_tage].index
    training_daten = training_daten[valide_tickers]
    
    #Anpassung der Spalten in den Test-Daten passend zu Trainingsdaten (rausfallende Cash-Out, neue ohne Investment)
    vorhandene_assets = test_daten.columns.intersection(training_daten.columns)
    test_daten = test_daten[vorhandene_assets]
    test_daten = test_daten.fillna(0) #Annahme: ab Ausfall keine Performance, Cash-Out
    
    #Erzeugung Matrizen
    cov_matrix = ledoit_shrink(training_daten)
    
    #aus der geschrumpften Matrix die Korrelationsmatrix bauen
    standardabweichung = np.sqrt(np.diag(cov_matrix))
    corr_matrix = cov_matrix / np.outer(standardabweichung, standardabweichung)
    
    #Ermittlung der Gewichte anhand der Trainingsdaten
    reduziert_shrinked_gewichte_equally_weighted = equally_weighted(training_daten)
    reduziert_shrinked_gewichte_min_variance= min_variance_opt(cov_matrix)
    reduziert_shrinked_gewichte_max_diversification = max_diversification_portfolio(cov_matrix)
    reduziert_shrinked_gewichte_inverse_volatility = inverse_volatility_portfolio(cov_matrix)
    reduziert_shrinked_gewichte_risk_parity = get_risk_parity_weights(cov_matrix)
    reduziert_shrinked_gewichte_hrp = hrp_main(corr_matrix, cov_matrix, training_daten)
    reduziert_shrinked_gewichte_herc = herc_ledoit(training_daten)
    
    gewichte_dict = {
    "Equally-Weighted": reduziert_shrinked_gewichte_equally_weighted,
    "Minimum-Variance": reduziert_shrinked_gewichte_min_variance,
    "Maximum-Diversification": reduziert_shrinked_gewichte_max_diversification,
    "Inverse-Volatility": reduziert_shrinked_gewichte_inverse_volatility,
    "Equal-Risk-Contribution": reduziert_shrinked_gewichte_risk_parity,
    "HRP": reduziert_shrinked_gewichte_hrp,
    "HERC": reduziert_shrinked_gewichte_herc
    }
    
    #Ermitteln der Ergebnisse und Überführen in Ergebnis-Tabellen
    test_portfolio_returns = pd.DataFrame(index=test_daten.index)
    for methode, gewichte in gewichte_dict.items():
        test_portfolio_returns[methode] = test_daten @ gewichte
    
    # Ergebnisse speichern
    portfolio_returns_list.append(test_portfolio_returns)
    
     #Weiter rollieren
    training_anfang = training_anfang + pd.DateOffset(months = test_fenster)
    training_anfang = training_anfang + MonthBegin(0)
    training_ende = training_anfang + pd.DateOffset(months = training_fenster) - pd.DateOffset(days = 1)
    training_ende = training_ende + MonthEnd(0)
    test_anfang = training_ende + pd.DateOffset(days = 1)
    test_anfang = test_anfang + MonthBegin(0)
    test_ende = training_ende + pd.DateOffset(months = test_fenster)
    test_ende = test_ende + MonthEnd(0)
    
#Alle Testperioden zusammenführen
portfolio_returns_df_reduziert_shrinked = pd.concat(portfolio_returns_list)
portfolio_returns_df_reduziert_shrinked = portfolio_returns_df_reduziert_shrinked.reset_index().rename(columns={"index": "Date"})
    
print("Prozedur abgeschlossen")
# Out:
# 2005-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.068558709922772e-05
#             Iterations: 262
#             Function evaluations: 26986
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6511078138392
#             Iterations: 48
#             Function evaluations: 4991
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9801819573744985e-09
#             Iterations: 20
#             Function evaluations: 2060
#             Gradient evaluations: 20
# 2005-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1337054481984163e-05
#             Iterations: 243
#             Function evaluations: 25758
#             Gradient evaluations: 243
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.62236971267672
#             Iterations: 45
#             Function evaluations: 4815
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7209725690258e-09
#             Iterations: 44
#             Function evaluations: 4665
#             Gradient evaluations: 44
# 2005-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7090695295607643e-05
#             Iterations: 223
#             Function evaluations: 24084
#             Gradient evaluations: 223
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.822690256880799
#             Iterations: 51
#             Function evaluations: 5556
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3301261847075104e-09
#             Iterations: 33
#             Function evaluations: 3564
#             Gradient evaluations: 33
# 2006-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.772520246759691e-05
#             Iterations: 221
#             Function evaluations: 25415
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6492143126548826
#             Iterations: 44
#             Function evaluations: 5104
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8992657409632197e-09
#             Iterations: 31
#             Function evaluations: 3565
#             Gradient evaluations: 31
# 2006-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.79588839349678e-05
#             Iterations: 229
#             Function evaluations: 26335
#             Gradient evaluations: 229
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.716516627849747
#             Iterations: 50
#             Function evaluations: 5800
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1906232743412936e-09
#             Iterations: 33
#             Function evaluations: 3795
#             Gradient evaluations: 33
# 2006-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8337675250845002e-05
#             Iterations: 234
#             Function evaluations: 26910
#             Gradient evaluations: 234
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5817920498688967
#             Iterations: 42
#             Function evaluations: 4870
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2849092875597742e-09
#             Iterations: 33
#             Function evaluations: 3795
#             Gradient evaluations: 33
# 2006-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.819598606506064e-05
#             Iterations: 177
#             Function evaluations: 20355
#             Gradient evaluations: 177
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3295094710007476
#             Iterations: 30
#             Function evaluations: 3480
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.614478717004363e-10
#             Iterations: 42
#             Function evaluations: 4830
#             Gradient evaluations: 42
# 2007-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.921850538958274e-05
#             Iterations: 145
#             Function evaluations: 17690
#             Gradient evaluations: 145
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.299595190927548
#             Iterations: 34
#             Function evaluations: 4181
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5435141566134135e-09
#             Iterations: 41
#             Function evaluations: 5003
#             Gradient evaluations: 41
# 2007-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.6252425712278434e-05
#             Iterations: 153
#             Function evaluations: 18666
#             Gradient evaluations: 153
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4501496718585263
#             Iterations: 29
#             Function evaluations: 3568
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.5274305668087737e-10
#             Iterations: 61
#             Function evaluations: 7442
#             Gradient evaluations: 61
# 2007-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.7458012129708145e-05
#             Iterations: 203
#             Function evaluations: 24766
#             Gradient evaluations: 203
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4435283513023394
#             Iterations: 30
#             Function evaluations: 3689
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.605256934557082e-10
#             Iterations: 70
#             Function evaluations: 8540
#             Gradient evaluations: 70
# 2007-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021483732436094428
#             Iterations: 112
#             Function evaluations: 13776
#             Gradient evaluations: 112
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8025238484959207
#             Iterations: 22
#             Function evaluations: 2723
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1460553778536066e-10
#             Iterations: 78
#             Function evaluations: 9594
#             Gradient evaluations: 78
# 2008-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00023961366770006148
#             Iterations: 117
#             Function evaluations: 14859
#             Gradient evaluations: 117
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7740004807916947
#             Iterations: 22
#             Function evaluations: 2808
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4176928019094525e-10
#             Iterations: 92
#             Function evaluations: 11685
#             Gradient evaluations: 92
# 2008-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00025754278353979124
#             Iterations: 100
#             Function evaluations: 12700
#             Gradient evaluations: 100
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.6489914692526664
#             Iterations: 23
#             Function evaluations: 2938
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.488965859949403e-10
#             Iterations: 98
#             Function evaluations: 12447
#             Gradient evaluations: 98
# 2008-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00024156931363108355
#             Iterations: 96
#             Function evaluations: 12192
#             Gradient evaluations: 96
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.6642421010636157
#             Iterations: 21
#             Function evaluations: 2680
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.819471908937439e-10
#             Iterations: 107
#             Function evaluations: 13589
#             Gradient evaluations: 107
# 2008-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.13047979861831e-05
#             Iterations: 129
#             Function evaluations: 16512
#             Gradient evaluations: 129
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9834214809428932
#             Iterations: 25
#             Function evaluations: 3222
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.9992223480307345e-10
#             Iterations: 169
#             Function evaluations: 21633
#             Gradient evaluations: 169
# 2009-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.4101376997643074e-05
#             Iterations: 152
#             Function evaluations: 21737
#             Gradient evaluations: 152
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.181784743820974
#             Iterations: 28
#             Function evaluations: 4029
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.866199822832166e-10
#             Iterations: 125
#             Function evaluations: 17875
#             Gradient evaluations: 125
# 2009-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.126809792754314e-05
#             Iterations: 211
#             Function evaluations: 30173
#             Gradient evaluations: 211
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1990058615013677
#             Iterations: 29
#             Function evaluations: 4172
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.565722637539197e-10
#             Iterations: 60
#             Function evaluations: 8580
#             Gradient evaluations: 60
# 2009-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.333732284135419e-05
#             Iterations: 182
#             Function evaluations: 26027
#             Gradient evaluations: 182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0221765604987967
#             Iterations: 25
#             Function evaluations: 3594
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0149197696080385e-09
#             Iterations: 52
#             Function evaluations: 7436
#             Gradient evaluations: 52
# 2009-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.833302630402602e-05
#             Iterations: 197
#             Function evaluations: 28171
#             Gradient evaluations: 197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.904543490153316
#             Iterations: 22
#             Function evaluations: 3165
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.72174801046665e-10
#             Iterations: 52
#             Function evaluations: 7436
#             Gradient evaluations: 52
# 2010-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.471310211858311e-05
#             Iterations: 175
#             Function evaluations: 25201
#             Gradient evaluations: 175
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.9868883913940387
#             Iterations: 25
#             Function evaluations: 3622
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.131054002313916e-09
#             Iterations: 53
#             Function evaluations: 7632
#             Gradient evaluations: 53
# 2010-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8550550408859802e-05
#             Iterations: 172
#             Function evaluations: 24768
#             Gradient evaluations: 172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.127017477382424
#             Iterations: 30
#             Function evaluations: 4346
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4331866702524086e-09
#             Iterations: 42
#             Function evaluations: 6049
#             Gradient evaluations: 42
# 2010-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.019811017897637e-05
#             Iterations: 165
#             Function evaluations: 23761
#             Gradient evaluations: 165
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8271489120887416
#             Iterations: 24
#             Function evaluations: 3477
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0155409113148262e-09
#             Iterations: 52
#             Function evaluations: 7488
#             Gradient evaluations: 52
# 2010-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.483693165912601e-05
#             Iterations: 146
#             Function evaluations: 21024
#             Gradient evaluations: 146
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.677017339456309
#             Iterations: 21
#             Function evaluations: 3036
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.753249250335283e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.588828327951158e-05
#             Iterations: 165
#             Function evaluations: 23761
#             Gradient evaluations: 165
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.7317825680399375
#             Iterations: 23
#             Function evaluations: 3326
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.166834323318394e-10
#             Iterations: 70
#             Function evaluations: 10080
#             Gradient evaluations: 70
# 2011-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.535484624477159e-05
#             Iterations: 156
#             Function evaluations: 22464
#             Gradient evaluations: 156
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.725505592507676
#             Iterations: 23
#             Function evaluations: 3326
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.974445511070134e-10
#             Iterations: 69
#             Function evaluations: 9936
#             Gradient evaluations: 69
# 2011-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.337664586375212e-05
#             Iterations: 188
#             Function evaluations: 27072
#             Gradient evaluations: 188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0231737689931677
#             Iterations: 26
#             Function evaluations: 3769
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.975450638383764e-10
#             Iterations: 79
#             Function evaluations: 11376
#             Gradient evaluations: 79
# 2011-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0651465129527578e-05
#             Iterations: 235
#             Function evaluations: 33840
#             Gradient evaluations: 235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.424350177061322
#             Iterations: 32
#             Function evaluations: 4640
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1430588923012695e-09
#             Iterations: 51
#             Function evaluations: 7344
#             Gradient evaluations: 51
# 2012-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1577226993486775e-05
#             Iterations: 247
#             Function evaluations: 35569
#             Gradient evaluations: 247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3304368310104198
#             Iterations: 32
#             Function evaluations: 4639
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.055138050144455e-09
#             Iterations: 42
#             Function evaluations: 6048
#             Gradient evaluations: 42
# 2012-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4538276575218678e-05
#             Iterations: 241
#             Function evaluations: 34705
#             Gradient evaluations: 241
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3650000754036595
#             Iterations: 33
#             Function evaluations: 4783
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0348944582843632e-09
#             Iterations: 42
#             Function evaluations: 6048
#             Gradient evaluations: 42
# 2012-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6373124556111437e-05
#             Iterations: 262
#             Function evaluations: 37728
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4179712777793703
#             Iterations: 32
#             Function evaluations: 4641
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.746939041488598e-10
#             Iterations: 32
#             Function evaluations: 4609
#             Gradient evaluations: 32
# 2012-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.408783701158818e-05
#             Iterations: 274
#             Function evaluations: 39457
#             Gradient evaluations: 274
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.543750547563549
#             Iterations: 35
#             Function evaluations: 5076
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.364330815821692e-09
#             Iterations: 21
#             Function evaluations: 3024
#             Gradient evaluations: 21
# 2013-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5952069512678103e-05
#             Iterations: 248
#             Function evaluations: 37200
#             Gradient evaluations: 248
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4760987227758697
#             Iterations: 41
#             Function evaluations: 6188
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1006720991012197e-09
#             Iterations: 21
#             Function evaluations: 3150
#             Gradient evaluations: 21
# 2013-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3813400081944086e-05
#             Iterations: 267
#             Function evaluations: 40051
#             Gradient evaluations: 267
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4525310188909275
#             Iterations: 37
#             Function evaluations: 5585
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7271588824091818e-09
#             Iterations: 21
#             Function evaluations: 3150
#             Gradient evaluations: 21
# 2013-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.940566499597267e-05
#             Iterations: 268
#             Function evaluations: 40201
#             Gradient evaluations: 268
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.527899214517681
#             Iterations: 45
#             Function evaluations: 6791
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6516041527611984e-09
#             Iterations: 19
#             Function evaluations: 2850
#             Gradient evaluations: 19
# 2013-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0097322345817476e-05
#             Iterations: 256
#             Function evaluations: 38400
#             Gradient evaluations: 256
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.419728026435166
#             Iterations: 39
#             Function evaluations: 5889
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.080504853456581e-09
#             Iterations: 20
#             Function evaluations: 3000
#             Gradient evaluations: 20
# 2014-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2704597243845808e-05
#             Iterations: 261
#             Function evaluations: 41499
#             Gradient evaluations: 261
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.5185418034721
#             Iterations: 44
#             Function evaluations: 7041
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3615846243212637e-09
#             Iterations: 21
#             Function evaluations: 3340
#             Gradient evaluations: 21
# 2014-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.783713665508944e-05
#             Iterations: 230
#             Function evaluations: 36570
#             Gradient evaluations: 230
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.3692317909181013
#             Iterations: 35
#             Function evaluations: 5600
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.73852002032358e-09
#             Iterations: 9
#             Function evaluations: 1432
#             Gradient evaluations: 9
# 2014-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.097402484783674e-05
#             Iterations: 254
#             Function evaluations: 40386
#             Gradient evaluations: 254
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1182368308311212
#             Iterations: 29
#             Function evaluations: 4641
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7676309922297037e-09
#             Iterations: 20
#             Function evaluations: 3180
#             Gradient evaluations: 20
# 2014-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.9004713388664054e-05
#             Iterations: 255
#             Function evaluations: 40800
#             Gradient evaluations: 255
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.0899498682986075
#             Iterations: 30
#             Function evaluations: 4829
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.299363774050765e-10
#             Iterations: 30
#             Function evaluations: 4800
#             Gradient evaluations: 30
# 2015-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.066968714596362e-05
#             Iterations: 286
#             Function evaluations: 47762
#             Gradient evaluations: 286
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1344055367850863
#             Iterations: 27
#             Function evaluations: 4535
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.314876852395903e-10
#             Iterations: 39
#             Function evaluations: 6513
#             Gradient evaluations: 39
# 2015-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.9373008978846424e-05
#             Iterations: 227
#             Function evaluations: 38136
#             Gradient evaluations: 227
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2199245623883046
#             Iterations: 36
#             Function evaluations: 6083
#             Gradient evaluations: 36
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3728992975491576e-09
#             Iterations: 37
#             Function evaluations: 6217
#             Gradient evaluations: 37
# 2015-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.988643472167371e-05
#             Iterations: 241
#             Function evaluations: 40729
#             Gradient evaluations: 241
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.441594617260232
#             Iterations: 39
#             Function evaluations: 6630
#             Gradient evaluations: 39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5721746576798726e-09
#             Iterations: 48
#             Function evaluations: 8112
#             Gradient evaluations: 48
# 2015-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.454183689111872e-05
#             Iterations: 263
#             Function evaluations: 44711
#             Gradient evaluations: 263
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.6671309347238568
#             Iterations: 43
#             Function evaluations: 7353
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3009945464747836e-09
#             Iterations: 49
#             Function evaluations: 8330
#             Gradient evaluations: 49
# 2016-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9659448972130323e-05
#             Iterations: 290
#             Function evaluations: 51910
#             Gradient evaluations: 290
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1113942200320244
#             Iterations: 57
#             Function evaluations: 10258
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2017544410293427e-09
#             Iterations: 28
#             Function evaluations: 5012
#             Gradient evaluations: 28
# 2016-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6605645427167005e-05
#             Iterations: 279
#             Function evaluations: 49942
#             Gradient evaluations: 279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1755760401338606
#             Iterations: 60
#             Function evaluations: 10800
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3182952756908822e-09
#             Iterations: 29
#             Function evaluations: 5191
#             Gradient evaluations: 29
# 2016-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4187814896881602e-05
#             Iterations: 309
#             Function evaluations: 55312
#             Gradient evaluations: 309
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.2681733081259026
#             Iterations: 64
#             Function evaluations: 11337
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3372980596609563e-09
#             Iterations: 17
#             Function evaluations: 3043
#             Gradient evaluations: 17
# 2016-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.537879439547573e-06
#             Iterations: 328
#             Function evaluations: 58712
#             Gradient evaluations: 328
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.848939897845526
#             Iterations: 75
#             Function evaluations: 13325
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.260808678904619e-09
#             Iterations: 10
#             Function evaluations: 1790
#             Gradient evaluations: 10
# 2017-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.611252465105055e-05
#             Iterations: 281
#             Function evaluations: 52828
#             Gradient evaluations: 281
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.1319287005786136
#             Iterations: 62
#             Function evaluations: 11718
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.988917141493055e-09
#             Iterations: 9
#             Function evaluations: 1692
#             Gradient evaluations: 9
# 2017-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1246944926716554e-05
#             Iterations: 283
#             Function evaluations: 53204
#             Gradient evaluations: 283
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.930155797705595
#             Iterations: 53
#             Function evaluations: 10016
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1580488730471493e-09
#             Iterations: 20
#             Function evaluations: 3760
#             Gradient evaluations: 20
# 2017-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3576244678679057e-05
#             Iterations: 285
#             Function evaluations: 53296
#             Gradient evaluations: 285
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8724348385774006
#             Iterations: 52
#             Function evaluations: 9773
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4347093473889332e-09
#             Iterations: 20
#             Function evaluations: 3740
#             Gradient evaluations: 20
# 2017-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9993509539989655e-05
#             Iterations: 259
#             Function evaluations: 48433
#             Gradient evaluations: 259
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.74688835979106
#             Iterations: 43
#             Function evaluations: 8086
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9320034416149537e-09
#             Iterations: 22
#             Function evaluations: 4114
#             Gradient evaluations: 22
# 2018-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.095418849931409e-05
#             Iterations: 282
#             Function evaluations: 54426
#             Gradient evaluations: 282
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7244888383260233
#             Iterations: 52
#             Function evaluations: 10084
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.366796753291621e-09
#             Iterations: 41
#             Function evaluations: 7914
#             Gradient evaluations: 41
# 2018-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5805229559414356e-05
#             Iterations: 278
#             Function evaluations: 53655
#             Gradient evaluations: 278
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9111682130457885
#             Iterations: 56
#             Function evaluations: 10862
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8607202901691653e-09
#             Iterations: 34
#             Function evaluations: 6562
#             Gradient evaluations: 34
# 2018-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.301169288876025e-05
#             Iterations: 298
#             Function evaluations: 57514
#             Gradient evaluations: 298
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7038835274179704
#             Iterations: 41
#             Function evaluations: 7951
#             Gradient evaluations: 41
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.787195744699705e-09
#             Iterations: 39
#             Function evaluations: 7527
#             Gradient evaluations: 39
# 2018-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.960284111809578e-05
#             Iterations: 267
#             Function evaluations: 51799
#             Gradient evaluations: 267
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.778682674928608
#             Iterations: 52
#             Function evaluations: 10138
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.994345531207907e-09
#             Iterations: 32
#             Function evaluations: 6209
#             Gradient evaluations: 32
# 2019-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8257094894025957e-05
#             Iterations: 292
#             Function evaluations: 57816
#             Gradient evaluations: 292
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8217445560075185
#             Iterations: 54
#             Function evaluations: 10746
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.225591960411621e-09
#             Iterations: 33
#             Function evaluations: 6534
#             Gradient evaluations: 33
# 2019-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015103626241617105
#             Iterations: 152
#             Function evaluations: 30097
#             Gradient evaluations: 152
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.974949843080331
#             Iterations: 22
#             Function evaluations: 4374
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.322620919387401e-10
#             Iterations: 87
#             Function evaluations: 17226
#             Gradient evaluations: 87
# 2019-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001533638296946301
#             Iterations: 136
#             Function evaluations: 27065
#             Gradient evaluations: 136
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.968854210065282
#             Iterations: 24
#             Function evaluations: 4796
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.92361097361791e-10
#             Iterations: 105
#             Function evaluations: 20895
#             Gradient evaluations: 105
# 2019-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001706362963578513
#             Iterations: 139
#             Function evaluations: 27661
#             Gradient evaluations: 139
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.002074512397377
#             Iterations: 23
#             Function evaluations: 4592
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.716708726828573e-10
#             Iterations: 114
#             Function evaluations: 22686
#             Gradient evaluations: 114
# 2020-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00017122366446506833
#             Iterations: 169
#             Function evaluations: 34307
#             Gradient evaluations: 169
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.033399775668096
#             Iterations: 22
#             Function evaluations: 4484
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.498908436032042e-10
#             Iterations: 124
#             Function evaluations: 25173
#             Gradient evaluations: 124
# 2020-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.317748638077612e-05
#             Iterations: 221
#             Function evaluations: 45084
#             Gradient evaluations: 221
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.8473124042152054
#             Iterations: 40
#             Function evaluations: 8200
#             Gradient evaluations: 40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.442176439386253e-09
#             Iterations: 59
#             Function evaluations: 12037
#             Gradient evaluations: 59
# 2020-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.299808638227844e-05
#             Iterations: 207
#             Function evaluations: 42228
#             Gradient evaluations: 207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.111461929211641
#             Iterations: 48
#             Function evaluations: 9842
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.835342638080953e-09
#             Iterations: 41
#             Function evaluations: 8365
#             Gradient evaluations: 41
# 2020-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4869255945455282e-05
#             Iterations: 287
#             Function evaluations: 58548
#             Gradient evaluations: 287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.229270202936395
#             Iterations: 57
#             Function evaluations: 11482
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.989243785044526e-09
#             Iterations: 41
#             Function evaluations: 8364
#             Gradient evaluations: 41
# 2021-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8845884999209437e-05
#             Iterations: 318
#             Function evaluations: 65190
#             Gradient evaluations: 318
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.152848256969397
#             Iterations: 42
#             Function evaluations: 8649
#             Gradient evaluations: 42
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.212893155646206e-09
#             Iterations: 32
#             Function evaluations: 6561
#             Gradient evaluations: 32
# 2021-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.200561133112604e-05
#             Iterations: 259
#             Function evaluations: 53095
#             Gradient evaluations: 259
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.7268581666619367
#             Iterations: 43
#             Function evaluations: 8853
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2347313716952904e-09
#             Iterations: 38
#             Function evaluations: 7790
#             Gradient evaluations: 38
# 2021-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.5640133291716026e-05
#             Iterations: 255
#             Function evaluations: 52275
#             Gradient evaluations: 255
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.4237185997387085
#             Iterations: 37
#             Function evaluations: 7621
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5232463122242004e-09
#             Iterations: 47
#             Function evaluations: 9635
#             Gradient evaluations: 47
# 2021-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.120665236936547e-05
#             Iterations: 250
#             Function evaluations: 51250
#             Gradient evaluations: 250
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.228138697365681
#             Iterations: 32
#             Function evaluations: 6592
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.562408509300391e-10
#             Iterations: 58
#             Function evaluations: 11890
#             Gradient evaluations: 58
# 2022-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.217307366330243e-05
#             Iterations: 225
#             Function evaluations: 47476
#             Gradient evaluations: 225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.1834235503747164
#             Iterations: 31
#             Function evaluations: 6570
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3042730524737306e-09
#             Iterations: 46
#             Function evaluations: 9707
#             Gradient evaluations: 46
# 2022-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.83027864561891e-05
#             Iterations: 226
#             Function evaluations: 47686
#             Gradient evaluations: 226
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.2585587626599475
#             Iterations: 33
#             Function evaluations: 6994
#             Gradient evaluations: 33
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4232756562717557e-09
#             Iterations: 48
#             Function evaluations: 10128
#             Gradient evaluations: 48
# 2022-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.954661903251922e-05
#             Iterations: 232
#             Function evaluations: 48952
#             Gradient evaluations: 232
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.437892014571878
#             Iterations: 37
#             Function evaluations: 7843
#             Gradient evaluations: 37
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5564349318884864e-09
#             Iterations: 41
#             Function evaluations: 8652
#             Gradient evaluations: 41
# 2022-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.999813301548462e-05
#             Iterations: 258
#             Function evaluations: 54438
#             Gradient evaluations: 258
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2.9315102861577227
#             Iterations: 46
#             Function evaluations: 9747
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9001313199290736e-09
#             Iterations: 39
#             Function evaluations: 8229
#             Gradient evaluations: 39
# 2023-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3720593797624813e-05
#             Iterations: 299
#             Function evaluations: 63089
#             Gradient evaluations: 299
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.242104366408943
#             Iterations: 66
#             Function evaluations: 13153
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9183758338917725e-09
#             Iterations: 38
#             Function evaluations: 8019
#             Gradient evaluations: 38
# 2023-06-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9604968886548632e-05
#             Iterations: 262
#             Function evaluations: 55282
#             Gradient evaluations: 262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.5396286273022137
#             Iterations: 57
#             Function evaluations: 12080
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.209351805185172e-09
#             Iterations: 27
#             Function evaluations: 5697
#             Gradient evaluations: 27
# 2023-09-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8673650036426046e-05
#             Iterations: 280
#             Function evaluations: 59081
#             Gradient evaluations: 280
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7616346087650547
#             Iterations: 61
#             Function evaluations: 12930
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.077258410431351e-09
#             Iterations: 21
#             Function evaluations: 4432
#             Gradient evaluations: 21
# 2023-12-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7142097511704284e-05
#             Iterations: 251
#             Function evaluations: 52962
#             Gradient evaluations: 251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.8899534090777754
#             Iterations: 68
#             Function evaluations: 14419
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.978264312522957e-09
#             Iterations: 20
#             Function evaluations: 4221
#             Gradient evaluations: 20
# 2024-03-01 00:00:00
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8463465219869636e-05
#             Iterations: 252
#             Function evaluations: 54685
#             Gradient evaluations: 252
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.910095597467382
#             Iterations: 92
#             Function evaluations: 19191
#             Gradient evaluations: 88
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.057901365513298e-09
#             Iterations: 20
#             Function evaluations: 4340
#             Gradient evaluations: 20
# Prozedur abgeschlossen

# %%
#Exportieren nach CSV
portfolio_returns_df_reduziert_shrinked.to_csv("returnsreduziertshrinked_3Monate_f.csv")
